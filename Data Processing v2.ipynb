# %%
# Construction of dataset

import os, itertools, time, pickle, sys, glob, requests
import subprocess
from xml.dom import minidom
from collections import Counter, OrderedDict
from operator import itemgetter
from nltk.corpus import wordnet
import tensorflow as tf
import tensorflow_hub as hub
from scipy import spatial
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from sklearn.feature_extraction.text import TfidfVectorizer
import re
import numpy as np
import scipy.sparse as sp
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from math import ceil, exp
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
flatten = lambda l: [item for sublist in l for item in sublist]

class Ontology():
    def __init__(self, ontology):
        self.ontology = ontology
        self.ontology_obj = minidom.parse(ontology)
        self.root = self.ontology_obj.documentElement
        self.construct_mapping_dict()
        
        self.subclasses = self.parse_subclasses()
        self.object_properties = self.parse_object_properties()
        self.data_properties = self.parse_data_properties()
        self.triples = self.parse_triples()
        self.classes = self.parse_classes()        
    
    def construct_mapping_dict(self):
        self.mapping_dict = {self.extract_ID(el, False): self.get_child_node(el, "rdfs:label")[0].firstChild.nodeValue for el in self.root.getElementsByTagName("owl:Class") if self.get_child_node(el, "rdfs:label")}
        self.mapping_dict_inv = {self.mapping_dict[key]: key for key in self.mapping_dict}
        return
        
    def get_child_node(self, element, tag):
        return [e for e in element._get_childNodes() if type(e)==minidom.Element and e._get_tagName() == tag]
        
    def has_attribute_value(self, element, attribute, value):
        return True if element.getAttribute(attribute).split("#")[-1] == value else False
    
    def get_subclass_triples(self):
        return [(b,a,c) for (a,b,c) in self.get_subclasses()]
    
    def parse_triples(self, union_flag=0, subclass_of=True):
        obj_props = self.object_properties
        data_props = self.data_properties
        props = obj_props + data_props
        all_triples = []
        for prop in props:
            domain_children = self.get_child_node(prop, "rdfs:domain")
            range_children = self.get_child_node(prop, "rdfs:range")
            domain_prop = self.filter_null([self.extract_ID(el) for el in domain_children])
            range_prop = self.filter_null([self.extract_ID(el) for el in range_children])
            if not domain_children or not range_children:
                continue
#             if not domain_prop:
#                 domain_prop = self.filter_null([self.extract_ID(el) for el in domain_children[0].getElementsByTagName("owl:Class")])
#             if not range_prop:
#                 range_prop = self.filter_null([self.extract_ID(el) for el in range_children[0].getElementsByTagName("owl:Class")])
            if domain_prop and range_prop:
                if union_flag == 0:
                    all_triples.extend([(el[0], el[1], self.extract_ID(prop)) for el in list(itertools.product(domain_prop, range_prop))])
                else:
                    all_triples.append(("###".join(domain_prop), "###".join(range_prop), self.extract_ID(prop)))
        if subclass_of:
            all_triples.extend(self.get_subclass_triples())
        return list(set(all_triples))
    
    def get_triples(self, union_flag=0, subclass_of=True):
        return self.parse_triples(union_flag, subclass_of)

    def parse_subclasses(self, union_flag=0):
        subclasses = self.root.getElementsByTagName("rdfs:subClassOf")
        subclass_pairs = []
        for el in subclasses:
            inline_subclasses = self.extract_ID(el)
            if inline_subclasses:
                subclass_pairs.append((el, el.parentNode, "subclass_of"))
            else:
                level1_class = self.get_child_node(el, "owl:Class")
                if not level1_class:
                    continue
                else:
                    if self.extract_ID(level1_class[0]):
                        subclass_pairs.append((level1_class[0], el.parentNode, "subclass_of"))
                    else:
#                         level2classes = level1_class[0].getElementsByTagName("owl:Class")
#                         subclass_pairs.extend([(elem, el.parentNode, "subclass_of") for elem in level2classes if self.extract_ID(elem)])
                        continue
        return subclass_pairs
        
    def get_subclasses(self):
        subclasses = [(self.extract_ID(a), self.extract_ID(b), c) for (a,b,c) in self.subclasses]
        return [el for el in subclasses if el[0] and el[1] and el[2]]
    
    def filter_null(self, data):
        return [el for el in data if el]
    
    def extract_ID(self, element, check_coded = True):
        element_id = element.getAttribute("rdf:ID") or element.getAttribute("rdf:resource") or element.getAttribute("rdf:about")
        element_id = element_id.split("#")[-1]
        if len(list(filter(str.isdigit, element_id))) >= 3 and "_" in element_id and check_coded:
            return self.mapping_dict[element_id]
        return element_id.replace("UNDEFINED_", "").replace("DO_", "")
    
    def parse_classes(self):
        class_elems = [self.extract_ID(el) for el in self.root.getElementsByTagName("owl:Class")]
        subclass_classes = list(set(flatten([el[:-1] for el in self.triples])))
        return list(set(self.filter_null(class_elems + subclass_classes)))
    
    def get_classes(self):
        return self.classes
    
    def get_entities(self):
        entities = [self.extract_ID(el) for el in self.root.getElementsByTagName("owl:Class")]
        return list(set(self.filter_null(entities)))

    def parse_data_properties(self):
        data_properties = [el for el in self.get_child_node(self.root, 'owl:DatatypeProperty')]
        fn_data_properties = [el for el in self.get_child_node(self.root, 'owl:FunctionalProperty') if el]
        fn_data_properties = [el for el in fn_data_properties if type(el)==minidom.Element and 
            [el for el in self.get_child_node(el, "rdf:type") if 
             self.has_attribute_value(el, "rdf:resource", "DatatypeProperty")]]
        inv_fn_data_properties = [el for el in self.get_child_node(self.root, 'owl:InverseFunctionalProperty') if el]
        inv_fn_data_properties = [el for el in inv_fn_data_properties if type(el)==minidom.Element and 
            [el for el in self.get_child_node(el, "rdf:type") if 
             self.has_attribute_value(el, "rdf:resource", "DatatypeProperty")]]
        return data_properties + fn_data_properties + inv_fn_data_properties
        
    def parse_object_properties(self):
        obj_properties = [el for el in self.get_child_node(self.root, 'owl:ObjectProperty')]
        fn_obj_properties = [el for el in self.get_child_node(self.root, 'owl:FunctionalProperty') if el]
        fn_obj_properties = [el for el in fn_obj_properties if type(el)==minidom.Element and 
            [el for el in self.get_child_node(el, "rdf:type") if 
             self.has_attribute_value(el, "rdf:resource", "ObjectProperty")]]
        inv_fn_obj_properties = [el for el in self.get_child_node(self.root, 'owl:InverseFunctionalProperty') if el]
        inv_fn_obj_properties = [el for el in inv_fn_obj_properties if type(el)==minidom.Element and 
            [el for el in self.get_child_node(el, "rdf:type") if 
             self.has_attribute_value(el, "rdf:resource", "ObjectProperty")]]
        return obj_properties + fn_obj_properties + inv_fn_obj_properties
    
    def get_object_properties(self):
        obj_props = [self.extract_ID(el) for el in self.object_properties]
        return list(set(self.filter_null(obj_props)))
    
    def get_data_properties(self):
        data_props = [self.extract_ID(el) for el in self.data_properties]
        return list(set(self.filter_null(data_props)))

# %%
USE_folder = "/home/vlead/USE"
alignment_folder = "reference-alignment/"

# Load reference alignments 
def load_alignments(folder):
    alignments = []
    for f in os.listdir(folder):
        doc = minidom.parse(folder + f)
        ls = list(zip(doc.getElementsByTagName('entity1'), doc.getElementsByTagName('entity2')))
        alignments.extend([(a.getAttribute('rdf:resource'), b.getAttribute('rdf:resource')) for (a,b) in ls])
    return alignments

# Extracting USE embeddings

def extractUSEEmbeddings(words):
    try:
        embed = hub.KerasLayer(USE_folder)
    except Exception as e:
        # !mkdir $USE_folder
        # !curl -L "https://tfhub.dev/google/universal-sentence-encoder-large/5?tf-hub-format=compressed" | tar -zxvC $USE_folder
        embed = hub.KerasLayer(USE_folder)
        pass
    word_embeddings = embed(words)
    return word_embeddings.numpy()

def cos_sim(a,b):
    return 1 - spatial.distance.cosine(a, b)


reference_alignments = load_alignments(alignment_folder)

# ra_anatomy_coded = load_alignments("../Anatomy/Alignments/")
# ra_anatomy = []
# ont1 = Ontology("../Anatomy/Ontologies/mouse.owl")
# ont2 = Ontology("../Anatomy/Ontologies/human.owl")
# for elem in ra_anatomy_coded:
#     pre1, pre2 = elem[0].split("#")[0].split(".")[0].split("/")[-1], elem[1].split("#")[0].split(".")[0].split("/")[-1]
#     elem1, elem2 = elem[0].split("#")[-1], elem[1].split("#")[-1]
#     ra_anatomy.append(( pre1 + "#" + ont1.mapping_dict[elem1], pre2 + "#" + ont2.mapping_dict[elem2]))

gt_mappings = [tuple([elem.split("/")[-1] for elem in el]) for el in reference_alignments]
# gt_mappings.extend(ra_anatomy)


ontologies_in_alignment = pickle.load(open("../data_generic.pkl", "rb"))[-1][:-1]
# ontologies_in_alignment += [["../Anatomy/Ontologies/human.owl", "../Anatomy/Ontologies/mouse.owl"]]

# %%
Ontology("conference_ontologies/iasted.owl").get_triples()
# Out:
# [('Activity', 'Item', 'is_connected_with'),
#  ('Item', 'Person', 'is_sent_by'),
#  ('Trip_day', 'Time', 'subclass_of'),
#  ('Technic_activity', 'Conference_activity', 'subclass_of'),
#  ('Review', 'Document', 'subclass_of'),
#  ('Presentation', 'Conference_activity', 'subclass_of'),
#  ('Conference_activity', 'Activity', 'subclass_of'),
#  ('Introduction', 'Conference_activity', 'subclass_of'),
#  ('Item', 'Activity', 'go_through'),
#  ('One_day_presenter', 'Delegate', 'subclass_of'),
#  ('Transport_vehicle', 'Item', 'subclass_of'),
#  ('Credit_card', 'Card', 'subclass_of'),
#  ('Person', 'Item', 'is_connected_with'),
#  ('Person', 'State', 'occupy'),
#  ('Video_cassette_player', 'Audiovisual_equipment', 'subclass_of'),
#  ('Nonauthor_registration_fee', 'Registration_fee', 'subclass_of'),
#  ('Social_program', 'Conference_activity', 'subclass_of'),
#  ('Conference_hotel', 'Building', 'subclass_of'),
#  ('Deadline', 'date', 'done_till'),
#  ('Conference_airport', 'Building', 'subclass_of'),
#  ('Submission', 'Document', 'subclass_of'),
#  ('Activity', 'dateTime', 'is_dated_on'),
#  ('Author_cd_proceedings_included', 'Author', 'subclass_of'),
#  ('Conference_restaurant', 'Building', 'subclass_of'),
#  ('Lecture', 'Conference_activity', 'subclass_of'),
#  ('Person', 'Money', 'pay'),
#  ('Activity', 'Time', 'is_held_in'),
#  ('Tutorial_speaker', 'Author', 'subclass_of'),
#  ('Technical_commitee', 'Delegate', 'subclass_of'),
#  ('Student_non_speaker', 'Non_speaker', 'subclass_of'),
#  ('Audiovisual_equipment', 'Item', 'subclass_of'),
#  ('Activity_after_conference', 'Activity', 'subclass_of'),
#  ('Sponsor_company_house', 'Building', 'subclass_of'),
#  ('Speaker', 'Delegate', 'subclass_of'),
#  ('Modelling', 'Research', 'subclass_of'),
#  ('Conference_city', 'City', 'subclass_of'),
#  ('IASTED_non_member', 'Delegate', 'subclass_of'),
#  ('Document', 'Item', 'subclass_of'),
#  ('Tax', 'Money', 'subclass_of'),
#  ('Computer', 'Audiovisual_equipment', 'subclass_of'),
#  ('Item', 'Item', 'is_made_from'),
#  ('Person', 'Place', 'speak_in'),
#  ('Memeber_registration_fee', 'Registration_fee', 'subclass_of'),
#  ('Building', 'Building', 'is_situated_in'),
#  ('Fee_for_extra_trip', 'Fee', 'subclass_of'),
#  ('Session_room', 'Place', 'subclass_of'),
#  ('Registration_form', 'Form', 'subclass_of'),
#  ('Conference_Hiker', 'Delegate', 'subclass_of'),
#  ('Person', 'Time', 'is_present'),
#  ('City', 'Person', 'is_occupied_by'),
#  ('Person', 'Item', 'need'),
#  ('Departure_tax', 'Tax', 'subclass_of'),
#  ('Deadline_hotel_reservation', 'Deadline', 'subclass_of'),
#  ('PowerPoint_presentation', 'Presentation', 'subclass_of'),
#  ('Hotel_fee', 'Fee', 'subclass_of'),
#  ('State', 'Person', 'is_occupied_by'),
#  ('Nonmember_registration_fee', 'Registration_fee', 'subclass_of'),
#  ('Presenter_city', 'City', 'subclass_of'),
#  ('Book_proceeding', 'Publication', 'subclass_of'),
#  ('Introduction_of_speaker', 'Introduction', 'subclass_of'),
#  ('Place', 'State', 'is_situated_in'),
#  ('Person', 'Item', 'prepare'),
#  ('Overhead_projector', 'Audiovisual_equipment', 'subclass_of'),
#  ('Cd_proceening', 'Publication', 'subclass_of'),
#  ('Money', 'Building', 'is_paid_in'),
#  ('Conference_days', 'Time', 'subclass_of'),
#  ('Building', 'Place', 'is_situated_in'),
#  ('One_conference_day', 'Conference_days', 'subclass_of'),
#  ('Non_speaker', 'Delegate', 'subclass_of'),
#  ('Place', 'Place', 'is_situated_in'),
#  ('Viza', 'Document', 'subclass_of'),
#  ('Fee', 'Money', 'subclass_of'),
#  ('Card', 'Item', 'subclass_of'),
#  ('Item', 'Money', 'is_used_for'),
#  ('Receiving_manuscript', 'Activity_before_conference', 'subclass_of'),
#  ('Deadline_for_notification_of_acceptance', 'Deadline', 'subclass_of'),
#  ('Shuttle_bus', 'Transport_vehicle', 'subclass_of'),
#  ('Hotel_presenter', 'Delegate', 'subclass_of'),
#  ('IASTED_member', 'Delegate', 'subclass_of'),
#  ('Building', 'Person', 'is_occupied_by'),
#  ('Item', 'Person', 'is_given_to'),
#  ('Van', 'Transport_vehicle', 'subclass_of'),
#  ('Brief_introduction_for_Session_chair', 'Document', 'subclass_of'),
#  ('Worker_lecturer', 'Lecturer', 'subclass_of'),
#  ('Item', 'Person', 'is_given_by'),
#  ('Delegate', 'Person', 'subclass_of'),
#  ('Student_lecturer', 'Lecturer', 'subclass_of'),
#  ('Item', 'Time', 'is_sent_after'),
#  ('Plenary_lecture', 'Lecture', 'subclass_of'),
#  ('Author', 'Speaker', 'subclass_of'),
#  ('Listener', 'Delegate', 'subclass_of'),
#  ('Submissions_deadline', 'Deadline', 'subclass_of'),
#  ('Double_hotel_room', 'Hotel_room', 'subclass_of'),
#  ('Publication', 'Item', 'subclass_of'),
#  ('Tip', 'Money', 'subclass_of'),
#  ('Place', 'Building', 'is_situated_in'),
#  ('Form', 'Document', 'subclass_of'),
#  ('Initial_manuscipt', 'Submission', 'subclass_of'),
#  ('City', 'Thing', 'subclass_of'),
#  ('LCD_projector', 'Audiovisual_equipment', 'subclass_of'),
#  ('Simulating', 'Research', 'subclass_of'),
#  ('Video_presentation', 'Presentation', 'subclass_of'),
#  ('Item', 'Time', 'is_sent_before'),
#  ('Speaker_lecture', 'Session', 'subclass_of'),
#  ('Accepting_manuscript', 'Activity_before_conference', 'subclass_of'),
#  ('Time', 'Activity', 'is_designed_for'),
#  ('Author_book_proceedings_included', 'Author', 'subclass_of'),
#  ('Item', 'Person', 'is_signed_by'),
#  ('Activity', 'Person', 'is_given_by'),
#  ('Registation_deadline', 'Deadline', 'subclass_of'),
#  ('Refusing_manuscript', 'Activity_before_conference', 'subclass_of'),
#  ('Single_hotel_room', 'Hotel_room', 'subclass_of'),
#  ('Sponsor_city', 'City', 'subclass_of'),
#  ('Activity', 'Person', 'is_designed_for'),
#  ('Sponsor', 'Person', 'subclass_of'),
#  ('Deadline', 'Time', 'subclass_of'),
#  ('Person', 'Item', 'write'),
#  ('Car', 'Transport_vehicle', 'subclass_of'),
#  ('Money', 'Activity', 'is_designed_for'),
#  ('Sponsor_state', 'State', 'subclass_of'),
#  ('Place', 'Item', 'is_equipped_by'),
#  ('Item', 'Person', 'is_needed_for'),
#  ('City', 'Building', 'is_situated_in'),
#  ('Registration', 'Conference_activity', 'subclass_of'),
#  ('Record_of_attendance', 'Document', 'subclass_of'),
#  ('Welcome_address', 'Conference_activity', 'subclass_of'),
#  ('Conference_hall', 'Place', 'subclass_of'),
#  ('Main_office', 'Place', 'subclass_of'),
#  ('Taxi', 'Transport_vehicle', 'subclass_of'),
#  ('Person', 'Item', 'obtain'),
#  ('Item', 'Person', 'is_writen_by'),
#  ('Tutorial', 'Lecture', 'subclass_of'),
#  ('Mailing_list', 'Document', 'subclass_of'),
#  ('Person', 'Time', 'is_present_in'),
#  ('Activity', 'Place', 'is_connected_with'),
#  ('Time', 'Person', 'is_designed_for'),
#  ('Value_added_tax', 'Tax', 'subclass_of'),
#  ('Item', 'Person', 'is_prepared_by'),
#  ('Building', 'Place', 'subclass_of'),
#  ('Dinner_banquet', 'Social_program', 'subclass_of'),
#  ('Camera_ready_manuscript_deadline', 'Deadline', 'subclass_of'),
#  ('Final_manuscript', 'Submission', 'subclass_of'),
#  ('Person', 'Place', 'is_present_in'),
#  ('Money', 'Activity', 'is_paid_for'),
#  ('Person', 'Time', 'speak_in'),
#  ('State', 'Person', 'is_visited_by'),
#  ('Session_chair', 'Delegate', 'subclass_of'),
#  ('Conference_building', 'Building', 'subclass_of'),
#  ('Lecturer', 'Author', 'subclass_of'),
#  ('Activity', 'Activity', 'is_designed_for'),
#  ('Coffee_break', 'Conference_activity', 'subclass_of'),
#  ('Place', 'Thing', 'subclass_of'),
#  ('Person', 'Place', 'is_connected_with'),
#  ('City', 'Person', 'is_visited_by'),
#  ('Hotel_room', 'Place', 'subclass_of'),
#  ('Plenary_lecture_speaker', 'Author', 'subclass_of'),
#  ('Person', 'Building', 'occupy'),
#  ('Person', 'Item', 'sign'),
#  ('Presenter_state', 'State', 'subclass_of'),
#  ('Person', 'Activity', 'give'),
#  ('Money', 'Person', 'is_paid_by'),
#  ('Student_registration_fee', 'Registration_fee', 'subclass_of'),
#  ('Item', 'Person', 'is_used_by'),
#  ('Sponzorship', 'Money', 'subclass_of'),
#  ('Author_attendee_book_registration_fee', 'Registration_fee', 'subclass_of'),
#  ('Transparency', 'Document', 'subclass_of'),
#  ('Research', 'Activity_before_conference', 'subclass_of'),
#  ('Conference_state', 'State', 'subclass_of'),
#  ('City', 'City', 'is_situated_in'),
#  ('Person', 'Item', 'give'),
#  ('Author_attendee_cd_registration_fee', 'Registration_fee', 'subclass_of'),
#  ('Coctail_reception', 'Conference_activity', 'subclass_of'),
#  ('Item', 'Activity', 'is_used_for'),
#  ('Money', 'Person', 'is_designed_for'),
#  ('Activity_before_conference', 'Activity', 'subclass_of'),
#  ('Invitation_letter', 'Document', 'subclass_of'),
#  ('Departure', 'Activity_after_conference', 'subclass_of'),
#  ('Activity', 'Time', 'is_held_after'),
#  ('Building', 'Person', 'is_visited_by'),
#  ('Building', 'State', 'is_situated_in'),
#  ('Full_day_tour', 'Activity_after_conference', 'subclass_of'),
#  ('City', 'Place', 'is_situated_in'),
#  ('Person', 'Item', 'send'),
#  ('Session', 'Lecture', 'subclass_of'),
#  ('Presenter_university', 'Building', 'subclass_of'),
#  ('Place', 'City', 'is_situated_in'),
#  ('Worker_non_speaker', 'Non_speaker', 'subclass_of'),
#  ('Author_information_form', 'Form', 'subclass_of'),
#  ('Money', 'int', 'has_amount_of'),
#  ('Payment_document', 'Document', 'subclass_of'),
#  ('Cheque', 'Payment_document', 'subclass_of'),
#  ('Renting', 'Activity_before_conference', 'subclass_of'),
#  ('Person', 'City', 'occupy'),
#  ('Activity', 'Time', 'is_held_before'),
#  ('Reviewer', 'Speaker', 'subclass_of'),
#  ('Trip_city', 'City', 'subclass_of'),
#  ('City', 'State', 'is_situated_in'),
#  ('Activity', 'Place', 'is_held_in'),
#  ('Money', 'Item', 'is_paid_for'),
#  ('Hotel_registration_form', 'Form', 'subclass_of'),
#  ('Money', 'Item', 'is_paid_with'),
#  ('Registration_fee', 'Fee', 'subclass_of'),
#  ('Building', 'City', 'is_situated_in'),
#  ('Bank_transfer', 'Payment_document', 'subclass_of'),
#  ('Presenter_house', 'Building', 'subclass_of')]

# %%
# Combinatorial mapping generation
entity_mappings, property_mappings = [], []

for l in ontologies_in_alignment:
    ont1 = Ontology("conference_ontologies/" + l[0] + ".owl")
    ont2 = Ontology("conference_ontologies/" + l[1] + ".owl")
    
    ent1 = ont1.get_entities()
    ent2 = ont2.get_entities()
    
    mappings = list(itertools.product(ent1, ent2))
    entity_mappings.extend([(l[0] + "#" + el[0], l[1] + "#" + el[1]) for el in mappings])
    
    obj1 = ont1.get_object_properties()
    obj2 = ont2.get_object_properties()
    
    data1 = ont1.get_data_properties()
    data2 = ont2.get_data_properties()
    
    mappings = list(itertools.product(obj1, obj2)) + list(itertools.product(data1, data2))
    property_mappings.extend([(l[0] + "#" + el[0], l[1] + "#" + el[1]) for el in mappings])
    
data_entity = {mapping: False for mapping in entity_mappings}
data_property = {mapping: False for mapping in property_mappings}

for mapping in set(gt_mappings):
    if mapping in data_entity:
        data_entity[mapping] = True
    elif mapping in data_property:
        data_property[mapping] = True
    else:
        print ("Error", mapping)

# %%
# Abbrevation resolution preprocessing

abbreviations_dict = {}
final_dict = {}

for mapping in entity_mappings + property_mappings:
    mapping = tuple([el.split("#")[1] for el in mapping])
    is_abb = re.search("[A-Z][A-Z]+", mapping[0])
    if is_abb:
        abbreviation = "".join([el[0].upper() for el in mapping[1].split("_")])
        if is_abb.group() in abbreviation:
            
            start = abbreviation.find(is_abb.group())
            end = start + len(is_abb.group())
            fullform = "_".join(mapping[1].split("_")[start:end])
            print ("left", mapping, abbreviation, fullform)
            
            rest_first = " ".join([el for el in mapping[0].replace(is_abb.group(), "").split("_") if el]).lower()
            rest_second = " ".join(mapping[1].split("_")[:start] + mapping[1].split("_")[end:])
            if is_abb.group() not in final_dict:
                final_dict[is_abb.group()] = [(fullform, rest_first, rest_second)]
            else:
                final_dict[is_abb.group()].append((fullform, rest_first, rest_second))

    is_abb = re.search("[A-Z][A-Z]+", mapping[1])
    if is_abb:
        abbreviation = "".join([el[0].upper() for el in mapping[0].split("_")])
        
        if is_abb.group() in abbreviation:
            start = abbreviation.find(is_abb.group())
            end = start + len(is_abb.group())
            fullform = "_".join(mapping[0].split("_")[start:end])
            print ("right", mapping, abbreviation, fullform)

            rest_first = " ".join([el for el in mapping[1].replace(is_abb.group(), "").split("_") if el]).lower()
            rest_second = " ".join(mapping[0].split("_")[:start] + mapping[0].split("_")[end:])
            if is_abb.group() not in final_dict:
                final_dict[is_abb.group()] = [(fullform, rest_first, rest_second)]
            else:
                final_dict[is_abb.group()].append((fullform, rest_first, rest_second))

keys = [el for el in list(set(flatten([flatten([tup[1:] for tup in final_dict[key]]) for key in final_dict]))) if el]
abb_embeds = dict(zip(keys, extractUSEEmbeddings(keys)))

scored_dict = {}
for abbr in final_dict:
    sim_list = [(tup[0], tup[1], tup[2], cos_sim(abb_embeds[tup[1]], abb_embeds[tup[2]])) if tup[1] and tup[2]
                else (tup[0], tup[1], tup[2], 0) for tup in final_dict[abbr]]
    scored_dict[abbr] = sorted(list(set(sim_list)), key=lambda x:x[-1], reverse=True)

resolved_dict = {key: scored_dict[key][0] for key in scored_dict}
filtered_dict = {key: " ".join(resolved_dict[key][0].split("_")) for key in resolved_dict if resolved_dict[key][-1] > 0.9}
# Out:
# left ('Chair_PC', 'Program_Chair') PC Program_Chair
# left ('Chair_PC', 'Program_Committee_member') PCM Program_Committee
# left ('Chair_PC', 'Program_Committee') PC Program_Committee
# left ('Member_PC', 'Program_Chair') PC Program_Chair
# left ('Member_PC', 'Program_Committee_member') PCM Program_Committee
# left ('Member_PC', 'Program_Committee') PC Program_Committee
# left ('Chair_PC', 'Presenter_city') PC Presenter_city
# left ('Member_PC', 'Presenter_city') PC Presenter_city
# left ('PC_Member', 'Program_Chair') PC Program_Chair
# left ('PC_Member', 'Program_Committee_member') PCM Program_Committee
# left ('PC_Member', 'Program_Committee') PC Program_Committee
# left ('PC_Chair', 'Program_Chair') PC Program_Chair
# left ('PC_Chair', 'Program_Committee_member') PCM Program_Committee
# left ('PC_Chair', 'Program_Committee') PC Program_Committee
# left ('OC_Member', 'Organizing_Committee') OC Organizing_Committee
# left ('OC_Member', 'Organizing_Committee_member') OCM Organizing_Committee
# left ('OC_Chair', 'Organizing_Committee') OC Organizing_Committee
# left ('OC_Chair', 'Organizing_Committee_member') OCM Organizing_Committee
# right ('Passive_conference_participant', 'Chair_PC') PCP Passive_conference
# right ('Passive_conference_participant', 'Member_PC') PCP Passive_conference
# right ('Program_committee', 'Chair_PC') PC Program_committee
# right ('Program_committee', 'Member_PC') PC Program_committee
# left ('PC_Member', 'Presenter_city') PC Presenter_city
# left ('PC_Chair', 'Presenter_city') PC Presenter_city
# left ('OC_Member', 'One_conference_day') OCD One_conference
# left ('OC_Chair', 'One_conference_day') OCD One_conference
# left ('SC_Member', 'Sponsor_company_house') SCH Sponsor_company
# left ('SC_Member', 'Brief_introduction_for_Session_chair') BIFSC Session_chair
# left ('SC_Member', 'Sponsor_city') SC Sponsor_city
# left ('SC_Member', 'Session_chair') SC Session_chair
# left ('Chair_PC', 'PC_Chair') PC PC_Chair
# left ('Member_PC', 'PC_Chair') PC PC_Chair
# right ('Organizing_committee', 'OC_Member') OC Organizing_committee
# right ('Organizing_committee', 'OC_Chair') OC Organizing_committee
# right ('Passive_conference_participant', 'PC_Member') PCP Passive_conference
# right ('Passive_conference_participant', 'PC_Chair') PCP Passive_conference
# right ('Program_committee', 'PC_Member') PC Program_committee
# right ('Program_committee', 'PC_Chair') PC Program_committee
# right ('Steering_committee', 'SC_Member') SC Steering_committee
# right ('Submitted_contribution', 'SC_Member') SC Submitted_contribution
# left ('paperID', 'is_dated_on') IDO is_dated

# %%
def camel_case_split(identifier):
    matches = re.finditer('.+?(?:(?<=[a-z])(?=[A-Z])|(?<=[A-Z])(?=[A-Z][a-z])|$)', identifier)
    return [m.group(0) for m in matches]

def parse(word):
    return flatten([el.split("_") for el in camel_case_split(word)])
    

extracted_elems = []

for ont_name in list(set(flatten(ontologies_in_alignment))):
    ont = Ontology("conference_ontologies/" + ont_name + ".owl")
    entities = ont.get_entities()
    props = ont.get_object_properties() + ont.get_data_properties()
    triples = list(set(flatten(ont.get_triples())))
    extracted_elems.extend([ont_name + "#" + elem for elem in entities + props + triples])

extracted_elems = list(set(extracted_elems))
inp = [" ".join(parse(word.split("#")[1])) for word in extracted_elems]

# Lowering case except in abbreviations
inp_case_handled = []
for concept in inp:
    final_list = []
    for word in concept.split(" "):
        if not re.search("[A-Z][A-Z]+", concept):
            final_list.append(word.lower())
        else:
            final_list.append(word)
    case_resolved = " ".join(final_list)
    inp_case_handled.append(case_resolved)
inp = inp_case_handled

# Resolving abbreviations to full forms
inp_resolved = []
for concept in inp:
    for key in filtered_dict:
        concept = concept.replace(key, filtered_dict[key]).lower()
    inp_resolved.append(concept)

url = "https://montanaflynn-spellcheck.p.rapidapi.com/check/"

headers = {
    'x-rapidapi-host': "montanaflynn-spellcheck.p.rapidapi.com",
    'x-rapidapi-key': "9965b01207msh06291e57d6f2c55p1a6a16jsn0fb016da4a62"
    }

inp_spellchecked = []
for concept in inp_resolved:
    querystring = {"text": concept}
    response = requests.request("GET", url, headers=headers, params=querystring).json()
    if response["suggestion"] != concept:
        resolved = str(concept)
        final_list = []
        for word in concept.split(" "):
            if not re.search("[A-Z][A-Z]+", concept):
                final_list.append(word.lower())
            else:
                final_list.append(word)
        resolved = " ".join(final_list)
#         print (resolved, "suggestion", response)
        for word in response["corrections"]:
            if not re.search("[A-Z][A-Z]+", concept):
                resolved = resolved.replace(word.lower(), response["corrections"][word][0].lower())
                
        
        print (concept, resolved)
        inp_spellchecked.append(resolved)
    else:
        inp_spellchecked.append(concept)

print ("Total number of extracted unique classes and properties from entire RA set: ", len(extracted_elems))

extracted_elems = ["<UNK>"] + extracted_elems

# stopwords = ["has", "is", "a", "an", "the"]
stopwords = ["has"]
inp_stemmed = []
for elem in inp_spellchecked:
    words = " ".join([word for word in elem.split() if word not in stopwords])
    words = words.replace("-", " ")
    inp_stemmed.append(words)


embeds = np.array([np.zeros(512,)] + list(extractUSEEmbeddings(inp_stemmed)))
# embeds = np.array([np.zeros(512,)] + list(extractUSEEmbeddings(inp_spellchecked)))
embeddings = dict(zip(extracted_elems, embeds))


emb_vals = list(embeddings.values())
emb_indexer = {key: i for i, key in enumerate(list(embeddings.keys()))}
emb_indexer_inv = {i: key for i, key in enumerate(list(embeddings.keys()))}
# Out:
# modelling modeling
# iasted non member tasted non member
# organises organists
# acm sigkdd acm sigrid
# tprogram committee member program committee member
# cheque exchequer
# has programme has programmer
# hardcopy mailing manifests printed by hard copy mailing manifests printed by
# oc member co member
# scientifically organises scientifically organists
# memeber registration fee member registration fee
# has a url has a url
# sc member sc member
# scientifically organised by scientifically organized by
# holded by holed by
# conference www conference www
# contribution 1th-author contribution th-author
# author attendee cd registration fee author attendee cd registration fee
# programme programmer
# flyer flayer
# registration sigkdd member registration sigrid member
# reviewes reviewed
# has a commtitee has a committee
# initial manuscipt initial manuscript
# computer networks aapplications topic computer networks applications topic
# programme brochure programmer brochure
# oc chair co chair
# technically organises technically organists
# viza viz
# any uri any uri
# sponzor sponsor
# site url site url
# accpet if room rating accept if room rating
# author cd proceedings included author cd proceedings included
# iasted member tasted member
# registeered applicant registered applicant
# technically organised by technically organized by
# powerline transmission topic power line transmission topic
# registation deadline registration deadline
# cd proceening cd proceeding
# presentationed by presentation ed by
# technic activity technical activity
# is writen by is write by
# accepts hardcopy submissions accepts hard copy submissions
# registration sigmod member registration sigmoid member
# was a committe co-chair of was a committee co-chair of
# print hardcopy mailing manifests print hard copy mailing manifests
# ngo no
# operating topicsystems operating topic systems
# organising agency organizing agency
# sponzorship sponsorship
# nonauthor registration fee non author registration fee
# organised by organized by
# technical commitee technical committee
# organizator organization
# sponzor fee sponsor fee
# is the 1th part of is the th part of
# has an isbn has an isbn
# coctail reception cocktail reception
# webmaster web master
# organisation organization
# lcd projector lcd projector
# is a topis of conference parts is a tops of conference parts
# logo url logo url
# Total number of extracted unique classes and properties from entire RA set:  833

# %%
def path_to_root(elem, ont_mappings):
    if elem not in ont_mappings or not ont_mappings[elem]:
        return []
    output = ont_mappings[elem] + path_to_root(ont_mappings[elem][0], ont_mappings)
    return output

def find_path_to_root(ont):
    ont_obj = Ontology("conference_ontologies/" + ont + ".owl")
    triples = ont_obj.get_triples()
    entities = [(a,b) for (a,b,c) in triples]
    properties = [c for (a,b,c) in triples]
    
    entities_neighbours_dict = {elem: [] for elem in list(set(flatten(entities)))}
#     entities_neighbours_dict["Thing"] = []
    properties_neighbours_dict = {elem: [] for elem in list(set(properties))}
    
    for e1, e2, p in triples:
        if p=="subclass_of" and e2!="Thing":
            entities_neighbours_dict[e1].append(e2)
        else:
            properties_neighbours_dict[p].append((e1, e2))
    
#     for elem in entities_neighbours_dict:
#         if not entities_neighbours_dict[elem] and elem!="Thing":
#             entities_neighbours_dict[elem] = ["Thing"]
            
    entities_neighbours_dict = {elem: [elem] + path_to_root(elem, entities_neighbours_dict) for elem in entities_neighbours_dict}

#     if ont == "edas":
#         print (entities_neighbours_dict)
    
#     prop_triples = ont_obj.get_triples(subclass_of=False)
#     neighbours_dict_props = {c: [c] for a,b,c in prop_triples}
#     for e1, e2, p in prop_triples:
#         neighbours_dict_props[p].extend([e1, e2])

    #neighbours_dict = {**neighbours_dict, **neighbours_dict_props}
    
    # for elem in ont_obj.get_entities() + ont_obj.get_object_properties() + ont_obj.get_data_properties():
    #     if elem not in neighbours_dict:
    #         neighbours_dict[elem] = [elem]

#     entities_neighbours_dict = {el: entities_neighbours_dict[el][:1] + sorted(list(set(entities_neighbours_dict[el][1:])))
#                        for el in entities_neighbours_dict}
#     neighbours_dict = {el: neighbours_dict[el][:23] for el in neighbours_dict if len( neighbours_dict[el]) > 2}
#     entities_neighbours_dict = {ont + "#" + el: [ont + "#" + e for e in entities_neighbours_dict[el]] for el in entities_neighbours_dict if len(entities_neighbours_dict[el]) == 1}
    entities_neighbours_dict = {ont + "#" + el: [ont + "#" + e for e in entities_neighbours_dict[el]] for el in entities_neighbours_dict if len(entities_neighbours_dict[el]) > 1}
    
    properties_neighbours_dict = {ont + "#" + el: [tuple([ont + "#" + e for e in tup]) for tup in properties_neighbours_dict[el]] for el in properties_neighbours_dict if len(properties_neighbours_dict[el]) == 1}

    return entities_neighbours_dict

neighbours_dicts = {ont: find_path_to_root(ont) for ont in list(set(flatten(ontologies_in_alignment)))}
max_neighbours = np.max(flatten([[len(el[e]) for e in el] for el in neighbours_dicts.values()]))
neighbours_lens = {ont: {key: len(neighbours_dicts[ont][key]) for key in neighbours_dicts[ont]}
                   for ont in neighbours_dicts}
# neighbours_dicts = {ont: {key: neighbours_dicts[ont][key] + ["<UNK>" for i in range(max_neighbours -len(neighbours_dicts[ont][key]))]
#               for key in neighbours_dicts[ont]} for ont in neighbours_dicts}

# # ontologies_in_alignment = [[el.split("/")[1].split(".")[0] for el in ont] for ont in ontologies_in_alignment]
f = open("data_path.pkl", "wb")
pickle.dump([data, emb_indexer, emb_indexer_inv, emb_vals, gt_mappings, neighbours_dicts, ontologies_in_alignment], f)

# %%
data = {**data_entity, **data_property}

# %%
neighbours_dicts["confOf"]
# Out:
# {'confOf#Administrative_event': ['confOf#Administrative_event',
#   'confOf#Event',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>'],
#  'confOf#Registration_of_participants_event': ['confOf#Registration_of_participants_event',
#   'confOf#Administrative_event',
#   'confOf#Event',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>'],
#  'confOf#Workshop': ['confOf#Workshop',
#   'confOf#Working_event',
#   'confOf#Event',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>'],
#  'confOf#Submission_event': ['confOf#Submission_event',
#   'confOf#Administrative_event',
#   'confOf#Event',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>'],
#  'confOf#Participant': ['confOf#Participant',
#   'confOf#Person',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>'],
#  'confOf#Social_event': ['confOf#Social_event',
#   'confOf#Event',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>'],
#  'confOf#Assistant': ['confOf#Assistant',
#   'confOf#Person',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>'],
#  'confOf#Chair_PC': ['confOf#Chair_PC',
#   'confOf#Person',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>'],
#  'confOf#Trip': ['confOf#Trip',
#   'confOf#Social_event',
#   'confOf#Event',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>'],
#  'confOf#Conference': ['confOf#Conference',
#   'confOf#Working_event',
#   'confOf#Event',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>'],
#  'confOf#Short_paper': ['confOf#Short_paper',
#   'confOf#Contribution',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>'],
#  'confOf#Reviewing_event': ['confOf#Reviewing_event',
#   'confOf#Administrative_event',
#   'confOf#Event',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>'],
#  'confOf#Science_Worker': ['confOf#Science_Worker',
#   'confOf#Person',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>'],
#  'confOf#Banquet': ['confOf#Banquet',
#   'confOf#Social_event',
#   'confOf#Event',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>'],
#  'confOf#Volunteer': ['confOf#Volunteer',
#   'confOf#Person',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>'],
#  'confOf#Tutorial': ['confOf#Tutorial',
#   'confOf#Working_event',
#   'confOf#Event',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>'],
#  'confOf#Author': ['confOf#Author',
#   'confOf#Person',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>'],
#  'confOf#Administrator': ['confOf#Administrator',
#   'confOf#Person',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>'],
#  'confOf#Member': ['confOf#Member',
#   'confOf#Participant',
#   'confOf#Person',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>'],
#  'confOf#Paper': ['confOf#Paper',
#   'confOf#Contribution',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>'],
#  'confOf#University': ['confOf#University',
#   'confOf#Organization',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>'],
#  'confOf#Working_event': ['confOf#Working_event',
#   'confOf#Event',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>'],
#  'confOf#Scholar': ['confOf#Scholar',
#   'confOf#Person',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>'],
#  'confOf#Student': ['confOf#Student',
#   'confOf#Participant',
#   'confOf#Person',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>'],
#  'confOf#Reviewing_results_event': ['confOf#Reviewing_results_event',
#   'confOf#Administrative_event',
#   'confOf#Event',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>'],
#  'confOf#Camera_Ready_event': ['confOf#Camera_Ready_event',
#   'confOf#Administrative_event',
#   'confOf#Event',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>'],
#  'confOf#Poster': ['confOf#Poster',
#   'confOf#Contribution',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>'],
#  'confOf#Member_PC': ['confOf#Member_PC',
#   'confOf#Person',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>'],
#  'confOf#Regular': ['confOf#Regular',
#   'confOf#Participant',
#   'confOf#Person',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>'],
#  'confOf#Reception': ['confOf#Reception',
#   'confOf#Social_event',
#   'confOf#Event',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>'],
#  'confOf#Company': ['confOf#Company',
#   'confOf#Organization',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>',
#   '<UNK>']}

# %%
cos_sim(*extractUSEEmbeddings(['late paid applicant', 'late registered participant']))
# Out:
# 0.6148052215576172

# %%
# AML test
def is_test(test_onto, key):
    return tuple([el.split("#")[0] for el in key]) in test_onto

results = []
all_ont_pairs = list(set([tuple([el.split("#")[0] for el in l]) for l in data.keys()]))
for i in list(range(0, len(all_ont_pairs), 3)):
    test_onto = all_ont_pairs[i:i+3]
    for ont_pair in test_onto:
        a, b, c = ont_pair[0], ont_pair[1], ont_pair[0] + "-" + ont_pair[1]
        java_command = "java -jar AML_v3.1/AgreementMakerLight.jar -s conference_ontologies/" + a + ".owl" + \
                            " -t conference_ontologies/" + b + ".owl -o AML-test-results/" + c + ".rdf -a"
        process = subprocess.Popen(java_command.split(), stdout=subprocess.PIPE)
        output, error = process.communicate()
    print (os.listdir("AML-test-results/"))
    pred_aml = load_alignments("AML-test-results/")
    pred_aml = [tuple([el.split("/")[-1] for el in key]) for key in pred_aml]
    tp = len([elem for elem in pred_aml if data[elem]])
    fn = len([key for key in gt_mappings if key not in set(pred_aml) and is_test(test_onto, key)])
    fp = len([elem for elem in pred_aml if not data[elem]])

    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    f1score = 2 * precision * recall / (precision + recall)
    f2score = 5 * precision * recall / (4 * precision + recall)
    f0_5score = 1.25 * precision * recall / (0.25 * precision + recall)
    print (precision, recall, f1score, f2score, f0_5score)
    
    metrics = [precision, recall, f1score, f2score, f0_5score]
    results.append(metrics)
    
    _ = [os.remove(f) for f in glob.glob('AML-test-results/*')]
    
print ("Final Results:", np.mean(results, axis=0))
# Out:
# ['confOf-sigkdd.rdf', 'iasted-sigkdd.rdf', 'cmt-ekaw.rdf']
# 0.8275862068965517 0.7272727272727273 0.7741935483870968 0.7453416149068324 0.8053691275167786
# ['confOf-iasted.rdf', 'conference-edas.rdf', 'cmt-sigkdd.rdf']
# 0.8148148148148148 0.5789473684210527 0.6769230769230768 0.6145251396648045 0.7534246575342465
# ['ekaw-sigkdd.rdf', 'conference-sigkdd.rdf', 'conference-confOf.rdf']
# 0.78125 0.6097560975609756 0.684931506849315 0.6377551020408163 0.7396449704142012
# ['confOf-edas.rdf', 'edas-iasted.rdf', 'cmt-conference.rdf']
# 0.7941176470588235 0.5094339622641509 0.6206896551724137 0.548780487804878 0.7142857142857143
# ['edas-sigkdd.rdf', 'conference-iasted.rdf', 'ekaw-iasted.rdf']
# 0.7916666666666666 0.48717948717948717 0.6031746031746031 0.5277777777777778 0.7037037037037036
# ['cmt-confOf.rdf', 'cmt-edas.rdf', 'edas-ekaw.rdf']
# 0.8181818181818182 0.5192307692307693 0.6352941176470589 0.5601659751037344 0.733695652173913
# ['conference-ekaw.rdf', 'confOf-ekaw.rdf', 'cmt-iasted.rdf']
# 0.7954545454545454 0.7142857142857143 0.7526881720430106 0.7291666666666666 0.7777777777777778
# Final Results: [0.80329596 0.59230088 0.67827067 0.62335897 0.74684309]

# %%
for i in list(range(0, len(ontologies_in_alignment)-1, 3)):
    
    test_onto = ontologies_in_alignment[i:i+3]
    print (test_onto)
# Out:
# [['conference', 'ekaw'], ['confOf', 'ekaw'], ['ekaw', 'sigkdd']]
# [['edas', 'sigkdd'], ['confOf', 'sigkdd'], ['iasted', 'sigkdd']]
# [['confOf', 'iasted'], ['conference', 'iasted'], ['confOf', 'edas']]
# [['edas', 'iasted'], ['conference', 'edas'], ['cmt', 'ekaw']]
# [['cmt', 'confOf'], ['cmt', 'edas'], ['conference', 'sigkdd']]
# [['cmt', 'sigkdd'], ['conference', 'confOf'], ['edas', 'ekaw']]
# [['cmt', 'conference'], ['cmt', 'iasted'], ['ekaw', 'iasted']]

# %%
Ontology("conference_ontologies/cmt.owl").triples
# Out:
# [('Paper', 'Document', 'subclass_of'),
#  ('Reviewer', 'ConferenceMember', 'subclass_of'),
#  ('Conference', 'Administrator', 'virtualMeetingEnabledBy'),
#  ('Administrator', 'Conference', 'startReviewerBidding'),
#  ('Reviewer', 'User', 'subclass_of'),
#  ('ConferenceChair', 'ConferenceMember', 'subclass_of'),
#  ('Paper', 'Bid', 'hasBid'),
#  ('Conference', 'Administrator', 'detailsEnteredBy'),
#  ('Rejection', 'Decision', 'subclass_of'),
#  ('Meta-Review', 'Review', 'subclass_of'),
#  ('ExternalReviewer', 'Reviewer', 'assignedByReviewer'),
#  ('Administrator', 'Conference', 'enableVirtualMeeting'),
#  ('Administrator', 'ProgramCommitteeMember', 'setMaxPapers'),
#  ('Co-author', 'Paper', 'co-writePaper'),
#  ('Conference', 'boolean', 'acceptsHardcopySubmissions'),
#  ('ProgramCommittee', 'ProgramCommitteeMember', 'hasProgramCommitteeMember'),
#  ('Paper', 'unsignedLong', 'paperID'),
#  ('Author', 'Paper', 'writePaper'),
#  ('Paper', 'Co-author', 'hasCo-author'),
#  ('Paper', 'string', 'title'),
#  ('Author', 'Paper', 'submitPaper'),
#  ('Administrator', 'ProgramCommitteeMember', 'addProgramCommitteeMember'),
#  ('ProgramCommitteeMember', 'ProgramCommittee', 'memberOfProgramCommittee'),
#  ('ProgramCommitteeMember', 'int', 'maxPapers'),
#  ('Paper', 'Decision', 'hasDecision'),
#  ('PaperFullVersion', 'Paper', 'subclass_of'),
#  ('Administrator', 'Conference', 'enterReviewCriteria'),
#  ('Administrator', 'User', 'subclass_of'),
#  ('Bid', 'Reviewer', 'adjustedBy'),
#  ('Person', 'string', 'email'),
#  ('User', 'Person', 'subclass_of'),
#  ('Author', 'ConferenceMember', 'subclass_of'),
#  ('Paper', 'Reviewer', 'assignedTo'),
#  ('Administrator', 'Conference', 'finalizePaperAssignment'),
#  ('Conference', 'date', 'date'),
#  ('Co-author', 'Author', 'subclass_of'),
#  ('Conference', 'ConferenceMember', 'hasConferenceMember'),
#  ('ProgramCommitteeMember', 'Person', 'subclass_of'),
#  ('ProgramCommitteeMember', 'ConferenceMember', 'subclass_of'),
#  ('Administrator', 'Reviewer', 'assignReviewer'),
#  ('Conference', 'Administrator', 'paperAssignmentToolsRunBy'),
#  ('ExternalReviewer', 'Person', 'subclass_of'),
#  ('Conference', 'Thing', 'subclass_of'),
#  ('Review', 'Reviewer', 'writtenBy'),
#  ('Conference', 'Administrator', 'hardcopyMailingManifestsPrintedBy'),
#  ('Administrator', 'Paper', 'rejectPaper'),
#  ('Conference', 'int', 'reviewsPerPaper'),
#  ('Reviewer', 'Bid', 'adjustBid'),
#  ('Chairman', 'Person', 'subclass_of'),
#  ('ConferenceMember', 'Conference', 'memberOfConference'),
#  ('Paper', 'SubjectArea', 'hasSubjectArea'),
#  ('Paper', 'Administrator', 'acceptedBy'),
#  ('Paper', 'Reviewer', 'readByReviewer'),
#  ('Reviewer', 'Review', 'writeReview'),
#  ('Reviewer', 'Paper', 'readPaper'),
#  ('Administrator', 'Paper', 'acceptPaper'),
#  ('Meta-Reviewer', 'Reviewer', 'subclass_of'),
#  ('Administrator', 'Conference', 'runPaperAssignmentTools'),
#  ('Author', 'User', 'subclass_of'),
#  ('Administrator', 'Conference', 'printHardcopyMailingManifests'),
#  ('Reviewer', 'ExternalReviewer', 'assignExternalReviewer'),
#  ('ProgramCommitteeChair', 'Review', 'endReview'),
#  ('Conference', 'Administrator', 'reviewerBiddingStartedBy'),
#  ('Conference', 'anyURI', 'logoURL'),
#  ('Acceptance', 'Decision', 'subclass_of'),
#  ('AuthorNotReviewer', 'Author', 'subclass_of'),
#  ('Paper', 'Meta-Reviewer', 'readByMeta-Reviewer'),
#  ('ProgramCommitteeMember', 'Administrator', 'addedBy'),
#  ('Paper', 'Author', 'hasAuthor'),
#  ('Conference', 'Administrator', 'reviewCriteriaEnteredBy'),
#  ('Paper', 'Administrator', 'rejectedBy'),
#  ('Review', 'Document', 'subclass_of'),
#  ('Reviewer', 'Administrator', 'assignedByAdministrator'),
#  ('Conference', 'anyURI', 'siteURL'),
#  ('ConferenceMember', 'Person', 'subclass_of'),
#  ('PaperAbstract', 'Paper', 'subclass_of'),
#  ('ProgramCommitteeChair', 'ProgramCommitteeMember', 'subclass_of'),
#  ('AssociatedChair', 'ConferenceMember', 'subclass_of'),
#  ('Conference', 'Administrator', 'paperAssignmentFinalizedBy'),
#  ('Reviewer', 'Paper', 'hasBeenAssigned'),
#  ('Administrator', 'Conference', 'enterConferenceDetails'),
#  ('Person', 'Document', 'hasConflictOfInterest')]

# %%
def count_non_unk(elem):
    return len([l for l in elem if l!="<UNK>"])
neighbours_dicts = {ont: {el: neighbours_dicts[ont][el][:int(sys.argv[1])] for el in neighbours_dicts[ont]
       if count_non_unk(neighbours_dicts[ont][el]) > int(sys.argv[2])} for ont in neighbours_dicts}
# Out:
# (167, 1240)

# %%
from collections import Counter
c = Counter(dict(sorted(Counter(flatten([l.split() for l in inp])).items(), key=lambda x:x[1], reverse=True)))
c
# Out:
# Counter({'has': 95,
#          'paper': 61,
#          'conference': 58,
#          'of': 54,
#          'is': 49,
#          'by': 46,
#          'topic': 39,
#          'a': 35,
#          'review': 31,
#          'event': 27,
#          'committee': 27,
#          'member': 24,
#          'chair': 22,
#          'registration': 18,
#          'date': 18,
#          'author': 18,
#          'reviewer': 15,
#          'for': 14,
#          'session': 14,
#          'fee': 13,
#          'contribution': 13,
#          'program': 13,
#          'speaker': 12,
#          'abstract': 11,
#          'name': 11,
#          'computer': 11,
#          'deadline': 11,
#          'submission': 10,
#          'city': 9,
#          'hotel': 9,
#          'in': 9,
#          'to': 9,
#          'networks': 9,
#          'student': 9,
#          'was': 8,
#          'document': 8,
#          'presenter': 8,
#          'an': 8,
#          'time': 8,
#          'presentation': 8,
#          'on': 8,
#          'call': 7,
#          'subclass': 7,
#          'invited': 7,
#          'talk': 7,
#          'participant': 7,
#          'paid': 7,
#          'workshop': 7,
#          'place': 7,
#          'part': 7,
#          'tutorial': 7,
#          'person': 7,
#          'organization': 6,
#          'assigned': 6,
#          'proceedings': 6,
#          'room': 6,
#          'rating': 6,
#          'location': 6,
#          'volume': 6,
#          'written': 6,
#          'manuscript': 6,
#          'activity': 5,
#          'non': 5,
#          'email': 5,
#          'sponsor': 5,
#          'int': 5,
#          'organizing': 5,
#          'form': 5,
#          'history': 5,
#          'applicant': 5,
#          'attendee': 5,
#          'best': 5,
#          'string': 5,
#          'break': 5,
#          'supporter': 5,
#          'regular': 5,
#          'award': 5,
#          'camera': 5,
#          'ready': 5,
#          'trip': 5,
#          'accepted': 4,
#          'assignment': 4,
#          'expertise': 4,
#          'with': 4,
#          'held': 4,
#          'submitted': 4,
#          'start': 4,
#          'lecture': 4,
#          'end': 4,
#          'rejected': 4,
#          'meeting': 4,
#          'social': 4,
#          'papers': 4,
#          'day': 4,
#          'communications': 4,
#          'title': 4,
#          'pc': 4,
#          'state': 4,
#          'publisher': 4,
#          'related': 4,
#          'poster': 4,
#          'country': 4,
#          'research': 4,
#          'cd': 3,
#          'steering': 3,
#          'reviews': 3,
#          'tax': 3,
#          'co-chair': 3,
#          'max': 3,
#          'choice': 3,
#          'academic': 3,
#          'worker': 3,
#          'lecturer': 3,
#          'information': 3,
#          'given': 3,
#          'sent': 3,
#          'before': 3,
#          'after': 3,
#          'mailing': 3,
#          'at': 3,
#          'belongs': 3,
#          'bid': 3,
#          'reception': 3,
#          'personal': 3,
#          'meal': 3,
#          'menu': 3,
#          'demo': 3,
#          'question': 3,
#          'co-author': 3,
#          'reviewing': 3,
#          'organised': 3,
#          'university': 3,
#          'hardcopy': 3,
#          'introduction': 3,
#          'currency': 3,
#          'banquet': 3,
#          'reference': 3,
#          'due': 3,
#          'book': 3,
#          'programme': 3,
#          'url': 3,
#          'full': 3,
#          'version': 3,
#          'reject': 3,
#          'first': 3,
#          'notification': 3,
#          'acceptance': 3,
#          'submit': 3,
#          'write': 3,
#          'administrator': 3,
#          'read': 3,
#          'the': 3,
#          'organises': 3,
#          'departure': 2,
#          'tools': 2,
#          'run': 2,
#          'assign': 2,
#          'external': 2,
#          'contact': 2,
#          'street': 2,
#          'list': 2,
#          'participants': 2,
#          'card': 2,
#          'plenary': 2,
#          'sponzor': 2,
#          'used': 2,
#          'computing': 2,
#          'dinner': 2,
#          'amount': 2,
#          'enter': 2,
#          'criteria': 2,
#          'parts': 2,
#          'projector': 2,
#          'phone': 2,
#          'virtual': 2,
#          'listener': 2,
#          'early': 2,
#          'manifests': 2,
#          'coffee': 2,
#          'cost': 2,
#          'boolean': 2,
#          'one': 2,
#          'been': 2,
#          'details': 2,
#          'announcement': 2,
#          'industrial': 2,
#          'and': 2,
#          'included': 2,
#          'scientifically': 2,
#          'important': 2,
#          'dates': 2,
#          'short': 2,
#          'track-workshop-tutorial': 2,
#          'sigkdd': 2,
#          'site': 2,
#          'single': 2,
#          'entered': 2,
#          'bidding': 2,
#          'postal': 2,
#          'code': 2,
#          'designed': 2,
#          'video': 2,
#          'publication': 2,
#          'security': 2,
#          'positive': 2,
#          'preference': 2,
#          'parallel': 2,
#          'updated': 2,
#          'track': 2,
#          'company': 2,
#          'oc': 2,
#          'pay': 2,
#          'hall': 2,
#          'decision': 2,
#          'administrative': 2,
#          'house': 2,
#          'active': 2,
#          'accept': 2,
#          'present': 2,
#          'submissions': 2,
#          'technically': 2,
#          'track-workshop': 2,
#          'main': 2,
#          'office': 2,
#          'reviewed': 2,
#          'welcome': 2,
#          'or': 2,
#          'building': 2,
#          'level': 2,
#          'last': 2,
#          'iasted': 2,
#          'agency': 2,
#          'obtain': 2,
#          'subject': 2,
#          'area': 2,
#          'until': 2,
#          'added': 2,
#          'meta-reviewer': 2,
#          'set': 2,
#          'conflict': 2,
#          'interest': 2,
#          'item': 1,
#          'proceening': 1,
#          'prepared': 1,
#          'technic': 1,
#          'transport': 1,
#          'vehicle': 1,
#          'tip': 1,
#          'general': 1,
#          'hiker': 1,
#          'contributes': 1,
#          'deals': 1,
#          'e-mail': 1,
#          'cad': 1,
#          'government': 1,
#          'rejection': 1,
#          'scholar': 1,
#          'default': 1,
#          'associated': 1,
#          'credit': 1,
#          'ending': 1,
#          'reviewers': 1,
#          'days': 1,
#          'restaurant': 1,
#          'nonmember': 1,
#          'ngo': 1,
#          'mobile': 1,
#          'viza': 1,
#          'exhibitor': 1,
#          'transparency': 1,
#          'user': 1,
#          'textual': 1,
#          'design': 1,
#          'overhead': 1,
#          'price': 1,
#          'sponzorship': 1,
#          'biography': 1,
#          'enabled': 1,
#          'modelling': 1,
#          'awards': 1,
#          'results': 1,
#          'accpet': 1,
#          'if': 1,
#          'flyer': 1,
#          'presented': 1,
#          'as': 1,
#          'sc': 1,
#          'sponsorship': 1,
#          'switching': 1,
#          'hold': 1,
#          'contains': 1,
#          'covers': 1,
#          'printed': 1,
#          'institution': 1,
#          'performance': 1,
#          '1th-author': 1,
#          'contributed': 1,
#          'satellite': 1,
#          'space': 1,
#          'gives': 1,
#          'presentations': 1,
#          'study': 1,
#          'acm': 1,
#          'aapplications': 1,
#          'web': 1,
#          'shuttle': 1,
#          'bus': 1,
#          'vat': 1,
#          'any': 1,
#          'uri': 1,
#          'occupy': 1,
#          'science': 1,
#          'committe': 1,
#          'send': 1,
#          'webmaster': 1,
#          'cryptography': 1,
#          'www': 1,
#          'belong': 1,
#          'excursion': 1,
#          'evaluated': 1,
#          'power': 1,
#          'point': 1,
#          'brochure': 1,
#          'proceeding': 1,
#          'started': 1,
#          'logo': 1,
#          'record': 1,
#          'attendance': 1,
#          'fax': 1,
#          'late': 1,
#          'platinum': 1,
#          'week': 1,
#          'enterprise': 1,
#          'registeered': 1,
#          'brief': 1,
#          'adjust': 1,
#          'dated': 1,
#          'lists': 1,
#          'registation': 1,
#          'working': 1,
#          'measurements': 1,
#          'search': 1,
#          'receiving': 1,
#          'delegate': 1,
#          'tutorials': 1,
#          'institute': 1,
#          'go': 1,
#          'through': 1,
#          'van': 1,
#          'finalize': 1,
#          'authors': 1,
#          'workshops': 1,
#          'optical': 1,
#          'isbn': 1,
#          'car': 1,
#          'academia': 1,
#          'references': 1,
#          'architecture': 1,
#          'individual': 1,
#          'expert': 1,
#          'prepare': 1,
#          'commtitee': 1,
#          'refusing': 1,
#          'signal': 1,
#          'processing': 1,
#          'withdrawn': 1,
#          'management': 1,
#          'simulating': 1,
#          'scientific': 1,
#          'sensor': 1,
#          'coctail': 1,
#          'covered': 1,
#          'money': 1,
#          'extra': 1,
#          'writes': 1,
#          'distributed': 1,
#          'initial': 1,
#          'manuscipt': 1,
#          'initiates': 1,
#          'enable': 1,
#          'tpc': 1,
#          'provided': 1,
#          'double': 1,
#          'connected': 1,
#          'tracks': 1,
#          'published': 1,
#          'not': 1,
#          'give': 1,
#          'possible': 1,
#          'powerline': 1,
#          'transmission': 1,
#          'cheque': 1,
#          'add': 1,
#          'per': 1,
#          'organisation': 1,
#          'accepts': 1,
#          'accepting': 1,
#          'topis': 1,
#          'travel': 1,
#          'grant': 1,
#          'negative': 1,
#          'airport': 1,
#          'early-registered': 1,
#          'can': 1,
#          'stay': 1,
#          'min': 1,
#          'home': 1,
#          'page': 1,
#          'contributions': 1,
#          'print': 1,
#          'numerical': 1,
#          'signed': 1,
#          'lcd': 1,
#          'unsigned': 1,
#          'long': 1,
#          'antennas': 1,
#          'relates': 1,
#          'holded': 1,
#          'nation': 1,
#          'final': 1,
#          'late-registered': 1,
#          'accommodation': 1,
#          'dining': 1,
#          'extended': 1,
#          'volumes': 1,
#          'referenced': 1,
#          'co-write': 1,
#          'multimedia': 1,
#          'equipped': 1,
#          'organising': 1,
#          'memeber': 1,
#          'starting': 1,
#          'non-member': 1,
#          'payment': 1,
#          'participation': 1,
#          'needed': 1,
#          'technical': 1,
#          'commitee': 1,
#          'radio': 1,
#          'reviewes': 1,
#          '1th': 1,
#          'invitation': 1,
#          'letter': 1,
#          'applications': 1,
#          'multi-author': 1,
#          'awarded': 1,
#          'done': 1,
#          'till': 1,
#          'keyword': 1,
#          'contributor': 1,
#          'passive': 1,
#          'closing': 1,
#          'bronze': 1,
#          'inverse': 1,
#          '7': 1,
#          'surname': 1,
#          'remark': 1,
#          'presentationed': 1,
#          'microelectronics': 1,
#          'meta-review': 1,
#          'finalized': 1,
#          'visited': 1,
#          'fees': 1,
#          'gender': 1,
#          'neutral': 1,
#          'members': 1,
#          'assistant': 1,
#          'volunteer': 1,
#          'nonauthor': 1,
#          'reservation': 1,
#          'instructions': 1,
#          'issues': 1,
#          'cassette': 1,
#          'player': 1,
#          'provider': 1,
#          'ends': 1,
#          'organizer': 1,
#          'organizational': 1,
#          'medicine': 1,
#          'sigmod': 1,
#          'occupied': 1,
#          'rated': 1,
#          'free': 1,
#          'tour': 1,
#          'renting': 1,
#          'value': 1,
#          'venue': 1,
#          'invites': 1,
#          'co-reviewers': 1,
#          'pending': 1,
#          'two': 1,
#          'integer': 1,
#          'operating': 1,
#          'topicsystems': 1,
#          'bank': 1,
#          'transfer': 1,
#          'employed': 1,
#          'speak': 1,
#          'starts': 1,
#          'gold': 1,
#          'follows': 1,
#          'chairman': 1,
#          'slide': 1,
#          'organizator': 1,
#          'address': 1,
#          'issue': 1,
#          'test': 1,
#          'only': 1,
#          'payed': 1,
#          'audiovisual': 1,
#          'equipment': 1,
#          'degree': 1,
#          'silver': 1,
#          'initiated': 1,
#          'taxi': 1,
#          'manuscripts': 1,
#          'id': 1,
#          'wireless': 1,
#          'industry': 1,
#          'staff': 1,
#          'mark': 1,
#          'communication': 1,
#          'theory': 1,
#          'made': 1,
#          'from': 1,
#          'adjusted': 1,
#          'sign': 1,
#          'writen': 1,
#          'situated': 1,
#          'zone': 1,
#          'need': 1,
#          'searched': 1})

# %%
fn, fp = pickle.load(open("test_v2.pkl", "rb"))

# %%
import requests

url = "https://montanaflynn-spellcheck.p.rapidapi.com/check/"

headers = {
    'x-rapidapi-host': "montanaflynn-spellcheck.p.rapidapi.com",
    'x-rapidapi-key': "9965b01207msh06291e57d6f2c55p1a6a16jsn0fb016da4a62"
    }

# inp_spellchecked = []
for concept in inp[731:]:
    querystring = {"text": concept}
    response = requests.request("GET", url, headers=headers, params=querystring).json()
    if response["suggestion"] != concept:
        resolved = str(concept)
        for word in response["corrections"]:
            if not re.search("[A-Z][A-Z]+", concept):
                resolved = resolved.replace(word, response["corrections"][word][0])
        
        inp_spellchecked.append(resolved)
        print (concept, resolved)
    else:
        inp_spellchecked.append(concept)
# Out:
# registeered applicant registered applicant
# technically organised by technically organized by
# ngo no
# sponzorship sponsorship

# %%
querystring = {"text": "technically Organised By"}
response = requests.request("GET", url, headers=headers, params=querystring)
response.json()
# Out:
# {'original': 'technically Organised By',
#  'suggestion': 'technically Organized By',
#  'corrections': {'Organised': ['Organized',
#    'Organist',
#    'Organism',
#    'Organizes',
#    'Disorganize',
#    'Organize',
#    'Agonized']}}

# %%
gt_mappings
# Out:
# [('conference#Information_for_participants', 'ekaw#Programme_Brochure'),
#  ('conference#Person', 'ekaw#Person'),
#  ('conference#Tutorial', 'ekaw#Tutorial'),
#  ('conference#Review', 'ekaw#Review'),
#  ('conference#has_a_review', 'ekaw#hasReview'),
#  ('conference#Workshop', 'ekaw#Workshop'),
#  ('conference#Late_paid_applicant', 'ekaw#Late-Registered_Participant'),
#  ('conference#Early_paid_applicant', 'ekaw#Early-Registered_Participant'),
#  ('conference#Organization', 'ekaw#Organisation'),
#  ('conference#Track-workshop_chair', 'ekaw#Workshop_Chair'),
#  ('conference#Abstract', 'ekaw#Abstract'),
#  ('conference#Conference_proceedings', 'ekaw#Conference_Proceedings'),
#  ('conference#Conference_volume', 'ekaw#Conference'),
#  ('conference#Rejected_contribution', 'ekaw#Rejected_Paper'),
#  ('conference#Poster', 'ekaw#Poster_Paper'),
#  ('conference#Track', 'ekaw#Track'),
#  ('conference#Topic', 'ekaw#Research_Topic'),
#  ('conference#Conference_www', 'ekaw#Web_Site'),
#  ('conference#Invited_speaker', 'ekaw#Invited_Speaker'),
#  ('conference#contributes', 'ekaw#authorOf'),
#  ('conference#Accepted_contribution', 'ekaw#Accepted_Paper'),
#  ('conference#Conference_document', 'ekaw#Document'),
#  ('conference#Reviewed_contribution', 'ekaw#Evaluated_Paper'),
#  ('conference#Submitted_contribution', 'ekaw#Submitted_Paper'),
#  ('conference#Regular_author', 'ekaw#Paper_Author'),
#  ('confOf#Tutorial', 'ekaw#Tutorial'),
#  ('confOf#Poster', 'ekaw#Poster_Paper'),
#  ('confOf#Social_event', 'ekaw#Social_Event'),
#  ('confOf#Person', 'ekaw#Person'),
#  ('confOf#Working_event', 'ekaw#Scientific_Event'),
#  ('confOf#Conference', 'ekaw#Conference'),
#  ('confOf#Author', 'ekaw#Paper_Author'),
#  ('confOf#Banquet', 'ekaw#Conference_Banquet'),
#  ('confOf#Workshop', 'ekaw#Workshop'),
#  ('confOf#Topic', 'ekaw#Research_Topic'),
#  ('confOf#Contribution', 'ekaw#Paper'),
#  ('confOf#Participant', 'ekaw#Conference_Participant'),
#  ('confOf#Chair_PC', 'ekaw#PC_Chair'),
#  ('confOf#Organization', 'ekaw#Organisation'),
#  ('confOf#Student', 'ekaw#Student'),
#  ('confOf#University', 'ekaw#University'),
#  ('confOf#Trip', 'ekaw#Conference_Trip'),
#  ('confOf#Member_PC', 'ekaw#PC_Member'),
#  ('confOf#Scholar', 'ekaw#Student'),
#  ('confOf#Event', 'ekaw#Event'),
#  ('ekaw#Conference', 'sigkdd#Conference'),
#  ('ekaw#Person', 'sigkdd#Person'),
#  ('ekaw#Paper', 'sigkdd#Paper'),
#  ('ekaw#Review', 'sigkdd#Review'),
#  ('ekaw#Invited_Speaker', 'sigkdd#Invited_Speaker'),
#  ('ekaw#OC_Member', 'sigkdd#Organizing_Committee_member'),
#  ('ekaw#Abstract', 'sigkdd#Abstract'),
#  ('ekaw#PC_Chair', 'sigkdd#Program_Chair'),
#  ('ekaw#Paper_Author', 'sigkdd#Author'),
#  ('ekaw#Document', 'sigkdd#Document'),
#  ('ekaw#Location', 'sigkdd#Place'),
#  ('edas#Place', 'sigkdd#Place'),
#  ('edas#hasCostAmount', 'sigkdd#Price'),
#  ('edas#Person', 'sigkdd#Person'),
#  ('edas#hasName', 'sigkdd#Name_of_conference'),
#  ('edas#ConferenceVenuePlace', 'sigkdd#Conference_hall'),
#  ('edas#Author', 'sigkdd#Author'),
#  ('edas#AccommodationPlace', 'sigkdd#Hotel'),
#  ('edas#startDate', 'sigkdd#Start_of_conference'),
#  ('edas#ConferenceChair', 'sigkdd#General_Chair'),
#  ('edas#Conference', 'sigkdd#Conference'),
#  ('edas#endDate', 'sigkdd#End_of_conference'),
#  ('edas#Review', 'sigkdd#Review'),
#  ('edas#Document', 'sigkdd#Document'),
#  ('edas#Paper', 'sigkdd#Paper'),
#  ('edas#Attendee', 'sigkdd#Listener'),
#  ('confOf#Person', 'sigkdd#Person'),
#  ('confOf#Member_PC', 'sigkdd#Program_Committee_member'),
#  ('confOf#hasEmail', 'sigkdd#E-mail'),
#  ('confOf#Author', 'sigkdd#Author'),
#  ('confOf#Conference', 'sigkdd#Conference'),
#  ('confOf#Chair_PC', 'sigkdd#Program_Chair'),
#  ('confOf#Paper', 'sigkdd#Paper'),
#  ('iasted#Place', 'sigkdd#Place'),
#  ('iasted#Review', 'sigkdd#Review'),
#  ('iasted#Student_registration_fee', 'sigkdd#Registration_Student'),
#  ('iasted#Fee', 'sigkdd#Fee'),
#  ('iasted#Registration_fee', 'sigkdd#Registration_fee'),
#  ('iasted#Sponsor', 'sigkdd#Sponzor'),
#  ('iasted#Deadline_for_notification_of_acceptance',
#   'sigkdd#Deadline_Author_notification'),
#  ('iasted#Nonmember_registration_fee', 'sigkdd#Registration_Non-Member'),
#  ('iasted#Author', 'sigkdd#Author'),
#  ('iasted#Listener', 'sigkdd#Listener'),
#  ('iasted#Main_office', 'sigkdd#Main_office'),
#  ('iasted#Conference_hall', 'sigkdd#Conference_hall'),
#  ('iasted#Person', 'sigkdd#Person'),
#  ('iasted#Deadline', 'sigkdd#Deadline'),
#  ('iasted#Speaker', 'sigkdd#Speaker'),
#  ('confOf#Event', 'iasted#Activity'),
#  ('confOf#Author', 'iasted#Author'),
#  ('confOf#Person', 'iasted#Person'),
#  ('confOf#Banquet', 'iasted#Dinner_banquet'),
#  ('confOf#Administrative_event', 'iasted#Activity_before_conference'),
#  ('confOf#Reception', 'iasted#Coctail_reception'),
#  ('confOf#City', 'iasted#City'),
#  ('confOf#Tutorial', 'iasted#Tutorial'),
#  ('confOf#Country', 'iasted#State'),
#  ('conference#Passive_conference_participant', 'iasted#Listener'),
#  ('conference#Active_conference_participant', 'iasted#Speaker'),
#  ('conference#Reviewer', 'iasted#Reviewer'),
#  ('conference#Person', 'iasted#Person'),
#  ('conference#Regular_author', 'iasted#Author'),
#  ('conference#Conference_fees', 'iasted#Fee'),
#  ('conference#Tutorial', 'iasted#Tutorial'),
#  ('conference#contributes', 'iasted#write'),
#  ('conference#Review', 'iasted#Review'),
#  ('conference#Conference_document', 'iasted#Document'),
#  ('conference#Conference_part', 'iasted#Conference_activity'),
#  ('conference#Submitted_contribution', 'iasted#Submission'),
#  ('conference#Camera_ready_contribution', 'iasted#Final_manuscript'),
#  ('conference#Conference_proceedings', 'iasted#Publication'),
#  ('confOf#Trip', 'edas#Excursion'),
#  ('confOf#Social_event', 'edas#SocialEvent'),
#  ('confOf#reviewes', 'edas#isReviewing'),
#  ('confOf#Organization', 'edas#Organization'),
#  ('confOf#writtenBy', 'edas#isWrittenBy'),
#  ('confOf#Working_event', 'edas#AcademicEvent'),
#  ('confOf#Reception', 'edas#Reception'),
#  ('confOf#hasSurname', 'edas#hasLastName'),
#  ('confOf#Workshop', 'edas#Workshop'),
#  ('confOf#Author', 'edas#Author'),
#  ('confOf#hasFirstName', 'edas#hasFirstName'),
#  ('confOf#Event', 'edas#ConferenceEvent'),
#  ('confOf#Topic', 'edas#Topic'),
#  ('confOf#Country', 'edas#Country'),
#  ('confOf#Participant', 'edas#Attendee'),
#  ('confOf#Person', 'edas#Person'),
#  ('confOf#Member_PC', 'edas#TPCMember'),
#  ('confOf#Paper', 'edas#Paper'),
#  ('confOf#writes', 'edas#hasRelatedPaper'),
#  ('edas#Place', 'iasted#Place'),
#  ('edas#SessionChair', 'iasted#Session_chair'),
#  ('edas#Author', 'iasted#Author'),
#  ('edas#Document', 'iasted#Document'),
#  ('edas#Country', 'iasted#State'),
#  ('edas#WelcomeTalk', 'iasted#Welcome_address'),
#  ('edas#Sponsorship', 'iasted#Sponzorship'),
#  ('edas#Reviewer', 'iasted#Reviewer'),
#  ('edas#Attendee', 'iasted#Delegate'),
#  ('edas#ConferenceDinner', 'iasted#Dinner_banquet'),
#  ('edas#SocialEvent', 'iasted#Social_program'),
#  ('edas#CoffeeBreak', 'iasted#Coffee_break'),
#  ('edas#Review', 'iasted#Review'),
#  ('edas#Reception', 'iasted#Coctail_reception'),
#  ('edas#ConferenceEvent', 'iasted#Conference_activity'),
#  ('edas#SlideSet', 'iasted#Transparency'),
#  ('edas#Paper', 'iasted#Submission'),
#  ('edas#ConferenceVenuePlace', 'iasted#Conference_building'),
#  ('edas#DiningPlace', 'iasted#Conference_restaurant'),
#  ('conference#Person', 'edas#Person'),
#  ('conference#Conference_participant', 'edas#Attendee'),
#  ('conference#Organization', 'edas#Organization'),
#  ('conference#Reviewer', 'edas#Reviewer'),
#  ('conference#has_the_first_name', 'edas#hasFirstName'),
#  ('conference#Conference_part', 'edas#ConferenceEvent'),
#  ('conference#Workshop', 'edas#Workshop'),
#  ('conference#Conference_document', 'edas#Document'),
#  ('conference#Paper', 'edas#Paper'),
#  ('conference#has_a_review_expertise', 'edas#hasRating'),
#  ('conference#has_the_last_name', 'edas#hasLastName'),
#  ('conference#Review', 'edas#Review'),
#  ('conference#Conference_volume', 'edas#Conference'),
#  ('conference#Rejected_contribution', 'edas#RejectedPaper'),
#  ('conference#Topic', 'edas#Topic'),
#  ('conference#Accepted_contribution', 'edas#AcceptedPaper'),
#  ('conference#Regular_author', 'edas#Author'),
#  ('cmt#Document', 'ekaw#Document'),
#  ('cmt#ConferenceMember', 'ekaw#Conference_Participant'),
#  ('cmt#Author', 'ekaw#Paper_Author'),
#  ('cmt#writtenBy', 'ekaw#reviewWrittenBy'),
#  ('cmt#hasBeenAssigned', 'ekaw#reviewerOfPaper'),
#  ('cmt#Person', 'ekaw#Person'),
#  ('cmt#Conference', 'ekaw#Conference'),
#  ('cmt#assignedTo', 'ekaw#hasReviewer'),
#  ('cmt#Review', 'ekaw#Review'),
#  ('cmt#Paper', 'ekaw#Paper'),
#  ('cmt#PaperFullVersion', 'ekaw#Regular_Paper'),
#  ('cmt#ProgramCommitteeChair', 'confOf#Chair_PC'),
#  ('cmt#writePaper', 'confOf#writes'),
#  ('cmt#Author', 'confOf#Author'),
#  ('cmt#ConferenceMember', 'confOf#Member'),
#  ('cmt#Administrator', 'confOf#Administrator'),
#  ('cmt#title', 'confOf#hasTitle'),
#  ('cmt#SubjectArea', 'confOf#Topic'),
#  ('cmt#PaperFullVersion', 'confOf#Paper'),
#  ('cmt#hasBeenAssigned', 'confOf#reviewes'),
#  ('cmt#hasAuthor', 'confOf#writtenBy'),
#  ('cmt#Conference', 'confOf#Conference'),
#  ('cmt#ProgramCommitteeMember', 'confOf#Member_PC'),
#  ('cmt#hasSubjectArea', 'confOf#dealsWith'),
#  ('cmt#Person', 'confOf#Person'),
#  ('cmt#Paper', 'confOf#Contribution'),
#  ('cmt#email', 'confOf#hasEmail'),
#  ('cmt#Person', 'edas#Person'),
#  ('cmt#Conference', 'edas#Conference'),
#  ('cmt#Author', 'edas#Author'),
#  ('cmt#Reviewer', 'edas#Reviewer'),
#  ('cmt#hasConferenceMember', 'edas#hasMember'),
#  ('cmt#memberOfConference', 'edas#isMemberOf'),
#  ('cmt#ConferenceChair', 'edas#ConferenceChair'),
#  ('cmt#Review', 'edas#Review'),
#  ('cmt#Document', 'edas#Document'),
#  ('cmt#Paper', 'edas#Paper'),
#  ('cmt#hasAuthor', 'edas#isWrittenBy'),
#  ('cmt#hasBeenAssigned', 'edas#isReviewing'),
#  ('cmt#assignedTo', 'edas#isReviewedBy'),
#  ('conference#Abstract', 'sigkdd#Abstract'),
#  ('conference#Invited_speaker', 'sigkdd#Invited_Speaker'),
#  ('conference#Regular_author', 'sigkdd#Author'),
#  ('conference#Review', 'sigkdd#Review'),
#  ('conference#Program_committee', 'sigkdd#Program_Committee'),
#  ('conference#Conference_volume', 'sigkdd#Conference'),
#  ('conference#Conference_fees', 'sigkdd#Fee'),
#  ('conference#has_an_email', 'sigkdd#E-mail'),
#  ('conference#Paper', 'sigkdd#Paper'),
#  ('conference#Organizing_committee', 'sigkdd#Organizing_Committee'),
#  ('conference#Person', 'sigkdd#Person'),
#  ('conference#Committee', 'sigkdd#Committee'),
#  ('conference#is_given_by', 'sigkdd#presentationed_by'),
#  ('conference#gives_presentations', 'sigkdd#presentation'),
#  ('conference#Conference_document', 'sigkdd#Document'),
#  ('cmt#Conference', 'sigkdd#Conference'),
#  ('cmt#Paper', 'sigkdd#Paper'),
#  ('cmt#ProgramCommitteeMember', 'sigkdd#Program_Committee_member'),
#  ('cmt#Document', 'sigkdd#Document'),
#  ('cmt#ConferenceChair', 'sigkdd#General_Chair'),
#  ('cmt#email', 'sigkdd#E-mail'),
#  ('cmt#Review', 'sigkdd#Review'),
#  ('cmt#ProgramCommittee', 'sigkdd#Program_Committee'),
#  ('cmt#ProgramCommitteeChair', 'sigkdd#Program_Chair'),
#  ('cmt#Author', 'sigkdd#Author'),
#  ('cmt#submitPaper', 'sigkdd#submit'),
#  ('cmt#Person', 'sigkdd#Person'),
#  ('conference#Conference_participant', 'confOf#Participant'),
#  ('conference#has_an_email', 'confOf#hasEmail'),
#  ('conference#Poster', 'confOf#Poster'),
#  ('conference#Organization', 'confOf#Organization'),
#  ('conference#Topic', 'confOf#Topic'),
#  ('conference#Workshop', 'confOf#Workshop'),
#  ('conference#Paper', 'confOf#Paper'),
#  ('conference#Person', 'confOf#Person'),
#  ('conference#Conference_contribution', 'confOf#Contribution'),
#  ('conference#Tutorial', 'confOf#Tutorial'),
#  ('conference#Conference_volume', 'confOf#Conference'),
#  ('conference#has_a_track-workshop-tutorial_topic', 'confOf#hasTopic'),
#  ('conference#Regular_author', 'confOf#Author'),
#  ('conference#has_the_last_name', 'confOf#hasSurname'),
#  ('conference#has_the_first_name', 'confOf#hasFirstName'),
#  ('edas#ConferenceDinner', 'ekaw#Conference_Banquet'),
#  ('edas#AcademicEvent', 'ekaw#Scientific_Event'),
#  ('edas#AcceptedPaper', 'ekaw#Accepted_Paper'),
#  ('edas#isReviewedBy', 'ekaw#hasReviewer'),
#  ('edas#Place', 'ekaw#Location'),
#  ('edas#AcademiaOrganization', 'ekaw#Academic_Institution'),
#  ('edas#SocialEvent', 'ekaw#Social_Event'),
#  ('edas#isReviewing', 'ekaw#reviewerOfPaper'),
#  ('edas#Organization', 'ekaw#Organisation'),
#  ('edas#Author', 'ekaw#Paper_Author'),
#  ('edas#isLocationOf', 'ekaw#locationOf'),
#  ('edas#Topic', 'ekaw#Research_Topic'),
#  ('edas#Document', 'ekaw#Document'),
#  ('edas#RejectedPaper', 'ekaw#Rejected_Paper'),
#  ('edas#ConferenceEvent', 'ekaw#Event'),
#  ('edas#SessionChair', 'ekaw#Session_Chair'),
#  ('edas#Person', 'ekaw#Person'),
#  ('edas#Programme', 'ekaw#Programme_Brochure'),
#  ('edas#Review', 'ekaw#Review'),
#  ('edas#Workshop', 'ekaw#Workshop'),
#  ('edas#Paper', 'ekaw#Paper'),
#  ('edas#Attendee', 'ekaw#Conference_Participant'),
#  ('edas#hasLocation', 'ekaw#heldIn'),
#  ('cmt#Conference', 'conference#Conference_volume'),
#  ('cmt#Preference', 'conference#Review_preference'),
#  ('cmt#Author', 'conference#Regular_author'),
#  ('cmt#Person', 'conference#Person'),
#  ('cmt#email', 'conference#has_an_email'),
#  ('cmt#Co-author', 'conference#Contribution_co-author'),
#  ('cmt#PaperAbstract', 'conference#Abstract'),
#  ('cmt#Document', 'conference#Conference_document'),
#  ('cmt#Review', 'conference#Review'),
#  ('cmt#Conference', 'conference#Conference'),
#  ('cmt#ProgramCommittee', 'conference#Program_committee'),
#  ('cmt#Chairman', 'conference#Chair'),
#  ('cmt#SubjectArea', 'conference#Topic'),
#  ('cmt#assignedByReviewer', 'conference#invited_by'),
#  ('cmt#assignExternalReviewer', 'conference#invites_co-reviewers'),
#  ('cmt#Author', 'iasted#Author'),
#  ('cmt#Review', 'iasted#Review'),
#  ('cmt#Person', 'iasted#Person'),
#  ('cmt#Reviewer', 'iasted#Reviewer'),
#  ('ekaw#Location', 'iasted#Place'),
#  ('ekaw#Document', 'iasted#Document'),
#  ('ekaw#Event', 'iasted#Activity'),
#  ('ekaw#Person', 'iasted#Person'),
#  ('ekaw#Paper_Author', 'iasted#Author'),
#  ('ekaw#Session', 'iasted#Session'),
#  ('ekaw#Review', 'iasted#Review'),
#  ('ekaw#Conference_Banquet', 'iasted#Dinner_banquet'),
#  ('ekaw#Tutorial', 'iasted#Tutorial'),
#  ('ekaw#Session_Chair', 'iasted#Session_chair')]

# %%
fn_spellchecked, fp_spellchecked = [dict(el) for el in pickle.load(open("test_v2.pkl", "rb"))]
fn_baseline, fp_baseline = [dict(el) for el in pickle.load(open("test_best.pkl", "rb"))]
fn_unhas, fp_unhas = [dict(el) for el in pickle.load(open("test_unhas.pkl", "rb"))]
fn_resolved, fp_resolved = [dict(el) for el in pickle.load(open("test_resolved.pkl", "rb"))]

fn_dict, fp_dict = {}, {}
def create_comparison_file(file, idx):
    fn, fp = [dict(el) for el in pickle.load(open(file, "rb"))]
    
    for key in fn:
        if key in fn_dict:
            fn_dict[key][idx] = fn[key]
        else:
            fn_dict[key] = ["N/A" for i in range(4)]
            fn_dict[key][idx] = fn[key]
    
    for key in fp:
        if key in fp_dict:
            fp_dict[key][idx] = fp[key]
        else:
            fp_dict[key] = ["N/A" for i in range(4)]
            fp_dict[key][idx] = fp[key]
    

create_comparison_file("test_best.pkl", 0)
create_comparison_file("test_unhas.pkl", 1)
create_comparison_file("test_v2.pkl", 2)
create_comparison_file("test_resolved.pkl", 3)

open("fn - comparison.tsv", "w+").write("\n".join(["\t".join([str(el) for el in flatten(el)]) for el in fn_dict.items()]))
open("fp - comparison.tsv", "w+").write("\n".join(["\t".join([str(el) for el in flatten(el)]) for el in fp_dict.items()]))
# Out:
# 7796

# %%
# Out:
# [(('confOf#Member_PC', 'sigkdd#Program_Committee_member'), 0.460159499824062),
#  (('confOf#Chair_PC', 'sigkdd#Program_Chair'), 0.710800728376894),
#  (('iasted#Student_registration_fee', 'sigkdd#Registration_Student'),
#   0.8369251770941893),
#  (('iasted#Deadline_for_notification_of_acceptance',
#    'sigkdd#Deadline_Author_notification'),
#   0.6263288918181976),
#  (('iasted#Nonmember_registration_fee', 'sigkdd#Registration_Non-Member'),
#   0.8778317801581551),
#  (('cmt#ConferenceMember', 'ekaw#Conference_Participant'), 0.5669564770296416),
#  (('cmt#Author', 'ekaw#Paper_Author'), 0.8141944477873271),
#  (('cmt#writtenBy', 'ekaw#reviewWrittenBy'), 0.7592434303979944),
#  (('cmt#hasBeenAssigned', 'ekaw#reviewerOfPaper'), 0.2502871547766108),
#  (('cmt#assignedTo', 'ekaw#hasReviewer'), 0.3499445900379554),
#  (('cmt#PaperFullVersion', 'ekaw#Regular_Paper'), 0.5529287816442782),
#  (('confOf#Administrative_event', 'iasted#Activity_before_conference'),
#   0.3867995449037805),
#  (('confOf#Reception', 'iasted#Coctail_reception'), 0.7053720960016232),
#  (('confOf#Country', 'iasted#State'), 0.8351277496668734),
#  (('conference#Conference_participant', 'edas#Attendee'), 0.680457795262619),
#  (('conference#has_a_review_expertise', 'edas#hasRating'), 0.3899073903898582),
#  (('conference#Rejected_contribution', 'edas#RejectedPaper'),
#   0.665432017501309),
#  (('cmt#ConferenceChair', 'sigkdd#General_Chair'), 0.5731875576956728),
#  (('cmt#ProgramCommitteeChair', 'sigkdd#Program_Chair'), 0.7962102707873221),
#  (('cmt#submitPaper', 'sigkdd#submit'), 0.7581630948456032),
#  (('ekaw#OC_Member', 'sigkdd#Organizing_Committee_member'), 0.365178639301853),
#  (('ekaw#PC_Chair', 'sigkdd#Program_Chair'), 0.7128738905671085),
#  (('ekaw#Paper_Author', 'sigkdd#Author'), 0.8141944477873271),
#  (('ekaw#Location', 'sigkdd#Place'), 0.8596690903888166),
#  (('conference#Conference_fees', 'sigkdd#Fee'), 0.6188697294990487),
#  (('conference#has_an_email', 'sigkdd#E-mail'), 0.8262672905906706),
#  (('conference#is_given_by', 'sigkdd#presentationed_by'), 0.3609120954885683),
#  (('conference#gives_presentations', 'sigkdd#presentation'),
#   0.6056676430562652),
#  (('conference#Conference_participant', 'confOf#Participant'),
#   0.9139417152851563),
#  (('conference#has_an_email', 'confOf#hasEmail'), 0.8262672905906706),
#  (('conference#Conference_contribution', 'confOf#Contribution'),
#   0.8257674560380555),
#  (('conference#Conference_volume', 'confOf#Conference'), 0.7533685068578012),
#  (('conference#has_a_track-workshop-tutorial_topic', 'confOf#hasTopic'),
#   0.7067523308326147),
#  (('conference#has_the_last_name', 'confOf#hasSurname'), 0.8760424400918999),
#  (('conference#has_the_first_name', 'confOf#hasFirstName'), 0.880357115623567),
#  (('confOf#Trip', 'edas#Excursion'), 0.7857979792365696),
#  (('confOf#reviewes', 'edas#isReviewing'), 0.6861398267050898),
#  (('confOf#writtenBy', 'edas#isWrittenBy'), 0.8407108246292888),
#  (('confOf#Participant', 'edas#Attendee'), 0.8228379601853789),
#  (('confOf#Member_PC', 'edas#TPCMember'), 0.7001620647253476),
#  (('confOf#writes', 'edas#hasRelatedPaper'), 0.297312720126214),
#  (('edas#Country', 'iasted#State'), 0.5430233172462778),
#  (('edas#WelcomeTalk', 'iasted#Welcome_address'), 0.6376587870417061),
#  (('edas#Attendee', 'iasted#Delegate'), 0.5733914370867992),
#  (('edas#ConferenceDinner', 'iasted#Dinner_banquet'), 0.739438108407966),
#  (('edas#SocialEvent', 'iasted#Social_program'), 0.3893037550125193),
#  (('edas#Reception', 'iasted#Coctail_reception'), 0.7053720960016232),
#  (('edas#SlideSet', 'iasted#Transparency'), 0.22742734295143396),
#  (('edas#Paper', 'iasted#Submission'), 0.5517583006498755),
#  (('edas#ConferenceVenuePlace', 'iasted#Conference_building'),
#   0.6181335242447228),
#  (('edas#DiningPlace', 'iasted#Conference_restaurant'), 0.6283572995412593),
#  (('cmt#Conference', 'conference#Conference_volume'), 0.8272255663492522),
#  (('cmt#Preference', 'conference#Review_preference'), 0.783329808487203),
#  (('cmt#email', 'conference#has_an_email'), 0.8262672905906706),
#  (('cmt#Co-author', 'conference#Contribution_co-author'), 0.7145446174859915),
#  (('cmt#PaperAbstract', 'conference#Abstract'), 0.802760641840036),
#  (('cmt#Chairman', 'conference#Chair'), 0.742547898378855),
#  (('cmt#SubjectArea', 'conference#Topic'), 0.7154184628848549),
#  (('cmt#assignedByReviewer', 'conference#invited_by'), 0.48464419365137834),
#  (('cmt#assignExternalReviewer', 'conference#invites_co-reviewers'),
#   0.18083443297598478),
#  (('edas#hasCostAmount', 'sigkdd#Price'), 0.7047592167957165),
#  (('edas#hasName', 'sigkdd#Name_of_conference'), 0.4805131633714943),
#  (('edas#ConferenceVenuePlace', 'sigkdd#Conference_hall'), 0.6646223919595833),
#  (('edas#AccommodationPlace', 'sigkdd#Hotel'), 0.5498427937907697),
#  (('edas#startDate', 'sigkdd#Start_of_conference'), 0.528186177578591),
#  (('edas#ConferenceChair', 'sigkdd#General_Chair'), 0.5731875576956728),
#  (('edas#endDate', 'sigkdd#End_of_conference'), 0.5493031244333424),
#  (('edas#Attendee', 'sigkdd#Listener'), 0.4827829321776764),
#  (('conference#Passive_conference_participant', 'iasted#Listener'),
#   0.3169095830935159),
#  (('conference#Active_conference_participant', 'iasted#Speaker'),
#   0.007739548663681727),
#  (('conference#Conference_fees', 'iasted#Fee'), 0.6188697294990487),
#  (('conference#contributes', 'iasted#write'), 0.37880804066855067),
#  (('conference#Conference_part', 'iasted#Conference_activity'),
#   0.8886715422116587),
#  (('conference#Submitted_contribution', 'iasted#Submission'),
#   0.7701747652528736),
#  (('conference#Camera_ready_contribution', 'iasted#Final_manuscript'),
#   0.09563412426112805),
#  (('conference#Conference_proceedings', 'iasted#Publication'),
#   0.277308755346886),
#  (('ekaw#Location', 'iasted#Place'), 0.8596690903888166),
#  (('ekaw#Paper_Author', 'iasted#Author'), 0.8141944477873271),
#  (('ekaw#Conference_Banquet', 'iasted#Dinner_banquet'), 0.8085170862766579),
#  (('cmt#ProgramCommitteeChair', 'confOf#Chair_PC'), 0.46274629824637237),
#  (('cmt#writePaper', 'confOf#writes'), 0.6220006428478738),
#  (('cmt#ConferenceMember', 'confOf#Member'), 0.6716821946490479),
#  (('cmt#SubjectArea', 'confOf#Topic'), 0.7154184628848549),
#  (('cmt#PaperFullVersion', 'confOf#Paper'), 0.48035408507207067),
#  (('cmt#hasBeenAssigned', 'confOf#reviewes'), 0.40867753235276827),
#  (('cmt#hasAuthor', 'confOf#writtenBy'), 0.5261010208677641),
#  (('cmt#ProgramCommitteeMember', 'confOf#Member_PC'), 0.515681421800031),
#  (('cmt#hasSubjectArea', 'confOf#dealsWith'), 0.25596982134585333),
#  (('cmt#hasConferenceMember', 'edas#hasMember'), 0.6716821946490479),
#  (('cmt#memberOfConference', 'edas#isMemberOf'), 0.5384339627563817),
#  (('cmt#hasAuthor', 'edas#isWrittenBy'), 0.3940901098620504),
#  (('cmt#hasBeenAssigned', 'edas#isReviewing'), 0.4039842265275537),
#  (('cmt#assignedTo', 'edas#isReviewedBy'), 0.5476728328223632),
#  (('edas#ConferenceDinner', 'ekaw#Conference_Banquet'), 0.8214476362145399),
#  (('edas#isReviewedBy', 'ekaw#hasReviewer'), 0.38891106779153306),
#  (('edas#Place', 'ekaw#Location'), 0.8596690903888166),
#  (('edas#AcademiaOrganization', 'ekaw#Academic_Institution'),
#   0.6167993963857633),
#  (('edas#isReviewing', 'ekaw#reviewerOfPaper'), 0.4574440998156941),
#  (('edas#Author', 'ekaw#Paper_Author'), 0.8141944477873271),
#  (('edas#isLocationOf', 'ekaw#locationOf'), 0.7440274368714033),
#  (('edas#ConferenceEvent', 'ekaw#Event'), 0.8561795162846109),
#  (('edas#Programme', 'ekaw#Programme_Brochure'), 0.2568290424430378),
#  (('edas#Attendee', 'ekaw#Conference_Participant'), 0.680457795262619),
#  (('edas#hasLocation', 'ekaw#heldIn'), 0.3689859558260715),
#  (('conference#Information_for_participants', 'ekaw#Programme_Brochure'),
#   0.11419782286364621),
#  (('conference#has_a_review', 'ekaw#hasReview'), 0.8414144976832975),
#  (('conference#Late_paid_applicant', 'ekaw#Late-Registered_Participant'),
#   0.33586687035150753),
#  (('conference#Early_paid_applicant', 'ekaw#Early-Registered_Participant'),
#   0.30097502276887556),
#  (('conference#Track-workshop_chair', 'ekaw#Workshop_Chair'),
#   0.7393360075552987),
#  (('conference#Conference_volume', 'ekaw#Conference'), 0.7533685068578012),
#  (('conference#Rejected_contribution', 'ekaw#Rejected_Paper'),
#   0.665432017501309),
#  (('conference#Poster', 'ekaw#Poster_Paper'), 0.848680973814423),
#  (('conference#Conference_www', 'ekaw#Web_Site'), 0.5195802296722623),
#  (('conference#contributes', 'ekaw#authorOf'), 0.3016937274326247),
#  (('conference#Accepted_contribution', 'ekaw#Accepted_Paper'),
#   0.6685831555241036),
#  (('conference#Conference_document', 'ekaw#Document'), 0.8845942230269834),
#  (('conference#Reviewed_contribution', 'ekaw#Evaluated_Paper'),
#   0.8643469743614404),
#  (('conference#Regular_author', 'ekaw#Paper_Author'), 0.6647226575589719),
#  (('confOf#Poster', 'ekaw#Poster_Paper'), 0.848680973814423),
#  (('confOf#Author', 'ekaw#Paper_Author'), 0.8141944477873271),
#  (('confOf#Banquet', 'ekaw#Conference_Banquet'), 0.8356824654363613),
#  (('confOf#Participant', 'ekaw#Conference_Participant'), 0.8650235820817712),
#  (('confOf#Trip', 'ekaw#Conference_Trip'), 0.6513987957309976),
#  (('confOf#Scholar', 'ekaw#Student'), 0.6424033499330857)]

# %%
d = {('confOf#Organization', 'sigkdd#Organizator'): (1,2,3,4),
 ('iasted#Document', 'sigkdd#Document'): (5,6,78,8)}
[[str(el) for el in flatten(el)] for el in d.items()]
# Out:
# [['confOf#Organization', 'sigkdd#Organizator', '1', '2', '3', '4'],
#  ['iasted#Document', 'sigkdd#Document', '5', '6', '78', '8']]

# %%
abbreviations_dict = {}
final_dict = {}

for mapping in all_mappings:
    mapping = tuple([el.split("#")[1] for el in mapping])
    is_abb = re.search("[A-Z][A-Z]+", mapping[0])
    if is_abb:
        abbreviation = "".join([el[0].upper() for el in mapping[1].split("_")])
        if is_abb.group() in abbreviation:
            
            start = abbreviation.find(is_abb.group())
            end = start + len(is_abb.group())
            fullform = "_".join(mapping[1].split("_")[start:end])
            print ("left", mapping, abbreviation, fullform)
            
            rest_first = " ".join([el for el in mapping[0].replace(is_abb.group(), "").split("_") if el]).lower()
            rest_second = " ".join(mapping[1].split("_")[:start] + mapping[1].split("_")[end:])
            if is_abb.group() not in final_dict:
                final_dict[is_abb.group()] = [(fullform, rest_first, rest_second)]
            else:
                final_dict[is_abb.group()].append((fullform, rest_first, rest_second))

    is_abb = re.search("[A-Z][A-Z]+", mapping[1])
    if is_abb:
        abbreviation = "".join([el[0].upper() for el in mapping[0].split("_")])
        
        if is_abb.group() in abbreviation:
            start = abbreviation.find(is_abb.group())
            end = start + len(is_abb.group())
            fullform = "_".join(mapping[0].split("_")[start:end])
            print ("right", mapping, abbreviation, fullform)

            rest_first = " ".join([el for el in mapping[1].replace(is_abb.group(), "").split("_") if el]).lower()
            rest_second = " ".join(mapping[0].split("_")[:start] + mapping[0].split("_")[end:])
            if is_abb.group() not in final_dict:
                final_dict[is_abb.group()] = [(fullform, rest_first, rest_second)]
            else:
                final_dict[is_abb.group()].append((fullform, rest_first, rest_second))

keys = [el for el in list(set(flatten([flatten([tup[1:] for tup in final_dict[key]]) for key in final_dict]))) if el]
abb_embeds = dict(zip(keys, extractUSEEmbeddings(keys)))

scored_dict = {}
for abbr in final_dict:
    sim_list = [(tup[0], tup[1], tup[2], cos_sim(abb_embeds[tup[1]], abb_embeds[tup[2]])) if tup[1] and tup[2]
                else (tup[0], tup[1], tup[2], 0) for tup in final_dict[abbr]]
    scored_dict[abbr] = sorted(list(set(sim_list)), key=lambda x:x[-1], reverse=True)

resolved_dict = {key: scored_dict[key][0] for key in scored_dict}
filtered_dict = {key: " ".join(resolved_dict[key][0].split("_")) for key in resolved_dict if resolved_dict[key][-1] > 0.9}
inp_resolved = []
for concept in inp:
    for key in filtered_dict:
        concept = concept.replace(key, filtered_dict[key])
    inp_resolved.append(concept)
inp_resolved
# Out:
# left ('Chair_PC', 'Program_Chair') PC Program_Chair
# left ('Chair_PC', 'Program_Committee') PC Program_Committee
# left ('Chair_PC', 'Program_Committee_member') PCM Program_Committee
# left ('Member_PC', 'Program_Chair') PC Program_Chair
# left ('Member_PC', 'Program_Committee') PC Program_Committee
# left ('Member_PC', 'Program_Committee_member') PCM Program_Committee
# left ('Chair_PC', 'Presenter_city') PC Presenter_city
# left ('Member_PC', 'Presenter_city') PC Presenter_city
# left ('OC_Member', 'Organizing_Committee_member') OCM Organizing_Committee
# left ('OC_Member', 'Organizing_Committee') OC Organizing_Committee
# left ('PC_Member', 'Program_Chair') PC Program_Chair
# left ('PC_Member', 'Program_Committee') PC Program_Committee
# left ('PC_Member', 'Program_Committee_member') PCM Program_Committee
# left ('OC_Chair', 'Organizing_Committee_member') OCM Organizing_Committee
# left ('OC_Chair', 'Organizing_Committee') OC Organizing_Committee
# left ('PC_Chair', 'Program_Chair') PC Program_Chair
# left ('PC_Chair', 'Program_Committee') PC Program_Committee
# left ('PC_Chair', 'Program_Committee_member') PCM Program_Committee
# right ('Passive_conference_participant', 'Chair_PC') PCP Passive_conference
# right ('Passive_conference_participant', 'Member_PC') PCP Passive_conference
# right ('Program_committee', 'Chair_PC') PC Program_committee
# right ('Program_committee', 'Member_PC') PC Program_committee
# left ('SC_Member', 'Brief_introduction_for_Session_chair') BIFSC Session_chair
# left ('SC_Member', 'Session_chair') SC Session_chair
# left ('SC_Member', 'Sponsor_city') SC Sponsor_city
# left ('SC_Member', 'Sponsor_company_house') SCH Sponsor_company
# left ('OC_Member', 'One_conference_day') OCD One_conference
# left ('PC_Member', 'Presenter_city') PC Presenter_city
# left ('OC_Chair', 'One_conference_day') OCD One_conference
# left ('PC_Chair', 'Presenter_city') PC Presenter_city
# left ('Chair_PC', 'PC_Chair') PC PC_Chair
# left ('Member_PC', 'PC_Chair') PC PC_Chair
# right ('Submitted_contribution', 'SC_Member') SC Submitted_contribution
# right ('Steering_committee', 'SC_Member') SC Steering_committee
# right ('Passive_conference_participant', 'PC_Member') PCP Passive_conference
# right ('Passive_conference_participant', 'PC_Chair') PCP Passive_conference
# right ('Program_committee', 'PC_Member') PC Program_committee
# right ('Program_committee', 'PC_Chair') PC Program_committee
# right ('Organizing_committee', 'OC_Member') OC Organizing_committee
# right ('Organizing_committee', 'OC_Chair') OC Organizing_committee
# left ('paperID', 'is_dated_on') IDO is_dated

# %%
keys = [el for el in list(set(flatten([flatten([tup[1:] for tup in final_dict[key]]) for key in final_dict]))) if el]
abb_embeds = dict(zip(keys, extractUSEEmbeddings(keys)))

# %%
cos_sim(*extractUSEEmbeddings(["Deadline for notification of acceptance", "Deadline Author notification"]))
# Out:
# 0.6263289451599121

# %%
fn, fp = pickle.load(open("test_path5_1.pkl", "rb"))

# %%
ontologies_in_alignment
# Out:
# [['confOf', 'sigkdd'],
#  ['iasted', 'sigkdd'],
#  ['cmt', 'ekaw'],
#  ['confOf', 'iasted'],
#  ['conference', 'edas'],
#  ['cmt', 'sigkdd'],
#  ['ekaw', 'sigkdd'],
#  ['conference', 'confOf'],
#  ['conference', 'sigkdd'],
#  ['confOf', 'edas'],
#  ['cmt', 'conference'],
#  ['edas', 'iasted'],
#  ['conference', 'iasted'],
#  ['edas', 'sigkdd'],
#  ['ekaw', 'iasted'],
#  ['cmt', 'edas'],
#  ['edas', 'ekaw'],
#  ['cmt', 'confOf'],
#  ['confOf', 'ekaw'],
#  ['conference', 'ekaw'],
#  ['cmt', 'iasted']]

# %%
fp
# Out:
# [(('cmt#ProgramCommitteeChair', 'ekaw#PC_Chair'), 0.9999934369224981),
#  (('cmt#ProgramCommitteeMember', 'ekaw#PC_Member'), 0.9999839542611472),
#  (('iasted#Hotel_room', 'sigkdd#Hotel'), 0.9455056507783086),
#  (('confOf#Organization', 'sigkdd#Organizator'), 1.0),
#  (('cmt#writtenBy', 'ekaw#writtenBy'), 1.0),
#  (('iasted#pay', 'sigkdd#pay'), 1.0),
#  (('iasted#Document', 'sigkdd#Document'), 1.0),
#  (('iasted#obtain', 'sigkdd#obtain'), 1.0),
#  (('cmt#Chairman', 'sigkdd#General_Chair'), 0.9182169664306405),
#  (('confOf#Social_event', 'iasted#Social_program'), 0.9243420630169328),
#  (('conference#Passive_conference_participant', 'edas#Attendee'),
#   0.9045829570298654),
#  (('cmt#PaperAbstract', 'sigkdd#Abstract'), 0.9398814618172477),
#  (('conference#Presentation', 'edas#PaperPresentation'), 0.9227664359315235),
#  (('cmt#Author', 'sigkdd#Author_of_paper'), 0.895869406686101),
#  (('conference#Conference', 'edas#Conference'), 1.0),
#  (('cmt#date', 'sigkdd#Date'), 1.0),
#  (('cmt#name', 'sigkdd#Name'), 1.0),
#  (('conference#Chair', 'sigkdd#General_Chair'), 0.9288781060598581),
#  (('ekaw#Conference_Participant', 'sigkdd#Listener'), 0.88924088982503),
#  (('ekaw#Paper_Author', 'sigkdd#Author_of_paper_student'), 0.9372961815535029),
#  (('conference#Extended_abstract', 'sigkdd#Abstract'), 0.9303638382970012),
#  (('ekaw#Paper_Author', 'sigkdd#Author_of_paper'), 0.9858267765268676),
#  (('conference#Conference_participant', 'sigkdd#Listener'), 0.88924088982503),
#  (('ekaw#PC_Member', 'sigkdd#Program_Committee_member'), 0.9999998969163005),
#  (('conference#Regular_author', 'sigkdd#Author_of_paper'), 0.9102552233832142),
#  (('conference#Conference', 'sigkdd#Conference'), 1.0),
#  (('conference#Conference', 'confOf#Conference'), 1.0),
#  (('ekaw#Organisation', 'sigkdd#Organizator'), 1.0),
#  (('conference#Organization', 'sigkdd#Organizator'), 1.0),
#  (('cmt#Paper', 'conference#Paper'), 0.9999457324923126),
#  (('cmt#PaperFullVersion', 'conference#Paper'), 0.886746745299086),
#  (('edas#PaperPresentation', 'iasted#Presentation'), 0.9060486942389531),
#  (('cmt#Reviewer', 'conference#Reviewer'), 0.9998392366623549),
#  (('confOf#Conference', 'edas#Conference'), 1.0),
#  (('confOf#hasCountry', 'edas#hasCountry'), 1.0),
#  (('edas#isWrittenBy', 'iasted#is_writen_by'), 0.8918244507168838),
#  (('edas#Person', 'iasted#Person'), 1.0),
#  (('confOf#hasPostalCode', 'edas#hasPostalCode'), 1.0),
#  (('edas#Sponsorship', 'iasted#Sponsor'), 0.9182850519799463),
#  (('confOf#hasPhone', 'edas#hasPhone'), 1.0),
#  (('confOf#hasEmail', 'edas#hasEmail'), 1.0),
#  (('confOf#hasStreet', 'edas#hasStreet'), 1.0),
#  (('confOf#hasTopic', 'edas#hasTopic'), 1.0),
#  (('edas#GovernmentOrganization', 'sigkdd#Organizator'), 0.9391334310796076),
#  (('edas#TPCMember', 'sigkdd#Program_Committee_member'), 0.9994037593505222),
#  (('conference#Presentation', 'iasted#Presentation'), 0.9998008889312407),
#  (('edas#Sponsorship', 'sigkdd#Sponzor'), 0.9182850519799463),
#  (('edas#Organization', 'sigkdd#Organizator'), 1.0),
#  (('edas#hasName', 'sigkdd#Name'), 1.0),
#  (('conference#is_given_by', 'iasted#is_given_by'), 1.0),
#  (('cmt#Paper', 'confOf#Paper'), 0.999998894239506),
#  (('cmt#ProgramCommitteeMember', 'edas#TPCMember'), 0.9999952129150204),
#  (('cmt#Chairman', 'edas#ConferenceChair'), 0.9323692214645233),
#  (('edas#TPCMember', 'ekaw#PC_Member'), 0.9999940012958162),
#  (('edas#Presenter', 'ekaw#Presenter'), 0.9999964092156857),
#  (('cmt#email', 'edas#hasEmail'), 1.0),
#  (('cmt#title', 'confOf#has_title'), 1.0),
#  (('edas#Conference', 'ekaw#Conference'), 1.0),
#  (('edas#ConferenceSession', 'ekaw#Conference_Session'), 1.0),
#  (('cmt#name', 'edas#hasName'), 1.0),
#  (('edas#hasLocation', 'ekaw#locationOf'), 0.9459043859432793),
#  (('cmt#writtenBy', 'confOf#writtenBy'), 1.0),
#  (('conference#Invited_talk', 'ekaw#Invited_Talk'), 0.9999803570800074),
#  (('conference#Extended_abstract', 'ekaw#Abstract'), 0.9500528081866834),
#  (('cmt#Paper', 'iasted#Submission'), 0.9485684614929605),
#  (('conference#Conference_participant', 'ekaw#Conference_Participant'), 1.0),
#  (('confOf#Paper', 'ekaw#Paper'), 0.999892530479969),
#  (('conference#Paper', 'ekaw#Paper'), 0.9995912699696715),
#  (('conference#Co-chair', 'ekaw#OC_Chair'), 0.9994910673964745),
#  (('confOf#writtenBy', 'ekaw#writtenBy'), 1.0),
#  (('conference#Conference', 'ekaw#Conference'), 1.0),
#  (('cmt#Document', 'iasted#Document'), 1.0)]

# %%
Ontology("conference_ontologies/conference.owl").triples
# Out:
# [('Conference_proceedings', 'string', 'has_a_name'),
#  ('Committee_member', 'Committee', 'was_a_member_of'),
#  ('Review', 'Conference_document', 'subclass_of'),
#  ('Review_preference', 'Reviewer', 'belongs_to_reviewers'),
#  ('Information_for_participants', 'Conference_document', 'subclass_of'),
#  ('Regular_author', 'Conference_contributor', 'subclass_of'),
#  ('Late_paid_applicant', 'Paid_applicant', 'subclass_of'),
#  ('Active_conference_participant', 'Presentation', 'gives_presentations'),
#  ('Invited_speaker', 'Conference_contributor', 'subclass_of'),
#  ('Program_committee', 'Conference_volume', 'was_a_program_committee_of'),
#  ('Topic', 'Review_preference', 'has_been_assigned_a_review_reference'),
#  ('Conference_volume', 'Important_dates', 'has_important_dates'),
#  ('Rejected_contribution', 'Reviewed_contribution', 'subclass_of'),
#  ('Contribution_co-author', 'Regular_author', 'subclass_of'),
#  ('Active_conference_participant', 'Conference_contributor', 'subclass_of'),
#  ('Presentation', 'Abstract', 'has_an_abstract'),
#  ('Conference_proceedings', 'string', 'has_an_ISBN'),
#  ('Accepted_contribution', 'Reviewed_contribution', 'subclass_of'),
#  ('Steering_committee', 'Committee', 'subclass_of'),
#  ('Conference_www', 'Conference_document', 'subclass_of'),
#  ('Person', 'string', 'has_an_email'),
#  ('Passive_conference_participant', 'Conference_participant', 'subclass_of'),
#  ('Program_committee', 'Committee', 'subclass_of'),
#  ('Workshop', 'Conference_part', 'subclass_of'),
#  ('Active_conference_participant', 'Regular_author', 'subclass_of'),
#  ('Submitted_contribution', 'Poster', 'subclass_of'),
#  ('Organizer', 'Organization', 'subclass_of'),
#  ('Co-chair', 'Committee', 'was_a_committe_co-chair_of'),
#  ('Reviewed_contribution', 'Submitted_contribution', 'subclass_of'),
#  ('Topic', 'Review_preference', 'belongs_to_a_review_reference'),
#  ('Submitted_contribution',
#   'Review_preference',
#   'has_been_assigned_a_review_reference'),
#  ('Conference_part', 'string', 'has_a_name'),
#  ('Person', 'string', 'has_the_last_name'),
#  ('Conference_volume', 'Tutorial', 'has_tutorials'),
#  ('Conference_participant', 'Person', 'subclass_of'),
#  ('Topic', 'string', 'has_a_name'),
#  ('Review_expertise', 'Reviewer', 'belongs_to_reviewers'),
#  ('Conference_volume', 'Organizing_committee', 'has_an_organizing_committee'),
#  ('Submitted_contribution', 'Review_expertise', 'has_a_review_expertise'),
#  ('Conference_volume', 'Workshop', 'has_workshops'),
#  ('Committee', 'Chair', 'has_a_committee_chair'),
#  ('Conference_volume', 'Conference', 'subclass_of'),
#  ('Abstract', 'Presentation', 'is_the_1th_part_of'),
#  ('Co-chair', 'Committee_member', 'subclass_of'),
#  ('Chair', 'Committee_member', 'subclass_of'),
#  ('Important_dates', 'date', 'is_a_full_paper_submission_date'),
#  ('Important_dates', 'date', 'is_a_starting_date'),
#  ('Important_dates', 'date', 'is_an_abstract_submission_date'),
#  ('Committee', 'Co-chair', 'has_a_committee_co-chair'),
#  ('Reviewer', 'Reviewer', 'invites_co-reviewers'),
#  ('Submitted_contribution', 'Regular_contribution', 'subclass_of'),
#  ('Presentation', 'Conference_contribution', 'subclass_of'),
#  ('Committee', 'Conference_volume', 'was_a_committee_of'),
#  ('Track', 'Conference_part', 'subclass_of'),
#  ('Important_dates', 'Conference_volume', 'belong_to_a_conference_volume'),
#  ('Conference_document', 'Person', 'has_authors'),
#  ('Important_dates', 'date', 'is_an_ending_date'),
#  ('Review', 'Reviewed_contribution', 'reviews'),
#  ('Written_contribution', 'Regular_contribution', 'subclass_of'),
#  ('Poster', 'Conference_contribution', 'subclass_of'),
#  ('Call_for_paper', 'Conference_document', 'subclass_of'),
#  ('Conference_part',
#   'Track-workshop_chair',
#   'has_a_track-workshop-tutorial_chair'),
#  ('Written_contribution', 'Poster', 'subclass_of'),
#  ('Conference_contributor', 'Person', 'subclass_of'),
#  ('Conference_volume', 'string', 'has_a_location'),
#  ('Written_contribution', 'Conference_contribution', 'subclass_of'),
#  ('Submitted_contribution', 'Written_contribution', 'subclass_of'),
#  ('Conference_volume', 'Program_committee', 'has_a_program_committee'),
#  ('Reviewed_contribution', 'Review', 'has_a_review'),
#  ('Conference_contribution', 'Conference_volume', 'is_submitted_at'),
#  ('Conference_volume', 'Conference_part', 'has_parts'),
#  ('Call_for_participation', 'Conference_document', 'subclass_of'),
#  ('Abstract', 'Paper', 'is_the_1th_part_of'),
#  ('Poster', 'Abstract', 'has_an_abstract'),
#  ('Publisher', 'string', 'has_a_name'),
#  ('Conference_document', 'date', 'has_a_date_of_issue'),
#  ('Conference_volume', 'Conference_contribution', 'has_contributions'),
#  ('Review_expertise',
#   'Submitted_contribution',
#   'has_a_submitted_contribution'),
#  ('Organizing_committee', 'Committee', 'subclass_of'),
#  ('Regular_contribution', 'Written_contribution', 'subclass_of'),
#  ('Conference_proceedings', 'int', 'has_a_volume'),
#  ('Active_conference_participant', 'Invited_speaker', 'subclass_of'),
#  ('Extended_abstract', 'Regular_contribution', 'subclass_of'),
#  ('Contribution_1th-author', 'Regular_author', 'subclass_of'),
#  ('Conference_contribution', 'Conference_document', 'subclass_of'),
#  ('Conference_volume', 'Track', 'has_tracks'),
#  ('Review_preference', 'Topic', 'has_a_topic_or_a_submission_contribution'),
#  ('Reviewer', 'Person', 'subclass_of'),
#  ('Tutorial', 'Conference_part', 'subclass_of'),
#  ('Committee', 'Committee_member', 'has_members'),
#  ('Person', 'Conference_document', 'contributes'),
#  ('Conference_proceedings', 'Publisher', 'has_a_publisher'),
#  ('Review_preference', 'int', 'has_a_degree'),
#  ('Topic', 'Conference_part', 'is_a_topis_of_conference_parts'),
#  ('Conference_www', 'string', 'has_a_URL'),
#  ('Organizer', 'Committee_member', 'subclass_of'),
#  ('Paper', 'Regular_contribution', 'subclass_of'),
#  ('Conference_part', 'Conference_volume', 'is_part_of_conference_volumes'),
#  ('Conference_volume', 'Steering_committee', 'has_a_steering_committee'),
#  ('Camera_ready_contribution', 'Accepted_contribution', 'subclass_of'),
#  ('Abstract', 'Extended_abstract', 'subclass_of'),
#  ('Track-workshop_chair', 'Person', 'subclass_of'),
#  ('Invited_talk', 'Presentation', 'subclass_of'),
#  ('Paper', 'Abstract', 'has_an_abstract'),
#  ('Conference_applicant', 'Person', 'subclass_of'),
#  ('Steering_committee', 'Conference_volume', 'was_a_steering_committee_of'),
#  ('Track-workshop_chair', 'Conference_part', 'was_a_track-workshop_chair_of'),
#  ('Reviewer', 'Review_preference', 'has_a_review_reference_or_expertise'),
#  ('Organizing_committee',
#   'Conference_volume',
#   'was_an_organizing_committee_of'),
#  ('Important_dates', 'date', 'is_a_date_of_acceptance_announcement'),
#  ('Committee_member', 'Person', 'subclass_of'),
#  ('Conference_volume', 'Committee', 'has_a_commtitee'),
#  ('Abstract', 'Poster', 'is_the_1th_part_of'),
#  ('Person', 'string', 'has_the_first_name'),
#  ('Review_preference',
#   'Submitted_contribution',
#   'has_a_topic_or_a_submission_contribution'),
#  ('Important_dates', 'date', 'is_a_date_of_camera_ready_paper_submission'),
#  ('Publisher', 'Conference_proceedings', 'issues'),
#  ('Conference_part', 'Topic', 'has_a_track-workshop-tutorial_topic'),
#  ('Paid_applicant', 'Registeered_applicant', 'subclass_of'),
#  ('Early_paid_applicant', 'Paid_applicant', 'subclass_of'),
#  ('Conference_announcement', 'Conference_document', 'subclass_of'),
#  ('Reviewer', 'Review_expertise', 'has_a_review_reference_or_expertise'),
#  ('Presentation', 'Active_conference_participant', 'is_given_by'),
#  ('Reviewer', 'Reviewer', 'invited_by'),
#  ('Chair', 'Committee', 'was_a_committee_chair_of'),
#  ('Conference', 'string', 'has_a_name'),
#  ('Registeered_applicant', 'Conference_applicant', 'subclass_of'),
#  ('Active_conference_participant', 'Conference_participant', 'subclass_of')]

# %%
fn, fp = pickle.load(open("test_lstm4_2.pkl", "rb"))

# %%
fn
# Out:
# [(('confOf#Member_PC', 'sigkdd#Program_Committee_member'), 0.9821488151234276),
#  (('confOf#hasEmail', 'sigkdd#E-mail'), 0.9161555776735063),
#  (('confOf#Chair_PC', 'sigkdd#Program_Chair'), 0.7888411974945077),
#  (('iasted#Student_registration_fee', 'sigkdd#Registration_Student'),
#   0.4687132189112725),
#  (('iasted#Deadline_for_notification_of_acceptance',
#    'sigkdd#Deadline_Author_notification'),
#   0.6263288918181976),
#  (('iasted#Nonmember_registration_fee', 'sigkdd#Registration_Non-Member'),
#   0.6004082945181627),
#  (('iasted#Author', 'sigkdd#Author'), 0.3705828543501226),
#  (('cmt#ConferenceMember', 'ekaw#Conference_Participant'), 0.834017866174724),
#  (('cmt#Author', 'ekaw#Paper_Author'), 0.8141944477873271),
#  (('cmt#writtenBy', 'ekaw#reviewWrittenBy'), 0.7592434303979944),
#  (('cmt#hasBeenAssigned', 'ekaw#reviewerOfPaper'), 0.2502871547766108),
#  (('cmt#assignedTo', 'ekaw#hasReviewer'), 0.3499445900379554),
#  (('cmt#PaperFullVersion', 'ekaw#Regular_Paper'), 0.10331508386734323),
#  (('confOf#Event', 'iasted#Activity'), 0.5581517710561262),
#  (('confOf#Banquet', 'iasted#Dinner_banquet'), 0.18097070808734436),
#  (('confOf#Administrative_event', 'iasted#Activity_before_conference'),
#   0.3036915113998797),
#  (('confOf#Reception', 'iasted#Coctail_reception'), -0.03129058186116528),
#  (('confOf#Tutorial', 'iasted#Tutorial'), 0.21387886017822516),
#  (('confOf#Country', 'iasted#State'), 0.5430233172462778),
#  (('conference#Conference_participant', 'edas#Attendee'), 0.680457795262619),
#  (('conference#Conference_part', 'edas#ConferenceEvent'), 0.7123990785927831),
#  (('conference#Conference_document', 'edas#Document'), 0.7318412469605324),
#  (('conference#has_a_review_expertise', 'edas#hasRating'), 0.3899073903898582),
#  (('conference#Conference_volume', 'edas#Conference'), 0.7533685068578012),
#  (('conference#Rejected_contribution', 'edas#RejectedPaper'),
#   0.09788885353992387),
#  (('conference#Accepted_contribution', 'edas#AcceptedPaper'),
#   -0.050747441241070154),
#  (('conference#Regular_author', 'edas#Author'), 0.6760209535160544),
#  (('cmt#ProgramCommitteeMember', 'sigkdd#Program_Committee_member'),
#   0.12101807605307842),
#  (('cmt#ConferenceChair', 'sigkdd#General_Chair'), 0.10862814819370689),
#  (('cmt#ProgramCommitteeChair', 'sigkdd#Program_Chair'), 0.27471117733011247),
#  (('cmt#Author', 'sigkdd#Author'), 0.3269696970747065),
#  (('cmt#submitPaper', 'sigkdd#submit'), 0.7581630948456032),
#  (('ekaw#Invited_Speaker', 'sigkdd#Invited_Speaker'), -0.005471438831432869),
#  (('ekaw#OC_Member', 'sigkdd#Organizing_Committee_member'),
#   -0.3221050977175612),
#  (('ekaw#PC_Chair', 'sigkdd#Program_Chair'), 0.10384285524445626),
#  (('ekaw#Paper_Author', 'sigkdd#Author'), 0.8141944477873271),
#  (('ekaw#Location', 'sigkdd#Place'), 0.8596690903888166),
#  (('conference#Invited_speaker', 'sigkdd#Invited_Speaker'),
#   0.08755618637463043),
#  (('conference#Regular_author', 'sigkdd#Author'), 0.4074159367903612),
#  (('conference#Conference_volume', 'sigkdd#Conference'), 0.7533685068578012),
#  (('conference#Conference_fees', 'sigkdd#Fee'), 0.6188697294990487),
#  (('conference#has_an_email', 'sigkdd#E-mail'), 0.7713571936527924),
#  (('conference#is_given_by', 'sigkdd#presentationed_by'), 0.3609120954885683),
#  (('conference#gives_presentations', 'sigkdd#presentation'),
#   0.6056676430562652),
#  (('conference#Conference_document', 'sigkdd#Document'), 0.7318412469605324),
#  (('conference#Conference_participant', 'confOf#Participant'),
#   0.7016424044537422),
#  (('conference#has_an_email', 'confOf#hasEmail'), 0.8262672905906706),
#  (('conference#Conference_contribution', 'confOf#Contribution'),
#   0.7123623222067245),
#  (('conference#Conference_volume', 'confOf#Conference'), 0.7533685068578012),
#  (('conference#has_a_track-workshop-tutorial_topic', 'confOf#hasTopic'),
#   0.2714890208534184),
#  (('conference#Regular_author', 'confOf#Author'), 0.6760209535160544),
#  (('conference#has_the_last_name', 'confOf#hasSurname'), 0.8760424400918999),
#  (('conference#has_the_first_name', 'confOf#hasFirstName'), 0.880357115623567),
#  (('confOf#Trip', 'edas#Excursion'), 0.0008992838706213022),
#  (('confOf#reviewes', 'edas#isReviewing'), 0.6861398267050898),
#  (('confOf#writtenBy', 'edas#isWrittenBy'), 0.8407108246292888),
#  (('confOf#Working_event', 'edas#AcademicEvent'), 0.5697583260242169),
#  (('confOf#Reception', 'edas#Reception'), -0.25005143444249417),
#  (('confOf#hasSurname', 'edas#hasLastName'), 0.9311650234513776),
#  (('confOf#Workshop', 'edas#Workshop'), -0.33005956141346166),
#  (('confOf#Event', 'edas#ConferenceEvent'), 0.7100217396868489),
#  (('confOf#Participant', 'edas#Attendee'), 0.8228379601853789),
#  (('confOf#Member_PC', 'edas#TPCMember'), 0.9821488151234276),
#  (('confOf#writes', 'edas#hasRelatedPaper'), 0.297312720126214),
#  (('edas#Country', 'iasted#State'), 0.5430233172462778),
#  (('edas#WelcomeTalk', 'iasted#Welcome_address'), 0.41187487085386565),
#  (('edas#Attendee', 'iasted#Delegate'), 0.5733914370867992),
#  (('edas#ConferenceDinner', 'iasted#Dinner_banquet'), 0.20408367034059077),
#  (('edas#SocialEvent', 'iasted#Social_program'), 0.6417233591092479),
#  (('edas#CoffeeBreak', 'iasted#Coffee_break'), 0.606221417627202),
#  (('edas#Reception', 'iasted#Coctail_reception'), -0.029877606166541237),
#  (('edas#ConferenceEvent', 'iasted#Conference_activity'), 0.7512946188134567),
#  (('edas#SlideSet', 'iasted#Transparency'), 0.22742734295143396),
#  (('edas#Paper', 'iasted#Submission'), 0.417742688704723),
#  (('edas#ConferenceVenuePlace', 'iasted#Conference_building'),
#   0.6181335242447228),
#  (('edas#DiningPlace', 'iasted#Conference_restaurant'), 0.6283572995412593),
#  (('cmt#Conference', 'conference#Conference_volume'), 0.7533685068578012),
#  (('cmt#Preference', 'conference#Review_preference'), 0.783329808487203),
#  (('cmt#Author', 'conference#Regular_author'), -0.03144576501007539),
#  (('cmt#email', 'conference#has_an_email'), 0.8262672905906706),
#  (('cmt#Co-author', 'conference#Contribution_co-author'), 0.21237458097590423),
#  (('cmt#PaperAbstract', 'conference#Abstract'), -0.013282719905117727),
#  (('cmt#Document', 'conference#Conference_document'), 0.7318412469605324),
#  (('cmt#Chairman', 'conference#Chair'), 0.7892468263134209),
#  (('cmt#SubjectArea', 'conference#Topic'), 0.7154184628848549),
#  (('cmt#assignedByReviewer', 'conference#invited_by'), 0.48464419365137834),
#  (('cmt#assignExternalReviewer', 'conference#invites_co-reviewers'),
#   0.4054012020450263),
#  (('edas#hasCostAmount', 'sigkdd#Price'), 0.7047592167957165),
#  (('edas#hasName', 'sigkdd#Name_of_conference'), 0.4805131633714943),
#  (('edas#ConferenceVenuePlace', 'sigkdd#Conference_hall'), 0.6646223919595833),
#  (('edas#AccommodationPlace', 'sigkdd#Hotel'), 0.5498427937907697),
#  (('edas#startDate', 'sigkdd#Start_of_conference'), 0.528186177578591),
#  (('edas#ConferenceChair', 'sigkdd#General_Chair'), 0.5731875576956728),
#  (('edas#endDate', 'sigkdd#End_of_conference'), 0.5493031244333424),
#  (('edas#Attendee', 'sigkdd#Listener'), 0.4827829321776764),
#  (('conference#Passive_conference_participant', 'iasted#Listener'),
#   -0.18738920796302297),
#  (('conference#Active_conference_participant', 'iasted#Speaker'),
#   0.5047184594171131),
#  (('conference#Regular_author', 'iasted#Author'), 0.5959274881310813),
#  (('conference#Conference_fees', 'iasted#Fee'), 0.6188697294990487),
#  (('conference#contributes', 'iasted#write'), 0.37880804066855067),
#  (('conference#Conference_document', 'iasted#Document'), 0.7318412469605324),
#  (('conference#Conference_part', 'iasted#Conference_activity'),
#   0.6551659304932106),
#  (('conference#Submitted_contribution', 'iasted#Submission'),
#   -0.012160660146596171),
#  (('conference#Camera_ready_contribution', 'iasted#Final_manuscript'),
#   0.10275980636189408),
#  (('conference#Conference_proceedings', 'iasted#Publication'),
#   0.24726511082421077),
#  (('ekaw#Location', 'iasted#Place'), 0.8596690903888166),
#  (('ekaw#Event', 'iasted#Activity'), 0.5581517710561262),
#  (('ekaw#Paper_Author', 'iasted#Author'), 0.8141944477873271),
#  (('ekaw#Session', 'iasted#Session'), 0.4149855588830988),
#  (('ekaw#Conference_Banquet', 'iasted#Dinner_banquet'), -0.07428776285315747),
#  (('ekaw#Tutorial', 'iasted#Tutorial'), 0.0828616558366563),
#  (('ekaw#Session_Chair', 'iasted#Session_chair'), -0.032061339360600974),
#  (('cmt#ProgramCommitteeChair', 'confOf#Chair_PC'), 0.986554819545401),
#  (('cmt#writePaper', 'confOf#writes'), 0.6220006428478738),
#  (('cmt#ConferenceMember', 'confOf#Member'), 0.6716821946490479),
#  (('cmt#SubjectArea', 'confOf#Topic'), 0.7154184628848549),
#  (('cmt#PaperFullVersion', 'confOf#Paper'), 0.48035408507207067),
#  (('cmt#hasBeenAssigned', 'confOf#reviewes'), 0.40867753235276827),
#  (('cmt#hasAuthor', 'confOf#writtenBy'), 0.5261010208677641),
#  (('cmt#ProgramCommitteeMember', 'confOf#Member_PC'), 0.9821488151234276),
#  (('cmt#hasSubjectArea', 'confOf#dealsWith'), 0.25596982134585333),
#  (('cmt#Paper', 'confOf#Contribution'), 0.3507197898940486),
#  (('cmt#hasConferenceMember', 'edas#hasMember'), 0.6716821946490479),
#  (('cmt#memberOfConference', 'edas#isMemberOf'), 0.5384339627563817),
#  (('cmt#hasAuthor', 'edas#isWrittenBy'), 0.3940901098620504),
#  (('cmt#hasBeenAssigned', 'edas#isReviewing'), 0.4039842265275537),
#  (('cmt#assignedTo', 'edas#isReviewedBy'), 0.5476728328223632),
#  (('edas#ConferenceDinner', 'ekaw#Conference_Banquet'), -0.10068103130354622),
#  (('edas#AcademicEvent', 'ekaw#Scientific_Event'), 0.6817697160376507),
#  (('edas#AcceptedPaper', 'ekaw#Accepted_Paper'), -0.18724426310324924),
#  (('edas#isReviewedBy', 'ekaw#hasReviewer'), 0.38891106779153306),
#  (('edas#Place', 'ekaw#Location'), 0.8596690903888166),
#  (('edas#AcademiaOrganization', 'ekaw#Academic_Institution'),
#   0.6167993963857633),
#  (('edas#isReviewing', 'ekaw#reviewerOfPaper'), 0.4574440998156941),
#  (('edas#Author', 'ekaw#Paper_Author'), 0.8141944477873271),
#  (('edas#isLocationOf', 'ekaw#locationOf'), 0.7440274368714033),
#  (('edas#Topic', 'ekaw#Research_Topic'), 0.7430159871513041),
#  (('edas#RejectedPaper', 'ekaw#Rejected_Paper'), -0.020348237640516728),
#  (('edas#ConferenceEvent', 'ekaw#Event'), 0.7100217396868489),
#  (('edas#Programme', 'ekaw#Programme_Brochure'), 0.536879033526011),
#  (('edas#Workshop', 'ekaw#Workshop'), 0.06704767808008007),
#  (('edas#Attendee', 'ekaw#Conference_Participant'), 0.680457795262619),
#  (('edas#hasLocation', 'ekaw#heldIn'), 0.3689859558260715),
#  (('conference#Information_for_participants', 'ekaw#Programme_Brochure'),
#   0.11419782286364621),
#  (('conference#has_a_review', 'ekaw#hasReview'), 0.8414144924885054),
#  (('conference#Late_paid_applicant', 'ekaw#Late-Registered_Participant'),
#   -0.09589691192403141),
#  (('conference#Early_paid_applicant', 'ekaw#Early-Registered_Participant'),
#   -0.029289772843140164),
#  (('conference#Track-workshop_chair', 'ekaw#Workshop_Chair'),
#   0.8792302506300801),
#  (('conference#Conference_volume', 'ekaw#Conference'), 0.7533685068578012),
#  (('conference#Rejected_contribution', 'ekaw#Rejected_Paper'),
#   -0.07034024700273334),
#  (('conference#Poster', 'ekaw#Poster_Paper'), 0.30490975985805313),
#  (('conference#Topic', 'ekaw#Research_Topic'), 0.7430159871513041),
#  (('conference#Conference_www', 'ekaw#Web_Site'), 0.38331955121201877),
#  (('conference#Invited_speaker', 'ekaw#Invited_Speaker'), 0.2001741891398703),
#  (('conference#contributes', 'ekaw#authorOf'), 0.3016937274326247),
#  (('conference#Accepted_contribution', 'ekaw#Accepted_Paper'),
#   0.026288591670958063),
#  (('conference#Conference_document', 'ekaw#Document'), 0.7318412337363689),
#  (('conference#Reviewed_contribution', 'ekaw#Evaluated_Paper'),
#   -0.14433291569085221),
#  (('conference#Submitted_contribution', 'ekaw#Submitted_Paper'),
#   -0.2408891091773817),
#  (('conference#Regular_author', 'ekaw#Paper_Author'), 0.6647226575589719),
#  (('confOf#Tutorial', 'ekaw#Tutorial'), -0.20946678461094698),
#  (('confOf#Poster', 'ekaw#Poster_Paper'), 0.848680973814423),
#  (('confOf#Working_event', 'ekaw#Scientific_Event'), 0.567228825030526),
#  (('confOf#Author', 'ekaw#Paper_Author'), 0.8141944477873271),
#  (('confOf#Banquet', 'ekaw#Conference_Banquet'), -0.06086751587648767),
#  (('confOf#Topic', 'ekaw#Research_Topic'), 0.7430159871513041),
#  (('confOf#Contribution', 'ekaw#Paper'), 0.3507197898940486),
#  (('confOf#Participant', 'ekaw#Conference_Participant'), 0.7016424044537422),
#  (('confOf#Trip', 'ekaw#Conference_Trip'), 0.1653674921166052),
#  (('confOf#Scholar', 'ekaw#Student'), 0.6424033499330857),
#  (('cmt#Author', 'iasted#Author'), -0.11634449534401786),
#  (('cmt#Reviewer', 'iasted#Reviewer'), -0.17988360759238078)]

# %%
fp
# Out:
# [(('iasted#obtain', 'sigkdd#obtain'), 1.0),
#  (('iasted#pay', 'sigkdd#pay'), 1.0),
#  (('iasted#Document', 'sigkdd#Document'), 1.0),
#  (('confOf#Organization', 'sigkdd#Organizator'), 1.0),
#  (('cmt#writtenBy', 'ekaw#writtenBy'), 1.0),
#  (('confOf#Camera_Ready_event', 'iasted#Receiving_manuscript'),
#   0.9066686556244711),
#  (('cmt#Administrator', 'sigkdd#Program_Chair'), 0.9217834141598852),
#  (('conference#Chair', 'edas#Reception'), 0.981828811095803),
#  (('conference#Registeered_applicant', 'edas#ComputerNetworksOpticalTopic'),
#   0.996343065443642),
#  (('confOf#Registration_of_participants_event', 'iasted#Lecture'),
#   0.9902831965079355),
#  (('conference#Passive_conference_participant', 'edas#FreeTimeBreak'),
#   0.9415719517377226),
#  (('confOf#Banquet', 'iasted#Author'), 0.9932710473256426),
#  (('conference#Conference', 'edas#Conference'), 1.0),
#  (('cmt#name', 'sigkdd#Name'), 1.0),
#  (('cmt#date', 'sigkdd#Date'), 1.0),
#  (('conference#Conference', 'confOf#Conference'), 1.0),
#  (('ekaw#Organisation', 'sigkdd#Organizator'), 1.0),
#  (('conference#Organization', 'sigkdd#Organizator'), 1.0),
#  (('conference#Conference', 'sigkdd#Conference'), 1.0),
#  (('confOf#hasPhone', 'edas#hasPhone'), 1.0),
#  (('confOf#hasStreet', 'edas#hasStreet'), 1.0),
#  (('cmt#Reviewer', 'conference#Reviewer'), 1.0),
#  (('confOf#hasEmail', 'edas#hasEmail'), 1.0),
#  (('confOf#hasPostalCode', 'edas#hasPostalCode'), 1.0),
#  (('cmt#Paper', 'conference#Paper'), 1.0),
#  (('confOf#hasCountry', 'edas#hasCountry'), 1.0),
#  (('edas#Person', 'iasted#Person'), 1.0),
#  (('confOf#hasTopic', 'edas#hasTopic'), 1.0),
#  (('confOf#Conference', 'edas#Conference'), 1.0),
#  (('edas#hasName', 'sigkdd#Name'), 1.0),
#  (('edas#TPCMember', 'sigkdd#Program_Committee_member'), 1.0),
#  (('edas#Organization', 'sigkdd#Organizator'), 1.0),
#  (('conference#is_given_by', 'iasted#is_given_by'), 1.0),
#  (('cmt#name', 'edas#hasName'), 1.0),
#  (('cmt#title', 'confOf#has_title'), 1.0),
#  (('cmt#writtenBy', 'confOf#writtenBy'), 1.0),
#  (('edas#TPCMember', 'ekaw#PC_Member'), 1.0),
#  (('edas#Conference', 'ekaw#Conference'), 1.0),
#  (('cmt#ProgramCommitteeMember', 'edas#TPCMember'), 1.0),
#  (('cmt#Paper', 'confOf#Paper'), 1.0),
#  (('edas#ConferenceSession', 'ekaw#Conference_Session'), 1.0),
#  (('edas#Presenter', 'ekaw#Presenter'), 1.0),
#  (('cmt#email', 'edas#hasEmail'), 1.0),
#  (('cmt#PaperFullVersion', 'iasted#Author'), 0.9957505098048379),
#  (('confOf#Reception', 'ekaw#Late-Registered_Participant'), 0.997082666031856),
#  (('cmt#ProgramCommitteeChair', 'iasted#Plenary_lecture_speaker'),
#   0.997303054282327),
#  (('conference#Chair', 'ekaw#Proceedings'), 0.9993795887229124),
#  (('conference#Conference', 'ekaw#Conference'), 1.0),
#  (('confOf#writtenBy', 'ekaw#writtenBy'), 1.0),
#  (('conference#Paper', 'ekaw#Paper'), 1.0),
#  (('cmt#Document', 'iasted#Document'), 1.0),
#  (('confOf#Paper', 'ekaw#Paper'), 1.0),
#  (('conference#Conference_participant', 'ekaw#Conference_Participant'), 1.0)]
