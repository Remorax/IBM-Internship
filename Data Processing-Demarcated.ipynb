# %%
# Construction of dataset

import os, itertools, time, pickle, sys, glob, requests
import subprocess
from xml.dom import minidom
from collections import Counter, OrderedDict
from operator import itemgetter
from nltk.corpus import wordnet
import tensorflow as tf
import tensorflow_hub as hub
from scipy import spatial
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from sklearn.feature_extraction.text import TfidfVectorizer
import re
import numpy as np
import scipy.sparse as sp
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from math import ceil, exp
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
import networkx as nx
import matplotlib.pyplot as plt
from orderedset import OrderedSet
from copy import deepcopy
# %matplotlib inline

# %%
flatten = lambda l: [item for sublist in l for item in sublist]

class Ontology():
    def __init__(self, ontology):
        self.ontology = ontology
        self.ontology_obj = minidom.parse(ontology)
        self.root = self.ontology_obj.documentElement
        self.construct_mapping_dict()
        
        self.parents_dict = {}
        self.subclasses = self.parse_subclasses()
        self.object_properties = self.parse_object_properties()
        self.data_properties = self.parse_data_properties()
        self.triples = self.parse_triples()
        self.classes = self.parse_classes()        
    
    def construct_mapping_dict(self):
        self.mapping_dict = {self.extract_ID(el, False): self.get_child_node(el, "rdfs:label")[0].firstChild.nodeValue for el in self.root.getElementsByTagName("owl:Class") if self.get_child_node(el, "rdfs:label")}
        self.mapping_dict_inv = {self.mapping_dict[key]: key for key in self.mapping_dict}
        return
        
    def get_child_node(self, element, tag):
        return [e for e in element._get_childNodes() if type(e)==minidom.Element and e._get_tagName() == tag]
        
    def has_attribute_value(self, element, attribute, value):
        return True if element.getAttribute(attribute).split("#")[-1] == value else False
    
    def get_subclass_triples(self):
        subclasses = self.get_subclasses()
        self.parents_dict = {}
        for (a,b,c,d) in subclasses:
            if c == "subclass_of" and a!="Thing" and b!="Thing":
                if b not in self.parents_dict:
                    self.parents_dict[b] = [a]
                else:
                    self.parents_dict[b].append(a)
        return [(b,a,c,d) for (a,b,c,d) in subclasses]
    
    def parse_triples(self, union_flag=0, subclass_of=True):
        obj_props = [(prop, "Object Property") for prop in self.object_properties]
        data_props = [(prop, "Datatype Property") for prop in self.data_properties]
        props = obj_props + data_props
        all_triples = []
        for prop, prop_type in props:
            domain_children = self.get_child_node(prop, "rdfs:domain")
            range_children = self.get_child_node(prop, "rdfs:range")
            domain_prop = self.filter_null([self.extract_ID(el) for el in domain_children])
            range_prop = self.filter_null([self.extract_ID(el) for el in range_children])
            if not domain_children or not range_children:
                continue
            if not domain_prop:
                domain_prop = self.filter_null([self.extract_ID(el) for el in domain_children[0].getElementsByTagName("owl:Class")])
            if not range_prop:
                range_prop = self.filter_null([self.extract_ID(el) for el in range_children[0].getElementsByTagName("owl:Class")])
            if domain_prop and range_prop:
                if union_flag == 0:
                    all_triples.extend([(el[0], el[1], self.extract_ID(prop), prop_type) for el in list(itertools.product(domain_prop, range_prop))])
                else:
                    all_triples.append(("###".join(domain_prop), "###".join(range_prop), self.extract_ID(prop), prop_type))
        if subclass_of:
            all_triples.extend(self.get_subclass_triples())
        return list(set(all_triples))
    
    def get_triples(self, union_flag=0, subclass_of=True):
        return self.parse_triples(union_flag, subclass_of)

    def parse_subclasses(self, union_flag=0):
        subclasses = self.root.getElementsByTagName("rdfs:subClassOf")
        subclass_pairs = []
        for el in subclasses:
            inline_subclasses = self.extract_ID(el)
            if inline_subclasses:
                subclass_pairs.append((el, el.parentNode, "subclass_of", "Subclass"))
            else:
                level1_class = self.get_child_node(el, "owl:Class")
                if not level1_class:
                    restriction = el.getElementsByTagName("owl:Restriction")
                    if not restriction:
                        continue
                    prop = self.get_child_node(restriction[0], "owl:onProperty")
                    some_vals = self.get_child_node(restriction[0], "owl:someValuesFrom")
                    
                    if not prop or not some_vals:
                        continue
#                     print(self.extract_ID(el), "**", self.extract_ID(some_vals[0]), "**", self.extract_ID(prop[0]))
                    try:
                        if self.extract_ID(prop[0]) and self.extract_ID(some_vals[0]):
                            subclass_pairs.append((el.parentNode, some_vals[0], self.extract_ID(prop[0]), "Object Property"))
                        elif self.extract_ID(prop[0]) and not self.extract_ID(some_vals[0]):
                            class_vals = self.get_child_node(some_vals[0], "owl:Class")
                            subclass_pairs.append((el.parentNode, class_vals[0], self.extract_ID(prop[0]), "Object Property"))
                        elif not self.extract_ID(prop[0]) and self.extract_ID(some_vals[0]):
                            prop_vals = self.get_child_node(prop[0], "owl:ObjectProperty")
                            subclass_pairs.append((el.parentNode, some_vals[0], self.extract_ID(prop_vals[0]), "Object Property"))
                        else:
                            prop_vals = self.get_child_node(prop[0], "owl:ObjectProperty")
                            class_vals = self.get_child_node(some_vals[0], "owl:Class")
                            subclass_pairs.append((el.parentNode, class_vals[0], self.extract_ID(prop_vals[0]), "Object Property"))
                    except:
                        try:
                            if not self.extract_ID(prop[0]) and self.extract_ID(some_vals[0]):
                                prop_vals = self.get_child_node(prop[0], "owl:DatatypeProperty")
                                subclass_pairs.append((el.parentNode, some_vals[0], self.extract_ID(prop_vals[0]), "Datatype Property"))
                            elif not self.extract_ID(prop[0]) and not self.extract_ID(some_vals[0]):
                                prop_vals = self.get_child_node(prop[0], "owl:DatatypeProperty")
                                class_vals = self.get_child_node(some_vals[0], "owl:Class")
                                subclass_pairs.append((el.parentNode, class_vals[0], self.extract_ID(prop_vals[0]), "Datatype Property"))
                        except Exception as e:
                            print (e)
                            continue
                else:
                    if self.extract_ID(level1_class[0]):
                        subclass_pairs.append((level1_class[0], el.parentNode, "subclass_of", "Subclass"))
                    else:
#                         level2classes = level1_class[0].getElementsByTagName("owl:Class")
#                         subclass_pairs.extend([(elem, el.parentNode, "subclass_of", "Subclass") for elem in level2classes if self.extract_ID(elem)])
                        continue
        return subclass_pairs
        
    def get_subclasses(self):
        subclasses = [(self.extract_ID(a), self.extract_ID(b), c, d) for (a,b,c,d) in self.subclasses]
        return [el for el in subclasses if el[0] and el[1] and el[2] and el[0]!="Thing" and el[1]!="Thing"]
    
    def filter_null(self, data):
        return [el for el in data if el]
    
    def extract_ID(self, element, check_coded = True):
        element_id = element.getAttribute("rdf:ID") or element.getAttribute("rdf:resource") or element.getAttribute("rdf:about")
        element_id = element_id.split("#")[-1]
        if len(list(filter(str.isdigit, element_id))) >= 3 and "_" in element_id and check_coded:
            return self.mapping_dict[element_id]
        return element_id.replace("UNDEFINED_", "").replace("DO_", "")
    
    def parse_classes(self):
        class_elems = [self.extract_ID(el) for el in self.root.getElementsByTagName("owl:Class")]
        subclass_classes = list(set(flatten([el[:-2] for el in self.triples])))
        return list(set(self.filter_null(class_elems + subclass_classes)))
    
    def get_classes(self):
        return self.classes
    
    def get_entities(self):
        entities = [self.extract_ID(el) for el in self.root.getElementsByTagName("owl:Class")]
        return list(set(self.filter_null(entities)))

    def parse_data_properties(self):
        data_properties = [el for el in self.get_child_node(self.root, 'owl:DatatypeProperty')]
        fn_data_properties = [el for el in self.get_child_node(self.root, 'owl:FunctionalProperty') if el]
        fn_data_properties = [el for el in fn_data_properties if type(el)==minidom.Element and 
            [el for el in self.get_child_node(el, "rdf:type") if 
             self.has_attribute_value(el, "rdf:resource", "DatatypeProperty")]]
        inv_fn_data_properties = [el for el in self.get_child_node(self.root, 'owl:InverseFunctionalProperty') if el]
        inv_fn_data_properties = [el for el in inv_fn_data_properties if type(el)==minidom.Element and 
            [el for el in self.get_child_node(el, "rdf:type") if 
             self.has_attribute_value(el, "rdf:resource", "DatatypeProperty")]]
        return data_properties + fn_data_properties + inv_fn_data_properties
        
    def parse_object_properties(self):
        obj_properties = [el for el in self.get_child_node(self.root, 'owl:ObjectProperty')]
        fn_obj_properties = [el for el in self.get_child_node(self.root, 'owl:FunctionalProperty') if el]
        fn_obj_properties = [el for el in fn_obj_properties if type(el)==minidom.Element and 
            [el for el in self.get_child_node(el, "rdf:type") if 
             self.has_attribute_value(el, "rdf:resource", "ObjectProperty")]]
        inv_fn_obj_properties = [el for el in self.get_child_node(self.root, 'owl:InverseFunctionalProperty') if el]
        inv_fn_obj_properties = [el for el in inv_fn_obj_properties if type(el)==minidom.Element and 
            [el for el in self.get_child_node(el, "rdf:type") if 
             self.has_attribute_value(el, "rdf:resource", "ObjectProperty")]]
        return obj_properties + fn_obj_properties + inv_fn_obj_properties
    
    def get_object_properties(self):
        obj_props = [self.extract_ID(el) for el in self.object_properties]
        return list(set(self.filter_null(obj_props)))
    
    def get_data_properties(self):
        data_props = [self.extract_ID(el) for el in self.data_properties]
        return list(set(self.filter_null(data_props)))

# %%
USE_folder = "/home/vlead/USE"
alignment_folder = "reference-alignment/"

# Load reference alignments 
def load_alignments(folder):
    alignments = []
    for f in os.listdir(folder):
        doc = minidom.parse(folder + f)
        ls = list(zip(doc.getElementsByTagName('entity1'), doc.getElementsByTagName('entity2'), doc.getElementsByTagName('measure')))
        alignments.extend([(a.getAttribute('rdf:resource'), b.getAttribute('rdf:resource')) for (a,b,c) in ls])
    return alignments

# Extracting USE embeddings

def extractUSEEmbeddings(words):
    model = hub.load("https://tfhub.dev/google/universal-sentence-encoder-large/5?tf-hub-format=compressed")
    embeds = model(words)
    return embeds.numpy()

def cos_sim(a,b):
    return 1 - spatial.distance.cosine(a, b)


reference_alignments = load_alignments(alignment_folder)

# ra_anatomy_coded = load_alignments("../Anatomy/Alignments/")
# ra_anatomy = []
# ont1 = Ontology("../Anatomy/Ontologies/mouse.owl")
# ont2 = Ontology("../Anatomy/Ontologies/human.owl")
# for elem in ra_anatomy_coded:
#     pre1, pre2 = elem[0].split("#")[0].split(".")[0].split("/")[-1], elem[1].split("#")[0].split(".")[0].split("/")[-1]
#     elem1, elem2 = elem[0].split("#")[-1], elem[1].split("#")[-1]
#     ra_anatomy.append(( pre1 + "#" + ont1.mapping_dict[elem1], pre2 + "#" + ont2.mapping_dict[elem2]))

gt_mappings = [tuple([elem.split("/")[-1] for elem in el]) for el in reference_alignments]
# gt_mappings.extend(ra_anatomy)


ontologies_in_alignment = pickle.load(open("../data_generic.pkl", "rb"))[-1][:-1]
# ontologies_in_alignment += [["../Anatomy/Ontologies/human.owl", "../Anatomy/Ontologies/mouse.owl"]]

# %%
# Combinatorial mapping generation
all_mappings = []
props = []
for l in ontologies_in_alignment:
    ont1 = Ontology("conference_ontologies/" + l[0] + ".owl")
    ont2 = Ontology("conference_ontologies/" + l[1] + ".owl")
    
    ent1 = ont1.get_entities()
    ent2 = ont2.get_entities()
    
    obj1 = ont1.get_object_properties()
    obj2 = ont2.get_object_properties()
    
    data1 = ont1.get_data_properties()
    data2 = ont2.get_data_properties()

    mappings = list(itertools.product(ent1, ent2)) + list(itertools.product(obj1, obj2)) + list(itertools.product(data1, data2))
    prop = list(itertools.product(obj1, obj2)) + list(itertools.product(data1, data2))

    all_mappings.extend([(l[0].split(".")[0].split("/")[-1] + "#" + el[0], l[1].split(".")[0].split("/")[-1] + "#" + el[1]) for el in mappings])
    props.extend([(l[0].split(".")[0].split("/")[-1] + "#" + el[0], l[1].split(".")[0].split("/")[-1] + "#" + el[1]) for el in prop])

data = {mapping: False for mapping in all_mappings}
for mapping in set(gt_mappings):
    data[tuple(mapping[:2])] = True
# Out:
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range

# %%
sorted(Counter([float(el[-1]) for el in gt_mappings]).items())
# Out:
# [(0.6, 4),
#  (0.6075, 3),
#  (0.6123, 1),
#  (0.6194, 1),
#  (0.6248, 1),
#  (0.627, 1),
#  (0.6362, 1),
#  (0.6534, 1),
#  (0.6579, 1),
#  (0.66, 7),
#  (0.6621, 1),
#  (0.6656, 4),
#  (0.6674, 1),
#  (0.6857, 1),
#  (0.6939, 2),
#  (0.7128, 1),
#  (0.7316, 1),
#  (0.7351, 7),
#  (0.7361, 1),
#  (0.7367, 3),
#  (0.7635, 1),
#  (0.7679, 1),
#  (0.7753, 1),
#  (0.78, 1),
#  (0.7841, 1),
#  (0.7875, 1),
#  (0.8036, 4),
#  (0.8168, 1),
#  (0.8338, 1),
#  (0.846, 2),
#  (0.8571, 1),
#  (0.8821, 1),
#  (0.9603, 12),
#  (0.9619, 2),
#  (0.9653, 1),
#  (0.9801, 65),
#  (0.9802, 2),
#  (0.9804, 1),
#  (0.9807, 1),
#  (0.9809, 1),
#  (0.9812, 2),
#  (0.9813, 1),
#  (0.9823, 1),
#  (0.9824, 1),
#  (0.9827, 1),
#  (0.9828, 1),
#  (0.9835, 1),
#  (0.9836, 3),
#  (0.9847, 1),
#  (0.9848, 2),
#  (0.9855, 1),
#  (0.9856, 1),
#  (0.9857, 6),
#  (0.9863, 1),
#  (0.9865, 1),
#  (0.9869, 2),
#  (0.9874, 1),
#  (0.9878, 1),
#  (0.988, 1),
#  (0.9884, 1),
#  (0.9886, 1),
#  (0.9888, 1),
#  (0.989, 2),
#  (0.9894, 1),
#  (0.9897, 2),
#  (0.9898, 2),
#  (0.9899, 2),
#  (0.99, 47),
#  (1.0, 7)]

# %%
# Abbrevation resolution preprocessing

abbreviations_dict = {}
final_dict = {}

for mapping in all_mappings:
    mapping = tuple([el.split("#")[1] for el in mapping])
    is_abb = re.search("[A-Z][A-Z]+", mapping[0])
    if is_abb:
        abbreviation = "".join([el[0].upper() for el in mapping[1].split("_")])
        if is_abb.group() in abbreviation:
            
            start = abbreviation.find(is_abb.group())
            end = start + len(is_abb.group())
            fullform = "_".join(mapping[1].split("_")[start:end])
            print ("left", mapping, abbreviation, fullform)
            
            rest_first = " ".join([el for el in mapping[0].replace(is_abb.group(), "").split("_") if el]).lower()
            rest_second = " ".join(mapping[1].split("_")[:start] + mapping[1].split("_")[end:])
            if is_abb.group() not in final_dict:
                final_dict[is_abb.group()] = [(fullform, rest_first, rest_second)]
            else:
                final_dict[is_abb.group()].append((fullform, rest_first, rest_second))

    is_abb = re.search("[A-Z][A-Z]+", mapping[1])
    if is_abb:
        abbreviation = "".join([el[0].upper() for el in mapping[0].split("_")])
        
        if is_abb.group() in abbreviation:
            start = abbreviation.find(is_abb.group())
            end = start + len(is_abb.group())
            fullform = "_".join(mapping[0].split("_")[start:end])
            print ("right", mapping, abbreviation, fullform)

            rest_first = " ".join([el for el in mapping[1].replace(is_abb.group(), "").split("_") if el]).lower()
            rest_second = " ".join(mapping[0].split("_")[:start] + mapping[0].split("_")[end:])
            if is_abb.group() not in final_dict:
                final_dict[is_abb.group()] = [(fullform, rest_first, rest_second)]
            else:
                final_dict[is_abb.group()].append((fullform, rest_first, rest_second))

keys = [el for el in list(set(flatten([flatten([tup[1:] for tup in final_dict[key]]) for key in final_dict]))) if el]
abb_embeds = dict(zip(keys, extractUSEEmbeddings(keys)))

scored_dict = {}
for abbr in final_dict:
    sim_list = [(tup[0], tup[1], tup[2], cos_sim(abb_embeds[tup[1]], abb_embeds[tup[2]])) if tup[1] and tup[2]
                else (tup[0], tup[1], tup[2], 0) for tup in final_dict[abbr]]
    scored_dict[abbr] = sorted(list(set(sim_list)), key=lambda x:x[-1], reverse=True)

resolved_dict = {key: scored_dict[key][0] for key in scored_dict}
filtered_dict = {key: " ".join(resolved_dict[key][0].split("_")) for key in resolved_dict if resolved_dict[key][-1] > 0.9}
# Out:
# left ('Member_PC', 'Program_Committee') PC Program_Committee
# left ('Member_PC', 'Program_Committee_member') PCM Program_Committee
# left ('Member_PC', 'Program_Chair') PC Program_Chair
# left ('Chair_PC', 'Program_Committee') PC Program_Committee
# left ('Chair_PC', 'Program_Committee_member') PCM Program_Committee
# left ('Chair_PC', 'Program_Chair') PC Program_Chair
# left ('Member_PC', 'Presenter_city') PC Presenter_city
# left ('Chair_PC', 'Presenter_city') PC Presenter_city
# left ('PC_Member', 'Program_Committee') PC Program_Committee
# left ('PC_Member', 'Program_Committee_member') PCM Program_Committee
# left ('PC_Member', 'Program_Chair') PC Program_Chair
# left ('PC_Chair', 'Program_Committee') PC Program_Committee
# left ('PC_Chair', 'Program_Committee_member') PCM Program_Committee
# left ('PC_Chair', 'Program_Chair') PC Program_Chair
# left ('OC_Member', 'Organizing_Committee') OC Organizing_Committee
# left ('OC_Member', 'Organizing_Committee_member') OCM Organizing_Committee
# left ('OC_Chair', 'Organizing_Committee') OC Organizing_Committee
# left ('OC_Chair', 'Organizing_Committee_member') OCM Organizing_Committee
# right ('Program_committee', 'Member_PC') PC Program_committee
# right ('Program_committee', 'Chair_PC') PC Program_committee
# right ('Passive_conference_participant', 'Member_PC') PCP Passive_conference
# right ('Passive_conference_participant', 'Chair_PC') PCP Passive_conference
# left ('SC_Member', 'Sponsor_city') SC Sponsor_city
# left ('SC_Member', 'Sponsor_company_house') SCH Sponsor_company
# left ('SC_Member', 'Session_chair') SC Session_chair
# left ('SC_Member', 'Brief_introduction_for_Session_chair') BIFSC Session_chair
# left ('PC_Member', 'Presenter_city') PC Presenter_city
# left ('PC_Chair', 'Presenter_city') PC Presenter_city
# left ('OC_Member', 'One_conference_day') OCD One_conference
# left ('OC_Chair', 'One_conference_day') OCD One_conference
# left ('Member_PC', 'PC_Chair') PC PC_Chair
# left ('Chair_PC', 'PC_Chair') PC PC_Chair
# right ('Program_committee', 'PC_Member') PC Program_committee
# right ('Program_committee', 'PC_Chair') PC Program_committee
# right ('Passive_conference_participant', 'PC_Member') PCP Passive_conference
# right ('Passive_conference_participant', 'PC_Chair') PCP Passive_conference
# right ('Submitted_contribution', 'SC_Member') SC Submitted_contribution
# right ('Organizing_committee', 'OC_Member') OC Organizing_committee
# right ('Organizing_committee', 'OC_Chair') OC Organizing_committee
# right ('Steering_committee', 'SC_Member') SC Steering_committee
# left ('paperID', 'is_dated_on') IDO is_dated

# %%
filtered_dict = {}
def camel_case_split(identifier):
    matches = re.finditer('.+?(?:(?<=[a-z])(?=[A-Z])|(?<=[A-Z])(?=[A-Z][a-z])|$)', identifier)
    return [m.group(0) for m in matches]

def parse(word):
    return flatten([el.split("_") for el in camel_case_split(word)])
    

extracted_elems = []

for ont_name in list(set(flatten(ontologies_in_alignment))):
    ont = Ontology("conference_ontologies/" + ont_name + ".owl")
    entities = ont.get_entities()
    props = ont.get_object_properties() + ont.get_data_properties()
    triples = list(set(flatten([(a,b,c) for (a,b,c,d) in ont.get_triples()])))
    extracted_elems.extend([ont_name + "#" + elem for elem in entities + props + triples])

extracted_elems = list(set(extracted_elems))
inp = [" ".join(parse(word.split("#")[1])) for word in extracted_elems]

# Resolving abbreviations to full forms
inp_resolved = []
for concept in inp:
    for key in filtered_dict:
        concept = concept.replace(key, filtered_dict[key])
    final_list = []
    # Lowering case except in abbreviations
    for word in concept.split(" "):
        if not re.search("[A-Z][A-Z]+", word):
            final_list.append(word.lower())
        else:
            final_list.append(word)
    concept = " ".join(final_list)
    inp_resolved.append(concept)


url = "https://montanaflynn-spellcheck.p.rapidapi.com/check/"

headers = {
    'x-rapidapi-host': "montanaflynn-spellcheck.p.rapidapi.com",
    'x-rapidapi-key': "9965b01207msh06291e57d6f2c55p1a6a16jsn0fb016da4a62"
    }

inp_spellchecked = []
for concept in inp_resolved:
    querystring = {"text": concept}
    response = requests.request("GET", url, headers=headers, params=querystring)
    
    if response.json()["suggestion"] != concept:
        resolved = str(concept)
        final_list = []
        for word in concept.split(" "):
            if not re.search("[A-Z][A-Z]+", concept):
                final_list.append(word.lower())
            else:
                final_list.append(word)
        resolved = " ".join(final_list)
#         print (resolved, "suggestion", response)
        for word in response["corrections"]:
            if not re.search("[A-Z][A-Z]+", concept):
                resolved = resolved.replace(word.lower(), response.json()["corrections"][word][0].lower())
                
        
        print (concept, resolved)
        inp_spellchecked.append(resolved)
    else:
        inp_spellchecked.append(concept)

print ("Total number of extracted unique classes and properties from entire RA set: ", len(extracted_elems))

extracted_elems = ["<UNK>"] + extracted_elems

# stopwords = ["has", "is", "a", "an", "the"]
stopwords = ["has"]
inp_stemmed = []
for elem in inp_spellchecked:
    words = " ".join([word for word in elem.split() if word not in stopwords])
    words = words.replace("-", " ")
    inp_stemmed.append(words)


embeds = np.array([np.zeros(512,)] + list(extractUSEEmbeddings(inp_stemmed)))
# embeds = np.array([np.zeros(512,)] + list(extractUSEEmbeddings(inp_spellchecked)))
embeddings = dict(zip(extracted_elems, embeds))


emb_vals = list(embeddings.values())
emb_indexer = {key: i for i, key in enumerate(list(embeddings.keys()))}
emb_indexer_inv = {i: key for i, key in enumerate(list(embeddings.keys()))}
# Out:
# list index out of range
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-31-9a3fb261bb44> in <module>
#      48     response = requests.request("GET", url, headers=headers, params=querystring)
#      49
# ---> 50     if response.json()["suggestion"] != concept:
#      51         resolved = str(concept)
#      52         final_list = []
#
# ~/anaconda3/lib/python3.7/site-packages/requests/models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# ~/anaconda3/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~/anaconda3/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/anaconda3/lib/python3.7/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
# import random
random.seed(0)
a = [1,2,3,4]
for i in range(6):

    random.shuffle(a)
    print (a)
# Out:
# [3, 1, 2, 4]
# [3, 1, 4, 2]
# [3, 4, 1, 2]
# [4, 3, 2, 1]
# [2, 4, 1, 3]
# [3, 4, 1, 2]

# %%
from spellchecker import SpellChecker

spell = SpellChecker()

inp_spellchecked = []
for concept in inp_resolved:
    resolved = str(concept)
    final_list = []
    words = concept.split(" ")
    for word in words:
        if "-" in word:
            parts = word.split("-")
            temp = []
            for part in parts:
                part_corrected = spell.correction(part)
                if part!=part_corrected:
                    print ("-: {} corrected to {}".format(part, part_corrected), parts)
                    temp.append(part_corrected)
                else:
                    temp.append(part)
            word = "-".join(temp)
            final_list.append(word)
        else:
            word_corrected = spell.correction(word)
            if word!=word_corrected and not re.search("[A-Z][A-Z]+", concept):
                print ("{} corrected to {}".format(word, word_corrected), concept)
                final_list.append(word_corrected)
            else:
                final_list.append(word)
    resolved = " ".join(final_list)
    inp_spellchecked.append(resolved)
# Out:
# powerline corrected to powering powerline transmission topic
# sponzorship corrected to sponsorship sponzorship
# commitee corrected to committee technical commitee
# nonauthor corrected to co-author nonauthor registration fee
# www corrected to wow conference www
# registation corrected to registration registation deadline
# registeered corrected to registered registeered applicant
# commtitee corrected to committee has a commtitee
# accpet corrected to accept accpet if room rating
# sponzor corrected to sponsor sponzor fee
# writen corrected to written is writen by
# attendee corrected to attended attendee
# aapplications corrected to applications computer networks aapplications topic
# presentationed corrected to presentation presentationed by
# holded corrected to holder holded by
# attendee corrected to attended author attendee book registration fee
# attendee corrected to attended author attendee cd registration fee
# committe corrected to committee was a committe co-chair of
# organizator corrected to organization organizator
# attendee corrected to attended has attendee
# nonmember corrected to non-member nonmember registration fee
# reviewes corrected to reviewed reviewes
# memeber corrected to member memeber registration fee
# coctail corrected to cocktail coctail reception
# manuscipt corrected to manuscript initial manuscipt
# viza corrected to via viza
# -: 1th corrected to th ['1th', 'author']
# sponzor corrected to sponsor sponzor
# topis corrected to topic is a topis of conference parts
# webmaster corrected to webster webmaster
# 1th corrected to th is the 1th part of
# attendee corrected to attended attendee at
# proceening corrected to proceeding cd proceening

# %%
import requests, urllib



url = "https://grammarbot.p.rapidapi.com/check"

headers = {
    'x-rapidapi-host': "grammarbot.p.rapidapi.com",
    'x-rapidapi-key': "9965b01207msh06291e57d6f2c55p1a6a16jsn0fb016da4a62",
    'content-type': "application/x-www-form-urlencoded"
    }

inp_spellchecked = []

for concept in inp_resolved:
    payload = "language=en-US&text=" + urllib.parse.quote_plus(concept)
    response = requests.request("POST", url, data=payload, headers=headers).json()
    concept_corrected = str(concept)
    for elem in response["matches"]:
        start, end = elem["offset"], elem["offset"] + elem["length"]
        concept_corrected = concept_corrected[:start] + elem["replacements"][0]["value"] + concept_corrected[end:]
    if concept.lower() != concept_corrected.lower():
        print ("{} corrected to {}".format(concept, concept_corrected))
        inp_spellchecked.append(concept_corrected)
    else:
        inp_spellchecked.append(concept)
# Out:
# payed by corrected to paid by
# sponzorship corrected to sponsorship
# technical commitee corrected to Technical committee
# best student paper award corrected to the best student paper award
# nonauthor registration fee corrected to non author registration fee
# registation deadline corrected to registration deadline
# technic activity corrected to ethnic activity
# organises corrected to organisms
# registeered applicant corrected to registered applicant
# has programme corrected to Has programmed
# has a commtitee corrected to Has a committee
# accpet if room rating corrected to accept if room rating
# operating topicsystems corrected to Operating topic systems
# sponzor fee corrected to sponsor fee
# ACM SIGKDD corrected to ACM Signed
# is writen by corrected to Is written by
# scientifically organises corrected to Scientifically organisms
# computer networks aapplications topic corrected to Computer networks applications topic
# non academic event corrected to non-academic event
# presentationed by corrected to presentation ed by
# IASTED non member corrected to Lasted non-member
# holded by corrected to held by
# best student paper supporter corrected to the best student paper supporter
# was a committe co-chair of corrected to Was a committed co-chair of
# registration SIGKDD member corrected to Registration Signed member
# technically organises corrected to Technically organisms
# has amount of corrected to Has amounted of
# programme brochure corrected to programmed brochure
# IASTED member corrected to Lasted member
# organizator corrected to organization
# web site corrected to website
# programme corrected to programmed
# OC member corrected to Of member
# reviewes corrected to reviews
# memeber registration fee corrected to member registration fee
# organising agency corrected to organizing agency
# coctail reception corrected to cocktail reception
# organisation corrected to organization
# initial manuscipt corrected to Initial manuscript
# viza corrected to via
# best applications paper award corrected to the best applications paper award
# contribution 1th-author corrected to Contribution 1st-author
# sponzor corrected to sponsor
# is a topis of conference parts corrected to Is a topics of conference parts
# scientifically organised by corrected to Scientifically organized by
# technically organised by corrected to Technically organized by
# is the 1th part of corrected to Is the 1st part of
# organised by corrected to organized by
# cd proceening corrected to CD proceeding
# OC chair corrected to Of chair

# %%
_, _, emb_indexer, emb_indexer_inv, emb_vals, gt_mappings, features_dict, ontologies_in_alignment = pickle.load(open("Input/data_conf_oaei_aml_bagofnbrs.pkl", "rb"))
# data_items = data.items()
# np.random.shuffle(list(data_items))
# data = OrderedDict(data_items)
pickle.dump([data, emb_indexer, emb_indexer_inv, emb_vals, gt_mappings, features_dict, ontologies_in_alignment], open("Input/data_conf_bagofnbrs.pkl", "wb"))

# %%
# Load reference alignments 
def load_alignments(folder):
    alignments = []
    for f in os.listdir(folder):
#         print (folder + f)
        doc = minidom.parse(folder + f)
        ls = list(zip(doc.getElementsByTagName('entity1'), doc.getElementsByTagName('entity2'), doc.getElementsByTagName('measure')))
        src = doc.getElementsByTagName('Ontology')[0].getAttribute("rdf:about").split("/")[-1].split(".")[0] + ".owl"
        targ = doc.getElementsByTagName('Ontology')[1].getAttribute("rdf:about").split("/")[-1].split(".")[0] + ".owl"
        print (src, targ)
        alignments.extend([(a.getAttribute('rdf:resource'), b.getAttribute('rdf:resource'), c.firstChild.nodeValue) for (a,b,c) in ls])
    return alignments

load_alignments("../VeeAlign/datasets/web-directory/alignments/")
# Out:
# google web
# dmoz google
# google yahoo
# web yahoo
# dmoz yahoo
# dmoz web
# [('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Fotografie',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Freizeit-Hobby_Fotografie',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Freizeit-Hobby',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Basteln',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Freizeit-Hobby_Basteln-Handarbeit_Basteln-allgemein',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Basteln_Kerzen',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Freizeit-Hobby_Basteln-Handarbeit_Kerzen',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Basteln_Window-Color',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Freizeit-Hobby_Basteln-Handarbeit_Window-Color',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Drogen_Hanf',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Headshops-Hanfprodukte',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Handarbeiten',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Freizeit-Hobby_Basteln-Handarbeit_Handarbeit-allgemein',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Handarbeiten_Naehen',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Freizeit-Hobby_Basteln-Handarbeit_Naehen',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Handarbeiten_Sticken',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Freizeit-Hobby_Basteln-Handarbeit_Sticken',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Handarbeiten_Stricken-und-Haekeln',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Freizeit-Hobby_Basteln-Handarbeit_Stricken',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Modellbau',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Freizeit-Hobby_Modellbau',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Modellbau_Eisenbahnen',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Freizeit-Hobby_Sammeln_Eisenbahnartikel',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Modellbau_Fahrzeuge',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Freizeit-Hobby_Sammeln_Modellfahrzeuge',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Natur-und-Wissenschaft_Astronomie',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Freizeit-Hobby_Astronomie',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Outdoor-und-Camping',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Sportartikel_Camping-Outdoor',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Outdoor-und-Camping_Jagd',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Sportartikel_Jagd-Schiesssport',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Partys',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Freizeit-Hobby_Feste-feiern_Festdekoration',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Partys_Ballons',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Blumen-Geschenke_Ballons',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Partys_Feuerwerk',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Freizeit-Hobby_Feste-feiern_Sylvester',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Waffen',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Sportartikel_Jagd-Schiesssport',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Waffen_Bogen-und-Armbrust',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Sportartikel_Bogenschiessen',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Geschenke',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Blumen-Geschenke_Geschenke-allgemein',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Geschenke_Geschenkgutscheine',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Blumen-Geschenke_Geschenkgutscheine',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Geschenke_Praesentkoerbe',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Blumen-Geschenke_Geschenkkoerbe',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Geschenke_Scherzartikel',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Blumen-Geschenke_Scherzartikel',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Geschenke_Scherzartikel',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Freizeit-Hobby_Feste-feiern_Halloween',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Gesundheit_Ernaehrung_Nahrungsergaenzung',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Gesundheit-Kosmetik_Nahrungsergaenzungsmittel',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Gesundheit_Krankheiten-und-Beschwerden_Diabetes',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Gesundheit-Kosmetik_Medizinische-Produkte_Diabetikerbedarf',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Gesundheit_Sehen',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Gesundheit-Kosmetik_Optik',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Gesundheit_Sehen_Kontaktlinsen',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Gesundheit-Kosmetik_Optik_Kontaktlinsen',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Gesundheit_Zahnmedizin',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Gesundheit-Kosmetik_Medizinische-Produkte_Zahnpflege',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Haus-und-Garten',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Haus-Garten',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Haus-und-Garten_Dekorationsartikel',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Haus-Garten_Einrichten_Dekorationsgegenstaende',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Haus-und-Garten_Dekorationsartikel_Kerzen',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Blumen-Geschenke_Kerzen',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Haus-und-Garten_Dekorationsartikel_Uhren',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Haus-Garten_Einrichten_Uhren',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Haus-und-Garten_Haushaltsbedarf_Haushaltsgeraete',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Haus-Garten_Elektrogeraete',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Haus-und-Garten_Haushaltsbedarf_Messer-und-Bestecke',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Haus-Garten_Haushaltswaren_Bestecke',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Haus-und-Garten_Haustechnik_Sicherheit',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Haus-Garten_Selbstschutz-Sicherheitstechnik',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Haus-und-Garten_Moebel',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Haus-Garten_Moebel',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Haus-und-Garten_Moebel_Kuechen',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Haus-Garten_Kueche',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Haus-und-Garten_Moebel_Lampen-und-Leuchten',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Haus-Garten_Einrichten_Leuchten',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Haus-und-Garten_Packmaterial',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Haus-Garten_Umzugsbedarf',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Blumen',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Blumen-Geschenke_Blumen',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Haustiere_Aquaristik',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Haus-Garten_Haustierbedarf_Aquaristik',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Haustiere_Futter',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Haus-Garten_Haustierbedarf_Futter',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Haustiere_Hunde-und-Katzen_Hunde',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Haus-Garten_Haustierbedarf_Hund-Katze',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Haustiere_Hunde-und-Katzen_Katzen',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Haus-Garten_Haustierbedarf_Hund-Katze',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Haustiere_Terraristik',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Haus-Garten_Haustierbedarf_Terraristik',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Haustiere_Voegel',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Haus-Garten_Haustierbedarf_Voegel',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Hochzeit',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Freizeit-Hobby_Feste-feiern_Hochzeit',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Kinder',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Kinder-Babybedarf',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Kleinanzeigen-und-Flohmaerkte',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Kleinanzeigen',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Kleinanzeigen-und-Flohmaerkte_Kinder',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Kleinanzeigen_Kindersachen',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Kleinanzeigen-und-Flohmaerkte_Schweiz',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Kleinanzeigen_Anzeigenmaerkte_Schweiz',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Kunst_Galerien',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Haus-Garten_Kunstgegenstaende_Galerien',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Kunst_Material-und-Zubehoer',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Freizeit-Hobby_Basteln-Handarbeit_Kuenstlerbedarf',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Kunst_Reproduktionen',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Haus-Garten_Kunstgegenstaende_Reproduktionen',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Kunsthandwerk',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Blumen-Geschenke_Kunsthandwerk',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Kunsthandwerk_Keramik',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Freizeit-Hobby_Basteln-Handarbeit_Keramik',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Musik',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Buecher_Musik-Filme_Musik',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Musik_Fanartikel',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Freizeit-Hobby_Fanartikel_Musik',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Musik_Instrumente',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Freizeit-Hobby_Musizieren_Instrumente',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Musik_Noten',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Freizeit-Hobby_Musizieren_Noten-Musikbuecher',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Naturprodukte',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Gesundheit-Kosmetik_Naturprodukte-allgemein',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Publikationen_Buecher_Allgemeines-Sortiment',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Buecher_Musik-Filme_Buchshops_Allgemein',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Publikationen_Buecher_Antiquariate',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Buecher_Musik-Filme_Buchshops_Antiquariate',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Publikationen_Buecher_Computer',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Buecher_Musik-Filme_Buchshops_Fachbuecher_Computer',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Publikationen_Buecher_Essen-und-Trinken',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Buecher_Musik-Filme_Buchshops_Fachbuecher_Kochen',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Publikationen_Buecher_Gesundheit',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Buecher_Musik-Filme_Buchshops_Fachbuecher_Gesundheit',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Publikationen_Buecher_Kinder',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Buecher_Musik-Filme_Buchshops_Kinder-Jugendbuecher',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Publikationen_Buecher_Kunst',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Buecher_Musik-Filme_Buchshops_Fachbuecher_Kunst',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Publikationen_Buecher_Natur-und-Tiere',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Buecher_Musik-Filme_Buchshops_Fachbuecher_Tiere',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Publikationen_Buecher_Recht',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Buecher_Musik-Filme_Buchshops_Fachbuecher_Recht',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Publikationen_Buecher_Religion-und-Spiritualitaet',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Buecher_Musik-Filme_Buchshops_Fachbuecher_Religion',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Publikationen_Buecher_Religion-und-Spiritualitaet_Esoterik',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Buecher_Musik-Filme_Buchshops_Fachbuecher_Esoterik',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Publikationen_Buecher_Schueler-und-Lernhilfen',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Buecher_Musik-Filme_Buchshops_Fachbuecher_Lernen',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Publikationen_Buecher_Wirtschaft',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Buecher_Musik-Filme_Buchshops_Fachbuecher_Wirtschaft',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Publikationen_Buecher_Wissenschaft',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Buecher_Musik-Filme_Buchshops_Fachbuecher_Wissenschaft',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Publikationen_Comics',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Buecher_Musik-Filme_Buchshops_Comics',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Publikationen_Kalender',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Buecher_Musik-Filme_Buchshops_Kalendershops',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Reisen_Gepaeck',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Mode-Accessoires_Koffer-Taschen',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Religion-und-Spiritualitaet_Esoterik',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Gesundheit-Kosmetik_Esoterik',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Sammelbare-Objekte_Autogramme',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Freizeit-Hobby_Sammeln_Autogramme',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Sammelbare-Objekte_Briefmarken',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Freizeit-Hobby_Sammeln_Briefmarken',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Sammelbare-Objekte_Fanartikel',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Freizeit-Hobby_Fanartikel',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Sammelbare-Objekte_Historische-Wertpapiere',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Freizeit-Hobby_Sammeln_Historische-Wertpapiere',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Sammelbare-Objekte_Muenzen',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Freizeit-Hobby_Sammeln_Muenzen',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Schmuck',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Mode-Accessoires_Schmuck',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Schmuck_Uhren',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Mode-Accessoires_Schmuck_Armbanduhren',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Schoenheit_Duefte',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Gesundheit-Kosmetik_Kosmetik_Parfum',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Schoenheit_Haare_Pflege',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Gesundheit-Kosmetik_Kosmetik_Haarpflege',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Schoenheit_Hautpflege_Naturprodukte',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Gesundheit-Kosmetik_Kosmetik_Naturkosmetik',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Schoenheit_Kosmetik',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Gesundheit-Kosmetik_Kosmetik_Kosmetik-allgemein',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Schreibwaren-und-Buerobedarf',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Buero-Schreibwaren',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Schreibwaren-und-Buerobedarf_Materialien-und-Zubehoer_Papierwaren',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Buero-Schreibwaren_Papeterie-Schreibwaren',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Schreibwaren-und-Buerobedarf_Materialien-und-Zubehoer_Stempel',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Buero-Schreibwaren_Stempel',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Schreibwaren-und-Buerobedarf_Moebel',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Buero-Schreibwaren_Bueromoebel',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Schreibwaren-und-Buerobedarf_Werbeartikel',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Blumen-Geschenke_Werbeartikel',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Spielwaren',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Spiele-Spielzeug',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Spielwaren_Holz',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Spiele-Spielzeug_Holzspielzeug',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Spielwaren_Puppen',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Freizeit-Hobby_Sammeln_Puppen-Spielzeug',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Spielwaren_Spiele_Brettspiele_Schach',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Sportartikel_Schach',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Sport_Allgemeines-Sortiment',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Sportartikel_Sportartikel-allgemein',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Sport_Angeln',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Sportartikel_Angeln',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Sport_Auszeichnungen',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Sportartikel_Vereinsbedarf',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Sport_Badminton',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Sportartikel_Badminton',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Sport_Ballsport_Fussball',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Sportartikel_Fussball',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Sport_Ballsport_Fussball_Fanartikel',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Sportartikel_Fussball_Fan-Artikel',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Sport_Billard-und-Dart',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Sportartikel_Billard',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Sport_Billard-und-Dart',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Sportartikel_Darts',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Sport_Drachensport',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Sportartikel_Luftsport_Lenkdrachen',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Sport_Fanartikel',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Freizeit-Hobby_Fanartikel_Sport',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Sport_Fitness',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Sportartikel_Fitness',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Sport_Flugsport',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Sportartikel_Luftsport_Flug-Pilotenbedarf',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Sport_Golf',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Sportartikel_Golf',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Sport_Kampfsport',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Sportartikel_Kampfsport',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Sport_Kegel-und-Kugelsport',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Sportartikel_Kegeln',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Sport_Laufsport',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Sportartikel_Laufsport',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Sport_Motorsport_Kart',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Auto-Motorradzubehoer_Kartzubehoer',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Sport_Paintball',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Sportartikel_Paintball',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Sport_Pferdesport',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Sportartikel_Reitsport',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Sport_Schiesssport',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Sportartikel_Jagd-Schiesssport',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Sport_Sporternaehrung',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Sportartikel_Sporternaehrung',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Sport_Sporternaehrung_Nahrungsergaenzung',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Gesundheit-Kosmetik_Nahrungsergaenzungsmittel',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Sport_Tennis',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Sportartikel_Tennis',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Sport_Tischtennis',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Sportartikel_Tischtennis',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Sport_Turnen-und-Gymnastik',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Sportartikel_Turnen',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Sport_Wassersport',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Sportartikel_Wassersport',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Sport_Wassersport_Tauchen',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Sportartikel_Tauchen',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Sport_Wintersport',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Sportartikel_Wintersport',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Tabak',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Tabakwaren',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Tabak_Feuerzeuge',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Blumen-Geschenke_Feuerzeuge',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Unterhaltung',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Unterhaltungselektronik',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Unterhaltung_Bild-und-Tontraeger_Musik',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Buecher_Musik-Filme_Musik',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Unterhaltung_Bild-und-Tontraeger_Musik_Genres_Klassik',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Buecher_Musik-Filme_Musik_CDs_Klassik',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Unterhaltung_Bild-und-Tontraeger_Musik_Vinyl',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Buecher_Musik-Filme_Musik_LPs',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Unterhaltung_Bild-und-Tontraeger_Video',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Buecher_Musik-Filme_Filme_Videos',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Unterhaltung_Bild-und-Tontraeger_Video_DVD',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Buecher_Musik-Filme_Filme_DVDs',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Unterhaltung_Film-und-Fernsehen_Poster-und-Plakate',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Freizeit-Hobby_Fanartikel_Poster-Plakate',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Werkzeug',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Haus-Garten_Werkzeuge',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Werkzeug_Messer',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Freizeit-Hobby_Sammeln_Messer',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Antiquitaeten',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Haus-Garten_Einrichten_Antikes-Troedel',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Bekleidung',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Mode-Accessoires_Kleidung',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Bekleidung_Accessoires',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Mode-Accessoires_Accessoires',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Bekleidung_Accessoires_Taschen',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Mode-Accessoires_Koffer-Taschen',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Bekleidung_Berufsbekleidung',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Mode-Accessoires_Kleidung_Berufs-Sicherheitsbekleidung',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Bekleidung_Damen',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Mode-Accessoires_Kleidung_Frauen',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Bekleidung_Herren',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Mode-Accessoires_Kleidung_Maenner',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Bekleidung_Jeans',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Mode-Accessoires_Kleidung_Jeans',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Bekleidung_Kinder',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Mode-Accessoires_Kleidung_Kinder',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Bekleidung_Kostueme_Karneval-Fasching',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Freizeit-Hobby_Feste-feiern_Karneval',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Bekleidung_Kundenspezifisch_Textildruck_T-Shirts',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Mode-Accessoires_Kleidung_T-Shirts',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Bekleidung_Leder',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Mode-Accessoires_Kleidung_Lederwaren',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Bekleidung_Naturtextilien_Wolle',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Mode-Accessoires_Kleidung_Wollwaren',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Bekleidung_Nischenprodukte_Tanz',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Sportartikel_Tanzsport',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Bekleidung_Schuhe',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Mode-Accessoires_Kleidung_Schuhe',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Bekleidung_Schuhe_Sport',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Sportartikel_Sportschuhe',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Bekleidung_Sondergroessen',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Mode-Accessoires_Kleidung_Uebergroessen',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Bekleidung_Sport_Badesport',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Mode-Accessoires_Kleidung_Bademoden',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Bekleidung_T-Shirts',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Mode-Accessoires_Kleidung_T-Shirts',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Bekleidung_Unterwaesche',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Mode-Accessoires_Kleidung_Unterwaesche',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Bildung',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Buecher_Musik-Filme_Buchshops_Fachbuecher_Lernen',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Computer',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Computer',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Computer_Hardware',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Computer_Hardware',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Computer_Hardware_Komplettsysteme',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Computer_Komplettsysteme',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Computer_Hardware_Komplettsysteme_Handhelds',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Computer_Palmtops',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Computer_Hardware_Komplettsysteme_Notebooks',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Computer_Notebooks',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Computer_Hardware_Peripherie_Drucker',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Computer_Zubehoer_Drucker',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Computer_Software',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Computer_Software',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Computer_Spiele',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Computer_Software_Spiele',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Computer_Zubehoer',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Computer_Zubehoer',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Elektronik',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Elektronik-allgemein',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Elektronik_Multimedia_Heimkino',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Unterhaltungselektronik_Heimkino',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Elektronik_Satellitentechnik',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Unterhaltungselektronik_Satelliten-Digital-TV',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Elektronik_Sicherheit',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Haus-Garten_Selbstschutz-Sicherheitstechnik',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Elektronik_Telekommunikation',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Telekommunikation',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Elektronik_Telekommunikation_Handys',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Telekommunikation_Mobilfunk',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Elektronik_Telekommunikation_Handys_Zubehoer',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Telekommunikation_Mobilfunk_Zubehoer',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Essen-und-Trinken_Backwaren',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Back-Suesswaren',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Essen-und-Trinken_Fisch-und-Meeresfruechte',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Fisch',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Essen-und-Trinken_Fleisch-und-Wurst',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Fleisch-Wurst',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Bier',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Bier',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Kaffee-und-Tee',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Tee-Kaffee',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Spirituosen',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Spirituosen',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Wein',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Wein_Biowein',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Oekologischer-Weinbau',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Wein_Europaeisch_Deutsch_Baden',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Deutschland_Baden',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Wein_Europaeisch_Deutsch_Franken',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Deutschland_Franken',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Wein_Europaeisch_Deutsch_Mosel-Saar-Ruwer',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Deutschland_Mosel',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Wein_Europaeisch_Deutsch_Mosel-Saar-Ruwer',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Deutschland_Saar',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Wein_Europaeisch_Deutsch_Nahe',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Deutschland_Nahe',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Wein_Europaeisch_Deutsch_Pfalz',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Deutschland_Pfalz',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Wein_Europaeisch_Deutsch_Rheingau',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Deutschland_Rheingau',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Wein_Europaeisch_Deutsch_Rheinhessen',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Deutschland_Rheinhessen',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Wein_Europaeisch_Franzoesisch',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Frankreich',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Wein_Europaeisch_Italienisch',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Italien',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Wein_Europaeisch_Oesterreichisch',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Oesterreich',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Wein_Europaeisch_Schweizer',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Schweiz',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Wein_Europaeisch_Spanisch',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Spanien',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Wein_Geschenke',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Weinpraesente',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Essen-und-Trinken_Gewuerze-und-Kraeuter',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Kraeuter-Gewuerze',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Essen-und-Trinken_Kaese',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Kaese-Milchprodukte',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Essen-und-Trinken_Regionale-Spezialitaeten',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Spezialitaeten',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Essen-und-Trinken_Suesswaren',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Back-Suesswaren',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Essen-und-Trinken_Tiefkuehlkost',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Tiefkuehlkost',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Essen-und-Trinken_Vegetarisch',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Naturkost',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Fahrzeuge_Autos_Ersatzteile-und-Zubehoer',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Auto-Motorradzubehoer_Autozubehoer',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Fahrzeuge_Autos_Kleinanzeigen',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Kleinanzeigen_Auto',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Fahrzeuge_Motorraeder_Kleinanzeigen',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Kleinanzeigen_Motorrad',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Fahrzeuge_Motorraeder_Teile-und-Zubehoer',
#   'http://localhost:80/web.owl#Verzeichnis_Einkaufen-Sparen_Auto-Motorradzubehoer_Motorradzubehoer',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch',
#   'http://localhost:80/google.owl#World_Deutsch',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Fest_und_Feiertage',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Fest-und-Feiertage',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Fest_und_Feiertage_Weihnachten',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Fest-und-Feiertage_Weihnachten',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Fotografie',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Fotografie',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Fotografie_Dienstleistungen',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Fotografie_Dienstleistungen',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Fotografie_Dienstleistungen_Digital',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Fotografie_Dienstleistungen_Digital',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Freizeit',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Freizeit_Artistik',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Artistik',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Freizeit_Basteln',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Basteln',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Freizeit_Basteln_Kerzen',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Basteln_Kerzen',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Freizeit_Basteln_Malen',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Basteln_Malen',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Freizeit_Basteln_Papier',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Basteln_Papier',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Freizeit_Basteln_Perlen',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Basteln_Perlen',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Freizeit_Basteln_Serviettentechnik',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Basteln_Serviettentechnik',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Freizeit_Basteln_Stempeltechnik',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Basteln_Stempeltechnik',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Freizeit_Basteln_Window_Color',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Basteln_Window-Color',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Freizeit_Drogen',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Drogen',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Freizeit_Drogen_Hanf',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Drogen_Hanf',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Freizeit_Handarbeiten',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Handarbeiten',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Freizeit_Handarbeiten_Maschinen_und_Zubehoer',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Handarbeiten_Maschinen-und-Zubehoer',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Freizeit_Handarbeiten_Naehen',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Handarbeiten_Naehen',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Freizeit_Handarbeiten_Naehen_Patchworken_und_Quilten',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Handarbeiten_Naehen_Patchworken-und-Quilten',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Freizeit_Handarbeiten_Sticken',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Handarbeiten_Sticken',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Freizeit_Handarbeiten_Stricken_und_Haekeln',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Handarbeiten_Stricken-und-Haekeln',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Freizeit_Lebendige_Geschichte',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Lebendige-Geschichte',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Freizeit_Lebendige_Geschichte_LARP',
# ...
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Fahrzeuge_Autos_Ersatzteile-und-Zubehoer_Marderabwehr',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_Ersatzteile_und_Zubehoer_Pflegemittel',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Fahrzeuge_Autos_Ersatzteile-und-Zubehoer_Pflegemittel',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_Ersatzteile_und_Zubehoer_Raeder_und_Reifen',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Fahrzeuge_Autos_Ersatzteile-und-Zubehoer_Raeder-und-Reifen',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_Ersatzteile_und_Zubehoer_Schmierstoffe',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Fahrzeuge_Autos_Ersatzteile-und-Zubehoer_Schmierstoffe',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_Ersatzteile_und_Zubehoer_Traegersysteme',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Fahrzeuge_Autos_Ersatzteile-und-Zubehoer_Traegersysteme',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_Ersatzteile_und_Zubehoer_Tuning',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Fahrzeuge_Autos_Ersatzteile-und-Zubehoer_Tuning',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_Jahreswagen',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Fahrzeuge_Autos_Jahreswagen',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_Kleinanzeigen',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Fahrzeuge_Autos_Kleinanzeigen',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_Verzeichnisse_und_Portale',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Fahrzeuge_Autos_Verzeichnisse-und-Portale',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Fahrzeuge_Fahrraeder',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Fahrzeuge_Fahrraeder',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Fahrzeuge_Fahrraeder_Anhaenger',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Fahrzeuge_Fahrraeder_Anhaenger',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Fahrzeuge_Fahrraeder_Mountainbikes',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Fahrzeuge_Fahrraeder_Mountainbikes',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Fahrzeuge_Fahrraeder_Zubehoer',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Fahrzeuge_Fahrraeder_Zubehoer',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Fahrzeuge_Motorraeder',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Fahrzeuge_Motorraeder',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Fahrzeuge_Motorraeder_Kleinanzeigen',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Fahrzeuge_Motorraeder_Kleinanzeigen',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Fahrzeuge_Motorraeder_Motorroller',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Fahrzeuge_Motorraeder_Motorroller',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Fahrzeuge_Motorraeder_Pflegemittel',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Fahrzeuge_Motorraeder_Pflegemittel',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Fahrzeuge_Motorraeder_Quads',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Fahrzeuge_Motorraeder_Quads',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Fahrzeuge_Motorraeder_Teile_und_Zubehoer',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Fahrzeuge_Motorraeder_Teile-und-Zubehoer',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Fahrzeuge_Motorraeder_Trikes',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Fahrzeuge_Motorraeder_Trikes',
#   '1.0'),
#  ('http://localhost:80/dmoz.owl#Top_World_Deutsch_Online-Shops_Fahrzeuge_Motorraeder_Bekleidung',
#   'http://localhost:80/google.owl#World_Deutsch_Online-Shops_Fahrzeuge_Motorraeder_Bekleidung',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Fest-und-Feiertage_Weihnachten',
#   'http://localhost:80/yahoo.small.owl#Firmen_Haus-und-Garten_Weihnachten',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Artistik',
#   'http://localhost:80/yahoo.small.owl#Firmen_Unterhaltung_Jonglieren',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Basteln_Malen',
#   'http://localhost:80/yahoo.small.owl#Firmen_Kunst-und-Kunsthandwerk_Malerei-und-Bildhauerei',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Basteln_Stempeltechnik',
#   'http://localhost:80/yahoo.small.owl#Firmen_Kunst-und-Kunsthandwerk_Bedarf-und-Zubehoer_Stempel',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Basteln_Window-Color',
#   'http://localhost:80/yahoo.small.owl#Firmen_Kunst-und-Kunsthandwerk_Bedarf-und-Zubehoer_Window-Color',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Drogen',
#   'http://localhost:80/yahoo.small.owl#Firmen_Tabakwaren_Wasserpfeifen',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Drogen_Hanf',
#   'http://localhost:80/yahoo.small.owl#Firmen_Bekleidung_Stoffe-und-Textilien_Hanf',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Drogen_Hanf',
#   'http://localhost:80/yahoo.small.owl#Firmen_Gesundheit_Alternativmedizin_Produkte_Ethnobotanische-Produkte_Hanf',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Handarbeiten',
#   'http://localhost:80/yahoo.small.owl#Firmen_Kunst-und-Kunsthandwerk_Kunsthandwerk_Handarbeiten',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Handarbeiten_Naehen',
#   'http://localhost:80/yahoo.small.owl#Firmen_Kunst-und-Kunsthandwerk_Kunsthandwerk_Naehen',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Handarbeiten_Naehen_Patchworken-und-Quilten',
#   'http://localhost:80/yahoo.small.owl#Firmen_Kunst-und-Kunsthandwerk_Kunsthandwerk_Patchwork',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Handarbeiten_Sticken',
#   'http://localhost:80/yahoo.small.owl#Firmen_Kunst-und-Kunsthandwerk_Kunsthandwerk_Handarbeiten_Stickmuster-und-Zubehoer',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Handarbeiten_Stricken-und-Haekeln',
#   'http://localhost:80/yahoo.small.owl#Firmen_Kunst-und-Kunsthandwerk_Kunsthandwerk_Stricken-und-Haekeln',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Lebendige-Geschichte',
#   'http://localhost:80/yahoo.small.owl#Firmen_Spiele-und-Spielzeug_Rollenspiele',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Modellbau',
#   'http://localhost:80/yahoo.small.owl#Firmen_Spiele-und-Spielzeug_Modellbau',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Modellbau_Eisenbahnen',
#   'http://localhost:80/yahoo.small.owl#Firmen_Spiele-und-Spielzeug_Modellbau_Eisenbahn',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Modellbau_Fahrzeuge_Autos',
#   'http://localhost:80/yahoo.small.owl#Firmen_Spiele-und-Spielzeug_Modellbau_Autos',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Modellbau_Flugzeuge-und-Helikopter_Flugzeuge',
#   'http://localhost:80/yahoo.small.owl#Firmen_Spiele-und-Spielzeug_Modellbau_Flugzeuge',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Modellbau_Schiffe',
#   'http://localhost:80/yahoo.small.owl#Firmen_Spiele-und-Spielzeug_Modellbau_Schiffe',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Modellbau_Zubehoer',
#   'http://localhost:80/yahoo.small.owl#Firmen_Spiele-und-Spielzeug_Modellbau_Werkzeug-und-Zubehoer',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Outdoor-und-Camping',
#   'http://localhost:80/yahoo.small.owl#Firmen_Outdoors',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Outdoor-und-Camping_Bekleidung',
#   'http://localhost:80/yahoo.small.owl#Firmen_Outdoors_Bekleidung-und-Ausruestung',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Outdoor-und-Camping_Jagd',
#   'http://localhost:80/yahoo.small.owl#Firmen_Outdoors_Jagen',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Outdoor-und-Camping_Zelte',
#   'http://localhost:80/yahoo.small.owl#Firmen_Outdoors_Camping',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Partys',
#   'http://localhost:80/yahoo.small.owl#Firmen_Unterhaltung_Partys-und-Veranstaltungen',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Waffen',
#   'http://localhost:80/yahoo.small.owl#Firmen_Waffen',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Waffen_Bogen-und-Armbrust',
#   'http://localhost:80/yahoo.small.owl#Firmen_Sport_Bogenschiessen',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Waffen_Schusswaffen',
#   'http://localhost:80/yahoo.small.owl#Firmen_Waffen_Schusswaffen',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Waffen_Schusswaffen_Luft-und-Gasdruck',
#   'http://localhost:80/yahoo.small.owl#Firmen_Waffen_Schusswaffen_Softair-Waffen',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Waffen_Schusswaffen_Zubehoer',
#   'http://localhost:80/yahoo.small.owl#Firmen_Waffen_Schusswaffen_Zubehoer',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Freizeit_Zaubern',
#   'http://localhost:80/yahoo.small.owl#Firmen_Unterhaltung_Zauberei',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Geschenke_Personalisiert_Literatur',
#   'http://localhost:80/yahoo.small.owl#Firmen_Buecher_Buchhandel_Kinderbuecher_Personalisierte-Kinderbuecher',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Geschenke_Scherzartikel',
#   'http://localhost:80/yahoo.small.owl#Firmen_Unterhaltung_Partys-und-Veranstaltungen_Scherzartikel-und-Partygags',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Gesundheit',
#   'http://localhost:80/yahoo.small.owl#Firmen_Gesundheit',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Gesundheit_Alternative-Medizin',
#   'http://localhost:80/yahoo.small.owl#Firmen_Gesundheit_Alternativmedizin',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Gesundheit_Alternative-Medizin_Ayurveda',
#   'http://localhost:80/yahoo.small.owl#Firmen_Gesundheit_Alternativmedizin_Ayurveda',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Gesundheit_Alternative-Medizin_Bluetentherapie',
#   'http://localhost:80/yahoo.small.owl#Firmen_Gesundheit_Alternativmedizin_Bluetentherapie',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Gesundheit_Alternative-Medizin_Bluetentherapie_Bachblueten',
#   'http://localhost:80/yahoo.small.owl#Firmen_Gesundheit_Alternativmedizin_Bluetentherapie_Produkte',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Gesundheit_Alternative-Medizin_Homoeopathie',
#   'http://localhost:80/yahoo.small.owl#Firmen_Gesundheit_Alternativmedizin_Homoeopathie',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Gesundheit_Alternative-Medizin_Magnetfeldtherapie',
#   'http://localhost:80/yahoo.small.owl#Firmen_Gesundheit_Alternativmedizin_Magnetfeldtherapie',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Gesundheit_Alternative-Medizin_Reiki',
#   'http://localhost:80/yahoo.small.owl#Firmen_Gesundheit_Alternativmedizin_Reiki',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Gesundheit_Alternative-Medizin_TCM-und-Akupunkturbedarf',
#   'http://localhost:80/yahoo.small.owl#Firmen_Gesundheit_Alternativmedizin_Akupunktur',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Gesundheit_Behandlungen-und-Pflege',
#   'http://localhost:80/yahoo.small.owl#Firmen_Gesundheit_Behandlungen-und-Untersuchungen',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Gesundheit_Behandlungen-und-Pflege_Massage',
#   'http://localhost:80/yahoo.small.owl#Firmen_Gesundheit_Behandlungen-und-Untersuchungen_Massage',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Gesundheit_Ernaehrung',
#   'http://localhost:80/yahoo.small.owl#Firmen_Gesundheit_Ernaehrung',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Gesundheit_Ernaehrung_Diaet',
#   'http://localhost:80/yahoo.small.owl#Firmen_Gesundheit_Ernaehrung_Spezialernaehrung',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Gesundheit_Ernaehrung_Diaet',
#   'http://localhost:80/yahoo.small.owl#Firmen_Gesundheit_Abnehmen_Diaeten-und-Kurse',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Gesundheit_Ernaehrung_Nahrungsergaenzung',
#   'http://localhost:80/yahoo.small.owl#Firmen_Gesundheit_Ernaehrung_Nahrungsergaenzungsmittel',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Gesundheit_Hoeren',
#   'http://localhost:80/yahoo.small.owl#Firmen_Gesundheit_Hoerakustik',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Gesundheit_Krankheiten-und-Beschwerden',
#   'http://localhost:80/yahoo.small.owl#Firmen_Gesundheit_Krankheiten-und-Beschwerden',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Gesundheit_Krankheiten-und-Beschwerden_Allergien',
#   'http://localhost:80/yahoo.small.owl#Firmen_Gesundheit_Krankheiten-und-Beschwerden_Allergien',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Gesundheit_Krankheiten-und-Beschwerden_Diabetes',
#   'http://localhost:80/yahoo.small.owl#Firmen_Gesundheit_Krankheiten-und-Beschwerden_Diabetes',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Gesundheit_Sehen',
#   'http://localhost:80/yahoo.small.owl#Firmen_Gesundheit_Augenoptik',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Gesundheit_Sehen_Kontaktlinsen',
#   'http://localhost:80/yahoo.small.owl#Firmen_Gesundheit_Augenoptik_Kontaktlinsen',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Gesundheit_Zahnmedizin',
#   'http://localhost:80/yahoo.small.owl#Firmen_Gesundheit_Zahnmedizin',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Haus-und-Garten',
#   'http://localhost:80/yahoo.small.owl#Firmen_Haus-und-Garten',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Haus-und-Garten_Aussenanlagen_Gartenhaeuser',
#   'http://localhost:80/yahoo.small.owl#Firmen_Haus-und-Garten_Garten-und-Pflanzen_Gartenhaeuser-und-Gewaechshaeuser',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Haus-und-Garten_Aussenanlagen_Gewaechshaeuser',
#   'http://localhost:80/yahoo.small.owl#Firmen_Haus-und-Garten_Garten-und-Pflanzen_Gartenhaeuser-und-Gewaechshaeuser',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Haus-und-Garten_Aussenanlagen_Zaeune-und-Tore',
#   'http://localhost:80/yahoo.small.owl#Firmen_Haus-und-Garten_Garten-und-Pflanzen_Gartenzaeune-und-Gartentore',
#   '1.0'),
#  ('http://localhost:80/google.owl#World_Deutsch_Online-Shops_Haus-und-Garten_Dekorationsartikel_Kerzen',
#   'http://localhost:80/yahoo.small.owl#Firmen_Haus-und-Garten_Haushaltswaren_Kerzen',
#   '1.0'),
#  ...]

# %%
def path_to_root(elem, ont_mappings, curr = [], rootpath=[]):
    curr.append(elem)
    if elem not in ont_mappings or not ont_mappings[elem]:
        rootpath.append(curr)
        return
    for node in ont_mappings[elem]:
        curr_orig = deepcopy(curr)
        _ = path_to_root(node, ont_mappings, curr, rootpath)
        curr = curr_orig
    return rootpath

def get_one_hop_neighbours(ont, K=1):
    ont_obj = Ontology("conference_ontologies/" + ont + ".owl")
    triples = ont_obj.get_triples()
    entities = [(a,b) for (a,b,c,d) in triples]
    neighbours_dict = {elem: [[] for i in range(4)] for elem in list(set(flatten(entities)))}
    print (ont)
    for (e1, e2, p, d) in triples:
        if e1==e2:
            continue
        if d == "Object Property":
            neighbours_dict[e1][2].append([p + " -> " + e2])
            neighbours_dict[e2][2].append([p + " -> " + e1])
        elif d == "Datatype Property":
            neighbours_dict[e1][3].append([p + " -> " + e2])
            neighbours_dict[e2][3].append([p + " -> " + e1])
        elif d == "Subclass":
            neighbours_dict[e2][1].append([e1])
        else:
            print ("Error wrong value of d: ", d)
    
    rootpath_dict = ont_obj.parents_dict
    rootpath_dict_new = {}
    for elem in rootpath_dict:
        rootpath_dict_new[elem] = path_to_root(elem, rootpath_dict, [], [])
    ont = ont.split("/")[-1].split(".")[0]

    
    for entity in neighbours_dict:
        if entity in rootpath_dict_new and len(rootpath_dict_new[entity]) > 0:
            neighbours_dict[entity][0].extend(rootpath_dict_new[entity])
        else:
            continue
    
#     prop_triples = ont_obj.get_triples(subclass_of=False)
#     neighbours_dict_props = {c: [c] for a,b,c in prop_triples}
#     for e1, e2, p in prop_triples:
#         neighbours_dict_props[p].extend([e1, e2])

    #neighbours_dict = {**neighbours_dict, **neighbours_dict_props}
    
    # for elem in ont_obj.get_entities() + ont_obj.get_object_properties() + ont_obj.get_data_properties():
    #     if elem not in neighbours_dict:
    #         neighbours_dict[elem] = [elem]

#     neighbours_dict = {elem: [key[:1] + sorted(list(set(key[1:]))) for key in neighbours_dict[elem]]
#                        for elem in neighbours_dict}
#     neighbours_dict = {el: neighbours_dict[el][:23] for el in neighbours_dict if len( neighbours_dict[el]) > 2}
#     ont = ont.split("/")[-1].split(".")[0]
    neighbours_dict = {ont + "#" + el: [[tuple([ont + "#" + node for node in path]) for path in nbr_type]
                                        for nbr_type in neighbours_dict[el]] 
                       for el in neighbours_dict}
    neighbours_dict = {el: [[list(path) for path in nbr_type] for nbr_type in neighbours_dict[el]]
                       for el in neighbours_dict}
    return neighbours_dict

# neighbours_dicts = {ont.split("/")[-1].split(".")[0]: get_one_hop_neighbours(ont) for ont in list(set(flatten(ontologies_in_alignment)))}
neighbours_dicts = {}
for ont in list(set(flatten(ontologies_in_alignment))):
    neighbours_dicts = {**neighbours_dicts, **get_one_hop_neighbours(ont)}
# max_paths = np.max([[len(nbr_type) for nbr_type in elem] for elem in neighbours_dicts.values()])
# max_pathlen = np.max(flatten([flatten([[len(path) for path in nbr_type] for nbr_type in elem]) for elem in neighbours_dicts.values()]), axis=0)
# neighbours_dicts_lenpadded = {elem: [[path + ["<UNK>" for i in range(max_pathlen -len(path))] for path in nbr_type]
#                                 for nbr_type in neighbours_dicts[elem]] for elem in neighbours_dicts}
# neighbours_dicts_pathpadded = {elem: [nbr_type + [["<UNK>" for j in range(max_pathlen)] for i in range(max_paths - len(nbr_type))]
#                                 for k,nbr_type in enumerate(neighbours_dicts_lenpadded[elem])] for elem in neighbours_dicts_lenpadded}
# neighbours_dicts_pathpadded = {elem: np.array(neighbours_dicts_pathpadded[elem]) for elem in neighbours_dicts_pathpadded}
# # ontologies_in_alignment_rev = [[el.split("/")[1].split(".")[0] for el in ont] for ont in ontologies_in_alignment]
# f = open("data_aml_uniqpath.pkl", "wb")
# pickle.dump([data, aml_data, emb_indexer, emb_indexer_inv, emb_vals, gt_mappings, neighbours_dicts_pathpadded, ontologies_in_alignment], f)
# # # # neighbours_dicts
# Out:
# sigkdd
# edas
# list index out of range
# confOf
# conference
# cmt
# iasted
# ekaw

# %%
from orderedset import OrderedSet
def get_context_inf(pair):
    final_results = []
    for elem in pair:
        if elem not in neighbours_dicts:
            return []
        context = neighbours_dicts[elem]
        ancestors = [" -> ".join([elem for elem in path]) for path in context[0]]
        children = list(flatten(context[1])) #shorten later
        oprop_neighbours = [el for el in flatten(context[2])]
        dprop_neighbours = [el for el in flatten(context[3])]
        final_results.append([elem, ancestors, children, oprop_neighbours, dprop_neighbours])
    children_a, children_b = final_results[0][2], final_results[1][2]
    all_children_pairs = [(elem_pair[0], elem_pair[1], cos_sim(*[emb_vals[emb_indexer[elem]] for elem in elem_pair])) 
     for elem_pair in list(itertools.product(children_a, children_b))]
    all_children_pairs = [elem[:2] for elem in sorted(all_children_pairs, key = lambda el: el[-1], reverse=True)][:6]
    all_children_pairs = [tuple([elem for elem in elem_pair]) for elem_pair in all_children_pairs]
    try:
        children_a, children_b = [list(OrderedSet(elem)) if elem else [] for elem in list(zip(*all_children_pairs))]
    except Exception as e:
#         print (e)
        children_a, children_b = [], []
    final_results[0][2] = children_a
    final_results[1][2] = children_b
    
    children_a, children_b = final_results[0][3], final_results[1][3]
    all_children_pairs = [(elem_pair[0], elem_pair[1], cos_sim(*[emb_vals[emb_indexer[elem.split(" -> ")[-1]]] for elem in elem_pair])) 
     for elem_pair in list(itertools.product(children_a, children_b))]
    all_children_pairs = [elem[:2] for elem in sorted(all_children_pairs, key = lambda el: el[-1], reverse=True)][:6]
    all_children_pairs = [tuple([elem for elem in elem_pair]) for elem_pair in all_children_pairs]
    try:
        children_a, children_b = [list(OrderedSet(elem)) if elem else [] for elem in list(zip(*all_children_pairs))]
    except Exception as e:
#         print (e)
        children_a, children_b = [], []
    final_results[0][3] = children_a
    final_results[1][3] = children_b
    return final_results

def group_cos_sim(a, b):
    return np.mean([cos_sim(emb_vals[emb_indexer[pair[0]]], emb_vals[emb_indexer[pair[1]]]) for pair in itertools.product(a,b)])

def sort_by_sim(unsorted_list):
    w_e = 1
    w_r = 0.7
    w_o, w_d = 0.5, 0.2
    w_c = 0.25
    sorted_list = []
    for elem_pair in unsorted_list:
        score = 0
        score += w_e * cos_sim(emb_vals[emb_indexer[elem_pair[0][0]]], emb_vals[emb_indexer[elem_pair[1][0]]])
        ancestors_score = [group_cos_sim(path_pair[0].split(" -> "), path_pair[1].split(" -> ")) for path_pair in itertools.product(elem_pair[0][1], elem_pair[1][1])]
        if ancestors_score:
            score += w_r * max(ancestors_score)
        children_score = sorted([cos_sim(emb_vals[emb_indexer[pair[0]]], emb_vals[emb_indexer[pair[1]]]) for pair in itertools.product(elem_pair[0][2], elem_pair[1][2])])[:3]
        if children_score:
            score += w_c * np.mean(children_score)
        obj_score = [cos_sim(emb_vals[emb_indexer[pair[0].split(" -> ")[1]]], emb_vals[emb_indexer[pair[1].split(" -> ")[1]]]) for pair in itertools.product(elem_pair[0][3], elem_pair[1][3])]
        if obj_score:
            score += w_o * max(obj_score)
        data_score = [cos_sim(emb_vals[emb_indexer[pair[0].split(" -> ")[1]]], emb_vals[emb_indexer[pair[1].split(" -> ")[1]]]) for pair in itertools.product(elem_pair[0][4], elem_pair[1][4])]
        if data_score:
            score += w_d * max(data_score)
        sorted_list.append([elem_pair[0], elem_pair[1], score])
    return sorted(sorted_list, key = lambda el:el[-1], reverse=True)
unsorted_entities = [elem for elem in [get_context_inf(el[:2]) for el in all_mappings] if elem]
sorted_entities = sort_by_sim(unsorted_entities)

# %%
# open ("aml_false_negatives.tsv").write("\n".join)
def stringify(elem_pair):
    final_list = []
    for elem in elem_pair[:2]:        
        curr = []
        for obj in elem:
            if isinstance(obj, str):
                curr.append(obj)
            elif obj == []:
                curr.append(" ")
            elif isinstance(obj, list):
                curr.append(", ".join(obj))
        final_list.extend(curr)
    final_list.append(str(round(elem_pair[-1], 3)))
    return "\t".join(final_list)

false_negatives = [stringify(elem_pair) for elem_pair in sorted_entities if tuple([el[0] for el in elem_pair[:2]]) not in aml_mappings]

# %%
[i for i,elem in enumerate(false_negatives) if (elem.split("\t")[0], elem.split("\t")[5]) in gt_mappings]
# Out:
# [18,
#  44,
#  49,
#  54,
#  57,
#  63,
#  67,
#  94,
#  106,
#  107,
#  136,
#  150,
#  188,
#  196,
#  208,
#  224,
#  228,
#  244,
#  245,
#  247,
#  264,
#  314,
#  330,
#  332,
#  338,
#  367,
#  381,
#  382,
#  388,
#  392,
#  440,
#  448,
#  459,
#  470,
#  481,
#  490,
#  492,
#  552,
#  596,
#  604,
#  677,
#  688,
#  698,
#  702,
#  703,
#  756,
#  775,
#  790,
#  815,
#  853,
#  925,
#  938,
#  1089,
#  1120,
#  1388,
#  1479,
#  1781,
#  1851,
#  1981,
#  1993,
#  2013,
#  2148,
#  2322,
#  2888,
#  3166,
#  4626,
#  4627,
#  5364,
#  6297,
#  8151,
#  11253,
#  18435,
#  29693,
#  53291,
#  61541]

# %%
open("false_negatives.tsv","w+").write("\n".join(false_negatives[:10000]))
# Out:
# 3163687

# %%
false_negatives
# Out:
# ['edas#ActivePaper\tedas#ActivePaper -> edas#Paper -> edas#Document\tedas#RatedPapers\tedas#hasRating -> edas#ReviewRating\t \tekaw#Paper\tekaw#Paper -> ekaw#Document\tekaw#Submitted_Paper, ekaw#Regular_Paper, ekaw#Demo_Paper, ekaw#Poster_Paper, ekaw#Industrial_Paper, ekaw#Conference_Paper\tekaw#hasReview -> ekaw#Review, ekaw#reviewOfPaper -> ekaw#Review, ekaw#hasReviewer -> ekaw#Possible_Reviewer, ekaw#reviewerOfPaper -> ekaw#Possible_Reviewer, ekaw#coversTopic -> ekaw#Research_Topic, ekaw#topicCoveredBy -> ekaw#Research_Topic\t \t1.348',
#  'cmt#Paper\tcmt#Paper -> cmt#Document\tcmt#PaperAbstract, cmt#PaperFullVersion\tcmt#readByReviewer -> cmt#Reviewer, cmt#markConflictOfInterest -> cmt#Reviewer, cmt#readPaper -> cmt#Reviewer, cmt#assignedTo -> cmt#Reviewer, cmt#hasBeenAssigned -> cmt#Reviewer, cmt#readByMeta-Reviewer -> cmt#Meta-Reviewer\tcmt#paperID -> cmt#unsignedLong, cmt#title -> cmt#string\tedas#ActivePaper\tedas#ActivePaper -> edas#Paper -> edas#Document\tedas#RatedPapers\tedas#hasRating -> edas#ReviewRating\t \t1.248',
#  'cmt#Reviewer\tcmt#Reviewer -> cmt#ConferenceMember -> cmt#Person, cmt#Reviewer -> cmt#User -> cmt#Person\tcmt#Meta-Reviewer\tcmt#readByReviewer -> cmt#Paper, cmt#markConflictOfInterest -> cmt#Paper, cmt#readPaper -> cmt#Paper, cmt#assignedTo -> cmt#Paper, cmt#hasBeenAssigned -> cmt#Paper, cmt#adjustedBy -> cmt#Bid\t \tsigkdd#Author\tsigkdd#Author -> sigkdd#Speaker -> sigkdd#Person\tsigkdd#Author_of_paper, sigkdd#Author_of_paper_student\tsigkdd#submit -> sigkdd#Paper, sigkdd#obtain -> sigkdd#Award\t \t1.213',
#  'cmt#Paper\tcmt#Paper -> cmt#Document\tcmt#PaperAbstract, cmt#PaperFullVersion\tcmt#hasSubjectArea -> cmt#SubjectArea, cmt#hasBid -> cmt#Bid, cmt#acceptedBy -> cmt#Administrator, cmt#rejectPaper -> cmt#Administrator\tcmt#paperID -> cmt#unsignedLong, cmt#title -> cmt#string\tconfOf#Working_event\tconfOf#Working_event -> confOf#Event\tconfOf#Tutorial, confOf#Conference, confOf#Workshop\tconfOf#hasTopic -> confOf#Topic, confOf#hasAdministrativeEvent -> confOf#Administrative_event\tconfOf#has_short_title -> confOf#string, confOf#hasVAT -> confOf#string, confOf#location -> confOf#string, confOf#defaultChoice -> confOf#positiveInteger, confOf#has_title -> confOf#string, confOf#minChoice -> confOf#positiveInteger, confOf#maxChoice -> confOf#positiveInteger\t1.205',
#  'cmt#Chairman\tcmt#Chairman -> cmt#Person\t \tcmt#markConflictOfInterest -> cmt#Paper\t \tedas#ConferenceChair\tedas#ConferenceChair -> edas#Person\t \tedas#isReviewing -> edas#Paper, edas#isReviewedBy -> edas#Paper, edas#initiates -> edas#Call, edas#isInitiatedBy -> edas#Call\t \t1.195',
#  'cmt#Review\tcmt#Review -> cmt#Document\tcmt#Meta-Review\tcmt#writtenBy -> cmt#Reviewer, cmt#writeReview -> cmt#Reviewer\t \tedas#Paper\tedas#Paper -> edas#Document\tedas#PublishedPaper, edas#AcceptedPaper, edas#PendingPaper, edas#RejectedPaper, edas#ActivePaper, edas#WithdrawnPaper\tedas#isReviewing -> edas#Reviewer, edas#isReviewedBy -> edas#Reviewer, edas#isWrittenBy -> edas#Author, edas#hasRelatedPaper -> edas#Author\t \t1.192',
#  'iasted#Building\tiasted#Building -> iasted#Place\t \tiasted#occupy -> iasted#Person, iasted#is_occupied_by -> iasted#Person, iasted#is_visited_by -> iasted#Person, iasted#is_situated_in -> iasted#City, iasted#is_situated_in -> iasted#State\t \tsigkdd#Hotel\tsigkdd#Hotel -> sigkdd#Place\t \tsigkdd#can_stay_in -> sigkdd#Person\t \t1.178',
#  'cmt#Paper\tcmt#Paper -> cmt#Document\tcmt#PaperAbstract, cmt#PaperFullVersion\tcmt#submitPaper -> cmt#Author, cmt#writePaper -> cmt#Author\tcmt#paperID -> cmt#unsignedLong, cmt#title -> cmt#string\tconfOf#Contribution\t \tconfOf#Short_paper, confOf#Paper, confOf#Poster\tconfOf#writes -> confOf#Author, confOf#writtenBy -> confOf#Author\tconfOf#abstract -> confOf#string, confOf#hasTitle -> confOf#string, confOf#remark -> confOf#string, confOf#hasKeyword -> confOf#string, confOf#contactEmail -> confOf#string\t1.166',
#  'cmt#Chairman\tcmt#Chairman -> cmt#Person\t \tcmt#markConflictOfInterest -> cmt#Paper\t \tedas#SessionChair\tedas#SessionChair -> edas#Person\t \tedas#isReviewedBy -> edas#Paper, edas#isReviewing -> edas#Paper, edas#isInitiatedBy -> edas#Call, edas#initiates -> edas#Call\t \t1.163',
#  'conference#Conference_part\t \t \tconference#is_a_topis_of_conference_parts -> conference#Topic, conference#has_a_track-workshop-tutorial_topic -> conference#Topic\tconference#has_a_name -> conference#string\tedas#Conference\t \t \tedas#isTopicOf -> edas#Topic, edas#hasTopic -> edas#Topic, edas#hasRelatedDocument -> edas#Document, edas#relatesTo -> edas#Document\tedas#paperDueOn -> edas#dateTime, edas#registrationDueOn -> edas#dateTime, edas#endDate -> edas#dateTime, edas#startDate -> edas#dateTime, edas#manuscriptDueOn -> edas#dateTime, edas#hasName -> edas#string\t1.159',
#  'edas#ConferenceEvent\t \tedas#AcademicEvent, edas#NonAcademicEvent\tedas#attendeeAt -> edas#Person, edas#hasLocation -> edas#Place, edas#isLocationOf -> edas#Place\tedas#hasStartDateTime -> edas#dateTime, edas#hasEndDateTime -> edas#dateTime\tiasted#Activity\t \tiasted#Conference_activity, iasted#Activity_after_conference, iasted#Activity_before_conference\tiasted#give -> iasted#Person, iasted#is_given_by -> iasted#Person, iasted#is_designed_for -> iasted#Person, iasted#is_connected_with -> iasted#Place, iasted#is_held_in -> iasted#Place\tiasted#is_dated_on -> iasted#dateTime\t1.157',
#  'cmt#Reviewer\tcmt#Reviewer -> cmt#ConferenceMember -> cmt#Person, cmt#Reviewer -> cmt#User -> cmt#Person\tcmt#Meta-Reviewer\tcmt#readByReviewer -> cmt#Paper, cmt#markConflictOfInterest -> cmt#Paper, cmt#readPaper -> cmt#Paper\t \tekaw#Review\tekaw#Review -> ekaw#Document\tekaw#Negative_Review, ekaw#Positive_Review, ekaw#Neutral_Review\tekaw#hasReview -> ekaw#Paper, ekaw#reviewOfPaper -> ekaw#Paper\t \t1.154',
#  'cmt#Co-author\tcmt#Co-author -> cmt#Author -> cmt#ConferenceMember -> cmt#Person, cmt#Co-author -> cmt#Author -> cmt#User -> cmt#Person\t \tcmt#co-writePaper -> cmt#Paper, cmt#hasCo-author -> cmt#Paper\t \tsigkdd#Author\tsigkdd#Author -> sigkdd#Speaker -> sigkdd#Person\t \tsigkdd#submit -> sigkdd#Paper, sigkdd#obtain -> sigkdd#Award, sigkdd#notification_until -> sigkdd#Deadline_Author_notification\t \t1.146',
#  'cmt#Reviewer\tcmt#Reviewer -> cmt#ConferenceMember -> cmt#Person, cmt#Reviewer -> cmt#User -> cmt#Person\tcmt#Meta-Reviewer\tcmt#readByReviewer -> cmt#Paper, cmt#markConflictOfInterest -> cmt#Paper, cmt#readPaper -> cmt#Paper\t \tekaw#Possible_Reviewer\tekaw#Possible_Reviewer -> ekaw#Person\tekaw#PC_Member\tekaw#hasReviewer -> ekaw#Paper, ekaw#reviewerOfPaper -> ekaw#Paper\t \t1.141',
#  'conference#Presentation\tconference#Presentation -> conference#Conference_contribution -> conference#Conference_document\tconference#Invited_talk\tconference#is_the_1th_part_of -> conference#Abstract, conference#has_an_abstract -> conference#Abstract\t \tekaw#Individual_Presentation\tekaw#Individual_Presentation -> ekaw#Scientific_Event -> ekaw#Event\tekaw#Invited_Talk, ekaw#Contributed_Talk, ekaw#Tutorial\tekaw#paperPresentedAs -> ekaw#Abstract, ekaw#presentationOfPaper -> ekaw#Abstract, ekaw#presentationOfPaper -> ekaw#Paper, ekaw#paperPresentedAs -> ekaw#Paper\t \t1.131',
#  'conference#Conference_part\t \tconference#Track, conference#Tutorial, conference#Workshop\tconference#is_a_topis_of_conference_parts -> conference#Topic, conference#has_a_track-workshop-tutorial_topic -> conference#Topic\tconference#has_a_name -> conference#string\tconfOf#Contribution\t \tconfOf#Paper, confOf#Poster, confOf#Short_paper\tconfOf#dealsWith -> confOf#Topic, confOf#writes -> confOf#Author, confOf#writtenBy -> confOf#Author\tconfOf#abstract -> confOf#string, confOf#hasTitle -> confOf#string, confOf#remark -> confOf#string, confOf#hasKeyword -> confOf#string, confOf#contactEmail -> confOf#string\t1.121',
#  'cmt#Chairman\tcmt#Chairman -> cmt#Person\t \tcmt#markConflictOfInterest -> cmt#Paper\t \tsigkdd#Author\tsigkdd#Author -> sigkdd#Speaker -> sigkdd#Person\t \tsigkdd#submit -> sigkdd#Paper, sigkdd#obtain -> sigkdd#Award, sigkdd#notification_until -> sigkdd#Deadline_Author_notification\t \t1.119',
#  'edas#Paper\tedas#Paper -> edas#Document\t \tedas#isReviewing -> edas#Reviewer, edas#isReviewedBy -> edas#Reviewer, edas#isWrittenBy -> edas#Author, edas#hasRelatedPaper -> edas#Author, edas#isTopicOf -> edas#Topic, edas#hasTopic -> edas#Topic\t \tiasted#Review\tiasted#Review -> iasted#Document -> iasted#Item\t \tiasted#is_writen_by -> iasted#Reviewer\t \t1.11',
#  'cmt#Paper\tcmt#Paper -> cmt#Document\t \tcmt#readByReviewer -> cmt#Reviewer, cmt#markConflictOfInterest -> cmt#Reviewer, cmt#readPaper -> cmt#Reviewer, cmt#assignedTo -> cmt#Reviewer, cmt#hasBeenAssigned -> cmt#Reviewer, cmt#readByMeta-Reviewer -> cmt#Meta-Reviewer\tcmt#paperID -> cmt#unsignedLong, cmt#title -> cmt#string\tiasted#Review\tiasted#Review -> iasted#Document -> iasted#Item\t \tiasted#is_writen_by -> iasted#Reviewer\t \t1.11',
#  'conference#Conference_document\t \tconference#Conference_announcement, conference#Conference_contribution, conference#Information_for_participants, conference#Conference_www\tconference#has_authors -> conference#Person, conference#contributes -> conference#Person\tconference#has_a_date_of_issue -> conference#date\tedas#ConferenceEvent\t \tedas#AcademicEvent, edas#NonAcademicEvent\tedas#attendeeAt -> edas#Person, edas#hasAttendee -> edas#Person, edas#hasProgramme -> edas#Programme, edas#belongsToEvent -> edas#Programme\tedas#hasStartDateTime -> edas#dateTime, edas#hasEndDateTime -> edas#dateTime\t1.106',
#  'cmt#Paper\tcmt#Paper -> cmt#Document\tcmt#PaperAbstract, cmt#PaperFullVersion\tcmt#markConflictOfInterest -> cmt#Chairman, cmt#submitPaper -> cmt#Author, cmt#writePaper -> cmt#Author\tcmt#paperID -> cmt#unsignedLong, cmt#title -> cmt#string\tsigkdd#Registration_fee\tsigkdd#Registration_fee -> sigkdd#Fee\tsigkdd#Registration_Student, sigkdd#Registration_Non-Member, sigkdd#Registration_SIGKDD_Member, sigkdd#Registration_SIGMOD_Member\tsigkdd#payed_by -> sigkdd#Person, sigkdd#pay -> sigkdd#Person\tsigkdd#Currency -> sigkdd#string, sigkdd#Price -> sigkdd#int\t1.094',
#  'confOf#Person\t \tconfOf#Volunteer, confOf#Scholar, confOf#Assistant, confOf#Administrator, confOf#Chair_PC, confOf#Science_Worker\tconfOf#employedBy -> confOf#Organization, confOf#hasCountry -> confOf#Country\tconfOf#hasHomePage -> confOf#string, confOf#hasSurname -> confOf#string, confOf#hasEmail -> confOf#string, confOf#hasPhone -> confOf#string, confOf#hasFax -> confOf#string, confOf#hasPostalCode -> confOf#string, confOf#hasFirstName -> confOf#string, confOf#hasStreet -> confOf#string\tedas#Sponsorship\t \tedas#TravelGrant\tedas#providedBy -> edas#Organization, edas#isProviderOf -> edas#Organization\tedas#hasCostAmount -> edas#int, edas#hasCostCurrency -> edas#string\t1.092',
#  'confOf#Organization\t \t \tconfOf#hasCountry -> confOf#Country, confOf#employedBy -> confOf#Person, confOf#hasCity -> confOf#City\tconfOf#hasPostalCode -> confOf#string, confOf#hasStreet -> confOf#string\tedas#Conference\t \t \tedas#hasCountry -> edas#Country, edas#isMemberOf -> edas#Person, edas#hasMember -> edas#Person\tedas#paperDueOn -> edas#dateTime, edas#registrationDueOn -> edas#dateTime, edas#endDate -> edas#dateTime, edas#startDate -> edas#dateTime, edas#manuscriptDueOn -> edas#dateTime, edas#hasName -> edas#string\t1.09',
#  'iasted#Money\t \tiasted#Fee, iasted#Sponzorship, iasted#Tax, iasted#Tip\tiasted#pay -> iasted#Person, iasted#is_designed_for -> iasted#Person, iasted#is_paid_by -> iasted#Person\tiasted#has_amount_of -> iasted#int\tsigkdd#Registration_fee\tsigkdd#Registration_fee -> sigkdd#Fee\tsigkdd#Registration_Student, sigkdd#Registration_Non-Member, sigkdd#Registration_SIGKDD_Member\tsigkdd#payed_by -> sigkdd#Person, sigkdd#pay -> sigkdd#Person\tsigkdd#Currency -> sigkdd#string, sigkdd#Price -> sigkdd#int\t1.09',
#  'cmt#ProgramCommitteeMember\tcmt#ProgramCommitteeMember -> cmt#Person, cmt#ProgramCommitteeMember -> cmt#ConferenceMember -> cmt#Person\t \tcmt#hasProgramCommitteeMember -> cmt#ProgramCommittee, cmt#memberOfProgramCommittee -> cmt#ProgramCommittee\tcmt#maxPapers -> cmt#int\tconference#Conference_volume\tconference#Conference_volume -> conference#Conference\t \tconference#has_a_program_committee -> conference#Program_committee, conference#was_a_program_committee_of -> conference#Program_committee, conference#has_a_commtitee -> conference#Committee, conference#was_a_committee_of -> conference#Committee\tconference#has_a_location -> conference#string\t1.088',
#  'cmt#Review\tcmt#Review -> cmt#Document\tcmt#Meta-Review\tcmt#writtenBy -> cmt#Reviewer, cmt#writeReview -> cmt#Reviewer\t \tekaw#Paper\tekaw#Paper -> ekaw#Document\tekaw#Demo_Paper, ekaw#Conference_Paper, ekaw#Submitted_Paper, ekaw#Poster_Paper, ekaw#Workshop_Paper, ekaw#Industrial_Paper\tekaw#hasReview -> ekaw#Review, ekaw#reviewOfPaper -> ekaw#Review, ekaw#hasReviewer -> ekaw#Possible_Reviewer, ekaw#reviewerOfPaper -> ekaw#Possible_Reviewer\t \t1.083',
#  'cmt#Paper\tcmt#Paper -> cmt#Document\tcmt#PaperFullVersion, cmt#PaperAbstract\tcmt#markConflictOfInterest -> cmt#Chairman, cmt#acceptedBy -> cmt#Administrator, cmt#rejectPaper -> cmt#Administrator, cmt#rejectedBy -> cmt#Administrator, cmt#acceptPaper -> cmt#Administrator, cmt#readByReviewer -> cmt#Reviewer\tcmt#paperID -> cmt#unsignedLong, cmt#title -> cmt#string\tiasted#Submission\tiasted#Submission -> iasted#Document -> iasted#Item\tiasted#Final_manuscript, iasted#Initial_manuscipt\tiasted#is_writen_by -> iasted#Speaker\t \t1.078',
#  'cmt#Chairman\tcmt#Chairman -> cmt#Person\t \tcmt#markConflictOfInterest -> cmt#Paper\t \tsigkdd#Speaker\tsigkdd#Speaker -> sigkdd#Person\t \tsigkdd#presentationed_by -> sigkdd#Document, sigkdd#presentation -> sigkdd#Document\t \t1.077',
#  'iasted#Transparency\tiasted#Transparency -> iasted#Document -> iasted#Item\t \tiasted#prepare -> iasted#Author, iasted#is_prepared_by -> iasted#Speaker\t \tsigkdd#Paper\tsigkdd#Paper -> sigkdd#Document\t \tsigkdd#submit -> sigkdd#Author\t \t1.077',
#  'edas#Paper\tedas#Paper -> edas#Document\t \tedas#isWrittenBy -> edas#Author, edas#hasRelatedPaper -> edas#Author, edas#isReviewing -> edas#ConferenceChair, edas#isReviewedBy -> edas#ConferenceChair, edas#isReviewing -> edas#Reviewer, edas#isReviewedBy -> edas#Reviewer\t \tiasted#Transparency\tiasted#Transparency -> iasted#Document -> iasted#Item\t \tiasted#prepare -> iasted#Author, iasted#is_prepared_by -> iasted#Speaker\t \t1.077',
#  'cmt#Paper\tcmt#Paper -> cmt#Document\t \tcmt#submitPaper -> cmt#Author, cmt#writePaper -> cmt#Author, cmt#hasAuthor -> cmt#Author, cmt#markConflictOfInterest -> cmt#Author, cmt#co-writePaper -> cmt#Co-author, cmt#hasCo-author -> cmt#Co-author\tcmt#paperID -> cmt#unsignedLong, cmt#title -> cmt#string\tiasted#Transparency\tiasted#Transparency -> iasted#Document -> iasted#Item\t \tiasted#prepare -> iasted#Author\t \t1.077',
#  'edas#AcceptedPaper\tedas#AcceptedPaper -> edas#Paper -> edas#Document\t \tedas#relatedToPaper -> edas#PaperPresentation, edas#relatedToEvent -> edas#PaperPresentation\t \tekaw#Paper\tekaw#Paper -> ekaw#Document\t \tekaw#presentationOfPaper -> ekaw#Individual_Presentation, ekaw#paperPresentedAs -> ekaw#Individual_Presentation, ekaw#coversTopic -> ekaw#Research_Topic, ekaw#topicCoveredBy -> ekaw#Research_Topic\t \t1.075',
#  'cmt#Administrator\tcmt#Administrator -> cmt#User -> cmt#Person\t \tcmt#acceptedBy -> cmt#Paper, cmt#rejectPaper -> cmt#Paper, cmt#rejectedBy -> cmt#Paper, cmt#acceptPaper -> cmt#Paper, cmt#assignReviewer -> cmt#Reviewer, cmt#assignedByAdministrator -> cmt#Reviewer\t \tsigkdd#Author\tsigkdd#Author -> sigkdd#Speaker -> sigkdd#Person\t \tsigkdd#submit -> sigkdd#Paper, sigkdd#obtain -> sigkdd#Award\t \t1.071',
#  'edas#Conference\t \t \tedas#isMemberOf -> edas#Person, edas#hasMember -> edas#Person\tedas#paperDueOn -> edas#dateTime, edas#registrationDueOn -> edas#dateTime, edas#endDate -> edas#dateTime, edas#startDate -> edas#dateTime, edas#manuscriptDueOn -> edas#dateTime, edas#hasName -> edas#string\tiasted#Activity\t \t \tiasted#give -> iasted#Person, iasted#is_given_by -> iasted#Person, iasted#is_designed_for -> iasted#Person\tiasted#is_dated_on -> iasted#dateTime\t1.068',
#  'edas#Conference\t \t \tedas#hasRelatedDocument -> edas#Document, edas#relatesTo -> edas#Document, edas#isTopicOf -> edas#Topic, edas#hasTopic -> edas#Topic, edas#isMemberOf -> edas#Person, edas#hasMember -> edas#Person\tedas#paperDueOn -> edas#dateTime, edas#registrationDueOn -> edas#dateTime, edas#endDate -> edas#dateTime, edas#startDate -> edas#dateTime, edas#manuscriptDueOn -> edas#dateTime, edas#hasName -> edas#string\tsigkdd#Deadline\t \t \tsigkdd#submit_until -> sigkdd#Document\tsigkdd#Date -> sigkdd#dateTime\t1.064',
#  'conference#Conference_document\t \tconference#Conference_announcement, conference#Conference_www, conference#Conference_contribution\tconference#has_authors -> conference#Person, conference#contributes -> conference#Person\tconference#has_a_date_of_issue -> conference#date\tiasted#Activity\t \tiasted#Conference_activity, iasted#Activity_after_conference, iasted#Activity_before_conference\tiasted#give -> iasted#Person, iasted#is_given_by -> iasted#Person, iasted#is_designed_for -> iasted#Person\tiasted#is_dated_on -> iasted#dateTime\t1.062',
#  'edas#Paper\tedas#Paper -> edas#Document\t \tedas#isReviewing -> edas#ConferenceChair, edas#isReviewedBy -> edas#ConferenceChair, edas#isReviewedBy -> edas#SessionChair, edas#isReviewing -> edas#SessionChair, edas#isReviewedBy -> edas#TPCMember, edas#isReviewing -> edas#TPCMember\t \tekaw#Camera_Ready_Paper\tekaw#Camera_Ready_Paper -> ekaw#Paper -> ekaw#Document\t \tekaw#writtenBy -> ekaw#Conference_Participant\t \t1.062',
#  'confOf#Organization\t \tconfOf#University, confOf#Company\tconfOf#employedBy -> confOf#Person, confOf#hasCity -> confOf#City\tconfOf#hasPostalCode -> confOf#string, confOf#hasStreet -> confOf#string\tsigkdd#Registration_fee\tsigkdd#Registration_fee -> sigkdd#Fee\tsigkdd#Registration_Student, sigkdd#Registration_Non-Member, sigkdd#Registration_SIGMOD_Member, sigkdd#Registration_SIGKDD_Member\tsigkdd#payed_by -> sigkdd#Person, sigkdd#pay -> sigkdd#Person\tsigkdd#Currency -> sigkdd#string, sigkdd#Price -> sigkdd#int\t1.06',
#  'confOf#Person\t \t \tconfOf#hasCountry -> confOf#Country, confOf#hasCity -> confOf#City\tconfOf#hasHomePage -> confOf#string, confOf#hasSurname -> confOf#string, confOf#hasEmail -> confOf#string, confOf#hasPhone -> confOf#string, confOf#hasFax -> confOf#string, confOf#hasPostalCode -> confOf#string, confOf#hasFirstName -> confOf#string, confOf#hasStreet -> confOf#string\tedas#Conference\t \t \tedas#hasCountry -> edas#Country, edas#isMemberOf -> edas#Person, edas#hasMember -> edas#Person\tedas#paperDueOn -> edas#dateTime, edas#registrationDueOn -> edas#dateTime, edas#endDate -> edas#dateTime, edas#startDate -> edas#dateTime, edas#manuscriptDueOn -> edas#dateTime, edas#hasName -> edas#string\t1.06',
#  'cmt#Person\t \t \tcmt#hasConflictOfInterest -> cmt#Document\tcmt#email -> cmt#string, cmt#name -> cmt#string\tedas#Conference\t \t \tedas#hasRelatedDocument -> edas#Document, edas#relatesTo -> edas#Document, edas#isTopicOf -> edas#Topic, edas#hasTopic -> edas#Topic, edas#isMemberOf -> edas#Person, edas#hasMember -> edas#Person\tedas#paperDueOn -> edas#dateTime, edas#registrationDueOn -> edas#dateTime, edas#endDate -> edas#dateTime, edas#startDate -> edas#dateTime, edas#manuscriptDueOn -> edas#dateTime, edas#hasName -> edas#string\t1.06',
#  'confOf#Contribution\t \t \tconfOf#dealsWith -> confOf#Topic\tconfOf#abstract -> confOf#string, confOf#hasTitle -> confOf#string, confOf#remark -> confOf#string, confOf#hasKeyword -> confOf#string, confOf#contactEmail -> confOf#string\tedas#Conference\t \t \tedas#isTopicOf -> edas#Topic, edas#hasTopic -> edas#Topic, edas#hasRelatedDocument -> edas#Document, edas#relatesTo -> edas#Document\tedas#paperDueOn -> edas#dateTime, edas#registrationDueOn -> edas#dateTime, edas#endDate -> edas#dateTime, edas#startDate -> edas#dateTime, edas#manuscriptDueOn -> edas#dateTime, edas#hasName -> edas#string\t1.057',
#  'cmt#Author\tcmt#Author -> cmt#ConferenceMember -> cmt#Person, cmt#Author -> cmt#User -> cmt#Person\tcmt#Co-author, cmt#AuthorNotReviewer\tcmt#submitPaper -> cmt#Paper, cmt#writePaper -> cmt#Paper, cmt#hasAuthor -> cmt#Paper\t \tekaw#Possible_Reviewer\tekaw#Possible_Reviewer -> ekaw#Person\tekaw#PC_Member\tekaw#hasReviewer -> ekaw#Paper, ekaw#reviewerOfPaper -> ekaw#Paper\t \t1.056',
#  'conference#Conference_document\t \t \tconference#has_authors -> conference#Person, conference#contributes -> conference#Person\tconference#has_a_date_of_issue -> conference#date\tedas#Conference\t \t \tedas#isMemberOf -> edas#Person, edas#hasMember -> edas#Person, edas#hasRelatedDocument -> edas#Document, edas#relatesTo -> edas#Document\tedas#paperDueOn -> edas#dateTime, edas#registrationDueOn -> edas#dateTime, edas#endDate -> edas#dateTime, edas#startDate -> edas#dateTime, edas#manuscriptDueOn -> edas#dateTime, edas#hasName -> edas#string\t1.056',
#  'confOf#Working_event\tconfOf#Working_event -> confOf#Event\t \tconfOf#hasTopic -> confOf#Topic\tconfOf#has_short_title -> confOf#string, confOf#hasVAT -> confOf#string, confOf#location -> confOf#string, confOf#defaultChoice -> confOf#positiveInteger, confOf#has_title -> confOf#string, confOf#minChoice -> confOf#positiveInteger, confOf#maxChoice -> confOf#positiveInteger\tedas#Conference\t \t \tedas#isTopicOf -> edas#Topic, edas#hasTopic -> edas#Topic, edas#hasRelatedDocument -> edas#Document, edas#relatesTo -> edas#Document\tedas#paperDueOn -> edas#dateTime, edas#registrationDueOn -> edas#dateTime, edas#endDate -> edas#dateTime, edas#startDate -> edas#dateTime, edas#manuscriptDueOn -> edas#dateTime, edas#hasName -> edas#string\t1.052',
#  'cmt#Meta-Reviewer\tcmt#Meta-Reviewer -> cmt#Reviewer -> cmt#ConferenceMember -> cmt#Person, cmt#Meta-Reviewer -> cmt#Reviewer -> cmt#User -> cmt#Person\t \tcmt#readByMeta-Reviewer -> cmt#Paper\t \tekaw#Possible_Reviewer\tekaw#Possible_Reviewer -> ekaw#Person\t \tekaw#hasReviewer -> ekaw#Paper, ekaw#reviewerOfPaper -> ekaw#Paper, ekaw#reviewWrittenBy -> ekaw#Review\t \t1.045',
#  'ekaw#Possible_Reviewer\tekaw#Possible_Reviewer -> ekaw#Person\t \tekaw#reviewWrittenBy -> ekaw#Review, ekaw#hasReviewer -> ekaw#Paper, ekaw#reviewerOfPaper -> ekaw#Paper\t \tiasted#Reviewer\tiasted#Reviewer -> iasted#Speaker -> iasted#Delegate -> iasted#Person\t \tiasted#is_writen_by -> iasted#Review\t \t1.044',
#  'edas#Paper\tedas#Paper -> edas#Document\tedas#PublishedPaper, edas#WithdrawnPaper, edas#RejectedPaper\tedas#isReviewing -> edas#ConferenceChair, edas#isReviewedBy -> edas#ConferenceChair, edas#isReviewedBy -> edas#SessionChair, edas#isReviewing -> edas#SessionChair, edas#isReviewing -> edas#Reviewer, edas#isReviewedBy -> edas#Reviewer\t \tiasted#Submission\tiasted#Submission -> iasted#Document -> iasted#Item\tiasted#Initial_manuscipt, iasted#Final_manuscript\tiasted#is_writen_by -> iasted#Speaker\t \t1.041',
#  'edas#Conference\t \t \tedas#isMemberOf -> edas#Person, edas#hasMember -> edas#Person, edas#hasRelatedDocument -> edas#Document\tedas#paperDueOn -> edas#dateTime, edas#registrationDueOn -> edas#dateTime, edas#endDate -> edas#dateTime, edas#startDate -> edas#dateTime, edas#manuscriptDueOn -> edas#dateTime, edas#hasName -> edas#string\tsigkdd#Registration_fee\tsigkdd#Registration_fee -> sigkdd#Fee\t \tsigkdd#payed_by -> sigkdd#Person, sigkdd#pay -> sigkdd#Person\tsigkdd#Currency -> sigkdd#string, sigkdd#Price -> sigkdd#int\t1.04',
#  'ekaw#Possible_Reviewer\tekaw#Possible_Reviewer -> ekaw#Person\tekaw#PC_Member\tekaw#hasReviewer -> ekaw#Paper, ekaw#reviewerOfPaper -> ekaw#Paper, ekaw#reviewWrittenBy -> ekaw#Review\t \tsigkdd#Author\tsigkdd#Author -> sigkdd#Speaker -> sigkdd#Person\tsigkdd#Author_of_paper_student, sigkdd#Author_of_paper\tsigkdd#submit -> sigkdd#Paper, sigkdd#obtain -> sigkdd#Award\t \t1.036',
#  'edas#Paper\tedas#Paper -> edas#Document\tedas#RejectedPaper, edas#AcceptedPaper, edas#WithdrawnPaper\tedas#isReviewing -> edas#Reviewer, edas#isReviewedBy -> edas#Reviewer, edas#isTopicOf -> edas#Topic, edas#hasTopic -> edas#Topic\t \tekaw#Review\tekaw#Review -> ekaw#Document\tekaw#Negative_Review, ekaw#Neutral_Review, ekaw#Positive_Review\tekaw#reviewWrittenBy -> ekaw#Possible_Reviewer, ekaw#hasReview -> ekaw#Paper, ekaw#reviewOfPaper -> ekaw#Paper\t \t1.034',
#  'cmt#Reviewer\tcmt#Reviewer -> cmt#ConferenceMember -> cmt#Person, cmt#Reviewer -> cmt#User -> cmt#Person\tcmt#Meta-Reviewer\tcmt#readByReviewer -> cmt#Paper, cmt#markConflictOfInterest -> cmt#Paper, cmt#readPaper -> cmt#Paper\t \tsigkdd#Speaker\tsigkdd#Speaker -> sigkdd#Person\tsigkdd#Author, sigkdd#Invited_Speaker\tsigkdd#presentationed_by -> sigkdd#Document, sigkdd#presentation -> sigkdd#Document\t \t1.033',
#  'cmt#Paper\tcmt#Paper -> cmt#Document\t \tcmt#markConflictOfInterest -> cmt#Chairman, cmt#hasDecision -> cmt#Decision, cmt#acceptedBy -> cmt#Administrator\tcmt#paperID -> cmt#unsignedLong, cmt#title -> cmt#string\tconference#Conference_volume\tconference#Conference_volume -> conference#Conference\t \tconference#has_a_commtitee -> conference#Committee, conference#was_a_committee_of -> conference#Committee, conference#has_a_steering_committee -> conference#Steering_committee, conference#was_a_steering_committee_of -> conference#Steering_committee\tconference#has_a_location -> conference#string\t1.03',
#  'cmt#Author\tcmt#Author -> cmt#ConferenceMember -> cmt#Person, cmt#Author -> cmt#User -> cmt#Person\tcmt#Co-author, cmt#AuthorNotReviewer\tcmt#submitPaper -> cmt#Paper, cmt#writePaper -> cmt#Paper, cmt#hasAuthor -> cmt#Paper\t \tsigkdd#Speaker\tsigkdd#Speaker -> sigkdd#Person\tsigkdd#Author, sigkdd#Invited_Speaker\tsigkdd#presentationed_by -> sigkdd#Document, sigkdd#presentation -> sigkdd#Document\t \t1.029',
#  'cmt#Meta-Reviewer\tcmt#Meta-Reviewer -> cmt#Reviewer -> cmt#ConferenceMember -> cmt#Person, cmt#Meta-Reviewer -> cmt#Reviewer -> cmt#User -> cmt#Person\t \tcmt#readByMeta-Reviewer -> cmt#Paper\t \tsigkdd#Author\tsigkdd#Author -> sigkdd#Speaker -> sigkdd#Person\t \tsigkdd#submit -> sigkdd#Paper, sigkdd#obtain -> sigkdd#Award, sigkdd#notification_until -> sigkdd#Deadline_Author_notification\t \t1.027',
#  'cmt#Administrator\tcmt#Administrator -> cmt#User -> cmt#Person\t \tcmt#acceptedBy -> cmt#Paper, cmt#rejectPaper -> cmt#Paper, cmt#rejectedBy -> cmt#Paper\t \tedas#SessionChair\tedas#SessionChair -> edas#Person\t \tedas#isReviewedBy -> edas#Paper, edas#isReviewing -> edas#Paper\t \t1.015',
#  'cmt#Conference\t \t \tcmt#hasConferenceMember -> cmt#ConferenceMember, cmt#memberOfConference -> cmt#ConferenceMember\tcmt#siteURL -> cmt#anyURI, cmt#acceptsHardcopySubmissions -> cmt#boolean, cmt#logoURL -> cmt#anyURI, cmt#reviewsPerPaper -> cmt#int, cmt#name -> cmt#string, cmt#date -> cmt#date\tconference#Conference_volume\tconference#Conference_volume -> conference#Conference\t \tconference#has_parts -> conference#Conference_part, conference#is_part_of_conference_volumes -> conference#Conference_part, conference#is_submitted_at -> conference#Conference_contribution, conference#has_contributions -> conference#Conference_contribution\tconference#has_a_location -> conference#string\t1.014',
#  'cmt#Paper\tcmt#Paper -> cmt#Document\tcmt#PaperAbstract, cmt#PaperFullVersion\tcmt#readByReviewer -> cmt#Reviewer, cmt#markConflictOfInterest -> cmt#Reviewer, cmt#readPaper -> cmt#Reviewer, cmt#assignedTo -> cmt#Reviewer, cmt#hasBeenAssigned -> cmt#Reviewer, cmt#readByMeta-Reviewer -> cmt#Meta-Reviewer\tcmt#paperID -> cmt#unsignedLong, cmt#title -> cmt#string\tekaw#Review\tekaw#Review -> ekaw#Document\tekaw#Neutral_Review, ekaw#Negative_Review, ekaw#Positive_Review\tekaw#reviewWrittenBy -> ekaw#Possible_Reviewer\t \t1.013',
#  'cmt#Administrator\tcmt#Administrator -> cmt#User -> cmt#Person\t \tcmt#acceptedBy -> cmt#Paper, cmt#rejectPaper -> cmt#Paper, cmt#rejectedBy -> cmt#Paper\t \tedas#ConferenceChair\tedas#ConferenceChair -> edas#Person\t \tedas#isReviewing -> edas#Paper, edas#isReviewedBy -> edas#Paper\t \t1.011',
#  'edas#ConferenceChair\tedas#ConferenceChair -> edas#Person\t \tedas#isReviewing -> edas#Paper, edas#isReviewedBy -> edas#Paper, edas#initiates -> edas#Call, edas#isInitiatedBy -> edas#Call\t \tsigkdd#Author\tsigkdd#Author -> sigkdd#Speaker -> sigkdd#Person\t \tsigkdd#submit -> sigkdd#Paper, sigkdd#obtain -> sigkdd#Award\t \t1.004',
#  'cmt#ConferenceMember\tcmt#ConferenceMember -> cmt#Person\tcmt#ConferenceChair, cmt#AssociatedChair, cmt#ProgramCommitteeMember\tcmt#hasConferenceMember -> cmt#Conference, cmt#memberOfConference -> cmt#Conference\t \tiasted#Delegate\tiasted#Delegate -> iasted#Person\tiasted#Session_chair, iasted#Speaker, iasted#Conference_Hiker, iasted#Non_speaker, iasted#Technical_commitee\tiasted#is_visited_by -> iasted#Conference_state, iasted#is_visited_by -> iasted#Conference_city, iasted#is_occupied_by -> iasted#Conference_building\t \t1.002',
#  'edas#ConferenceChair\tedas#ConferenceChair -> edas#Person\t \tedas#isReviewing -> edas#Paper, edas#isReviewedBy -> edas#Paper, edas#initiates -> edas#Call\t \tsigkdd#Speaker\tsigkdd#Speaker -> sigkdd#Person\t \tsigkdd#presentationed_by -> sigkdd#Document, sigkdd#presentation -> sigkdd#Document\t \t0.999',
#  'cmt#Reviewer\tcmt#Reviewer -> cmt#ConferenceMember -> cmt#Person, cmt#Reviewer -> cmt#User -> cmt#Person\t \tcmt#readByReviewer -> cmt#Paper, cmt#markConflictOfInterest -> cmt#Paper, cmt#readPaper -> cmt#Paper\t \tedas#ConferenceChair\tedas#ConferenceChair -> edas#Person\t \tedas#isReviewing -> edas#Paper, edas#isReviewedBy -> edas#Paper\t \t0.998',
#  'cmt#Administrator\tcmt#Administrator -> cmt#User -> cmt#Person\t \tcmt#acceptedBy -> cmt#Paper, cmt#rejectPaper -> cmt#Paper, cmt#rejectedBy -> cmt#Paper\t \tekaw#Possible_Reviewer\tekaw#Possible_Reviewer -> ekaw#Person\t \tekaw#hasReviewer -> ekaw#Paper, ekaw#reviewerOfPaper -> ekaw#Paper\t \t0.996',
#  'conference#Conference_volume\tconference#Conference_volume -> conference#Conference\t \tconference#was_an_organizing_committee_of -> conference#Organizing_committee, conference#has_an_organizing_committee -> conference#Organizing_committee, conference#has_tracks -> conference#Track, conference#has_tutorials -> conference#Tutorial\tconference#has_a_location -> conference#string\tconfOf#Working_event\tconfOf#Working_event -> confOf#Event\t \tconfOf#hasAdministrativeEvent -> confOf#Administrative_event, confOf#hasTopic -> confOf#Topic\tconfOf#has_short_title -> confOf#string, confOf#hasVAT -> confOf#string, confOf#location -> confOf#string, confOf#defaultChoice -> confOf#positiveInteger, confOf#has_title -> confOf#string, confOf#minChoice -> confOf#positiveInteger, confOf#maxChoice -> confOf#positiveInteger\t0.994',
#  'ekaw#Paper\tekaw#Paper -> ekaw#Document\t \tekaw#hasReview -> ekaw#Review, ekaw#reviewOfPaper -> ekaw#Review, ekaw#hasReviewer -> ekaw#Possible_Reviewer, ekaw#reviewerOfPaper -> ekaw#Possible_Reviewer, ekaw#coversTopic -> ekaw#Research_Topic, ekaw#topicCoveredBy -> ekaw#Research_Topic\t \tiasted#Review\tiasted#Review -> iasted#Document -> iasted#Item\t \tiasted#is_writen_by -> iasted#Reviewer\t \t0.992',
#  'cmt#ConferenceMember\tcmt#ConferenceMember -> cmt#Person\tcmt#ConferenceChair, cmt#AssociatedChair, cmt#Reviewer, cmt#Author\tcmt#hasConferenceMember -> cmt#Conference, cmt#memberOfConference -> cmt#Conference\t \tconference#Committee_member\tconference#Committee_member -> conference#Person\tconference#Chair, conference#Co-chair\tconference#was_a_member_of -> conference#Committee, conference#has_members -> conference#Committee\t \t0.992',
#  'cmt#Author\tcmt#Author -> cmt#ConferenceMember -> cmt#Person, cmt#Author -> cmt#User -> cmt#Person\t \tcmt#submitPaper -> cmt#Paper, cmt#writePaper -> cmt#Paper, cmt#hasAuthor -> cmt#Paper\t \tedas#ConferenceChair\tedas#ConferenceChair -> edas#Person\t \tedas#isReviewing -> edas#Paper, edas#isReviewedBy -> edas#Paper\t \t0.99',
#  'cmt#Reviewer\tcmt#Reviewer -> cmt#ConferenceMember -> cmt#Person, cmt#Reviewer -> cmt#User -> cmt#Person\t \tcmt#readByReviewer -> cmt#Paper, cmt#markConflictOfInterest -> cmt#Paper, cmt#readPaper -> cmt#Paper\t \tedas#SessionChair\tedas#SessionChair -> edas#Person\t \tedas#isReviewedBy -> edas#Paper, edas#isReviewing -> edas#Paper\t \t0.988',
#  'cmt#ProgramCommitteeMember\tcmt#ProgramCommitteeMember -> cmt#Person, cmt#ProgramCommitteeMember -> cmt#ConferenceMember -> cmt#Person\tcmt#ProgramCommitteeChair\tcmt#addProgramCommitteeMember -> cmt#Administrator, cmt#setMaxPapers -> cmt#Administrator, cmt#addedBy -> cmt#Administrator\tcmt#maxPapers -> cmt#int\tsigkdd#Registration_fee\tsigkdd#Registration_fee -> sigkdd#Fee\tsigkdd#Registration_Student, sigkdd#Registration_SIGKDD_Member, sigkdd#Registration_Non-Member, sigkdd#Registration_SIGMOD_Member\tsigkdd#payed_by -> sigkdd#Person, sigkdd#pay -> sigkdd#Person\tsigkdd#Currency -> sigkdd#string, sigkdd#Price -> sigkdd#int\t0.987',
#  'cmt#Chairman\tcmt#Chairman -> cmt#Person\t \tcmt#markConflictOfInterest -> cmt#Paper\t \tekaw#Possible_Reviewer\tekaw#Possible_Reviewer -> ekaw#Person\t \tekaw#hasReviewer -> ekaw#Paper, ekaw#reviewerOfPaper -> ekaw#Paper, ekaw#reviewWrittenBy -> ekaw#Review\t \t0.986',
#  'ekaw#Conference_Session\tekaw#Conference_Session -> ekaw#Session -> ekaw#Scientific_Event -> ekaw#Event\tekaw#Industrial_Session\tekaw#partOfEvent -> ekaw#Conference\t \tiasted#Conference_activity\tiasted#Conference_activity -> iasted#Activity\tiasted#Coffee_break, iasted#Technic_activity, iasted#Presentation, iasted#Registration, iasted#Social_program, iasted#Lecture\tiasted#is_held_in -> iasted#Conference_state, iasted#is_held_in -> iasted#Conference_days, iasted#is_paid_for -> iasted#Registration_fee\t \t0.986',
#  'cmt#Reviewer\tcmt#Reviewer -> cmt#ConferenceMember -> cmt#Person, cmt#Reviewer -> cmt#User -> cmt#Person\tcmt#Meta-Reviewer\tcmt#adjustedBy -> cmt#Bid, cmt#adjustBid -> cmt#Bid, cmt#writtenBy -> cmt#Review, cmt#writeReview -> cmt#Review\t \tiasted#Speaker\tiasted#Speaker -> iasted#Delegate -> iasted#Person\tiasted#Reviewer, iasted#Author\tiasted#is_writen_by -> iasted#Submission, iasted#give -> iasted#Lecture\t \t0.985',
#  'cmt#Administrator\tcmt#Administrator -> cmt#User -> cmt#Person\t \tcmt#paperAssignmentToolsRunBy -> cmt#Conference, cmt#enterReviewCriteria -> cmt#Conference, cmt#runPaperAssignmentTools -> cmt#Conference, cmt#enableVirtualMeeting -> cmt#Conference, cmt#virtualMeetingEnabledBy -> cmt#Conference, cmt#detailsEnteredBy -> cmt#Conference\t \tiasted#Delegate\tiasted#Delegate -> iasted#Person\t \tiasted#is_visited_by -> iasted#Conference_state\t \t0.98',
#  'cmt#Reviewer\tcmt#Reviewer -> cmt#ConferenceMember -> cmt#Person, cmt#Reviewer -> cmt#User -> cmt#Person\tcmt#Meta-Reviewer\tcmt#writtenBy -> cmt#Review, cmt#writeReview -> cmt#Review, cmt#adjustedBy -> cmt#Bid\t \tconference#Reviewed_contribution\tconference#Reviewed_contribution -> conference#Submitted_contribution -> conference#Written_contribution -> conference#Conference_contribution -> conference#Conference_document\tconference#Accepted_contribution, conference#Rejected_contribution\tconference#has_a_review -> conference#Review, conference#reviews -> conference#Review\t \t0.978',
#  'confOf#Working_event\tconfOf#Working_event -> confOf#Event\tconfOf#Workshop, confOf#Tutorial, confOf#Conference\tconfOf#hasTopic -> confOf#Topic, confOf#hasAdministrativeEvent -> confOf#Administrative_event\tconfOf#has_short_title -> confOf#string, confOf#hasVAT -> confOf#string, confOf#location -> confOf#string, confOf#defaultChoice -> confOf#positiveInteger, confOf#has_title -> confOf#string, confOf#minChoice -> confOf#positiveInteger, confOf#maxChoice -> confOf#positiveInteger\tsigkdd#Registration_fee\tsigkdd#Registration_fee -> sigkdd#Fee\tsigkdd#Registration_Student, sigkdd#Registration_Non-Member, sigkdd#Registration_SIGKDD_Member\tsigkdd#payed_by -> sigkdd#Person, sigkdd#pay -> sigkdd#Person\tsigkdd#Currency -> sigkdd#string, sigkdd#Price -> sigkdd#int\t0.976',
#  'cmt#Meta-Reviewer\tcmt#Meta-Reviewer -> cmt#Reviewer -> cmt#ConferenceMember -> cmt#Person, cmt#Meta-Reviewer -> cmt#Reviewer -> cmt#User -> cmt#Person\t \tcmt#readByMeta-Reviewer -> cmt#Paper\t \tekaw#Review\tekaw#Review -> ekaw#Document\t \tekaw#hasReview -> ekaw#Paper, ekaw#reviewOfPaper -> ekaw#Paper, ekaw#reviewWrittenBy -> ekaw#Possible_Reviewer\t \t0.975',
#  'cmt#ConferenceMember\tcmt#ConferenceMember -> cmt#Person\tcmt#ConferenceChair, cmt#AssociatedChair, cmt#ProgramCommitteeMember, cmt#Reviewer, cmt#Author\tcmt#hasConferenceMember -> cmt#Conference, cmt#memberOfConference -> cmt#Conference\t \tekaw#Conference_Session\tekaw#Conference_Session -> ekaw#Session -> ekaw#Scientific_Event -> ekaw#Event\tekaw#Industrial_Session\tekaw#partOfEvent -> ekaw#Conference\t \t0.973',
#  'conference#Topic\t \t \tconference#is_a_topis_of_conference_parts -> conference#Conference_part, conference#has_a_track-workshop-tutorial_topic -> conference#Conference_part\tconference#has_a_name -> conference#string\tedas#Person\t \t \tedas#isMemberOf -> edas#Conference, edas#hasMember -> edas#Conference, edas#attendeeAt -> edas#ConferenceEvent, edas#hasAttendee -> edas#ConferenceEvent\tedas#hasEmail -> edas#string, edas#hasLastName -> edas#string, edas#hasFirstName -> edas#string, edas#hasBiography -> edas#string\t0.971',
#  'cmt#Reviewer\tcmt#Reviewer -> cmt#ConferenceMember -> cmt#Person, cmt#Reviewer -> cmt#User -> cmt#Person\tcmt#Meta-Reviewer\tcmt#writtenBy -> cmt#Review, cmt#writeReview -> cmt#Review, cmt#assignedByReviewer -> cmt#ExternalReviewer\t \tekaw#Paper\tekaw#Paper -> ekaw#Document\tekaw#Poster_Paper, ekaw#Submitted_Paper, ekaw#Workshop_Paper, ekaw#Demo_Paper, ekaw#Industrial_Paper, ekaw#Regular_Paper\tekaw#hasReview -> ekaw#Review, ekaw#reviewOfPaper -> ekaw#Review, ekaw#hasReviewer -> ekaw#Possible_Reviewer, ekaw#reviewerOfPaper -> ekaw#Possible_Reviewer\t \t0.97',
#  'cmt#Paper\tcmt#Paper -> cmt#Document\t \tcmt#readByReviewer -> cmt#Reviewer, cmt#markConflictOfInterest -> cmt#Reviewer, cmt#readPaper -> cmt#Reviewer, cmt#assignedTo -> cmt#Reviewer, cmt#hasBeenAssigned -> cmt#Reviewer, cmt#readByMeta-Reviewer -> cmt#Meta-Reviewer\tcmt#paperID -> cmt#unsignedLong, cmt#title -> cmt#string\tekaw#Accepted_Paper\tekaw#Accepted_Paper -> ekaw#Evaluated_Paper -> ekaw#Assigned_Paper -> ekaw#Submitted_Paper -> ekaw#Paper -> ekaw#Document\t \tekaw#hasReview -> ekaw#Positive_Review\t \t0.968',
#  'edas#Paper\tedas#Paper -> edas#Document\t \tedas#isReviewing -> edas#Reviewer, edas#isReviewedBy -> edas#Reviewer, edas#isWrittenBy -> edas#Author, edas#hasRelatedPaper -> edas#Author, edas#isTopicOf -> edas#Topic, edas#hasTopic -> edas#Topic\t \tekaw#Accepted_Paper\tekaw#Accepted_Paper -> ekaw#Evaluated_Paper -> ekaw#Assigned_Paper -> ekaw#Submitted_Paper -> ekaw#Paper -> ekaw#Document\t \tekaw#hasReview -> ekaw#Positive_Review\t \t0.968',
#  'edas#SessionChair\tedas#SessionChair -> edas#Person\t \tedas#isReviewedBy -> edas#Paper, edas#isReviewing -> edas#Paper, edas#isInitiatedBy -> edas#Call, edas#initiates -> edas#Call\t \tsigkdd#Author\tsigkdd#Author -> sigkdd#Speaker -> sigkdd#Person\t \tsigkdd#submit -> sigkdd#Paper, sigkdd#obtain -> sigkdd#Award\t \t0.967',
#  'cmt#Author\tcmt#Author -> cmt#ConferenceMember -> cmt#Person, cmt#Author -> cmt#User -> cmt#Person\tcmt#AuthorNotReviewer, cmt#Co-author\tcmt#submitPaper -> cmt#Paper, cmt#writePaper -> cmt#Paper, cmt#hasAuthor -> cmt#Paper\t \tekaw#Review\tekaw#Review -> ekaw#Document\tekaw#Negative_Review, ekaw#Neutral_Review, ekaw#Positive_Review\tekaw#hasReview -> ekaw#Paper, ekaw#reviewOfPaper -> ekaw#Paper\t \t0.967',
#  'edas#ActivePaper\tedas#ActivePaper -> edas#Paper -> edas#Document\t \tedas#hasRating -> edas#ReviewRating\t \tekaw#Accepted_Paper\tekaw#Accepted_Paper -> ekaw#Evaluated_Paper -> ekaw#Assigned_Paper -> ekaw#Submitted_Paper -> ekaw#Paper -> ekaw#Document\t \tekaw#hasReview -> ekaw#Positive_Review, ekaw#updatedVersionOf -> ekaw#Camera_Ready_Paper\t \t0.965',
#  'conference#Conference_part\t \tconference#Track, conference#Workshop, conference#Tutorial\tconference#has_parts -> conference#Conference_volume, conference#is_part_of_conference_volumes -> conference#Conference_volume\tconference#has_a_name -> conference#string\tedas#Person\t \tedas#Attendee, edas#SessionChair, edas#ConferenceChair\tedas#isMemberOf -> edas#Conference, edas#hasMember -> edas#Conference, edas#attendeeAt -> edas#ConferenceEvent, edas#hasAttendee -> edas#ConferenceEvent\tedas#hasEmail -> edas#string, edas#hasLastName -> edas#string, edas#hasFirstName -> edas#string, edas#hasBiography -> edas#string\t0.964',
#  'edas#Paper\tedas#Paper -> edas#Document\tedas#PublishedPaper, edas#ActivePaper, edas#WithdrawnPaper, edas#PendingPaper, edas#RejectedPaper, edas#AcceptedPaper\t \t \tekaw#Submitted_Paper\tekaw#Submitted_Paper -> ekaw#Paper -> ekaw#Document\tekaw#Assigned_Paper\t \t \t0.963',
#  'conference#Reviewer\tconference#Reviewer -> conference#Person\t \tconference#belongs_to_reviewers -> conference#Review_expertise, conference#has_a_review_reference_or_expertise -> conference#Review_expertise, conference#belongs_to_reviewers -> conference#Review_preference, conference#has_a_review_reference_or_expertise -> conference#Review_preference\t \tekaw#Possible_Reviewer\tekaw#Possible_Reviewer -> ekaw#Person\t \tekaw#reviewWrittenBy -> ekaw#Review\t \t0.962',
#  'cmt#Administrator\tcmt#Administrator -> cmt#User -> cmt#Person\t \tcmt#acceptedBy -> cmt#Paper, cmt#rejectPaper -> cmt#Paper, cmt#rejectedBy -> cmt#Paper\t \tsigkdd#Speaker\tsigkdd#Speaker -> sigkdd#Person\t \tsigkdd#presentationed_by -> sigkdd#Document, sigkdd#presentation -> sigkdd#Document\t \t0.962',
#  'edas#SessionChair\tedas#SessionChair -> edas#Person\t \tedas#isReviewedBy -> edas#Paper, edas#isReviewing -> edas#Paper, edas#isInitiatedBy -> edas#Call\t \tsigkdd#Speaker\tsigkdd#Speaker -> sigkdd#Person\t \tsigkdd#presentationed_by -> sigkdd#Document, sigkdd#presentation -> sigkdd#Document\t \t0.959',
#  'edas#Programme\tedas#Programme -> edas#Document\t \tedas#hasProgramme -> edas#ConferenceEvent, edas#belongsToEvent -> edas#ConferenceEvent\t \tekaw#Programme_Brochure\tekaw#Programme_Brochure -> ekaw#Document\t \tekaw#listsEvent -> ekaw#Event, ekaw#eventOnList -> ekaw#Event, ekaw#publisherOf -> ekaw#Organisation\t \t0.957',
#  'cmt#Review\tcmt#Review -> cmt#Document\tcmt#Meta-Review\tcmt#writtenBy -> cmt#Reviewer, cmt#writeReview -> cmt#Reviewer, cmt#endReview -> cmt#ProgramCommitteeChair\t \tedas#ActivePaper\tedas#ActivePaper -> edas#Paper -> edas#Document\tedas#RatedPapers\tedas#hasRating -> edas#ReviewRating\t \t0.956',
#  'cmt#Author\tcmt#Author -> cmt#ConferenceMember -> cmt#Person, cmt#Author -> cmt#User -> cmt#Person\t \tcmt#submitPaper -> cmt#Paper, cmt#writePaper -> cmt#Paper, cmt#hasAuthor -> cmt#Paper\t \tedas#SessionChair\tedas#SessionChair -> edas#Person\t \tedas#isReviewedBy -> edas#Paper, edas#isReviewing -> edas#Paper\t \t0.956',
#  'conference#Conference_volume\tconference#Conference_volume -> conference#Conference\t \tconference#has_parts -> conference#Conference_part, conference#is_part_of_conference_volumes -> conference#Conference_part, conference#is_submitted_at -> conference#Conference_contribution, conference#has_contributions -> conference#Conference_contribution, conference#has_a_commtitee -> conference#Committee, conference#was_a_committee_of -> conference#Committee\tconference#has_a_location -> conference#string\tekaw#Conference\tekaw#Conference -> ekaw#Scientific_Event -> ekaw#Event\t \tekaw#partOfEvent -> ekaw#Conference_Session\t \t0.955',
#  'confOf#Working_event\tconfOf#Working_event -> confOf#Event\tconfOf#Workshop, confOf#Conference, confOf#Tutorial\tconfOf#hasTopic -> confOf#Topic\tconfOf#has_short_title -> confOf#string, confOf#hasVAT -> confOf#string, confOf#location -> confOf#string, confOf#defaultChoice -> confOf#positiveInteger, confOf#has_title -> confOf#string, confOf#minChoice -> confOf#positiveInteger, confOf#maxChoice -> confOf#positiveInteger\tedas#AcademicEvent\tedas#AcademicEvent -> edas#ConferenceEvent\tedas#Workshop, edas#TalkEvent, edas#OrganizationalMeeting\tedas#relatesTo -> edas#Document, edas#hasRelatedDocument -> edas#Document, edas#hasCall -> edas#Call, edas#forEvent -> edas#Call\t \t0.954',
#  'conference#Conference_volume\tconference#Conference_volume -> conference#Conference\t \tconference#has_a_program_committee -> conference#Program_committee, conference#was_a_program_committee_of -> conference#Program_committee, conference#was_an_organizing_committee_of -> conference#Organizing_committee\tconference#has_a_location -> conference#string\tconfOf#Contribution\t \t \tconfOf#reviewes -> confOf#Member_PC\tconfOf#abstract -> confOf#string, confOf#hasTitle -> confOf#string, confOf#remark -> confOf#string, confOf#hasKeyword -> confOf#string, confOf#contactEmail -> confOf#string\t0.953',
#  'edas#ActivePaper\tedas#ActivePaper -> edas#Paper -> edas#Document\tedas#RatedPapers\t \t \tekaw#Assigned_Paper\tekaw#Assigned_Paper -> ekaw#Submitted_Paper -> ekaw#Paper -> ekaw#Document\tekaw#Evaluated_Paper\t \t \t0.952',
#  'edas#AcademicEvent\tedas#AcademicEvent -> edas#ConferenceEvent\tedas#TalkEvent, edas#Workshop, edas#PaperPresentation\tedas#relatesTo -> edas#Document, edas#hasRelatedDocument -> edas#Document\t \tekaw#Individual_Presentation\tekaw#Individual_Presentation -> ekaw#Scientific_Event -> ekaw#Event\tekaw#Contributed_Talk, ekaw#Invited_Talk, ekaw#Tutorial\tekaw#presentationOfPaper -> ekaw#Paper, ekaw#paperPresentedAs -> ekaw#Paper, ekaw#hasEvent -> ekaw#Session\t \t0.951',
#  'cmt#Administrator\tcmt#Administrator -> cmt#User -> cmt#Person\t \tcmt#assignReviewer -> cmt#Reviewer, cmt#assignedByAdministrator -> cmt#Reviewer, cmt#paperAssignmentToolsRunBy -> cmt#Conference, cmt#enterReviewCriteria -> cmt#Conference, cmt#runPaperAssignmentTools -> cmt#Conference, cmt#enableVirtualMeeting -> cmt#Conference\t \tiasted#Reviewer\tiasted#Reviewer -> iasted#Speaker -> iasted#Delegate -> iasted#Person\t \tiasted#is_writen_by -> iasted#Review\t \t0.948',
#  'iasted#Hotel_room\tiasted#Hotel_room -> iasted#Place\t \tiasted#is_designed_for -> iasted#Hotel_presenter, iasted#is_situated_in -> iasted#Conference_hotel\t \tsigkdd#Hotel\tsigkdd#Hotel -> sigkdd#Place\t \tsigkdd#can_stay_in -> sigkdd#Person\t \t0.947',
#  'iasted#Deadline_for_notification_of_acceptance\tiasted#Deadline_for_notification_of_acceptance -> iasted#Deadline -> iasted#Time\t \tiasted#is_sent_after -> iasted#Author_information_form\t \tsigkdd#Deadline_Author_notification\tsigkdd#Deadline_Author_notification -> sigkdd#Deadline\t \tsigkdd#notification_until -> sigkdd#Author\t \t0.946',
#  'iasted#Speaker\tiasted#Speaker -> iasted#Delegate -> iasted#Person\tiasted#Author, iasted#Reviewer\tiasted#is_writen_by -> iasted#Submission, iasted#give -> iasted#Lecture, iasted#write -> iasted#Final_manuscript, iasted#is_prepared_by -> iasted#Transparency\t \tsigkdd#Author\tsigkdd#Author -> sigkdd#Speaker -> sigkdd#Person\tsigkdd#Author_of_paper, sigkdd#Author_of_paper_student\tsigkdd#obtain -> sigkdd#Award, sigkdd#submit -> sigkdd#Paper\t \t0.944',
#  'ekaw#Review\tekaw#Review -> ekaw#Document\tekaw#Negative_Review, ekaw#Neutral_Review, ekaw#Positive_Review\tekaw#hasReview -> ekaw#Paper, ekaw#reviewOfPaper -> ekaw#Paper, ekaw#reviewWrittenBy -> ekaw#Possible_Reviewer\t \tsigkdd#Author\tsigkdd#Author -> sigkdd#Speaker -> sigkdd#Person\tsigkdd#Author_of_paper, sigkdd#Author_of_paper_student\tsigkdd#submit -> sigkdd#Paper, sigkdd#obtain -> sigkdd#Award, sigkdd#notification_until -> sigkdd#Deadline_Author_notification\t \t0.943',
#  'cmt#Reviewer\tcmt#Reviewer -> cmt#ConferenceMember -> cmt#Person, cmt#Reviewer -> cmt#User -> cmt#Person\t \tcmt#writtenBy -> cmt#Review, cmt#writeReview -> cmt#Review, cmt#assignedByReviewer -> cmt#ExternalReviewer, cmt#assignExternalReviewer -> cmt#ExternalReviewer, cmt#assignReviewer -> cmt#Administrator, cmt#assignedByAdministrator -> cmt#Administrator\t \tiasted#Review\tiasted#Review -> iasted#Document -> iasted#Item\t \tiasted#is_writen_by -> iasted#Reviewer\t \t0.942',
# ...
#  'confOf#Reception\tconfOf#Reception -> confOf#Social_event -> confOf#Event\t \t \t \tekaw#Social_Event\tekaw#Social_Event -> ekaw#Event\t \t \t \t0.718',
#  'cmt#User\tcmt#User -> cmt#Person\tcmt#Author, cmt#Reviewer, cmt#Administrator\t \t \tsigkdd#Author\tsigkdd#Author -> sigkdd#Speaker -> sigkdd#Person\tsigkdd#Author_of_paper, sigkdd#Author_of_paper_student\t \t \t0.718',
#  'conference#Steering_committee\tconference#Steering_committee -> conference#Committee\t \tconference#has_a_steering_committee -> conference#Conference_volume, conference#was_a_steering_committee_of -> conference#Conference_volume\t \tekaw#Conference_Session\tekaw#Conference_Session -> ekaw#Session -> ekaw#Scientific_Event -> ekaw#Event\t \tekaw#partOfEvent -> ekaw#Conference\t \t0.718',
#  'cmt#Review\tcmt#Review -> cmt#Document\t \tcmt#endReview -> cmt#ProgramCommitteeChair, cmt#writtenBy -> cmt#Reviewer, cmt#writeReview -> cmt#Reviewer\t \tedas#Programme\tedas#Programme -> edas#Document\t \tedas#hasProgramme -> edas#ConferenceEvent, edas#belongsToEvent -> edas#ConferenceEvent\t \t0.718',
#  'edas#ActivePaper\tedas#ActivePaper -> edas#Paper -> edas#Document\t \t \t \tekaw#Conference_Paper\tekaw#Conference_Paper -> ekaw#Paper -> ekaw#Document\t \t \t \t0.718',
#  'ekaw#Individual_Presentation\tekaw#Individual_Presentation -> ekaw#Scientific_Event -> ekaw#Event\t \tekaw#hasEvent -> ekaw#Session, ekaw#presentationOfPaper -> ekaw#Paper, ekaw#paperPresentedAs -> ekaw#Paper\t \tiasted#Brief_introduction_for_Session_chair\tiasted#Brief_introduction_for_Session_chair -> iasted#Document -> iasted#Item\t \tiasted#is_given_to -> iasted#Session_chair, iasted#obtain -> iasted#Session_chair, iasted#give -> iasted#Author, iasted#is_given_by -> iasted#Author\t \t0.718',
#  'edas#Paper\tedas#Paper -> edas#Document\t \tedas#isReviewing -> edas#ConferenceChair, edas#isReviewedBy -> edas#ConferenceChair, edas#isReviewedBy -> edas#SessionChair, edas#isReviewing -> edas#SessionChair, edas#isReviewedBy -> edas#TPCMember, edas#isReviewing -> edas#TPCMember\t \tekaw#Conference\tekaw#Conference -> ekaw#Scientific_Event -> ekaw#Event\t \tekaw#partOfEvent -> ekaw#Conference_Session\t \t0.718',
#  'cmt#User\tcmt#User -> cmt#Person\tcmt#Administrator, cmt#Reviewer, cmt#Author\t \t \tiasted#Delegate\tiasted#Delegate -> iasted#Person\tiasted#Speaker, iasted#Hotel_presenter, iasted#Listener\t \t \t0.718',
#  'confOf#Organization\t \tconfOf#Company, confOf#University\tconfOf#hasCountry -> confOf#Country, confOf#hasCity -> confOf#City\tconfOf#hasPostalCode -> confOf#string, confOf#hasStreet -> confOf#string\tsigkdd#Sponzor\t \tsigkdd#Exhibitor, sigkdd#Silver_Supporter, sigkdd#Gold_Supporter, sigkdd#Bronze_Supporter, sigkdd#Platinum_Supporter\tsigkdd#search -> sigkdd#ACM_SIGKDD, sigkdd#searched_by -> sigkdd#ACM_SIGKDD\tsigkdd#Name_of_sponsor -> sigkdd#string\t0.718',
#  'cmt#Administrator\tcmt#Administrator -> cmt#User -> cmt#Person\t \tcmt#paperAssignmentToolsRunBy -> cmt#Conference, cmt#enterReviewCriteria -> cmt#Conference, cmt#runPaperAssignmentTools -> cmt#Conference\t \tconference#Steering_committee\tconference#Steering_committee -> conference#Committee\t \tconference#has_a_steering_committee -> conference#Conference_volume, conference#was_a_steering_committee_of -> conference#Conference_volume\t \t0.717',
#  'edas#Programme\tedas#Programme -> edas#Document\t \tedas#hasProgramme -> edas#ConferenceEvent, edas#belongsToEvent -> edas#ConferenceEvent\t \tiasted#Form\tiasted#Form -> iasted#Document -> iasted#Item\t \tiasted#is_given_to -> iasted#Delegate\t \t0.717',
#  'iasted#Book_proceeding\tiasted#Book_proceeding -> iasted#Publication -> iasted#Item\t \tiasted#obtain -> iasted#Author_book_proceedings_included, iasted#is_paid_for -> iasted#Author_attendee_book_registration_fee\t \tsigkdd#Paper\tsigkdd#Paper -> sigkdd#Document\t \tsigkdd#submit -> sigkdd#Author\t \t0.717',
#  'edas#Paper\tedas#Paper -> edas#Document\t \tedas#isWrittenBy -> edas#Author, edas#hasRelatedPaper -> edas#Author, edas#isReviewing -> edas#Reviewer, edas#isReviewedBy -> edas#Reviewer\t \tiasted#Book_proceeding\tiasted#Book_proceeding -> iasted#Publication -> iasted#Item\t \tiasted#obtain -> iasted#Author_book_proceedings_included, iasted#is_paid_for -> iasted#Author_attendee_book_registration_fee\t \t0.717',
#  'cmt#Paper\tcmt#Paper -> cmt#Document\t \tcmt#submitPaper -> cmt#Author, cmt#writePaper -> cmt#Author, cmt#hasAuthor -> cmt#Author, cmt#markConflictOfInterest -> cmt#Author\tcmt#paperID -> cmt#unsignedLong, cmt#title -> cmt#string\tiasted#Book_proceeding\tiasted#Book_proceeding -> iasted#Publication -> iasted#Item\t \tiasted#obtain -> iasted#Author_book_proceedings_included, iasted#is_paid_for -> iasted#Author_attendee_book_registration_fee\t \t0.717',
#  'cmt#Chairman\tcmt#Chairman -> cmt#Person\t \tcmt#markConflictOfInterest -> cmt#Paper\t \tconference#Committee_member\tconference#Committee_member -> conference#Person\t \tconference#was_a_member_of -> conference#Committee, conference#has_members -> conference#Committee\t \t0.717',
#  'iasted#Registration_form\tiasted#Registration_form -> iasted#Form -> iasted#Document -> iasted#Item\t \tiasted#send -> iasted#Delegate, iasted#is_sent_by -> iasted#Delegate, iasted#is_sent_before -> iasted#Registation_deadline\t \tsigkdd#Paper\tsigkdd#Paper -> sigkdd#Document\t \tsigkdd#submit -> sigkdd#Author\t \t0.717',
#  'edas#ConferenceEvent\t \tedas#AcademicEvent, edas#NonAcademicEvent\tedas#hasProgramme -> edas#Programme, edas#belongsToEvent -> edas#Programme, edas#attendeeAt -> edas#Person, edas#hasAttendee -> edas#Person, edas#hasLocation -> edas#Place, edas#isLocationOf -> edas#Place\tedas#hasStartDateTime -> edas#dateTime, edas#hasEndDateTime -> edas#dateTime\tiasted#Deadline\tiasted#Deadline -> iasted#Time\tiasted#Registation_deadline, iasted#Submissions_deadline, iasted#Deadline_for_notification_of_acceptance\tiasted#is_designed_for -> iasted#Delegate\tiasted#done_till -> iasted#date\t0.717',
#  'confOf#University\tconfOf#University -> confOf#Organization\t \tconfOf#studyAt -> confOf#Scholar\t \tiasted#Presenter_university\tiasted#Presenter_university -> iasted#Building -> iasted#Place\t \tiasted#is_situated_in -> iasted#Presenter_city, iasted#is_situated_in -> iasted#Presenter_state\t \t0.716',
#  'confOf#Member_PC\tconfOf#Member_PC -> confOf#Person\t \tconfOf#expertOn -> confOf#Topic, confOf#reviewes -> confOf#Contribution\t \tedas#Paper\tedas#Paper -> edas#Document\t \tedas#isTopicOf -> edas#Topic, edas#hasTopic -> edas#Topic, edas#isReviewing -> edas#Reviewer, edas#isReviewedBy -> edas#Reviewer\t \t0.716',
#  'ekaw#Web_Site\tekaw#Web_Site -> ekaw#Document\t \tekaw#listsEvent -> ekaw#Event, ekaw#eventOnList -> ekaw#Event, ekaw#publisherOf -> ekaw#Organisation\t \tiasted#Review\tiasted#Review -> iasted#Document -> iasted#Item\t \tiasted#is_writen_by -> iasted#Reviewer\t \t0.716',
#  'cmt#Paper\tcmt#Paper -> cmt#Document\t \t \tcmt#paperID -> cmt#unsignedLong, cmt#title -> cmt#string\tekaw#Rejected_Paper\tekaw#Rejected_Paper -> ekaw#Evaluated_Paper -> ekaw#Assigned_Paper -> ekaw#Submitted_Paper -> ekaw#Paper -> ekaw#Document\t \t \t \t0.716',
#  'ekaw#Rejected_Paper\tekaw#Rejected_Paper -> ekaw#Evaluated_Paper -> ekaw#Assigned_Paper -> ekaw#Submitted_Paper -> ekaw#Paper -> ekaw#Document\t \t \t \tsigkdd#Paper\tsigkdd#Paper -> sigkdd#Document\t \t \t \t0.716',
#  'edas#Paper\tedas#Paper -> edas#Document\t \t \t \tekaw#Rejected_Paper\tekaw#Rejected_Paper -> ekaw#Evaluated_Paper -> ekaw#Assigned_Paper -> ekaw#Submitted_Paper -> ekaw#Paper -> ekaw#Document\t \t \t \t0.716',
#  'edas#RejectedPaper\tedas#RejectedPaper -> edas#Paper -> edas#Document\t \t \t \tekaw#Industrial_Paper\tekaw#Industrial_Paper -> ekaw#Paper -> ekaw#Document\t \t \t \t0.716',
#  'cmt#Reviewer\tcmt#Reviewer -> cmt#ConferenceMember -> cmt#Person, cmt#Reviewer -> cmt#User -> cmt#Person\t \tcmt#adjustedBy -> cmt#Bid, cmt#adjustBid -> cmt#Bid\t \tiasted#Sponsor\tiasted#Sponsor -> iasted#Person\t \tiasted#occupy -> iasted#Sponsor_state, iasted#is_occupied_by -> iasted#Sponsor_city, iasted#occupy -> iasted#Sponsor_city\t \t0.716',
#  'cmt#Co-author\tcmt#Co-author -> cmt#Author -> cmt#ConferenceMember -> cmt#Person, cmt#Co-author -> cmt#Author -> cmt#User -> cmt#Person\t \tcmt#co-writePaper -> cmt#Paper, cmt#hasCo-author -> cmt#Paper\t \tekaw#Conference_Participant\tekaw#Conference_Participant -> ekaw#Person\t \tekaw#writtenBy -> ekaw#Camera_Ready_Paper\t \t0.716',
#  'edas#AcceptedPaper\tedas#AcceptedPaper -> edas#Paper -> edas#Document\t \t \t \tekaw#Evaluated_Paper\tekaw#Evaluated_Paper -> ekaw#Assigned_Paper -> ekaw#Submitted_Paper -> ekaw#Paper -> ekaw#Document\t \t \t \t0.716',
#  'edas#RejectedPaper\tedas#RejectedPaper -> edas#Paper -> edas#Document\t \t \t \tekaw#Evaluated_Paper\tekaw#Evaluated_Paper -> ekaw#Assigned_Paper -> ekaw#Submitted_Paper -> ekaw#Paper -> ekaw#Document\t \t \t \t0.716',
#  'iasted#Tutorial_speaker\tiasted#Tutorial_speaker -> iasted#Author -> iasted#Speaker -> iasted#Delegate -> iasted#Person\t \tiasted#speak_in -> iasted#Conference_hall\t \tsigkdd#Speaker\tsigkdd#Speaker -> sigkdd#Person\t \tsigkdd#presentationed_by -> sigkdd#Document, sigkdd#presentation -> sigkdd#Document\t \t0.716',
#  'cmt#Administrator\tcmt#Administrator -> cmt#User -> cmt#Person\t \tcmt#paperAssignmentToolsRunBy -> cmt#Conference, cmt#enterReviewCriteria -> cmt#Conference, cmt#runPaperAssignmentTools -> cmt#Conference, cmt#enableVirtualMeeting -> cmt#Conference, cmt#virtualMeetingEnabledBy -> cmt#Conference, cmt#detailsEnteredBy -> cmt#Conference\t \tiasted#Tip\tiasted#Tip -> iasted#Money\t \tiasted#is_paid_in -> iasted#Conference_restaurant\t \t0.716',
#  'edas#Paper\tedas#Paper -> edas#Document\t \tedas#isTopicOf -> edas#Topic, edas#hasTopic -> edas#Topic, edas#isWrittenBy -> edas#Author, edas#hasRelatedPaper -> edas#Author, edas#isReviewing -> edas#ConferenceChair, edas#isReviewedBy -> edas#ConferenceChair\t \tekaw#Flyer\tekaw#Flyer -> ekaw#Document\t \tekaw#publisherOf -> ekaw#Organisation\t \t0.716',
#  'conference#Abstract\tconference#Abstract -> conference#Extended_abstract -> conference#Regular_contribution -> conference#Written_contribution -> conference#Conference_contribution -> conference#Conference_document\t \tconference#is_the_1th_part_of -> conference#Presentation, conference#has_an_abstract -> conference#Presentation\t \tekaw#Paper\tekaw#Paper -> ekaw#Document\t \tekaw#presentationOfPaper -> ekaw#Individual_Presentation, ekaw#paperPresentedAs -> ekaw#Individual_Presentation, ekaw#hasReview -> ekaw#Review, ekaw#reviewOfPaper -> ekaw#Review\t \t0.716',
#  'conference#Reviewer\tconference#Reviewer -> conference#Person\t \tconference#belongs_to_reviewers -> conference#Review_expertise, conference#has_a_review_reference_or_expertise -> conference#Review_expertise, conference#belongs_to_reviewers -> conference#Review_preference, conference#has_a_review_reference_or_expertise -> conference#Review_preference\t \tiasted#Delegate\tiasted#Delegate -> iasted#Person\t \tiasted#is_designed_for -> iasted#Deadline, iasted#is_designed_for -> iasted#Registration\t \t0.716',
#  'cmt#ConferenceMember\tcmt#ConferenceMember -> cmt#Person\t \tcmt#hasConferenceMember -> cmt#Conference, cmt#memberOfConference -> cmt#Conference\t \tconference#Tutorial\tconference#Tutorial -> conference#Conference_part\t \tconference#has_tutorials -> conference#Conference_volume\t \t0.716',
#  'cmt#Administrator\tcmt#Administrator -> cmt#User -> cmt#Person\t \tcmt#paperAssignmentToolsRunBy -> cmt#Conference, cmt#enterReviewCriteria -> cmt#Conference, cmt#runPaperAssignmentTools -> cmt#Conference, cmt#enableVirtualMeeting -> cmt#Conference, cmt#virtualMeetingEnabledBy -> cmt#Conference, cmt#detailsEnteredBy -> cmt#Conference\t \tiasted#Session_room\tiasted#Session_room -> iasted#Place\t \tiasted#is_situated_in -> iasted#Conference_building\t \t0.715',
#  'edas#PendingPaper\tedas#PendingPaper -> edas#Paper -> edas#Document\t \t \t \tekaw#Demo_Paper\tekaw#Demo_Paper -> ekaw#Paper -> ekaw#Document\t \t \t \t0.715',
#  'conference#Track\tconference#Track -> conference#Conference_part\t \tconference#has_tracks -> conference#Conference_volume\t \tiasted#Conference_activity\tiasted#Conference_activity -> iasted#Activity\t \tiasted#is_held_in -> iasted#Conference_state, iasted#is_held_in -> iasted#Conference_days, iasted#is_paid_for -> iasted#Registration_fee\t \t0.715',
#  'conference#Conference_proceedings\t \t \tconference#issues -> conference#Publisher, conference#has_a_publisher -> conference#Publisher\tconference#has_a_volume -> conference#int, conference#has_an_ISBN -> conference#string, conference#has_a_name -> conference#string\tiasted#Money\t \t \tiasted#is_paid_with -> iasted#Item, iasted#is_used_for -> iasted#Item, iasted#is_paid_for -> iasted#Item\tiasted#has_amount_of -> iasted#int\t0.714',
#  'edas#Paper\tedas#Paper -> edas#Document\tedas#PublishedPaper, edas#AcceptedPaper, edas#PendingPaper\tedas#isReviewedBy -> edas#SessionChair, edas#isReviewing -> edas#SessionChair, edas#isReviewing -> edas#ConferenceChair\t \tiasted#Author\tiasted#Author -> iasted#Speaker -> iasted#Delegate -> iasted#Person\tiasted#Author_book_proceedings_included, iasted#Lecturer, iasted#Author_cd_proceedings_included\tiasted#give -> iasted#Brief_introduction_for_Session_chair, iasted#is_given_by -> iasted#Brief_introduction_for_Session_chair\t \t0.714',
#  'ekaw#Session\tekaw#Session -> ekaw#Scientific_Event -> ekaw#Event\tekaw#Poster_Session, ekaw#Demo_Session, ekaw#Conference_Session, ekaw#Regular_Session, ekaw#Workshop_Session\tekaw#hasEvent -> ekaw#Individual_Presentation\t \tiasted#Lecture\tiasted#Lecture -> iasted#Conference_activity -> iasted#Activity\tiasted#Session, iasted#Plenary_lecture\tiasted#is_designed_for -> iasted#Listener, iasted#give -> iasted#Speaker\t \t0.714',
#  'cmt#Author\tcmt#Author -> cmt#ConferenceMember -> cmt#Person, cmt#Author -> cmt#User -> cmt#Person\tcmt#Co-author, cmt#AuthorNotReviewer\tcmt#submitPaper -> cmt#Paper, cmt#writePaper -> cmt#Paper, cmt#hasAuthor -> cmt#Paper\t \tconference#Committee_member\tconference#Committee_member -> conference#Person\tconference#Co-chair, conference#Chair\tconference#was_a_member_of -> conference#Committee, conference#has_members -> conference#Committee\t \t0.714',
#  'edas#ActivePaper\tedas#ActivePaper -> edas#Paper -> edas#Document\t \t \t \tekaw#Workshop_Paper\tekaw#Workshop_Paper -> ekaw#Paper -> ekaw#Document\t \t \t \t0.714',
#  'edas#ConferenceChair\tedas#ConferenceChair -> edas#Person\t \tedas#initiates -> edas#Call, edas#isInitiatedBy -> edas#Call, edas#isReviewing -> edas#Paper, edas#isReviewedBy -> edas#Paper\t \tiasted#Conference_state\tiasted#Conference_state -> iasted#State\t \tiasted#is_visited_by -> iasted#Delegate, iasted#is_situated_in -> iasted#Place\t \t0.713',
#  'cmt#PaperFullVersion\tcmt#PaperFullVersion -> cmt#Paper -> cmt#Document\t \t \t \tekaw#Demo_Paper\tekaw#Demo_Paper -> ekaw#Paper -> ekaw#Document\t \t \t \t0.713',
#  'confOf#Scholar\tconfOf#Scholar -> confOf#Person\t \t \t \tekaw#Student\tekaw#Student -> ekaw#Person\t \t \t \t0.713',
#  'conference#Publisher\t \t \tconference#issues -> conference#Conference_proceedings, conference#has_a_publisher -> conference#Conference_proceedings\tconference#has_a_name -> conference#string\tconfOf#Working_event\tconfOf#Working_event -> confOf#Event\t \tconfOf#hasAdministrativeEvent -> confOf#Administrative_event, confOf#hasTopic -> confOf#Topic\tconfOf#has_short_title -> confOf#string, confOf#hasVAT -> confOf#string, confOf#location -> confOf#string, confOf#defaultChoice -> confOf#positiveInteger, confOf#has_title -> confOf#string, confOf#minChoice -> confOf#positiveInteger, confOf#maxChoice -> confOf#positiveInteger\t0.713',
#  ...]

# %%
gt_mappings = [el[:2] for el in gt_mappings]
open("gt_mappings_fn.tsv", "w+").write("\n".join([elem for i,elem in enumerate(false_negatives) if (elem.split("\t")[0], elem.split("\t")[5]) in gt_mappings]))
# Out:
# 22695

# %%
neighbours_dicts = {}
for key in neighbours_dicts_conf:
    neighbours_dicts[key] = neighbours_dicts_conf[key]
for key in neighbours_dicts_german:
    neighbours_dicts[key] = neighbours_dicts_german[key]
max_paths = np.max([[len(nbr_type) for nbr_type in elem] for elem in neighbours_dicts.values()])
max_pathlen = np.max(flatten([flatten([[len(path) for path in nbr_type] for nbr_type in elem]) for elem in neighbours_dicts.values()]), axis=0)
max_types = np.max([len([nbr_type for nbr_type in elem if nbr_type]) for elem in neighbours_dicts.values()])

# %%
f = open("Input/data_conf_oaei_german_aml.pkl", "wb")
pickle.dump([data_conf, data_german, aml_data, emb_indexer, emb_indexer_inv, emb_vals, neighbours_dicts, max_paths, max_pathlen, max_types, ontologies_in_alignment], f)

# %%
data_conf, data_german, _, emb_indexer, emb_indexer_inv, emb_vals, neighbours_dicts, max_paths, max_pathlen, max_types, ontologies_in_alignment = pickle.load(open("Input/data_conf_oaei_german_aml_thresh.pkl", "rb"))
pickle.dump([data_conf, data_german, data_logmap, emb_indexer, emb_indexer_inv, emb_vals, neighbours_dicts, max_paths, max_pathlen, max_types, ontologies_in_alignment], open("data_conf_oaei_german_logmap_thresh.pkl", "wb"))

# %%
f = open("Input/data_conf_oaei_german_bagofnbrs.pkl", "wb")
# pickle.dump([data_conf, data_german, emb_indexer_german, emb_indexer_inv_german, emb_vals_german, emb_indexer_conf, emb_indexer_inv_conf, emb_vals_conf, neighbours_dicts_german, neighbours_dicts_conf, max_paths_german, max_pathlen_german, max_types_german, max_paths_conf, max_pathlen_conf, max_types_conf, ontologies_in_alignment], f)
pickle.dump([data_conf, data_german, emb_indexer_german, emb_indexer_inv_german, emb_vals_german, emb_indexer_conf, emb_indexer_inv_conf, emb_vals_conf, neighbours_dicts, max_paths, max_pathlen, max_types, ontologies_in_alignment], f)

# %%
data_conf, data_german, aml_data, emb_indexer, emb_indexer_inv, emb_vals, _, _, _, _, ontologies_in_alignment = pickle.load(open("Input/data_conf_oaei_german_aml.pkl", "rb"))
f = open("Input/data_conf_oaei_german_aml_bagofnbrs.pkl", "wb")
pickle.dump([data_conf, data_german, aml_data, emb_indexer, emb_indexer_inv, emb_vals, neighbours_dicts, max_paths, max_pathlen, max_types, ontologies_in_alignment], f)

# %%
def path_to_root(elem, ont_mappings, curr = [], rootpath=[]):
    curr.append(elem)
    if elem not in ont_mappings or not ont_mappings[elem]:
        rootpath.append(curr)
        return
    for node in ont_mappings[elem]:
        curr_orig = deepcopy(curr)
        _ = path_to_root(node, ont_mappings, curr, rootpath)
        curr = curr_orig
    return rootpath

def get_one_hop_neighbours(ont, K=1):
    ont_obj = Ontology("conference_ontologies/" + ont + ".owl")
    triples = ont_obj.get_triples()
    entities = [(a,b) for (a,b,c,d) in triples]
    neighbours_dict = {elem: [[] for i in range(4)] for elem in list(set(flatten(entities)))}
    print (ont)
    for (e1, e2, p, d) in triples:
        if e1==e2:
            continue
        if d == "Object Property":
            neighbours_dict[e1][2].append(e2)
            neighbours_dict[e2][2].append(e1)
        elif d == "Datatype Property":
            neighbours_dict[e1][3].append(e2)
            neighbours_dict[e2][3].append(e1)
        elif d == "Subclass":
            neighbours_dict[e2][1].append(e1)
        else:
            print ("Error wrong value of d: ", d)
    
    rootpath_dict = ont_obj.parents_dict
    rootpath_dict_new = {}
    for elem in rootpath_dict:
        rootpath_dict_new[elem] = path_to_root(elem, rootpath_dict, [], [])
    ont = ont.split("/")[-1].split(".")[0]

    
    for entity in neighbours_dict:
        neighbours_dict[entity][1] = [neighbours_dict[entity][1]]
        neighbours_dict[entity][2] = [neighbours_dict[entity][2]]
        neighbours_dict[entity][3] = [neighbours_dict[entity][3]]
        if entity in rootpath_dict_new and len(rootpath_dict_new[entity]) > 0:
            neighbours_dict[entity][0].extend(rootpath_dict_new[entity])
        else:
            continue
    
#     prop_triples = ont_obj.get_triples(subclass_of=False)
#     neighbours_dict_props = {c: [c] for a,b,c in prop_triples}
#     for e1, e2, p in prop_triples:
#         neighbours_dict_props[p].extend([e1, e2])

    #neighbours_dict = {**neighbours_dict, **neighbours_dict_props}
    
    # for elem in ont_obj.get_entities() + ont_obj.get_object_properties() + ont_obj.get_data_properties():
    #     if elem not in neighbours_dict:
    #         neighbours_dict[elem] = [elem]

#     neighbours_dict = {elem: [key[:1] + sorted(list(set(key[1:]))) for key in neighbours_dict[elem]]
#                        for elem in neighbours_dict}
#     neighbours_dict = {el: neighbours_dict[el][:23] for el in neighbours_dict if len( neighbours_dict[el]) > 2}
#     ont = ont.split("/")[-1].split(".")[0]
    neighbours_dict = {ont + "#" + el: [OrderedSet([tuple([ont + "#" + node for node in path]) for path in nbr_type])
                                        for nbr_type in neighbours_dict[el]] 
                       for el in neighbours_dict}
    neighbours_dict = {el: [[list(path) for path in nbr_type] for nbr_type in neighbours_dict[el]]
                       for el in neighbours_dict}
    return neighbours_dict

# neighbours_dicts = {ont.split("/")[-1].split(".")[0]: get_one_hop_neighbours(ont) for ont in list(set(flatten(ontologies_in_alignment)))}
neighbours_dicts = {}
for ont in list(set(flatten(ontologies_in_alignment))):
    neighbours_dicts = {**neighbours_dicts, **get_one_hop_neighbours(ont)}
max_paths = np.max([[len(nbr_type) for nbr_type in elem] for elem in neighbours_dicts.values()])
max_pathlen = np.max(flatten([flatten([[len(path) for path in nbr_type] for nbr_type in elem]) for elem in neighbours_dicts.values()]), axis=0)
neighbours_dicts_lenpadded = {elem: [[path + ["<UNK>" for i in range(max_pathlen -len(path))] for path in nbr_type]
                                for nbr_type in neighbours_dicts[elem]] for elem in neighbours_dicts}
neighbours_dicts_pathpadded = {elem: [nbr_type + [["<UNK>" for j in range(max_pathlen)] for i in range(max_paths - len(nbr_type))]
                                for k,nbr_type in enumerate(neighbours_dicts_lenpadded[elem])] for elem in neighbours_dicts_lenpadded}
neighbours_dicts_pathpadded = {elem: np.array(neighbours_dicts_pathpadded[elem]) for elem in neighbours_dicts_pathpadded}
# # # ontologies_in_alignment_rev = [[el.split("/")[1].split(".")[0] for el in ont] for ont in ontologies_in_alignment]
# # f = open("data_aml_uniqpath.pkl", "wb")
# # pickle.dump([data, aml_data, emb_indexer, emb_indexer_inv, emb_vals, gt_mappings, neighbours_dicts_pathpadded, ontologies_in_alignment], f)
# # # # # neighbours_dicts
# Out:
# sigkdd
# edas
# list index out of range
# confOf
# conference
# cmt
# iasted
# ekaw

# %%
max_paths, max_pathlen
# Out:
# (2, 38)

# %%
sorted(Counter(flatten([[len(nbr_type) for nbr_type in elem] for elem in neighbours_dicts.values()])).items())
# Out:
# [(0, 9808),
#  (1, 4062),
#  (2, 257),
#  (3, 151),
#  (4, 93),
#  (5, 56),
#  (6, 43),
#  (7, 39),
#  (8, 17),
#  (9, 15),
#  (10, 9),
#  (11, 6),
#  (12, 7),
#  (13, 7),
#  (15, 5),
#  (16, 3),
#  (17, 3),
#  (18, 1),
#  (19, 2),
#  (20, 4),
#  (21, 6),
#  (22, 4),
#  (23, 1),
#  (24, 2),
#  (26, 3),
#  (38, 1),
#  (42, 1),
#  (48, 1),
#  (49, 1)]

# %%
_, data_conf, emb_indexer_conf, emb_indexer_inv_conf, emb_vals_conf, gt_mappings_conf, _, ontologies_in_alignment_conf = pickle.load(open("../Input/data_aml.pkl", "rb"))
pickle.dump([aml_data, data_conf, emb_indexer_conf, emb_indexer_inv_conf, emb_vals_conf, gt_mappings_conf, neighbours_dicts_pathpadded, ontologies_in_alignment_conf], open("Input/data_conf_oaei_aml_bagofnbrs.pkl", "wb"))

# %%
# max_paths
def count_non_unk(elem):
    return len([l for l in elem if list(l)!=["<UNK>" for i in range(6)]])
sorted(Counter(flatten([[len(nbr_type) for nbr_type in elem] for elem in neighbours_dicts.values()])).items())
# Out:
# [(0, 9808),
#  (1, 4062),
#  (2, 257),
#  (3, 151),
#  (4, 93),
#  (5, 56),
#  (6, 43),
#  (7, 39),
#  (8, 17),
#  (9, 15),
#  (10, 9),
#  (11, 6),
#  (12, 7),
#  (13, 7),
#  (15, 5),
#  (16, 3),
#  (17, 3),
#  (18, 1),
#  (19, 2),
#  (20, 4),
#  (21, 6),
#  (22, 4),
#  (23, 1),
#  (24, 2),
#  (26, 3),
#  (38, 1),
#  (42, 1),
#  (48, 1),
#  (49, 1)]

# %%
output = """
Output_att12_1_0.6075_conf_oaei_german_aml.txt:Final Results: [0.72243346 0.62295082 0.66901408 0.64059339 0.70007369]

Output_att18_1_0.6075_conf_oaei_german_aml.txt:Final Results: [0.66013072 0.66229508 0.66121113 0.66186107 0.66056246]

Output_att18_3_0.6075_conf_oaei_german_aml.txt:Final Results: [0.73895582 0.60327869 0.66425993 0.62627638 0.70714835]

Output_att18_6_0.6075_conf_oaei_german_aml.txt:Final Results: [0.73451327 0.5442623  0.6252354  0.57399723 0.68651778]

Output_att3_1_0.6075_conf_oaei_german_aml.txt:Final Results: [0.71698113 0.62295082 0.66666667 0.63973064 0.6959707 ]

Output_att3_3_0.6075_conf_oaei_german_aml.txt:Final Results: [0.732      0.6        0.65945946 0.62244898 0.70114943]

Output_att3_4_0.6075_conf_oaei_german_aml.txt:Final Results: [0.72623574 0.62622951 0.67253521 0.64396494 0.70375829]

Output_att5_1_0.6075_conf_oaei_german_aml.txt:Final Results: [0.76237624 0.50491803 0.60749507 0.54149086 0.6918239 ]

Output_att5_3_0.6075_conf_oaei_german_aml.txt:Final Results: [0.75732218 0.59344262 0.66544118 0.62028787 0.71768438]

Output_att5_4_0.6075_conf_oaei_german_aml.txt:Final Results: [0.724      0.59344262 0.65225225 0.61564626 0.69348659]

Output_att7_1_0.6075_conf_oaei_german_aml.txt:Final Results: [0.7188755  0.58688525 0.64620939 0.609258   0.68793236]

Output_att7_3_0.6075_conf_oaei_german_aml.txt:Final Results: [0.75565611 0.54754098 0.63498099 0.57945871 0.70227082]

Output_att7_3_0.6075_conf_oaei_german_aml.txt:Final Results: [0.72265625 0.60655738 0.65953654 0.62669377 0.69601204]

Output_att7_4_0.6075_conf_oaei_german_aml.txt:Final Results: [0.61490683 0.64918033 0.63157895 0.64202335 0.62146893]

Output_att7_6_0.6075_conf_oaei_german_aml.txt:Final Results: [0.72       0.59016393 0.64864865 0.6122449  0.68965517]

Output_att12_1_0.612_conf_oaei_german_aml.txt:Final Results: [0.70454545 0.60983607 0.65377856 0.62668464 0.68332109]

Output_att18_1_0.612_conf_oaei_german_aml.txt:Final Results: [0.69960474 0.58032787 0.6344086  0.60081466 0.67198178]

Output_att18_3_0.612_conf_oaei_german_aml.txt:Final Results: [0.70212766 0.64918033 0.6746167  0.65912117 0.69085834]

Output_att18_6_0.612_conf_oaei_german_aml.txt:Final Results: [0.73895582 0.60327869 0.66425993 0.62627638 0.70714835]

Output_att3_1_0.612_conf_oaei_german_aml.txt:Final Results: [0.77       0.50491803 0.60990099 0.54225352 0.69683258]

Output_att3_3_0.612_conf_oaei_german_aml.txt:Final Results: [0.75117371 0.52459016 0.61776062 0.55826936 0.69144339]

Output_att3_4_0.612_conf_oaei_german_aml.txt:Final Results: [0.72373541 0.60983607 0.66192171 0.62965471 0.69767442]

Output_att5_1_0.612_conf_oaei_german_aml.txt:Final Results: [0.76168224 0.53442623 0.62813102 0.56834031 0.70198105]

Output_att5_3_0.612_conf_oaei_german_aml.txt:Final Results: [0.69056604 0.6        0.64210526 0.61616162 0.67032967]

Output_att5_4_0.612_conf_oaei_german_aml.txt:Final Results: [0.68503937 0.5704918  0.62254025 0.59023066 0.65859198]

Output_att7_1_0.612_conf_oaei_german_aml.txt:Final Results: [0.77777778 0.55081967 0.64491363 0.58495822 0.71856287]

Output_att7_3_0.612_conf_oaei_german_aml.txt:Final Results: [0.76605505 0.54754098 0.63862333 0.58066759 0.70943076]

Output_att7_3_0.612_conf_oaei_german_aml.txt:Final Results: [0.70866142 0.59016393 0.64400716 0.61058345 0.68130204]

Output_att7_4_0.612_conf_oaei_german_aml.txt:Final Results: [0.75980392 0.50819672 0.60903733 0.54424157 0.69134701]

Output_att7_6_0.612_conf_oaei_german_aml.txt:Final Results: [0.67142857 0.61639344 0.64273504 0.62666667 0.65964912]

Output_att12_1_0.735_conf_oaei_german_aml.txt:Final Results: [0.74248927 0.56721311 0.64312268 0.59532003 0.69927243]

Output_att13_4_0.735_conf_oaei_german_aml.txt:Final Results: [0.73390558 0.56065574 0.63568773 0.58843772 0.69118836]

Output_att13_5_0.735_conf_oaei_german_aml.txt:Final Results: [0.73251029 0.58360656 0.64963504 0.60833903 0.69694597]

Output_att13_8_0.735_conf_oaei_german_aml.txt:Final Results: [0.71272727 0.64262295 0.67586207 0.65551839 0.6975089 ]

Output_att18_1_0.735_conf_oaei_german_aml.txt:Final Results: [0.7        0.59672131 0.64424779 0.61486486 0.67657993]

Output_att18_3_0.735_conf_oaei_german_aml.txt:Final Results: [0.68265683 0.60655738 0.64236111 0.620389   0.66594672]

Output_att18_6_0.735_conf_oaei_german_aml.txt:Final Results: [0.73662551 0.58688525 0.65328467 0.61175666 0.70086139]

Output_att21_1_0.735_conf_oaei_german_aml.txt:Final Results: [0.6962963  0.61639344 0.65391304 0.63087248 0.67870036]

Output_att21_5_0.735_conf_oaei_german_aml.txt:Final Results: [0.69144981 0.60983607 0.64808362 0.62458026 0.67342505]

Output_att3_1_0.735_conf_oaei_german_aml.txt:Final Results: [0.72961373 0.55737705 0.63197026 0.58499656 0.68714632]

Output_att3_3_0.735_conf_oaei_german_aml.txt:Final Results: [0.68904594 0.63934426 0.66326531 0.64870259 0.67849687]

Output_att3_4_0.735_conf_oaei_german_aml.txt:Final Results: [0.74152542 0.57377049 0.64695009 0.60096154 0.70056045]

Output_att5_1_0.735_conf_oaei_german_aml.txt:Final Results: [0.7398374  0.59672131 0.66061706 0.6207367  0.70597362]

Output_att5_3_0.735_conf_oaei_german_aml.txt:Final Results: [0.76635514 0.53770492 0.63198459 0.57182706 0.70628768]

Output_att5_4_0.735_conf_oaei_german_aml.txt:Final Results: [0.73221757 0.57377049 0.64338235 0.59972584 0.69389374]

Output_att7_1_0.735_conf_oaei_german_aml.txt:Final Results: [0.66542751 0.58688525 0.62369338 0.60107455 0.6480811 ]

Output_att7_3_0.735_conf_oaei_german_aml.txt:Final Results: [0.7265625  0.60983607 0.6631016  0.6300813  0.69977427]

Output_att7_3_0.735_conf_oaei_german_aml.txt:Final Results: [0.69548872 0.60655738 0.64798599 0.62247645 0.67567568]

Output_att7_6_0.735_conf_oaei_german_aml.txt:Final Results: [0.70869565 0.53442623 0.60934579 0.56206897 0.66530612]
"""
def parse_line(line):
    
    max_paths, max_pathlen, threshold = line[10:].split("_")[:3]
    a = "VeeAlign (max_path={}, max_pathlen={}, threshold={})(self+self german+aml two-step)".format(max_paths, max_pathlen, threshold)
    content = a + "\t" + "\t".join(line.split("[")[1].split("]")[0].split())
    return content
    
open("results.tsv", "w+").write("\n".join([parse_line(l) for l in output.split("\n") if l]))
# Out:
# 6827

# %%
pickle.load(open("Input/da")
# Out:
# array([1., 2., 3.])

# %%
def check_best_performance():
    output_file = "Results/Output_att*conf_oaei_german_aml.txt"
    results_lines = [[l for l in open(file).read().split("\n") if "Final Results:" in l] for file in glob.glob(output_file)]
    results_lines = [line[0] for line in results_lines if line]
    results_lines = [line.split("[")[1].split("]")[0].split(" ") for line in results_lines]
    results_lines = [float([value for value in line if value][2]) for line in results_lines]
    return max(results_lines)

check_best_performance()
# Out:
# 0.68292683

# %%
c = torch.randn((10,4,22,6,512))
b = torch.randn((10,4,1,6,512))
d = b * c

# %%
e = torch.bmm(c.permute(0,1,3,4,2).reshape(-1, 22, 1), b.permute(0,1,3,4,2).reshape(-1, 1, 1)).squeeze(-1).reshape(-1,4,6,512,22).permute(0,1,4,2,3)

# %%
from gensim.models import KeyedVectors
word_vectors = KeyedVectors.load("~/", mmap='r')
# Out:
# (tensor([[[[-2.6975e-02,  1.1427e+00,  4.1698e-01,  ..., -8.3755e+00,
#             -4.7765e-01, -2.1633e-01],
#            [ 2.8020e-01, -6.6962e-01,  1.4016e+00,  ...,  7.5675e-04,
#              2.2802e-01, -1.7932e+00],
#            [-1.1675e-01,  2.9058e-02,  1.4350e-01,  ..., -1.8113e+00,
#             -9.6346e-01,  2.6943e+00],
#            [ 9.3339e-02,  5.5481e-01,  5.7394e-01,  ...,  6.9919e-01,
#             -3.4617e-01,  2.7778e-01],
#            [-1.4753e-01, -4.3234e-01,  1.7809e+00,  ..., -1.4585e+00,
#             -7.7736e-01,  1.1985e-01],
#            [-5.5448e-01,  8.2052e-01,  1.4681e-03,  ..., -3.1119e-02,
#             -1.6508e-01, -6.0103e-01]],
#
#           [[ 1.1321e-01,  1.9631e-01,  1.0589e+00,  ...,  4.4958e+00,
#              4.9575e-02,  2.7624e-01],
#            [-2.5041e-01,  1.0904e+00,  1.4865e+00,  ..., -3.6319e-01,
#             -4.8349e-01,  6.8312e-01],
#            [-2.0786e+00,  5.2171e-03, -1.3269e-02,  ...,  1.5515e-01,
#              1.1037e+00, -2.8357e-01],
#            [-1.6813e-01, -3.7349e-01,  1.3249e+00,  ..., -3.1635e-02,
#             -2.6777e-01, -3.5144e-01],
#            [-4.7156e-02,  6.9693e-01, -3.7944e+00,  ...,  8.2782e-01,
#             -3.4735e+00, -1.5640e+00],
#            [ 1.0004e-01,  8.5018e-01, -1.1673e-01,  ...,  4.3758e-01,
#              4.1557e-01,  1.9148e-01]],
#
#           [[ 8.4804e-02, -1.9090e-01,  3.3380e-01,  ..., -3.4426e+00,
#              3.0574e-02,  2.3107e-01],
#            [ 2.2145e-01, -2.3321e+00,  1.4031e+00,  ..., -3.7283e-01,
#             -1.6912e+00,  9.2597e-01],
#            [-1.5250e+00, -2.3280e-02,  2.4597e-01,  ...,  7.9027e-01,
#             -9.4733e-01,  8.7970e-01],
#            [ 3.8091e-02, -3.8998e-01, -2.2662e-01,  ..., -3.3237e-02,
#              5.0703e-01, -1.2149e-01],
#            [-1.1305e-02,  5.8724e-02,  1.0739e+00,  ...,  7.2756e-01,
#             -1.0941e+00, -2.7587e-01],
#            [-6.4559e-03, -1.2770e+00,  1.9988e-01,  ..., -1.4452e-01,
#              3.9880e-01,  5.1171e-01]],
#
#           ...,
#
#           [[ 9.3022e-02, -1.3080e+00,  4.3844e-01,  ...,  6.7089e+00,
#             -7.4844e-02, -1.0296e-01],
#            [ 5.1513e-01, -1.5177e+00, -2.4742e+00,  ..., -1.0126e+00,
#              9.4409e-01, -1.7644e+00],
#            [ 1.5795e+00, -1.2499e-02,  3.1105e-01,  ...,  2.4935e-01,
#             -2.5942e+00,  4.2571e-01],
#            [-4.3305e-02,  7.7402e-01,  4.8391e-02,  ..., -1.7993e-02,
#             -3.8225e-01,  1.6393e-01],
#            [-1.2804e-02, -1.1867e-01,  1.6239e+00,  ..., -2.4819e+00,
#              6.3592e-01, -6.5775e-01],
#            [-6.8280e-01,  1.6357e-01,  2.8135e-01,  ..., -4.5650e-01,
#              5.8016e-01,  3.7909e-01]],
#
#           [[ 2.7604e-01, -5.2317e-01, -3.5259e-01,  ..., -4.3182e+00,
#             -1.0420e-02,  2.3876e-01],
#            [-8.2358e-01,  1.2819e+00,  3.2237e+00,  ..., -1.4079e+00,
#              8.2605e-01, -3.5490e+00],
#            [ 7.2705e-01,  1.0179e-02,  4.1682e-02,  ..., -1.2930e+00,
#             -1.0318e-02, -9.7465e-01],
#            [ 7.1487e-02, -5.2067e-01,  1.9646e-01,  ..., -6.5025e-02,
#              3.0096e-01,  2.5064e-01],
#            [-9.5270e-03, -2.6696e-01,  1.2718e+00,  ...,  1.3878e-01,
#              8.9478e-01,  2.6727e-01],
#            [-1.0195e-01,  2.9243e-01,  5.7825e-02,  ..., -1.4137e-01,
#              9.0536e-01,  8.3997e-01]],
#
#           [[-3.7994e-01, -3.5905e-01,  8.5735e-01,  ..., -2.2555e+00,
#              2.9540e-01,  1.4439e-01],
#            [-2.5761e-01,  7.6109e-01,  2.1357e+00,  ...,  3.2990e-01,
#              8.4556e-01,  1.9200e+00],
#            [-1.3175e+00,  2.9954e-02,  1.1293e-01,  ..., -1.1721e+00,
#              3.4716e-01, -3.2099e+00],
#            [-9.7234e-02,  3.1779e-01,  2.1693e-01,  ..., -6.0591e-01,
#             -1.5350e-01, -3.5609e-01],
#            [ 2.7051e-02, -2.9286e-01,  1.6291e-01,  ...,  2.3671e-01,
#              1.4252e-01, -8.5905e-01],
#            [ 4.1113e-01, -9.3422e-01,  5.5501e-02,  ..., -3.9380e-02,
#              2.7077e-01,  2.4971e-02]]],
#
#
#          [[[-3.9128e-01,  3.0329e-01,  1.7438e+00,  ..., -5.1570e-02,
#              2.7041e-01,  1.1142e-01],
#            [ 9.7906e-01, -6.6916e-01,  1.5667e-01,  ..., -1.1040e+00,
#             -1.0028e+00, -3.1761e-01],
#            [ 1.3956e-02,  4.7639e-01, -3.4994e-01,  ...,  4.4730e-01,
#              5.8166e-02,  3.7031e+00],
#            [-6.1185e-01, -2.9059e-02, -2.5640e+00,  ..., -4.8810e-01,
#              7.2237e-02, -3.3621e-02],
#            [ 1.1702e+00, -5.4646e-01,  4.0832e-01,  ..., -3.3780e-01,
#             -3.6306e-02, -2.0265e-01],
#            [-3.4012e-01, -8.7453e-01,  6.7431e-02,  ..., -2.4516e-01,
#              1.1414e+00, -8.6555e-01]],
#
#           [[-1.4254e-01,  6.6979e-02,  5.7138e-01,  ..., -2.7770e-02,
#             -2.1318e-01, -2.1749e-01],
#            [ 8.6064e-01,  7.9722e-01,  5.1855e-01,  ...,  3.1673e-01,
#              1.1649e-01, -1.3670e-01],
#            [-6.5740e-01, -2.4898e+00, -6.6839e-02,  ...,  8.8526e-01,
#              5.8112e-02,  2.1320e-01],
#            [-2.1838e+00,  1.2566e-01,  2.0784e+00,  ...,  1.1584e-03,
#              1.7045e-01,  5.8616e-02],
#            [-3.7954e-01,  6.8714e-01, -2.4719e-01,  ..., -2.9393e-01,
#              1.1800e+00,  5.9116e-01],
#            [-3.4312e-01, -3.4138e-01, -1.7100e-01,  ...,  2.5343e-02,
#             -1.2067e-01, -8.6847e-01]],
#
#           [[-1.8238e-01,  2.5802e-01, -1.7092e-01,  ..., -2.6656e-02,
#              2.8145e-02, -9.4126e-02],
#            [ 2.5779e+00, -4.7903e-01, -1.0201e-01,  ...,  2.4409e+00,
#              2.5932e-01, -2.8913e-01],
#            [ 3.5668e-01,  8.4694e-01,  3.5863e+00,  ..., -1.1736e+00,
#             -7.2177e-02, -2.4034e+00],
#            [-1.8247e+00,  4.7933e-03, -4.0635e-01,  ..., -2.3482e-01,
#             -5.0712e-03,  8.8910e-03],
#            [-1.8990e+00, -1.4103e+00, -1.3095e-01,  ...,  1.3795e+00,
#             -7.5172e-01, -1.6649e-01],
#            [-1.5989e-01, -8.0318e-02,  1.2440e-01,  ..., -3.1794e-01,
#             -5.3846e-03, -1.6965e+00]],
#
#           ...,
#
#           [[-4.1347e-01, -6.1763e-02, -1.9373e+00,  ...,  1.7914e-02,
#              1.5746e-01,  2.1768e-02],
#            [ 1.0763e+00, -7.5147e-01, -2.7873e-01,  ..., -1.9096e+00,
#             -2.2879e-01,  1.5889e-01],
#            [ 1.6303e-01, -9.7796e-01, -1.6298e+00,  ...,  2.7444e-02,
#              2.5554e-01, -3.8790e+00],
#            [-2.0949e+00,  4.0024e-01,  5.5578e-01,  ..., -9.9825e-02,
#             -1.3430e-02, -1.2625e-01],
#            [ 9.7021e-01,  3.7204e-01,  5.8349e-02,  ...,  7.2699e-01,
#             -4.6000e-01,  7.1423e-01],
#            [ 5.6306e-02, -1.0799e+00, -1.7901e-01,  ..., -1.2894e-01,
#             -1.6473e+00,  4.7823e-01]],
#
#           [[-1.1248e+00,  2.2253e-01,  7.8126e-01,  ...,  3.7603e-02,
#              6.1945e-02, -1.4676e-01],
#            [-3.3485e-01,  9.5780e-01, -7.5927e-01,  ..., -1.6628e-01,
#              1.0203e+00,  9.1956e-01],
#            [-2.7452e-01,  8.7849e-01,  4.8874e-01,  ..., -1.1384e-01,
#             -5.4279e-02, -1.8832e+00],
#            [-1.5225e+00,  1.0040e+00,  1.8975e+00,  ..., -8.2773e-01,
#              1.7396e-01,  1.2552e-01],
#            [-2.9785e-01, -1.7266e-01, -2.0563e-02,  ..., -8.7540e-01,
#              4.1189e-01,  1.8740e-01],
#            [ 6.9159e-02, -6.7810e-01, -6.8640e-02,  ..., -2.1745e-01,
#              4.1672e-01,  2.4365e-01]],
#
#           [[ 9.9051e-01,  1.2811e-01,  1.3409e+00,  ...,  2.9462e-02,
#             -8.4088e-03,  7.1865e-03],
#            [-8.5172e-01,  1.0129e-01,  4.4222e-01,  ...,  2.2883e+00,
#             -6.4905e-01,  5.2368e-01],
#            [ 1.0729e+00,  9.8708e-01, -1.6862e-01,  ...,  7.0265e-01,
#             -5.9329e-02,  5.3208e+00],
#            [ 1.4086e+00,  2.1408e-01,  1.4659e+00,  ...,  2.1148e+00,
#             -2.9359e-02,  2.8720e-02],
#            [ 6.2179e-01, -3.4007e-01, -2.6456e-01,  ..., -3.3377e-01,
#              4.7947e-01,  6.9489e-01],
#            [ 1.1050e-01,  3.0068e-01,  7.1646e-01,  ...,  1.0166e-01,
#              1.1267e+00, -1.1611e+00]]],
#
#
#          [[[-1.2776e+00,  6.6240e-01, -7.5534e-01,  ...,  3.1367e+00,
#             -1.0594e+00,  2.6497e-03],
#            [-3.2259e-01, -1.9115e-02, -2.7109e+00,  ...,  8.0087e-02,
#              1.7099e-02,  5.2779e-01],
#            [ 2.0627e+00, -1.8393e+00,  1.3044e-01,  ..., -2.5227e-01,
#             -1.4063e-02,  6.3648e-01],
#            [ 3.9800e-01,  2.9768e-01, -2.4887e+00,  ..., -2.8875e-01,
#              1.0805e+00, -1.8065e-01],
#            [-1.5657e+00, -1.6136e+00,  1.1761e-01,  ...,  2.2830e+00,
#              4.7534e-01, -2.9714e-01],
#            [ 3.3093e-01, -9.3196e-01,  1.0973e-01,  ..., -3.9303e-01,
#             -2.4432e-01, -1.9283e-03]],
#
#           [[ 1.6752e+00,  9.8728e-01,  1.3048e+00,  ...,  2.4546e+00,
#              8.9778e-01,  5.9942e-02],
#            [-1.1321e+00, -8.3169e-02, -1.0655e+00,  ..., -5.3610e-02,
#              3.0933e-02,  1.6996e+00],
#            [ 1.3572e+00,  3.5087e+00, -5.6493e-01,  ...,  1.5630e-01,
#              1.1401e-01,  8.7724e-02],
#            [ 1.8826e+00, -8.0536e-01, -6.4915e-01,  ..., -6.0300e-01,
#              4.2268e-01, -1.0250e+00],
#            [ 1.2450e+00, -3.1476e-03, -7.2572e-02,  ...,  4.9648e+00,
#              2.4514e-01, -8.4797e-01],
#            [-5.2386e-01,  2.2547e-01, -1.7916e-02,  ..., -1.3301e-01,
#             -4.7206e-02, -4.0686e-03]],
#
#           [[ 1.0815e+00, -1.0988e-02, -7.6541e-01,  ...,  5.6168e-01,
#              1.3622e+00,  3.0586e-02],
#            [ 3.2631e-01, -1.2213e-01, -1.0583e+00,  ..., -7.7928e-02,
#              3.5818e-01,  2.6620e+00],
#            [-1.6855e+00, -1.9894e+00, -4.5614e-02,  ...,  1.2573e-01,
#             -1.8470e-02,  1.2172e-01],
#            [ 2.6492e-01, -4.6880e-01, -6.2964e-01,  ...,  1.5370e+00,
#             -7.7000e-01, -2.8234e-01],
#            [-7.7528e-01,  1.9819e+00, -5.0842e-02,  ...,  1.7884e+00,
#             -7.5354e-01, -5.6921e-01],
#            [ 2.2637e-01, -2.1493e-01, -4.0555e-01,  ...,  9.7193e-01,
#              2.7136e-01, -5.0617e-03]],
#
#           ...,
#
#           [[-1.6761e+00, -6.9634e-01, -2.9371e+00,  ..., -4.4699e+00,
#              2.8774e-01,  3.1593e-02],
#            [ 7.5001e-01, -1.7541e-01,  2.4237e+00,  ..., -2.8136e-02,
#             -4.8825e-01,  1.2874e+00],
#            [ 6.3596e-01, -7.1867e-01, -6.9524e-01,  ..., -1.6781e+00,
#             -2.1677e-02, -1.5335e+00],
#            [-2.5790e+00, -1.0584e-02, -1.0483e+00,  ..., -1.7448e+00,
#             -1.4666e+00,  2.3281e-01],
#            [-9.5808e-01,  2.9462e-01, -6.1532e-02,  ...,  1.8991e-01,
#             -6.3903e-01, -4.4545e-01],
#            [ 1.4676e+00, -3.7433e-01, -6.6621e-01,  ...,  6.9258e-01,
#              3.5610e-01, -1.0788e-02]],
#
#           [[ 2.5123e+00, -7.5566e-01,  1.1096e-01,  ...,  1.3473e-01,
#             -2.2708e-01, -3.9094e-02],
#            [ 6.5271e-01, -2.0388e-02, -2.1433e+00,  ...,  4.3907e-02,
#             -7.5354e-02,  7.4683e-01],
#            [ 6.7876e+00, -2.3339e+00, -2.8033e-01,  ..., -2.1698e+00,
#              1.4436e-01, -4.9290e-01],
#            [ 6.1602e-01, -5.6363e-01,  1.3801e+00,  ..., -4.0051e-01,
#             -7.5461e-01,  5.7494e-01],
#            [-3.0167e-02,  3.6551e-01,  6.7787e-02,  ...,  4.4475e-01,
#              3.8094e-01,  7.7020e-01],
#            [-1.1885e+00, -2.8034e-01, -1.4673e+00,  ..., -2.0912e+00,
#              6.1728e-01, -6.6052e-03]],
#
#           [[ 1.7005e-01, -9.5639e-01,  8.3401e-01,  ...,  4.1265e+00,
#             -4.8697e-01,  1.5795e-02],
#            [-2.3039e-01,  7.2300e-02, -1.5875e+00,  ...,  6.1212e-03,
#              6.0843e-01,  1.8745e+00],
#            [-2.4100e+00, -3.2166e+00, -7.1851e-01,  ...,  4.6821e-01,
#             -1.7675e-01,  9.0657e-02],
#            [ 2.4667e+00, -1.4381e-01, -2.9427e-01,  ..., -2.1643e+00,
#              6.7028e-01, -1.2055e+00],
#            [-7.2312e-02, -2.6526e+00,  2.7557e-02,  ...,  2.0110e-01,
#              1.1650e-01,  2.1880e-01],
#            [ 3.8107e-01,  6.2959e-01,  1.4402e+00,  ..., -3.3811e-01,
#              2.7137e-02, -1.1046e-02]]],
#
#
#          [[[-1.9799e-01, -1.0474e+00,  3.9488e-01,  ..., -5.9977e-01,
#              3.5057e-01, -6.1720e-02],
#            [ 1.3887e+00,  1.6019e-02,  6.0418e-02,  ..., -9.7386e-02,
#             -5.5413e-01, -3.6288e-01],
#            [ 6.5327e-02,  9.7353e-01,  9.7260e-01,  ...,  2.4383e+00,
#             -2.1460e-01, -2.7932e-02],
#            [-1.0480e+00, -1.0425e-01,  2.9479e+00,  ...,  3.2914e-02,
#             -5.4207e-01,  2.7993e-01],
#            [-3.8733e-02,  3.6474e-02, -4.9346e-02,  ..., -4.1101e-03,
#             -1.7190e-01, -3.4881e+00],
#            [-1.9772e-01, -9.7184e-01,  4.2002e-01,  ...,  1.1510e+00,
#              5.3057e-01,  5.9662e-01]],
#
#           [[-7.4967e-01,  5.3059e-01, -2.8009e-01,  ...,  3.8959e-01,
#              2.5969e-01,  1.4966e-01],
#            [-7.9521e-01,  2.6058e-02, -1.2064e-01,  ..., -8.2575e-02,
#             -1.8534e+00, -5.0869e-02],
#            [-1.9795e-01, -8.8266e-01, -2.4738e-01,  ...,  8.5146e-01,
#             -1.1261e+00, -1.8805e-01],
#            [ 1.8331e-01, -1.8868e+00,  8.9332e-01,  ...,  4.9033e-02,
#              1.8825e-01,  9.3771e-01],
#            [-2.2461e-01,  1.4022e-01,  1.2745e-01,  ...,  3.0978e-02,
#             -4.2821e-01,  8.2945e-01],
#            [ 5.9763e-02,  1.7124e+00,  7.6708e-01,  ..., -3.7124e-01,
#              1.1468e+00, -4.0842e-01]],
#
#           [[-1.5076e-01,  7.1000e-01, -2.6991e-01,  ..., -1.6360e+00,
#              7.4268e-01, -2.1080e-01],
#            [-3.3807e-01,  6.0745e-03, -2.1080e-01,  ...,  6.8113e-01,
#              5.6193e-01,  1.2204e+00],
#            [ 7.2956e-02, -5.7872e-01,  2.1656e-01,  ...,  6.8145e-01,
#             -1.0226e+00, -2.0339e-02],
#            [ 4.9369e-01,  1.4821e+00,  2.0072e+00,  ...,  3.2044e-02,
#              6.8801e-02,  2.9638e-01],
#            [-7.3051e-02, -1.9066e-02,  1.6803e-01,  ...,  2.0623e-02,
#             -6.9824e-04, -3.9758e-01],
#            [-1.5591e-01,  9.3328e-01, -1.3587e+00,  ...,  7.3300e-01,
#              1.6953e-01, -1.5582e+00]],
#
#           ...,
#
#           [[-2.7664e-01, -1.8857e+00,  8.7860e-01,  ...,  4.7520e-01,
#              5.4525e-01,  4.4563e-01],
#            [-7.5818e-03,  8.3224e-03, -2.0980e-02,  ..., -6.9776e-03,
#             -1.7057e+00,  6.3151e-01],
#            [-7.0812e-02, -1.3246e+00, -1.9379e-01,  ...,  3.2553e+00,
#              1.1956e+00,  1.0837e-01],
#            [-7.5002e-02,  1.4966e+00, -3.6178e-02,  ..., -2.3434e-03,
#              5.1565e-01,  7.8180e-01],
#            [-5.5843e-01, -1.7150e-02, -2.1473e-02,  ..., -8.0408e-03,
#             -8.8851e-01, -1.4625e+00],
#            [-6.6335e-01, -1.0445e+00, -1.1495e-01,  ..., -3.6094e-01,
#              9.4952e-01, -1.7040e+00]],
#
#           [[ 7.0314e-01,  1.6645e+00,  2.0218e-01,  ..., -1.7009e+00,
#             -1.9302e+00,  1.4525e-01],
#            [-8.6105e-01,  6.6612e-03,  2.6004e-01,  ...,  6.0774e-02,
#             -4.0759e-01, -1.2774e-01],
#            [-1.4428e-01, -1.0626e+00,  7.5401e-01,  ..., -3.6413e+00,
#              5.5741e-01, -1.0945e-02],
#            [-7.6872e-01,  8.4739e-01, -1.2904e+00,  ..., -1.8525e-02,
#              3.0466e-01, -8.8579e-01],
#            [-3.2058e-01,  1.2891e-01, -1.5625e-01,  ...,  3.3673e-02,
#             -7.7622e-01, -5.4562e-01],
#            [-2.7213e-01, -4.3999e-01,  1.7622e-01,  ..., -7.3896e-01,
#              5.4364e-01, -1.8108e+00]],
#
#           [[ 5.6690e-01, -8.3288e-01,  3.5096e-01,  ...,  3.5231e-02,
#              6.7654e-01,  1.9529e-01],
#            [-4.6758e-01,  3.1353e-02,  5.3074e-02,  ..., -3.7825e-02,
#              1.4918e-01, -8.0422e-01],
#            [ 2.7325e-01, -3.8499e+00,  2.4066e-01,  ..., -1.0311e+00,
#              1.7889e+00, -9.8299e-02],
#            [-2.4920e-01,  9.7937e-01, -2.0386e+00,  ..., -7.2151e-02,
#             -1.2201e-01,  3.7687e-01],
#            [ 5.1112e-01, -1.5703e-01, -1.4800e-01,  ...,  1.1858e-02,
#             -1.2259e+00,  2.0146e+00],
#            [-1.1600e-01,  8.1005e-01, -1.1470e-01,  ..., -4.4872e-01,
#             -7.9987e-01,  2.0416e-01]]]]),
#  tensor([[[[-2.6975e-02,  1.1427e+00,  4.1698e-01,  ..., -8.3755e+00,
#             -4.7765e-01, -2.1633e-01],
#            [ 2.8020e-01, -6.6962e-01,  1.4016e+00,  ...,  7.5675e-04,
#              2.2802e-01, -1.7932e+00],
#            [-1.1675e-01,  2.9058e-02,  1.4350e-01,  ..., -1.8113e+00,
#             -9.6346e-01,  2.6943e+00],
#            [ 9.3339e-02,  5.5481e-01,  5.7394e-01,  ...,  6.9919e-01,
#             -3.4617e-01,  2.7778e-01],
#            [-1.4753e-01, -4.3234e-01,  1.7809e+00,  ..., -1.4585e+00,
#             -7.7736e-01,  1.1985e-01],
#            [-5.5448e-01,  8.2052e-01,  1.4681e-03,  ..., -3.1119e-02,
#             -1.6508e-01, -6.0103e-01]],
#
#           [[ 1.1321e-01,  1.9631e-01,  1.0589e+00,  ...,  4.4958e+00,
#              4.9575e-02,  2.7624e-01],
#            [-2.5041e-01,  1.0904e+00,  1.4865e+00,  ..., -3.6319e-01,
#             -4.8349e-01,  6.8312e-01],
#            [-2.0786e+00,  5.2171e-03, -1.3269e-02,  ...,  1.5515e-01,
#              1.1037e+00, -2.8357e-01],
#            [-1.6813e-01, -3.7349e-01,  1.3249e+00,  ..., -3.1635e-02,
#             -2.6777e-01, -3.5144e-01],
#            [-4.7156e-02,  6.9693e-01, -3.7944e+00,  ...,  8.2782e-01,
#             -3.4735e+00, -1.5640e+00],
#            [ 1.0004e-01,  8.5018e-01, -1.1673e-01,  ...,  4.3758e-01,
#              4.1557e-01,  1.9148e-01]],
#
#           [[ 8.4804e-02, -1.9090e-01,  3.3380e-01,  ..., -3.4426e+00,
#              3.0574e-02,  2.3107e-01],
#            [ 2.2145e-01, -2.3321e+00,  1.4031e+00,  ..., -3.7283e-01,
#             -1.6912e+00,  9.2597e-01],
#            [-1.5250e+00, -2.3280e-02,  2.4597e-01,  ...,  7.9027e-01,
#             -9.4733e-01,  8.7970e-01],
#            [ 3.8091e-02, -3.8998e-01, -2.2662e-01,  ..., -3.3237e-02,
#              5.0703e-01, -1.2149e-01],
#            [-1.1305e-02,  5.8724e-02,  1.0739e+00,  ...,  7.2756e-01,
#             -1.0941e+00, -2.7587e-01],
#            [-6.4559e-03, -1.2770e+00,  1.9988e-01,  ..., -1.4452e-01,
#              3.9880e-01,  5.1171e-01]],
#
#           ...,
#
#           [[ 9.3022e-02, -1.3080e+00,  4.3844e-01,  ...,  6.7089e+00,
#             -7.4844e-02, -1.0296e-01],
#            [ 5.1513e-01, -1.5177e+00, -2.4742e+00,  ..., -1.0126e+00,
#              9.4409e-01, -1.7644e+00],
#            [ 1.5795e+00, -1.2499e-02,  3.1105e-01,  ...,  2.4935e-01,
#             -2.5942e+00,  4.2571e-01],
#            [-4.3305e-02,  7.7402e-01,  4.8391e-02,  ..., -1.7993e-02,
#             -3.8225e-01,  1.6393e-01],
#            [-1.2804e-02, -1.1867e-01,  1.6239e+00,  ..., -2.4819e+00,
#              6.3592e-01, -6.5775e-01],
#            [-6.8280e-01,  1.6357e-01,  2.8135e-01,  ..., -4.5650e-01,
#              5.8016e-01,  3.7909e-01]],
#
#           [[ 2.7604e-01, -5.2317e-01, -3.5259e-01,  ..., -4.3182e+00,
#             -1.0420e-02,  2.3876e-01],
#            [-8.2358e-01,  1.2819e+00,  3.2237e+00,  ..., -1.4079e+00,
#              8.2605e-01, -3.5490e+00],
#            [ 7.2705e-01,  1.0179e-02,  4.1682e-02,  ..., -1.2930e+00,
#             -1.0318e-02, -9.7465e-01],
#            [ 7.1487e-02, -5.2067e-01,  1.9646e-01,  ..., -6.5025e-02,
#              3.0096e-01,  2.5064e-01],
#            [-9.5270e-03, -2.6696e-01,  1.2718e+00,  ...,  1.3878e-01,
#              8.9478e-01,  2.6727e-01],
#            [-1.0195e-01,  2.9243e-01,  5.7825e-02,  ..., -1.4137e-01,
#              9.0536e-01,  8.3997e-01]],
#
#           [[-3.7994e-01, -3.5905e-01,  8.5735e-01,  ..., -2.2555e+00,
#              2.9540e-01,  1.4439e-01],
#            [-2.5761e-01,  7.6109e-01,  2.1357e+00,  ...,  3.2990e-01,
#              8.4556e-01,  1.9200e+00],
#            [-1.3175e+00,  2.9954e-02,  1.1293e-01,  ..., -1.1721e+00,
#              3.4716e-01, -3.2099e+00],
#            [-9.7234e-02,  3.1779e-01,  2.1693e-01,  ..., -6.0591e-01,
#             -1.5350e-01, -3.5609e-01],
#            [ 2.7051e-02, -2.9286e-01,  1.6291e-01,  ...,  2.3671e-01,
#              1.4252e-01, -8.5905e-01],
#            [ 4.1113e-01, -9.3422e-01,  5.5501e-02,  ..., -3.9380e-02,
#              2.7077e-01,  2.4971e-02]]],
#
#
#          [[[-3.9128e-01,  3.0329e-01,  1.7438e+00,  ..., -5.1570e-02,
#              2.7041e-01,  1.1142e-01],
#            [ 9.7906e-01, -6.6916e-01,  1.5667e-01,  ..., -1.1040e+00,
#             -1.0028e+00, -3.1761e-01],
#            [ 1.3956e-02,  4.7639e-01, -3.4994e-01,  ...,  4.4730e-01,
#              5.8166e-02,  3.7031e+00],
#            [-6.1185e-01, -2.9059e-02, -2.5640e+00,  ..., -4.8810e-01,
#              7.2237e-02, -3.3621e-02],
#            [ 1.1702e+00, -5.4646e-01,  4.0832e-01,  ..., -3.3780e-01,
#             -3.6306e-02, -2.0265e-01],
#            [-3.4012e-01, -8.7453e-01,  6.7431e-02,  ..., -2.4516e-01,
#              1.1414e+00, -8.6555e-01]],
#
#           [[-1.4254e-01,  6.6979e-02,  5.7138e-01,  ..., -2.7770e-02,
#             -2.1318e-01, -2.1749e-01],
#            [ 8.6064e-01,  7.9722e-01,  5.1855e-01,  ...,  3.1673e-01,
#              1.1649e-01, -1.3670e-01],
#            [-6.5740e-01, -2.4898e+00, -6.6839e-02,  ...,  8.8526e-01,
#              5.8112e-02,  2.1320e-01],
#            [-2.1838e+00,  1.2566e-01,  2.0784e+00,  ...,  1.1584e-03,
#              1.7045e-01,  5.8616e-02],
#            [-3.7954e-01,  6.8714e-01, -2.4719e-01,  ..., -2.9393e-01,
#              1.1800e+00,  5.9116e-01],
#            [-3.4312e-01, -3.4138e-01, -1.7100e-01,  ...,  2.5343e-02,
#             -1.2067e-01, -8.6847e-01]],
#
#           [[-1.8238e-01,  2.5802e-01, -1.7092e-01,  ..., -2.6656e-02,
#              2.8145e-02, -9.4126e-02],
#            [ 2.5779e+00, -4.7903e-01, -1.0201e-01,  ...,  2.4409e+00,
#              2.5932e-01, -2.8913e-01],
#            [ 3.5668e-01,  8.4694e-01,  3.5863e+00,  ..., -1.1736e+00,
#             -7.2177e-02, -2.4034e+00],
#            [-1.8247e+00,  4.7933e-03, -4.0635e-01,  ..., -2.3482e-01,
#             -5.0712e-03,  8.8910e-03],
#            [-1.8990e+00, -1.4103e+00, -1.3095e-01,  ...,  1.3795e+00,
#             -7.5172e-01, -1.6649e-01],
#            [-1.5989e-01, -8.0318e-02,  1.2440e-01,  ..., -3.1794e-01,
#             -5.3846e-03, -1.6965e+00]],
#
#           ...,
#
#           [[-4.1347e-01, -6.1763e-02, -1.9373e+00,  ...,  1.7914e-02,
#              1.5746e-01,  2.1768e-02],
#            [ 1.0763e+00, -7.5147e-01, -2.7873e-01,  ..., -1.9096e+00,
#             -2.2879e-01,  1.5889e-01],
#            [ 1.6303e-01, -9.7796e-01, -1.6298e+00,  ...,  2.7444e-02,
#              2.5554e-01, -3.8790e+00],
#            [-2.0949e+00,  4.0024e-01,  5.5578e-01,  ..., -9.9825e-02,
#             -1.3430e-02, -1.2625e-01],
#            [ 9.7021e-01,  3.7204e-01,  5.8349e-02,  ...,  7.2699e-01,
#             -4.6000e-01,  7.1423e-01],
#            [ 5.6306e-02, -1.0799e+00, -1.7901e-01,  ..., -1.2894e-01,
#             -1.6473e+00,  4.7823e-01]],
#
#           [[-1.1248e+00,  2.2253e-01,  7.8126e-01,  ...,  3.7603e-02,
#              6.1945e-02, -1.4676e-01],
#            [-3.3485e-01,  9.5780e-01, -7.5927e-01,  ..., -1.6628e-01,
#              1.0203e+00,  9.1956e-01],
#            [-2.7452e-01,  8.7849e-01,  4.8874e-01,  ..., -1.1384e-01,
#             -5.4279e-02, -1.8832e+00],
#            [-1.5225e+00,  1.0040e+00,  1.8975e+00,  ..., -8.2773e-01,
#              1.7396e-01,  1.2552e-01],
#            [-2.9785e-01, -1.7266e-01, -2.0563e-02,  ..., -8.7540e-01,
#              4.1189e-01,  1.8740e-01],
#            [ 6.9159e-02, -6.7810e-01, -6.8640e-02,  ..., -2.1745e-01,
#              4.1672e-01,  2.4365e-01]],
#
#           [[ 9.9051e-01,  1.2811e-01,  1.3409e+00,  ...,  2.9462e-02,
#             -8.4088e-03,  7.1865e-03],
#            [-8.5172e-01,  1.0129e-01,  4.4222e-01,  ...,  2.2883e+00,
#             -6.4905e-01,  5.2368e-01],
#            [ 1.0729e+00,  9.8708e-01, -1.6862e-01,  ...,  7.0265e-01,
#             -5.9329e-02,  5.3208e+00],
#            [ 1.4086e+00,  2.1408e-01,  1.4659e+00,  ...,  2.1148e+00,
#             -2.9359e-02,  2.8720e-02],
#            [ 6.2179e-01, -3.4007e-01, -2.6456e-01,  ..., -3.3377e-01,
#              4.7947e-01,  6.9489e-01],
#            [ 1.1050e-01,  3.0068e-01,  7.1646e-01,  ...,  1.0166e-01,
#              1.1267e+00, -1.1611e+00]]],
#
#
#          [[[-1.2776e+00,  6.6240e-01, -7.5534e-01,  ...,  3.1367e+00,
#             -1.0594e+00,  2.6497e-03],
#            [-3.2259e-01, -1.9115e-02, -2.7109e+00,  ...,  8.0087e-02,
#              1.7099e-02,  5.2779e-01],
#            [ 2.0627e+00, -1.8393e+00,  1.3044e-01,  ..., -2.5227e-01,
#             -1.4063e-02,  6.3648e-01],
#            [ 3.9800e-01,  2.9768e-01, -2.4887e+00,  ..., -2.8875e-01,
#              1.0805e+00, -1.8065e-01],
#            [-1.5657e+00, -1.6136e+00,  1.1761e-01,  ...,  2.2830e+00,
#              4.7534e-01, -2.9714e-01],
#            [ 3.3093e-01, -9.3196e-01,  1.0973e-01,  ..., -3.9303e-01,
#             -2.4432e-01, -1.9283e-03]],
#
#           [[ 1.6752e+00,  9.8728e-01,  1.3048e+00,  ...,  2.4546e+00,
#              8.9778e-01,  5.9942e-02],
#            [-1.1321e+00, -8.3169e-02, -1.0655e+00,  ..., -5.3610e-02,
#              3.0933e-02,  1.6996e+00],
#            [ 1.3572e+00,  3.5087e+00, -5.6493e-01,  ...,  1.5630e-01,
#              1.1401e-01,  8.7724e-02],
#            [ 1.8826e+00, -8.0536e-01, -6.4915e-01,  ..., -6.0300e-01,
#              4.2268e-01, -1.0250e+00],
#            [ 1.2450e+00, -3.1476e-03, -7.2572e-02,  ...,  4.9648e+00,
#              2.4514e-01, -8.4797e-01],
#            [-5.2386e-01,  2.2547e-01, -1.7916e-02,  ..., -1.3301e-01,
#             -4.7206e-02, -4.0686e-03]],
#
#           [[ 1.0815e+00, -1.0988e-02, -7.6541e-01,  ...,  5.6168e-01,
#              1.3622e+00,  3.0586e-02],
#            [ 3.2631e-01, -1.2213e-01, -1.0583e+00,  ..., -7.7928e-02,
#              3.5818e-01,  2.6620e+00],
#            [-1.6855e+00, -1.9894e+00, -4.5614e-02,  ...,  1.2573e-01,
#             -1.8470e-02,  1.2172e-01],
#            [ 2.6492e-01, -4.6880e-01, -6.2964e-01,  ...,  1.5370e+00,
#             -7.7000e-01, -2.8234e-01],
#            [-7.7528e-01,  1.9819e+00, -5.0842e-02,  ...,  1.7884e+00,
#             -7.5354e-01, -5.6921e-01],
#            [ 2.2637e-01, -2.1493e-01, -4.0555e-01,  ...,  9.7193e-01,
#              2.7136e-01, -5.0617e-03]],
#
#           ...,
#
#           [[-1.6761e+00, -6.9634e-01, -2.9371e+00,  ..., -4.4699e+00,
#              2.8774e-01,  3.1593e-02],
#            [ 7.5001e-01, -1.7541e-01,  2.4237e+00,  ..., -2.8136e-02,
#             -4.8825e-01,  1.2874e+00],
#            [ 6.3596e-01, -7.1867e-01, -6.9524e-01,  ..., -1.6781e+00,
#             -2.1677e-02, -1.5335e+00],
#            [-2.5790e+00, -1.0584e-02, -1.0483e+00,  ..., -1.7448e+00,
#             -1.4666e+00,  2.3281e-01],
#            [-9.5808e-01,  2.9462e-01, -6.1532e-02,  ...,  1.8991e-01,
#             -6.3903e-01, -4.4545e-01],
#            [ 1.4676e+00, -3.7433e-01, -6.6621e-01,  ...,  6.9258e-01,
#              3.5610e-01, -1.0788e-02]],
#
#           [[ 2.5123e+00, -7.5566e-01,  1.1096e-01,  ...,  1.3473e-01,
#             -2.2708e-01, -3.9094e-02],
#            [ 6.5271e-01, -2.0388e-02, -2.1433e+00,  ...,  4.3907e-02,
#             -7.5354e-02,  7.4683e-01],
#            [ 6.7876e+00, -2.3339e+00, -2.8033e-01,  ..., -2.1698e+00,
#              1.4436e-01, -4.9290e-01],
#            [ 6.1602e-01, -5.6363e-01,  1.3801e+00,  ..., -4.0051e-01,
#             -7.5461e-01,  5.7494e-01],
#            [-3.0167e-02,  3.6551e-01,  6.7787e-02,  ...,  4.4475e-01,
#              3.8094e-01,  7.7020e-01],
#            [-1.1885e+00, -2.8034e-01, -1.4673e+00,  ..., -2.0912e+00,
#              6.1728e-01, -6.6052e-03]],
#
#           [[ 1.7005e-01, -9.5639e-01,  8.3401e-01,  ...,  4.1265e+00,
#             -4.8697e-01,  1.5795e-02],
#            [-2.3039e-01,  7.2300e-02, -1.5875e+00,  ...,  6.1212e-03,
#              6.0843e-01,  1.8745e+00],
#            [-2.4100e+00, -3.2166e+00, -7.1851e-01,  ...,  4.6821e-01,
#             -1.7675e-01,  9.0657e-02],
#            [ 2.4667e+00, -1.4381e-01, -2.9427e-01,  ..., -2.1643e+00,
#              6.7028e-01, -1.2055e+00],
#            [-7.2312e-02, -2.6526e+00,  2.7557e-02,  ...,  2.0110e-01,
#              1.1650e-01,  2.1880e-01],
#            [ 3.8107e-01,  6.2959e-01,  1.4402e+00,  ..., -3.3811e-01,
#              2.7137e-02, -1.1046e-02]]],
#
#
#          [[[-1.9799e-01, -1.0474e+00,  3.9488e-01,  ..., -5.9977e-01,
#              3.5057e-01, -6.1720e-02],
#            [ 1.3887e+00,  1.6019e-02,  6.0418e-02,  ..., -9.7386e-02,
#             -5.5413e-01, -3.6288e-01],
#            [ 6.5327e-02,  9.7353e-01,  9.7260e-01,  ...,  2.4383e+00,
#             -2.1460e-01, -2.7932e-02],
#            [-1.0480e+00, -1.0425e-01,  2.9479e+00,  ...,  3.2914e-02,
#             -5.4207e-01,  2.7993e-01],
#            [-3.8733e-02,  3.6474e-02, -4.9346e-02,  ..., -4.1101e-03,
#             -1.7190e-01, -3.4881e+00],
#            [-1.9772e-01, -9.7184e-01,  4.2002e-01,  ...,  1.1510e+00,
#              5.3057e-01,  5.9662e-01]],
#
#           [[-7.4967e-01,  5.3059e-01, -2.8009e-01,  ...,  3.8959e-01,
#              2.5969e-01,  1.4966e-01],
#            [-7.9521e-01,  2.6058e-02, -1.2064e-01,  ..., -8.2575e-02,
#             -1.8534e+00, -5.0869e-02],
#            [-1.9795e-01, -8.8266e-01, -2.4738e-01,  ...,  8.5146e-01,
#             -1.1261e+00, -1.8805e-01],
#            [ 1.8331e-01, -1.8868e+00,  8.9332e-01,  ...,  4.9033e-02,
#              1.8825e-01,  9.3771e-01],
#            [-2.2461e-01,  1.4022e-01,  1.2745e-01,  ...,  3.0978e-02,
#             -4.2821e-01,  8.2945e-01],
#            [ 5.9763e-02,  1.7124e+00,  7.6708e-01,  ..., -3.7124e-01,
#              1.1468e+00, -4.0842e-01]],
#
#           [[-1.5076e-01,  7.1000e-01, -2.6991e-01,  ..., -1.6360e+00,
#              7.4268e-01, -2.1080e-01],
#            [-3.3807e-01,  6.0745e-03, -2.1080e-01,  ...,  6.8113e-01,
#              5.6193e-01,  1.2204e+00],
#            [ 7.2956e-02, -5.7872e-01,  2.1656e-01,  ...,  6.8145e-01,
#             -1.0226e+00, -2.0339e-02],
#            [ 4.9369e-01,  1.4821e+00,  2.0072e+00,  ...,  3.2044e-02,
#              6.8801e-02,  2.9638e-01],
#            [-7.3051e-02, -1.9066e-02,  1.6803e-01,  ...,  2.0623e-02,
#             -6.9824e-04, -3.9758e-01],
#            [-1.5591e-01,  9.3328e-01, -1.3587e+00,  ...,  7.3300e-01,
#              1.6953e-01, -1.5582e+00]],
#
#           ...,
#
#           [[-2.7664e-01, -1.8857e+00,  8.7860e-01,  ...,  4.7520e-01,
#              5.4525e-01,  4.4563e-01],
#            [-7.5818e-03,  8.3224e-03, -2.0980e-02,  ..., -6.9776e-03,
#             -1.7057e+00,  6.3151e-01],
#            [-7.0812e-02, -1.3246e+00, -1.9379e-01,  ...,  3.2553e+00,
#              1.1956e+00,  1.0837e-01],
#            [-7.5002e-02,  1.4966e+00, -3.6178e-02,  ..., -2.3434e-03,
#              5.1565e-01,  7.8180e-01],
#            [-5.5843e-01, -1.7150e-02, -2.1473e-02,  ..., -8.0408e-03,
#             -8.8851e-01, -1.4625e+00],
#            [-6.6335e-01, -1.0445e+00, -1.1495e-01,  ..., -3.6094e-01,
#              9.4952e-01, -1.7040e+00]],
#
#           [[ 7.0314e-01,  1.6645e+00,  2.0218e-01,  ..., -1.7009e+00,
#             -1.9302e+00,  1.4525e-01],
#            [-8.6105e-01,  6.6612e-03,  2.6004e-01,  ...,  6.0774e-02,
#             -4.0759e-01, -1.2774e-01],
#            [-1.4428e-01, -1.0626e+00,  7.5401e-01,  ..., -3.6413e+00,
#              5.5741e-01, -1.0945e-02],
#            [-7.6872e-01,  8.4739e-01, -1.2904e+00,  ..., -1.8525e-02,
#              3.0466e-01, -8.8579e-01],
#            [-3.2058e-01,  1.2891e-01, -1.5625e-01,  ...,  3.3673e-02,
#             -7.7622e-01, -5.4562e-01],
#            [-2.7213e-01, -4.3999e-01,  1.7622e-01,  ..., -7.3896e-01,
#              5.4364e-01, -1.8108e+00]],
#
#           [[ 5.6690e-01, -8.3288e-01,  3.5096e-01,  ...,  3.5231e-02,
#              6.7654e-01,  1.9529e-01],
#            [-4.6758e-01,  3.1353e-02,  5.3074e-02,  ..., -3.7825e-02,
#              1.4918e-01, -8.0422e-01],
#            [ 2.7325e-01, -3.8499e+00,  2.4066e-01,  ..., -1.0311e+00,
#              1.7889e+00, -9.8299e-02],
#            [-2.4920e-01,  9.7937e-01, -2.0386e+00,  ..., -7.2151e-02,
#             -1.2201e-01,  3.7687e-01],
#            [ 5.1112e-01, -1.5703e-01, -1.4800e-01,  ...,  1.1858e-02,
#             -1.2259e+00,  2.0146e+00],
#            [-1.1600e-01,  8.1005e-01, -1.1470e-01,  ..., -4.4872e-01,
#             -7.9987e-01,  2.0416e-01]]]]))

# %%
data_conf, data_german, aml_data, emb_indexer, emb_indexer_inv, emb_vals, neighbours_dicts, max_paths, max_pathlen, max_types, ontologies_in_alignment = pickle.load(open("Input/data_conf_oaei_german_aml_thresh.pkl", "rb"))
data_conf, data_german, logmap_data, emb_indexer, emb_indexer_inv, emb_vals, neighbours_dicts, max_paths, max_pathlen, max_types, ontologies_in_alignment = pickle.load(open("Input/data_conf_oaei_german_logmap_thresh.pkl", "rb"))
pickle.dump([data_conf, data_german, aml_data, logmap_data, emb_indexer, emb_indexer_inv, emb_vals, neighbours_dicts, max_paths, max_pathlen, max_types, ontologies_in_alignment], open("Input/data_conf_oaei_german_logmap_aml_thresh.pkl", "wb"))

# %%
ctimes, dtimes = [], []
for i in range(100):
    a = torch.randn((10,4,22,6,512))
    b = torch.randn((10,4,1,6,512))
    t = time.time()
    c = a * b
    ctimes.append(time.time()-t)
    t = time.time()
    d = torch.bmm(c.permute(0,1,3,4,2).reshape(-1, 22, 1), b.permute(0,1,3,4,2).reshape(-1, 1, 1)).squeeze(-1).reshape(-1,4,6,512,22).permute(0,1,4,2,3)
    dtimes.append(time.time()-t)

# %%
a = torch.randn((10,4,22,6,512))
b = torch.randn((10,4,22,6,512))
c = a * torch.sum(b,dim=2).unsqueeze(2)

# %%
# AML test
def is_test(test_onto, key):
    return tuple([el.split("#")[0] for el in key]) in test_onto

results = []
outputs = {}
# all_ont_pairs = list(set([tuple([el.split("#")[0] for el in l]) for l in data.keys()]))
ontologies_in_alignment = [tuple(pair) for pair in ontologies_in_alignment]
gt_mappings = [el[:2] for el in gt_mappings]

test_onto = ontologies_in_alignment
for ont_pair in test_onto:
    a, b, c = ont_pair[0], ont_pair[1], ont_pair[0] + "-" + ont_pair[1]
    java_command = "java -jar AML_v3.1/AgreementMakerLight.jar -s conference_ontologies/" + a + ".owl" + \
                        " -t conference_ontologies/" + b + ".owl -o AML-test-results/" + c + ".rdf -a"
    process = subprocess.Popen(java_command.split(), stdout=subprocess.PIPE)
    output, error = process.communicate()
print (test_onto)
pred_aml = load_alignments("AML-test-results/")
pred_aml = [tuple([el.split("/")[-1] for el in key][:2]) for key in pred_aml]
outputs[ont_pair] = pred_aml
tp = len([elem for elem in pred_aml if data[elem]])
fn = len([key for key in gt_mappings if key not in set(pred_aml) and is_test(test_onto, key)])
fp = len([elem for elem in pred_aml if not data[elem]])

precision = tp/(tp+fp)
recall = tp/(tp+fn)
f1score = 2 * precision * recall / (precision + recall)
f2score = 5 * precision * recall / (4 * precision + recall)
f0_5score = 1.25 * precision * recall / (0.25 * precision + recall)
print (precision, recall, f1score, f2score, f0_5score)

metrics = [precision, recall, f1score, f2score, f0_5score]
results.append(metrics)

_ = [os.remove(f) for f in glob.glob('AML-test-results/*')]

print ("Final Results:", np.mean(results, axis=0))
# Out:
# [('confOf', 'sigkdd'), ('iasted', 'sigkdd'), ('cmt', 'ekaw'), ('confOf', 'iasted'), ('conference', 'edas'), ('cmt', 'sigkdd'), ('ekaw', 'sigkdd'), ('conference', 'confOf'), ('conference', 'sigkdd'), ('confOf', 'edas'), ('cmt', 'conference'), ('edas', 'iasted'), ('conference', 'iasted'), ('edas', 'sigkdd'), ('ekaw', 'iasted'), ('cmt', 'edas'), ('edas', 'ekaw'), ('cmt', 'confOf'), ('confOf', 'ekaw'), ('conference', 'ekaw'), ('cmt', 'iasted')]
# 0.8026905829596412 0.5868852459016394 0.678030303030303 0.6202356202356203 0.747702589807853
# Final Results: [0.80269058 0.58688525 0.6780303  0.62023562 0.74770259]

# %%
# AML test
def is_test(test_onto, key):
    return tuple([el.split("#")[0] for el in key]) in test_onto

results = []
outputs = {}
# all_ont_pairs = list(set([tuple([el.split("#")[0] for el in l]) for l in data.keys()]))
ontologies_in_alignment = [tuple(pair) for pair in ontologies_in_alignment]
gt_mappings = [el[:2] for el in gt_mappings]
for i in list(range(0, len(ontologies_in_alignment), 1)):
    test_onto = ontologies_in_alignment[i:i+1]
    for ont_pair in test_onto:
        a, b, c = ont_pair[0], ont_pair[1], ont_pair[0] + "-" + ont_pair[1]
        java_command = "java -jar AML_v3.1/AgreementMakerLight.jar -s conference_ontologies/" + a + ".owl" + \
                            " -t conference_ontologies/" + b + ".owl -o AML-test-results/" + c + ".rdf -a"
        process = subprocess.Popen(java_command.split(), stdout=subprocess.PIPE)
        output, error = process.communicate()
    print (test_onto)
    pred_aml = load_alignments("AML-test-results/")
    pred_aml = [tuple([el.split("/")[-1] for el in key][:2]) for key in pred_aml]
    outputs[ont_pair] = pred_aml
    tp = len([elem for elem in pred_aml if data[elem]])
    fn = len([key for key in gt_mappings if key not in set(pred_aml) and is_test(test_onto, key)])
    fp = len([elem for elem in pred_aml if not data[elem]])

    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    f1score = 2 * precision * recall / (precision + recall)
    f2score = 5 * precision * recall / (4 * precision + recall)
    f0_5score = 1.25 * precision * recall / (0.25 * precision + recall)
    print (precision, recall, f1score, f2score, f0_5score)
    
    metrics = [precision, recall, f1score, f2score, f0_5score]
    results.append(metrics)
    
    _ = [os.remove(f) for f in glob.glob('AML-test-results/*')]
    
print ("Final Results:", np.mean(results, axis=0))
# Out:
# [('confOf', 'sigkdd')]
# 1.0 0.7142857142857143 0.8333333333333333 0.7575757575757576 0.9259259259259259
# [('iasted', 'sigkdd')]
# 0.8666666666666667 0.8666666666666667 0.8666666666666667 0.8666666666666667 0.8666666666666667
# [('cmt', 'ekaw')]
# 0.6666666666666666 0.5454545454545454 0.6 0.5660377358490566 0.6382978723404255
# [('confOf', 'iasted')]
# 0.8 0.4444444444444444 0.5714285714285714 0.4878048780487804 0.6896551724137931
# [('conference', 'edas')]
# 0.75 0.5294117647058824 0.6206896551724139 0.5625 0.6923076923076923
# [('cmt', 'sigkdd')]
# 0.9 0.75 0.8181818181818182 0.7758620689655173 0.8653846153846154
# [('ekaw', 'sigkdd')]
# 0.8 0.7272727272727273 0.761904761904762 0.7407407407407407 0.7843137254901961
# [('conference', 'confOf')]
# 0.7272727272727273 0.5333333333333333 0.6153846153846153 0.5633802816901409 0.6779661016949153
# [('conference', 'sigkdd')]
# 0.8181818181818182 0.6 0.6923076923076923 0.6338028169014084 0.7627118644067796
# [('confOf', 'edas')]
# 0.9 0.47368421052631576 0.6206896551724138 0.5232558139534883 0.7627118644067795
# [('cmt', 'conference')]
# 0.6153846153846154 0.5333333333333333 0.5714285714285715 0.5479452054794521 0.5970149253731344
# [('edas', 'iasted')]
# 0.9090909090909091 0.5263157894736842 0.6666666666666666 0.5747126436781608 0.7936507936507935
# [('conference', 'iasted')]
# 0.625 0.35714285714285715 0.45454545454545453 0.390625 0.5434782608695652
# [('edas', 'sigkdd')]
# 1.0 0.4666666666666667 0.6363636363636364 0.5223880597014926 0.813953488372093
# [('ekaw', 'iasted')]
# 0.7777777777777778 0.7 0.7368421052631577 0.7142857142857142 0.7608695652173912
# [('cmt', 'edas')]
# 0.8888888888888888 0.6153846153846154 0.7272727272727274 0.6557377049180328 0.8163265306122449
# [('edas', 'ekaw')]
# 0.75 0.5217391304347826 0.6153846153846153 0.5555555555555556 0.6896551724137931
# [('cmt', 'confOf')]
# 0.875 0.4375 0.5833333333333334 0.4861111111111111 0.7291666666666666
# [('confOf', 'ekaw')]
# 0.9375 0.75 0.8333333333333334 0.78125 0.8928571428571429
# [('conference', 'ekaw')]
# 0.7272727272727273 0.64 0.6808510638297872 0.6557377049180328 0.7079646017699116
# [('cmt', 'iasted')]
# 0.6666666666666666 1.0 0.8 0.9090909090909091 0.7142857142857142
# Final Results: [0.80958902 0.60631599 0.68126706 0.63195554 0.74881735]

# %%
data_log
# Out:
# [('conference#Information_for_participants', 'ekaw#Programme_Brochure', '1.0'),
#  ('conference#Person', 'ekaw#Person', '1.0'),
#  ('conference#Tutorial', 'ekaw#Tutorial', '1.0'),
#  ('conference#Review', 'ekaw#Review', '1.0'),
#  ('conference#has_a_review', 'ekaw#hasReview', '1.0'),
#  ('conference#Workshop', 'ekaw#Workshop', '1.0'),
#  ('conference#Late_paid_applicant', 'ekaw#Late-Registered_Participant', '1.0'),
#  ('conference#Early_paid_applicant',
#   'ekaw#Early-Registered_Participant',
#   '1.0'),
#  ('conference#Organization', 'ekaw#Organisation', '1.0'),
#  ('conference#Track-workshop_chair', 'ekaw#Workshop_Chair', '1.0'),
#  ('conference#Abstract', 'ekaw#Abstract', '1.0'),
#  ('conference#Conference_proceedings', 'ekaw#Conference_Proceedings', '1.0'),
#  ('conference#Conference_volume', 'ekaw#Conference', '1.0'),
#  ('conference#Rejected_contribution', 'ekaw#Rejected_Paper', '1.0'),
#  ('conference#Poster', 'ekaw#Poster_Paper', '1.0'),
#  ('conference#Track', 'ekaw#Track', '1.0'),
#  ('conference#Topic', 'ekaw#Research_Topic', '1.0'),
#  ('conference#Conference_www', 'ekaw#Web_Site', '1.0'),
#  ('conference#Invited_speaker', 'ekaw#Invited_Speaker', '1.0'),
#  ('conference#contributes', 'ekaw#authorOf', '1.0'),
#  ('conference#Accepted_contribution', 'ekaw#Accepted_Paper', '1.0'),
#  ('conference#Conference_document', 'ekaw#Document', '1.0'),
#  ('conference#Reviewed_contribution', 'ekaw#Evaluated_Paper', '1.0'),
#  ('conference#Submitted_contribution', 'ekaw#Submitted_Paper', '1.0'),
#  ('conference#Regular_author', 'ekaw#Paper_Author', '1.0'),
#  ('confOf#Tutorial', 'ekaw#Tutorial', '1.0'),
#  ('confOf#Poster', 'ekaw#Poster_Paper', '1.0'),
#  ('confOf#Social_event', 'ekaw#Social_Event', '1.0'),
#  ('confOf#Person', 'ekaw#Person', '1.0'),
#  ('confOf#Working_event', 'ekaw#Scientific_Event', '1.0'),
#  ('confOf#Conference', 'ekaw#Conference', '1.0'),
#  ('confOf#Author', 'ekaw#Paper_Author', '1.0'),
#  ('confOf#Banquet', 'ekaw#Conference_Banquet', '1.0'),
#  ('confOf#Workshop', 'ekaw#Workshop', '1.0'),
#  ('confOf#Topic', 'ekaw#Research_Topic', '1.0'),
#  ('confOf#Contribution', 'ekaw#Paper', '1.0'),
#  ('confOf#Participant', 'ekaw#Conference_Participant', '1.0'),
#  ('confOf#Chair_PC', 'ekaw#PC_Chair', '1.0'),
#  ('confOf#Organization', 'ekaw#Organisation', '1.0'),
#  ('confOf#Student', 'ekaw#Student', '1.0'),
#  ('confOf#University', 'ekaw#University', '1.0'),
#  ('confOf#Trip', 'ekaw#Conference_Trip', '1.0'),
#  ('confOf#Member_PC', 'ekaw#PC_Member', '1.0'),
#  ('confOf#Scholar', 'ekaw#Student', '1.0'),
#  ('confOf#Event', 'ekaw#Event', '1.0'),
#  ('ekaw#Conference', 'sigkdd#Conference', '1.0'),
#  ('ekaw#Person', 'sigkdd#Person', '1.0'),
#  ('ekaw#Paper', 'sigkdd#Paper', '1.0'),
#  ('ekaw#Review', 'sigkdd#Review', '1.0'),
#  ('ekaw#Invited_Speaker', 'sigkdd#Invited_Speaker', '1.0'),
#  ('ekaw#OC_Member', 'sigkdd#Organizing_Committee_member', '1.0'),
#  ('ekaw#Abstract', 'sigkdd#Abstract', '1.0'),
#  ('ekaw#PC_Chair', 'sigkdd#Program_Chair', '1.0'),
#  ('ekaw#Paper_Author', 'sigkdd#Author', '1.0'),
#  ('ekaw#Document', 'sigkdd#Document', '1.0'),
#  ('ekaw#Location', 'sigkdd#Place', '1.0'),
#  ('edas#Place', 'sigkdd#Place', '1.0'),
#  ('edas#hasCostAmount', 'sigkdd#Price', '1.0'),
#  ('edas#Person', 'sigkdd#Person', '1.0'),
#  ('edas#hasName', 'sigkdd#Name_of_conference', '1.0'),
#  ('edas#ConferenceVenuePlace', 'sigkdd#Conference_hall', '1.0'),
#  ('edas#Author', 'sigkdd#Author', '1.0'),
#  ('edas#AccommodationPlace', 'sigkdd#Hotel', '1.0'),
#  ('edas#startDate', 'sigkdd#Start_of_conference', '1.0'),
#  ('edas#ConferenceChair', 'sigkdd#General_Chair', '1.0'),
#  ('edas#Conference', 'sigkdd#Conference', '1.0'),
#  ('edas#endDate', 'sigkdd#End_of_conference', '1.0'),
#  ('edas#Review', 'sigkdd#Review', '1.0'),
#  ('edas#Document', 'sigkdd#Document', '1.0'),
#  ('edas#Paper', 'sigkdd#Paper', '1.0'),
#  ('edas#Attendee', 'sigkdd#Listener', '1.0'),
#  ('confOf#Person', 'sigkdd#Person', '1.0'),
#  ('confOf#Member_PC', 'sigkdd#Program_Committee_member', '1.0'),
#  ('confOf#hasEmail', 'sigkdd#E-mail', '1.0'),
#  ('confOf#Author', 'sigkdd#Author', '1.0'),
#  ('confOf#Conference', 'sigkdd#Conference', '1.0'),
#  ('confOf#Chair_PC', 'sigkdd#Program_Chair', '1.0'),
#  ('confOf#Paper', 'sigkdd#Paper', '1.0'),
#  ('iasted#Place', 'sigkdd#Place', '1.0'),
#  ('iasted#Review', 'sigkdd#Review', '1.0'),
#  ('iasted#Student_registration_fee', 'sigkdd#Registration_Student', '1.0'),
#  ('iasted#Fee', 'sigkdd#Fee', '1.0'),
#  ('iasted#Registration_fee', 'sigkdd#Registration_fee', '1.0'),
#  ('iasted#Sponsor', 'sigkdd#Sponzor', '1.0'),
#  ('iasted#Deadline_for_notification_of_acceptance',
#   'sigkdd#Deadline_Author_notification',
#   '1.0'),
#  ('iasted#Nonmember_registration_fee',
#   'sigkdd#Registration_Non-Member',
#   '1.0'),
#  ('iasted#Author', 'sigkdd#Author', '1.0'),
#  ('iasted#Listener', 'sigkdd#Listener', '1.0'),
#  ('iasted#Main_office', 'sigkdd#Main_office', '1.0'),
#  ('iasted#Conference_hall', 'sigkdd#Conference_hall', '1.0'),
#  ('iasted#Person', 'sigkdd#Person', '1.0'),
#  ('iasted#Deadline', 'sigkdd#Deadline', '1.0'),
#  ('iasted#Speaker', 'sigkdd#Speaker', '1.0'),
#  ('confOf#Event', 'iasted#Activity', '1.0'),
#  ('confOf#Author', 'iasted#Author', '1.0'),
#  ('confOf#Person', 'iasted#Person', '1.0'),
#  ('confOf#Banquet', 'iasted#Dinner_banquet', '1.0'),
#  ('confOf#Administrative_event', 'iasted#Activity_before_conference', '1.0'),
#  ('confOf#Reception', 'iasted#Coctail_reception', '1.0'),
#  ('confOf#City', 'iasted#City', '1.0'),
#  ('confOf#Tutorial', 'iasted#Tutorial', '1.0'),
#  ('confOf#Country', 'iasted#State', '1.0'),
#  ('conference#Passive_conference_participant', 'iasted#Listener', '1.0'),
#  ('conference#Active_conference_participant', 'iasted#Speaker', '1.0'),
#  ('conference#Reviewer', 'iasted#Reviewer', '1.0'),
#  ('conference#Person', 'iasted#Person', '1.0'),
#  ('conference#Regular_author', 'iasted#Author', '1.0'),
#  ('conference#Conference_fees', 'iasted#Fee', '1.0'),
#  ('conference#Tutorial', 'iasted#Tutorial', '1.0'),
#  ('conference#contributes', 'iasted#write', '1.0'),
#  ('conference#Review', 'iasted#Review', '1.0'),
#  ('conference#Conference_document', 'iasted#Document', '1.0'),
#  ('conference#Conference_part', 'iasted#Conference_activity', '1.0'),
#  ('conference#Submitted_contribution', 'iasted#Submission', '1.0'),
#  ('conference#Camera_ready_contribution', 'iasted#Final_manuscript', '1.0'),
#  ('conference#Conference_proceedings', 'iasted#Publication', '1.0'),
#  ('confOf#Trip', 'edas#Excursion', '1.0'),
#  ('confOf#Social_event', 'edas#SocialEvent', '1.0'),
#  ('confOf#reviewes', 'edas#isReviewing', '1.0'),
#  ('confOf#Organization', 'edas#Organization', '1.0'),
#  ('confOf#writtenBy', 'edas#isWrittenBy', '1.0'),
#  ('confOf#Working_event', 'edas#AcademicEvent', '1.0'),
#  ('confOf#Reception', 'edas#Reception', '1.0'),
#  ('confOf#hasSurname', 'edas#hasLastName', '1.0'),
#  ('confOf#Workshop', 'edas#Workshop', '1.0'),
#  ('confOf#Author', 'edas#Author', '1.0'),
#  ('confOf#hasFirstName', 'edas#hasFirstName', '1.0'),
#  ('confOf#Event', 'edas#ConferenceEvent', '1.0'),
#  ('confOf#Topic', 'edas#Topic', '1.0'),
#  ('confOf#Country', 'edas#Country', '1.0'),
#  ('confOf#Participant', 'edas#Attendee', '1.0'),
#  ('confOf#Person', 'edas#Person', '1.0'),
#  ('confOf#Member_PC', 'edas#TPCMember', '1.0'),
#  ('confOf#Paper', 'edas#Paper', '1.0'),
#  ('confOf#writes', 'edas#hasRelatedPaper', '1.0'),
#  ('edas#Place', 'iasted#Place', '1.0'),
#  ('edas#SessionChair', 'iasted#Session_chair', '1.0'),
#  ('edas#Author', 'iasted#Author', '1.0'),
#  ('edas#Document', 'iasted#Document', '1.0'),
#  ('edas#Country', 'iasted#State', '1.0'),
#  ('edas#WelcomeTalk', 'iasted#Welcome_address', '1.0'),
#  ('edas#Sponsorship', 'iasted#Sponzorship', '1.0'),
#  ('edas#Reviewer', 'iasted#Reviewer', '1.0'),
#  ('edas#Attendee', 'iasted#Delegate', '1.0'),
#  ('edas#ConferenceDinner', 'iasted#Dinner_banquet', '1.0'),
#  ('edas#SocialEvent', 'iasted#Social_program', '1.0'),
#  ('edas#CoffeeBreak', 'iasted#Coffee_break', '1.0'),
#  ('edas#Review', 'iasted#Review', '1.0'),
#  ('edas#Reception', 'iasted#Coctail_reception', '1.0'),
#  ('edas#ConferenceEvent', 'iasted#Conference_activity', '1.0'),
#  ('edas#SlideSet', 'iasted#Transparency', '1.0'),
#  ('edas#Paper', 'iasted#Submission', '1.0'),
#  ('edas#ConferenceVenuePlace', 'iasted#Conference_building', '1.0'),
#  ('edas#DiningPlace', 'iasted#Conference_restaurant', '1.0'),
#  ('conference#Person', 'edas#Person', '1.0'),
#  ('conference#Conference_participant', 'edas#Attendee', '1.0'),
#  ('conference#Organization', 'edas#Organization', '1.0'),
#  ('conference#Reviewer', 'edas#Reviewer', '1.0'),
#  ('conference#has_the_first_name', 'edas#hasFirstName', '1.0'),
#  ('conference#Conference_part', 'edas#ConferenceEvent', '1.0'),
#  ('conference#Workshop', 'edas#Workshop', '1.0'),
#  ('conference#Conference_document', 'edas#Document', '1.0'),
#  ('conference#Paper', 'edas#Paper', '1.0'),
#  ('conference#has_a_review_expertise', 'edas#hasRating', '1.0'),
#  ('conference#has_the_last_name', 'edas#hasLastName', '1.0'),
#  ('conference#Review', 'edas#Review', '1.0'),
#  ('conference#Conference_volume', 'edas#Conference', '1.0'),
#  ('conference#Rejected_contribution', 'edas#RejectedPaper', '1.0'),
#  ('conference#Topic', 'edas#Topic', '1.0'),
#  ('conference#Accepted_contribution', 'edas#AcceptedPaper', '1.0'),
#  ('conference#Regular_author', 'edas#Author', '1.0'),
#  ('cmt#Document', 'ekaw#Document', '1.0'),
#  ('cmt#ConferenceMember', 'ekaw#Conference_Participant', '1.0'),
#  ('cmt#Author', 'ekaw#Paper_Author', '1.0'),
#  ('cmt#writtenBy', 'ekaw#reviewWrittenBy', '1.0'),
#  ('cmt#hasBeenAssigned', 'ekaw#reviewerOfPaper', '1.0'),
#  ('cmt#Person', 'ekaw#Person', '1.0'),
#  ('cmt#Conference', 'ekaw#Conference', '1.0'),
#  ('cmt#assignedTo', 'ekaw#hasReviewer', '1.0'),
#  ('cmt#Review', 'ekaw#Review', '1.0'),
#  ('cmt#Paper', 'ekaw#Paper', '1.0'),
#  ('cmt#PaperFullVersion', 'ekaw#Regular_Paper', '1.0'),
#  ('cmt#ProgramCommitteeChair', 'confOf#Chair_PC', '1.0'),
#  ('cmt#writePaper', 'confOf#writes', '1.0'),
#  ('cmt#Author', 'confOf#Author', '1.0'),
#  ('cmt#ConferenceMember', 'confOf#Member', '1.0'),
#  ('cmt#Administrator', 'confOf#Administrator', '1.0'),
#  ('cmt#title', 'confOf#hasTitle', '1.0'),
#  ('cmt#SubjectArea', 'confOf#Topic', '1.0'),
#  ('cmt#PaperFullVersion', 'confOf#Paper', '1.0'),
#  ('cmt#hasBeenAssigned', 'confOf#reviewes', '1.0'),
#  ('cmt#hasAuthor', 'confOf#writtenBy', '1.0'),
#  ('cmt#Conference', 'confOf#Conference', '1.0'),
#  ('cmt#ProgramCommitteeMember', 'confOf#Member_PC', '1.0'),
#  ('cmt#hasSubjectArea', 'confOf#dealsWith', '1.0'),
#  ('cmt#Person', 'confOf#Person', '1.0'),
#  ('cmt#Paper', 'confOf#Contribution', '1.0'),
#  ('cmt#email', 'confOf#hasEmail', '1.0'),
#  ('cmt#Person', 'edas#Person', '1.0'),
#  ('cmt#Conference', 'edas#Conference', '1.0'),
#  ('cmt#Author', 'edas#Author', '1.0'),
#  ('cmt#Reviewer', 'edas#Reviewer', '1.0'),
#  ('cmt#hasConferenceMember', 'edas#hasMember', '1.0'),
#  ('cmt#memberOfConference', 'edas#isMemberOf', '1.0'),
#  ('cmt#ConferenceChair', 'edas#ConferenceChair', '1.0'),
#  ('cmt#Review', 'edas#Review', '1.0'),
#  ('cmt#Document', 'edas#Document', '1.0'),
#  ('cmt#Paper', 'edas#Paper', '1.0'),
#  ('cmt#hasAuthor', 'edas#isWrittenBy', '1.0'),
#  ('cmt#hasBeenAssigned', 'edas#isReviewing', '1.0'),
#  ('cmt#assignedTo', 'edas#isReviewedBy', '1.0'),
#  ('conference#Abstract', 'sigkdd#Abstract', '1.0'),
#  ('conference#Invited_speaker', 'sigkdd#Invited_Speaker', '1.0'),
#  ('conference#Regular_author', 'sigkdd#Author', '1.0'),
#  ('conference#Review', 'sigkdd#Review', '1.0'),
#  ('conference#Program_committee', 'sigkdd#Program_Committee', '1.0'),
#  ('conference#Conference_volume', 'sigkdd#Conference', '1.0'),
#  ('conference#Conference_fees', 'sigkdd#Fee', '1.0'),
#  ('conference#has_an_email', 'sigkdd#E-mail', '1.0'),
#  ('conference#Paper', 'sigkdd#Paper', '1.0'),
#  ('conference#Organizing_committee', 'sigkdd#Organizing_Committee', '1.0'),
#  ('conference#Person', 'sigkdd#Person', '1.0'),
#  ('conference#Committee', 'sigkdd#Committee', '1.0'),
#  ('conference#is_given_by', 'sigkdd#presentationed_by', '1.0'),
#  ('conference#gives_presentations', 'sigkdd#presentation', '1.0'),
#  ('conference#Conference_document', 'sigkdd#Document', '1.0'),
#  ('cmt#Conference', 'sigkdd#Conference', '1.0'),
#  ('cmt#Paper', 'sigkdd#Paper', '1.0'),
#  ('cmt#ProgramCommitteeMember', 'sigkdd#Program_Committee_member', '1.0'),
#  ('cmt#Document', 'sigkdd#Document', '1.0'),
#  ('cmt#ConferenceChair', 'sigkdd#General_Chair', '1.0'),
#  ('cmt#email', 'sigkdd#E-mail', '1.0'),
#  ('cmt#Review', 'sigkdd#Review', '1.0'),
#  ('cmt#ProgramCommittee', 'sigkdd#Program_Committee', '1.0'),
#  ('cmt#ProgramCommitteeChair', 'sigkdd#Program_Chair', '1.0'),
#  ('cmt#Author', 'sigkdd#Author', '1.0'),
#  ('cmt#submitPaper', 'sigkdd#submit', '1.0'),
#  ('cmt#Person', 'sigkdd#Person', '1.0'),
#  ('conference#Conference_participant', 'confOf#Participant', '1.0'),
#  ('conference#has_an_email', 'confOf#hasEmail', '1.0'),
#  ('conference#Poster', 'confOf#Poster', '1.0'),
#  ('conference#Organization', 'confOf#Organization', '1.0'),
#  ('conference#Topic', 'confOf#Topic', '1.0'),
#  ('conference#Workshop', 'confOf#Workshop', '1.0'),
#  ('conference#Paper', 'confOf#Paper', '1.0'),
#  ('conference#Person', 'confOf#Person', '1.0'),
#  ('conference#Conference_contribution', 'confOf#Contribution', '1.0'),
#  ('conference#Tutorial', 'confOf#Tutorial', '1.0'),
#  ('conference#Conference_volume', 'confOf#Conference', '1.0'),
#  ('conference#has_a_track-workshop-tutorial_topic', 'confOf#hasTopic', '1.0'),
#  ('conference#Regular_author', 'confOf#Author', '1.0'),
#  ('conference#has_the_last_name', 'confOf#hasSurname', '1.0'),
#  ('conference#has_the_first_name', 'confOf#hasFirstName', '1.0'),
#  ('edas#ConferenceDinner', 'ekaw#Conference_Banquet', '1.0'),
#  ('edas#AcademicEvent', 'ekaw#Scientific_Event', '1.0'),
#  ('edas#AcceptedPaper', 'ekaw#Accepted_Paper', '1.0'),
#  ('edas#isReviewedBy', 'ekaw#hasReviewer', '1.0'),
#  ('edas#Place', 'ekaw#Location', '1.0'),
#  ('edas#AcademiaOrganization', 'ekaw#Academic_Institution', '1.0'),
#  ('edas#SocialEvent', 'ekaw#Social_Event', '1.0'),
#  ('edas#isReviewing', 'ekaw#reviewerOfPaper', '1.0'),
#  ('edas#Organization', 'ekaw#Organisation', '1.0'),
#  ('edas#Author', 'ekaw#Paper_Author', '1.0'),
#  ('edas#isLocationOf', 'ekaw#locationOf', '1.0'),
#  ('edas#Topic', 'ekaw#Research_Topic', '1.0'),
#  ('edas#Document', 'ekaw#Document', '1.0'),
#  ('edas#RejectedPaper', 'ekaw#Rejected_Paper', '1.0'),
#  ('edas#ConferenceEvent', 'ekaw#Event', '1.0'),
#  ('edas#SessionChair', 'ekaw#Session_Chair', '1.0'),
#  ('edas#Person', 'ekaw#Person', '1.0'),
#  ('edas#Programme', 'ekaw#Programme_Brochure', '1.0'),
#  ('edas#Review', 'ekaw#Review', '1.0'),
#  ('edas#Workshop', 'ekaw#Workshop', '1.0'),
#  ('edas#Paper', 'ekaw#Paper', '1.0'),
#  ('edas#Attendee', 'ekaw#Conference_Participant', '1.0'),
#  ('edas#hasLocation', 'ekaw#heldIn', '1.0'),
#  ('cmt#Conference', 'conference#Conference_volume', '1.0'),
#  ('cmt#Preference', 'conference#Review_preference', '1.0'),
#  ('cmt#Author', 'conference#Regular_author', '1.0'),
#  ('cmt#Person', 'conference#Person', '1.0'),
#  ('cmt#email', 'conference#has_an_email', '1.0'),
#  ('cmt#Co-author', 'conference#Contribution_co-author', '1.0'),
#  ('cmt#PaperAbstract', 'conference#Abstract', '1.0'),
#  ('cmt#Document', 'conference#Conference_document', '1.0'),
#  ('cmt#Review', 'conference#Review', '1.0'),
#  ('cmt#Conference', 'conference#Conference', '1.0'),
#  ('cmt#ProgramCommittee', 'conference#Program_committee', '1.0'),
#  ('cmt#Chairman', 'conference#Chair', '1.0'),
#  ('cmt#SubjectArea', 'conference#Topic', '1.0'),
#  ('cmt#assignedByReviewer', 'conference#invited_by', '1.0'),
#  ('cmt#assignExternalReviewer', 'conference#invites_co-reviewers', '1.0'),
#  ('cmt#Author', 'iasted#Author', '1.0'),
#  ('cmt#Review', 'iasted#Review', '1.0'),
#  ('cmt#Person', 'iasted#Person', '1.0'),
#  ('cmt#Reviewer', 'iasted#Reviewer', '1.0'),
#  ('ekaw#Location', 'iasted#Place', '1.0'),
#  ('ekaw#Document', 'iasted#Document', '1.0'),
#  ('ekaw#Event', 'iasted#Activity', '1.0'),
#  ('ekaw#Person', 'iasted#Person', '1.0'),
#  ('ekaw#Paper_Author', 'iasted#Author', '1.0'),
#  ('ekaw#Session', 'iasted#Session', '1.0'),
#  ('ekaw#Review', 'iasted#Review', '1.0'),
#  ('ekaw#Conference_Banquet', 'iasted#Dinner_banquet', '1.0'),
#  ('ekaw#Tutorial', 'iasted#Tutorial', '1.0'),
#  ('ekaw#Session_Chair', 'iasted#Session_chair', '1.0')]

# %%
# LogMap test
def is_test(test_onto, key):
    return tuple([el.split("#")[0] for el in key]) in test_onto

results = []
prefix = "/data/Vivek/IBM/IBM-Internship/conference_ontologies/"
for i in list(range(0, len(ontologies_in_alignment), 3)):
    test_onto = ontologies_in_alignment[i:i+3]
    tp_tot, fn_tot, fp_tot = [], [], []
    for ont_pair in test_onto:
        a, b, c = prefix + ont_pair[0], prefix + ont_pair[1], ont_pair[0] + "-" + ont_pair[1]
        # !mkdir $c
        java_command = "java -jar logmap-matcher/target/logmap-matcher-4.0.jar MATCHER file:" +  a + ".owl file:" + b + ".owl " + \
                        "/data/Vivek/IBM/IBM-Internship/" + c + "/ false"
        process = subprocess.Popen(java_command.split(), stdout=subprocess.PIPE)
        output, error = process.communicate()
        
        pred_aml = [l.strip().split("\t")[:2] for l in open(c + "/logmap2_mappings.tsv", "r").read().split("\n")[:-1]]
        pred_aml = [tuple([el.split("/")[-1] for el in key]) for key in pred_aml]
        tp = [elem for elem in pred_aml if data[elem]]
        fn = [key for key in gt_mappings if key not in set(pred_aml) and is_test(test_onto, key)]
        fp = [elem for elem in pred_aml if not data[elem]]
        
        tp_tot.extend(tp)
        fn_tot.extend(fn)
        fp_tot.extend(fp)
        
        # !rm -rf $c
   
    precision = len(tp_tot)/(len(tp_tot)+len(fp_tot))
    recall = len(tp_tot)/(len(tp_tot)+len(fn_tot))
    f1score = 2 * precision * recall / (precision + recall)
    f2score = 5 * precision * recall / (4 * precision + recall)
    f0_5score = 1.25 * precision * recall / (0.25 * precision + recall)
    print (test_onto, precision, recall, f1score, f2score, f0_5score)
    
    metrics = [precision, recall, f1score, f2score, f0_5score]
    results.append(metrics)
    
    
    
print ("Final Results:", np.mean(results, axis=0))
# Out:
# [('cmt', 'ekaw')] 0.75 0.5454545454545454 0.631578947368421 0.5769230769230769 0.6976744186046512
# [('cmt', 'sigkdd')] 1.0 0.9166666666666666 0.9565217391304348 0.9322033898305083 0.9821428571428572
# [('conference', 'sigkdd')] 0.7857142857142857 0.7333333333333333 0.7586206896551724 0.7432432432432431 0.7746478873239436
# [('edas', 'iasted')] 0.875 0.3684210526315789 0.5185185185185185 0.41666666666666663 0.6862745098039215
# [('ekaw', 'iasted')] 0.7 0.7 0.7 0.7 0.7
# [('cmt', 'confOf')] 0.8333333333333334 0.3125 0.45454545454545453 0.35714285714285715 0.625
# [('cmt', 'iasted')] 0.8 1.0 0.888888888888889 0.9523809523809523 0.8333333333333334
# Final Results: [0.82057823 0.65376794 0.70123918 0.66836574 0.75701043]

# %%
# LogMap test
def is_test(test_onto, key):
    return tuple([el.split("#")[0] for el in key]) in test_onto

results = []
prefix = "/data/Vivek/IBM/IBM-Internship/conference_ontologies/"
for ont_pair in ontologies_in_alignment:
    a, b, c = prefix + ont_pair[0], prefix + ont_pair[1], "LogMap-conference-results/" + ont_pair[0] + "-" + ont_pair[1]
    # !rm -rf $c
    # !mkdir $c
    java_command = "java -jar logmap-matcher/target/logmap-matcher-4.0.jar MATCHER file:" +  a + ".owl file:" + b + ".owl " + \
                    "/data/Vivek/IBM/IBM-Internship/" + c + "/ false"
    process = subprocess.Popen(java_command.split(), stdout=subprocess.PIPE)
    output, error = process.communicate()
        
    pred_aml = [l.strip().split("\t") for l in open(c + "/logmap2_mappings.tsv", "r").read().split("\n")[:-1]]
    pred_aml = [tuple([el.split("/")[-1] for el in key]) for key in pred_aml]
    results.extend(pred_aml)

# %%
data_conf, data_german, aml_data, emb_indexer, emb_indexer_inv, emb_vals, neighbours_dicts, max_paths, max_pathlen, max_types, ontologies_in_alignment = pickle.load(open("Input/data_conf_oaei_german_aml_thresh.pkl", "rb"))
aml_data_corrected = dict(aml_data)
for elem in aml_data:
    if elem in corrected_aml:
        aml_data_corrected[elem] = int(corrected_aml[elem])

# %%
fn = [l.split("\t")[:5] for l in open("validated_fn.tsv", "r").read().split("\n")[1:1200]]
fn = [[False if el =="FALSE" else True if el=="TRUE" else el for el in elem] for elem in fn]
corrected_aml = {tuple(elem[:2]): sum(elem[2:]) >= 2 for elem in fn}

# %%
fp = [l.split("\t")[:3] for l in open("validated_fp.tsv", "r").read().split("\n")[1:]]
fp = [[False if el =="FALSE" else True if el=="TRUE" else el for el in elem] for elem in fp]
for elem in fp:
    corrected_aml[tuple(elem[:2])] = elem[2]

# %%
[elem for elem in aml_data_corrected.items() if aml_data_corrected[elem[0]] != aml_data_corrected[elem[0]]
# Out:
# [['cmt#Paper', 'edas#Paper', True],
#  ['cmt#Paper', 'sigkdd#Paper', True],
#  ['edas#Paper', 'sigkdd#Paper', True],
#  ['edas#Paper', 'ekaw#Paper', True],
#  ['cmt#Paper', 'ekaw#Paper', True],
#  ['cmt#Author', 'sigkdd#Author', True],
#  ['cmt#Review', 'ekaw#Review', True],
#  ['cmt#Review', 'iasted#Review', True],
#  ['cmt#Person', 'edas#Person', True],
#  ['cmt#Reviewer', 'iasted#Reviewer', True],
#  ['ekaw#Paper', 'sigkdd#Paper', True],
#  ['iasted#Speaker', 'sigkdd#Speaker', True],
#  ['ekaw#Review', 'iasted#Review', True],
#  ['iasted#Registration_fee', 'sigkdd#Registration_fee', True],
#  ['conference#Person', 'edas#Person', True],
#  ['cmt#Reviewer', 'conference#Reviewer', True],
#  ['cmt#Person', 'conference#Person', True],
#  ['cmt#Review', 'conference#Review', True],
#  ['confOf#Author', 'sigkdd#Author', True],
#  ['confOf#Social_event', 'ekaw#Social_Event', True],
#  ['conference#Reviewer', 'iasted#Reviewer', True],
#  ['conference#Review', 'ekaw#Review', True],
#  ['confOf#Person', 'sigkdd#Person', True],
#  ['edas#AcceptedPaper', 'ekaw#Accepted_Paper', True],
#  ['conference#Program_committee', 'sigkdd#Program_Committee', True],
#  ['conference#Review', 'iasted#Review', True],
#  ['cmt#Author', 'confOf#Author', True],
#  ['conference#Organizing_committee', 'sigkdd#Organizing_Committee', True],
#  ['cmt#ProgramCommitteeMember', 'conference#Committee_member', True],
#  ['confOf#Person', 'edas#Person', True],
#  ['cmt#Person', 'sigkdd#Person', True],
#  ['cmt#Person', 'confOf#Person', True],
#  ['edas#Person', 'sigkdd#Person', True],
#  ['conference#Abstract', 'ekaw#Abstract', True],
#  ['iasted#Author', 'sigkdd#Author', True],
#  ['iasted#Deadline', 'sigkdd#Deadline', True],
#  ['conference#Person', 'confOf#Person', True],
#  ['cmt#Conference', 'edas#Conference', True],
#  ['cmt#Author', 'iasted#Author', True],
#  ['edas#SocialEvent', 'ekaw#Social_Event', True],
#  ['confOf#Social_event', 'edas#SocialEvent', True],
#  ['cmt#Review', 'edas#Review', True],
#  ['ekaw#Review', 'sigkdd#Review', True],
#  ['cmt#Review', 'sigkdd#Review', True],
#  ['edas#Review', 'sigkdd#Review', True],
#  ['edas#Review', 'ekaw#Review', True],
#  ['conference#Person', 'sigkdd#Person', True],
#  ['cmt#ProgramCommitteeMember', 'confOf#Member_PC', True],
#  ['confOf#Author', 'iasted#Author', True],
#  ['conference#Conference_participant', 'ekaw#Conference_Participant', True],
#  ['ekaw#Abstract', 'sigkdd#Abstract', True],
#  ['confOf#Student', 'ekaw#Student', True],
#  ['iasted#Main_office', 'sigkdd#Main_office', True],
#  ['edas#Author', 'sigkdd#Author', True],
#  ['iasted#Review', 'sigkdd#Review', True],
#  ['edas#Review', 'iasted#Review', True],
#  ['edas#RejectedPaper', 'ekaw#Rejected_Paper', True],
#  ['cmt#Administrator', 'confOf#Administrator', True],
#  ['edas#Conference', 'sigkdd#Conference', True],
#  ['ekaw#Session', 'iasted#Session', True],
#  ['cmt#Author', 'edas#Author', True],
#  ['iasted#Person', 'sigkdd#Person', True],
#  ['confOf#University', 'ekaw#University', True],
#  ['conference#Review', 'sigkdd#Review', True],
#  ['conference#Review', 'edas#Review', True],
#  ['iasted#Conference_hall', 'sigkdd#Conference_hall', True],
#  ['iasted#Listener', 'sigkdd#Listener', True],
#  ['iasted#Place', 'sigkdd#Place', True],
#  ['cmt#Paper', 'conference#Paper', True],
#  ['confOf#Person', 'iasted#Person', True],
#  ['cmt#Document', 'edas#Document', True],
#  ['conference#Paper', 'edas#Paper', True],
#  ['cmt#Conference', 'sigkdd#Conference', True],
#  ['edas#Document', 'ekaw#Document', True],
#  ['cmt#Paper', 'confOf#Paper', True],
#  ['confOf#Paper', 'sigkdd#Paper', True],
#  ['confOf#Paper', 'edas#Paper', True],
#  ['cmt#ConferenceChair', 'edas#ConferenceChair', True],
#  ['cmt#Person', 'ekaw#Person', True],
#  ['confOf#Workshop', 'ekaw#Workshop', True],
#  ['confOf#Conference', 'ekaw#Conference', True],
#  ['edas#Person', 'ekaw#Person', True],
#  ['cmt#Document', 'ekaw#Document', True],
#  ['conference#Paper', 'sigkdd#Paper', True],
#  ['edas#SessionChair', 'ekaw#Session_Chair', True],
#  ['conference#Invited_speaker', 'sigkdd#Invited_Speaker', True],
#  ['ekaw#Invited_Speaker', 'sigkdd#Invited_Speaker', True],
#  ['confOf#Reception', 'edas#Reception', True],
#  ['cmt#Reviewer', 'edas#Reviewer', True],
#  ['conference#Conference', 'sigkdd#Conference', True],
#  ['confOf#City', 'iasted#City', True],
#  ['conference#Conference', 'edas#Conference', True],
#  ['cmt#Conference', 'conference#Conference', True],
#  ['edas#Workshop', 'ekaw#Workshop', True],
#  ['confOf#Workshop', 'edas#Workshop', True],
#  ['edas#SessionChair', 'iasted#Session_chair', True],
#  ['ekaw#Paper_Author', 'sigkdd#Author_of_paper', True],
#  ['conference#Invited_speaker', 'ekaw#Invited_Speaker', True],
#  ['edas#Presenter', 'ekaw#Presenter', True],
#  ['conference#Presentation', 'iasted#Presentation', False],
#  ['cmt#ProgramCommitteeMember', 'ekaw#PC_Member', False],
#  ['conference#Workshop', 'edas#Workshop', True],
#  ['confOf#Banquet', 'ekaw#Conference_Banquet', True],
#  ['conference#Conference_part', 'confOf#Working_event', False],
#  ['cmt#ProgramCommitteeChair', 'confOf#Chair_PC', True],
#  ['ekaw#Session_Chair', 'iasted#Session_chair', True],
#  ['conference#Paper', 'confOf#Paper', True],
#  ['cmt#ProgramCommitteeMember', 'sigkdd#Program_Committee_member', True],
#  ['conference#Poster', 'confOf#Poster', True],
#  ['conference#Workshop', 'confOf#Workshop', True],
#  ['cmt#ProgramCommitteeChair', 'ekaw#PC_Chair', True],
#  ['confOf#Tutorial', 'ekaw#Tutorial', True],
#  ['confOf#Member_PC', 'sigkdd#Program_Committee_member', True],
#  ['iasted#Student_registration_fee', 'sigkdd#Registration_Student', True],
#  ['confOf#Chair_PC', 'ekaw#PC_Chair', True],
#  ['conference#Person', 'ekaw#Person', True],
#  ['confOf#Author', 'ekaw#Paper_Author', True],
#  ['conference#Workshop', 'ekaw#Workshop', True],
#  ['conference#Chair', 'edas#ConferenceChair', True],
#  ['ekaw#OC_Member', 'sigkdd#Organizing_Committee_member', True],
#  ['conference#Topic', 'edas#Topic', True],
#  ['conference#Track', 'ekaw#Track', True],
#  ['edas#Place', 'iasted#Place', True],
#  ['conference#Tutorial', 'iasted#Tutorial', True],
#  ['conference#Abstract', 'sigkdd#Abstract', True],
#  ['edas#CoffeeBreak', 'iasted#Coffee_break', True],
#  ['conference#Presentation', 'edas#PaperPresentation', False],
#  ['confOf#Member_PC', 'ekaw#PC_Member', True],
#  ['cmt#Author', 'ekaw#Paper_Author', True],
#  ['iasted#Conference_hotel', 'sigkdd#Hotel', True],
#  ['confOf#Tutorial', 'iasted#Tutorial', True],
#  ['conference#Tutorial', 'confOf#Tutorial', True],
#  ['conference#Call_for_paper', 'edas#CallForPapers', True],
#  ['cmt#Conference', 'ekaw#Conference', True],
#  ['ekaw#PC_Member', 'sigkdd#Program_Committee_member', True],
#  ['cmt#Person', 'iasted#Person', True],
#  ['ekaw#Person', 'iasted#Person', True],
#  ['cmt#Document', 'sigkdd#Document', True],
#  ['conference#Conference_participant', 'confOf#Participant', True],
#  ['conference#Invited_talk', 'ekaw#Invited_Talk', True],
#  ['conference#Tutorial', 'ekaw#Tutorial', True],
#  ['edas#Person', 'iasted#Person', True],
#  ['confOf#Participant', 'ekaw#Conference_Participant', True],
#  ['conference#Track-workshop_chair', 'ekaw#Workshop_Chair', True],
#  ['ekaw#Tutorial', 'iasted#Tutorial', True],
#  ['confOf#Poster', 'ekaw#Poster_Paper', True],
#  ['ekaw#Document', 'sigkdd#Document', True],
#  ['edas#Document', 'sigkdd#Document', True],
#  ['conference#Conference_document', 'ekaw#Document', True],
#  ['ekaw#Person', 'sigkdd#Person', True],
#  ['ekaw#Paper_Author', 'iasted#Author', True],
#  ['cmt#Document', 'conference#Conference_document', True],
#  ['confOf#Organization', 'ekaw#Organisation', True],
#  ['conference#Poster', 'ekaw#Poster_Paper', True],
#  ['confOf#Person', 'ekaw#Person', True],
#  ['cmt#ConferenceMember', 'confOf#Member', True],
#  ['cmt#Co-author', 'conference#Contribution_co-author', True],
#  ['confOf#Trip', 'ekaw#Conference_Trip', True],
#  ['conference#Committee_member', 'sigkdd#Program_Committee_member', True],
#  ['confOf#Country', 'edas#Country', True],
#  ['edas#Author', 'iasted#Author', True],
#  ['edas#Organization', 'ekaw#Organisation', True],
#  ['cmt#ConferenceChair', 'conference#Chair', True],
#  ['edas#Reviewer', 'iasted#Reviewer', True],
#  ['conference#Person', 'iasted#Person', True],
#  ['edas#ConferenceSession', 'ekaw#Conference_Session', True],
#  ['cmt#ProgramCommitteeChair', 'sigkdd#Program_Chair', True],
#  ['conference#Reviewer', 'edas#Reviewer', True],
#  ['confOf#Organization', 'edas#Organization', True],
#  ['conference#Topic', 'confOf#Topic', True],
#  ['confOf#Author', 'edas#Author', True],
#  ['confOf#Topic', 'edas#Topic', True],
#  ['edas#Place', 'sigkdd#Place', True],
#  ['edas#Conference', 'ekaw#Conference', True],
#  ['iasted#Deadline_hotel_reservation',
#   'sigkdd#Deadline_Author_notification',
#   False],
#  ['confOf#Event', 'ekaw#Event', True],
#  ['conference#Submitted_contribution', 'ekaw#Submitted_Paper', True],
#  ['cmt#AuthorNotReviewer', 'sigkdd#Author_of_paper', False],
#  ['iasted#Fee', 'sigkdd#Fee', True],
#  ['iasted#Nonmember_registration_fee', 'sigkdd#Registration_Non-Member', True],
#  ['cmt#ProgramCommittee', 'conference#Program_committee', True],
#  ['conference#Committee', 'sigkdd#Committee', True],
#  ['confOf#Submission_event', 'iasted#Submission', False],
#  ['iasted#Document', 'sigkdd#Document', True],
#  ['cmt#Document', 'iasted#Document', True],
#  ['edas#Document', 'iasted#Document', True],
#  ['conference#Accepted_contribution', 'ekaw#Accepted_Paper', True],
#  ['ekaw#Document', 'iasted#Document', True],
#  ['conference#Rejected_contribution', 'ekaw#Rejected_Paper', True],
#  ['ekaw#Conference', 'sigkdd#Conference', True],
#  ['ekaw#Tutorial_Chair', 'iasted#Tutorial_speaker', False],
#  ['conference#Reviewed_contribution', 'ekaw#Evaluated_Paper', True],
#  ['conference#Conference_document', 'sigkdd#Document', True],
#  ['conference#Accepted_contribution', 'edas#AcceptedPaper', True],
#  ['conference#Late_paid_applicant', 'ekaw#Late-Registered_Participant', True],
#  ['conference#Early_paid_applicant',
#   'ekaw#Early-Registered_Participant',
#   True],
#  ['conference#Rejected_contribution', 'edas#RejectedPaper', True],
#  ['cmt#Conference', 'confOf#Conference', True],
#  ['confOf#Conference', 'sigkdd#Conference', True],
#  ['conference#Conference_proceedings', 'ekaw#Conference_Proceedings', True],
#  ['conference#Conference', 'ekaw#Conference', True],
#  ['conference#Conference', 'confOf#Conference', True],
#  ['cmt#ProgramCommittee', 'sigkdd#Program_Committee', True],
#  ['confOf#Conference', 'edas#Conference', True],
#  ['edas#Sponsorship', 'iasted#Sponzorship', True],
#  ['edas#WelcomeTalk', 'iasted#Welcome_address', True],
#  ['confOf#Camera_Ready_event', 'ekaw#Camera_Ready_Paper', False],
#  ['conference#Conference_contribution', 'confOf#Contribution', True],
#  ['cmt#SubjectArea', 'confOf#Topic', True],
#  ['edas#ConferenceSession', 'iasted#Session', True],
#  ['cmt#SubjectArea', 'conference#Topic', True],
#  ['edas#Author', 'ekaw#Paper_Author', True],
#  ['conference#Regular_contribution', 'ekaw#Regular_Paper', True],
#  ['conference#Conference_document', 'iasted#Document', True],
#  ['conference#Topic', 'ekaw#Event', False],
#  ['cmt#SubjectArea', 'edas#CommunicationsTopic', False]]

# %%
corrected_aml.items()
# Out:
# dict_items([(('edas#ActivePaper', 'ekaw#Paper'), False), (('conference#Conference_part', 'edas#Conference'), False), (('cmt#Paper', 'edas#ActivePaper'), False), (('cmt#Reviewer', 'ekaw#Review'), False), (('cmt#Chairman', 'edas#ConferenceChair'), False), (('cmt#Co-author', 'sigkdd#Author'), False), (('conference#Presentation', 'ekaw#Individual_Presentation'), False), (('cmt#Reviewer', 'sigkdd#Author'), False), (('cmt#Reviewer', 'ekaw#Possible_Reviewer'), False), (('cmt#Chairman', 'edas#SessionChair'), False), (('conference#Conference_document', 'edas#Conference'), False), (('conference#Conference_document', 'edas#ConferenceEvent'), False), (('cmt#Chairman', 'sigkdd#Speaker'), False), (('iasted#Building', 'sigkdd#Hotel'), False), (('cmt#Conference', 'conference#Conference_volume'), False), (('iasted#Hotel_room', 'sigkdd#Hotel'), False), (('iasted#Memeber_registration_fee', 'sigkdd#Registration_fee'), False), (('conference#Paper', 'ekaw#Paper'), False), (('ekaw#Possible_Reviewer', 'iasted#Reviewer'), False), (('cmt#Conference', 'conference#Conference_part'), False), (('conference#Conference_volume', 'ekaw#Conference'), False), (('cmt#Reviewer', 'iasted#Review'), False), (('cmt#ConferenceMember', 'conference#Committee_member'), False), (('ekaw#Conference_Session', 'iasted#Conference_activity'), False), (('cmt#ConferenceMember', 'ekaw#Conference_Session'), False), (('edas#AcceptedPaper', 'ekaw#Paper'), False), (('edas#ActivePaper', 'ekaw#Assigned_Paper'), False), (('ekaw#Conference', 'iasted#Conference_state'), False), (('confOf#Paper', 'ekaw#Paper'), False), (('cmt#Review', 'edas#Paper'), False), (('cmt#Review', 'iasted#Reviewer'), False), (('ekaw#Conference', 'iasted#Conference_city'), False), (('edas#Sponsorship', 'sigkdd#Sponzor'), False), (('cmt#Chairman', 'sigkdd#Author'), False), (('conference#Reviewer', 'ekaw#Possible_Reviewer'), False), (('edas#ConferenceChair', 'sigkdd#Speaker'), False), (('cmt#Paper', 'confOf#Contribution'), False), (('edas#GovernmentOrganization', 'ekaw#Organising_Agency'), False), (('ekaw#Conference_Session', 'iasted#Session_room'), False), (('cmt#Author', 'sigkdd#Author_of_paper'), False), (('confOf#Organization', 'edas#Conference'), False), (('edas#Paper', 'ekaw#Camera_Ready_Paper'), False), (('edas#ConferenceEvent', 'iasted#Activity'), False), (('conference#Conference_volume', 'edas#Conference'), False), (('ekaw#Conference', 'iasted#Conference_hall'), False), (('cmt#Meta-Reviewer', 'ekaw#Possible_Reviewer'), False), (('cmt#Co-author', 'confOf#Author'), False), (('cmt#Review', 'conference#Reviewer'), False), (('conference#Conference_volume', 'ekaw#Conference_Session'), False), (('iasted#Nonauthor_registration_fee', 'sigkdd#Registration_fee'), False), (('conference#Reviewer', 'iasted#Review'), False), (('ekaw#Conference', 'iasted#Conference_building'), False), (('cmt#ConferenceMember', 'ekaw#Conference_Participant'), False), (('cmt#ConferenceMember', 'conference#Active_conference_participant'), False), (('confOf#Participant', 'edas#Attendee'), True), (('conference#Conference_volume', 'iasted#Conference_city'), False), (('ekaw#Conference_Session', 'iasted#Conference_hall'), False), (('iasted#Deadline_for_notification_of_acceptance', 'sigkdd#Deadline_Author_notification'), True), (('cmt#ConferenceMember', 'conference#Conference_participant'), False), (('edas#PublishedPaper', 'ekaw#Submitted_Paper'), False), (('cmt#ExternalReviewer', 'conference#Reviewer'), False), (('cmt#ExternalReviewer', 'iasted#Reviewer'), False), (('edas#Paper', 'ekaw#Assigned_Paper'), False), (('cmt#Paper', 'ekaw#Regular_Paper'), False), (('ekaw#Regular_Paper', 'sigkdd#Paper'), False), (('edas#Paper', 'ekaw#Regular_Paper'), False), (('edas#Paper', 'ekaw#Submitted_Paper'), False), (('conference#Conference_volume', 'iasted#Conference_hall'), False), (('conference#Conference_volume', 'iasted#Conference_state'), False), (('cmt#Chairman', 'conference#Chair'), True), (('edas#ConferenceChair', 'ekaw#Conference_Participant'), False), (('cm ...

# %%
import requests

url = "https://montanaflynn-spellcheck.p.rapidapi.com/check/"

headers = {
    'x-rapidapi-host': "montanaflynn-spellcheck.p.rapidapi.com",
    'x-rapidapi-key': "9965b01207msh06291e57d6f2c55p1a6a16jsn0fb016da4a62"
    }

# inp_spellchecked = []
for concept in inp[731:]:
    querystring = {"text": concept}
    response = requests.request("GET", url, headers=headers, params=querystring).json()
    if response["suggestion"] != concept:
        resolved = str(concept)
        for word in response["corrections"]:
            if not re.search("[A-Z][A-Z]+", concept):
                resolved = resolved.replace(word, response["corrections"][word][0])
        
        inp_spellchecked.append(resolved)
        print (concept, resolved)
    else:
        inp_spellchecked.append(concept)
# Out:
# registeered applicant registered applicant
# technically organised by technically organized by
# ngo no
# sponzorship sponsorship

# %%
querystring = {"text": "technically Organised By"}
response = requests.request("GET", url, headers=headers, params=querystring)
response.json()
# Out:
# {'original': 'technically Organised By',
#  'suggestion': 'technically Organized By',
#  'corrections': {'Organised': ['Organized',
#    'Organist',
#    'Organism',
#    'Organizes',
#    'Disorganize',
#    'Organize',
#    'Agonized']}}

# %%
int(False)
# Out:
# 0

# %%
fn_spellchecked, fp_spellchecked = [dict(el) for el in pickle.load(open("test_v2.pkl", "rb"))]
fn_baseline, fp_baseline = [dict(el) for el in pickle.load(open("test_best.pkl", "rb"))]
fn_unhas, fp_unhas = [dict(el) for el in pickle.load(open("test_unhas.pkl", "rb"))]
fn_resolved, fp_resolved = [dict(el) for el in pickle.load(open("test_resolved.pkl", "rb"))]

fn_dict, fp_dict = {}, {}
def create_comparison_file(file, idx):
    fn, fp = [dict(el) for el in pickle.load(open(file, "rb"))]
    
    for key in fn:
        if key in fn_dict:
            fn_dict[key][idx] = fn[key]
        else:
            fn_dict[key] = ["N/A" for i in range(4)]
            fn_dict[key][idx] = fn[key]
    
    for key in fp:
        if key in fp_dict:
            fp_dict[key][idx] = fp[key]
        else:
            fp_dict[key] = ["N/A" for i in range(4)]
            fp_dict[key][idx] = fp[key]
    

create_comparison_file("test_best.pkl", 0)
create_comparison_file("test_unhas.pkl", 1)
create_comparison_file("test_v2.pkl", 2)
create_comparison_file("test_resolved.pkl", 3)

open("fn - comparison.tsv", "w+").write("\n".join(["\t".join([str(el) for el in flatten(el)]) for el in fn_dict.items()]))
open("fp - comparison.tsv", "w+").write("\n".join(["\t".join([str(el) for el in flatten(el)]) for el in fp_dict.items()]))
# Out:
# 7796

# %%
ontologies_in_alignment = pickle.load(open("data_path.pkl", "rb"))[-1]
ontologies_in_alignment
# Out:
# [['confOf', 'sigkdd'],
#  ['iasted', 'sigkdd'],
#  ['cmt', 'ekaw'],
#  ['confOf', 'iasted'],
#  ['conference', 'edas'],
#  ['cmt', 'sigkdd'],
#  ['ekaw', 'sigkdd'],
#  ['conference', 'confOf'],
#  ['conference', 'sigkdd'],
#  ['confOf', 'edas'],
#  ['cmt', 'conference'],
#  ['edas', 'iasted'],
#  ['conference', 'iasted'],
#  ['edas', 'sigkdd'],
#  ['ekaw', 'iasted'],
#  ['cmt', 'edas'],
#  ['edas', 'ekaw'],
#  ['cmt', 'confOf'],
#  ['confOf', 'ekaw'],
#  ['conference', 'ekaw'],
#  ['cmt', 'iasted']]

# %%
d = {('confOf#Organization', 'sigkdd#Organizator'): (1,2,3,4),
 ('iasted#Document', 'sigkdd#Document'): (5,6,78,8)}
[[str(el) for el in flatten(el)] for el in d.items()]
# Out:
# [['confOf#Organization', 'sigkdd#Organizator', '1', '2', '3', '4'],
#  ['iasted#Document', 'sigkdd#Document', '5', '6', '78', '8']]

# %%
abbreviations_dict = {}
final_dict = {}

for mapping in all_mappings:
    mapping = tuple([el.split("#")[1] for el in mapping])
    is_abb = re.search("[A-Z][A-Z]+", mapping[0])
    if is_abb:
        abbreviation = "".join([el[0].upper() for el in mapping[1].split("_")])
        if is_abb.group() in abbreviation:
            
            start = abbreviation.find(is_abb.group())
            end = start + len(is_abb.group())
            fullform = "_".join(mapping[1].split("_")[start:end])
            print ("left", mapping, abbreviation, fullform)
            
            rest_first = " ".join([el for el in mapping[0].replace(is_abb.group(), "").split("_") if el]).lower()
            rest_second = " ".join(mapping[1].split("_")[:start] + mapping[1].split("_")[end:])
            if is_abb.group() not in final_dict:
                final_dict[is_abb.group()] = [(fullform, rest_first, rest_second)]
            else:
                final_dict[is_abb.group()].append((fullform, rest_first, rest_second))

    is_abb = re.search("[A-Z][A-Z]+", mapping[1])
    if is_abb:
        abbreviation = "".join([el[0].upper() for el in mapping[0].split("_")])
        
        if is_abb.group() in abbreviation:
            start = abbreviation.find(is_abb.group())
            end = start + len(is_abb.group())
            fullform = "_".join(mapping[0].split("_")[start:end])
            print ("right", mapping, abbreviation, fullform)

            rest_first = " ".join([el for el in mapping[1].replace(is_abb.group(), "").split("_") if el]).lower()
            rest_second = " ".join(mapping[0].split("_")[:start] + mapping[0].split("_")[end:])
            if is_abb.group() not in final_dict:
                final_dict[is_abb.group()] = [(fullform, rest_first, rest_second)]
            else:
                final_dict[is_abb.group()].append((fullform, rest_first, rest_second))

keys = [el for el in list(set(flatten([flatten([tup[1:] for tup in final_dict[key]]) for key in final_dict]))) if el]
abb_embeds = dict(zip(keys, extractUSEEmbeddings(keys)))

scored_dict = {}
for abbr in final_dict:
    sim_list = [(tup[0], tup[1], tup[2], cos_sim(abb_embeds[tup[1]], abb_embeds[tup[2]])) if tup[1] and tup[2]
                else (tup[0], tup[1], tup[2], 0) for tup in final_dict[abbr]]
    scored_dict[abbr] = sorted(list(set(sim_list)), key=lambda x:x[-1], reverse=True)

resolved_dict = {key: scored_dict[key][0] for key in scored_dict}
filtered_dict = {key: " ".join(resolved_dict[key][0].split("_")) for key in resolved_dict if resolved_dict[key][-1] > 0.9}
inp_resolved = []
for concept in inp:
    for key in filtered_dict:
        concept = concept.replace(key, filtered_dict[key])
    inp_resolved.append(concept)
inp_resolved
# Out:
# left ('Chair_PC', 'Program_Chair') PC Program_Chair
# left ('Chair_PC', 'Program_Committee') PC Program_Committee
# left ('Chair_PC', 'Program_Committee_member') PCM Program_Committee
# left ('Member_PC', 'Program_Chair') PC Program_Chair
# left ('Member_PC', 'Program_Committee') PC Program_Committee
# left ('Member_PC', 'Program_Committee_member') PCM Program_Committee
# left ('Chair_PC', 'Presenter_city') PC Presenter_city
# left ('Member_PC', 'Presenter_city') PC Presenter_city
# left ('OC_Member', 'Organizing_Committee_member') OCM Organizing_Committee
# left ('OC_Member', 'Organizing_Committee') OC Organizing_Committee
# left ('PC_Member', 'Program_Chair') PC Program_Chair
# left ('PC_Member', 'Program_Committee') PC Program_Committee
# left ('PC_Member', 'Program_Committee_member') PCM Program_Committee
# left ('OC_Chair', 'Organizing_Committee_member') OCM Organizing_Committee
# left ('OC_Chair', 'Organizing_Committee') OC Organizing_Committee
# left ('PC_Chair', 'Program_Chair') PC Program_Chair
# left ('PC_Chair', 'Program_Committee') PC Program_Committee
# left ('PC_Chair', 'Program_Committee_member') PCM Program_Committee
# right ('Passive_conference_participant', 'Chair_PC') PCP Passive_conference
# right ('Passive_conference_participant', 'Member_PC') PCP Passive_conference
# right ('Program_committee', 'Chair_PC') PC Program_committee
# right ('Program_committee', 'Member_PC') PC Program_committee
# left ('SC_Member', 'Brief_introduction_for_Session_chair') BIFSC Session_chair
# left ('SC_Member', 'Session_chair') SC Session_chair
# left ('SC_Member', 'Sponsor_city') SC Sponsor_city
# left ('SC_Member', 'Sponsor_company_house') SCH Sponsor_company
# left ('OC_Member', 'One_conference_day') OCD One_conference
# left ('PC_Member', 'Presenter_city') PC Presenter_city
# left ('OC_Chair', 'One_conference_day') OCD One_conference
# left ('PC_Chair', 'Presenter_city') PC Presenter_city
# left ('Chair_PC', 'PC_Chair') PC PC_Chair
# left ('Member_PC', 'PC_Chair') PC PC_Chair
# right ('Submitted_contribution', 'SC_Member') SC Submitted_contribution
# right ('Steering_committee', 'SC_Member') SC Steering_committee
# right ('Passive_conference_participant', 'PC_Member') PCP Passive_conference
# right ('Passive_conference_participant', 'PC_Chair') PCP Passive_conference
# right ('Program_committee', 'PC_Member') PC Program_committee
# right ('Program_committee', 'PC_Chair') PC Program_committee
# right ('Organizing_committee', 'OC_Member') OC Organizing_committee
# right ('Organizing_committee', 'OC_Chair') OC Organizing_committee
# left ('paperID', 'is_dated_on') IDO is_dated

# %%
keys = [el for el in list(set(flatten([flatten([tup[1:] for tup in final_dict[key]]) for key in final_dict]))) if el]
abb_embeds = dict(zip(keys, extractUSEEmbeddings(keys)))

# %%
cos_sim(*extractUSEEmbeddings(["Conference Banquet", "Dinner Banquet"]))
# Out:
# 0.8085169792175293

# %%
len(pickle.load(open("../Input/data_german_dataset.pkl","rb"))[0])
# Out:
# 130000

# %%
scored_dict = {}
for abbr in final_dict:
    sim_list = [(tup[0], tup[1], tup[2], cos_sim(abb_embeds[tup[1]], abb_embeds[tup[2]])) if tup[1] and tup[2]
                else (tup[0], tup[1], tup[2], 0) for tup in final_dict[abbr]]
    scored_dict[abbr] = sorted(list(set(sim_list)), key=lambda x:x[-1], reverse=True)

# %%
inp_case_handled = []
for concept in inp:
    final_list = []
    for word in concept.split(" "):
        if not re.search("[A-Z][A-Z]+", concept):
            final_list.append(word.lower())
        else:
            final_list.append(word)
    case_resolved = " ".join(final_list)
    inp_case_handled.append(case_resolved)
    
inp_case_handled
# Out:
# ['pay',
#  'rejected by',
#  'Registration SIGMOD Member',
#  'is connected with',
#  'NGO',
#  'overhead projector',
#  'name of conference',
#  'call for participation',
#  'coffee break',
#  'scientifically organised by',
#  'volunteer',
#  'publisher',
#  'regular',
#  'add program committee member',
#  'contact email',
#  'part of event',
#  'dinner banquet',
#  'social program',
#  'decision',
#  'is sent by',
#  'was a committee chair of',
#  'organisation',
#  'paper',
#  'assign external reviewer',
#  'was a member of',
#  'has cost amount',
#  'session chair',
#  'single level conference',
#  'hotel',
#  'deadline hotel reservation',
#  'country',
#  'important dates',
#  'paper',
#  'has parts',
#  'event',
#  'paper due on',
#  'is the 1th part of',
#  'has surname',
#  'wireless communications topic',
#  'two level conference',
#  'has first name',
#  'bid',
#  'is designed for',
#  'author',
#  'double hotel room',
#  'review form',
#  'presentation',
#  'subject area',
#  'positive integer',
#  'deadline abstract submission',
#  'has a degree',
#  'is present in',
#  'related to event',
#  'reviews',
#  'topic',
#  'e-mail',
#  'has keyword',
#  'university',
#  'has street',
#  'reviewed contribution',
#  'call',
#  'occupy',
#  'ends on',
#  'presenter university',
#  'rejected paper',
#  'obtain',
#  'invited by',
#  'paper',
#  'updated version of',
#  'company',
#  'topic',
#  'call for paper',
#  'student',
#  'has reviewer',
#  'has updated version',
#  'invited talk',
#  'free time break',
#  'non academic event',
#  'best student paper supporter',
#  'publisher of',
#  'submit paper',
#  'author',
#  'program committee',
#  'TPC Member',
#  'listener',
#  'hotel fee',
#  'int',
#  'default choice',
#  'review of paper',
#  'author',
#  'poster',
#  'has amount of',
#  'web site',
#  'has location',
#  'subclass of',
#  'conference days',
#  'has a track-workshop-tutorial topic',
#  'welcome address',
#  'sponzorship',
#  'program committee',
#  'read by meta-reviewer',
#  'conference proceedings',
#  'regular contribution',
#  'reception',
#  'abstract',
#  'print hardcopy mailing manifests',
#  'Chair PC',
#  'has co-author',
#  'card',
#  'location',
#  'conference hall',
#  'is writen by',
#  'has email',
#  'antennas topic',
#  'trip city',
#  'has contributions',
#  'review',
#  'was a committee of',
#  'call for manuscripts',
#  'worker lecturer',
#  'video presentation',
#  'has email',
#  'reception',
#  'meta-review',
#  'inverse of part of 7',
#  'computer networks topic',
#  'paper presentation',
#  'coctail reception',
#  'slide set',
#  'has biography',
#  'subclass of',
#  'has an email',
#  'location',
#  'chair',
#  'receiving manuscript',
#  'user',
#  'has menu',
#  'author of',
#  'tip',
#  'is an abstract submission date',
#  'date',
#  'session room',
#  'committee',
#  'details entered by',
#  'committee',
#  'nonauthor registration fee',
#  'workshop',
#  'personal history',
#  'has call',
#  'program committee',
#  'speak in',
#  'programme brochure',
#  'end date',
#  'accepted contribution',
#  'enable virtual meeting',
#  'topic covered by',
#  'sponzor',
#  'has city',
#  'has topic',
#  'scientific event',
#  'has phone',
#  'co-chair',
#  'written contribution',
#  'string',
#  'submit until',
#  'personal review history',
#  'location of',
#  'has an ISBN',
#  'subclass of',
#  'date',
#  'registration',
#  'remark',
#  'state',
#  'building',
#  'city of conference',
#  'possible reviewer',
#  'personal publication history',
#  'conference banquet',
#  'gives presentations',
#  'tax',
#  'email',
#  'has end date time',
#  'SC Member',
#  'conference part',
#  'date',
#  'session',
#  'contributes',
#  'assigned paper',
#  'external reviewer',
#  'Registration SIGKDD Member',
#  'submissions deadline',
#  'prepare',
#  'radio communications topic',
#  'PC Member',
#  'introduction',
#  'steering committee',
#  'security topic',
#  'has title',
#  'travel grant',
#  'submit',
#  'science worker',
#  'set max papers',
#  'invited speaker',
#  'has review',
#  'poster',
#  'author of paper student',
#  'camera ready manuscript deadline',
#  'modelling',
#  'is held after',
#  'powerline transmission topic',
#  'name',
#  'read paper',
#  'computer networks management topic',
#  'review question',
#  'presentation',
#  'negative review',
#  'communications topic',
#  'co-write paper',
#  'PC Chair',
#  'has phone',
#  'memeber registration fee',
#  'conference volume',
#  'date time',
#  'date',
#  'worker non speaker',
#  'review',
#  'invitation letter',
#  'conference venue place',
#  'has related document',
#  'presenter city',
#  'delegate',
#  'workshop session',
#  'research institute',
#  'has a location',
#  'multi-author volume',
#  'industrial session',
#  'currency',
#  'lists event',
#  'car',
#  'held in',
#  'has gender',
#  'has member',
#  'conference trip',
#  'presentationed by',
#  'one day presenter',
#  'city',
#  'follows',
#  'hotel room',
#  'satellite and space communications topic',
#  'conference session',
#  'computer networks enterprise topic',
#  'referenced in',
#  'associated chair',
#  'contribution co-author',
#  'coffee break',
#  'obtain',
#  'has attendee',
#  'is paid with',
#  'covers topic',
#  'document',
#  'organizing committee member',
#  'plenary lecture speaker',
#  'conference participant',
#  'can stay in',
#  'has a review reference or expertise',
#  'conference hall',
#  'track',
#  'has a program committee',
#  'start date',
#  'working event',
#  'student non speaker',
#  'academia organization',
#  'invited speaker',
#  'workshop',
#  'is a date of camera ready paper submission',
#  'registration of participants event',
#  'has subject area',
#  'contribution',
#  'reviewing event',
#  'paper assignment tools run by',
#  'sponsor state',
#  'evaluated paper',
#  'sponsor',
#  'technic activity',
#  'accepted paper',
#  'conference',
#  'parallel with',
#  'unsigned long',
#  'IASTED non member',
#  'review rating',
#  'conference document',
#  'has author',
#  'workshop',
#  'document',
#  'program committee chair',
#  'registration fee',
#  'organizational meeting',
#  'assigned by administrator',
#  'book proceeding',
#  'has part',
#  'has conflict of interest',
#  'sponsor company house',
#  'string',
#  'has short title',
#  'enter review criteria',
#  'int',
#  'boolean',
#  'is needed for',
#  'author',
#  'name',
#  'payed by',
#  'int',
#  'has street',
#  'write',
#  'tutorial speaker',
#  'invited talk abstract',
#  'has rating',
#  'paper abstract',
#  'presenter state',
#  'has tracks',
#  'member of program committee',
#  'has last name',
#  'author information form',
#  'max papers',
#  'one conference day',
#  'is reviewing',
#  'social event',
#  'logo URL',
#  'has a volume',
#  'invites co-reviewers',
#  'session chair',
#  'communication theory topic',
#  'has review history',
#  'conference applicant',
#  'operating topicsystems',
#  'has a topic or a submission contribution',
#  'welcome talk',
#  'webmaster',
#  'cryptography topic',
#  'sponsorship',
#  'person',
#  'has submission instructions',
#  'paid applicant',
#  'workshop chair',
#  'activity after conference',
#  'organizing committee',
#  'conference',
#  'bank transfer',
#  'assigned by reviewer',
#  'has city',
#  'assistant',
#  'Member PC',
#  'banquet',
#  'poster session',
#  'technically organised by',
#  'computer networks sensor topic',
#  'is member of',
#  'is given by',
#  'done till',
#  'review written by',
#  'belongs to event',
#  'provided by',
#  'late-registered participant',
#  'study at',
#  'administrator',
#  'starts on',
#  'has important dates',
#  'sponzor fee',
#  'conference chair',
#  'audiovisual equipment',
#  'assign reviewer',
#  'has start date time',
#  'has a steering committee',
#  'reject rating',
#  'lecture',
#  'person',
#  'is visited by',
#  'demo paper',
#  'gold supporter',
#  'conference contributor',
#  'attendee',
#  'has country',
#  'is submitted at',
#  'credit card',
#  'deals with',
#  'textual review question',
#  'best research paper award',
#  'dining place',
#  'neutral review',
#  'nation',
#  'abstract',
#  'accepted by',
#  'is topic of',
#  'best paper awards committee',
#  'has a publisher',
#  'tutorial abstract',
#  'author',
#  'deadline paper submission',
#  'meal event',
#  'committee member',
#  'conference airport',
#  'registration due on',
#  'exhibitor',
#  'CAD Topic',
#  'review preference',
#  'volume contains paper',
#  'has a submitted contribution',
#  'reviewer',
#  'camera ready contribution',
#  'place',
#  'is prepared by',
#  'has a date of issue',
#  'trip day',
#  'conference fees',
#  'is signed by',
#  'demo session',
#  'string',
#  'platinum supporter',
#  'pay',
#  'administrative event',
#  'is held in',
#  'computer networks optical topic',
#  'final manuscript',
#  'accepted paper',
#  'author of paper',
#  'has postal code',
#  'contribution 1th-author',
#  'is present',
#  'was a program committee of',
#  'author cd proceedings included',
#  'multimedia topic',
#  'sponsor city',
#  'speaker',
#  'write paper',
#  'numerical review question',
#  'research topic',
#  'co-author',
#  'fee for extra trip',
#  'was a track-workshop chair of',
#  'subclass of',
#  'contributed talk',
#  'hold',
#  'has title',
#  'van',
#  'acceptance',
#  'abstract',
#  'scholar',
#  'conference activity',
#  'adjust bid',
#  'hotel registration form',
#  'conference city',
#  'read by reviewer',
#  'government organization',
#  'reviewing results event',
#  'active paper',
#  'workshop',
#  'mobile computing topic',
#  'int',
#  'document',
#  'publication',
#  'excursion',
#  'student registration fee',
#  'reviewer',
#  'has a URL',
#  'written by',
#  'for event',
#  'finalize paper assignment',
#  'has been assigned',
#  'cd proceening',
#  'paper',
#  'registration student',
#  'deadline for notification of acceptance',
#  'has authors',
#  'computer architecture topic',
#  'is reviewed by',
#  'agency staff member',
#  'paper full version',
#  'introduction of speaker',
#  'registration form',
#  'person',
#  'computer networks switching topic',
#  'reviewer',
#  'has submission deadline',
#  'organization',
#  'accept rating',
#  'hotel presenter',
#  'subclass of',
#  'programme',
#  'conference',
#  'listener',
#  'related to paper',
#  'has members',
#  'submission event',
#  'event',
#  'award',
#  'conference',
#  'country',
#  'conference contribution',
#  'is sent after',
#  'go through',
#  'is given by',
#  'organising agency',
#  'closing talk',
#  'is dated on',
#  'start reviewer bidding',
#  'title',
#  'cheque',
#  'camera ready paper',
#  'end of conference',
#  'form',
#  'is made from',
#  'paper ID',
#  'is paid by',
#  'holded by',
#  'extended abstract',
#  'write review',
#  'is provider of',
#  'silver supporter',
#  'meta-reviewer',
#  'paper',
#  'end review',
#  'conference hiker',
#  'is occupied by',
#  'paper',
#  'member',
#  'is paid in',
#  'conference proceedings',
#  'is review history of',
#  'industry organization',
#  'time zone',
#  'has been assigned a review reference',
#  'call for papers',
#  'trip',
#  'single hotel room',
#  'boolean',
#  'meal break',
#  'information for participants',
#  'conference dinner',
#  'review expertise',
#  'organizer',
#  'string',
#  'is written by',
#  'poster paper',
#  'is a topis of conference parts',
#  'early paid applicant',
#  'belongs to reviewers',
#  'simulating',
#  'conference event',
#  'topic',
#  'tutorial chair',
#  'sign',
#  'has event',
#  'week reject rating',
#  'regular paper',
#  'power point presentation',
#  'industrial paper',
#  'award',
#  'search',
#  'has home page',
#  'has an abstract',
#  'departure tax',
#  'early registration',
#  'presenter',
#  'invited speaker',
#  'hardcopy mailing manifests printed by',
#  'written by',
#  'has the last name',
#  'talk event',
#  'camera ready event',
#  'has country',
#  'person',
#  'is used by',
#  'social event',
#  'enter conference details',
#  'is a full paper submission date',
#  'notification until',
#  'session',
#  'is sent before',
#  'is a date of acceptance announcement',
#  'was a steering committee of',
#  'conference hotel',
#  'expert on',
#  'person',
#  'meal menu',
#  'shuttle bus',
#  'taxi',
#  'rejection',
#  'initiates',
#  'academic institution',
#  'has topic',
#  'is given to',
#  'paper assignment finalized by',
#  'main office',
#  'has the first name',
#  'is initiated by',
#  'student lecturer',
#  'has bid',
#  'presenter',
#  'passive conference participant',
#  'belong to a conference volume',
#  'bronze supporter',
#  'site URL',
#  'ACM SIGKDD',
#  'conference member',
#  'accept paper',
#  'conference announcement',
#  'author attendee book registration fee',
#  'active conference participant',
#  'invited talk',
#  'individual presentation',
#  'part of',
#  'meeting room place',
#  'registration non-member',
#  'withdrawn paper',
#  'medicine topic',
#  'registation deadline',
#  'start of conference',
#  'date time',
#  'is a starting date',
#  'relates to',
#  'conference www',
#  'departure',
#  'full day tour',
#  'any URI',
#  'microelectronics topic',
#  'issues',
#  'attendee at',
#  'is an ending date',
#  'run paper assignment tools',
#  'mailing list',
#  'signal processing topic',
#  'value added tax',
#  'academic event',
#  'event on list',
#  'reject paper',
#  'review',
#  'is location of',
#  'record of attendance',
#  'registration fee',
#  'presenter house',
#  'late paid applicant',
#  'is held before',
#  'tutorial',
#  'computer networks measurements topic',
#  'conference',
#  'track-workshop chair',
#  'conference session',
#  'participant',
#  'is situated in',
#  'track',
#  'technically organises',
#  'adjusted by',
#  'nonmember registration fee',
#  'is equipped by',
#  'conference chair',
#  'technical commitee',
#  'fee',
#  'lecturer',
#  'video cassette player',
#  'program committee member',
#  'OC Chair',
#  'item',
#  'organises',
#  'research',
#  'best student paper award',
#  'organization',
#  'price',
#  'accepts hardcopy submissions',
#  'conference',
#  'author not reviewer',
#  'student',
#  'design',
#  'general chair',
#  'organization',
#  'has first name',
#  'organised by',
#  'has program committee member',
#  'manuscript due on',
#  'conference restaurant',
#  'paper in volume',
#  'review criteria entered by',
#  'tutorial',
#  'money',
#  'positive review',
#  'computer',
#  'parallel and distributed computing topic',
#  'has related paper',
#  'assigned to',
#  'non speaker',
#  'pending paper',
#  'proceedings',
#  'has decision',
#  'has an expertise',
#  'city',
#  'has a review',
#  'organizing committee',
#  'added by',
#  'activity before conference',
#  'employed by',
#  'main office',
#  'contact information',
#  'was an organizing committee of',
#  'scientifically organises',
#  'max choice',
#  'has workshops',
#  'is paid for',
#  'computer networks security topic',
#  'published paper',
#  'social event',
#  'author attendee cd registration fee',
#  'date time',
#  'has fax',
#  'is used for',
#  'time',
#  'references',
#  'workshop paper',
#  'document',
#  'has administrative event',
#  'has cost currency',
#  'conference participant',
#  'has an organizing committee',
#  'mark conflict of interest',
#  'brief introduction for session chair',
#  'rejected paper',
#  'IASTED member',
#  'submission',
#  'has a committee co-chair',
#  'plenary lecture',
#  'give',
#  'designed by',
#  'conference paper',
#  'demo chair',
#  'person',
#  'program chair',
#  'virtual meeting enabled by',
#  'member of conference',
#  'searched by',
#  'need',
#  'author book proceedings included',
#  'best applications paper award',
#  'has name',
#  'flyer',
#  'submitted paper',
#  'place',
#  'has postal code',
#  'has programme',
#  'review',
#  'review',
#  'conference building',
#  'reviewer',
#  'reviewer of paper',
#  'has a committee chair',
#  'tutorial',
#  'deadline author notification',
#  'awarded by',
#  'conference state',
#  'initial manuscipt',
#  'is menu of',
#  'submitted contribution',
#  'activity',
#  'has conference member',
#  'fee',
#  'document',
#  'has tutorials',
#  'place',
#  'belongs to a review reference',
#  'paper presented as',
#  'written by',
#  'has a commtitee',
#  'reviews per paper',
#  'review',
#  'presentation of paper',
#  'string',
#  'abstract',
#  'preference',
#  'reviewer bidding started by',
#  'viza',
#  'renting',
#  'transparency',
#  'payment document',
#  'tutorial',
#  'organizator',
#  'performance topic',
#  'paper author',
#  'computer networks aapplications topic',
#  'was a committe co-chair of',
#  'program committee member',
#  'break event',
#  'short paper',
#  'accepting manuscript',
#  'speaker',
#  'has a name',
#  'session chair',
#  'subclass of',
#  'regular author',
#  'reviewes',
#  'transport vehicle',
#  'int',
#  'LCD projector',
#  'writes',
#  'OC Member',
#  'chairman',
#  'test only topic',
#  'currency',
#  'rejected contribution',
#  'has VAT',
#  'has a track-workshop-tutorial chair',
#  'registeered applicant',
#  'accpet if room rating',
#  'university',
#  'refusing manuscript',
#  'proceedings publisher',
#  'send',
#  'has a review expertise',
#  'speaker lecture',
#  'call for reviews',
#  'administrator',
#  'is part of conference volumes',
#  'name of sponsor',
#  'deadline',
#  'presentation',
#  'deadline',
#  'early-registered participant',
#  'rated papers',
#  'person',
#  'regular session',
#  'accommodation place',
#  'min choice',
#  'subclass of']

# %%
Ontology("conference_ontologies/conference.owl").triples
# Out:
# [('Conference_proceedings', 'string', 'has_a_name'),
#  ('Committee_member', 'Committee', 'was_a_member_of'),
#  ('Review', 'Conference_document', 'subclass_of'),
#  ('Review_preference', 'Reviewer', 'belongs_to_reviewers'),
#  ('Information_for_participants', 'Conference_document', 'subclass_of'),
#  ('Regular_author', 'Conference_contributor', 'subclass_of'),
#  ('Late_paid_applicant', 'Paid_applicant', 'subclass_of'),
#  ('Active_conference_participant', 'Presentation', 'gives_presentations'),
#  ('Invited_speaker', 'Conference_contributor', 'subclass_of'),
#  ('Program_committee', 'Conference_volume', 'was_a_program_committee_of'),
#  ('Topic', 'Review_preference', 'has_been_assigned_a_review_reference'),
#  ('Conference_volume', 'Important_dates', 'has_important_dates'),
#  ('Rejected_contribution', 'Reviewed_contribution', 'subclass_of'),
#  ('Contribution_co-author', 'Regular_author', 'subclass_of'),
#  ('Active_conference_participant', 'Conference_contributor', 'subclass_of'),
#  ('Presentation', 'Abstract', 'has_an_abstract'),
#  ('Conference_proceedings', 'string', 'has_an_ISBN'),
#  ('Accepted_contribution', 'Reviewed_contribution', 'subclass_of'),
#  ('Steering_committee', 'Committee', 'subclass_of'),
#  ('Conference_www', 'Conference_document', 'subclass_of'),
#  ('Person', 'string', 'has_an_email'),
#  ('Passive_conference_participant', 'Conference_participant', 'subclass_of'),
#  ('Program_committee', 'Committee', 'subclass_of'),
#  ('Workshop', 'Conference_part', 'subclass_of'),
#  ('Active_conference_participant', 'Regular_author', 'subclass_of'),
#  ('Submitted_contribution', 'Poster', 'subclass_of'),
#  ('Organizer', 'Organization', 'subclass_of'),
#  ('Co-chair', 'Committee', 'was_a_committe_co-chair_of'),
#  ('Reviewed_contribution', 'Submitted_contribution', 'subclass_of'),
#  ('Topic', 'Review_preference', 'belongs_to_a_review_reference'),
#  ('Submitted_contribution',
#   'Review_preference',
#   'has_been_assigned_a_review_reference'),
#  ('Conference_part', 'string', 'has_a_name'),
#  ('Person', 'string', 'has_the_last_name'),
#  ('Conference_volume', 'Tutorial', 'has_tutorials'),
#  ('Conference_participant', 'Person', 'subclass_of'),
#  ('Topic', 'string', 'has_a_name'),
#  ('Review_expertise', 'Reviewer', 'belongs_to_reviewers'),
#  ('Conference_volume', 'Organizing_committee', 'has_an_organizing_committee'),
#  ('Submitted_contribution', 'Review_expertise', 'has_a_review_expertise'),
#  ('Conference_volume', 'Workshop', 'has_workshops'),
#  ('Committee', 'Chair', 'has_a_committee_chair'),
#  ('Conference_volume', 'Conference', 'subclass_of'),
#  ('Abstract', 'Presentation', 'is_the_1th_part_of'),
#  ('Co-chair', 'Committee_member', 'subclass_of'),
#  ('Chair', 'Committee_member', 'subclass_of'),
#  ('Important_dates', 'date', 'is_a_full_paper_submission_date'),
#  ('Important_dates', 'date', 'is_a_starting_date'),
#  ('Important_dates', 'date', 'is_an_abstract_submission_date'),
#  ('Committee', 'Co-chair', 'has_a_committee_co-chair'),
#  ('Reviewer', 'Reviewer', 'invites_co-reviewers'),
#  ('Submitted_contribution', 'Regular_contribution', 'subclass_of'),
#  ('Presentation', 'Conference_contribution', 'subclass_of'),
#  ('Committee', 'Conference_volume', 'was_a_committee_of'),
#  ('Track', 'Conference_part', 'subclass_of'),
#  ('Important_dates', 'Conference_volume', 'belong_to_a_conference_volume'),
#  ('Conference_document', 'Person', 'has_authors'),
#  ('Important_dates', 'date', 'is_an_ending_date'),
#  ('Review', 'Reviewed_contribution', 'reviews'),
#  ('Written_contribution', 'Regular_contribution', 'subclass_of'),
#  ('Poster', 'Conference_contribution', 'subclass_of'),
#  ('Call_for_paper', 'Conference_document', 'subclass_of'),
#  ('Conference_part',
#   'Track-workshop_chair',
#   'has_a_track-workshop-tutorial_chair'),
#  ('Written_contribution', 'Poster', 'subclass_of'),
#  ('Conference_contributor', 'Person', 'subclass_of'),
#  ('Conference_volume', 'string', 'has_a_location'),
#  ('Written_contribution', 'Conference_contribution', 'subclass_of'),
#  ('Submitted_contribution', 'Written_contribution', 'subclass_of'),
#  ('Conference_volume', 'Program_committee', 'has_a_program_committee'),
#  ('Reviewed_contribution', 'Review', 'has_a_review'),
#  ('Conference_contribution', 'Conference_volume', 'is_submitted_at'),
#  ('Conference_volume', 'Conference_part', 'has_parts'),
#  ('Call_for_participation', 'Conference_document', 'subclass_of'),
#  ('Abstract', 'Paper', 'is_the_1th_part_of'),
#  ('Poster', 'Abstract', 'has_an_abstract'),
#  ('Publisher', 'string', 'has_a_name'),
#  ('Conference_document', 'date', 'has_a_date_of_issue'),
#  ('Conference_volume', 'Conference_contribution', 'has_contributions'),
#  ('Review_expertise',
#   'Submitted_contribution',
#   'has_a_submitted_contribution'),
#  ('Organizing_committee', 'Committee', 'subclass_of'),
#  ('Regular_contribution', 'Written_contribution', 'subclass_of'),
#  ('Conference_proceedings', 'int', 'has_a_volume'),
#  ('Active_conference_participant', 'Invited_speaker', 'subclass_of'),
#  ('Extended_abstract', 'Regular_contribution', 'subclass_of'),
#  ('Contribution_1th-author', 'Regular_author', 'subclass_of'),
#  ('Conference_contribution', 'Conference_document', 'subclass_of'),
#  ('Conference_volume', 'Track', 'has_tracks'),
#  ('Review_preference', 'Topic', 'has_a_topic_or_a_submission_contribution'),
#  ('Reviewer', 'Person', 'subclass_of'),
#  ('Tutorial', 'Conference_part', 'subclass_of'),
#  ('Committee', 'Committee_member', 'has_members'),
#  ('Person', 'Conference_document', 'contributes'),
#  ('Conference_proceedings', 'Publisher', 'has_a_publisher'),
#  ('Review_preference', 'int', 'has_a_degree'),
#  ('Topic', 'Conference_part', 'is_a_topis_of_conference_parts'),
#  ('Conference_www', 'string', 'has_a_URL'),
#  ('Organizer', 'Committee_member', 'subclass_of'),
#  ('Paper', 'Regular_contribution', 'subclass_of'),
#  ('Conference_part', 'Conference_volume', 'is_part_of_conference_volumes'),
#  ('Conference_volume', 'Steering_committee', 'has_a_steering_committee'),
#  ('Camera_ready_contribution', 'Accepted_contribution', 'subclass_of'),
#  ('Abstract', 'Extended_abstract', 'subclass_of'),
#  ('Track-workshop_chair', 'Person', 'subclass_of'),
#  ('Invited_talk', 'Presentation', 'subclass_of'),
#  ('Paper', 'Abstract', 'has_an_abstract'),
#  ('Conference_applicant', 'Person', 'subclass_of'),
#  ('Steering_committee', 'Conference_volume', 'was_a_steering_committee_of'),
#  ('Track-workshop_chair', 'Conference_part', 'was_a_track-workshop_chair_of'),
#  ('Reviewer', 'Review_preference', 'has_a_review_reference_or_expertise'),
#  ('Organizing_committee',
#   'Conference_volume',
#   'was_an_organizing_committee_of'),
#  ('Important_dates', 'date', 'is_a_date_of_acceptance_announcement'),
#  ('Committee_member', 'Person', 'subclass_of'),
#  ('Conference_volume', 'Committee', 'has_a_commtitee'),
#  ('Abstract', 'Poster', 'is_the_1th_part_of'),
#  ('Person', 'string', 'has_the_first_name'),
#  ('Review_preference',
#   'Submitted_contribution',
#   'has_a_topic_or_a_submission_contribution'),
#  ('Important_dates', 'date', 'is_a_date_of_camera_ready_paper_submission'),
#  ('Publisher', 'Conference_proceedings', 'issues'),
#  ('Conference_part', 'Topic', 'has_a_track-workshop-tutorial_topic'),
#  ('Paid_applicant', 'Registeered_applicant', 'subclass_of'),
#  ('Early_paid_applicant', 'Paid_applicant', 'subclass_of'),
#  ('Conference_announcement', 'Conference_document', 'subclass_of'),
#  ('Reviewer', 'Review_expertise', 'has_a_review_reference_or_expertise'),
#  ('Presentation', 'Active_conference_participant', 'is_given_by'),
#  ('Reviewer', 'Reviewer', 'invited_by'),
#  ('Chair', 'Committee', 'was_a_committee_chair_of'),
#  ('Conference', 'string', 'has_a_name'),
#  ('Registeered_applicant', 'Conference_applicant', 'subclass_of'),
#  ('Active_conference_participant', 'Conference_participant', 'subclass_of')]

# %%
aml_data = pickle.load(open("Input/data_conf_oaei_german_aml_thresh.pkl", "rb"))[2]
# Out of 19, 13 are properties
# Total: Out of 305, 46 are properties
[elem for elem in fn if aml_data[elem[0]]]
# Out:
# [(('conference#has_an_email', 'sigkdd#E-mail'), 0.7713571766026859),
#  (('conference#has_the_first_name', 'confOf#hasFirstName'), 0.880357117961549),
#  (('conference#Conference_contribution', 'confOf#Contribution'),
#   0.8868231393924292),
#  (('conference#Conference_fees', 'sigkdd#Fee'), 0.6188696994468148),
#  (('edas#hasName', 'sigkdd#Name_of_conference'), 0.4805131363962989),
#  (('cmt#hasConferenceMember', 'edas#hasMember'), 0.6716822236329376),
#  (('edas#startDate', 'sigkdd#Start_of_conference'), 0.5281862044760653),
#  (('conference#has_the_first_name', 'edas#hasFirstName'), 0.880357117961549),
#  (('cmt#memberOfConference', 'edas#isMemberOf'), 0.5384340162535509),
#  (('conference#has_a_track-workshop-tutorial_topic', 'confOf#hasTopic'),
#   0.2714889827757321),
#  (('cmt#submitPaper', 'sigkdd#submit'), 0.7581631096558908),
#  (('conference#has_the_last_name', 'confOf#hasSurname'), 0.87604244145975),
#  (('cmt#ProgramCommitteeChair', 'sigkdd#Program_Chair'), 0.8825911780203144),
#  (('conference#Late_paid_applicant', 'ekaw#Late-Registered_Participant'),
#   0.43402182817268065),
#  (('conference#has_an_email', 'confOf#hasEmail'), 0.8262672926565403),
#  (('cmt#Co-author', 'conference#Contribution_co-author'), 0.864552390339656),
#  (('cmt#email', 'conference#has_an_email'), 0.8262672926565403),
#  (('conference#Early_paid_applicant', 'ekaw#Early-Registered_Participant'),
#   0.4156298876724708),
#  (('edas#endDate', 'sigkdd#End_of_conference'), 0.5493031425646613)]

# %%
fp
# Out:
# [(('conference#Conference', 'confOf#Conference'), 0.9973421982532529),
#  (('edas#Sponsorship', 'sigkdd#Sponzor'), 0.968656566134342),
#  (('confOf#Organization', 'sigkdd#Organizator'), 0.998551220616579),
#  (('edas#ConferenceSession', 'ekaw#Conference_Session'), 0.9999999884580107),
#  (('conference#Conference', 'ekaw#Conference'), 0.9973162966528599),
#  (('conference#Presentation', 'iasted#Video_presentation'),
#   0.9121530492200467),
#  (('edas#Presenter', 'ekaw#Presenter'), 0.9999999981909232),
#  (('iasted#Sponzorship', 'sigkdd#Sponzor'), 0.9635374504545844),
#  (('conference#Presentation', 'iasted#Presentation'), 0.9999998994128296),
#  (('iasted#Memeber_registration_fee', 'sigkdd#Registration_Non-Member'),
#   0.9158709829332377),
#  (('iasted#Hotel_room', 'sigkdd#Hotel'), 0.9344941446887469),
#  (('conference#Conference', 'edas#Conference'), 0.9999998180349513),
#  (('iasted#Document', 'sigkdd#Document'), 0.9999999307574674),
#  (('cmt#Document', 'iasted#Document'), 0.9999999162323577),
#  (('conference#Call_for_paper', 'edas#CallForPapers'), 0.9602917001822115),
#  (('edas#Organization', 'sigkdd#Organizator'), 0.999999949646944),
#  (('cmt#Paper', 'confOf#Paper'), 0.998116541128712),
#  (('conference#Invited_talk', 'ekaw#Invited_Talk'), 0.9999999999982317),
#  (('confOf#Paper', 'ekaw#Paper'), 0.999999689055936),
#  (('confOf#Conference', 'edas#Conference'), 0.9973833203066003),
#  (('ekaw#PC_Member', 'sigkdd#Program_Committee_member'), 0.9999999974431825),
#  (('conference#Conference', 'sigkdd#Conference'), 0.9999999963183593),
#  (('cmt#Paper', 'conference#Paper'), 0.9980946571510965),
#  (('ekaw#Organisation', 'sigkdd#Organizator'), 0.9999998950299622),
#  (('conference#Paper', 'ekaw#Paper'), 0.9999999186920736),
#  (('conference#Conference_participant', 'ekaw#Conference_Participant'),
#   0.9999999867076335),
#  (('cmt#ProgramCommitteeChair', 'ekaw#PC_Chair'), 0.9999999088718852),
#  (('ekaw#Paper_Author', 'sigkdd#Author_of_paper'), 0.9864920093270195),
#  (('conference#Chair', 'edas#ConferenceChair'), 0.9147413140418282),
#  (('edas#Sponsorship', 'iasted#Sponsor'), 0.9706123696660772),
#  (('cmt#ConferenceChair', 'conference#Chair'), 0.9145957729676113),
#  (('edas#Conference', 'ekaw#Conference'), 0.9973576446280369),
#  (('cmt#Reviewer', 'conference#Reviewer'), 0.9999999809706457),
#  (('iasted#Memeber_registration_fee', 'sigkdd#Registration_SIGMOD_Member'),
#   0.9025111514005368),
#  (('cmt#ProgramCommitteeMember', 'ekaw#PC_Member'), 0.9991250099428313),
#  (('iasted#Conference_hotel', 'sigkdd#Hotel'), 0.9173614755478805),
#  (('cmt#SubjectArea', 'edas#Topic'), 0.9432680651783126),
#  (('edas#Person', 'iasted#Person'), 0.9984094419514157),
#  (('conference#Camera_ready_contribution', 'ekaw#Camera_Ready_Paper'),
#   0.9077716208604143),
#  (('cmt#writtenBy', 'confOf#writtenBy'), 1.0),
#  (('cmt#hasAuthor', 'ekaw#authorOf'), 0.9229949299817664),
#  (('confOf#hasEmail', 'edas#hasEmail'), 1.0),
#  (('cmt#name', 'sigkdd#Name'), 1.0),
#  (('conference#Organization', 'sigkdd#Organizator'), 1.0),
#  (('cmt#date', 'sigkdd#Date'), 1.0),
#  (('cmt#title', 'confOf#has_title'), 1.0),
#  (('edas#hasLocation', 'ekaw#locationOf'), 0.9459043840042608),
#  (('confOf#hasPhone', 'edas#hasPhone'), 1.0),
#  (('confOf#hasTopic', 'edas#hasTopic'), 1.0),
#  (('cmt#name', 'edas#hasName'), 1.0),
#  (('conference#is_given_by', 'iasted#is_given_by'), 1.0),
#  (('cmt#writtenBy', 'ekaw#writtenBy'), 1.0),
#  (('confOf#hasCountry', 'edas#hasCountry'), 1.0),
#  (('edas#hasName', 'sigkdd#Name'), 1.0),
#  (('edas#hasEmail', 'sigkdd#E-mail'), 0.9161555696210969),
#  (('iasted#pay', 'sigkdd#pay'), 1.0),
#  (('confOf#hasPostalCode', 'edas#hasPostalCode'), 1.0),
#  (('confOf#hasStreet', 'edas#hasStreet'), 1.0),
#  (('iasted#obtain', 'sigkdd#obtain'), 1.0),
#  (('confOf#writtenBy', 'ekaw#writtenBy'), 1.0),
#  (('cmt#email', 'edas#hasEmail'), 1.0),
#  (('conference#is_given_by', 'iasted#is_given_to'), 0.9154352788833978)]

# %%
s = set(props)
len([elem for elem in gt_mappings if tuple(elem[:2]) not in s])
# Out:
# 259
