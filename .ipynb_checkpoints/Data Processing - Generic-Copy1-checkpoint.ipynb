# %%
# Construction of dataset

import os, itertools, time, pickle, sys, glob, requests
import subprocess
from xml.dom import minidom
from collections import Counter, OrderedDict
from operator import itemgetter
from nltk.corpus import wordnet
import tensorflow as tf
import tensorflow_hub as hub
from scipy import spatial
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from sklearn.feature_extraction.text import TfidfVectorizer
import re
import numpy as np
import scipy.sparse as sp
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from math import ceil, exp
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
flatten = lambda l: [item for sublist in l for item in sublist]

class Ontology():
    def __init__(self, ontology):
        self.ontology = ontology
        self.ontology_obj = minidom.parse(ontology)
        self.root = self.ontology_obj.documentElement
        self.construct_mapping_dict()
        
        self.subclasses = self.parse_subclasses()
        self.object_properties = self.parse_object_properties()
        self.data_properties = self.parse_data_properties()
        self.triples = self.parse_triples()
        self.classes = self.parse_classes()        
    
    def construct_mapping_dict(self):
        self.mapping_dict = {self.extract_ID(el, False): self.get_child_node(el, "rdfs:label")[0].firstChild.nodeValue for el in self.root.getElementsByTagName("owl:Class") if self.get_child_node(el, "rdfs:label")}
        self.mapping_dict_inv = {self.mapping_dict[key]: key for key in self.mapping_dict}
        return
        
    def get_child_node(self, element, tag):
        return [e for e in element._get_childNodes() if type(e)==minidom.Element and e._get_tagName() == tag]
        
    def has_attribute_value(self, element, attribute, value):
        return True if element.getAttribute(attribute).split("#")[-1] == value else False
    
    def get_subclass_triples(self):
        return [(b,a) for (a,b,c) in self.get_subclasses()]
    
    def parse_triples(self, union_flag=0, subclass_of=True):
        obj_props = self.object_properties
        data_props = self.data_properties
        props = obj_props + data_props
        all_triples = []
        for prop in props:
            domain_children = self.get_child_node(prop, "rdfs:domain")
            range_children = self.get_child_node(prop, "rdfs:range")
            domain_prop = self.filter_null([self.extract_ID(el) for el in domain_children])
            range_prop = self.filter_null([self.extract_ID(el) for el in range_children])
            if not domain_children or not range_children:
                continue
            if not domain_prop:
                domain_prop = self.filter_null([self.extract_ID(el) for el in domain_children[0].getElementsByTagName("owl:Class")])
            if not range_prop:
                range_prop = self.filter_null([self.extract_ID(el) for el in range_children[0].getElementsByTagName("owl:Class")])
            if domain_prop and range_prop:
                if union_flag == 0:
                    all_triples.extend([(el[0], el[1], self.extract_ID(prop)) for el in list(itertools.product(domain_prop, range_prop))])
                else:
                    all_triples.append(("###".join(domain_prop), "###".join(range_prop), self.extract_ID(prop)))
        if subclass_of:
            all_triples.extend(self.get_subclass_triples())
        return list(set(all_triples))
    
    def get_triples(self, union_flag=0, subclass_of=True):
        return self.parse_triples(union_flag, subclass_of)

    def parse_subclasses(self, union_flag=0):
        subclasses = self.root.getElementsByTagName("rdfs:subClassOf")
        subclass_pairs = []
        for el in subclasses:
            inline_subclasses = self.extract_ID(el)
            if inline_subclasses:
                subclass_pairs.append((el, el.parentNode, "subclass_of"))
            else:
                level1_class = self.get_child_node(el, "owl:Class")
                if not level1_class:
                    continue
                else:
                    if self.extract_ID(level1_class[0]):
                        subclass_pairs.append((level1_class[0], el.parentNode, "subclass_of"))
                    else:
#                         level2classes = level1_class[0].getElementsByTagName("owl:Class")
#                         subclass_pairs.extend([(elem, el.parentNode, "subclass_of") for elem in level2classes if self.extract_ID(elem)])
                        continue
        return subclass_pairs
        
    def get_subclasses(self):
        subclasses = [(self.extract_ID(a), self.extract_ID(b), c) for (a,b,c) in self.subclasses]
        return [el for el in subclasses if el[0] and el[1] and el[2]]
    
    def filter_null(self, data):
        return [el for el in data if el]
    
    def extract_ID(self, element, check_coded = True):
        element_id = element.getAttribute("rdf:ID") or element.getAttribute("rdf:resource") or element.getAttribute("rdf:about")
        element_id = element_id.split("#")[-1]
        if len(list(filter(str.isdigit, element_id))) >= 3 and "_" in element_id and check_coded:
            return self.mapping_dict[element_id]
        return element_id.replace("UNDEFINED_", "").replace("DO_", "")
    
    def parse_classes(self):
        class_elems = [self.extract_ID(el) for el in self.root.getElementsByTagName("owl:Class")]
        subclass_classes = list(set(flatten([el[:-1] for el in self.triples])))
        return list(set(self.filter_null(class_elems + subclass_classes)))
    
    def get_classes(self):
        return self.classes
    
    def get_entities(self):
        entities = [self.extract_ID(el) for el in self.root.getElementsByTagName("owl:Class")]
        return list(set(self.filter_null(entities)))

    def parse_data_properties(self):
        data_properties = [el for el in self.get_child_node(self.root, 'owl:DatatypeProperty')]
        fn_data_properties = [el for el in self.get_child_node(self.root, 'owl:FunctionalProperty') if el]
        fn_data_properties = [el for el in fn_data_properties if type(el)==minidom.Element and 
            [el for el in self.get_child_node(el, "rdf:type") if 
             self.has_attribute_value(el, "rdf:resource", "DatatypeProperty")]]
        inv_fn_data_properties = [el for el in self.get_child_node(self.root, 'owl:InverseFunctionalProperty') if el]
        inv_fn_data_properties = [el for el in inv_fn_data_properties if type(el)==minidom.Element and 
            [el for el in self.get_child_node(el, "rdf:type") if 
             self.has_attribute_value(el, "rdf:resource", "DatatypeProperty")]]
        return data_properties + fn_data_properties + inv_fn_data_properties
        
    def parse_object_properties(self):
        obj_properties = [el for el in self.get_child_node(self.root, 'owl:ObjectProperty')]
        fn_obj_properties = [el for el in self.get_child_node(self.root, 'owl:FunctionalProperty') if el]
        fn_obj_properties = [el for el in fn_obj_properties if type(el)==minidom.Element and 
            [el for el in self.get_child_node(el, "rdf:type") if 
             self.has_attribute_value(el, "rdf:resource", "ObjectProperty")]]
        inv_fn_obj_properties = [el for el in self.get_child_node(self.root, 'owl:InverseFunctionalProperty') if el]
        inv_fn_obj_properties = [el for el in inv_fn_obj_properties if type(el)==minidom.Element and 
            [el for el in self.get_child_node(el, "rdf:type") if 
             self.has_attribute_value(el, "rdf:resource", "ObjectProperty")]]
        return obj_properties + fn_obj_properties + inv_fn_obj_properties
    
    def get_object_properties(self):
        obj_props = [self.extract_ID(el) for el in self.object_properties]
        return list(set(self.filter_null(obj_props)))
    
    def get_data_properties(self):
        data_props = [self.extract_ID(el) for el in self.data_properties]
        return list(set(self.filter_null(data_props)))

# %%
USE_folder = "/home/vlead/USE"
alignment_folder = "reference-alignment/"

# Load reference alignments 
def load_alignments(folder):
    alignments = []
    for f in os.listdir(folder):
        doc = minidom.parse(folder + f)
        ls = list(zip(doc.getElementsByTagName('entity1'), doc.getElementsByTagName('entity2')))
        alignments.extend([(a.getAttribute('rdf:resource'), b.getAttribute('rdf:resource')) for (a,b) in ls])
    return alignments
        
reference_alignments = load_alignments(alignment_folder)

ra_anatomy_coded = load_alignments("../Anatomy/Alignments/")
ra_anatomy = []
ont1 = Ontology("../Anatomy/Ontologies/mouse.owl")
ont2 = Ontology("../Anatomy/Ontologies/human.owl")
for elem in ra_anatomy_coded:
    pre1, pre2 = elem[0].split("#")[0].split(".")[0].split("/")[-1], elem[1].split("#")[0].split(".")[0].split("/")[-1]
    elem1, elem2 = elem[0].split("#")[-1], elem[1].split("#")[-1]
    ra_anatomy.append(( pre1 + "#" + ont1.mapping_dict[elem1], pre2 + "#" + ont2.mapping_dict[elem2]))

gt_mappings = [tuple([elem.split("/")[-1] for elem in el]) for el in reference_alignments]
gt_mappings.extend(ra_anatomy)


ontologies_in_alignment = [["conference_ontologies/" + el  + ".owl" for el in l.split(".")[0].split("-")]
                           for l in os.listdir("reference-alignment/")]
ontologies_in_alignment += [["../Anatomy/Ontologies/human.owl", "../Anatomy/Ontologies/mouse.owl"]]

# %%
# Extracting USE embeddings

def extractUSEEmbeddings(words):
    try:
        embed = hub.KerasLayer(USE_folder)
    except Exception as e:
        # !mkdir $USE_folder
        # !curl -L "https://tfhub.dev/google/universal-sentence-encoder-large/5?tf-hub-format=compressed" | tar -zxvC $USE_folder
        embed = hub.KerasLayer(USE_folder)
        pass
    word_embeddings = embed(words)
    return word_embeddings.numpy()

def cos_sim(a,b):
    return 1 - spatial.distance.cosine(a, b)

def camel_case_split(identifier):
    matches = re.finditer('.+?(?:(?<=[a-z])(?=[A-Z])|(?<=[A-Z])(?=[A-Z][a-z])|$)', identifier)
    return [m.group(0).lower() for m in matches]

def parse(word):
    return flatten([el.split("_") for el in camel_case_split(word)])
    

extracted_elems = []

for ont_name in list(set(flatten(ontologies_in_alignment))):
    ont = Ontology(ont_name)
    entities = ont.get_entities()
    props = ont.get_object_properties() + ont.get_data_properties()
    triples = list(set(flatten(ont.get_triples())))
    extracted_elems.extend([ont_name.split("/")[-1].split(".")[0] + "#" + elem for elem in entities + props + triples])

extracted_elems = list(set(extracted_elems))
inp = [" ".join(parse(word.split("#")[1])) for word in extracted_elems]

print ("Total number of extracted unique classes and properties from entire RA set: ", len(extracted_elems))

extracted_elems = ["<UNK>"] + extracted_elems

embeds = np.array([np.zeros(512,)] + list(extractUSEEmbeddings(inp)))
embeddings = dict(zip(extracted_elems, embeds))
# Out:
# Total number of extracted unique classes and properties from entire RA set:  6884

# %%
# Combinatorial mapping generation

all_mappings = []
for l in ontologies_in_alignment:
    ont1 = Ontology(l[0])
    ont2 = Ontology(l[1])
    
    ent1 = ont1.get_entities()
    ent2 = ont2.get_entities()
    
    obj1 = ont1.get_object_properties()
    obj2 = ont2.get_object_properties()
    
    data1 = ont1.get_data_properties()
    data2 = ont2.get_data_properties()
    
    mappings = list(itertools.product(ent1, ent2)) + list(itertools.product(obj1, obj2)) + list(itertools.product(data1, data2))

    
    all_mappings.extend([(l[0].split("/")[-1].split(".")[0] + "#" + el[0], l[1].split("/")[-1].split(".")[0] + "#" + el[1]) for el in mappings])
    

data = {mapping: False for mapping in all_mappings}
for mapping in set(gt_mappings):
    data[mapping] = True
# data = {mapping: True if mapping in set(gt_mappings) else False for mapping in all_mappings}

emb_vals = list(embeddings.values())
emb_indexer = {key: i for i, key in enumerate(list(embeddings.keys()))}
emb_indexer_inv = {i: key for i, key in enumerate(list(embeddings.keys()))}

# %%
def get_one_hop_neighbours(ont, K=1):
    ont_obj = Ontology(ont)
    triples = ont_obj.get_triples()
    entities = [(a,b) for (a,b,c) in triples]
    neighbours_dict = {elem: [elem] for elem in list(set(flatten(entities)))}
    for e1, e2 in entities:
        neighbours_dict[e1].append(e2)
        neighbours_dict[e2].append(e1)
    
#     prop_triples = ont_obj.get_triples(subclass_of=False)
#     neighbours_dict_props = {c: [c] for a,b,c in prop_triples}
#     for e1, e2, p in prop_triples:
#         neighbours_dict_props[p].extend([e1, e2])

    #neighbours_dict = {**neighbours_dict, **neighbours_dict_props}
    
    # for elem in ont_obj.get_entities() + ont_obj.get_object_properties() + ont_obj.get_data_properties():
    #     if elem not in neighbours_dict:
    #         neighbours_dict[elem] = [elem]

    neighbours_dict = {el: neighbours_dict[el][:1] + sorted(list(set(neighbours_dict[el][1:])))
                       for el in neighbours_dict}
    neighbours_dict = {el: neighbours_dict[el][:23] for el in neighbours_dict if len( neighbours_dict[el]) > 2}
    ont = ont.split("/")[-1].split(".")[0]
    neighbours_dict = {ont + "#" + el: [ont + "#" + e for e in neighbours_dict[el]] for el in neighbours_dict}
    return neighbours_dict

neighbours_dicts = {ont.split("/")[-1].split(".")[0]: get_one_hop_neighbours(ont) for ont in list(set(flatten(ontologies_in_alignment)))}
max_neighbours = np.max(flatten([[len(el[e]) for e in el] for el in neighbours_dicts.values()]))
neighbours_lens = {ont: {key: len(neighbours_dicts[ont][key]) for key in neighbours_dicts[ont]}
                   for ont in neighbours_dicts}
neighbours_dicts = {ont: {key: neighbours_dicts[ont][key] + ["<UNK>" for i in range(max_neighbours -len(neighbours_dicts[ont][key]))]
              for key in neighbours_dicts[ont]} for ont in neighbours_dicts}

ontologies_in_alignment = [[el.split("/")[1].split(".")[0] for el in ont] for ont in ontologies_in_alignment]
# f = open("../data_generic.pkl", "wb")
# pickle.dump([data, emb_indexer, emb_indexer_inv, emb_vals, gt_mappings, neighbours_dicts, ontologies_in_alignment], f)

# %%
# AML test
def is_test(test_onto, key):
    return tuple([el.split("#")[0] for el in key]) in test_onto

results = []
all_ont_pairs = list(set([tuple([el.split("#")[0] for el in l]) for l in data.keys()]))
for i in list(range(0, len(all_ont_pairs), 3)):
    test_onto = all_ont_pairs[i:i+3]
    for ont_pair in test_onto:
        a, b, c = ont_pair[0], ont_pair[1], ont_pair[0] + "-" + ont_pair[1]
        java_command = "java -jar AML_v3.1/AgreementMakerLight.jar -s conference_ontologies/" + a + ".owl" + \
                            " -t conference_ontologies/" + b + ".owl -o AML-test-results/" + c + ".rdf -a"
        process = subprocess.Popen(java_command.split(), stdout=subprocess.PIPE)
        output, error = process.communicate()
    print (os.listdir("AML-test-results/"))
    pred_aml = load_alignments("AML-test-results/")
    pred_aml = [tuple([el.split("/")[-1] for el in key]) for key in pred_aml]
    tp = len([elem for elem in pred_aml if data[elem]])
    fn = len([key for key in gt_mappings if key not in set(pred_aml) and is_test(test_onto, key)])
    fp = len([elem for elem in pred_aml if not data[elem]])

    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    f1score = 2 * precision * recall / (precision + recall)
    f2score = 5 * precision * recall / (4 * precision + recall)
    f0_5score = 1.25 * precision * recall / (0.25 * precision + recall)
    print (precision, recall, f1score, f2score, f0_5score)
    
    metrics = [precision, recall, f1score, f2score, f0_5score]
    results.append(metrics)
    
    _ = [os.remove(f) for f in glob.glob('AML-test-results/*')]
    
print ("Final Results:", np.mean(results, axis=0))
# Out:
# ['confOf-sigkdd.rdf', 'iasted-sigkdd.rdf', 'cmt-ekaw.rdf']
# 0.8275862068965517 0.7272727272727273 0.7741935483870968 0.7453416149068324 0.8053691275167786
# ['confOf-iasted.rdf', 'conference-edas.rdf', 'cmt-sigkdd.rdf']
# 0.8148148148148148 0.5789473684210527 0.6769230769230768 0.6145251396648045 0.7534246575342465
# ['ekaw-sigkdd.rdf', 'conference-sigkdd.rdf', 'conference-confOf.rdf']
# 0.78125 0.6097560975609756 0.684931506849315 0.6377551020408163 0.7396449704142012
# ['confOf-edas.rdf', 'edas-iasted.rdf', 'cmt-conference.rdf']
# 0.7941176470588235 0.5094339622641509 0.6206896551724137 0.548780487804878 0.7142857142857143
# ['edas-sigkdd.rdf', 'conference-iasted.rdf', 'ekaw-iasted.rdf']
# 0.7916666666666666 0.48717948717948717 0.6031746031746031 0.5277777777777778 0.7037037037037036
# ['cmt-confOf.rdf', 'cmt-edas.rdf', 'edas-ekaw.rdf']
# 0.8181818181818182 0.5192307692307693 0.6352941176470589 0.5601659751037344 0.733695652173913
# ['conference-ekaw.rdf', 'confOf-ekaw.rdf', 'cmt-iasted.rdf']
# 0.7954545454545454 0.7142857142857143 0.7526881720430106 0.7291666666666666 0.7777777777777778
# Final Results: [0.80329596 0.59230088 0.67827067 0.62335897 0.74684309]

# %%
ontologies_in_alignment = [[el.split("/")[1].split(".")[0] for el in ont] for ont in ontologies_in_alignment][:-1] + [["human", "mouse"]]

# %%
for i in list(range(0, len(ontologies_in_alignment)-1, 3)):
    
    test_onto = ontologies_in_alignment[i:i+3]
    print (test_onto)
# Out:
# [['conference', 'ekaw'], ['confOf', 'ekaw'], ['ekaw', 'sigkdd']]
# [['edas', 'sigkdd'], ['confOf', 'sigkdd'], ['iasted', 'sigkdd']]
# [['confOf', 'iasted'], ['conference', 'iasted'], ['confOf', 'edas']]
# [['edas', 'iasted'], ['conference', 'edas'], ['cmt', 'ekaw']]
# [['cmt', 'confOf'], ['cmt', 'edas'], ['conference', 'sigkdd']]
# [['cmt', 'sigkdd'], ['conference', 'confOf'], ['edas', 'ekaw']]
# [['cmt', 'conference'], ['cmt', 'iasted'], ['ekaw', 'iasted']]

# %%
ontologies_in_alignment
# Out:
# [['conference', 'ekaw'],
#  ['confOf', 'ekaw'],
#  ['ekaw', 'sigkdd'],
#  ['edas', 'sigkdd'],
#  ['confOf', 'sigkdd'],
#  ['iasted', 'sigkdd'],
#  ['confOf', 'iasted'],
#  ['conference', 'iasted'],
#  ['confOf', 'edas'],
#  ['edas', 'iasted'],
#  ['conference', 'edas'],
#  ['cmt', 'ekaw'],
#  ['cmt', 'confOf'],
#  ['cmt', 'edas'],
#  ['conference', 'sigkdd'],
#  ['cmt', 'sigkdd'],
#  ['conference', 'confOf'],
#  ['edas', 'ekaw'],
#  ['cmt', 'conference'],
#  ['cmt', 'iasted'],
#  ['ekaw', 'iasted'],
#  ['Anatomy', 'Anatomy']]

# %%
def count_non_unk(elem):
    return len([l for l in elem if l!="<UNK>"])
neighbours_dicts = {ont: {el: neighbours_dicts[ont][el][:int(sys.argv[1])] for el in neighbours_dicts[ont]
       if count_non_unk(neighbours_dicts[ont][el]) > int(sys.argv[2])} for ont in neighbours_dicts}
# Out:
# (167, 1240)

# %%
a = torch.randn((1,22,512))
b = torch.randn((1,1,512))
W_sub = nn.Linear(512, 1)

att_weights = W_sub(a - b.squeeze(1)[:, None]).squeeze(-1)

# %%
fn, fp = pickle.load(open("test_results.pkl", "rb"))

# %%
# Out:
# [(('iasted#Document', 'sigkdd#Document'), 0.999999999942373),
#  (('iasted#pay', 'sigkdd#pay'), 1.0),
#  (('cmt#writtenBy', 'ekaw#writtenBy'), 1.0),
#  (('iasted#obtain', 'sigkdd#obtain'), 1.0),
#  (('conference#Conference', 'edas#Conference'), 1.0),
#  (('cmt#name', 'sigkdd#Name'), 1.0),
#  (('cmt#date', 'sigkdd#Date'), 1.0),
#  (('conference#Active_conference_participant', 'sigkdd#Speaker'),
#   0.991044085054821),
#  (('conference#Conference', 'sigkdd#Conference'), 1.0),
#  (('conference#Conference', 'confOf#Conference'), 1.0),
#  (('cmt#Paper', 'conference#Conference_contribution'), 0.9966678260293467),
#  (('confOf#Contribution', 'edas#Paper'), 0.9990494130461205),
#  (('cmt#ConferenceMember', 'conference#Conference_participant'),
#   0.9980556782089393),
#  (('cmt#Reviewer', 'conference#Reviewer'), 0.9999999999999913),
#  (('edas#ConferenceEvent', 'iasted#Activity'), 0.998262556915499),
#  (('edas#Person', 'iasted#Person'), 0.9999999999999942),
#  (('cmt#Paper', 'conference#Paper'), 1.0),
#  (('confOf#hasCountry', 'edas#hasCountry'), 1.0),
#  (('confOf#hasEmail', 'edas#hasEmail'), 1.0),
#  (('confOf#hasPhone', 'edas#hasPhone'), 1.0),
#  (('confOf#hasTopic', 'edas#hasTopic'), 1.0),
#  (('confOf#hasStreet', 'edas#hasStreet'), 1.0),
#  (('confOf#Conference', 'edas#Conference'), 1.0),
#  (('confOf#hasPostalCode', 'edas#hasPostalCode'), 1.0),
#  (('conference#Presentation', 'iasted#Presentation'), 0.9999999999965358),
#  (('ekaw#Event', 'iasted#Conference_activity'), 0.9965853973140699),
#  (('conference#Conference_part', 'iasted#Activity'), 0.9967455479583704),
#  (('ekaw#Paper', 'iasted#Submission'), 0.9972990004508588),
#  (('conference#is_given_by', 'iasted#is_given_by'), 1.0),
#  (('cmt#ConferenceMember', 'confOf#Participant'), 0.9615624714365677),
#  (('edas#TPCMember', 'ekaw#PC_Member'), 0.9881409570839953),
#  (('edas#Conference', 'ekaw#Conference'), 1.0),
#  (('cmt#Paper', 'confOf#Paper'), 1.0),
#  (('edas#ConferenceSession', 'ekaw#Conference_Session'), 1.0),
#  (('edas#Presenter', 'ekaw#Presenter'), 1.0),
#  (('cmt#writtenBy', 'confOf#writtenBy'), 1.0),
#  (('conference#Submitted_contribution', 'ekaw#Paper'), 0.9739579243994178),
#  (('conference#Conference_participant', 'ekaw#Conference_Participant'),
#   0.9999999788183456),
#  (('conference#Conference_contribution', 'ekaw#Paper'), 0.9735269090386576),
#  (('cmt#Paper', 'iasted#Submission'), 0.9917626963751777),
#  (('cmt#Document', 'iasted#Document'), 0.999999995309699),
#  (('conference#Conference', 'ekaw#Conference'), 1.0),
#  (('conference#Invited_talk', 'ekaw#Invited_Talk'), 1.0),
#  (('conference#Paper', 'ekaw#Paper'), 1.0),
#  (('confOf#writtenBy', 'ekaw#writtenBy'), 1.0),
#  (('confOf#Paper', 'ekaw#Paper'), 1.0)]

# %%
fn
# Out:
# [(('confOf#Member_PC', 'sigkdd#Program_Committee_member'), 0.460159499824062),
#  (('confOf#hasEmail', 'sigkdd#E-mail'), 0.8035841514246479),
#  (('confOf#Chair_PC', 'sigkdd#Program_Chair'), 0.710800728376894),
#  (('iasted#Student_registration_fee', 'sigkdd#Registration_Student'),
#   0.8369251770941893),
#  (('iasted#Sponsor', 'sigkdd#Sponzor'), 0.1958937696402332),
#  (('iasted#Deadline_for_notification_of_acceptance',
#    'sigkdd#Deadline_Author_notification'),
#   0.6263288918181976),
#  (('iasted#Nonmember_registration_fee', 'sigkdd#Registration_Non-Member'),
#   0.8778317801581551),
#  (('cmt#ConferenceMember', 'ekaw#Conference_Participant'), 0.7906002055500096),
#  (('cmt#Author', 'ekaw#Paper_Author'), 0.8141944477873271),
#  (('cmt#writtenBy', 'ekaw#reviewWrittenBy'), 0.7592434303979944),
#  (('cmt#hasBeenAssigned', 'ekaw#reviewerOfPaper'), 0.19312313842631723),
#  (('cmt#assignedTo', 'ekaw#hasReviewer'), 0.38125778992733905),
#  (('cmt#PaperFullVersion', 'ekaw#Regular_Paper'), 0.5529287816442782),
#  (('confOf#Banquet', 'iasted#Dinner_banquet'), 0.8745011745513749),
#  (('confOf#Administrative_event', 'iasted#Activity_before_conference'),
#   0.7843720878377882),
#  (('confOf#Reception', 'iasted#Coctail_reception'), 0.6464351840795272),
#  (('confOf#Country', 'iasted#State'), 0.5430233172462778),
#  (('conference#Conference_participant', 'edas#Attendee'), 0.680457795262619),
#  (('conference#has_the_first_name', 'edas#hasFirstName'), 0.8860897325778035),
#  (('conference#Conference_part', 'edas#ConferenceEvent'), 0.9446306436667664),
#  (('conference#has_a_review_expertise', 'edas#hasRating'), 0.4727859021312708),
#  (('conference#has_the_last_name', 'edas#hasLastName'), 0.9132894406752937),
#  (('conference#Rejected_contribution', 'edas#RejectedPaper'),
#   0.665432017501309),
#  (('conference#Accepted_contribution', 'edas#AcceptedPaper'),
#   0.6685831555241036),
#  (('conference#Regular_author', 'edas#Author'), 0.6760209535160544),
#  (('cmt#ConferenceChair', 'sigkdd#General_Chair'), 0.5731875576956728),
#  (('cmt#ProgramCommitteeChair', 'sigkdd#Program_Chair'), 0.7962102707873221),
#  (('cmt#submitPaper', 'sigkdd#submit'), 0.7581630948456032),
#  (('ekaw#OC_Member', 'sigkdd#Organizing_Committee_member'), 0.365178639301853),
#  (('ekaw#PC_Chair', 'sigkdd#Program_Chair'), 0.7128738905671085),
#  (('ekaw#Paper_Author', 'sigkdd#Author'), 0.8141944477873271),
#  (('ekaw#Location', 'sigkdd#Place'), 0.8596690903888166),
#  (('conference#Conference_fees', 'sigkdd#Fee'), 0.6188697294990487),
#  (('conference#has_an_email', 'sigkdd#E-mail'), 0.678050043948171),
#  (('conference#is_given_by', 'sigkdd#presentationed_by'), 0.5244645453028868),
#  (('conference#gives_presentations', 'sigkdd#presentation'),
#   0.6056676430562652),
#  (('conference#has_an_email', 'confOf#hasEmail'), 0.9087962590739993),
#  (('conference#Conference_contribution', 'confOf#Contribution'),
#   0.9659720113521155),
#  (('conference#Conference_volume', 'confOf#Conference'), 0.7533685068578012),
#  (('conference#has_a_track-workshop-tutorial_topic', 'confOf#hasTopic'),
#   0.7476494013785009),
#  (('conference#Regular_author', 'confOf#Author'), 0.6760209537433649),
#  (('conference#has_the_last_name', 'confOf#hasSurname'), 0.8442166695453384),
#  (('conference#has_the_first_name', 'confOf#hasFirstName'),
#   0.8860897325778035),
#  (('confOf#Trip', 'edas#Excursion'), 0.7857979792365696),
#  (('confOf#reviewes', 'edas#isReviewing'), 0.16008190059169547),
#  (('confOf#writtenBy', 'edas#isWrittenBy'), 0.8407108246292888),
#  (('confOf#hasSurname', 'edas#hasLastName'), 0.9124298888117032),
#  (('confOf#Participant', 'edas#Attendee'), 0.8228379601853789),
#  (('confOf#Member_PC', 'edas#TPCMember'), 0.9795734850691236),
#  (('confOf#writes', 'edas#hasRelatedPaper'), 0.28916946377192687),
#  (('edas#Country', 'iasted#State'), 0.5430233172462778),
#  (('edas#WelcomeTalk', 'iasted#Welcome_address'), 0.6376587870417061),
#  (('edas#Sponsorship', 'iasted#Sponzorship'), 0.2985675375146857),
#  (('edas#Attendee', 'iasted#Delegate'), 0.5733914370867992),
#  (('edas#ConferenceDinner', 'iasted#Dinner_banquet'), 0.739438108407966),
#  (('edas#SocialEvent', 'iasted#Social_program'), 0.5170070088673717),
#  (('edas#Reception', 'iasted#Coctail_reception'), 0.6464351840795272),
#  (('edas#SlideSet', 'iasted#Transparency'), 0.22742734295143396),
#  (('edas#Paper', 'iasted#Submission'), 0.9757805363275427),
#  (('edas#ConferenceVenuePlace', 'iasted#Conference_building'),
#   0.6181335242447228),
#  (('edas#DiningPlace', 'iasted#Conference_restaurant'), 0.6283572995412593),
#  (('cmt#Preference', 'conference#Review_preference'), 0.783329808487203),
#  (('cmt#email', 'conference#has_an_email'), 0.678050043948171),
#  (('cmt#Co-author', 'conference#Contribution_co-author'), 0.7145446174859915),
#  (('cmt#PaperAbstract', 'conference#Abstract'), 0.802760641840036),
#  (('cmt#Chairman', 'conference#Chair'), 0.7892468263134209),
#  (('cmt#SubjectArea', 'conference#Topic'), 0.7154184628848549),
#  (('cmt#assignedByReviewer', 'conference#invited_by'), 0.48464419365137834),
#  (('cmt#assignExternalReviewer', 'conference#invites_co-reviewers'),
#   0.18083443297598478),
#  (('edas#hasCostAmount', 'sigkdd#Price'), 0.4406298894593965),
#  (('edas#hasName', 'sigkdd#Name_of_conference'), 0.4045462270735172),
#  (('edas#ConferenceVenuePlace', 'sigkdd#Conference_hall'), 0.6646223919595833),
#  (('edas#AccommodationPlace', 'sigkdd#Hotel'), 0.5498427937907697),
#  (('edas#startDate', 'sigkdd#Start_of_conference'), 0.528186177578591),
#  (('edas#ConferenceChair', 'sigkdd#General_Chair'), 0.5731875576956728),
#  (('edas#endDate', 'sigkdd#End_of_conference'), 0.5493031244333424),
#  (('edas#Attendee', 'sigkdd#Listener'), 0.4827829321776764),
#  (('conference#Passive_conference_participant', 'iasted#Listener'),
#   0.3169095830935159),
#  (('conference#Active_conference_participant', 'iasted#Speaker'),
#   0.5680263989736565),
#  (('conference#Conference_fees', 'iasted#Fee'), 0.6188697294990487),
#  (('conference#contributes', 'iasted#write'), 0.37880804066855067),
#  (('conference#Submitted_contribution', 'iasted#Submission'),
#   0.9743701568387634),
#  (('conference#Camera_ready_contribution', 'iasted#Final_manuscript'),
#   0.09563412426112805),
#  (('conference#Conference_proceedings', 'iasted#Publication'),
#   0.6764157750052419),
#  (('ekaw#Location', 'iasted#Place'), 0.8596690903888166),
#  (('ekaw#Paper_Author', 'iasted#Author'), 0.8141944477873271),
#  (('ekaw#Conference_Banquet', 'iasted#Dinner_banquet'), 0.8085170862766579),
#  (('cmt#ProgramCommitteeChair', 'confOf#Chair_PC'), 0.46274629824637237),
#  (('cmt#writePaper', 'confOf#writes'), 0.6220006428478738),
#  (('cmt#ConferenceMember', 'confOf#Member'), 0.6716821946490479),
#  (('cmt#title', 'confOf#hasTitle'), 0.783218261736053),
#  (('cmt#SubjectArea', 'confOf#Topic'), 0.7154184628848549),
#  (('cmt#PaperFullVersion', 'confOf#Paper'), 0.48035408507207067),
#  (('cmt#hasBeenAssigned', 'confOf#reviewes'), 0.1451590757687069),
#  (('cmt#hasAuthor', 'confOf#writtenBy'), 0.5049379302566748),
#  (('cmt#ProgramCommitteeMember', 'confOf#Member_PC'), 0.7987872173050661),
#  (('cmt#hasSubjectArea', 'confOf#dealsWith'), 0.29254638675845823),
#  (('cmt#email', 'confOf#hasEmail'), 0.8035841514246479),
#  (('cmt#hasConferenceMember', 'edas#hasMember'), 0.7371957636588252),
#  (('cmt#memberOfConference', 'edas#isMemberOf'), 0.5384339627563817),
#  (('cmt#hasAuthor', 'edas#isWrittenBy'), 0.5059071234234503),
#  (('cmt#hasBeenAssigned', 'edas#isReviewing'), 0.41869106682196056),
#  (('cmt#assignedTo', 'edas#isReviewedBy'), 0.5476728328223632),
#  (('edas#ConferenceDinner', 'ekaw#Conference_Banquet'), 0.8214476362145399),
#  (('edas#isReviewedBy', 'ekaw#hasReviewer'), 0.5463104073389253),
#  (('edas#Place', 'ekaw#Location'), 0.8596690903888166),
#  (('edas#AcademiaOrganization', 'ekaw#Academic_Institution'),
#   0.6167993963857633),
#  (('edas#isReviewing', 'ekaw#reviewerOfPaper'), 0.4574440998156941),
#  (('edas#Author', 'ekaw#Paper_Author'), 0.8141944477873271),
#  (('edas#isLocationOf', 'ekaw#locationOf'), 0.7440274368714033),
#  (('edas#Topic', 'ekaw#Research_Topic'), 0.7430159871513041),
#  (('edas#Programme', 'ekaw#Programme_Brochure'), 0.646281550441289),
#  (('edas#Attendee', 'ekaw#Conference_Participant'), 0.680457795262619),
#  (('edas#hasLocation', 'ekaw#heldIn'), 0.43452960835641286),
#  (('conference#Information_for_participants', 'ekaw#Programme_Brochure'),
#   0.14447489564546379),
#  (('conference#has_a_review', 'ekaw#hasReview'), 0.871024504786548),
#  (('conference#Late_paid_applicant', 'ekaw#Late-Registered_Participant'),
#   0.33586687035150753),
#  (('conference#Early_paid_applicant', 'ekaw#Early-Registered_Participant'),
#   0.30097502276887556),
#  (('conference#Track-workshop_chair', 'ekaw#Workshop_Chair'),
#   0.6079487556759193),
#  (('conference#Conference_volume', 'ekaw#Conference'), 0.7533685068578012),
#  (('conference#Rejected_contribution', 'ekaw#Rejected_Paper'),
#   0.665432017501309),
#  (('conference#Poster', 'ekaw#Poster_Paper'), 0.848680973814423),
#  (('conference#Topic', 'ekaw#Research_Topic'), 0.7430159871513041),
#  (('conference#Conference_www', 'ekaw#Web_Site'), 0.38331955121201877),
#  (('conference#contributes', 'ekaw#authorOf'), 0.3016937274326247),
#  (('conference#Accepted_contribution', 'ekaw#Accepted_Paper'),
#   0.6685831555241036),
#  (('conference#Reviewed_contribution', 'ekaw#Evaluated_Paper'),
#   0.9118731205016369),
#  (('conference#Submitted_contribution', 'ekaw#Submitted_Paper'),
#   0.6310057945795197),
#  (('conference#Regular_author', 'ekaw#Paper_Author'), 0.6647226575589719),
#  (('confOf#Poster', 'ekaw#Poster_Paper'), 0.848680973814423),
#  (('confOf#Author', 'ekaw#Paper_Author'), 0.8141944484983646),
#  (('confOf#Banquet', 'ekaw#Conference_Banquet'), 0.8356824654363613),
#  (('confOf#Topic', 'ekaw#Research_Topic'), 0.7430159871513041),
#  (('confOf#Trip', 'ekaw#Conference_Trip'), 0.6513987957309976),
#  (('confOf#Scholar', 'ekaw#Student'), 0.6424033499330857)]

# %%
pickle.dump([fn, fp], open("test_best.pkl", "wb"))

# %%
gt_mappings
# Out:
# [('conference#Information_for_participants', 'ekaw#Programme_Brochure'),
#  ('conference#Person', 'ekaw#Person'),
#  ('conference#Tutorial', 'ekaw#Tutorial'),
#  ('conference#Review', 'ekaw#Review'),
#  ('conference#has_a_review', 'ekaw#hasReview'),
#  ('conference#Workshop', 'ekaw#Workshop'),
#  ('conference#Late_paid_applicant', 'ekaw#Late-Registered_Participant'),
#  ('conference#Early_paid_applicant', 'ekaw#Early-Registered_Participant'),
#  ('conference#Organization', 'ekaw#Organisation'),
#  ('conference#Track-workshop_chair', 'ekaw#Workshop_Chair'),
#  ('conference#Abstract', 'ekaw#Abstract'),
#  ('conference#Conference_proceedings', 'ekaw#Conference_Proceedings'),
#  ('conference#Conference_volume', 'ekaw#Conference'),
#  ('conference#Rejected_contribution', 'ekaw#Rejected_Paper'),
#  ('conference#Poster', 'ekaw#Poster_Paper'),
#  ('conference#Track', 'ekaw#Track'),
#  ('conference#Topic', 'ekaw#Research_Topic'),
#  ('conference#Conference_www', 'ekaw#Web_Site'),
#  ('conference#Invited_speaker', 'ekaw#Invited_Speaker'),
#  ('conference#contributes', 'ekaw#authorOf'),
#  ('conference#Accepted_contribution', 'ekaw#Accepted_Paper'),
#  ('conference#Conference_document', 'ekaw#Document'),
#  ('conference#Reviewed_contribution', 'ekaw#Evaluated_Paper'),
#  ('conference#Submitted_contribution', 'ekaw#Submitted_Paper'),
#  ('conference#Regular_author', 'ekaw#Paper_Author'),
#  ('confOf#Tutorial', 'ekaw#Tutorial'),
#  ('confOf#Poster', 'ekaw#Poster_Paper'),
#  ('confOf#Social_event', 'ekaw#Social_Event'),
#  ('confOf#Person', 'ekaw#Person'),
#  ('confOf#Working_event', 'ekaw#Scientific_Event'),
#  ('confOf#Conference', 'ekaw#Conference'),
#  ('confOf#Author', 'ekaw#Paper_Author'),
#  ('confOf#Banquet', 'ekaw#Conference_Banquet'),
#  ('confOf#Workshop', 'ekaw#Workshop'),
#  ('confOf#Topic', 'ekaw#Research_Topic'),
#  ('confOf#Contribution', 'ekaw#Paper'),
#  ('confOf#Participant', 'ekaw#Conference_Participant'),
#  ('confOf#Chair_PC', 'ekaw#PC_Chair'),
#  ('confOf#Organization', 'ekaw#Organisation'),
#  ('confOf#Student', 'ekaw#Student'),
#  ('confOf#University', 'ekaw#University'),
#  ('confOf#Trip', 'ekaw#Conference_Trip'),
#  ('confOf#Member_PC', 'ekaw#PC_Member'),
#  ('confOf#Scholar', 'ekaw#Student'),
#  ('confOf#Event', 'ekaw#Event'),
#  ('ekaw#Conference', 'sigkdd#Conference'),
#  ('ekaw#Person', 'sigkdd#Person'),
#  ('ekaw#Paper', 'sigkdd#Paper'),
#  ('ekaw#Review', 'sigkdd#Review'),
#  ('ekaw#Invited_Speaker', 'sigkdd#Invited_Speaker'),
#  ('ekaw#OC_Member', 'sigkdd#Organizing_Committee_member'),
#  ('ekaw#Abstract', 'sigkdd#Abstract'),
#  ('ekaw#PC_Chair', 'sigkdd#Program_Chair'),
#  ('ekaw#Paper_Author', 'sigkdd#Author'),
#  ('ekaw#Document', 'sigkdd#Document'),
#  ('ekaw#Location', 'sigkdd#Place'),
#  ('edas#Place', 'sigkdd#Place'),
#  ('edas#hasCostAmount', 'sigkdd#Price'),
#  ('edas#Person', 'sigkdd#Person'),
#  ('edas#hasName', 'sigkdd#Name_of_conference'),
#  ('edas#ConferenceVenuePlace', 'sigkdd#Conference_hall'),
#  ('edas#Author', 'sigkdd#Author'),
#  ('edas#AccommodationPlace', 'sigkdd#Hotel'),
#  ('edas#startDate', 'sigkdd#Start_of_conference'),
#  ('edas#ConferenceChair', 'sigkdd#General_Chair'),
#  ('edas#Conference', 'sigkdd#Conference'),
#  ('edas#endDate', 'sigkdd#End_of_conference'),
#  ('edas#Review', 'sigkdd#Review'),
#  ('edas#Document', 'sigkdd#Document'),
#  ('edas#Paper', 'sigkdd#Paper'),
#  ('edas#Attendee', 'sigkdd#Listener'),
#  ('confOf#Person', 'sigkdd#Person'),
#  ('confOf#Member_PC', 'sigkdd#Program_Committee_member'),
#  ('confOf#hasEmail', 'sigkdd#E-mail'),
#  ('confOf#Author', 'sigkdd#Author'),
#  ('confOf#Conference', 'sigkdd#Conference'),
#  ('confOf#Chair_PC', 'sigkdd#Program_Chair'),
#  ('confOf#Paper', 'sigkdd#Paper'),
#  ('iasted#Place', 'sigkdd#Place'),
#  ('iasted#Review', 'sigkdd#Review'),
#  ('iasted#Student_registration_fee', 'sigkdd#Registration_Student'),
#  ('iasted#Fee', 'sigkdd#Fee'),
#  ('iasted#Registration_fee', 'sigkdd#Registration_fee'),
#  ('iasted#Sponsor', 'sigkdd#Sponzor'),
#  ('iasted#Deadline_for_notification_of_acceptance',
#   'sigkdd#Deadline_Author_notification'),
#  ('iasted#Nonmember_registration_fee', 'sigkdd#Registration_Non-Member'),
#  ('iasted#Author', 'sigkdd#Author'),
#  ('iasted#Listener', 'sigkdd#Listener'),
#  ('iasted#Main_office', 'sigkdd#Main_office'),
#  ('iasted#Conference_hall', 'sigkdd#Conference_hall'),
#  ('iasted#Person', 'sigkdd#Person'),
#  ('iasted#Deadline', 'sigkdd#Deadline'),
#  ('iasted#Speaker', 'sigkdd#Speaker'),
#  ('confOf#Event', 'iasted#Activity'),
#  ('confOf#Author', 'iasted#Author'),
#  ('confOf#Person', 'iasted#Person'),
#  ('confOf#Banquet', 'iasted#Dinner_banquet'),
#  ('confOf#Administrative_event', 'iasted#Activity_before_conference'),
#  ('confOf#Reception', 'iasted#Coctail_reception'),
#  ('confOf#City', 'iasted#City'),
#  ('confOf#Tutorial', 'iasted#Tutorial'),
#  ('confOf#Country', 'iasted#State'),
#  ('conference#Passive_conference_participant', 'iasted#Listener'),
#  ('conference#Active_conference_participant', 'iasted#Speaker'),
#  ('conference#Reviewer', 'iasted#Reviewer'),
#  ('conference#Person', 'iasted#Person'),
#  ('conference#Regular_author', 'iasted#Author'),
#  ('conference#Conference_fees', 'iasted#Fee'),
#  ('conference#Tutorial', 'iasted#Tutorial'),
#  ('conference#contributes', 'iasted#write'),
#  ('conference#Review', 'iasted#Review'),
#  ('conference#Conference_document', 'iasted#Document'),
#  ('conference#Conference_part', 'iasted#Conference_activity'),
#  ('conference#Submitted_contribution', 'iasted#Submission'),
#  ('conference#Camera_ready_contribution', 'iasted#Final_manuscript'),
#  ('conference#Conference_proceedings', 'iasted#Publication'),
#  ('confOf#Trip', 'edas#Excursion'),
#  ('confOf#Social_event', 'edas#SocialEvent'),
#  ('confOf#reviewes', 'edas#isReviewing'),
#  ('confOf#Organization', 'edas#Organization'),
#  ('confOf#writtenBy', 'edas#isWrittenBy'),
#  ('confOf#Working_event', 'edas#AcademicEvent'),
#  ('confOf#Reception', 'edas#Reception'),
#  ('confOf#hasSurname', 'edas#hasLastName'),
#  ('confOf#Workshop', 'edas#Workshop'),
#  ('confOf#Author', 'edas#Author'),
#  ('confOf#hasFirstName', 'edas#hasFirstName'),
#  ('confOf#Event', 'edas#ConferenceEvent'),
#  ('confOf#Topic', 'edas#Topic'),
#  ('confOf#Country', 'edas#Country'),
#  ('confOf#Participant', 'edas#Attendee'),
#  ('confOf#Person', 'edas#Person'),
#  ('confOf#Member_PC', 'edas#TPCMember'),
#  ('confOf#Paper', 'edas#Paper'),
#  ('confOf#writes', 'edas#hasRelatedPaper'),
#  ('edas#Place', 'iasted#Place'),
#  ('edas#SessionChair', 'iasted#Session_chair'),
#  ('edas#Author', 'iasted#Author'),
#  ('edas#Document', 'iasted#Document'),
#  ('edas#Country', 'iasted#State'),
#  ('edas#WelcomeTalk', 'iasted#Welcome_address'),
#  ('edas#Sponsorship', 'iasted#Sponzorship'),
#  ('edas#Reviewer', 'iasted#Reviewer'),
#  ('edas#Attendee', 'iasted#Delegate'),
#  ('edas#ConferenceDinner', 'iasted#Dinner_banquet'),
#  ('edas#SocialEvent', 'iasted#Social_program'),
#  ('edas#CoffeeBreak', 'iasted#Coffee_break'),
#  ('edas#Review', 'iasted#Review'),
#  ('edas#Reception', 'iasted#Coctail_reception'),
#  ('edas#ConferenceEvent', 'iasted#Conference_activity'),
#  ('edas#SlideSet', 'iasted#Transparency'),
#  ('edas#Paper', 'iasted#Submission'),
#  ('edas#ConferenceVenuePlace', 'iasted#Conference_building'),
#  ('edas#DiningPlace', 'iasted#Conference_restaurant'),
#  ('conference#Person', 'edas#Person'),
#  ('conference#Conference_participant', 'edas#Attendee'),
#  ('conference#Organization', 'edas#Organization'),
#  ('conference#Reviewer', 'edas#Reviewer'),
#  ('conference#has_the_first_name', 'edas#hasFirstName'),
#  ('conference#Conference_part', 'edas#ConferenceEvent'),
#  ('conference#Workshop', 'edas#Workshop'),
#  ('conference#Conference_document', 'edas#Document'),
#  ('conference#Paper', 'edas#Paper'),
#  ('conference#has_a_review_expertise', 'edas#hasRating'),
#  ('conference#has_the_last_name', 'edas#hasLastName'),
#  ('conference#Review', 'edas#Review'),
#  ('conference#Conference_volume', 'edas#Conference'),
#  ('conference#Rejected_contribution', 'edas#RejectedPaper'),
#  ('conference#Topic', 'edas#Topic'),
#  ('conference#Accepted_contribution', 'edas#AcceptedPaper'),
#  ('conference#Regular_author', 'edas#Author'),
#  ('cmt#Document', 'ekaw#Document'),
#  ('cmt#ConferenceMember', 'ekaw#Conference_Participant'),
#  ('cmt#Author', 'ekaw#Paper_Author'),
#  ('cmt#writtenBy', 'ekaw#reviewWrittenBy'),
#  ('cmt#hasBeenAssigned', 'ekaw#reviewerOfPaper'),
#  ('cmt#Person', 'ekaw#Person'),
#  ('cmt#Conference', 'ekaw#Conference'),
#  ('cmt#assignedTo', 'ekaw#hasReviewer'),
#  ('cmt#Review', 'ekaw#Review'),
#  ('cmt#Paper', 'ekaw#Paper'),
#  ('cmt#PaperFullVersion', 'ekaw#Regular_Paper'),
#  ('cmt#ProgramCommitteeChair', 'confOf#Chair_PC'),
#  ('cmt#writePaper', 'confOf#writes'),
#  ('cmt#Author', 'confOf#Author'),
#  ('cmt#ConferenceMember', 'confOf#Member'),
#  ('cmt#Administrator', 'confOf#Administrator'),
#  ('cmt#title', 'confOf#hasTitle'),
#  ('cmt#SubjectArea', 'confOf#Topic'),
#  ('cmt#PaperFullVersion', 'confOf#Paper'),
#  ('cmt#hasBeenAssigned', 'confOf#reviewes'),
#  ('cmt#hasAuthor', 'confOf#writtenBy'),
#  ('cmt#Conference', 'confOf#Conference'),
#  ('cmt#ProgramCommitteeMember', 'confOf#Member_PC'),
#  ('cmt#hasSubjectArea', 'confOf#dealsWith'),
#  ('cmt#Person', 'confOf#Person'),
#  ('cmt#Paper', 'confOf#Contribution'),
#  ('cmt#email', 'confOf#hasEmail'),
#  ('cmt#Person', 'edas#Person'),
#  ('cmt#Conference', 'edas#Conference'),
#  ('cmt#Author', 'edas#Author'),
#  ('cmt#Reviewer', 'edas#Reviewer'),
#  ('cmt#hasConferenceMember', 'edas#hasMember'),
#  ('cmt#memberOfConference', 'edas#isMemberOf'),
#  ('cmt#ConferenceChair', 'edas#ConferenceChair'),
#  ('cmt#Review', 'edas#Review'),
#  ('cmt#Document', 'edas#Document'),
#  ('cmt#Paper', 'edas#Paper'),
#  ('cmt#hasAuthor', 'edas#isWrittenBy'),
#  ('cmt#hasBeenAssigned', 'edas#isReviewing'),
#  ('cmt#assignedTo', 'edas#isReviewedBy'),
#  ('conference#Abstract', 'sigkdd#Abstract'),
#  ('conference#Invited_speaker', 'sigkdd#Invited_Speaker'),
#  ('conference#Regular_author', 'sigkdd#Author'),
#  ('conference#Review', 'sigkdd#Review'),
#  ('conference#Program_committee', 'sigkdd#Program_Committee'),
#  ('conference#Conference_volume', 'sigkdd#Conference'),
#  ('conference#Conference_fees', 'sigkdd#Fee'),
#  ('conference#has_an_email', 'sigkdd#E-mail'),
#  ('conference#Paper', 'sigkdd#Paper'),
#  ('conference#Organizing_committee', 'sigkdd#Organizing_Committee'),
#  ('conference#Person', 'sigkdd#Person'),
#  ('conference#Committee', 'sigkdd#Committee'),
#  ('conference#is_given_by', 'sigkdd#presentationed_by'),
#  ('conference#gives_presentations', 'sigkdd#presentation'),
#  ('conference#Conference_document', 'sigkdd#Document'),
#  ('cmt#Conference', 'sigkdd#Conference'),
#  ('cmt#Paper', 'sigkdd#Paper'),
#  ('cmt#ProgramCommitteeMember', 'sigkdd#Program_Committee_member'),
#  ('cmt#Document', 'sigkdd#Document'),
#  ('cmt#ConferenceChair', 'sigkdd#General_Chair'),
#  ('cmt#email', 'sigkdd#E-mail'),
#  ('cmt#Review', 'sigkdd#Review'),
#  ('cmt#ProgramCommittee', 'sigkdd#Program_Committee'),
#  ('cmt#ProgramCommitteeChair', 'sigkdd#Program_Chair'),
#  ('cmt#Author', 'sigkdd#Author'),
#  ('cmt#submitPaper', 'sigkdd#submit'),
#  ('cmt#Person', 'sigkdd#Person'),
#  ('conference#Conference_participant', 'confOf#Participant'),
#  ('conference#has_an_email', 'confOf#hasEmail'),
#  ('conference#Poster', 'confOf#Poster'),
#  ('conference#Organization', 'confOf#Organization'),
#  ('conference#Topic', 'confOf#Topic'),
#  ('conference#Workshop', 'confOf#Workshop'),
#  ('conference#Paper', 'confOf#Paper'),
#  ('conference#Person', 'confOf#Person'),
#  ('conference#Conference_contribution', 'confOf#Contribution'),
#  ('conference#Tutorial', 'confOf#Tutorial'),
#  ('conference#Conference_volume', 'confOf#Conference'),
#  ('conference#has_a_track-workshop-tutorial_topic', 'confOf#hasTopic'),
#  ('conference#Regular_author', 'confOf#Author'),
#  ('conference#has_the_last_name', 'confOf#hasSurname'),
#  ('conference#has_the_first_name', 'confOf#hasFirstName'),
#  ('edas#ConferenceDinner', 'ekaw#Conference_Banquet'),
#  ('edas#AcademicEvent', 'ekaw#Scientific_Event'),
#  ('edas#AcceptedPaper', 'ekaw#Accepted_Paper'),
#  ('edas#isReviewedBy', 'ekaw#hasReviewer'),
#  ('edas#Place', 'ekaw#Location'),
#  ('edas#AcademiaOrganization', 'ekaw#Academic_Institution'),
#  ('edas#SocialEvent', 'ekaw#Social_Event'),
#  ('edas#isReviewing', 'ekaw#reviewerOfPaper'),
#  ('edas#Organization', 'ekaw#Organisation'),
#  ('edas#Author', 'ekaw#Paper_Author'),
#  ('edas#isLocationOf', 'ekaw#locationOf'),
#  ('edas#Topic', 'ekaw#Research_Topic'),
#  ('edas#Document', 'ekaw#Document'),
#  ('edas#RejectedPaper', 'ekaw#Rejected_Paper'),
#  ('edas#ConferenceEvent', 'ekaw#Event'),
#  ('edas#SessionChair', 'ekaw#Session_Chair'),
#  ('edas#Person', 'ekaw#Person'),
#  ('edas#Programme', 'ekaw#Programme_Brochure'),
#  ('edas#Review', 'ekaw#Review'),
#  ('edas#Workshop', 'ekaw#Workshop'),
#  ('edas#Paper', 'ekaw#Paper'),
#  ('edas#Attendee', 'ekaw#Conference_Participant'),
#  ('edas#hasLocation', 'ekaw#heldIn'),
#  ('cmt#Conference', 'conference#Conference_volume'),
#  ('cmt#Preference', 'conference#Review_preference'),
#  ('cmt#Author', 'conference#Regular_author'),
#  ('cmt#Person', 'conference#Person'),
#  ('cmt#email', 'conference#has_an_email'),
#  ('cmt#Co-author', 'conference#Contribution_co-author'),
#  ('cmt#PaperAbstract', 'conference#Abstract'),
#  ('cmt#Document', 'conference#Conference_document'),
#  ('cmt#Review', 'conference#Review'),
#  ('cmt#Conference', 'conference#Conference'),
#  ('cmt#ProgramCommittee', 'conference#Program_committee'),
#  ('cmt#Chairman', 'conference#Chair'),
#  ('cmt#SubjectArea', 'conference#Topic'),
#  ('cmt#assignedByReviewer', 'conference#invited_by'),
#  ('cmt#assignExternalReviewer', 'conference#invites_co-reviewers'),
#  ('cmt#Author', 'iasted#Author'),
#  ('cmt#Review', 'iasted#Review'),
#  ('cmt#Person', 'iasted#Person'),
#  ('cmt#Reviewer', 'iasted#Reviewer'),
#  ('ekaw#Location', 'iasted#Place'),
#  ('ekaw#Document', 'iasted#Document'),
#  ('ekaw#Event', 'iasted#Activity'),
#  ('ekaw#Person', 'iasted#Person'),
#  ('ekaw#Paper_Author', 'iasted#Author'),
#  ('ekaw#Session', 'iasted#Session'),
#  ('ekaw#Review', 'iasted#Review'),
#  ('ekaw#Conference_Banquet', 'iasted#Dinner_banquet'),
#  ('ekaw#Tutorial', 'iasted#Tutorial'),
#  ('ekaw#Session_Chair', 'iasted#Session_chair'),
#  ('mouse#urethralis', 'human#Urethralis'),
#  ('mouse#eyelid tarsus', 'human#Tarsal_Plate'),
#  ('mouse#femoral artery', 'human#Femoral_Artery'),
#  ('mouse#dorsal foot interosseus muscle',
#   'human#Dorsal_Foot_Interosseous_Muscle'),
#  ('mouse#transverse colon', 'human#Transverse_Colon'),
#  ('mouse#cochlear duct', 'human#Cochlear_Duct'),
#  ('mouse#spleen central arteriole', 'human#Splenic_Arteriole'),
#  ('mouse#rib 12', 'human#Rib_12'),
#  ('mouse#arm', 'human#Arm'),
#  ('mouse#exocrine pancreas', 'human#Exocrine_Pancreas'),
#  ('mouse#hippocampus CA2', 'human#CA2_Field_of_the_Cornu_Ammonis'),
#  ('mouse#arachnoid mater', 'human#Arachnoid_Membrane'),
#  ('mouse#testis', 'human#Testis'),
#  ('mouse#sclera', 'human#Sclera'),
#  ('mouse#lower eyelid', 'human#Lower_Eyelid'),
#  ('mouse#tibial artery', 'human#Tibial_Artery'),
#  ('mouse#cerebral aqueduct', 'human#Aqueduct_of_Sylvius'),
#  ('mouse#malleus', 'human#Malleus'),
#  ('mouse#meninges', 'human#Meninges'),
#  ('mouse#levator ani', 'human#Levator_Ani'),
#  ('mouse#phalanx', 'human#Phalanx'),
#  ('mouse#leg skin', 'human#Leg_Skin'),
#  ('mouse#small intestine', 'human#Small_Intestine'),
#  ('mouse#foot bone', 'human#Foot_Bone'),
#  ('mouse#geniohyoid', 'human#Geniohyoid'),
#  ('mouse#semispinalis cervicis', 'human#Semispinalis_Cervicis'),
#  ('mouse#nasal bone', 'human#Nasal_Bone'),
#  ('mouse#cystic duct', 'human#Cystic_Duct'),
#  ('mouse#right pulmonary vein', 'human#Right_Pulmonary_Vein'),
#  ('mouse#lacrimal gland', 'human#Lacrimal_Gland'),
#  ('mouse#liver', 'human#Liver'),
#  ('mouse#limb skin', 'human#Skin_of_the_Extremity'),
#  ('mouse#medial rectus extraocular muscle', 'human#Medial_Rectus_Muscle'),
#  ('mouse#alveolar artery', 'human#Alveolar_Artery'),
#  ('mouse#subiculum', 'human#Subiculum'),
#  ('mouse#retina inner plexiform layer', 'human#Inner_Plexiform_Layer'),
#  ('mouse#head', 'human#Head'),
#  ('mouse#left main bronchus', 'human#Left_Main_Bronchus'),
#  ('mouse#heart right atrium', 'human#Right_Atrium'),
#  ('mouse#orbit', 'human#Orbit'),
#  ('mouse#tibial nerve', 'human#Tibial_Nerve'),
#  ('mouse#artery smooth muscle', 'human#Artery_Smooth_Muscle_Tissue'),
#  ('mouse#ligament', 'human#Ligament'),
#  ('mouse#female reproductive system', 'human#Female_Reproductive_System'),
#  ('mouse#exocrine gland', 'human#Exocrine_Gland'),
#  ('mouse#fourth ventricle choroid plexus epithelium',
#   'human#Choroid_Plexus_Epithelium_of_the_Fourth_Ventricle'),
#  ('mouse#intervertebral disc', 'human#Intervertebral_Disc'),
#  ('mouse#stomach serosa', 'human#Gastric_Serosal_Surface'),
#  ('mouse#eyelash', 'human#Eyelash'),
#  ('mouse#heart atrium', 'human#Cardiac_Atrium'),
#  ('mouse#sternoclavicular joint', 'human#Sternoclavicular_Joint'),
#  ('mouse#right lung', 'human#Right_Lung'),
#  ('mouse#lacrimal artery', 'human#Lacrimal_Artery'),
#  ('mouse#palatine bone', 'human#Palatine_Bone'),
#  ('mouse#quadratus lumborum', 'human#Quadratus_Lumborum'),
#  ('mouse#female urethra', 'human#Female_Urethra'),
#  ('mouse#superior mesenteric vein', 'human#Superior_Mesenteric_Vein'),
#  ('mouse#filiform papilla', 'human#Filiform_Papilla'),
#  ('mouse#thyroid artery', 'human#Thyroid_Artery'),
#  ('mouse#talus', 'human#Astragalus'),
#  ('mouse#peroneus longus', 'human#Peroneus_Longus'),
#  ('mouse#right adrenal gland', 'human#Right_Adrenal_Gland'),
#  ('mouse#inferior epigastric artery', 'human#Inferior_Epigastric_Artery'),
#  ('mouse#interlobular artery', 'human#Interlobular_Artery'),
#  ('mouse#posterior limiting lamina', 'human#Descemet_s_Membrane'),
#  ('mouse#serum', 'human#Serum'),
#  ('mouse#vaginal hymen', 'human#Hymen'),
#  ('mouse#ileocolic vein', 'human#Ileocolic_Vein'),
#  ('mouse#common hepatic duct', 'human#Common_Hepatic_Duct'),
#  ('mouse#patella', 'human#Patella'),
#  ('mouse#coat hair bulb', 'human#Hair_Bulb'),
#  ('mouse#kidney collecting duct', 'human#Collecting_Tube'),
#  ('mouse#cuboid', 'human#Cuboid_Bone'),
#  ('mouse#masseteric vein', 'human#Masseteric_Vein'),
#  ('mouse#small intestine lamina propria',
#   'human#Small_Intestinal_Lamina_Propria'),
#  ('mouse#mammary gland milk', 'human#Breast_Milk'),
#  ('mouse#vein', 'human#Vein'),
#  ('mouse#feces', 'human#Feces'),
#  ('mouse#intestine secretion', 'human#Intestinal_Secretion'),
#  ('mouse#endocrine pancreas', 'human#Endocrine_Pancreas'),
#  ('mouse#bronchus epithelium', 'human#Bronchial_Epithelium'),
#  ('mouse#latissimus dorsi', 'human#Musculus_Latissimus_Dorsi'),
#  ('mouse#abducens VI nerve', 'human#Abducens_Nerve'),
#  ('mouse#tensor tympani', 'human#Tensor_Tympani'),
#  ('mouse#occipital bone', 'human#Occipital_Bone'),
#  ('mouse#thyroid gland follicle', 'human#Thyroid_Gland_Follicle'),
#  ('mouse#mental artery', 'human#Mental_Artery'),
#  ('mouse#extensor digitorum lateralis', 'human#Extensor_Digitorum_Lateralis'),
#  ('mouse#ear skin', 'human#Ear_Skin'),
#  ('mouse#macula of utricle', 'human#Macula_of_Utricle'),
#  ('mouse#flexor digitorum longus', 'human#Flexor_Digitorum_Longus'),
#  ('mouse#foot phalanx', 'human#Phalanx_of_the_Foot'),
#  ('mouse#psoas major', 'human#Psoas_Major'),
#  ('mouse#spinal nerve plexus', 'human#Spinal_Nerve_Plexus'),
#  ('mouse#bile duct', 'human#Bile_Duct'),
#  ('mouse#membranous urethra', 'human#Membranous_Urethra'),
#  ('mouse#liver perisinusoidal space', 'human#Perisinusoidal_Space'),
#  ('mouse#aorta', 'human#Aorta'),
#  ('mouse#artery', 'human#Artery'),
#  ('mouse#lymphatic vessel smooth muscle',
#   'human#Lymphatic_Vessel_Smooth_Muscle_Tissue'),
#  ('mouse#retina outer nuclear layer', 'human#Outer_Nuclear_Layer_of_Retina'),
#  ('mouse#anterior jugular vein', 'human#Anterior_Jugular_Vein'),
#  ('mouse#occipital artery', 'human#Occipital_Artery'),
#  ('mouse#pterygoid lateralis', 'human#External_Pterygoid_Muscle'),
#  ('mouse#ascending aorta', 'human#Ascending_Aorta'),
#  ('mouse#sacral vertebra 2', 'human#S2_Vertebra'),
#  ('mouse#anus', 'human#Anus'),
#  ('mouse#colon', 'human#Colon'),
#  ('mouse#arcuate nucleus', 'human#Arcuate_Nucleus'),
#  ('mouse#internal capsule', 'human#Internal_Capsule'),
#  ('mouse#putamen', 'human#Putamen'),
#  ('mouse#rib shaft', 'human#Rib_Shaft'),
#  ('mouse#portal vein', 'human#Portal_Vein'),
#  ('mouse#biceps femoris', 'human#Biceps_Femoris'),
#  ('mouse#cranium', 'human#Skull'),
#  ('mouse#parafascicular nucleus',
#   'human#Parafascicular_Nucleus_of_the_Thalamus'),
#  ('mouse#longissimus thoracis', 'human#Longissimus_Thoracis'),
#  ('mouse#cervical artery', 'human#Cervical_Artery'),
#  ('mouse#medial vestibular nucleus', 'human#Medial_Vestibular_Nucleus'),
#  ('mouse#penis', 'human#Penis'),
#  ('mouse#sublingual gland', 'human#Sublingual_Salivary_Gland'),
#  ('mouse#left lung bronchiole', 'human#Left_Lung_Bronchiole'),
#  ('mouse#spleen periarteriolar lymphatic sheath',
#   'human#Periarteriolar_Lymphoid_Sheath'),
#  ('mouse#seminiferous tubule', 'human#Seminiferous_Tubule'),
#  ('mouse#macula', 'human#Macula'),
#  ('mouse#tonsil capsule', 'human#Tonsillar_Capsule'),
#  ('mouse#vagina', 'human#Vagina'),
#  ('mouse#cerebral grey matter', 'human#Cerebral_Gray_Matter'),
#  ('mouse#bone', 'human#Bone'),
#  ('mouse#longus colli', 'human#Longus_Colli'),
#  ('mouse#ovarian artery', 'human#Ovarian_Artery'),
#  ('mouse#alveolar sac', 'human#Alveolar_Sac'),
#  ('mouse#external acoustic meatus', 'human#External_Acoustic_Meatus'),
#  ('mouse#lateral ventricle choroid plexus epithelium',
#   'human#Choroid_Plexus_Epithelium_of_the_Lateral_Ventricle'),
#  ('mouse#hamate', 'human#Hamate_Bone'),
#  ('mouse#heart right ventricle', 'human#Right_Ventricle'),
#  ('mouse#aorta smooth muscle', 'human#Aorta_Smooth_Muscle_Tissue'),
#  ('mouse#lienal artery', 'human#Splenic_Artery'),
#  ('mouse#internal iliac vein', 'human#Internal_Iliac_Vein'),
#  ('mouse#vastus lateralis', 'human#Vastus_Lateralis'),
#  ('mouse#lacrimal apparatus', 'human#Lacrimal_Apparatus'),
#  ('mouse#right kidney', 'human#Right_Kidney'),
#  ('mouse#nephron', 'human#Nephron'),
#  ('mouse#heart valve', 'human#Cardiac_Valve'),
#  ('mouse#spleen white pulp', 'human#Splenic_White_Pulp'),
#  ('mouse#renal pyramid', 'human#Renal_Pyramid'),
#  ('mouse#tectorial membrane', 'human#Tectorial_Membrane'),
#  ('mouse#dorsal metacarpal artery', 'human#Dorsal_Metacarpal_Artery'),
#  ('mouse#brain nucleus', 'human#Brain_Nucleus'),
#  ('mouse#labium', 'human#Labium'),
#  ('mouse#external naris', 'human#Nostril'),
#  ('mouse#hand digit 5 phalanx', 'human#Hand_Digit_5_Phalanx'),
#  ('mouse#hyoid bone', 'human#Hyoid_Bone'),
#  ('mouse#lumbosacral plexus', 'human#Lumbosacral_Plexus'),
#  ('mouse#rectus femoris', 'human#Rectus_Femoris'),
#  ('mouse#larynx connective tissue', 'human#Laryngeal_Connective_Tissue'),
#  ('mouse#lung surfactant', 'human#Lung_Surfactant'),
#  ('mouse#palatoglossus', 'human#Palatoglossus_Muscle'),
#  ('mouse#talus', 'human#Talus'),
#  ('mouse#anterior auricular vein', 'human#Anterior_Auricular_Vein'),
#  ('mouse#choroid plexus epithelium', 'human#Choroid_Plexus_Epithelium'),
#  ('mouse#eyelid skin', 'human#Eyelid_Skin'),
#  ('mouse#external ear cartilage', 'human#External_Ear_Cartilage'),
#  ('mouse#auricular artery', 'human#Auricular_Artery'),
#  ('mouse#lumbar vertebra 4', 'human#L4_Vertebra'),
#  ('mouse#rib tubercle', 'human#Rib_Tubercle'),
#  ('mouse#eye anterior chamber', 'human#Anterior_Chamber_of_the_Eye'),
#  ('mouse#pectoralis minor', 'human#Pectoralis_Minor'),
#  ('mouse#axial skeleton', 'human#Axial_Skeleton'),
#  ('mouse#olfactory bulb', 'human#Olfactory_Bulb'),
#  ('mouse#submandibular duct', 'human#Submandibular_Duct'),
#  ('mouse#omotransverse', 'human#Omotransverse'),
#  ('mouse#urine', 'human#Urine'),
#  ('mouse#pancreatico-duodenal vein', 'human#Pancreatico-Duodenal_Vein'),
#  ('mouse#kidney medulla', 'human#Renal_Medulla'),
#  ('mouse#cleidobrachial', 'human#Cleidobrachial'),
#  ('mouse#saccule', 'human#Saccule'),
#  ('mouse#stomach pyloric region', 'human#Pylorus'),
#  ('mouse#capitate', 'human#Capitate_Bone'),
#  ('mouse#basilar artery', 'human#Basilar_Artery'),
#  ('mouse#ureter', 'human#Ureter'),
#  ('mouse#cardiovascular system', 'human#Cardiovascular_System'),
#  ('mouse#extensor carpi radialis longus',
#   'human#Extensor_Carpi_Radialis_Longus'),
#  ('mouse#efferent lymphatic vessel', 'human#Lymph_Node_Efferent_Vessel'),
#  ('mouse#esophagus muscle', 'human#Esophageal_Muscularis_Mucosa'),
#  ('mouse#neck muscle', 'human#Neck_Muscle'),
#  ('mouse#submental vein', 'human#Submental_Vein'),
#  ('mouse#anterior facial vein', 'human#Anterior_Facial_Vein'),
#  ('mouse#urinary bladder neck', 'human#Bladder_Neck'),
#  ('mouse#large intestine serosa', 'human#Large_Intestinal_Serosal_Surface'),
#  ('mouse#abductor pollicis longus', 'human#Abductor_Pollicis_Longus'),
#  ('mouse#vas deferens', 'human#Vas_Deferens'),
#  ('mouse#small saphenous vein', 'human#Short_Saphenous_Vein'),
#  ('mouse#external jugular vein', 'human#External_Jugular_Vein'),
#  ('mouse#diencephalon', 'human#Diencephalon'),
#  ('mouse#pancreas secretion', 'human#Pancreatic_Secretion'),
#  ('mouse#femoral nerve', 'human#Femoral_Nerve'),
#  ('mouse#glans penis', 'human#Glans_Penis'),
#  ('mouse#loop of henle', 'human#Loop_of_Henle'),
#  ('mouse#solitary tract nucleus', 'human#Solitary_Nucleus'),
#  ('mouse#superior mesenteric artery', 'human#Superior_Mesenteric_Artery'),
#  ('mouse#external iliac vein', 'human#External_Iliac_Vein'),
#  ('mouse#supraorbital vein', 'human#Supra-orbital_Vein'),
#  ('mouse#dermis reticular layer', 'human#Stratum_Reticulare'),
#  ('mouse#molar', 'human#Molar_Tooth'),
#  ('mouse#trachea submucosa', 'human#Trachea_Submucosa'),
#  ('mouse#cervical vertebra 4', 'human#C4_Vertebra'),
#  ('mouse#flexor carpi radialis', 'human#Flexor_Carpi_Radialis'),
#  ('mouse#dentate gyrus', 'human#Dentate_Gyrus'),
#  ('mouse#foot phalanx', 'human#Foot_Phalanx'),
#  ('mouse#subcutaneous adipose tissue', 'human#Subcutis'),
#  ('mouse#longissimus lumborum', 'human#Longissimus_Lumborum'),
#  ('mouse#sacral vertebra 1', 'human#S1_Vertebra'),
#  ('mouse#pronator teres', 'human#Pronator_Teres'),
#  ('mouse#trigeminal V nucleus', 'human#Trigeminal_Nucleus'),
#  ('mouse#spinalis thoracis', 'human#Spinalis_Thoracis'),
#  ('mouse#palpebral conjunctiva', 'human#Palpebral_Conjunctiva'),
#  ('mouse#incisor', 'human#Incisor'),
#  ('mouse#pancreatico-duodenal artery', 'human#Pancreatico-Duodenal_Artery'),
#  ('mouse#loop of henle descending limb',
#   'human#Descending_Limb_of_the_Henle_s_Loop'),
#  ('mouse#anterior abdominal wall muscle',
#   'human#Anterior_Abdominal_Wall_Muscle'),
#  ('mouse#neck', 'human#Neck'),
#  ('mouse#venous sinus', 'human#Venous_Sinus'),
#  ('mouse#gingiva', 'human#Gingiva'),
#  ('mouse#telencephalon', 'human#Supratentorial_Brain'),
#  ('mouse#left lung terminal bronchiole',
#   'human#Left_Lung_Terminal_Bronchiole'),
#  ('mouse#spinal artery', 'human#Spinal_Artery'),
#  ('mouse#bony labyrinth', 'human#Osseous_Labyrinth'),
#  ('mouse#pancreas head', 'human#Head_of_the_Pancreas'),
#  ('mouse#endocrine pancreas secretion',
#   'human#Pancreatic_Endocrine_Secretion'),
#  ('mouse#longissimus cervicis', 'human#Longissimus_Cervicis'),
#  ('mouse#common iliac artery', 'human#Common_Iliac_Artery'),
#  ('mouse#proximal phalanx of hand', 'human#Proximal_Phalanx_of_the_Hand'),
#  ('mouse#anterior tibial artery', 'human#Anterior_Tibial_Artery'),
#  ('mouse#vulva', 'human#Vulva'),
#  ('mouse#bone marrow', 'human#Bone_Marrow'),
#  ('mouse#metatarsal bone digit 1', 'human#Metatarsal_Bone_Digit_1'),
#  ('mouse#prostate gland lobe', 'human#Prostate_Gland_Lobe'),
#  ('mouse#great vein of heart', 'human#Great_Cardiac_Vein'),
#  ('mouse#pia mater', 'human#Pia_Mater'),
#  ('mouse#dorsal nasal artery', 'human#Dorsal_Nasal_Artery'),
#  ('mouse#pallidum', 'human#Globus_Pallidus'),
#  ('mouse#venous system smooth muscle',
#   'human#Venous_System_Smooth_Muscle_Tissue'),
#  ('mouse#dermis papillary layer', 'human#Stratum_Papillare'),
#  ('mouse#anal region', 'human#Anal_Region'),
#  ('mouse#splenius', 'human#Splenius'),
#  ('mouse#heart septum', 'human#Heart_Septum'),
#  ('mouse#axillary lymph node', 'human#Axillary_Lymph_Node'),
#  ('mouse#gall bladder epithelium', 'human#Gallbladder_Epithelium'),
#  ('mouse#smooth muscle tissue', 'human#Smooth_Muscle_Tissue'),
#  ('mouse#cerebellum white matter', 'human#Cerebellum_White_Matter'),
#  ('mouse#tympanic membrane', 'human#Tympanic_Membrane'),
#  ('mouse#thoracic cavity', 'human#Thoracic_Cavity'),
#  ('mouse#metacarpal bone digit 4', 'human#Metacarpal_Bone_Digit_4'),
#  ('mouse#internal mammary vein', 'human#Internal_Mammary_Vein'),
#  ('mouse#lacrimal sac', 'human#Lacrimal_Sac'),
#  ('mouse#tectum', 'human#Tectum_Mesencephali'),
#  ('mouse#cerebral white matter', 'human#Cerebral_White_Matter'),
#  ('mouse#spleen capsule', 'human#Splenic_Capsule'),
#  ('mouse#cortical bone', 'human#Cortical_Bone'),
#  ('mouse#superior vena cava', 'human#Superior_Vena_Cava'),
#  ('mouse#pubis', 'human#Pubic_Bone'),
#  ('mouse#long bone metaphysis', 'human#Metaphysis'),
#  ('mouse#intestine mucosa', 'human#Intestinal_Mucosa'),
#  ('mouse#right lung cranial lobe', 'human#Upper_Lobe_of_the_Right_Lung'),
#  ('mouse#semimembranosus', 'human#Semimembranosus'),
#  ('mouse#hypogastric nerve plexus', 'human#Hypogastric_Nerve_Plexus'),
#  ('mouse#muscle tissue', 'human#Muscle_Tissue'),
#  ('mouse#fornix', 'human#Cerebral_Fornix'),
#  ('mouse#hand digit', 'human#Finger'),
#  ('mouse#intercostal artery', 'human#Intercostal_Artery'),
#  ('mouse#long bone epiphysis', 'human#Long_Bone_Epiphysis'),
#  ('mouse#limb', 'human#Extremities'),
#  ('mouse#wrist skin', 'human#Wrist_Skin'),
#  ('mouse#cerebellar cortex', 'human#Cerebellar_Cortex'),
#  ('mouse#male reproductive system', 'human#Male_Reproductive_System'),
#  ('mouse#tongue papilla', 'human#Papilla_of_the_Tongue'),
#  ('mouse#spleen marginal sinus', 'human#Splenic_Marginal_Sinus'),
#  ('mouse#nose', 'human#Nose'),
#  ('mouse#ear', 'human#Ear'),
#  ('mouse#hand digit 2 phalanx', 'human#Hand_Digit_2_Phalanx'),
#  ('mouse#cervical vertebra 1', 'human#C1_Vertebra'),
#  ('mouse#internal thoracic vein', 'human#Internal_Thoracic_Vein'),
#  ('mouse#iliothoracic', 'human#Iliothoracic'),
#  ('mouse#kidney cortex', 'human#Renal_Cortex'),
#  ('mouse#anterior lingual gland', 'human#Lingual_Salivary_Gland'),
#  ('mouse#lower jaw incisor', 'human#Lower_Jaw_Incisor'),
#  ('mouse#joint of vertebral body', 'human#Vertebral_Joint'),
#  ('mouse#ileal vein', 'human#Ileal_Vein'),
#  ('mouse#head/neck', 'human#Head_and_Neck'),
#  ('mouse#oculomotor III nerve', 'human#Oculomotor_Nerve'),
#  ('mouse#hematopoietic system', 'human#Hematopoietic_System'),
#  ('mouse#erector spinae', 'human#Erector_Spinae'),
#  ('mouse#cerebral artery', 'human#Cerebral_Artery'),
#  ('mouse#foot', 'human#Foot'),
#  ('mouse#intestine smooth muscle', 'human#Intestinal_Smooth_Muscle_Tissue'),
#  ('mouse#saphenous vein', 'human#Saphenous_Vein'),
#  ('mouse#distal phalanx of hand', 'human#Distal_Phalanx_of_the_Hand'),
#  ('mouse#pharynx', 'human#Pharynx'),
#  ('mouse#pancreatic duct', 'human#Pancreatic_Duct'),
#  ('mouse#gastrocnemius', 'human#Gastrocnemius_Muscle'),
#  ('mouse#stomach pyloric antrum', 'human#Antrum_Pylori'),
#  ('mouse#cerebellum granule cell layer',
#   'human#Granular_Layer_of_the_Cerebellum'),
#  ('mouse#endocrine system', 'human#Endocrine_System'),
#  ('mouse#subclavian artery', 'human#Subclavian_Artery'),
#  ('mouse#fourth ventricle', 'human#Fourth_Ventricle_of_the_Brain'),
#  ('mouse#female reproductive system fluid/secretion',
#   'human#Female_Genital_System_Fluid_or_Secretion'),
#  ('mouse#oviduct', 'human#Fallopian_Tube'),
#  ('mouse#liver lobule', 'human#Hepatic_Lobule'),
#  ('mouse#articular cartilage', 'human#Articular_Cartilage'),
#  ('mouse#brown fat', 'human#Brown_Adipose_Tissue'),
#  ('mouse#left renal vein', 'human#Left_Renal_Vein'),
#  ('mouse#ischium', 'human#Ischium'),
#  ('mouse#membranous labyrinth', 'human#Membranous_Labyrinth'),
#  ('mouse#esophagus epithelium', 'human#Esophageal_Epithelium'),
#  ('mouse#prepuce', 'human#Prepuce'),
#  ('mouse#third ventricle choroid plexus',
#   'human#Choroid_Plexus_of_the_Third_Ventricle'),
#  ('mouse#biceps brachii', 'human#Biceps'),
#  ('mouse#ovary capsule', 'human#Ovarian_Capsule'),
#  ('mouse#foot interosseus muscle', 'human#Foot_Interosseous_Muscle'),
#  ('mouse#thyroid gland left lobe', 'human#Left_Thyroid_Gland_Lobe'),
#  ('mouse#pancreatic vein', 'human#Pancreatic_Vein'),
#  ('mouse#spinal cord grey matter', 'human#Gray_Matter_of_the_Spinal_Cord'),
#  ('mouse#radius', 'human#Radius_Bone'),
#  ('mouse#sensory organ system', 'human#Special_Sense_Organ_System'),
#  ('mouse#larynx cartilage', 'human#Laryngeal_Cartilage'),
#  ('mouse#pleura', 'human#Pleural_Tissue'),
#  ('mouse#right lung hilus', 'human#Hilar_Area_of_the_Right_Lung'),
#  ('mouse#arteriole smooth muscle', 'human#Arteriole_Smooth_Muscle_Tissue'),
#  ('mouse#lymphoid system', 'human#Lymphatic_System'),
#  ('mouse#skin', 'human#Skin'),
#  ('mouse#stomach lesser curvature', 'human#Lesser_Curvature'),
#  ('mouse#central nervous system', 'human#Central_Nervous_System'),
#  ('mouse#conjunctiva', 'human#Conjunctiva'),
#  ('mouse#sphincter colli superficialis',
#   'human#Sphincter_Colli_Superficialis'),
#  ('mouse#medial geniculate nucleus', 'human#Internal_Geniculate_Body'),
#  ('mouse#cerebral vein', 'human#Cerebral_Vein'),
#  ('mouse#pterygoid medialis', 'human#Internal_Pterygoid_Muscle'),
#  ('mouse#uterus serosa', 'human#Uterus_Serosal_Surface'),
#  ('mouse#gall bladder smooth muscle',
#   'human#Gallbladder_Smooth_Muscle_Tissue'),
#  ('mouse#carotid artery', 'human#Carotid_Artery'),
#  ('mouse#bulboglandular', 'human#Bulboglandular'),
#  ('mouse#sternal manubrium', 'human#Sternal_Manubrium'),
#  ('mouse#blood vessel', 'human#Blood_Vessel'),
#  ('mouse#bile duct intrahepatic part', 'human#Intrahepatic_Bile_Duct'),
#  ('mouse#lymph node medulla', 'human#Lymph_Node_Medullary_Portion'),
#  ('mouse#liver quadrate lobe', 'human#Lobus_Quadratus'),
#  ('mouse#internal naris', 'human#Internal_Nare'),
#  ('mouse#rib 4', 'human#Rib_4'),
#  ('mouse#liver caudate lobe', 'human#Lobus_Caudatus'),
#  ('mouse#amygdala', 'human#Amygdala'),
#  ('mouse#auditory cortex', 'human#Auditory_Cortex'),
#  ('mouse#soft palate', 'human#Soft_Palate'),
#  ('mouse#transversus thoracis', 'human#Transversus_Thoracis'),
#  ('mouse#head/neck skin', 'human#Skin_of_the_Scalp_and_Neck'),
#  ('mouse#sphenoid sinus', 'human#Sphenoid_Sinus'),
#  ('mouse#sebaceous gland', 'human#Sebaceous_Gland'),
#  ('mouse#middle cerebral artery', 'human#Middle_Cerebral_Artery'),
#  ('mouse#right lung caudal lobe', 'human#Lower_Lobe_of_the_Right_Lung'),
#  ('mouse#efferent duct', 'human#Efferent_Ductule'),
#  ('mouse#genioglossus', 'human#Genioglossus'),
#  ('mouse#substantia nigra', 'human#Substantia_Nigra'),
#  ('mouse#vestibular membrane', 'human#Vestibular_Membrane'),
#  ('mouse#vas deferens epithelium', 'human#Vas_Deferens_Epithelium'),
#  ('mouse#lymph', 'human#Lymph'),
#  ('mouse#constrictor muscle of pharynx inferior',
#   'human#Cricopharyngeus_Muscle'),
#  ('mouse#tooth', 'human#Tooth'),
#  ('mouse#penis foreskin', 'human#Male_Prepuce'),
#  ('mouse#submucous nerve plexus', 'human#Submucous_Nerve_Plexus'),
#  ('mouse#trigeminal V mesencephalic nucleus',
#   'human#Nucleus_of_the_Mesencephalic_Tract_of_the_Trigeminal_Nerve'),
#  ('mouse#inferior pancreatico-duodenal vein',
#   'human#Inferior_Pancreatico-Duodenal_Vein'),
#  ('mouse#intrahepatic part of left hepatic duct',
#   'human#Intrahepatic_Portion_of_the_Left_Hepatic_Duct'),
#  ('mouse#left lung alveolar duct', 'human#Left_Lung_Alveolar_Duct'),
#  ('mouse#corneal stroma', 'human#Corneal_Stroma'),
#  ('mouse#bronchus cartilage', 'human#Bronchus_Cartilage'),
#  ('mouse#tooth substance', 'human#Tooth_Tissue'),
#  ('mouse#neurohypophysis', 'human#Posterior_Lobe_of_the_Pituitary_Gland'),
#  ('mouse#pericardiacophrenic vein', 'human#Pericardiacophrenic_Vein'),
#  ('mouse#internal iliac artery', 'human#Internal_Iliac_Artery'),
#  ('mouse#abdominal aorta', 'human#Abdominal_Aorta'),
#  ('mouse#areola', 'human#Areola'),
#  ('mouse#spleen trabeculum', 'human#Splenic_Trabecula'),
#  ('mouse#bronchus smooth muscle', 'human#Bronchus_Smooth_Muscle_Tissue'),
#  ('mouse#heart left ventricle', 'human#Left_Ventricle'),
#  ('mouse#left spermatic vein', 'human#Left_Spermatic_Vein'),
#  ('mouse#pisiform', 'human#Pisiform_Bone'),
#  ('mouse#parietal bone', 'human#Parietal_Bone'),
#  ('mouse#spinal cord ependymal layer',
#   'human#Remnants_of_the_Central_Canal_of_the_Spinal_Cord'),
#  ('mouse#thymus medulla', 'human#Thymus_Medulla'),
#  ('mouse#head skin', 'human#Head_Skin'),
#  ('mouse#pelvis', 'human#Pelvis'),
#  ('mouse#cortical layer II', 'human#External_Granular_Layer'),
#  ('mouse#foot digit 4', 'human#Foot_Digit_4'),
#  ('mouse#forebrain', 'human#Prosencephalon'),
#  ('mouse#pigmented retinal epithelium', 'human#Retinal_Pigment_Epithelium'),
#  ('mouse#right common carotid artery', 'human#Right_Common_Carotid_Artery'),
#  ('mouse#urethra epithelium', 'human#Urethra_Epithelium'),
#  ('mouse#fibula', 'human#Fibula'),
#  ('mouse#circumvallate papilla', 'human#Circumvallate_Papilla'),
#  ('mouse#leg', 'human#Leg'),
#  ('mouse#vascular system', 'human#Vascular_System'),
#  ('mouse#vestibulocochlear VIII nerve', 'human#Vestibulocochlear_Nerve'),
#  ('mouse#frontal bone', 'human#Frontal_Bone'),
#  ('mouse#gastrointestinal system', 'human#Gastrointestinal_Tract'),
#  ('mouse#gastric artery', 'human#Gastric_Artery'),
#  ('mouse#large intestine mucosa', 'human#Large_Intestinal_Mucosa'),
#  ('mouse#peroneal nerve', 'human#Peroneal_Nerve'),
#  ('mouse#left pulmonary vein', 'human#Left_Pulmonary_Vein'),
#  ('mouse#cervical vertebra 7', 'human#C7_Vertebra'),
#  ('mouse#sartorius', 'human#Sartorius_Muscle'),
#  ('mouse#superior suprarenal artery', 'human#Superior_Suprarenal_Artery'),
#  ('mouse#ovary follicle', 'human#Ovarian_Follicle'),
#  ('mouse#parietal cortex', 'human#Parietal_Lobe_of_the_Brain'),
#  ('mouse#hippocampus', 'human#Hippocampus'),
#  ('mouse#lymphatic vessel', 'human#Lymphatic_Vessel'),
#  ('mouse#mesothelium', 'human#Mesothelium'),
#  ('mouse#transverse facial artery', 'human#Transverse_Facial_Artery'),
#  ('mouse#lower arm', 'human#Forearm'),
#  ('mouse#lower jaw molar', 'human#Lower_Jaw_Molar'),
#  ('mouse#intrahepatic part of right hepatic duct',
#   'human#Intrahepatic_Portion_of_the_Right_Hepatic_Duct'),
#  ('mouse#uterine cervix', 'human#Cervix'),
#  ('mouse#brachial artery', 'human#Brachial_Artery'),
#  ('mouse#popliteus', 'human#Popliteus_Muscle'),
#  ('mouse#saliva', 'human#Saliva'),
#  ('mouse#parietal pleura', 'human#Parietal_Pleura'),
#  ('mouse#submandibular gland', 'human#Submandibular_Gland'),
#  ('mouse#acetabulum', 'human#Acetabulum'),
#  ('mouse#rib 11', 'human#Rib_11'),
#  ('mouse#afferent arteriole', 'human#Renal_Afferent_Vessel'),
#  ('mouse#accessory XI nerve', 'human#Accessory_Nerve'),
#  ('mouse#dilatator pupillae', 'human#Dilator_Pupillae_Muscle'),
#  ('mouse#dental pulp', 'human#Dental_Pulp'),
#  ('mouse#perineum', 'human#Perineum'),
#  ('mouse#thoracic aorta', 'human#Thoracic_Aorta'),
#  ('mouse#thymus capsule', 'human#Thymic_Capsule'),
#  ('mouse#cephalic vein', 'human#Cephalic_Vein'),
#  ('mouse#large intestine', 'human#Large_Intestine'),
#  ('mouse#iliac circumflex artery', 'human#Circumflex_Iliac_Artery'),
#  ('mouse#vitreous body', 'human#Vitreous_Body'),
#  ('mouse#facial VII nerve', 'human#Facial_Nerve'),
#  ('mouse#superficial cervical artery', 'human#Superficial_Cervical_Artery'),
#  ('mouse#hippocampus CA3', 'human#CA3_Field_of_the_Cornu_Ammonis'),
#  ('mouse#urinary bladder lamina propria', 'human#Bladder_Lamina_Propria'),
#  ('mouse#pulmonary artery', 'human#Pulmonary_Artery'),
#  ('mouse#esophagus muscularis mucosa', 'human#Esophageal_Muscular_Coat'),
#  ('mouse#esophagus squamous epithelium',
#   'human#Esophageal_Squamous_Epithelium'),
#  ('mouse#posterior communicating artery',
#   'human#Posterior_Communicating_Artery'),
#  ('mouse#stomach cardiac region', 'human#Cardia'),
#  ('mouse#skeletal system', 'human#Skeletal_System'),
#  ('mouse#serratus dorsalis caudalis', 'human#Serratus_Dorsalis_Caudalis'),
#  ('mouse#parotid duct', 'human#Parotid_Duct'),
#  ('mouse#esophagus lamina propria', 'human#Esophageal_Lamina_Propria'),
#  ('mouse#sacroiliac joint', 'human#Sacroiliac_Joint'),
#  ('mouse#biliary tract', 'human#Biliary_Tract'),
#  ('mouse#arytenoid cartilage', 'human#Arytenoid_Cartilage'),
#  ('mouse#skin fluid/secretion', 'human#Skin_Fluid_or_Secretion'),
#  ('mouse#retina inner nuclear layer', 'human#Inner_Nuclear_Layer'),
#  ('mouse#gastric vein', 'human#Gastric_Vein'),
#  ('mouse#hilar part of hepatic duct',
#   'human#Hilar_Portion_of_the_Hepatic_Duct'),
#  ('mouse#eye', 'human#Eye'),
#  ('mouse#cerebellum internal granule cell layer',
#   'human#Internal_Granular_Layer_of_the_Cerebellum'),
#  ('mouse#sinoatrial node', 'human#Sinoatrial_Node'),
#  ('mouse#vagina epithelium', 'human#Vaginal_Epithelium'),
#  ('mouse#communicating artery', 'human#Communicating_Artery'),
#  ('mouse#lymph node', 'human#Lymph_Node'),
#  ('mouse#epidermis', 'human#Epidermis'),
#  ('mouse#esophagus muscularis mucosa', 'human#Esophageal_Muscularis_Mucosa'),
#  ('mouse#superior intercostal vein', 'human#Superior_Intercostal_Vein'),
#  ('mouse#splenic cord', 'human#Splenic_Cord'),
#  ('mouse#sweat', 'human#Sweat'),
#  ('mouse#hand digit 5', 'human#Hand_Digit_5'),
#  ('mouse#cervical vertebra 6', 'human#C6_Vertebra'),
#  ('mouse#superior rectus extraocular muscle', 'human#Superior_Rectus_Muscle'),
#  ('mouse#endocrine gland', 'human#Endocrine_Gland'),
#  ('mouse#seminal vesicle secretion', 'human#Seminal_Vesicle_Secretion'),
#  ('mouse#flexor hallucis longus', 'human#Flexor_Hallucis_Longus'),
#  ('mouse#descending aorta', 'human#Descending_Aorta'),
#  ('mouse#rib', 'human#Rib'),
#  ('mouse#epidermis stratum basale', 'human#Stratum_Basale'),
#  ('mouse#trigeminal V nerve ophthalmic division', 'human#Ophthalmic_Nerve'),
#  ('mouse#lymph node follicle', 'human#Lymph_Node_Lymphoid_Follicle'),
#  ('mouse#upper leg', 'human#Thigh'),
#  ('mouse#stomach submucosa', 'human#Gastric_Submucosa'),
#  ('mouse#brachialis', 'human#Brachialis'),
#  ('mouse#thoracic vertebra 5', 'human#T5_Vertebra'),
#  ('mouse#meibomian gland', 'human#Meibomian_Gland'),
#  ('mouse#vertebral column', 'human#Vertebral_Column'),
#  ('mouse#renal artery', 'human#Renal_Artery'),
#  ('mouse#lumbar vertebra 2', 'human#L2_Vertebra'),
#  ('mouse#bronchus lamina propria', 'human#Bronchus_Lamina_Propria'),
#  ('mouse#serratus ventralis', 'human#Serratus_Ventralis'),
#  ('mouse#orbitalis muscle', 'human#Orbitalis_Muscle'),
#  ('mouse#trigeminal V motor nucleus',
#   'human#Motor_Nucleus_of_the_Trigeminal_Nerve'),
#  ('mouse#crura cerebri', 'human#Crus_Cerebri'),
#  ('mouse#iliocostalis', 'human#Iliocostal_Muscle'),
#  ('mouse#hypothalamus', 'human#Hypothalamus'),
#  ('mouse#hand digit 1', 'human#Hand_Digit_1'),
#  ('mouse#celiac ganglion', 'human#Coeliac_Ganglion'),
#  ('mouse#pharynx muscle', 'human#Pharyngeal_Muscle'),
#  ('mouse#facial VII ganglion', 'human#Geniculate_Ganglion'),
#  ('mouse#limb digit', 'human#Digit'),
#  ('mouse#trapezium', 'human#Trapezial_Bone'),
#  ('mouse#phrenic vein', 'human#Phrenic_Vein'),
#  ('mouse#choroid', 'human#Choroid'),
#  ('mouse#urethra', 'human#Urethra'),
#  ('mouse#spermatic vein', 'human#Spermatic_Vein'),
#  ('mouse#small intestine muscularis mucosa',
#   'human#Small_Intestinal_Muscularis_Mucosa'),
#  ('mouse#stapes', 'human#Stapes'),
#  ('mouse#kidney pelvis', 'human#Renal_Pelvis'),
#  ('mouse#inferior hypogastric nerve plexus',
#   'human#Inferior_Hypogastric_Nerve_Plexus'),
#  ('mouse#foot digit 2', 'human#Foot_Digit_2'),
#  ('mouse#right lung terminal bronchiole',
#   'human#Right_Lung_Terminal_Bronchiole'),
#  ('mouse#gracilis', 'human#Gracilis'),
#  ('mouse#thoraco-acromial artery', 'human#Acromial_Thoracic_Artery'),
#  ('mouse#facial VII nucleus', 'human#Facial_Nerve_Nucleus'),
#  ('mouse#external carotid artery', 'human#External_Carotid_Artery'),
#  ('mouse#mucosa associated lymphoid tissue',
#   'human#Mucosa-Associated_Lymphoid_Tissue'),
#  ('mouse#alveolar duct', 'human#Alveolar_Duct'),
#  ('mouse#prostate gland smooth muscle', 'human#Prostatic_Muscular_Tissue'),
#  ('mouse#dorsal metatarsal vein', 'human#Dorsal_Metatarsal_Vein'),
#  ('mouse#decidua', 'human#Decidua'),
#  ("mouse#peyer's patch germinal center",
#   'human#Peyer_s_Patch_Germinal_Center'),
#  ('mouse#obliquus internus abdominis', 'human#Internal_Oblique_Muscle'),
#  ('mouse#ilio-lumbar vein', 'human#Iliolumbar_Vein'),
#  ('mouse#cerebellar artery', 'human#Cerebellar_Artery'),
#  ('mouse#medial palpebral ligament', 'human#Medial_Palpebral_Ligament'),
#  ('mouse#spleen germinal center', 'human#Spleen_Germinal_Center'),
#  ('mouse#cortical layer III', 'human#External_Pyramidal_Cell_Layer'),
#  ('mouse#arterial system endothelium', 'human#Arterial_System_Endothelium'),
#  ('mouse#tibilais cranialis', 'human#Tibialis_Cranialis'),
#  ('mouse#jugular vein', 'human#Jugular_Vein'),
#  ('mouse#loop of henle ascending limb',
#   'human#Ascending_Limb_of_the_Henle_s_Loop'),
#  ('mouse#interpeduncular nucleus', 'human#Oculomotor_Nucleus'),
#  ('mouse#costovertebral joint', 'human#Costovertebral_Joint'),
#  ('mouse#palatine tonsil', 'human#Palatine_Tonsil'),
#  ('mouse#nasopharyngeal tonsil', 'human#Pharyngeal_Tonsil'),
#  ('mouse#right renal vein', 'human#Right_Renal_Vein'),
#  ('mouse#mammillary body', 'human#Mamillary_Body'),
#  ('mouse#right lung middle lobe', 'human#Middle_Lobe_of_the_Right_Lung'),
#  ('mouse#cricothyroid', 'human#Cricothyroid_Muscle'),
#  ('mouse#tongue skeletal muscle', 'human#Tongue_Muscle'),
#  ('mouse#costal cartilage', 'human#Costal_Cartilage'),
#  ('mouse#thyrohyoid', 'human#Thyrohyoid'),
#  ('mouse#soleus', 'human#Soleus'),
#  ('mouse#connective tissue', 'human#Connective_Tissue'),
#  ('mouse#cochlea', 'human#Cochlea'),
#  ('mouse#stomach mucosa', 'human#Gastric_Mucosa'),
#  ('mouse#left lung alveolus', 'human#Left_Lung_Alveolus'),
#  ('mouse#right lung lobe', 'human#Lobe_of_the_Right_Lung'),
#  ('mouse#cerebellum purkinje cell layer',
#   'human#Purkinje_Cell_Layer_of_the_Cerebellum'),
#  ('mouse#spleen marginal zone', 'human#Splenic_Marginal_Zone'),
#  ('mouse#alveolus epithelium', 'human#Alveolar_Epithelium'),
#  ('mouse#hindbrain', 'human#Hind-Brain'),
#  ('mouse#hand skin', 'human#Hand_Skin'),
#  ('mouse#chest', 'human#Chest'),
#  ('mouse#juxtaglomerular complex', 'human#Juxtaglomerular_Apparatus'),
#  ('mouse#gluteus medius', 'human#Gluteus_Medius'),
#  ('mouse#cricoarytenoid', 'human#Cricoarytenoid_Muscle'),
#  ('mouse#eyelid', 'human#Eyelid'),
#  ('mouse#male reproductive system fluid/secretion',
#   'human#Male_Genital_System_Fluid_or_Secretion'),
#  ('mouse#urinary bladder fundus region', 'human#Bladder_Fundus'),
#  ('mouse#visceral organ system', 'human#Viscera'),
#  ('mouse#vestibulocochlear VIII nerve cochlear component',
#   'human#Cochlear_Nerve'),
#  ('mouse#larynx', 'human#Larynx'),
#  ('mouse#inferior mesenteric vein', 'human#Inferior_Mesenteric_Vein'),
#  ("mouse#brunner's gland", 'human#Brunner_s_Gland'),
#  ('mouse#eye posterior segment', 'human#Posterior_Eye_Segment'),
#  ('mouse#parotid gland', 'human#Parotid_Gland'),
#  ('mouse#vertebral artery', 'human#Vertebral_Artery'),
#  ('mouse#wrist joint', 'human#Wrist_Joint'),
#  ('mouse#adrenal gland zona fasciculata', 'human#Fasciculata_Zone'),
#  ('mouse#posterior commissure', 'human#Posterior_Commissure'),
#  ('mouse#lip', 'human#Lip'),
#  ('mouse#cerebellar vermis', 'human#Vermis'),
#  ('mouse#temporal bone', 'human#Temporal_Bone'),
#  ('mouse#ovary', 'human#Ovary'),
#  ('mouse#stomach smooth muscle', 'human#Gastric_Muscular_Coat'),
#  ('mouse#lateral ventricle choroid plexus',
#   'human#Choroid_Plexus_of_the_Lateral_Ventricle'),
#  ('mouse#urethra urothelium', 'human#Urethra_Transitional_Cell_Epithelium'),
#  ('mouse#vestibular labyrinth', 'human#Vestibular_Labyrinth'),
#  ('mouse#otolymph', 'human#Otolymph'),
#  ('mouse#esophagus', 'human#Esophagus'),
#  ('mouse#triquetral', 'human#Triangular_Bone'),
#  ('mouse#sweat gland', 'human#Sweat_Gland'),
#  ('mouse#hand phalanx', 'human#Hand_Phalanx'),
#  ('mouse#iliac vein', 'human#Iliac_Vein'),
#  ('mouse#glomerular visceral epithelium',
#   'human#Visceral_Layer_of_Bowman_s_Capsule'),
#  ('mouse#costal arch', 'human#Costal_Arch'),
#  ('mouse#labial artery', 'human#Labial_Artery'),
#  ('mouse#lateral ventricle ependyma', 'human#Lateral_Ventricle_Ependyma'),
#  ('mouse#medial tarsal artery', 'human#Medial_Tarsal_Artery'),
#  ('mouse#peroneal artery', 'human#Peroneal_Artery'),
#  ('mouse#levator palpebrae superioris', 'human#Levator_Palpebrae_Superioris'),
#  ('mouse#gastroepiploic artery', 'human#Gastroepiploic_Artery'),
#  ('mouse#parathyroid gland', 'human#Parathyroid_Gland'),
#  ('mouse#superior pancreatico-duodenal artery',
#   'human#Superior_Pancreatico-Duodenal_Artery'),
#  ('mouse#sacral vertebra 3', 'human#S3_Vertebra'),
#  ('mouse#hand interosseous muscle', 'human#Hand_Interosseous_Muscle'),
#  ('mouse#cecum', 'human#Cecum'),
#  ('mouse#extensor digitorum communis', 'human#Extensor_Digitorum_Communis'),
#  ('mouse#subscapular artery', 'human#Subscapular_Artery'),
#  ('mouse#hand digit 4', 'human#Hand_Digit_4'),
#  ('mouse#cortical layer V', 'human#Ganglionic_Layer'),
#  ('mouse#lip skin', 'human#Skin_of_the_Lip'),
#  ('mouse#proximal phalanx of foot', 'human#Proximal_Phalanx_of_Foot'),
#  ('mouse#appendicular skeleton', 'human#Appendicular_Skeleton'),
#  ('mouse#solitary tract nucleus', 'human#Nucleus_of_the_Solitary_Tract'),
#  ('mouse#stomach greater curvature', 'human#Greater_Curvature'),
#  ('mouse#sacral vertebra', 'human#Sacral_Vertebra'),
#  ('mouse#prostate gland', 'human#Prostate_Gland'),
#  ('mouse#vena cava endothelium', 'human#Vena_Cava_Endothelium'),
#  ('mouse#spinal cord pia mater', 'human#Spinal_Cord_Pia_Mater'),
#  ('mouse#ulna', 'human#Ulna'),
#  ('mouse#urinary bladder serosa', 'human#Bladder_Serosal_Surface'),
#  ('mouse#respiratory bronchiole epithelium',
#   'human#Respiratory_Bronchiole_Epithelium'),
#  ('mouse#upper jaw molar', 'human#Upper_Jaw_Molar'),
#  ('mouse#atrioventricular bundle', 'human#Atrioventricular_Bundle'),
#  ('mouse#temporal cortex', 'human#Temporal_Lobe'),
#  ('mouse#extensor digitorum longus', 'human#Extensor_Digitorum_Longus'),
#  ('mouse#depressor labii inferioris', 'human#Depressor_Labii_Inferioris'),
#  ('mouse#lienal vein', 'human#Splenic_Vein'),
#  ('mouse#oropharynx epithelium', 'human#Oropharynx_Epithelium'),
#  ('mouse#medial cuneiform', 'human#Internal_Cuneiform_Bone_of_the_Foot'),
#  ('mouse#epigastric artery', 'human#Epigastric_Artery'),
#  ('mouse#inferior oblique extraocular muscle',
#   'human#Inferior_Oblique_Muscle'),
#  ('mouse#gall bladder lamina propria', 'human#Gallbladder_Lamina_Propria'),
#  ('mouse#heart endocardium', 'human#Endocardium'),
#  ('mouse#muscle', 'human#Muscle'),
#  ('mouse#sternothyroid', 'human#Sternothyroid'),
#  ('mouse#lower respiratory tract cartilage',
#   'human#Lower_Respiratory_Tract_Cartilage'),
#  ('mouse#sciatic nerve', 'human#Sciatic_Nerve'),
#  ('mouse#ear lobe', 'human#Lobule_of_the_Auricle'),
#  ('mouse#sputum', 'human#Sputum'),
#  ('mouse#pericardium', 'human#Pericardium'),
#  ('mouse#vertebral vein', 'human#Vertebral_Vein'),
#  ('mouse#thymic vein', 'human#Thymic_Vein'),
#  ('mouse#infundibulum', 'human#Brain_Infundibulum'),
#  ('mouse#renal/urinary system', 'human#Urinary_System'),
#  ('mouse#adenohypophysis', 'human#Anterior_Lobe_of_the_Pituitary_Gland'),
#  ('mouse#nerve', 'human#Nerve'),
#  ('mouse#arteriole', 'human#Arteriole'),
#  ('mouse#trunk skin', 'human#Skin_of_the_Trunk'),
#  ('mouse#basilic vein', 'human#Basilic_Vein'),
#  ('mouse#tricuspid valve', 'human#Tricuspid_Valve'),
#  ('mouse#subcostal artery', 'human#Subcostal_Artery'),
#  ('mouse#anterior commissure', 'human#Anterior_Commissure'),
#  ('mouse#right lung alveolus', 'human#Right_Lung_Alveolus'),
#  ('mouse#hand digit 3', 'human#Hand_Digit_3'),
#  ('mouse#skin apocrine gland', 'human#Apocrine_Sweat_Gland'),
#  ('mouse#metacarpo-phalangeal joint', 'human#Metacarpophalangeal_Joint'),
#  ('mouse#popliteal artery', 'human#Popliteal_Artery'),
#  ('mouse#small intestine mucosa', 'human#Small_Intestinal_Mucosa'),
#  ('mouse#trachea lamina propria', 'human#Trachea_Lamina_Propria'),
#  ('mouse#salivary duct', 'human#Duct_Salivary_Gland_System'),
#  ('mouse#epidermis stratum granulosum', 'human#Stratum_Granulosum'),
#  ('mouse#lateral geniculate nucleus', 'human#External_Geniculate_Body'),
#  ('mouse#urinary bladder wall', 'human#Bladder_Wall'),
#  ('mouse#oropharynx', 'human#Oropharynx'),
#  ('mouse#forebrain', 'human#Fore-Brain'),
#  ('mouse#left testis', 'human#Left_Testis'),
#  ('mouse#kidney calyx', 'human#Renal_Calyx'),
#  ('mouse#thoracic vertebra 12', 'human#T12_Vertebra'),
#  ('mouse#pineal gland', 'human#Pineal_Gland'),
#  ('mouse#cortical layer VI', 'human#Multiform_Cell_Layer'),
#  ('mouse#right renal artery', 'human#Right_Renal_Artery'),
#  ('mouse#upper jaw tooth', 'human#Upper_Jaw_Tooth'),
#  ('mouse#terminal bronchiole', 'human#Terminal_Bronchiole'),
#  ('mouse#trapezoid', 'human#Trapezoid_Bone'),
#  ('mouse#glomerular parietal epithelium',
#   'human#Parietal_Layer_of_Bowman_s_Capsule'),
#  ('mouse#sternohyoid', 'human#Sternohyoid'),
#  ('mouse#ovarian vein', 'human#Ovarian_Vein'),
#  ('mouse#inferior suprarenal artery', 'human#Inferior_Suprarenal_Artery'),
#  ('mouse#substantia gelatinosa', 'human#Substantia_Gelatinosa'),
#  ('mouse#thoracic vertebra', 'human#Thoracic_Vertebra'),
#  ('mouse#nasal turbinate', 'human#Nasal_Turbinate'),
#  ('mouse#ovary mature follicle', 'human#Graafian_Follicle'),
#  ('mouse#pons', 'human#Pons_Varolii'),
#  ('mouse#cleidooccipital', 'human#Cleidooccipital'),
#  ('mouse#rib head', 'human#Rib_Head'),
#  ('mouse#sacral vertebra 4', 'human#S4_Vertebra'),
#  ('mouse#cervical vertebra 3', 'human#C3_Vertebra'),
#  ('mouse#renal tubule epithelium', 'human#Renal_Tubule_Epithelium'),
#  ('mouse#basal ganglia', 'human#Basal_Ganglia'),
#  ('mouse#corneal epithelium', 'human#Corneal_Epithelium'),
#  ('mouse#carpal bone', 'human#Carpal_Bone'),
#  ('mouse#lens', 'human#Crystalline_Lens'),
#  ('mouse#white matter', 'human#White_Matter'),
#  ('mouse#spleen trabecular vein', 'human#Splenic_Trabecular_Vein'),
#  ('mouse#hypoglossal XII nucleus', 'human#Hypoglossal_Nucleus'),
#  ('mouse#navicular', 'human#Navicular_Bone'),
#  ('mouse#inner ear', 'human#Internal_Ear'),
#  ('mouse#lactiferous duct', 'human#Lactiferous_Duct'),
#  ('mouse#seminiferous tubule epithelium', 'human#Seminiferous_Epithelium'),
#  ('mouse#atrioventricular node', 'human#Atrioventricular_Node'),
#  ('mouse#nasopharynx epithelium', 'human#Nasopharynx_Epithelium'),
#  ...]

# %%
cos_sim(*extractUSEEmbeddings(["program committee member", "member program committee"]))
# Out:
# 0.9821487665176392
