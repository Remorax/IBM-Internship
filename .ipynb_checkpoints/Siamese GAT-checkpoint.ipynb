# %%
# Construction of dataset

import os, itertools, time
import subprocess
from xml.dom import minidom
from collections import Counter, OrderedDict
from operator import itemgetter
from nltk.corpus import wordnet
import tensorflow as tf
import tensorflow_hub as hub
from scipy import spatial
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.feature_extraction.text import TfidfVectorizer
import re
import numpy as np


USE_folder = "/home/vlead/USE"
alignment_folder = "reference-alignment/"

# Load reference alignments 
def load_alignments(folder):
    alignments = []
    for f in os.listdir(folder):
        doc = minidom.parse(folder + f)
        ls = list(zip(doc.getElementsByTagName('entity1'), doc.getElementsByTagName('entity2')))
        alignments.extend([(a.getAttribute('rdf:resource'), b.getAttribute('rdf:resource')) for (a,b) in ls])
    return alignments
        
reference_alignments = load_alignments(alignment_folder)

# %%
flatten = lambda l: [item for sublist in l for item in sublist]

class Ontology():
    def __init__(self, ontology):
        self.ontology = ontology
        self.ontology_obj = minidom.parse(ontology)
        self.root = self.ontology_obj.documentElement
        self.subclasses = self.parse_subclasses()
        self.object_properties = self.parse_object_properties()
        self.data_properties = self.parse_data_properties()
        self.triples = self.parse_triples()
        self.classes = self.parse_classes()
    
    def get_child_node(self, element, tag):
        return [e for e in element._get_childNodes() if type(e)==minidom.Element and e._get_tagName() == tag]
        
    def has_attribute_value(self, element, attribute, value):
        return True if element.getAttribute(attribute).split("#")[-1] == value else False
    
    def get_subclass_triples(self):
        return [(a,b,"subclass_of") for (a,b) in self.get_subclasses()]
    
    def parse_triples(self, union_flag=0, subclass_of=True):
        obj_props = self.object_properties
        data_props = self.data_properties
        props = obj_props + data_props
        all_triples = []
        for prop in props:
            domain_children = self.get_child_node(prop, "rdfs:domain")
            range_children = self.get_child_node(prop, "rdfs:range")
            domain_prop = self.filter_null([self.extract_ID(el) for el in domain_children])
            range_prop = self.filter_null([self.extract_ID(el) for el in range_children])
            if not domain_children or not range_children:
                continue
            if not domain_prop:
                domain_prop = self.filter_null([self.extract_ID(el) for el in domain_children[0].getElementsByTagName("owl:Class")])
            if not range_prop:
                range_prop = self.filter_null([self.extract_ID(el) for el in range_children[0].getElementsByTagName("owl:Class")])
            if domain_prop and range_prop:
                if union_flag == 0:
                    all_triples.extend([(el[0], el[1], self.extract_ID(prop)) for el in list(itertools.product(domain_prop, range_prop))])
                else:
                    all_triples.append(("###".join(domain_prop), "###".join(range_prop), self.extract_ID(prop)))
        if subclass_of:
            all_triples.extend(self.get_subclass_triples())
        return list(set(all_triples))
    
    def get_triples(self, union_flag=0, subclass_of=True):
        if union_flag == 0:
            return self.triples
        else:
            return self.parse_triples(union_flag = 1, subclass_of = False)

    def parse_subclasses(self, union_flag=0):
        subclasses = self.root.getElementsByTagName("rdfs:subClassOf")
        subclass_pairs = []
        for el in subclasses:
            inline_subclasses = self.extract_ID(el)
            if inline_subclasses:
                subclass_pairs.append((el, el.parentNode))
            else:
                level1_class = self.get_child_node(el, "owl:Class")
                if not level1_class:
                    continue
                if self.extract_ID(level1_class[0]):
                    subclass_pairs.append((level1_class[0], el.parentNode))
                else:
                    level2classes = level1_class[0].getElementsByTagName("owl:Class")
                    
                    subclass_pairs.extend([(elem, el.parentNode) for elem in level2classes if self.extract_ID(elem)])
        return subclass_pairs
        
    def get_subclasses(self):
        return [(self.extract_ID(a), self.extract_ID(b)) for (a,b) in self.subclasses]
    
    def filter_null(self, data):
        return [el for el in data if el]
    
    def extract_ID(self, element):
        element_id = element.getAttribute("rdf:ID") or element.getAttribute("rdf:resource") or element.getAttribute("rdf:about")
        return element_id.split("#")[-1]
    
    def parse_classes(self):
        class_elems = [self.extract_ID(el) for el in self.root.getElementsByTagName("owl:Class")]
        subclass_classes = list(set(flatten([el[:-1] for el in self.triples])))
        return list(set(self.filter_null(class_elems + subclass_classes)))
    
    def get_classes(self):
        return self.classes
    
    def get_entities(self):
        entities = [self.extract_ID(el) for el in self.root.getElementsByTagName("owl:Class")]
        return list(set(self.filter_null(entities)))

    def parse_data_properties(self):
        data_properties = [el for el in self.get_child_node(self.root, 'owl:DatatypeProperty')]
        fn_data_properties = [el for el in self.get_child_node(self.root, 'owl:FunctionalProperty') if el]
        fn_data_properties = [el for el in fn_data_properties if type(el)==minidom.Element and 
            [el for el in self.get_child_node(el, "rdf:type") if 
             self.has_attribute_value(el, "rdf:resource", "DatatypeProperty")]]
        inv_fn_data_properties = [el for el in self.get_child_node(self.root, 'owl:InverseFunctionalProperty') if el]
        inv_fn_data_properties = [el for el in inv_fn_data_properties if type(el)==minidom.Element and 
            [el for el in self.get_child_node(el, "rdf:type") if 
             self.has_attribute_value(el, "rdf:resource", "DatatypeProperty")]]
        return data_properties + fn_data_properties + inv_fn_data_properties
        
    def parse_object_properties(self):
        obj_properties = [el for el in self.get_child_node(self.root, 'owl:ObjectProperty')]
        fn_obj_properties = [el for el in self.get_child_node(self.root, 'owl:FunctionalProperty') if el]
        fn_obj_properties = [el for el in fn_obj_properties if type(el)==minidom.Element and 
            [el for el in self.get_child_node(el, "rdf:type") if 
             self.has_attribute_value(el, "rdf:resource", "ObjectProperty")]]
        inv_fn_obj_properties = [el for el in self.get_child_node(self.root, 'owl:InverseFunctionalProperty') if el]
        inv_fn_obj_properties = [el for el in inv_fn_obj_properties if type(el)==minidom.Element and 
            [el for el in self.get_child_node(el, "rdf:type") if 
             self.has_attribute_value(el, "rdf:resource", "ObjectProperty")]]
        return obj_properties + fn_obj_properties + inv_fn_obj_properties
    
    def get_object_properties(self):
        obj_props = [self.extract_ID(el) for el in self.object_properties]
        return list(set(self.filter_null(obj_props)))
    
    def get_data_properties(self):
        data_props = [self.extract_ID(el) for el in self.data_properties]
        return list(set(self.filter_null(data_props)))

# %%
# Data Generation for RotatE embeddings from OpenKE

ontologies_in_alignment = [l.split(".")[0].split("-") for l in os.listdir("reference-alignment/")]

def generate(ontology, concept_prefix, id_prefix=[0,0]):
    ont = Ontology(ontology)
    classes_dict = {concept_prefix+"#"+elem : str(id_prefix[0] + i) for i,elem in enumerate(ont.get_classes())} 
    props = ont.get_object_properties() + ont.get_data_properties() + ["subclass_of"]
    prop_dict = {concept_prefix+"#"+elem : str(id_prefix[1] + i) for i,elem in enumerate(props)} 
    triplets = ["\t".join((classes_dict[concept_prefix+"#"+el[0]], classes_dict[concept_prefix+"#"+el[1]], prop_dict[concept_prefix+"#"+el[2]]))
                for el in ont.get_triples()]
    return classes_dict, prop_dict, triplets

    
for l in ontologies_in_alignment:
    ont1 = "conference_ontologies/" + l[0] + ".owl"
    ont2 = "conference_ontologies/" + l[1] + ".owl"
    
    benchmark_dir = "OpenKE/benchmarks/" + l[0] + "-" + l[1]
    if not os.path.isdir(benchmark_dir):
        os.mkdir(benchmark_dir)
    
    c1, p1, t1 = generate(ont1, l[0])
    c2, p2, t2 = generate(ont2, l[1], [len(c1), len(p1)])
    
    classes_dict = {**c1, **c2}
    prop_dict = {**p1, **p2}
    triplets = t1 + t2
    
    entity_str = str(len(classes_dict)) + "\n" + "\n".join(["\t".join(elem) for elem in classes_dict.items()])
    prop_str = str(len(prop_dict)) + "\n" + "\n".join(["\t".join(elem) for elem in prop_dict.items()])
    triplets_str = str(len(triplets)) + "\n" + "\n".join(triplets)

    open(benchmark_dir + "/entity2id.txt", "w+").write(entity_str)
    open(benchmark_dir + "/relation2id.txt", "w+").write(prop_str)
    open(benchmark_dir + "/train2id.txt", "w+").write(triplets_str)

# %%
# Extracting USE embeddings
def extractUSEEmbeddings(words):
    try:
        embed = hub.KerasLayer(USE_folder)
    except Exception as e:
        # !mkdir $USE_folder
        # !curl -L "https://tfhub.dev/google/universal-sentence-encoder-large/5?tf-hub-format=compressed" | tar -zxvC $USE_folder
        embed = hub.KerasLayer(USE_folder)
        pass
    word_embeddings = embed(words)
    return word_embeddings.numpy()

def cos_sim(a,b):
    return 1 - spatial.distance.cosine(a, b)

def camel_case_split(identifier):
    matches = re.finditer('.+?(?:(?<=[a-z])(?=[A-Z])|(?<=[A-Z])(?=[A-Z][a-z])|$)', identifier)
    return [m.group(0).lower() for m in matches]

def parse(word):
    return flatten([el.split("_") for el in camel_case_split(word)])
    

extracted_elems = []

for ont_name in list(set(flatten(ontologies_in_alignment))):
    ont = Ontology("conference_ontologies/" + ont_name + ".owl")
    entities = ont.get_entities()
    props = ont.get_object_properties() + ont.get_data_properties()
    triples = list(set(flatten(ont.get_triples(subclass_of=False))))
    extracted_elems.extend(entities + props + triples)

extracted_elems = list(set(extracted_elems))

entities_parsed = [parse(word) for word in extracted_elems]
inp = [" ".join(e) for e in entities_parsed]
vectorizer = TfidfVectorizer(token_pattern=r"(?u)\S+")
X = vectorizer.fit_transform(inp)
word2idx_tfidf = {word: i for (i, word)  in enumerate(vectorizer.get_feature_names())}
entity2idx_tfidf = {word: i for (i, word)  in enumerate(extracted_elems)}


extracted_elems.extend(flatten(entities_parsed))
extracted_elems = list(set(extracted_elems))

print ("Total number of extracted unique classes and properties from entire RA set: ", len(extracted_elems))

embeds = extractUSEEmbeddings(extracted_elems)
embeddings = dict(zip(extracted_elems, embeds))
# Out:
# Total number of extracted unique classes and properties from entire RA set:  1228

# %%
# Feature generation

features_dict = {}

def get_tfidf_score(word, phrase):
    temp = X[entity2idx_tfidf[phrase]]
    return temp[:,word2idx_tfidf[word]][0,0]

# max_weight = 0

def get_property_features(triple):
#     weight = np.sum([get_tfidf_score(word, triple[-1]) for word in parse(triple[-1])])
    feats = []
#     feats.append(weight*embeddings[triple[-1]]) # Property name    
    feats.append(np.sum([get_tfidf_score(word, triple[-1]) * embeddings[word] for word in parse(triple[-1])]))
    feats.append([embeddings[el] for el in triple[0].split("###")]) # Domain 
    feats.append([embeddings[el] for el in triple[1].split("###")]) # Range
    
#     global max_weight
#     if weight > max_weight:
#         max_weight = weight
    return feats
    
def get_entity_features(entity):
    feats = []
#     weight = np.sum([get_tfidf_score(word, entity) for word in parse(entity)])
#     feats.append(weight*embeddings[entity]) # Entity name
    feats.append(np.sum([get_tfidf_score(word, entity) * embeddings[word] for word in parse(entity)]))
#     global max_weight
#     if weight > max_weight:
#         max_weight = weight
    return feats
    
for ont_name in list(set(flatten(ontologies_in_alignment))):
    ont = Ontology("conference_ontologies/" + ont_name + ".owl")
    
    triples = ont.get_triples(union_flag=1, subclass_of=False)
    entities = ont.get_entities()
    props = ont.get_object_properties() + ont.get_data_properties()

    for triple in triples:
        features_dict[triple[-1]] = {"type": "triple", "features": get_property_features(triple)}
    for entity in entities:
        features_dict[entity] = {"type": "entity", "features": get_entity_features(entity)}
    for prop in props:
        if prop not in features_dict:
            features_dict[prop] = {"type": "property", "features": get_entity_features(prop)}
#     for entity in features_dict:
#         tmp = np.array(features_dict[entity]["features"][0])
#         features_dict[entity]["features"][0] = (tmp / max_weight)

# %%
# Combinatorial mapping generation

all_mappings = []
for l in ontologies_in_alignment:
    ont1 = Ontology("conference_ontologies/" + l[0] + ".owl")
    ont2 = Ontology("conference_ontologies/" + l[1] + ".owl")
    
    ent1 = ont1.get_entities()
    ent2 = ont2.get_entities()
    
    obj1 = ont1.get_object_properties()
    obj2 = ont2.get_object_properties()
    
    data1 = ont1.get_data_properties()
    data2 = ont2.get_data_properties()
    
    mappings = list(itertools.product(ent1, ent2)) + list(itertools.product(obj1, obj2)) + list(itertools.product(data1, data2))
    
    all_mappings.extend([(l[0] + "#" + el[0], l[1] + "#" + el[1]) for el in mappings])

# %%
gt_mappings = [tuple([elem.split("/")[-1] for elem in el]) for el in reference_alignments]

def calc_sim_score(mapping):
    features = embedify(mapping)
    if features[0]["type"] != "triple" and features[1]["type"] != "triple":
        return cos_sim(*tuple([el["features"] for el in features]))
    elif features[0]["type"] == "triple"  and features[1]["type"] == "triple":
        sim_score = 0
        names, domains, ranges = [], [], []
        
        for elem in [el["features"] for el in features]:
            names.append(elem[0])
            domains.append(elem[1])
            ranges.append(elem[2])
        name_score = cos_sim(names[0], names[1])
#         domain_score = np.mean([cos_sim(*elem) for elem in itertools.product(domains[0], domains[1])])
#         ranges_score = np.mean([cos_sim(*elem) for elem in itertools.product(ranges[0], ranges[1])])
#         return ((name_score + domain_score + ranges_score)/(len(domains[0]) + len(ranges[0]) +  ))
#         return (name_score + domain_score + ranges_score)/3
        return name_score
    return cos_sim(*tuple([el["features"][0] for el in features]))
        
        

def embedify(mapping):
    removed_hash = tuple([elem.split("#")[1] for elem in mapping])
    return (features_dict[removed_hash[0]], features_dict[removed_hash[1]])

data = {}
for mapping in all_mappings:
    if mapping in gt_mappings:
        data[(mapping[0], mapping[1])] = (calc_sim_score(mapping), "T")
    else:
        data[(mapping[0], mapping[1])] = (calc_sim_score(mapping), "F")

# %%
def is_valid(test_onto, key):
    return tuple([el.split("#")[0] for el in key]) not in test_onto

data = OrderedDict(sorted(data.items(),  key=lambda x:x[1][0], reverse=True))
all_ont_pairs = list(set([tuple([el.split("#")[0] for el in l]) for l in data.keys()]))
results = []
failed = []
for i in list(range(0, len(all_ont_pairs), 3)):
    test_onto = all_ont_pairs[i:i+3]
    
    train_data = {elem: data[elem] for elem in data if tuple([el.split("#")[0] for el in elem]) not in test_onto}
    test_data = {elem: data[elem] for elem in data if tuple([el.split("#")[0] for el in elem]) in test_onto}

    opt_threshold, optimum_metrics = -1000, [-1000 for i in range(5)]
    t = time.time()
    for j,threshold in enumerate(np.arange(0.15, 1.0005, 0.01)):
        print ("threshold =", threshold, "Time = ", time.time()-t) 
        pred = []
        for i,key in enumerate(train_data):
            if train_data[key][0] > threshold:
                pred.append(key)

        tp = len([elem for elem in pred if train_data[elem][1] == "T"])
        fn = len([key for key in gt_mappings if key not in set(pred) and is_valid(test_onto, key)])
        fp = len([elem for elem in pred if train_data[elem][1] == "F"])

        try:
            precision = tp/(tp+fp)
            recall = tp/(tp+fn)
            f1score = 2 * precision * recall / (precision + recall)
            f2score = 5 * precision * recall / (4 * precision + recall)
            f0_5score = 1.25 * precision * recall / (0.25 * precision + recall)
        except Exception as e:
            print (e)
            continue
        print (precision, recall, f1score, f2score, f0_5score)

        if f1score > optimum_metrics[2]:
            optimum_metrics = [precision, recall, f1score, f2score, f0_5score]
            opt_threshold = threshold
    
    threshold = opt_threshold
    pred = []
    for i,key in enumerate(test_data):
        if test_data[key][0] > threshold:
            pred.append(key)

    curr = dict()
    
    curr["fn"] = [key for key in gt_mappings if key not in set(pred) and not is_valid(test_onto, key)]
    curr["fp"] = [elem for elem in pred if test_data[elem][1] == "F"]
    tp = len([elem for elem in pred if test_data[elem][1] == "T"])
    fn = len(curr["fn"])
    fp = len(curr["fp"])

    
    
    try:
        precision = tp/(tp+fp)
        recall = tp/(tp+fn)
        f1score = 2 * precision * recall / (precision + recall)
        f2score = 5 * precision * recall / (4 * precision + recall)
        f0_5score = 1.25 * precision * recall / (0.25 * precision + recall)
    except Exception as e:
        print (e)
        pass
            
    metrics = [precision, recall, f1score, f2score, f0_5score]
    failed.append(curr)
    results.append(metrics)

print ("Final Results:", np.mean(results, axis=0))
# Out:
# threshold = 0.15 Time =  2.3603439331054688e-05
# 0.0028753784825843553 0.967032967032967 0.005733708341025335 0.014207909069381956 0.0035915533196019906
# threshold = 0.16 Time =  3.675703525543213

# %%
# AML test
results = []
for i in list(range(0, len(all_ont_pairs), 3)):
    test_onto = all_ont_pairs[i:i+3]
    for ont_pair in test_onto:
        a, b, c = ont_pair[0], ont_pair[1], ont_pair[0] + "-" + ont_pair[1]
        java_command = "java -jar AML_v3.1/AgreementMakerLight.jar -s conference_ontologies/" + a + ".owl" + \
                            " -t conference_ontologies/" + b + ".owl -o AML-test-results/" + c + ".rdf -a"
    #     print (java_command)
        process = subprocess.Popen(java_command.split(), stdout=subprocess.PIPE)
        output, error = process.communicate()
    #     print (a,b,c)

    pred_aml = load_alignments("AML-test-results/")
    pred_aml = [tuple([el.split("/")[-1] for el in key]) for key in pred_aml]
    tp = len([elem for elem in pred_aml if data[elem][1] == "T"])
    fn = len([key for key in gt_mappings if key not in set(pred_aml) and not is_valid(test_onto, key)])
    fp = len([elem for elem in pred_aml if data[elem][1] == "F"])

    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    f1score = 2 * precision * recall / (precision + recall)
    f2score = 5 * precision * recall / (4 * precision + recall)
    f0_5score = 1.25 * precision * recall / (0.25 * precision + recall)
    print (precision, recall, f1score, f2score, f0_5score)
    
    metrics = [precision, recall, f1score, f2score, f0_5score]
    results.append(metrics)
    
    rm_command = "rm -rf AML-test-results/*"
    process = subprocess.Popen(rm_command.split(), stdout=subprocess.PIPE)
    output, error = process.communicate()
    
print ("Final Results:", np.mean(results, axis=0))

# %%
opt_threshold
# Out:
# 0.7700000000000006

# %%
# Out:
# []

# %%
cos_sim([[[1,2,3], [3,4,5]]], [[[32,14,3], [42, 53, 52]]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-554-22a46d1ccb72> in <module>
# ----> 1 cos_sim([[[1,2,3], [3,4,5]]], [[[32,14,3], [42, 53, 52]]])
#
# <ipython-input-530-b2cfe0f48df1> in cos_sim(a, b)
#      12
#      13 def cos_sim(a,b):
# ---> 14     return 1 - spatial.distance.cosine(a, b)
#      15
#      16 extracted_elems = []
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/spatial/distance.py in cosine(u, v, w)
#     764     # cosine distance is also referred to as 'uncentered correlation',
#     765     #   or 'reflective correlation'
# --> 766     return correlation(u, v, w=w, centered=False)
#     767
#     768
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/spatial/distance.py in correlation(u, v, w, centered)
#     706
#     707     """
# --> 708     u = _validate_vector(u)
#     709     v = _validate_vector(v)
#     710     if w is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/spatial/distance.py in _validate_vector(u, dtype)
#     336     u = np.atleast_1d(u)
#     337     if u.ndim > 1:
# --> 338         raise ValueError("Input vector should be 1-D.")
#     339     return u
#     340
#
# ValueError: Input vector should be 1-D.

# %%
list(itertools.product([[1,2], [3,4]], [[1,2], [3,4]]))
# Out:
# [([1, 2], [1, 2]), ([1, 2], [3, 4]), ([3, 4], [1, 2]), ([3, 4], [3, 4])]

# %%
len(list(set(flatten([parse(word) for word in extracted_elems])))), len(word2idx_tfidf.keys())
# Out:
# (533, 533)

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(inp)
word2idx_tfidf = {word: i for (i, word)  in enumerate(vectorizer.get_feature_names())}
entity2idx_tfidf = {word: i for (i, word)  in enumerate(extracted_elems)}
# Out:
# {'paperPresentedAs': 0,
#  'ParallelAndDistributedComputingTopic': 1,
#  'finalizePaperAssignment': 2,
#  'is_signed_by': 3,
#  'reviewCriteriaEnteredBy': 4,
#  'ReviewForm': 5,
#  'listsEvent': 6,
#  'Building': 7,
#  'is_held_after': 8,
#  'partOf': 9,
#  'was_a_committe_co-chair_of': 10,
#  'hasKeyword': 11,
#  'Worker_non_speaker': 12,
#  'hasMember': 13,
#  'is_sent_before': 14,
#  'technicallyOrganises': 15,
#  'name': 16,
#  'Presenter': 17,
#  'SignalProcessingTopic': 18,
#  'hasBid': 19,
#  'hasReviewHistory': 20,
#  'has_a_track-workshop-tutorial_chair': 21,
#  'has_title': 22,
#  'Committee_member': 23,
#  'hasLastName': 24,
#  'Academic_Institution': 25,
#  'ACM_SIGKDD': 26,
#  'ComputerNetworksSensorTopic': 27,
#  'publisherOf': 28,
#  'Fee': 29,
#  'WelcomeTalk': 30,
#  'invites_co-reviewers': 31,
#  'Chairman': 32,
#  'Video_presentation': 33,
#  'endReview': 34,
#  'Invited_Talk': 35,
#  'Call_for_paper': 36,
#  'Trip': 37,
#  'CallForManuscripts': 38,
#  'ConferenceSession': 39,
#  'Workshop_Paper': 40,
#  'Paper': 41,
#  'OrganizationalMeeting': 42,
#  'Regular_contribution': 43,
#  'AcademiaOrganization': 44,
#  'hasStartDateTime': 45,
#  'One_day_presenter': 46,
#  'Single_hotel_room': 47,
#  'contactEmail': 48,
#  'Submission': 49,
#  'MedicineTopic': 50,
#  'hasLocation': 51,
#  'RadioCommunicationsTopic': 52,
#  'acceptPaper': 53,
#  'Conference_Banquet': 54,
#  'assignReviewer': 55,
#  'has_a_date_of_issue': 56,
#  'AcceptedPaper': 57,
#  'ComputerNetworksAapplicationsTopic': 58,
#  'subclass_of': 59,
#  'Regular_author': 60,
#  'enterConferenceDetails': 61,
#  'Early-Registered_Participant': 62,
#  'IASTED_non_member': 63,
#  'Dinner_banquet': 64,
#  'is_a_date_of_camera_ready_paper_submission': 65,
#  'ComputerNetworksMeasurementsTopic': 66,
#  'Review_preference': 67,
#  'Speaker': 68,
#  'hasFirstName': 69,
#  'Coffee_break': 70,
#  'write': 71,
#  'Best_Applications_Paper_Award': 72,
#  'writeReview': 73,
#  'Tutorial_speaker': 74,
#  'Camera_ready_manuscript_deadline': 75,
#  'Program_Committee': 76,
#  'maxChoice': 77,
#  'hasCostCurrency': 78,
#  'Camera_Ready_event': 79,
#  'rejectedBy': 80,
#  'PowerlineTransmissionTopic': 81,
#  'Conference_Hiker': 82,
#  'TravelGrant': 83,
#  'General_Chair': 84,
#  'defaultChoice': 85,
#  'Van': 86,
#  'SecurityTopic': 87,
#  'ProgramCommitteeChair': 88,
#  'updatedVersionOf': 89,
#  'is_used_by': 90,
#  'Chair': 91,
#  'Trip_city': 92,
#  'send': 93,
#  'is_present_in': 94,
#  'Publisher': 95,
#  'ReviewRating': 96,
#  'MicroelectronicsTopic': 97,
#  'ProgramCommittee': 98,
#  'hasStreet': 99,
#  'Nonmember_registration_fee': 100,
#  'hasTitle': 101,
#  'readByMeta-Reviewer': 102,
#  'Name': 103,
#  'WithdrawnPaper': 104,
#  'has_authors': 105,
#  'has_an_email': 106,
#  'is_dated_on': 107,
#  'NonAcademicEvent': 108,
#  'is_a_full_paper_submission_date': 109,
#  'Conference_Proceedings': 110,
#  'Presenter_city': 111,
#  'earlyRegistration': 112,
#  'detailsEnteredBy': 113,
#  'Refusing_manuscript': 114,
#  'MealBreak': 115,
#  'AssociatedChair': 116,
#  'BreakEvent': 117,
#  'hasRating': 118,
#  'is_the_1th_part_of': 119,
#  'hasVAT': 120,
#  'was_a_steering_committee_of': 121,
#  'Organization': 122,
#  'CallForReviews': 123,
#  'Demo_Session': 124,
#  'RatedPapers': 125,
#  'TextualReviewQuestion': 126,
#  'Excursion': 127,
#  'submit_until': 128,
#  'occupy': 129,
#  'give': 130,
#  'Written_contribution': 131,
#  'ComputerNetworksTopic': 132,
#  'isWrittenBy': 133,
#  'is_an_ending_date': 134,
#  'organises': 135,
#  'has_a_review_expertise': 136,
#  'belongsToEvent': 137,
#  'hasSubjectArea': 138,
#  'Accepting_manuscript': 139,
#  'is_a_starting_date': 140,
#  'Activity_after_conference': 141,
#  'Computer': 142,
#  'has_a_track-workshop-tutorial_topic': 143,
#  'Proceedings': 144,
#  'Social_program': 145,
#  'has_a_degree': 146,
#  'Committee': 147,
#  'Author_book_proceedings_included': 148,
#  'has_short_title': 149,
#  'assignedByReviewer': 150,
#  'Early_paid_applicant': 151,
#  'Contribution': 152,
#  'has_been_assigned_a_review_reference': 153,
#  'Full_day_tour': 154,
#  'Author_cd_proceedings_included': 155,
#  'Sponsor_company_house': 156,
#  'Presenter_house': 157,
#  'Sponsor_city': 158,
#  'Accepted_contribution': 159,
#  'isMemberOf': 160,
#  'can_stay_in': 161,
#  'is_part_of_conference_volumes': 162,
#  'isProviderOf': 163,
#  'logoURL': 164,
#  'hardcopyMailingManifestsPrintedBy': 165,
#  'notification_until': 166,
#  'awarded_by': 167,
#  'gives_presentations': 168,
#  'Technic_activity': 169,
#  'WeekRejectRating': 170,
#  'Session_Chair': 171,
#  'Submitted_Paper': 172,
#  'Name_of_conference': 173,
#  'Presentation': 174,
#  'relatedToEvent': 175,
#  'Tutorial': 176,
#  'Publication': 177,
#  'Renting': 178,
#  'hasEmail': 179,
#  'ExternalReviewer': 180,
#  'Person': 181,
#  'Best_Paper_Awards_Committee': 182,
#  'Camera_Ready_Paper': 183,
#  'Cd_proceening': 184,
#  'Departure_tax': 185,
#  'was_a_track-workshop_chair_of': 186,
#  'Name_of_sponsor': 187,
#  'is_connected_with': 188,
#  'NumericalReviewQuestion': 189,
#  'pay': 190,
#  'Organizing_Committee': 191,
#  'Student_non_speaker': 192,
#  'TPCMember': 193,
#  'NGO': 194,
#  'has_a_steering_committee': 195,
#  'Demo_Paper': 196,
#  'Lecture': 197,
#  'organisedBy': 198,
#  'Sponsor_state': 199,
#  'PersonalHistory': 200,
#  'Information_for_participants': 201,
#  'Conference_city': 202,
#  'AcceptRating': 203,
#  'Author_attendee_book_registration_fee': 204,
#  'Camera_ready_contribution': 205,
#  'CommunicationsTopic': 206,
#  'Presenter_university': 207,
#  'setMaxPapers': 208,
#  'has_workshops': 209,
#  'Initial_manuscipt': 210,
#  'Important_dates': 211,
#  'Author_information_form': 212,
#  'sign': 213,
#  'Administrator': 214,
#  'Invitation_letter': 215,
#  'Tutorial_Chair': 216,
#  'Regular_Paper': 217,
#  'Conference_applicant': 218,
#  'Conference_building': 219,
#  'CADTopic': 220,
#  'adjustBid': 221,
#  'Brief_introduction_for_Session_chair': 222,
#  'Scientific_Event': 223,
#  'presentationed_by': 224,
#  'ReviewQuestion': 225,
#  'User': 226,
#  'Double_hotel_room': 227,
#  'PersonalReviewHistory': 228,
#  'Acceptance': 229,
#  'PC_Member': 230,
#  'AcademicEvent': 231,
#  'Demo_Chair': 232,
#  'relatesTo': 233,
#  'belong_to_a_conference_volume': 234,
#  'Assistant': 235,
#  'markConflictOfInterest': 236,
#  'Program_Committee_member': 237,
#  'speak_in': 238,
#  'presentationOfPaper': 239,
#  'references': 240,
#  'MeetingRoomPlace': 241,
#  'addedBy': 242,
#  'Track-workshop_chair': 243,
#  'Credit_card': 244,
#  'Conference_contributor': 245,
#  'was_an_organizing_committee_of': 246,
#  'has_tracks': 247,
#  'Industrial_Session': 248,
#  'is_held_before': 249,
#  'City_of_conference': 250,
#  'Abstract': 251,
#  'Listener': 252,
#  'coversTopic': 253,
#  'was_a_committee_chair_of': 254,
#  'Cheque': 255,
#  'belongs_to_a_review_reference': 256,
#  'Sponsor': 257,
#  'Transport_vehicle': 258,
#  'heldIn': 259,
#  'award': 260,
#  'is_visited_by': 261,
#  'Award': 262,
#  'acceptsHardcopySubmissions': 263,
#  'has_members': 264,
#  'Student_lecturer': 265,
#  'Book_proceeding': 266,
#  'AntennasTopic': 267,
#  'Taxi': 268,
#  'anyURI': 269,
#  'Conference_hotel': 270,
#  'boolean': 271,
#  'Final_manuscript': 272,
#  'OC_Chair': 273,
#  'Attendee': 274,
#  'paperAssignmentFinalizedBy': 275,
#  'ComputerNetworksSecurityTopic': 276,
#  'Volunteer': 277,
#  'Rejected_Paper': 278,
#  'Registration_SIGKDD_Member': 279,
#  'Conference_Participant': 280,
#  'Time': 281,
#  'Speaker_lecture': 282,
#  'hasCall': 283,
#  'Bank_transfer': 284,
#  'is_present': 285,
#  'submitPaper': 286,
#  'Registation_deadline': 287,
#  'Program_committee': 288,
#  'isReviewedBy': 289,
#  'is_prepared_by': 290,
#  'design': 291,
#  'startReviewerBidding': 292,
#  'Regular': 293,
#  'isLocationOf': 294,
#  'Social_event': 295,
#  'IndustryOrganization': 296,
#  'Bid': 297,
#  'Registration_Non-Member': 298,
#  'LCD_projector': 299,
#  'reviewsPerPaper': 300,
#  'SocialEvent': 301,
#  'ConferenceVenuePlace': 302,
#  'Silver_Supporter': 303,
#  'SC_Member': 304,
#  'has_a_URL': 305,
#  'Author_of_paper': 306,
#  'Value_added_tax': 307,
#  'TestOnlyTopic': 308,
#  'Programme': 309,
#  'Industrial_Paper': 310,
#  'hasEvent': 311,
#  'go_through': 312,
#  'Best_Student_Paper_Supporter': 313,
#  'SlideSet': 314,
#  'Technical_commitee': 315,
#  'startDate': 316,
#  'is_sent_by': 317,
#  'Call': 318,
#  'Individual_Presentation': 319,
#  'Registration_Student': 320,
#  'has_the_last_name': 321,
#  'ComputerNetworksSwitchingTopic': 322,
#  'has_a_committee_co-chair': 323,
#  'Student_registration_fee': 324,
#  'searched_by': 325,
#  'hasPart': 326,
#  'has_a_committee_chair': 327,
#  'Administrative_event': 328,
#  'Sponzor': 329,
#  'One_conference_day': 330,
#  'has_amount_of': 331,
#  'Topic': 332,
#  'is_needed_for': 333,
#  'Registeered_applicant': 334,
#  'SessionChair': 335,
#  'Transparency': 336,
#  'hasCostAmount': 337,
#  'Viza': 338,
#  'hasUpdatedVersion': 339,
#  'Poster_Session': 340,
#  'Best_Student_Paper_Award': 341,
#  'Nonauthor_registration_fee': 342,
#  'authorOf': 343,
#  'is_made_from': 344,
#  'is_designed_for': 345,
#  'Reception': 346,
#  'MealMenu': 347,
#  'Invited_Speaker': 348,
#  'MultimediaTopic': 349,
#  'has_a_commtitee': 350,
#  'ComputerNetworksEnterpriseTopic': 351,
#  'Social_Event': 352,
#  'has_a_location': 353,
#  'Author_of_paper_student': 354,
#  'Late_paid_applicant': 355,
#  'has_a_review': 356,
#  'rejectPaper': 357,
#  'Organizing_committee': 358,
#  'has_parts': 359,
#  'has_an_organizing_committee': 360,
#  'payed_by': 361,
#  'reviewWrittenBy': 362,
#  'MealEvent': 363,
#  'adjustedBy': 364,
#  'isMenuOf': 365,
#  'Submission_event': 366,
#  'Conference_Session': 367,
#  'hasCo-author': 368,
#  'is_given_by': 369,
#  'hasSurname': 370,
#  'Worker_lecturer': 371,
#  'paperID': 372,
#  'Registration_SIGMOD_Member': 373,
#  'assignedByAdministrator': 374,
#  'Hotel_fee': 375,
#  'has_a_topic_or_a_submission_contribution': 376,
#  'Conference_announcement': 377,
#  'Rejected_contribution': 378,
#  'hasPostalCode': 379,
#  'employedBy': 380,
#  'SubjectArea': 381,
#  'Organizer': 382,
#  'isTopicOf': 383,
#  'has_important_dates': 384,
#  'Location': 385,
#  'RejectRating': 386,
#  'hasConferenceMember': 387,
#  'reviews': 388,
#  'issues': 389,
#  'Currency': 390,
#  'Start_of_conference': 391,
#  'Tax': 392,
#  'hasAdministrativeEvent': 393,
#  'Car': 394,
#  'Assigned_Paper': 395,
#  'GovernmentOrganization': 396,
#  'dateTime': 397,
#  'Contributed_Talk': 398,
#  'Country': 399,
#  'Plenary_lecture': 400,
#  'attendeeAt': 401,
#  'registrationDueOn': 402,
#  'unsignedLong': 403,
#  'Conference_Paper': 404,
#  'Session': 405,
#  'Research': 406,
#  'is_held_in': 407,
#  'assignedTo': 408,
#  'technicallyOrganisedBy': 409,
#  'has_contributions': 410,
#  'FreeTimeBreak': 411,
#  'is_paid_for': 412,
#  'Sponsorship': 413,
#  'siteURL': 414,
#  'search': 415,
#  'providedBy': 416,
#  'is_equipped_by': 417,
#  'Card': 418,
#  'Co-chair': 419,
#  'PersonalPublicationHistory': 420,
#  'hasBiography': 421,
#  'has_gender': 422,
#  'volumeContainsPaper': 423,
#  'Trip_day': 424,
#  'E-mail': 425,
#  'date': 426,
#  'End_of_conference': 427,
#  'Tutorial_Abstract': 428,
#  'Audiovisual_equipment': 429,
#  'Conference_days': 430,
#  'Organizator': 431,
#  'CryptographyTopic': 432,
#  'Workshop_Session': 433,
#  'writePaper': 434,
#  'is_writen_by': 435,
#  'ConferenceChair': 436,
#  'Conference_document': 437,
#  'SatelliteAndSpaceCommunicationsTopic': 438,
#  'Company': 439,
#  'Conference_participant': 440,
#  'memberOfConference': 441,
#  'was_a_member_of': 442,
#  'RejectedPaper': 443,
#  'Fee_for_extra_trip': 444,
#  'Active_conference_participant': 445,
#  'addProgramCommitteeMember': 446,
#  'Presenter_state': 447,
#  'Working_event': 448,
#  'hasRelatedDocument': 449,
#  'has_tutorials': 450,
#  'ContactInformation': 451,
#  'Session_room': 452,
#  'Lecturer': 453,
#  'PaperFullVersion': 454,
#  'Conference_proceedings': 455,
#  'reviewerOfPaper': 456,
#  'Workshop': 457,
#  'Submitted_contribution': 458,
#  'State': 459,
#  'was_a_program_committee_of': 460,
#  'TwoLevelConference': 461,
#  'enableVirtualMeeting': 462,
#  'Money': 463,
#  'Steering_committee': 464,
#  'paperAssignmentToolsRunBy': 465,
#  'dealsWith': 466,
#  'isInitiatedBy': 467,
#  'has_an_expertise': 468,
#  'Sponzorship': 469,
#  'Welcome_address': 470,
#  'Hotel_registration_form': 471,
#  'Introduction_of_speaker': 472,
#  'PublishedPaper': 473,
#  'Submissions_deadline': 474,
#  'PerformanceTopic': 475,
#  'Paid_applicant': 476,
#  'contributes': 477,
#  'Agency_Staff_Member': 478,
#  'has_a_submitted_contribution': 479,
#  'hasDecision': 480,
#  'Platinum_Supporter': 481,
#  'scientificallyOrganises': 482,
#  'Deadline': 483,
#  'Registration_of_participants_event': 484,
#  'Reviewer': 485,
#  'abstract': 486,
#  'ends_on': 487,
#  'presentation': 488,
#  'Conference_restaurant': 489,
#  'Member': 490,
#  'done_till': 491,
#  'Negative_Review': 492,
#  'maxPapers': 493,
#  'ConferenceMember': 494,
#  'AuthorNotReviewer': 495,
#  'IASTED_member': 496,
#  'Thing': 497,
#  'is_situated_in': 498,
#  'hasPhone': 499,
#  'Sponzor_fee': 500,
#  'reviewes': 501,
#  'Paper_Author': 502,
#  'assignExternalReviewer': 503,
#  'enterReviewCriteria': 504,
#  'Registration_fee': 505,
#  'Passive_conference_participant': 506,
#  'locationOf': 507,
#  'hasHomePage': 508,
#  'Deadline_Abstract_Submission': 509,
#  'acceptedBy': 510,
#  'Conference_part': 511,
#  'PaperAbstract': 512,
#  'Hotel_room': 513,
#  'TalkEvent': 514,
#  'Activity_before_conference': 515,
#  'ComputerNetworksManagementTopic': 516,
#  'Overhead_projector': 517,
#  'Conference_volume': 518,
#  'CallForPapers': 519,
#  'is_submitted_at': 520,
#  'writtenBy': 521,
#  'hasProgramme': 522,
#  'Document': 523,
#  'Date': 524,
#  'Registration': 525,
#  'Flyer': 526,
#  'holded_by': 527,
#  'expertOn': 528,
#  'invited_by': 529,
#  'PendingPaper': 530,
#  'Plenary_lecture_speaker': 531,
#  'is_used_for': 532,
#  'positiveInteger': 533,
#  'Research_Institute': 534,
#  'minChoice': 535,
#  'Payment_document': 536,
#  'AccommodationPlace': 537,
#  'Departure': 538,
#  'MobileComputingTopic': 539,
#  'partOfEvent': 540,
#  'AccpetIfRoomRating': 541,
#  'Conference': 542,
#  'has_a_volume': 543,
#  'Decision': 544,
#  'topicCoveredBy': 545,
#  'hasAuthor': 546,
#  'PowerPoint_presentation': 547,
#  'Organisation': 548,
#  'scientificallyOrganisedBy': 549,
#  'Conference_contribution': 550,
#  'Review': 551,
#  'has_a_name': 552,
#  'reviewOfPaper': 553,
#  'Science_Worker': 554,
#  'hasCity': 555,
#  'Author': 556,
#  'Deadline_Author_notification': 557,
#  'Multi-author_Volume': 558,
#  'hasFax': 559,
#  'Video_cassette_player': 560,
#  'hasName': 561,
#  'obtain': 562,
#  'Item': 563,
#  'Invited_Talk_Abstract': 564,
#  'Meta-Review': 565,
#  'Exhibitor': 566,
#  'PC_Chair': 567,
#  'Conference_Trip': 568,
#  'has_a_program_committee': 569,
#  'isReviewHistoryOf': 570,
#  'Banquet': 571,
#  'Reviewing_results_event': 572,
#  'ComputerNetworksOpticalTopic': 573,
#  'Accepted_Paper': 574,
#  'Review_expertise': 575,
#  'co-writePaper': 576,
#  'email': 577,
#  'hasAttendee': 578,
#  'writes': 579,
#  'hasReview': 580,
#  'Student': 581,
#  'Place': 582,
#  'forEvent': 583,
#  'OC_Member': 584,
#  'Member_PC': 585,
#  'hasBeenAssigned': 586,
#  'Participant': 587,
#  'is_paid_by': 588,
#  'remark': 589,
#  'Time_zone': 590,
#  'Programme_Brochure': 591,
#  'has_a_publisher': 592,
#  'memberOfProgramCommittee': 593,
#  'Record_of_attendance': 594,
#  'Organizing_Committee_member': 595,
#  'Extended_abstract': 596,
#  'Tip': 597,
#  'Co-author': 598,
#  'Non_speaker': 599,
#  'is_paid_with': 600,
#  'Introduction': 601,
#  'Call_for_participation': 602,
#  'Activity': 603,
#  'Track': 604,
#  'Deadline_Paper_Submission': 605,
#  'Research_Topic': 606,
#  'eventOnList': 607,
#  'Nation': 608,
#  'ComputerArchitectureTopic': 609,
#  'Preference': 610,
#  'Late-Registered_Participant': 611,
#  'need': 612,
#  'starts_on': 613,
#  'hasSubmissionInstructions': 614,
#  'string': 615,
#  'designed_by': 616,
#  'Poster': 617,
#  'Poster_Paper': 618,
#  'Gold_Supporter': 619,
#  'endDate': 620,
#  'has_an_abstract': 621,
#  'Conference_www': 622,
#  'inverse_of_partOf_7': 623,
#  'Price': 624,
#  'submit': 625,
#  'Short_paper': 626,
#  'Proceedings_Publisher': 627,
#  'Possible_Reviewer': 628,
#  'Delegate': 629,
#  'Chair_PC': 630,
#  'ConferenceDinner': 631,
#  'ClosingTalk': 632,
#  'CoffeeBreak': 633,
#  'Contribution_co-author': 634,
#  'isReviewing': 635,
#  'Meta-Reviewer': 636,
#  'belongs_to_reviewers': 637,
#  'Conference_airport': 638,
#  'Memeber_registration_fee': 639,
#  'is_a_topis_of_conference_parts': 640,
#  'Deadline_for_notification_of_acceptance': 641,
#  'is_paid_in': 642,
#  'WirelessCommunicationsTopic': 643,
#  'prepare': 644,
#  'Coctail_reception': 645,
#  'referencedIn': 646,
#  'parallel_with': 647,
#  'Contribution_1th-author': 648,
#  'hasMenu': 649,
#  'Invited_talk': 650,
#  'paperInVolume': 651,
#  'Mailing_list': 652,
#  'Modelling': 653,
#  'Conference_hall': 654,
#  'hasTopic': 655,
#  'hasReviewer': 656,
#  'SingleLevelConference': 657,
#  'readByReviewer': 658,
#  'studyAt': 659,
#  'hasCountry': 660,
#  'hasProgramCommitteeMember': 661,
#  'Best_Research_Paper_Award': 662,
#  'is_an_abstract_submission_date': 663,
#  'Main_office': 664,
#  'relatedToPaper': 665,
#  'Conference_state': 666,
#  'ActivePaper': 667,
#  'Reviewing_event': 668,
#  'readPaper': 669,
#  'PaperPresentation': 670,
#  'Invited_speaker': 671,
#  'Form': 672,
#  'Receiving_manuscript': 673,
#  'DiningPlace': 674,
#  'CommunicationTheoryTopic': 675,
#  'Simulating': 676,
#  'paperDueOn': 677,
#  'has_an_ISBN': 678,
#  'has_a_review_reference_or_expertise': 679,
#  'Event': 680,
#  'initiates': 681,
#  'University': 682,
#  'hasConflictOfInterest': 683,
#  'Workshop_Chair': 684,
#  'is_occupied_by': 685,
#  'is_given_to': 686,
#  'hasRelatedPaper': 687,
#  'is_sent_after': 688,
#  'Reviewed_contribution': 689,
#  'hold': 690,
#  'virtualMeetingEnabledBy': 691,
#  'OperatingTopicsystems': 692,
#  'Deadline_hotel_reservation': 693,
#  'Scholar': 694,
#  'has_the_first_name': 695,
#  'Program_Chair': 696,
#  'runPaperAssignmentTools': 697,
#  'Conference_fees': 698,
#  'Shuttle_bus': 699,
#  'Evaluated_Paper': 700,
#  'was_a_committee_of': 701,
#  'title': 702,
#  'Regular_Session': 703,
#  'Web_Site': 704,
#  'Author_attendee_cd_registration_fee': 705,
#  'printHardcopyMailingManifests': 706,
#  'Bronze_Supporter': 707,
#  'Hotel_presenter': 708,
#  'Conference_activity': 709,
#  'hasEndDateTime': 710,
#  'ProgramCommitteeMember': 711,
#  'int': 712,
#  'follows': 713,
#  'Organising_Agency': 714,
#  'Neutral_Review': 715,
#  'is_a_date_of_acceptance_announcement': 716,
#  'Session_chair': 717,
#  'location': 718,
#  'reviewerBiddingStartedBy': 719,
#  'Positive_Review': 720,
#  'Webmaster': 721,
#  'Registration_form': 722,
#  'Hotel': 723,
#  'manuscriptDueOn': 724,
#  'Rejection': 725,
#  'City': 726,
#  'hasSubmissionDeadline': 727,
#  'ConferenceEvent': 728}

# %%
tmp[0]
# Out:
# array([-3.32923084e-02, -6.61843270e-03, -1.69279389e-02, -1.89156849e-02,
#        -3.77495140e-02, -1.86415445e-02,  5.27783819e-02,  6.30775169e-02,
#        -1.89297069e-02, -9.57503170e-03,  3.84151302e-02,  7.43583497e-03,
#         1.56472195e-02,  1.30205071e-02, -3.44151445e-02,  5.70965791e-03,
#        -4.81052399e-02, -2.15850538e-03,  2.90137548e-02, -1.14982098e-03,
#         4.35708500e-02,  5.33411242e-02, -9.89831984e-03, -7.55268112e-02,
#        -3.03623429e-03, -1.04758637e-02, -4.64556646e-03,  5.28141037e-02,
#        -3.03096529e-02,  7.37254024e-02,  7.13311741e-03,  1.19511643e-02,
#         5.17832562e-02,  6.22331239e-02, -8.19792971e-02,  1.09951505e-02,
#        -1.09791644e-02, -3.31103392e-02,  9.43025760e-03,  5.71564247e-04,
#        -2.54904814e-02, -7.33156642e-03, -4.20193449e-02, -6.96072914e-03,
#         7.61979818e-02,  5.74754141e-02,  1.99243743e-02,  2.04879674e-03,
#         9.07520875e-02, -3.81723116e-03, -4.66725640e-02,  4.07577977e-02,
#        -9.50154290e-03, -5.67313656e-02,  2.71435492e-02,  1.61497183e-02,
#         4.50195484e-02,  3.17869186e-02, -5.46461046e-02,  3.99530083e-02,
#        -7.21936449e-02,  4.47138399e-03, -3.19244564e-02, -5.65083623e-02,
#        -9.61941704e-02, -1.91119183e-02, -5.71736023e-02, -6.84264153e-02,
#         1.30593302e-02, -5.51984832e-02,  1.12108449e-02,  1.08843774e-01,
#         7.81526566e-02,  6.89106993e-04, -1.75713878e-02, -1.53175090e-02,
#        -2.50193104e-02,  2.28868723e-02,  4.37645847e-03, -1.68981347e-02,
#        -7.14074001e-02,  2.22497843e-02,  4.20462526e-02,  3.36156599e-02,
#        -1.70383658e-02, -3.36546488e-02, -4.73673269e-02,  4.18832293e-03,
#         1.15197618e-02, -3.35619040e-02,  7.15308115e-02, -1.02061868e-01,
#         7.11299628e-02, -5.27140200e-02, -1.06439002e-01, -1.19058916e-03,
#         3.64879519e-02,  2.55280938e-02,  2.02539265e-02,  8.41113273e-03,
#        -6.95376936e-03, -2.96763908e-02,  2.15677060e-02, -2.86875498e-02,
#        -4.52177972e-02,  1.09784026e-02, -8.00223872e-02, -4.45892066e-02,
#        -3.19351554e-02,  3.23596187e-02,  5.19603118e-02,  5.57538308e-02,
#         4.60009202e-02,  3.36409695e-02,  2.29820069e-02,  4.44384851e-02,
#         2.12967899e-02, -1.45613626e-02, -4.08527558e-04, -3.92220989e-02,
#        -8.80014896e-03, -4.79662493e-02, -3.08600552e-02, -6.74796756e-03,
#         7.34111201e-03, -1.69010889e-02,  2.56434809e-02, -2.21203882e-02,
#         2.85562215e-04,  2.29110382e-03, -6.52390858e-03, -6.46619946e-02,
#        -9.96368937e-03, -3.77602354e-02, -6.23790734e-02,  4.31477018e-02,
#         3.18501070e-02,  2.37741079e-02, -4.87938486e-02, -2.67700236e-02,
#         2.96596084e-02, -3.54747511e-02,  6.06306680e-02, -7.14630038e-02,
#        -1.50515595e-02, -4.32428904e-02,  8.52032844e-03, -2.02398151e-02,
#         4.77478877e-02,  6.27384111e-02, -1.43940467e-02,  5.80477603e-02,
#         2.21514758e-02,  6.78747892e-02, -5.20671047e-02,  4.13820893e-02,
#        -3.27299275e-02,  4.44914959e-02, -7.47320652e-02, -1.76433232e-02,
#         2.34465450e-02, -1.22051425e-02,  3.28019471e-03, -5.52979149e-02,
#        -3.43154818e-02, -7.05844238e-02,  3.20915715e-03,  7.54680708e-02,
#         1.50050242e-02,  2.85256337e-02, -8.28331932e-02, -1.89397279e-02,
#        -2.94188280e-02,  5.58805419e-03, -8.14755727e-03,  8.63229483e-03,
#         1.37973437e-02, -4.35821200e-03, -2.62681656e-02, -4.89582531e-02,
#        -3.27737187e-03,  1.92526821e-02, -3.04144155e-02,  5.33994194e-03,
#         1.97182805e-03, -6.68127760e-02, -7.42953345e-02, -1.21578388e-02,
#         2.95023322e-02, -7.11978003e-02, -7.82329440e-02,  4.04424816e-02,
#         4.25671563e-02, -8.73276666e-02,  3.25748362e-02,  7.28530809e-02,
#        -2.22452078e-02,  1.68798417e-02, -2.00579744e-02, -2.46121474e-02,
#        -1.71932913e-02,  3.14852893e-02, -1.40433747e-03,  2.08507944e-02,
#        -4.19353805e-02,  7.90071860e-02, -6.57353550e-03,  8.57195724e-03,
#         3.19229551e-02, -2.23784391e-02, -7.55777732e-02, -5.36756665e-02,
#         5.75121902e-02, -2.66527440e-02,  3.06315906e-02,  1.82393510e-02,
#        -1.19121447e-02, -7.29428753e-02, -1.24982046e-02,  3.92911285e-02,
#         3.39764319e-02,  1.01204269e-01, -6.80830553e-02, -5.20009883e-02,
#        -1.53419366e-02, -4.27568108e-02,  3.30537371e-02,  2.08796099e-01,
#         3.64746824e-02, -7.54516050e-02, -4.33263071e-02, -3.18664648e-02,
#        -4.78541479e-02, -7.06027169e-03,  2.75660376e-03,  4.12778556e-02,
#        -3.46025191e-02, -6.19798265e-02, -9.54067148e-03, -1.53629053e-02,
#        -3.65632698e-02,  1.06189542e-01,  8.88375472e-03,  4.47073430e-02,
#        -2.64618956e-02, -4.58744951e-02,  3.75779010e-02, -2.40689162e-02,
#        -1.75930969e-02, -1.27060721e-02, -2.83180997e-02, -1.75969377e-02,
#         2.87297089e-02, -2.05628853e-02, -7.70332962e-02, -3.20158005e-02,
#         2.87238453e-02, -4.67184633e-02, -2.86760256e-02, -2.94295163e-03,
#        -2.43995972e-02, -3.70089598e-02,  7.26290792e-02, -3.81182283e-02,
#         1.66130904e-02, -2.07771771e-02, -2.65383683e-02,  8.07068031e-03,
#         8.34167227e-02,  2.28952654e-02, -5.32954186e-02,  1.33539345e-02,
#         3.91038880e-02,  2.24207733e-02,  3.49015892e-02,  3.08999624e-02,
#         4.63748425e-02, -4.08715233e-02,  5.56541383e-02, -6.90292418e-02,
#         8.20423812e-02, -2.40814984e-02,  1.30568091e-02,  5.83182946e-02,
#         7.41589768e-03,  1.15119768e-02, -7.64128491e-02,  4.63633947e-02,
#         2.19329949e-02, -9.57132727e-02,  1.00009898e-02, -8.75320192e-03,
#         7.39674196e-02, -5.24397418e-02,  9.24004894e-03,  1.92788113e-02,
#        -2.67023803e-03, -9.06707253e-03,  2.24018227e-02, -1.26120616e-02,
#         1.75292753e-02, -2.42913347e-02, -6.26614615e-02, -1.77653711e-02,
#        -1.39483511e-02, -6.70117438e-02,  2.86800368e-03,  1.44318370e-02,
#        -3.21939886e-02, -1.40587762e-02, -1.19988052e-02, -4.66486514e-02,
#         1.31437043e-02, -3.60184908e-02,  5.72395958e-02,  5.38464971e-02,
#        -5.61257303e-02,  5.46849482e-02, -8.37797020e-03, -2.79177092e-02,
#         6.27639797e-03,  5.30610904e-02,  2.04491671e-02,  1.99566167e-02,
#         6.40053302e-02,  3.19059640e-02, -1.36755798e-02,  3.71674262e-02,
#         6.88357130e-02, -6.12291601e-03, -5.17546833e-02,  3.02895647e-03,
#         5.85514978e-02, -5.46385795e-02, -2.63786037e-03,  3.48492488e-02,
#         2.38431003e-02, -2.16583591e-02,  5.42095304e-02,  5.83872944e-02,
#         1.29588824e-02, -3.10177002e-02, -7.15354830e-02,  4.48586568e-02,
#        -2.84726359e-02,  3.75234447e-02, -5.58938785e-03,  9.37669724e-03,
#         6.24183975e-02,  1.90737024e-02,  9.35225934e-02,  4.13610265e-02,
#         1.25315404e-02,  7.46220164e-03, -4.56330627e-02, -2.31925342e-02,
#        -3.18083949e-02, -1.98220219e-02,  5.29708751e-02,  6.16066568e-02,
#         8.53604898e-02, -1.13660318e-03,  2.69396119e-02, -3.17290984e-02,
#         5.90078570e-02, -2.43475800e-03,  4.67413012e-03, -8.54590908e-02,
#        -2.76660398e-02, -7.21257599e-03,  9.58516542e-03, -2.49320529e-02,
#         4.13050829e-03, -5.51146455e-02,  4.34623938e-03,  4.88206856e-02,
#        -1.75995007e-02,  8.94317776e-02,  6.12512119e-02,  8.43747482e-02,
#        -3.99712287e-02,  1.16851060e-02, -1.53965270e-03, -4.74411659e-02,
#        -2.65006386e-02, -3.71606089e-02,  3.76559980e-02, -4.41127121e-02,
#        -5.15295044e-02, -3.17186187e-03, -1.59360766e-02, -1.39820511e-02,
#        -3.63889267e-03, -4.38804142e-02,  4.21885252e-02, -6.07024059e-02,
#         5.87559156e-02, -1.63095854e-02,  3.13607007e-02, -1.09264612e-01,
#        -1.53651377e-02,  7.67763657e-03, -8.50440282e-03,  3.05020846e-02,
#         3.41892503e-02,  5.13870865e-02,  1.94787019e-04,  1.52391475e-03,
#        -5.07508107e-02, -7.04656094e-02,  8.21038932e-02, -4.23038639e-02,
#         3.47836465e-02,  9.44440253e-03, -3.11371568e-03, -1.85795091e-02,
#         4.48783971e-02, -5.52575476e-02,  5.15943281e-02,  6.58467561e-02,
#        -9.32303667e-02,  2.17856225e-02, -8.18653032e-02,  6.93951398e-02,
#         2.38369852e-02,  5.81955500e-02,  5.69080450e-02,  3.82444486e-02,
#         2.96444762e-02, -1.38608431e-02, -4.90195230e-02, -2.52068305e-04,
#        -2.40474287e-02,  1.75666381e-02,  3.91703285e-02, -2.54857056e-02,
#        -4.59807850e-02,  6.02237172e-02, -5.98513568e-03, -4.94588055e-02,
#        -4.56174975e-03,  4.82664118e-03, -4.12440747e-02,  1.00295851e-02,
#        -3.13457102e-02, -1.79756023e-02, -1.89917181e-02,  6.01293147e-02,
#         2.41172947e-02,  4.24022414e-02, -8.38796515e-03, -1.64002944e-02,
#         6.73037544e-02, -2.23733671e-02, -2.20277682e-02,  4.63889074e-03,
#        -1.12165129e-02,  4.33860309e-02,  5.17853871e-02,  5.49189821e-02,
#         4.76761274e-02, -2.24055871e-02,  6.22303449e-02,  5.05174212e-02,
#         1.21109765e-02, -2.28107832e-02,  2.64399662e-03,  1.36489034e-04,
#         4.30420041e-03, -4.31031175e-03, -2.09692530e-02,  1.77517661e-03,
#         1.19140726e-02, -2.19200309e-02,  8.25599954e-02,  6.58087879e-02,
#         7.55585879e-02,  2.83293445e-02,  1.59642860e-01,  3.67591418e-02,
#         3.17214318e-02,  7.57482946e-02,  1.82705671e-02,  1.19120404e-02,
#         5.15892580e-02, -2.02929787e-03, -6.56714663e-03, -1.41511746e-02,
#         2.00949311e-02,  7.21918344e-02,  6.33457722e-03, -3.38323563e-02,
#        -1.83839910e-03,  4.79140691e-02, -7.68158063e-02,  1.84164375e-01,
#        -5.09120077e-02,  2.07262821e-02,  5.60873048e-03,  5.19897565e-02,
#         1.70311034e-02, -2.17748829e-03,  1.45871157e-03, -3.49609740e-02,
#        -2.86513381e-02,  5.68082370e-02, -4.11653519e-02, -1.54600469e-02,
#        -2.52430830e-02,  1.09560356e-01, -3.27790342e-02,  1.42226471e-02],
#       dtype=float32)
