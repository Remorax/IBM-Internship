# %%
flatten = lambda l: [item for sublist in l for item in sublist]

class Ontology():
    def __init__(self, ontology):
        self.ontology = ontology
        self.ontology_obj = minidom.parse(ontology)
        self.root = self.ontology_obj.documentElement
        self.construct_mapping_dict()
        
        self.parents_dict = {}
        self.subclasses = self.parse_subclasses()
        self.object_properties = self.parse_object_properties()
        self.data_properties = self.parse_data_properties()
        self.triples = self.parse_triples()
        self.classes = self.parse_classes()        
    
    def totext(self, content):
        return " ".join(t.nodeValue for t in content.childNodes if t.nodeType == t.TEXT_NODE)

    def construct_mapping_dict(self):
        self.mapping_dict = {self.extract_ID(el, False): self.get_child_node(el, "rdfs:label")[0].firstChild.nodeValue for el in self.root.getElementsByTagName("owl:Class") if self.get_child_node(el, "rdfs:label")}
        self.mapping_dict_inv = {self.mapping_dict[key]: key for key in self.mapping_dict}
        return
        
    def get_child_node(self, element, tag):
        return [e for e in element._get_childNodes() if type(e)==minidom.Element and e._get_tagName() == tag]
        
    def has_attribute_value(self, element, attribute, value):
        return True if element.getAttribute(attribute).split("#")[-1] == value else False
    
    def get_subclass_triples(self, rootpath=False):
        subclasses = self.get_subclasses(rootpath)
        
        return [(b,a,c) for (a,b,c) in subclasses]
    
    def parse_triples(self, union_flag=0, subclass_of=True, rootpath=False):
        obj_props = self.object_properties
        data_props = self.data_properties
        props = obj_props + data_props
        all_triples = []
        for prop in props:
            domain_children = self.get_child_node(prop, "rdfs:domain")
            range_children = self.get_child_node(prop, "rdfs:range")
            domain_prop = self.filter_null([self.extract_ID(el) for el in domain_children])
            range_prop = self.filter_null([self.extract_ID(el) for el in range_children])
            if not domain_children or not range_children:
                continue
            if not domain_prop:
                domain_prop = self.filter_null([self.extract_ID(el) for el in domain_children[0].getElementsByTagName("owl:Class")])
            if not range_prop:
                range_prop = self.filter_null([self.extract_ID(el) for el in range_children[0].getElementsByTagName("owl:Class")])
            if domain_prop and range_prop:
                if union_flag == 0:
                    all_triples.extend([(el[0], el[1], self.extract_ID(prop)) for el in list(itertools.product(domain_prop, range_prop))])
                else:
                    all_triples.append(("###".join(domain_prop), "###".join(range_prop), self.extract_ID(prop)))
        if subclass_of:
            all_triples.extend(self.get_subclass_triples(rootpath))
        return list(set(all_triples))
    
    def get_triples(self, union_flag=0, subclass_of=True, rootpath=False):
        return self.parse_triples(union_flag, subclass_of, rootpath)

    def parse_subclasses(self, union_flag=0):
        subclasses = self.root.getElementsByTagName("rdfs:subClassOf")
        subclass_pairs = []
        for el in subclasses:
            inline_subclasses = self.extract_ID(el)
            if inline_subclasses:
                subclass_pairs.append((el, el.parentNode, "subclass_of"))
            else:
                level1_class = self.get_child_node(el, "owl:Class")
                if not level1_class:
                    
                    restriction = el.getElementsByTagName("owl:Restriction")
                    if not restriction:
                        continue
                    prop = self.get_child_node(restriction[0], "owl:onProperty")
                    some_vals = self.get_child_node(restriction[0], "owl:someValuesFrom")
                    if not some_vals:
                        some_vals = self.get_child_node(restriction[0], "owl:cardinality")
                    if not prop or not some_vals:
                        continue
#                     print(self.extract_ID(el), "**", self.extract_ID(some_vals[0]), "**", self.extract_ID(prop[0]))
                    try:
                        if self.extract_ID(prop[0]) and self.extract_ID(some_vals[0]):
                            subclass_pairs.append((el.parentNode, some_vals[0], self.extract_ID(prop[0])))
                        elif self.extract_ID(prop[0]) and not self.extract_ID(some_vals[0]):
                            class_vals = self.get_child_node(some_vals[0], "owl:Class")
                            subclass_pairs.append((el.parentNode, class_vals[0], self.extract_ID(prop[0])))
                        elif not self.extract_ID(prop[0]) and self.extract_ID(some_vals[0]):
                            prop_vals = self.get_child_node(prop[0], "owl:ObjectProperty")
                            subclass_pairs.append((el.parentNode, some_vals[0], self.extract_ID(prop_vals[0])))
                        else:
                            prop_vals = self.get_child_node(prop[0], "owl:ObjectProperty")
                            class_vals = self.get_child_node(some_vals[0], "owl:Class")
                            subclass_pairs.append((el.parentNode, class_vals[0], self.extract_ID(prop_vals[0])))
                    except Exception as e:
                        print ("error", e)
                        continue
                else:
                    if self.extract_ID(level1_class[0]):
                        subclass_pairs.append((level1_class[0], el.parentNode, "subclass_of"))
                    else:
#                         level2classes = level1_class[0].getElementsByTagName("owl:Class")
#                         subclass_pairs.extend([(elem, el.parentNode, "subclass_of") for elem in level2classes if self.extract_ID(elem)])
                        continue
        return subclass_pairs
        
    def get_subclasses(self, rootpath=False):
        subclasses = [(self.extract_ID(a, not rootpath), self.extract_ID(b, not rootpath), c)
                      for (a,b,c) in self.subclasses]
        self.parents_dict = {}
        for (a,b,c) in subclasses:
            if c == "subclass_of" and a!="Thing" and b!="Thing":
                if b not in self.parents_dict:
                    self.parents_dict[b] = [a]
                else:
                    self.parents_dict[b].append(a)
        return [el for el in subclasses if el[0] and el[1] and el[2] and el[0]!="Thing" and el[1]!="Thing"]
    
    def filter_null(self, data):
        return [el for el in data if el]
    
    def extract_ID(self, element, check_coded = True):
        element_id = element.getAttribute("rdf:ID") or element.getAttribute("rdf:resource") or element.getAttribute("rdf:about")
        label = self.get_child_node(element, 'rdfs:label')
        element_id = element_id.split("#")[-1]
        if len(list(filter(str.isdigit, element_id))) >= 3 and "_" in element_id and check_coded:
            return self.mapping_dict[element_id]
#         print (element_id)
#         if check_coded and element_id in self.mapping_dict:
#             return self.mapping_dict[element_id]
        return element_id.replace("UNDEFINED_", "").replace("DO_", "")
    
    def parse_classes(self):
        class_elems = [self.extract_ID(el) for el in self.root.getElementsByTagName("owl:Class")]
        subclass_classes = list(set(flatten([el[:-1] for el in self.triples])))
        return list(set(self.filter_null(class_elems + subclass_classes)))
    
    def get_classes(self):
        return self.classes
    
    def get_entities(self):
        entities = [self.extract_ID(el) for el in self.root.getElementsByTagName("owl:Class")]
        return list(set(self.filter_null(entities)))

    def parse_data_properties(self):
        data_properties = [el for el in self.get_child_node(self.root, 'owl:DatatypeProperty')]
        fn_data_properties = [el for el in self.get_child_node(self.root, 'owl:FunctionalProperty') if el]
        fn_data_properties = [el for el in fn_data_properties if type(el)==minidom.Element and 
            [el for el in self.get_child_node(el, "rdf:type") if 
             self.has_attribute_value(el, "rdf:resource", "DatatypeProperty")]]
        inv_fn_data_properties = [el for el in self.get_child_node(self.root, 'owl:InverseFunctionalProperty') if el]
        inv_fn_data_properties = [el for el in inv_fn_data_properties if type(el)==minidom.Element and 
            [el for el in self.get_child_node(el, "rdf:type") if 
             self.has_attribute_value(el, "rdf:resource", "DatatypeProperty")]]
        return data_properties + fn_data_properties + inv_fn_data_properties
        
    def parse_object_properties(self):
        obj_properties = [el for el in self.get_child_node(self.root, 'owl:ObjectProperty')]
        fn_obj_properties = [el for el in self.get_child_node(self.root, 'owl:FunctionalProperty') if el]
        fn_obj_properties = [el for el in fn_obj_properties if type(el)==minidom.Element and 
            [el for el in self.get_child_node(el, "rdf:type") if 
             self.has_attribute_value(el, "rdf:resource", "ObjectProperty")]]
        inv_fn_obj_properties = [el for el in self.get_child_node(self.root, 'owl:InverseFunctionalProperty') if el]
        inv_fn_obj_properties = [el for el in inv_fn_obj_properties if type(el)==minidom.Element and 
            [el for el in self.get_child_node(el, "rdf:type") if 
             self.has_attribute_value(el, "rdf:resource", "ObjectProperty")]]
        return obj_properties + fn_obj_properties + inv_fn_obj_properties
    
    def get_object_properties(self):
        obj_props = [self.extract_ID(el) for el in self.object_properties]
        return list(set(self.filter_null(obj_props)))
    
    def get_data_properties(self):
        data_props = [self.extract_ID(el) for el in self.data_properties]
        return list(set(self.filter_null(data_props)))

# %%
USE_folder = "/home/vlead/USE_multilingual"
alignment_folder = "german_datasets/"

ontologies_in_alignment = []

# Load reference alignments 
def load_alignments(folder):
    gt = []
    for subdir in os.listdir(folder):
        path = folder + subdir + "/"
        path += [l for l in os.listdir(path) if l.endswith(".txt")][0]
        mappings = [content.strip() for content in open(path).read().split("--------------------------------------------------------") if content.strip()]
        for mapping in mappings:
            src = [line.split(":")[-1].strip() for line in mapping.split("\n") if line.startswith(" + Source: ")][0]
            targ = [line.split(":")[-1].strip() for line in mapping.split("\n") if line.startswith(" + Target: ")][0]
            ontologies_in_alignment.append((folder + subdir + "/"+src, folder + subdir + "/"+targ))
            src = src.rsplit(".",1)[0].replace(".", "_").lower()
            targ = targ.rsplit(".",1)[0].replace(".", "_").lower()
            lines = [["_".join(row.strip().split(":")[0].split(".")) for row in line.split("-",1)[1].strip().split("<->")]
                     for line in mapping.split("\n") if line.startswith(" -")]
            lines = [[src + "#" + line[0], targ + "#" + line[1]] for line in lines]
            gt.extend(lines)
    return gt



# Extracting USE embeddings

def extractUSEEmbeddings(words):
    try:
        embed = hub.KerasLayer(USE_folder)
    except Exception as e:
        # !mkdir $USE_folder
        # !curl -L "https://tfhub.dev/google/universal-sentence-encoder-multilingual/3?tf-hub-format=compressed" | tar -zxvC $USE_folder
        embed = hub.KerasLayer(USE_folder)
        pass
    word_embeddings = embed(words)
    return word_embeddings.numpy()

# model = SentenceTransformer('bert-large-nli-mean-tokens')
# def extractUSEEmbeddings(words):
#     return model.encode(words)

# cos_sim(*model.encode(["My brother plays guitar", "The sun is shining"]))

def cos_sim(a,b):
    return 1 - spatial.distance.cosine(a, b)


reference_alignments = load_alignments(alignment_folder)

# ra_anatomy_coded = load_alignments("../Anatomy/Alignments/")
# ra_anatomy = []
# ont1 = Ontology("../Anatomy/Ontologies/mouse.owl")
# ont2 = Ontology("../Anatomy/Ontologies/human.owl")
# for elem in ra_anatomy_coded:
#     pre1, pre2 = elem[0].split("#")[0].split(".")[0].split("/")[-1], elem[1].split("#")[0].split(".")[0].split("/")[-1]
#     elem1, elem2 = elem[0].split("#")[-1], elem[1].split("#")[-1]
#     ra_anatomy.append(( pre1 + "#" + ont1.mapping_dict[elem1], pre2 + "#" + ont2.mapping_dict[elem2]))

# gt_mappings = [tuple([elem.split("/")[-1] for elem in el]) for el in reference_alignments]
# gt_mappings.extend(ra_anatomy)

# ontologies_in_alignment = pickle.load(open("../data_generic.pkl", "rb"))[-1][:-1]
# ontologies_in_alignment += [["../Anatomy/Ontologies/human.owl", "../Anatomy/Ontologies/mouse.owl"]]

# %%
ontologies_in_alignment
# Out:
# [('german_datasets/mapping lebensmittel/Google.Lebensmittel.owl',
#   'german_datasets/mapping lebensmittel/web.Lebensmittel.owl'),
#  ('german_datasets/mapping freizeit/dmoz.Freizeit.owl',
#   'german_datasets/mapping freizeit/Google.Freizeit.owl'),
#  ('german_datasets/mapping webdirectory/dmoz.owl',
#   'german_datasets/mapping webdirectory/google.owl'),
#  ('german_datasets/mapping webdirectory/dmoz.owl',
#   'german_datasets/mapping webdirectory/web.owl'),
#  ('german_datasets/mapping webdirectory/dmoz.owl',
#   'german_datasets/mapping webdirectory/yahoo.small.owl'),
#  ('german_datasets/mapping webdirectory/google.owl',
#   'german_datasets/mapping webdirectory/web.owl'),
#  ('german_datasets/mapping webdirectory/google.owl',
#   'german_datasets/mapping webdirectory/yahoo.small.owl'),
#  ('german_datasets/mapping webdirectory/web.owl',
#   'german_datasets/mapping webdirectory/yahoo.small.owl')]

# %%
# Combinatorial mapping generation
all_mappings = []
for l in ontologies_in_alignment:
    ont1 = Ontology(l[0])
    ont2 = Ontology(l[1])
    
    ent1 = ont1.get_classes()
    ent2 = ont2.get_classes()
    
    obj1 = ont1.get_object_properties()
    obj2 = ont2.get_object_properties()
    
    data1 = ont1.get_data_properties()
    data2 = ont2.get_data_properties()

    mappings = list(itertools.product(ent1, ent2)) + list(itertools.product(obj1, obj2)) + list(itertools.product(data1, data2))
    
    pre1 = l[0].split("/")[-1].rsplit(".",1)[0].replace(".", "_").lower()
    pre2 = l[1].split("/")[-1].rsplit(".",1)[0].replace(".", "_").lower()
    print (pre1, pre2)
    all_mappings.extend([(pre1 + "#" + el[0], pre2 + "#" + el[1]) for el in mappings])
    

data = {mapping: False for mapping in all_mappings}
reference_alignments = [tuple(alignment) for alignment in reference_alignments]
s = set(all_mappings)
for mapping in set(reference_alignments):
    if mapping in s:
        data[mapping] = True
    else:
        mapping = tuple([el.replace(",-", "_") for el in mapping])
        if mapping in s:
            data[mapping] = True
        else:
            print (mapping)
# Out:
# google_lebensmittel web_lebensmittel
# dmoz_freizeit google_freizeit
# dmoz google
# dmoz web
# dmoz yahoo_small
# google web
# google yahoo_small
# web yahoo_small

# %%
a[1], b[1]
# Out:
# (array([-3.51269264e-03,  3.38228121e-02,  4.22673002e-02, -2.78660022e-02,
#         -3.13101038e-02,  1.66269522e-02, -2.53552590e-02,  1.10926665e-02,
#          1.88992620e-02, -2.40844507e-02,  7.01542571e-02,  3.90431397e-02,
#         -4.66191508e-02,  4.95024435e-02, -8.07325095e-02, -6.51722625e-02,
#          1.84831601e-02, -5.36775216e-02,  5.63435107e-02,  1.96375754e-02,
#         -9.62680206e-03, -1.21781193e-02,  7.82673582e-02, -1.17588174e-02,
#          9.98896733e-03,  6.25176579e-02, -3.90938073e-02,  5.55893686e-03,
#          2.52319220e-02,  3.91568104e-03,  1.78878773e-02, -3.94871905e-02,
#         -3.31385322e-02,  5.19221425e-02,  1.92756392e-02,  5.00136353e-02,
#          4.35547829e-02,  1.00794295e-02,  4.25346009e-02, -4.08579148e-02,
#         -7.51301646e-02, -7.75257424e-02, -3.18838842e-02, -7.21048340e-02,
#         -4.47573699e-02, -2.58584153e-02, -6.06630780e-02, -1.58498351e-05,
#          8.79219100e-02, -3.58868986e-02,  6.48758262e-02,  4.84112501e-02,
#          7.69602787e-03,  9.71343517e-02,  2.91889179e-02,  1.21967597e-02,
#          2.76637822e-02,  5.37251979e-02, -1.40470751e-02, -4.36989553e-02,
#         -4.14926484e-02, -5.87064913e-03,  2.35319827e-02,  5.73577136e-02,
#          4.51512821e-02, -8.54531527e-02, -4.08488922e-02,  7.23741250e-03,
#         -1.28941629e-02,  3.37971412e-02,  2.69859377e-02,  3.85930240e-02,
#         -3.59150432e-02,  7.95701519e-02, -2.94363834e-02,  1.84921976e-02,
#         -6.20293915e-02,  2.58564427e-02, -7.57396547e-03, -7.27614537e-02,
#          3.48582305e-02, -2.90006250e-02, -7.97921419e-02, -4.93810624e-02,
#         -2.06441488e-02,  4.38633710e-02, -2.62324922e-02, -2.45247614e-02,
#         -5.81596680e-02, -3.00461985e-02, -2.42695641e-02,  4.37487736e-02,
#          1.91017780e-02,  3.41571644e-02, -1.79659668e-02,  3.16732354e-03,
#          6.56732172e-02,  2.74118893e-02,  8.80583152e-02, -9.91774537e-03,
#          4.76918109e-02,  4.57726009e-02, -9.56837088e-02, -6.73504770e-02,
#          2.59404890e-02,  2.99484655e-02, -3.79432067e-02,  1.49674583e-02,
#         -3.92748043e-02, -3.31504345e-02,  1.20294476e-02,  4.28894721e-02,
#         -5.53269833e-02, -5.52061107e-03,  2.90705133e-02,  1.65056493e-02,
#          1.27701163e-02, -3.14423861e-03, -1.10042803e-02, -6.37934208e-02,
#          4.62024622e-02, -6.59118593e-02,  3.10077034e-02, -4.79839146e-02,
#         -6.42326921e-02,  7.21382035e-04, -2.60884315e-02, -3.76197211e-02,
#         -5.34749702e-02,  1.35241291e-02, -4.71908087e-03,  2.92573813e-02,
#          3.23652104e-02, -5.76829873e-02,  1.68377161e-02,  9.14590247e-03,
#         -8.50717425e-02, -7.72860572e-02, -2.05250620e-03,  6.22186577e-03,
#          6.88751042e-02, -2.18542907e-02,  4.67012729e-03,  1.68735106e-02,
#         -1.01943230e-02,  3.32149102e-05,  2.88676992e-02, -5.77010252e-02,
#         -6.18936010e-02,  4.92453873e-02, -6.43930733e-02,  3.05707417e-02]))

# %%
def camel_case_split(identifier):
    matches = re.finditer('.+?(?:(?<=[a-z])(?=[A-Z])|(?<=[A-Z])(?=[A-Z][a-z])|$)', identifier)
    return [m.group(0) for m in matches]

# Abbrevation resolution preprocessing
def parse(word):
    return " ".join(flatten([el.split("_") for el in camel_case_split(word)]))

abbreviations_dict = {}
final_dict = {}

for mapping in all_mappings:
    mapping = tuple([el.split("#")[1] for el in mapping])
    is_abb = re.search("[A-Z][A-Z]+", mapping[0])
    if is_abb:
        
        abbreviation = "".join([el[0].upper() for el in mapping[1].split("_") if el])
        if is_abb.group() in abbreviation:
            
            start = abbreviation.find(is_abb.group())
            end = start + len(is_abb.group())
            fullform = "_".join(mapping[1].split("_")[start:end])
            print ("left", mapping, abbreviation, fullform)
            
            rest_first = " ".join([el for el in mapping[0].replace(is_abb.group(), "").split("_") if el]).lower()
            rest_second = " ".join(mapping[1].split("_")[:start] + mapping[1].split("_")[end:])
            if is_abb.group() not in final_dict:
                final_dict[is_abb.group()] = [(fullform, rest_first, rest_second)]
            else:
                final_dict[is_abb.group()].append((fullform, rest_first, rest_second))

    is_abb = re.search("[A-Z][A-Z]+", mapping[1])
    if is_abb:
        abbreviation = "".join([el[0].upper() for el in mapping[0].split("_") if el])
        
        if is_abb.group() in abbreviation:
            start = abbreviation.find(is_abb.group())
            end = start + len(is_abb.group())
            fullform = "_".join(mapping[0].split("_")[start:end])
            print ("right", mapping, abbreviation, fullform)

            rest_first = " ".join([el for el in mapping[1].replace(is_abb.group(), "").split("_") if el]).lower()
            rest_second = " ".join(mapping[0].split("_")[:start] + mapping[0].split("_")[end:])
            if is_abb.group() not in final_dict:
                final_dict[is_abb.group()] = [(fullform, rest_first, rest_second)]
            else:
                final_dict[is_abb.group()].append((fullform, rest_first, rest_second))

keys = [el for el in list(set(flatten([flatten([tup[1:] for tup in final_dict[key]]) for key in final_dict]))) if el]
abb_embeds = dict(zip(keys, extractUSEEmbeddings([parse(el) for el in keys])))

scored_dict = {}
for abbr in final_dict:
    sim_list = [(tup[0], tup[1], tup[2], cos_sim(abb_embeds[tup[1]], abb_embeds[tup[2]])) if tup[1] and tup[2]
                else (tup[0], tup[1], tup[2], 0) for tup in final_dict[abbr]]
    scored_dict[abbr] = sorted(list(set(sim_list)), key=lambda x:x[-1], reverse=True)

resolved_dict = {key: scored_dict[key][0] for key in scored_dict}
filtered_dict = {key: " ".join(resolved_dict[key][0].split("_")) for key in resolved_dict if resolved_dict[key][-1] > 0.9}
# Out:
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Regionale_Spezialitaeten', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTRS Essen_und
# right ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_Ersatzteile_und_Zubehoer_Schmierstoffe', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOFAEUZS Ersatzteile_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Landwirtschaftliche_Erzeugnisse', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTLE Essen_und
# right ('Top_World_Deutsch_Online-Shops_Schmuck_Edel_und_Schmucksteine_Diamanten', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOSEUSD Edel_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Getraenke_Wein', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTGW Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Getraenke_Spirituosen_Wodka', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTGSW Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Obst_und_Gemuese', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTOUG Essen_und
# right ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_Ersatzteile_und_Zubehoer_Tuning', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOFAEUZT Ersatzteile_und
# right ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_Ersatzteile_und_Zubehoer_Ersatzteile', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOFAEUZE Ersatzteile_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Getraenke_Spirituosen_Absinth', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTGSA Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Essig_und_Oel_Olivenoel', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTEUOO Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Regionale_Spezialitaeten_Europaeisch_Italienisch', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTRSEI Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Getraenke_Kaffee_und_Tee_Tee', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTGKUTT Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Getraenke_Bier_Heimbrauen', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTGBH Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Getraenke_Cocktails', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTGC Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Getraenke_Kaffee_und_Tee', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTGKUT Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Getraenke_Wein_Suedafrikanisch', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTGWS Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Getraenke_Wein_Europaeisch_Deutsch_Pfalz', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTGWEDP Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Getraenke_Wein_Europaeisch_Deutsch_Baden', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTGWEDB Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Regionale_Spezialitaeten_Europaeisch_Griechisch', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTRSEG Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Getraenke_Kaffee_und_Tee_Kaffee', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTGKUTK Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Getraenke_Wein_Europaeisch', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTGWE Essen_und
# right ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_Ersatzteile_und_Zubehoer_Pflegemittel', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOFAEUZP Ersatzteile_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Getraenke_Wein_Europaeisch_Deutsch_Mosel-Saar-Ruwer', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTGWEDM Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Getraenke_Wein_Europaeisch_Deutsch_Franken', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTGWEDF Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Regionale_Spezialitaeten_Asiatisch', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTRSA Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Regionale_Spezialitaeten_Europaeisch_Franzoesisch', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTRSEF Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUT Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Kaese', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTK Essen_und
# right ('Top_World_Deutsch_Online-Shops_Schmuck_Edel_und_Schmucksteine_Bernstein', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOSEUSB Edel_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Backwaren_Weihnachtsgebaeck', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTBW Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Gewuerze_und_Kraeuter', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTGUK Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Getraenke', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTG Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Getraenke_Wein_Europaeisch_Deutsch_Rheinhessen', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTGWEDR Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Getraenke_Bier', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTGB Essen_und
# right ('Top_World_Deutsch_Online-Shops_Freizeit_Basteln_Window_Color', 'World_Deutsch_Online-Shops_Haus-und-Garten_Moebel_Badezimmer-und-WC') TWDOFBWC Window_Color
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Getraenke_Wasser', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTGW Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Getraenke_Wein_Europaeisch_Deutsch_Nahe', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTGWEDN Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Regionale_Spezialitaeten_Europaeisch_Oesterreichisch', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTRSEO Essen_und
# right ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_Ersatzteile_und_Zubehoer_Aufkleber_und_Folien', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOFAEUZAUF Ersatzteile_und
# right ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_Ersatzteile_und_Zubehoer_Raeder_und_Reifen', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOFAEUZRUR Ersatzteile_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Getraenke_Wein_Biowein', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTGWB Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Getraenke_Wein_Geschenke', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTGWG Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Getraenke_Wein_Europaeisch_Spanisch', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTGWES Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Biokost', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTB Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Honig', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTH Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Backwaren', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTB Essen_und
# right ('Top_World_Deutsch_Online-Shops_Publikationen_Buecher_Essen_und_Trinken', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOPBEUT Essen_und
# right ('Top_World_Deutsch_Online-Shops_Schmuck_Edel_und_Schmucksteine_Opale', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOSEUSO Edel_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Getraenke_Wein_Europaeisch_Schweizer', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTGWES Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Getraenke_Spirituosen_Whisky', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTGSW Essen_und
# right ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_Ersatzteile_und_Zubehoer_Elektronik', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOFAEUZE Ersatzteile_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Getraenke_Wein_Europaeisch_Franzoesisch', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTGWEF Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Fleisch_und_Wurst', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTFUW Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Delikatessen', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTD Essen_und
# right ('Top_World_Deutsch_Online-Shops_Schmuck_Edel_und_Schmucksteine', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOSEUS Edel_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Getraenke_Wein_Europaeisch_Deutsch_Wuerttemberg', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTGWEDW Essen_und
# right ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_Ersatzteile_und_Zubehoer', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOFAEUZ Ersatzteile_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Getraenke_Wein_Europaeisch_Deutsch', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTGWED Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Regionale_Spezialitaeten_Europaeisch_Spanisch', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTRSES Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Getraenke_Wein_Europaeisch_Oesterreichisch', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTGWEO Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Regionale_Spezialitaeten_Europaeisch_Deutsch', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTRSED Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Vegetarisch', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTV Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Essig_und_Oel', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTEUO Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Getraenke_Wein_Europaeisch_Deutsch_Ahr', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTGWEDA Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Getraenke_Wein_Europaeisch_Deutsch_Rheingau', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTGWEDR Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Tiefkuehlkost', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTT Essen_und
# right ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_Ersatzteile_und_Zubehoer_Marderabwehr', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOFAEUZM Ersatzteile_und
# right ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_Ersatzteile_und_Zubehoer_Traegersysteme', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOFAEUZT Ersatzteile_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Vegetarisch_Vegan', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTVV Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Fisch_und_Meeresfruechte', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTFUM Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Getraenke_Wein_Europaeisch_Italienisch', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTGWEI Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Getraenke_Spirituosen', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTGS Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Suesswaren', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTS Essen_und
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Regionale_Spezialitaeten_Europaeisch', 'World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge') TWDOEUTRSE Essen_und
# right ('Top_World_Deutsch_Online-Shops_Unterhaltung_Bild_und_Tontraeger_Video_DVD', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Unterhaltungselektronik_Satelliten-Digital-TV') TWDOUBUTVD Tontraeger_Video
# right ('Top_World_Deutsch_Online-Shops_Freizeit_Modellbau_Puppenhaeuser_und_Miniaturen', 'Verzeichnis_Einkaufen-Sparen_Buecher_Musik-Filme_Musik_MP3-Files') TWDOFMPUM Modellbau_Puppenhaeuser
# right ('Top_World_Deutsch_Online-Shops_Unterhaltung_Bild_und_Tontraeger_Video', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Unterhaltungselektronik_Satelliten-Digital-TV') TWDOUBUTV Tontraeger_Video
# right ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Motorraeder_Pflegemittel', 'Verzeichnis_Einkaufen-Sparen_Buecher_Musik-Filme_Musik_MP3-Files') TWDOFMP Motorraeder_Pflegemittel
# right ('Top_World_Deutsch_Online-Shops_Publikationen_Buecher_Fremdsprachige_Literatur_Polnisch', 'Verzeichnis_Einkaufen-Sparen_Buecher_Musik-Filme_Musik_LPs') TWDOPBFLP Literatur_Polnisch
# right ('Top_World_Deutsch_Online-Shops_Unterhaltung_Bild_und_Tontraeger_Video_DVD_Verleih', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Unterhaltungselektronik_Satelliten-Digital-TV') TWDOUBUTVDV Tontraeger_Video
# right ('Top_World_Deutsch_Online-Shops_Publikationen_Buecher_Fremdsprachige_Literatur_Portugiesisch', 'Verzeichnis_Einkaufen-Sparen_Buecher_Musik-Filme_Musik_LPs') TWDOPBFLP Literatur_Portugiesisch
# left ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Telekommunikation') VEUT Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik
# left ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Unterhaltungselektronik_DVD_Radio_Fernsehen-Video') VEUUDRF Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik
# left ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Telekommunikation_Allgemein') VEUTA Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik
# left ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Computer_Zubehoer_Mauspads') VEUCZM Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik
# left ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Telekommunikation_Mobilfunk_Zubehoer') VEUTMZ Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik
# left ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Computer') VEUC Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik
# left ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Unterhaltungselektronik_Satelliten-Digital-TV') VEUUS Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik
# left ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Telekommunikation_Mobilfunk_Freisprechanlagen') VEUTMF Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik
# left ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge', 'Verzeichnis_Einkaufen-Sparen_Haus-Garten_Einrichten_Uhren') VEHEU Einrichten_Uhren
# left ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Computer_Software_Software-allgemein') VEUCSS Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik
# left ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Computer_Komplettsysteme') VEUCK Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik
# left ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Elektronik-allgemein') VEUE Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik
# left ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Unterhaltungselektronik_Zubehoer') VEUUZ Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik
# left ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Fernsehgeraete') VEUF Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik
# left ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Unterhaltungselektronik_Unterhaltungselektronik-allgemein') VEUUU Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik
# left ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Computer_Software_Spiele') VEUCSS Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik
# left ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Computer_Zubehoer') VEUCZ Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik
# left ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Computer_Software_Audio-Software') VEUCSA Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik
# left ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Computer_Zubehoer_Zubehoer-allgemein') VEUCZZ Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik
# left ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Computer_Software') VEUCS Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik
# left ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik') VEU Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik
# left ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_HiFi-Geraete') VEUH Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik
# left ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Telekommunikation_Allgemein_ProfiSeller') VEUTAP Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik
# left ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Computer_Zubehoer_Drucker') VEUCZD Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik
# left ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Computer_Netzwerkkomponenten') VEUCN Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik
# left ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Computer_Software_CD-ROMs') VEUCSC Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik
# left ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Computer_Palmtops') VEUCP Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik
# left ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Unterhaltungselektronik_Veranstaltungstechnik') VEUUV Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik
# left ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Computer_Notebooks') VEUCN Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik
# left ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Unterhaltungselektronik') VEUU Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik
# left ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Telekommunikation_Mobilfunk') VEUTM Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik
# left ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Computer_Computer-allgemein') VEUCC Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik
# left ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Computer_Hardware') VEUCH Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik
# left ('Top_World_Deutsch_Online-Shops_Fahrzeuge_Autos_EU-Importfahrzeuge', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Unterhaltungselektronik_Heimkino') VEUUH Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Vegetarisch', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Unterhaltungselektronik_Satelliten-Digital-TV') TWDOEUTV Trinken_Vegetarisch
# right ('Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Vegetarisch_Vegan', 'Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Unterhaltungselektronik_Satelliten-Digital-TV') TWDOEUTVV Trinken_Vegetarisch
# right ('Top_World_Deutsch_Online-Shops_Schmuck_Modeschmuck_Perlen', 'Verzeichnis_Einkaufen-Sparen_Buecher_Musik-Filme_Musik_MP3-Files') TWDOSMP Modeschmuck_Perlen
# right ('Top_World_Deutsch_Online-Shops_Haus_und_Garten_Haushaltsbedarf_Haushaltsgeraete_Kaffeemaschinen', 'Firmen_Computer_Hardware_Beamer-und-Projektoren_HK-Computer-Systemhaus') TWDOHUGHHK Haushaltsgeraete_Kaffeemaschinen
# right ('Top_World_Deutsch_Online-Shops_Bestattungswesen', 'Firmen_Koerperpflege_Hygieneartikel-fuer-Frauen_OB') TWDOB Online-Shops_Bestattungswesen
# right ('Top_World_Deutsch_Online-Shops_Freizeit_Waffen_Hieb_und_Stichwaffen', 'Firmen_Kraftfahrzeuge_Ersatzteile-und-Zubehoer_US-Fahrzeuge') TWDOFWHUS und_Stichwaffen
# right ('Top_World_Deutsch_Online-Shops_Publikationen_Comics', 'Firmen_Computer_Hardware_PCs') TWDOPC Publikationen_Comics
# right ('Top_World_Deutsch_Online-Shops_Computer_Hardware_Komplettsysteme_Notebooks', 'Firmen_Computer_Hardware_Beamer-und-Projektoren_HK-Computer-Systemhaus') TWDOCHKN Hardware_Komplettsysteme
# right ('Top_World_Deutsch_Online-Shops_Schmuck_Edel_und_Schmucksteine_Diamanten', 'Firmen_Kraftfahrzeuge_Ersatzteile-und-Zubehoer_US-Fahrzeuge') TWDOSEUSD und_Schmucksteine
# right ('Top_World_Deutsch_Online-Shops_Publikationen_Buecher_Religion_und_Spiritualitaet', 'Firmen_Kraftfahrzeuge_Ersatzteile-und-Zubehoer_US-Fahrzeuge') TWDOPBRUS und_Spiritualitaet
# right ('Top_World_Deutsch_Online-Shops_Bekleidung_Kopfbedeckungen', 'Firmen_Koerperpflege_Hygieneartikel-fuer-Frauen_OB') TWDOBK Online-Shops_Bekleidung
# right ('Top_World_Deutsch_Online-Shops_Publikationen_Buecher_Religion_und_Spiritualitaet_Esoterik', 'Firmen_Kraftfahrzeuge_Ersatzteile-und-Zubehoer_US-Fahrzeuge') TWDOPBRUSE und_Spiritualitaet
# right ('Top_World_Deutsch_Online-Shops_Bekleidung_Sport', 'Firmen_Koerperpflege_Hygieneartikel-fuer-Frauen_OB') TWDOBS Online-Shops_Bekleidung
# right ('Top_World_Deutsch_Online-Shops_Bildung', 'Firmen_Koerperpflege_Hygieneartikel-fuer-Frauen_OB') TWD
online-Shops_Bekleidung
# right ('World_Deutsch_Online-Shops_Publikationen_Comics', 'Firmen_Computer_Hardware_PCs') WDOPC Publikationen_Comics
# right ('World_Deutsch_Online-Shops_Bekleidung_Sport', 'Firmen_Koerperpflege_Hygieneartikel-fuer-Frauen_OB') WDOBS Online-Shops_Bekleidung
# right ('World_Deutsch_Online-Shops_Bekleidung_Accessoires_Guertel-und-Hosentraeger', 'Firmen_Koerperpflege_Hygieneartikel-fuer-Frauen_OB') WDOBAG Online-Shops_Bekleidung
# right ('World_Deutsch_Online-Shops_Freizeit_Outdoor-und-Camping_Bekleidung', 'Firmen_Koerperpflege_Hygieneartikel-fuer-Frauen_OB') WDOFOB Outdoor-und-Camping_Bekleidung
# right ('World_Deutsch_Online-Shops_Bekleidung_Accessoires_Krawatten', 'Firmen_Koerperpflege_Hygieneartikel-fuer-Frauen_OB') WDOBAK Online-Shops_Bekleidung
# right ('World_Deutsch_Online-Shops_Computer_Hardware_Komplettsysteme', 'Firmen_Computer_Hardware_Beamer-und-Projektoren_HK-Computer-Systemhaus') WDOCHK Hardware_Komplettsysteme
# right ('World_Deutsch_Online-Shops_Blumen', 'Firmen_Koerperpflege_Hygieneartikel-fuer-Frauen_OB') WDOB Online-Shops_Blumen
# right ('World_Deutsch_Online-Shops_Bekleidung_Trachten_Europaeisch', 'Firmen_Koerperpflege_Hygieneartikel-fuer-Frauen_OB') WDOBTE Online-Shops_Bekleidung
# right ('World_Deutsch_Online-Shops_Bekleidung_Sport_Badesport', 'Firmen_Koerperpflege_Hygieneartikel-fuer-Frauen_OB') WDOBSB Online-Shops_Bekleidung
# right ('World_Deutsch_Online-Shops_Bekleidung_Kinder_Secondhand_Babys', 'Firmen_Koerperpflege_Hygieneartikel-fuer-Frauen_OB') WDOBKSB Online-Shops_Bekleidung
# right ('World_Deutsch_Online-Shops_Publikationen_Comics_Fanartikel', 'Firmen_Computer_Hardware_PCs') WDOPCF Publikationen_Comics
# right ('Verzeichnis_Einkaufen-Sparen_Haus-Garten_Kunstgegenstaende_Sonstiges', 'Firmen_Computer_Hardware_Beamer-und-Projektoren_HK-Computer-Systemhaus') VEHKS Haus-Garten_Kunstgegenstaende
# right ('Verzeichnis_Einkaufen-Sparen_Haus-Garten_Kunstgegenstaende_Reproduktionen', 'Firmen_Computer_Hardware_Beamer-und-Projektoren_HK-Computer-Systemhaus') VEHKR Haus-Garten_Kunstgegenstaende
# left ('Verzeichnis_Einkaufen-Sparen_Buecher_Musik-Filme_Musik_MP3-Files', 'Firmen_Essen-und-Trinken_Milchprodukte_Portale-und-Linksammlungen') FEMP Milchprodukte_Portale-und-Linksammlungen
# left ('Verzeichnis_Einkaufen-Sparen_Buecher_Musik-Filme_Musik_MP3-Files', 'Firmen_Kunst-und-Kunsthandwerk_Malerei-und-Bildhauerei_Portraet-Malerei') FKMP Malerei-und-Bildhauerei_Portraet-Malerei
# left ('Verzeichnis_Einkaufen-Sparen_Buecher_Musik-Filme_Musik_MP3-Files', 'Firmen_Gesundheit_Bildung-und-Ausbildung_Medizin_Pruefungsvorbereitung') FGBMP Medizin_Pruefungsvorbereitung
# left ('Verzeichnis_Einkaufen-Sparen_Buecher_Musik-Filme_Musik_MP3-Files', 'Firmen_Gesundheit_Behandlungen-und-Untersuchungen_Massage_Portale-und-Linksammlungen') FGBMP Massage_Portale-und-Linksammlungen
# right ('Verzeichnis_Einkaufen-Sparen_Unterhaltungs-Kommunikationselektronik_Unterhaltungselektronik_Satelliten-Digital-TV', 'Firmen_Kraftfahrzeuge_Ersatzteile-und-Zubehoer_US-Fahrzeuge') VEUUS Unterhaltungselektronik_Satelliten-Digital-TV
# right ('Verzeichnis_Einkaufen-Sparen_Haus-Garten_Kunstgegenstaende_Galerien', 'Firmen_Gesundheit_Medizinische-Geraete-und-Bedarf_Hempel-KG') VEHKG Kunstgegenstaende_Galerien
# right ('Verzeichnis_Einkaufen-Sparen_Haus-Garten_Kunstgegenstaende_Galerien', 'Firmen_Computer_Hardware_Beamer-und-Projektoren_HK-Computer-Systemhaus') VEHKG Haus-Garten_Kunstgegenstaende
# right ('Verzeichnis_Einkaufen-Sparen_Haus-Garten_Kunstgegenstaende', 'Firmen_Computer_Hardware_Beamer-und-Projektoren_HK-Computer-Systemhaus') VEHK Haus-Garten_Kunstgegenstaende
# left ('Verzeichnis_Einkaufen-Sparen_Buecher_Musik-Filme_Musik_LPs', 'Firmen_Musik_Labels_Pelham-Power-Productions-3p') FMLP Labels_Pelham-Power-Productions-3p
# right ('Verzeichnis_Einkaufen-Sparen_Haus-Garten_Kueche', 'Firmen_Computer_Hardware_Beamer-und-Projektoren_HK-Computer-Systemhaus') VEHK Haus-Garten_Kueche
# right ('Verzeichnis_Einkaufen-Sparen_Haus-Garten_Kunstgegenstaende_Bildende-Kunst', 'Firmen_Computer_Hardware_Beamer-und-Projektoren_HK-Computer-Systemhaus') VEHKB Haus-Garten_Kunstgegenstaende
# right ('Verzeichnis_Einkaufen-Sparen_Haus-Garten_Kunstgegenstaende_Handel', 'Firmen_Computer_Hardware_Beamer-und-Projektoren_HK-Computer-Systemhaus') VEHKH Haus-Garten_Kunstgegenstaende

# %%
extracted_elems = []
mapping_ont = {}
for ont_name in list(set(flatten(ontologies_in_alignment))):
    ont = Ontology(ont_name)
    entities = ont.get_classes()
    props = ont.get_object_properties() + ont.get_data_properties()
    triples = list(set(flatten(ont.get_triples())))
    ont_name = ont_name.split("/")[-1].rsplit(".",1)[0].replace(".", "_").lower()
    print (ont_name)
    mapping_ont[ont_name] = ont
    extracted_elems.extend([ont_name + "#" + elem for elem in entities + props + triples])

extracted_elems = list(set(extracted_elems))
inp = []
for word in extracted_elems:
    ont_name = word.split("#")[0]
    elem = word.split("#")[1]
    inp.append(parse(elem))

print ("Total number of extracted unique classes and properties from entire RA set: ", len(extracted_elems))

extracted_elems = ["<UNK>"] + extracted_elems

embeds = np.array(extractUSEEmbeddings(inp))
embeds = np.array([np.zeros(embeds.shape[1],)] + list(embeds))
# embeds = np.array([np.zeros(512,)] + list(extractUSEEmbeddings(inp_spellchecked)))
embeddings = dict(zip(extracted_elems, embeds))


emb_vals = list(embeddings.values())
emb_indexer = {key: i for i, key in enumerate(list(embeddings.keys()))}
emb_indexer_inv = {i: key for i, key in enumerate(list(embeddings.keys()))}
# Out:
# dmoz
# web
# google
# yahoo_small
# google_freizeit
# google_lebensmittel
# dmoz_freizeit
# web_lebensmittel
# Total number of extracted unique classes and properties from entire RA set:  3282

# %%
inp
# Out:
# ['World Deutsch Online-Shops Sport Pferdesport Reitbedarf Westernreiten',
#  'Verzeichnis Einkaufen-Sparen Haus-Garten Haustierbedarf Hund-Katze',
#  'Firmen Bekleidung Damenbekleidung Spezialgroessen',
#  'World Deutsch Online-Shops Essen-und-Trinken Getraenke Wein Europaeisch Schweizer',
#  'Verzeichnis Einkaufen-Sparen Freizeit-Hobby Sammeln Figuren',
#  'Top World Deutsch Online-Shops Freizeit Waffen Schusswaffen Luft und Gasdruck',
#  'Top World Deutsch Online-Shops Haustiere',
#  'Firmen Koerperpflege Kosmetik',
#  'Verzeichnis Einkaufen-Sparen Sportartikel Rugby',
#  'Top World Deutsch Online-Shops Secondhand',
#  'Firmen Buecher Buchhandel Hochschulbuchhandlungen',
#  'World Deutsch Online-Shops Freizeit Zaubern',
#  'World Deutsch Online-Shops Schreibwaren-und-Buerobedarf Materialien-und-Zubehoer Papierwaren',
#  'Firmen Haus-und-Garten Garten-und-Pflanzen Zimmer-und-Dekorationspflanzen',
#  'World Deutsch Online-Shops Kunsthandwerk Regionale-Spezialitaeten Amerikanisch',
#  'Verzeichnis Einkaufen-Sparen Haus-Garten Haushaltswaren Bestecke',
#  'World Deutsch Online-Shops Freizeit Lebendige-Geschichte Nordamerikanisch',
#  'Firmen Haus-und-Garten Garten-und-Pflanzen',
#  'Top World Deutsch Online-Shops Sammelbare Objekte Zahlungsmittel und Wertpapiere Historische Wertpapiere',
#  'World Deutsch Online-Shops Publikationen Buecher Fremdsprachige-Literatur Skandinavische-Sprachen',
#  'Firmen Sport Radsport BMX',
#  'Top World Deutsch Online-Shops Freizeit Handarbeiten Stricken und Haekeln',
#  'Verzeichnis Einkaufen-Sparen Sportartikel Boule',
#  'Top World Deutsch Online-Shops Freizeit Waffen Schusswaffen Boeller und Kanonen',
#  'Firmen Gesundheit Kuren',
#  'Top World Deutsch Online-Shops Haus und Garten Haustechnik Sicherheit Brandschutz',
#  'World Deutsch Online-Shops Unterhaltung Bild-und-Tontraeger Musik Genres Rock',
#  'Firmen Telekommunikation Telefondienstleistungen',
#  'Firmen Gesundheit Alternativmedizin Magnetfeldtherapie',
#  'Firmen Buecher Buchhandel Antiquariate Portale-und-Linksammlungen',
#  'Top World Deutsch Online-Shops Senioren',
#  'Firmen Buecher Buchhandel Bildung-und-Ausbildung Buchtitel',
#  'World Deutsch Online-Shops Haus-und-Garten Klima-Geraete Ventilatoren',
#  'Top World Deutsch Online-Shops Freizeit Modellbau',
#  'Top World Deutsch Online-Shops Unterhaltung Eintrittskarten Sport',
#  'Verzeichnis Einkaufen-Sparen Buecher Musik-Filme Buchshops Datenbanken Buchhaendler-bei-Libride',
#  'World Deutsch Online-Shops Bekleidung Kinder',
#  'Top World Deutsch Online-Shops Fahrzeuge Fahrraeder Mountainbikes',
#  'Top World Deutsch Online-Shops Publikationen Comics',
#  'World Deutsch Online-Shops Publikationen Buecher Haus-und-Garten',
#  'World Deutsch Online-Shops Schmuck Edel-und-Schmucksteine Opale',
#  'Firmen Antiquitaeten-und-Sammeln Militaria',
#  'Verzeichnis Einkaufen-Sparen Freizeit-Hobby Astronomie',
#  'World Deutsch Online-Shops Publikationen Buecher Freizeit-und-Sport',
#  'World Deutsch Online-Shops Essen-und-Trinken Getraenke Wein Europaeisch Italienisch',
#  'World Deutsch Online-Shops Freizeit Basteln Perlen',
#  'Top World Deutsch Online-Shops Freizeit Waffen Hieb und Stichwaffen',
#  'World Deutsch Online-Shops Regionale-Spezialitaeten Amerikanisch',
#  'Firmen Outdoors Boote-und-Schiffe Yacht-Charter Motoryachten',
#  'Verzeichnis Einkaufen-Sparen Unterhaltungs-Kommunikationselektronik Computer',
#  'World Deutsch Online-Shops Bekleidung Berufsbekleidung',
#  'Top World Deutsch Online-Shops Kunsthandwerk Keramik',
#  'Firmen Buecher Buchhandel Sport-und-Freizeit Sport',
#  'Firmen Schmuck Bedarf-und-Zubehoer',
#  'Firmen Gesundheit Behandlungen-und-Untersuchungen Massage Portale-und-Linksammlungen',
#  'Top World Deutsch Online-Shops Schreibwaren und Buerobedarf',
#  'World Deutsch Online-Shops Publikationen Buecher',
#  'World Deutsch Online-Shops Publikationen',
#  'Verzeichnis Einkaufen-Sparen Buero-Schreibwaren Postkarten',
#  'World Deutsch Online-Shops Sport Motorsport Kart',
#  'Verzeichnis Einkaufen-Sparen Haus-Garten Werkzeuge',
#  'Top World Deutsch',
#  'World Deutsch Online-Shops Fahrzeuge Motorraeder Motorroller',
#  'Firmen Koerperpflege Dentalhygiene-und-produkte Colgate-Palmolive Produkte',
#  'World Deutsch Online-Shops Bekleidung Nischenprodukte Tanz Schuhe',
#  'World Deutsch Online-Shops Sport Allgemeines-Sortiment',
#  'Firmen Unterhaltung Zauberei Bedarf-und-Zubehoer',
#  'Firmen Computer Software Betriebssysteme Linux',
#  'Firmen Kunst-und-Kunsthandwerk Kunsthandwerk Handarbeiten',
#  'Firmen Unterhaltung Diskotheken',
#  'Firmen Unterhaltung Eintrittskarten Sport Reisebuero-und-Hotel-Heidpark Formel-1',
#  'Top World Deutsch Online-Shops Publikationen Buecher Allgemeines Sortiment Oesterreich',
#  'World Deutsch Online-Shops Essen-und-Trinken Getraenke Wein Europaeisch Deutsch Pfalz',
#  'Top World Deutsch Online-Shops Haustiere Liebhaberartikel',
#  'World Deutsch Online-Shops Bekleidung Sport Badesport',
#  'World Deutsch Online-Shops Haus-und-Garten Grillen',
#  'Firmen Kunst-und-Kunsthandwerk Koerperkunst',
#  'Firmen Gesundheit Medizinische-Geraete-und-Bedarf Sanitaetshaeuser',
#  'World Deutsch Online-Shops Freizeit Modellbau Flugzeuge-und-Helikopter',
#  'World Deutsch Online-Shops Schoenheit Hautpflege Sonnenschutz',
#  'Firmen Sport Kampfsport Budo',
#  'Verzeichnis Einkaufen-Sparen Unterhaltungs-Kommunikationselektronik Telekommunikation Allgemein',
#  'Firmen Musik Labels Grover',
#  'Top World Deutsch Online-Shops Bekleidung Kundenspezifisch Stickerei',
#  'World Deutsch Online-Shops Bekleidung Trachten Islamisch',
#  'Firmen Kraftfahrzeuge Ersatzteile-und-Zubehoer Elektronik Fahrtenbuecher',
#  'World Deutsch Online-Shops Freizeit Lebendige-Geschichte',
#  'Top World Deutsch Online-Shops Freizeit Basteln Window Color',
#  'World Deutsch Online-Shops Sport Geraete-und-Zubehoer',
#  'Firmen Buecher Buchhandel Wirtschaft',
#  'Verzeichnis Einkaufen-Sparen Sportartikel Billard',
#  'Firmen Haus-und-Garten Garten-und-Pflanzen Teiche-und-Springbrunnen',
#  'Top World Deutsch Online-Shops Kunsthandwerk Regionale Spezialitaeten Afrikanisch',
#  'Verzeichnis Einkaufen-Sparen Verbraucherinformationen',
#  'World Deutsch Online-Shops Freizeit Modellbau Flugzeuge-und-Helikopter Flugzeuge',
#  'Verzeichnis Einkaufen-Sparen Freizeit-Hobby Fotografie',
#  'World Deutsch Online-Shops Freizeit Modellbau Eisenbahnen',
#  'Firmen Sport Skifahren Ski-Hersteller Elan-Skis',
#  'Firmen Unterhaltung Eintrittskarten Sport Reisebuero-und-Hotel-Heidpark',
#  'Firmen Essen-und-Trinken Fische-und-Meeresfruechte Lachs',
#  'World Deutsch Online-Shops Freizeit Outdoor-und-Camping Optik',
#  'World Deutsch Online-Shops Freizeit Waffen Bogen-und-Armbrust',
#  'Firmen Musik C Ds Schallplatten-und-Kassetten Musikgenre-spezialisierter-Fachhandel Oldies',
#  'Top World Deutsch Online-Shops Unterhaltung Film und Fernsehen',
#  'World Deutsch Online-Shops Fotografie Dienstleistungen',
#  'Firmen Kraftfahrzeuge Kleinanzeigen Gebrauchtwagen',
#  'Top World Deutsch Online-Shops Gesundheit',
#  'Firmen Spiele-und-Spielzeug Modellbau Autos',
#  'Top World Deutsch Online-Shops Musik Instrumente Schlaginstrumente',
#  'Top World Deutsch Online-Shops Haus und Garten Haushaltsbedarf Haushaltsgeraete Staubsauger',
#  'World Deutsch Online-Shops Freizeit Basteln',
#  'Verzeichnis Einkaufen-Sparen Buecher Musik-Filme Musik L Ps',
#  'Firmen Haus-und-Garten Garten-und-Pflanzen Bambus',
#  'Verzeichnis Einkaufen-Sparen Freizeit-Hobby Sammeln Parfumminiaturen',
#  'Firmen Haus-und-Garten Haushaltswaren Geschirr-und-Porzellan',
#  'World Deutsch Online-Shops Freizeit Basteln',
#  'Firmen Kunst-und-Kunsthandwerk Literatur Kreatives-Schreiben',
#  'Top World Deutsch Online-Shops Publikationen Buecher Religion und Spiritualitaet Esoterik',
#  'World Deutsch Online-Shops Haustiere Liebhaberartikel',
#  'Firmen Gesundheit Privatkliniken Chirurgie Neurochirurgie',
#  'Firmen Haus-und-Garten Garten-und-Pflanzen Baumschulen',
#  'Firmen Buecher Buchbinderei-und-konservierung',
#  'Firmen Telekommunikation ISDN',
#  'Top World Deutsch Online-Shops Nischenprodukte Lesben  Schwule und Bisexuelle',
#  'World Deutsch Online-Shops Computer Hardware Peripherie Monitore',
#  'Firmen Gesundheit Hoerakustik',
#  'Verzeichnis Einkaufen-Sparen Gesundheit-Kosmetik Optik Kontaktlinsen',
#  'Verzeichnis Einkaufen-Sparen Nahrungs-Genussmittel Supermarkt',
#  'Firmen Haus-und-Garten Moebel Moebelhaeuser Ideencenter-Trends',
#  'Firmen Buecher Buchhandel Portale-und-Linksammlungen Buchhandelde',
#  'Top World Deutsch Online-Shops Kunsthandwerk Regionale Spezialitaeten',
#  'Firmen Schmuck Grosshandel',
#  'Top World Deutsch Online-Shops Sammelbare Objekte Briefmarken',
#  'Firmen Bekleidung Herrenbekleidung Hemden',
#  'World Deutsch Online-Shops Freizeit Handarbeiten Stricken-und-Haekeln',
#  'World Deutsch Online-Shops Freizeit Partys Feuerwerk',
#  'Firmen Gesundheit Krankheiten-und-Beschwerden Inkontinenz',
#  'Top World Deutsch Online-Shops Bekleidung Naturtextilien',
#  'Firmen Religion Buddhismus',
#  'Top World Deutsch Online-Shops Publikationen Buecher Antiquarisch Verzeichnisse und Portale',
#  'Verzeichnis Einkaufen-Sparen Kleinanzeigen

#  'World Deutsch Online-Shops Essen-und-Trinken Regionale-Spezialitaeten Europaeisch Spanisch',
#  'Verzeichnis Einkaufen-Sparen Mode-Accessoires Stoffe',
#  'Firmen Buecher Buchhandel Religion',
#  'Top World Deutsch Online-Shops Haus und Garten Moebel Kuechen',
#  'Firmen Gesundheit Ernaehrung Nahrungsergaenzungsmittel Noni',
#  'World Deutsch Online-Shops Bekleidung Jeans',
#  'World Deutsch Online-Shops Freizeit Waffen Schusswaffen',
#  'World Deutsch Online-Shops Bekleidung Unterwaesche Herren',
#  'Top World Deutsch Online-Shops Freizeit Outdoor und Camping Jagd',
#  'Firmen Kraftfahrzeuge Autovermietungen Chauffeur-Service',
#  'World Deutsch Online-Shops Haustiere Aquaristik',
#  'World Deutsch Online-Shops Essen-und-Trinken Regionale-Spezialitaeten',
#  'Firmen Computer Hardware Drucker',
#  'Firmen Gesundheit Alternativmedizin Portale-und-Linksammlungen',
#  'Top World Deutsch Online-Shops Bekleidung Trachten Islamisch',
#  'Firmen Schmuck Edelmetalle Silber',
#  'Firmen Gesundheit Patientenberatung',
#  'Firmen Haus-und-Garten',
#  'Top World Deutsch Online-Shops Computer Hardware Gebrauchte',
#  'Top World Deutsch Online-Shops Sammelbare Objekte Spieluhren',
#  'Top World Deutsch Online-Shops Freizeit Drogen',
#  'Firmen Telekommunikation Handy-und-SMS Mobilfunknetz-Anbieter D2-Vodafone',
#  'Verzeichnis Einkaufen-Sparen Nahrungs-Genussmittel Getraenke Wein Sekt-Champagner Kroatien',
#  'Verzeichnis Einkaufen-Sparen Unterhaltungs-Kommunikationselektronik Computer Zubehoer Mauspads',
#  'Firmen Sport Pferdesport Westernreiten',
#  'Firmen Bekleidung Herrenbekleidung',
#  'Top World Deutsch Online-Shops Kinder Naturprodukte',
#  'Top World Deutsch Online-Shops Schreibwaren und Buerobedarf Technische Ausstattung',
#  'Verzeichnis Einkaufen-Sparen Kleinanzeigen Auto Schleswig-Holstein',
#  'World Deutsch Online-Shops Geschenke Praesentkoerbe',
#  'Verzeichnis Einkaufen-Sparen Kleinanzeigen Kleidung',
#  'Firmen Koerperpflege Drogeriemaerkte Schlecker-Drogeriemaerkte',
#  'Firmen Computer Hardware Modems',
#  'Firmen Buecher Buchhandel Bildung-und-Ausbildung',
#  'Verzeichnis Einkaufen-Sparen Kleinanzeigen Auto Thueringen',
#  'Top World Deutsch Online-Shops Essen und Trinken Getraenke Cocktails',
#  'Verzeichnis Einkaufen-Sparen Freizeit-Hobby',
#  'Top World Deutsch Online-Shops Essen und Trinken Regionale Spezialitaeten Europaeisch',
#  'Firmen Computer Versandhandel',
#  'Firmen Kunst-und-Kunsthandwerk Malerei-und-Bildhauerei Wandmalerei',
#  'Firmen Unterhaltung Gluecksspiel Lotto-und-Toto',
#  'Top World Deutsch Online-Shops Essen und Trinken Regionale Spezialitaeten Europaeisch Italienisch',
#  'Verzeichnis Einkaufen-Sparen Nahrungs-Genussmittel Fisch',
#  'World Deutsch Online-Shops Haus-und-Garten Haustechnik',
#  'World Deutsch Online-Shops Essen-und-Trinken Honig',
#  'World Deutsch Online-Shops Haustiere Voegel',
#  'Verzeichnis Einkaufen-Sparen Nahrungs-Genussmittel Fleisch-Wurst',
#  'Top World Deutsch Online-Shops Bekleidung Unterwaesche Korsetts',
#  'World Deutsch Online-Shops Elektronik Sicherheit Ueberwachungskameras',
#  'Firmen Essen-und-Trinken Fische-und-Meeresfruechte Lachs Raeucherlachs',
#  'Firmen Outdoors Drachen-und-Gleitschirmfliegen Flugschulen',
#  'World Deutsch Online-Shops Publikationen Zeitschriften',
#  'Top World Deutsch Online-Shops Schmuck Regionale Spezialitaeten',
#  'Top World Deutsch Online-Shops Gesundheit Behandlungen und Pflege',
#  'World Deutsch Online-Shops Gesundheit Alternative-Medizin Bluetentherapie Bachblueten',
#  'Top World Deutsch Online-Shops Essen und Trinken Getraenke',
#  'World Deutsch Online-Shops Freizeit Partys Feuerwerk',
#  'Firmen Bekleidung Unterwaesche-und-Dessous',
#  'Firmen Computer Hardware Monitore-und-Displays',
#  'Firmen Outdoors Canyoning',
#  'Top World Deutsch Online-Shops Kunsthandwerk Regionale Spezialitaeten Amerikanisch',
#  'World Deutsch Online-Shops Kleinanzeigen-und-Flohmaerkte Tauschboersen',
#  'Top World Deutsch Online-Shops Freizeit Lebendige Geschichte LARP',
#  'Verzeichnis Einkaufen-Sparen Nahrungs-Genussmittel Getraenke Wein Sekt-Champagner Deutschland Baden',
#  'World Deutsch Online-Shops Schreibwaren-und-Buerobedarf',
#  'World Deutsch Online-Shops Regionale-Spezialitaeten',
#  'World Deutsch Online-Shops Publikationen Kalender',
#  'Firmen Tabakwaren Zubehoer',
#  'Top World Deutsch Online-Shops Spielwaren Puppen',
#  'Firmen Unterhaltung Partys-und-Veranstaltungen Scherzartikel-und-Partygags',
#  'Top World Deutsch Online-Shops Freizeit Outdoor und Camping Zubehoer',
#  'World Deutsch Online-Shops Schoenheit Haare Entfernung',
#  'Verzeichnis Einkaufen-Sparen Mode-Accessoires Kleidung Jeans',
#  'Firmen Buecher Buchhandel Geschichte',
#  'Verzeichnis Einkaufen-Sparen Kleinanzeigen Computer',
#  'World Deutsch Online-Shops Religion-und-Spiritualitaet Esoterik Okkultismus',
#  'World Deutsch Online-Shops Haus-und-Garten Bauen-und-Renovieren Farben-und-Tapeten Farben',
#  'Top World Deutsch Online-Shops Fahrzeuge Motorraeder Quads',
#  'Top World Deutsch Online-Shops Musik Geraete und Zubehoer',
#  'World Deutsch Online-Shops Essen-und-Trinken Getraenke Cocktails',
#  'Verzeichnis Einkaufen-Sparen Auto-Motorradzubehoer Motorradzubehoer',
#  'World Deutsch Online-Shops Essen-und-Trinken Getraenke Wein Europaeisch Franzoesisch',
#  'World Deutsch Online-Shops Freizeit Waffen Hieb-und-Stichwaffen',
#  'World Deutsch Online-Shops Essen-und-Trinken Getraenke Wein Geschenke',
#  'Verzeichnis Einkaufen-Sparen Nahrungs-Genussmittel Getraenke Wein Sekt-Champagner Ungarn',
#  'Top World Deutsch Online-Shops Unterhaltung Bild und Tontraeger Aufbewahrung',
#  'Top World Deutsch Online-Shops Regionale Spezialitaeten Afrikanisch',
#  'Firmen Kunst-und-Kunsthandwerk Kunstdruck Poster',
#  'Top World Deutsch Online-Shops Regionale Spezialitaeten Afrikanisch Marokkanisch',
#  'World Deutsch Online-Shops Sport',
#  'World Deutsch Online-Shops Essen-und-Trinken Getraenke Kaffee-und-Tee Tee',
#  'Firmen Gesundheit Medizinische-Geraete-und-Bedarf',
#  'Top World Deutsch Online-Shops Publikationen Buecher Fremdsprachige Literatur Spanisch',
#  'Verzeichnis Einkaufen-Sparen Nahrungs-Genussmittel Getraenke Wein Sekt-Champagner Spanien',
#  'Verzeichnis Einkaufen-Sparen Mode-Accessoires Schmuck Armbanduhren',
#  'Top World Deutsch Online-Shops Freizeit Modellbau Flugmodelle Flugzeuge',
#  'World Deutsch Online-Shops Unterhaltung Bild-und-Tontraeger Musik Soundfiles',
#  'Firmen Sport Fitness Beratung',
#  'Firmen Spiele-und-Spielzeug Versandhandel',
#  'Top World Deutsch Online-Shops Sport Auszeichnungen',
#  'Verzeichnis Einkaufen-Sparen Kleinanzeigen Auto Niedersachsen',
#  'Firmen Musik Diskjockeys Ausruestung',
#  'Verzeichnis Einkaufen-Sparen Nahrungs-Genussmittel Getraenke Wein Sekt-Champagner Schweiz',
#  'Verzeichnis Einkaufen-Sparen Nahrungs-Genussmittel Getraenke Wein Sekt-Champagner Portugal',
#  'Firmen Haus-und-Garten Reinigung',
#  'Top World Deutsch Online-Shops Unterhaltung Bild und Tontraeger Musik Genres Rock Punk',
#  'World Deutsch Online-Shops Sport Pferdesport Reitbedarf',
#  'Firmen Kunst-und-Kunsthandwerk Malerei-und-Bildhauerei Bildhauerei',
#  'World Deutsch Online-Shops Sport Motorsport Fanartikel',
#  'Firmen Religion',
#  'Firmen Computer Computerkurse',
#  'Firmen Kraftfahrzeuge Beratung Medizinisch-Psychologische-Untersuchung',
#  'Verzeichnis Einkaufen-Sparen Buecher Musik-Filme Buchshops Fachbuecher Auto',
#  'Top World Deutsch Online-Shops Regionale Spezialitaeten Europaeisch Schweizer',
#  'World Deutsch Online-Shops Geschenke Papierwaren',
#  'World Deutsch Online-Shops Sammelbare-Objekte Puppen-und-Teddys',
#  'World Deutsch Online-Shops Schmuck Edelstahl',
#  'World Deutsch Online-Shops Freizeit Basteln Perlen',
#  'World Deutsch Online-Shops Essen-und-Trinken Essig-und-Oel Olivenoel',
#  'Verzeichnis Einkaufen-Sparen Blumen-Geschenke Kindergeschenke',
#  'Verzeichnis Einkaufen-Sparen Freizeit-Hobby Basteln-Handarbeit Basteln-allgemein',
#  'Verzeichnis Einkaufen-Sparen Blumen-Geschenke Themenshops Fantasy',
#  'Verzeichnis Einkaufen-Sparen Nahrungs-Genussmittel Getraenke Wein Sekt-Champagner Deutschland Pfalz',
#  'Verzeichnis Einkaufen-Sparen Freizeit-Hobby Feste-feiern Festdekoration',
#  'World Deutsch Online-Shops Haus-und-Garten Dekorationsartikel Kerzen Handgefertigt',
#  'Firmen Spiele-und-Spielzeug',
#  'Firmen Essen-und-Trinken Naturkost',
#  'Firmen Computer Hardware Zubehoer',
#  'Top World Deutsch Online-Shops Freizeit Modellbau Flugmodelle Helikopter',
#  'Verzeichnis Einkaufen-Sparen Nahrungs-Genussmittel Kraeuter-Gewuerze',
#  'Firmen Essen-und-Trinken Getraenke Kaffee Espresso',
#  'Firmen Kunst-und-Kunsthandwerk Tanz Ballettschulen',
#  'Firmen Koerperpflege Haare Haarpflege Schwarzkopf',
#  'Top World Deutsch Online-Shops Haus und Garten Pflanzen Exoten',
#  'Firmen Unterhaltung Gluecksspiel Lotto-und-Toto Tippgemeinschaften',
#  'Firmen Haus-und-Garten Sicherheitstechnik-und-systeme',
#  'Firmen Gesundheit Psyche Sucht-und-Entzug Nikotinabhaengigkeit',
#  'Firmen Haus-und-Garten Betten Wasserbetten Portale-und-Linksammlungen',
#  'Firmen Computer Hardware Gehaeuse',
#  'Verzeichnis Einkaufen-Sparen Unterhaltungs-Kommunikationselektronik Unterhaltungselektronik Veranstaltungstechnik',
#  'Verzeichnis Einkaufen-Sparen Freizeit-Hobby Modellbau',
#  'Firmen Essen-und-Trinken Naturkost Reformhaeuser',
#  'Firmen Gesundheit Privatkliniken Chirurgie Plastische-und-Aesthetische-Chirurgie',
#  'Top World Deutsch Online-Shops Sport Wassersport Tauchen Unterwasser-Fotografie',
#  'Top World Deutsch Online-Shops Freizeit Basteln Perlen',
#  'Top World Deutsch Online-Shops Elektronik Multimedia Audio Tragbare digitale Geraete',
#  'Top World Deutsch Online-Shops Freizeit Modellbau Fahrzeuge',
#  'Verzeichnis Einkaufen-Sparen Freizeit-Hobby Sammeln Sonstiges',
#  'Firmen Kunst-und-Kunsthandwerk Kulturen-und-Gruppen Marokkanische',
#  'World Deutsch Online-Shops Bekleidung Kundenspezifisch Textildruck T-Shirts',
#  'Top World Deutsch Online-Shops Musik Instrumente Tasteninstrumente',
#  'Top World Deutsch Online-Shops Regionale Spezialitaeten Ozeanisch',
#  'Top World Deutsch Online-Shops Bekleidung Schuhe Kinder',
#  'World Deutsch Online-Shops Publikationen Comics Fanartikel',
#  'Verzeichnis Einkaufen-Sparen Nahrungs-Genussmittel Getraenke Zustellservice',
#  'Firmen Sport Rodeln',
#  'World Deutsch Online-Shops Essen-und-Trinken Getraenke Wein Europaeisch Deutsch Pfalz',
#  'Top World Deutsch Online-Shops Regionale Spezialitaeten Asiatisch Indisch',
#  'Firmen Sport Tischtennis',
#  'World Deutsch Online-Shops Bekleidung Damen Brautmode',
#  'Firmen Buecher Buchhandel Sport-und-Freizeit',
#  'Top World Deutsch Online-Shops Haus und Garten Teiche und Wassergaerten',
#  'Verzeichnis Einkaufen-Sparen Sportartikel Sportschuhe',
#  'Firmen Kunst-und-Kunsthandwerk Malerei-und-Bildhauerei Malkurse',
#  'Verzeichnis Einkaufen-Sparen Gesundheit-Kosmetik Kosmetik Naturkosmetik',
#  'Firmen Computer Hardware PD As-und-Handhelds',
#  'Top World Deutsch Online-Shops Bekleidung Schuhe',
#  'Top World Deutsch Online-Shops Sport Turnen und Gymnastik Aerobic',
#  'Verzeichnis Einkaufen-Sparen Mode-Accessoires Kleidung Landhausmode',
#  'Firmen Haus-und-Garten Garten-und-Pflanzen Gartengeraete',
#  'Firmen Outdoors Boote-und-Schiffe Hausboote',
#  'Top World Deutsch Online-Shops Religion und Spiritualitaet Esoterik Okkultismus',
#  'Top World Deutsch Online-Shops Haus und Garten Dekorationsartikel Keramik',
#  'Firmen Buecher Buchhandel Computer',
#  'Top World Deutsch Online-Shops Sport Motorsport',
#  'Firmen Gesundheit Alternativmedizin Ayurveda Produkte',
#  'Top World Deutsch Online-Shops Essen und Trinken Kaese',
#  'World Deutsch Online-Shops Freizeit Outdoor-und-Camping Zubehoer',
#  'Firmen Essen-und-Trinken Regionale-Spezialitaeten Britisch-und-Irisch',
#  'Firmen Bekleidung Stoffe-und-Textilien Naturtextilien',
#  'Top World Deutsch Online-Shops Regionale Spezialitaeten Amerikanisch',
#  'Firmen Musik Instrumente Saiteninstrumente Gitarren-und-Baesse',
#  'Firmen Haus-und-Garten Eisenwaren',
#  'Top World Deutsch Online-Shops Sport Flugsport Accessoires',
#  'World Deutsch Online-Shops Gesundheit Ernaehrung',
#  'Firmen Essen-und-Trinken Getraenke Kaffee Tchibode',
#  'Firmen Bekleidung Damenbekleidung Masskonfektion',
#  'World Deutsch Online-Shops Essen-und-Trinken Getraenke Wein Biowein',
#  'Top World Deutsch Online-Shops Fahrzeuge Fahrraeder',
#  'Firmen Computer Hardware Tuning',
#  'Firmen Sport Rugby',
#  'Top World Deutsch Online-Shops Verzeichnisse und Portale',
#  'Verzeichnis Einkaufen-Sparen Haus-Garten Haustierbedarf Voegel',
#  'World Deutsch Online-Shops Spielwaren Bauen',
#  'Firmen Computer Computerkurse Kinder-und-Jugendliche Futurekids',
#  'World Deutsch Online-Shops Freizeit Artistik',
#  'Top World Deutsch Online-Shops Sammelbare Objekte Postkarten',
#  'Firmen Musik Diskjockeys',
#  'Firmen Kraftfahrzeuge Personenbefoerderung',
#  'Top World Deutsch Online-Shops Bekleidung Sport Badesport',
#  'World Deutsch Online-Shops Freizeit Modellbau Schiffe',
#  'World Deutsch Online-Shops Bekleidung Kinder Babys',
#  'Top World Deutsch Online-Shops Essen und Trinken Delikatessen',
#  'Firmen Haus-und-Garten Kacheloefen-und-Kamine',
#  'Firmen Antiquitaeten-und-Sammeln Science-Fiction Fantasy-und-Horror',
#  'Firmen Essen-und-Trinken Oele Olivenoel',
#  'Firmen Gesundheit Behandlungen-und-Untersuchungen Ergotherapie',
#  'World Deutsch Online-Shops Sport Motorsport',
#  'Top World Deutsch Online-Shops Gesundheit Frauen',
#  'Verzeichnis Einkaufen-Sparen Nahrungs-Genussmittel Fleisch-Wurst',
#  'World Deutsch Online-Shops Freizeit Basteln Stempeltechnik',
#  'World Deutsch Online-Shops Freizeit Natur-und-Wissenschaft Astronomie Ausserirdische-Grundstuecke',
#  'Verzeichnis Einkaufen-Sparen Auto-Motorradzubehoer Kartzubehoer',
#  'Top World Deutsch Online-Shops Elektronik Telekommunikation Handys Kleinanzeigen und Flohmaerkte',
#  'World Deutsch Online-Shops Computer Spiele',
#  'Firmen Outdoors Fallschirmspringen',
#  'Top World Deutsch Online-Shops Fahrzeuge Autos Ersatzteile und Zubehoer',
#  'Verzeichnis Einkaufen-Sparen Nahrungs-Genussmittel Getraenke Wein Sekt-Champagner',
#  'Verzeichnis Einkaufen-Sparen Sportartikel Basketball',
#  'World Deutsch Online-Shops Essen-und-Trinken Landwirtschaftliche-Erzeugnisse',
#  'Firmen Gesundheit Alternativmedizin Produkte Kraeuter-und-Getreidekissen',
#  'Firmen Waffen Schusswaffen Zubehoer',
#  'Verzeichnis Einkaufen-Sparen Sportartikel Triathlon',
#  'Top World Deutsch Online-Shops Haus und Garten Haustechnik',
#  'Top World Deutsch Online-Shops Sammelbare Objekte Zahlungsmittel und Wertpapiere Papiergeld',
#  'Verzeichnis Einkaufen-Sparen Nahrungs-Genussmittel Fertigprodukte',
#  'Verzeichnis Einkaufen-Sparen Unterhaltungs-Kommunikationselektronik Unterhaltungselektronik Heimkino',
#  'World Deutsch Online-Shops Regionale-Spezialitaeten Europaeisch Deutsch Ostdeutsch',
#  'Firmen Buecher Buchhandel Sport-und-Freizeit Outdoors',
#  'World Deutsch Online-Shops Haus-und-Garten Schaedlingsbekaempfung',
#  'Top World Deutsch Online-Shops Fahrzeuge Autos Anhaenger und Zubehoer',
#  'World Deutsch Online-Shops Publikationen Buecher Geschichte',
#  'World Deutsch Online-Shops Essen-und-Trinken Essig-und-Oel Olivenoel',
#  'Top World Deutsch Online-Shops Essen und Trinken Regionale Spezialitaeten Europaeisch Griechisch',
#  'World Deutsch Online-Shops Kinder Bild-und-Tontraeger',
#  'Firmen Sport Klettern-und-Bergsteigen',
#  'Top World Deutsch Online-Shops Computer Hardware Peripherie Drucker Verbrauchsmaterial Leergutankauf',
#  'Top World Deutsch Online-Shops Gesundheit Ernaehrung',
#  'Verzeichnis Einkaufen-Sparen Freizeit-Hobby Feste-feiern Karneval',
#  'Verzeichnis Einkaufen-Sparen Blumen-Geschenke Historische-Zeitungen',
#  'World Deutsch Online-Shops Sport Kampfsport',
#  'World Deutsch Online-Shops Freizeit Handarbeiten Naehen Patchworken-und-Quilten',
#  'World Deutsch Online-Shops Haus-und-Garten Moebel Lampen-und-Leuchten',
#  'Firmen Essen-und-Trinken Zucker-und-Suessstoffe Honig',
#  'World Deutsch Online-Shops Freizeit Modellbau',
#  'Top World Deutsch Online-Shops Schoenheit Duefte',
#  'Top World Deutsch Online-Shops Regionale Spezialitaeten Asiatisch Naher Osten',
#  'World Deutsch Online-Shops Schreibwaren-und-Buerobedarf Technische-Ausstattung',
#  'Top World Deutsch Online-Shops Essen und Trinken Getraenke Spirituosen Absinth',
#  'World Deutsch Online-Shops Haus-und-Garten Haustechnik Sicherheit Brandschutz',
#  'Firmen Sport Golf Ausruestung',
#  'World Deutsch Online-Shops Spielwaren Holz',
#  'Firmen Gesundheit Ernaehrung Spezialernaehrung',
#  'Firmen Kraftfahrzeuge Fahrschulen Portale-und-Linksammlungen',
#  'Verzeichnis Einkaufen-Sparen Sportartikel Kampfsport',
#  'Firmen Kraftfahrzeuge Personenbefoerderung Taxi',
#  'Firmen Kraftfahrzeuge Ersatzteile-und-Zubehoer Motoren',
#  'Firmen Schmuck Trauringe',
#  'Verzeichnis Einkaufen-Sparen Unterhaltungs-Kommunikationselektronik Computer Software Audio-Software',
#  'Verzeichnis Einkaufen-Sparen Haus-Garten Haustierbedarf Aquaristik',
#  'Firmen Kunst-und-Kunsthandwerk Kulturen-und-Gruppen Asiatische',
#  'Top World Deutsch Online-Shops Schreibwaren und Buerobedarf Moebel',
#  'Verzeichnis Einkaufen-Sparen Unterhaltungs-Kommunikationselektronik Computer Hardware',
#  'World Deutsch Online-Shops Freizeit Modellbau Eisenbahnen Zubehoer',
#  'World Deutsch Online-Shops Unterhaltung Bild-und-Tontraeger',
#  'Verzeichnis Einkaufen-Sparen Buecher Musik-Filme Buchshops Fachbuecher Technik',
#  'Verzeichnis Einkaufen-Sparen Unterhaltungs-Kommunikationselektronik Elektronik-allgemein',
#  'World Deutsch Online-Shops Freizeit Waffen',
#  'Verzeichnis Einkaufen-Sparen Nahrungs-Genussmittel Getraenke Wein Sekt-Champagner Deutschland',
#  'Firmen Unterhaltung Partys-und-Veranstaltungen Dekoration-und-Zubehoer',
#  'Top World Deutsch Online-Shops Publikationen Buecher Fremdsprachige Literatur Englisch',
#  'Top World Deutsch Online-Shops Regionale Spezialitaeten Amerikanisch Suedamerikanisch',
#  'Firmen Telekommunikation Geraete',
#  'Firmen Essen-und-Trinken Backwaren Baeckereien-und-Konditoreien',
#  'Firmen Kunst-und-Kunsthandwerk Tanz Bedarf-und-Zubehoer',
#  'Verzeichnis Einkaufen-Sparen Buecher Musik-Filme Musik C Ds Instrumentalmusik',
#  'World Deutsch Online-Shops Computer Netzwerk',
#  'Firmen Kunst-und-Kunsthandwerk Graffiti',
#  'World Deutsch Online-Shops Kunst Malerei',
#  'Firmen Schmuck Uhren Hersteller-und-Marken Seiko',
#  'Top World Deutsch Online-Shops Elektronik Multimedia Audio Autohifi',
#  'Firmen Gesundheit Alternativmedizin Homoeopathie',
#  'Top World Deutsch Online-Shops Sport Kegel und Kugelsport',
#  'Firmen Essen-und-Trinken Backwaren',
#  'Firmen Kraftfahrzeuge Reparatur-und-Service Abschlepp-und-Pannendienste',
#  'World Deutsch Online-Shops Schreibwaren-und-Buerobedarf Materialien-und-Zubehoer Schreibgeraete',
#  'World Deutsch Online-Shops Essen-und-Trinken Getraenke Kaffee-und-Tee Kaffee',
#  'Top World Deutsch Online-Shops Fahrzeuge Autos Verzeichnisse und Portale',
#  'Top World Deutsch Online-Shops Freizeit Drogen Hanf',
#  'Firmen Gesundheit Abnehmen Diaeten-und-Kurse Trennkost',
#  'Firmen Haus-und-Garten Briefkaesten',
#  'World Deutsch Online-Shops Spielwaren Spiele Brettspiele',
#  'Firmen Kraftfahrzeuge Oldtimer Cobra',
#  'Firmen Gesundheit Alternativmedizin Kinesiologie Bildung-und-Ausbildung',
#  'Firmen Sport Pferdesport Westernreiten Ranches-und-Westernreitzentren',
#  'Firmen Kunst-und-Kunsthandwerk Software',
#  'World Deutsch Online-Shops Elektronik Einzelteile',
#  'Verzeichnis Einkaufen-Sparen Kleinanzeigen Anzeigenmaerkte Oesterreich',
#  'Top World Deutsch Online-Shops Haus und Garten Klima-Geraete Ventilatoren',
#  'World Deutsch Online-Shops Musik Instrumente Saiteninstrumente Gitarre',
#  'Firmen Gesundheit Alternativmedizin Yoga Bedarf-und-Zubehoer',
#  'Top World Deutsch Online-Shops Religion und Spiritualitaet Christentum',
#  'Firmen Musik Instrumente Blasinstrumente Floeten',
#  'Firmen Buecher Buchhandel Computer Buchtitel',
#  'Firmen Buecher Buchhandel Kinderbuecher Buchtitel',
#  'World Deutsch Online-Shops Essen-und-Trinken Regionale-Spezialitaeten Europaeisch Italienisch',
#  'Top World Deutsch Online-Shops Bekleidung Damen Mutterschaft',
#  'World Deutsch Online-Shops Computer Zubehoer',
#  'Firmen Essen-und-Trinken Getraenke Kaffee Coffee-Nation',
#  'Firmen Buecher Buchhandel Genres Biographien',
#  'Verzeichnis Einkaufen-Sparen Unterhaltungs-Kommunikationselektronik Telekommunikation Mobilfunk Zubehoer',
#  'Firmen Haus-und-Garten Moebel Moebelhaeuser Flamme-Moebel',
#  'World Deutsch Online-Shops Freizeit Modellbau Puppenhaeuser-und-Miniaturen',
#  'Top World Deutsch Online-Shops Elektronik Telekommunikation Handys Logos und Klingeltoene',
#  'Top World Deutsch Online-Shops Freizeit',
#  'World Deutsch Online-Shops Freizeit Modellbau Fahrzeuge Autos Ferngesteuert',
#  'Firmen Spiele-und-Spielzeug Computerspiele Spieleentwickler-und-Verlage Ubi-Soft',
#  'Top World Deutsch Online-Shops Freizeit Lebendige Geschichte Nordamerikanisch',
#  'Verzeichnis Einkaufen-Sparen Freizeit-Hobby Musizieren',
#  'Top World Deutsch Online-Shops Computer Spiele',
#  'Top World Deutsch Online-Shops Freizeit Waffen Schusswaffen Zubehoer',
#  'Firmen Bekleidung Schuhe',
#  'Firmen Sport American-Football',
#  'Top World Deutsch Online-Shops Elektronik Multimedia Audio',
#  'World Deutsch Online-Shops Essen-und-Trinken Getraenke Wein',
#  'World Deutsch Online-Shops Essen-und-Trinken Getraenke Wein Europaeisch',
#  'Firmen Kunst-und-Kunsthandwerk Tanz Tanzschulen Salsa',
#  'Top World Deutsch Online-Shops Schmuck Edelmetalle Gold',
#  'World Deutsch Online-Shops Bekleidung Schuhe Damen',
#  'World Deutsch Online-Shops Unterhaltung Bild-und-Tontraeger Musik GEMA-frei',
#  'World Deutsch Online-Shops Essen-und-Trinken Getraenke Wein Geschenke',
#  'Firmen Gesundheit Augenoptik',
#  'World Deutsch Online-Shops Publikationen Buecher Essen-und-Trinken',
#  'Firmen Gesundheit Alternativmedizin Reiki',
#  'World Deutsch Online-Shops Freizeit Outdoor-und-Camping',
#  'Top World Deutsch Online-Shops Spielwaren Spiele Puzzles',
#  'Firmen Outdoors Kanu Kajak-und-Rafting',
#  'Firmen Haus-und-Garten Haushaltswaren',
#  'Top World Deutsch Online-Shops Freizeit Waffen Schusswaffen Luft und Gasdruck',
#  'Top World Deutsch Online-Shops Gesundheit Sehen',
#  'World Deutsch Online-Shops Freizeit Basteln Kerzen',
#  'Verzeichnis Einkaufen-Sparen Sportartikel Radsport',
#  'World Deutsch Online-Shops Essen-und-Trinken Getraenke Wein Europaeisch Deutsch Wuerttemberg',
#  'Firmen Gesundheit Krankheiten-und-Beschwerden Tinnitus',
#  'Top World Deutsch Online-Shops Haus und Garten Schaedlingsbekaempfung',
#  'Firmen Gesundheit Abnehmen Produkte Slim-Fast',
#  'Top World Deutsch Online-Shops Freizeit Drogen Hanf',
#  'Top World Deutsch Online-Shops Essen und Trinken Getraenke Wein Europaeisch Deutsch Baden',
#  'World Deutsch Online-Shops Freizeit Natur-und-Wissenschaft Geowissenschaften Meteorologie',
#  'Firmen Sport Fussball Schulen',
#  'World Deutsch Online-Shops Kunst Material-und-Zubehoer Rahmen',
#  'World Deutsch Online-Shops Bekleidung Schuhe Zubehoer',
#  'World Deutsch Online-Shops Bekleidung Sportswear',
#  'World Deutsch Online-Shops Regionale-Spezialitaeten Amerikanisch Vereinigte-Staaten',
#  'World Deutsch Online-Shops Freizeit Modellbau Flugzeuge-und-Helikopter Helikopter',
#  'Top World Deutsch Online-Shops Freizeit Zaubern',
#  'Top World Deutsch Online-Shops Essen und Trinken Honig',
#  'Verzeichnis Einkaufen-Sparen Nahrungs-Genussmittel Getraenke Wein Sekt-Champagner Oesterreich',
#  'Verzeichnis Einkaufen-Sparen Buecher Musik-Filme Buchshops Kinder-Jugendbuecher',
#  'Firmen Musik Labels Kontor-Records',
#  'World Deutsch Online-Shops Haustiere Hunde-und-Katzen',
#  'Firmen Buecher Buchhandel Comics Roedel-Doedel-Fun-Shop',
#  'Firmen Outdoors Software',
#  'Firmen Gesundheit Alternativmedizin Kinesiologie',
#  'World Deutsch Online-Shops Schoenheit Duefte',
#  'World Deutsch Online-Shops Nischenprodukte Linkshaender',
#  'World Deutsch Online-Shops Sport Pferdesport Haltung-und-Pflege Stallbau',
#  'Verzeichnis Einkaufen-Sparen Sportartikel Luftsport Kiteshops',
#  'Firmen Essen-und-Trinken Getraenke Alkohol-und-Spirituosen Wein Italienischer-Wein',
#  'Top World Deutsch Online-Shops Haus und Garten Gartendekoration Figuren',
#  'World Deutsch Online-Shops Essen-und-Trinken Getraenke Spirituosen Wodka',
#  'Firmen Tabakwaren Zigaretten',
#  'World Deutsch Online-Shops Schreibwaren-und-Buerobedarf Materialien-und-Zubehoer Papierwaren Umschlaege',
#  'Verzeichnis Einkaufen-Sparen Nahrungs-Genussmittel Fisch',
#  'Top World Deutsch Online-Shops Elektronik Einzelteile',
#  'Verzeichnis Einkaufen-Sparen Sportartikel',
#  'Firmen Kunst-und-Kunsthandwerk Malerei-und-Bildhauerei Portraet-Malerei',
#  'Verzeichnis Einkaufen-Sparen Freizeit-Hobby Basteln-Handarbeit Sticken',
#  'Top World Deutsch Online-Shops Publikationen Buecher Antiquarisch',
#  'Firmen Sport Gluecksspiele',
#  'Top World Deutsch Online-Shops Gesundheit Krankheiten und Beschwerden Schlafstoerungen',
#  'Firmen Kunst-und-Kunsthandwerk Kunsthandwerk Keramik Zeitschriften-und-Online-Magazine',
#  'Verzeichnis Einkaufen-Sparen Kleinanzeigen Auto Bundesweit',
#  'Firmen Gesundheit Augenoptik Sport-und-Sonnenbrillen',
#  'Firmen Gesundheit Krankheiten-und-Beschwerden Allergien',
#  'Firmen Essen-und-Trinken Pizzalieferservice Portale-und-Linksammlungen',
#  'Firmen Unterhaltung Video',
#  'Firmen Buecher Buchhandel Kochbuecher Titel',
#  'Verzeichnis Einkaufen-Sparen Sportartikel Angeln',
#  'World Deutsch Online-Shops Fahrzeuge Autos Kleinanzeigen',
#  'World Deutsch Online-Shops Computer Hardware',
#  'Top World Deutsch Online-Shops Freizeit Modellbau Ferngesteuert',
#  'Top World Deutsch Online-Shops Computer Hardware Taschenrechner',
#  'Top World Deutsch Online-Shops Haus und Garten Moebel Freizeit und Garten Teak',
#  'Top World Deutsch Online-Shops Haustiere Terraristik',
#  'Firmen Kraftfahrzeuge Ersatzteile-und-Zubehoer Elektronik Alarmanlagen',
#  'Top World Deutsch Online-Shops Essen und Trinken Getraenke Kaffee und Tee',
#  'Firmen Kraftfahrzeuge Motorraeder Motorraeder-fuer-Behinderte',
#  'World Deutsch Online-Shops Kunsthandwerk Glas',
#  'Firmen Gesundheit Bildung-und-Ausbildung Medizin',
#  'Firmen Kunst-und-Kunsthandwerk Kunsthandwerk Porzellan-und-Keramik',
#  'World Deutsch Online-Shops Freizeit Modellbau Flugzeuge-und-Helikopter',
#  'World Deutsch Online-Shops Bekleidung Kundenspezifisch Stickerei',
#  'Firmen Kunst-und-Kunsthandwerk Kunsthandwerk Porzellan-und-Keramik Portale-und-Linksammlungen',
#  'Top World Deutsch Online-Shops Gesundheit Alternative Medizin',
#  'Firmen Sport Motorsport',
#  'Top World Deutsch Online-Shops Publikationen Buecher Kunst',
#  'Verzeichnis Einkaufen-Sparen Buecher Musik-Filme Buchshops Fachbuecher Religion',
#  'Verzeichnis Einkaufen-Sparen Mode-Accessoires Accessoires',
#  'Firmen Buecher Buchhandel Philosophie',
#  'Top World Deutsch Online-Shops Fotografie',
#  'Top World Deutsch Online-Shops Musik Instrumente',
#  'World Deutsch Online-Shops Elektronik Multimedia Audio Tragbare-digitale-Geraete',
#  'Firmen Tabakwaren Zigarren',
#  'Firmen Kraftfahrzeuge Motorraeder Renn-und-Sicherheitstraining',
#  'Verzeichnis Einkaufen-Sparen Nahrungs-Genussmittel Getraenke Spirituosen',
#  'Top World Deutsch Online-Shops Schreibwaren und Buerobedarf Materialien und Zubehoer',
#  'Firmen Computer Hardware P Cs',
#  'Top World Deutsch Online-Shops Freizeit Outdoor und Camping Zelte',
#  'Verzeichnis Einkaufen-Sparen Nahrungs-Genussmittel Getraenke Wein Sekt-Champagner Deutschland Kleinstanbaugebiete',
#  'Firmen Waffen Schusswaffen',
#  'World Deutsch Online-Shops Publikationen Buecher Fremdsprachige-Literatur Englisch',
#  'Verzeichnis Einkaufen-Sparen Buecher Musik-Filme Musik C Ds Oldies',
#  'Firmen Kunst-und-Kunsthandwerk Malerei-und-Bildhauerei Airbrush',
#  'Firmen Kunst-und-Kunsthandwerk Kunstdesign',
#  'Top World Deutsch Online-Shops Bekleidung Berufsbekleidung',
#  'World Deutsch Online-Shops Fahrzeuge Tretroller',
#  'Firmen Buecher Buchhandel Computer Buchtitel Internet',
#  'World Deutsch Online-Shops Schoenheit Haare Pflege',
#  'Firmen Kraftfahrzeuge Fahrzeuge-fuer-Behinderte',
#  'World Deutsch Online-Shops Bekleidung Trachten Asiatisch',
#  'World Deutsch Online-Shops Essen-und-Trinken Getraenke Spirituosen Absinth',
#  'Firmen Buecher Buchhandel Buchtitel',
#  'World Deutsch Online-Shops Sport Flugsport',
#  'World Deutsch Online-Shops Kunst Fotografien',
#  'World Deutsch Online-Shops Freizeit Drogen Hanf',
#  'Top World Deutsch Online-Shops Fahrzeuge Fahrraeder Anhaenger',
#  'Top World Deutsch Online-Shops Freizeit Modellbau Eisenbahnen Zubehoer',
#  'Firmen Kraftfahrzeuge Motorraeder Ersatzteile-und-Zubehoer Harley-Davidson',
#  'Firmen Gesundheit Psyche',
#  'Top World Deutsch Online-Shops Haus und Garten Aussenanlagen Bewaesserungstechnik',
#  'Top World Deutsch Online-Shops Publikationen Buecher Fremdsprachige Literatur Polnisch',
#  'World Deutsch Online-Shops Publikationen Comics',
#  'Firmen Gesundheit Alternativmedizin Produkte',
#  'Top World Deutsch Online-Shops Haus und Garten Haushaltsbedarf Toepfe und Pfannen',
#  'Firmen Spiele-und-Spielzeug Gesellschaftsspiele',
#  'Firmen Computer Software Betriebssysteme',
#  'World Deutsch Online-Shops Bekleidung Schuhe Sport',
#  'Firmen Computer Software Systeme-und-Dienstprogramme',
#  'World Deutsch Online-Shops Haus-und-Garten Haushaltsbedarf Haushaltsgeraete Staubsauger',
#  'Firmen Kunst-und-Kunsthandwerk Kunstdesign Textilien Kuenstler',
#  'Firmen Buecher Buchhandel Genres Humor',
#  'World Deutsch Online-Shops Essen-und-Trinken Regionale-Spezialitaeten Europaeisch Franzoesisch',
#  'World Deutsch Online-Shops Spielwaren Spiele',
#  'Firmen Religion Schamanismus',
#  'World Deutsch Online-Shops Fahrzeuge Autos Verzeichnisse-und-Portale',
#  'Verzeichnis Einkaufen-Sparen Kleinanzeigen Anzeigenmaerkte Ungarn',
#  'Verzeichnis Einkaufen-Sparen Sonstiges',
#  'World Deutsch Online-Shops Essen-und-Trinken Getraenke Wein Europaeisch Deutsch Nahe',
#  'Top World Deutsch Online-Shops Freizeit Waffen Schusswaffen',
#  'Top World Deutsch Online-Shops Schmuck Amulette und Talismane',
#  'World Deutsch Online-Shops Essen-und-Trinken Getraenke Wein Europaeisch Deutsch Rheingau',
#  'World Deutsch Online-Shops Computer Hardware Komplettsysteme',
#  'Firmen Haus-und-Garten Moebel Massivholzmoebel',
#  'Verzeichnis Einkaufen-Sparen Haus-Garten Haustierbedarf Haustierbedarf-allgemein',
#  'Verzeichnis Einkaufen-Sparen Nahrungs-Genussmittel Home-Service Pizza',
#  'Top World Deutsch Online-Shops Publikationen Buecher Allgemeines Sortiment Deutschland',
#  'World Deutsch Online-Shops Bekleidung Nischenprodukte Tanz Ballett',
#  'Top World Deutsch Online-Shops Haus und Garten Dekorationsartikel Kerzen Handgefertigt',
#  'World Deutsch Online-Shops Computer Hardware Tuning',
#  'World Deutsch Online-Shops Haus-und-Garten Dekorationsartikel Maritimes',
#  'Top World Deutsch Online-Shops Freizeit Basteln Papier',
#  'Top World Deutsch Online-Shops Geschenke Papierwaren',
#  'Firmen Kraftfahrzeuge Auto-Tuning Zender-Firmengruppe',
#  'Firmen Essen-und-Trinken Backwaren Stollen',
#  'World Deutsch Online-Shops Sport Ballsport Bekleidung',
#  'Firmen Buecher Buchhandel Antiquariate',
#  'Top World Deutsch Online-Shops Kunst Galerien',
#  'Firmen Haus-und-Garten Weihnachten Nikolausvermittlung',
#  'World Deutsch Online-Shops Unterhaltung Bild-und-Tontrae

#  'Verzeichnis Einkaufen-Sparen Buecher Musik-Filme Buchshops Fachbuecher Lernen',
#  'Top World Deutsch Online-Shops Haustiere Liebhaberartikel Schmuck',
#  'World Deutsch Online-Shops Auktionen Schweiz',
#  'World Deutsch Online-Shops Haus-und-Garten Packmaterial',
#  'World Deutsch Online-Shops Freizeit Natur-und-Wissenschaft Geowissenschaften',
#  'World Deutsch Online-Shops Freizeit Lebendige-Geschichte Mittelalterlich',
#  'Top World Deutsch Online-Shops Unterhaltung Bild und Tontraeger Musik Genres Meditationsmusik',
#  'Firmen Musik Labels Bertelsmann-Music-Group-Entertainment-BMG',
#  'Top World Deutsch Online-Shops Haustiere Liebhaberartikel Fotografie Pferde',
#  'World Deutsch Online-Shops Allgemeines-Sortiment',
#  'Top World Deutsch Online-Shops Bekleidung Schuhe Komfort Hausschuhe',
#  'Top World Deutsch Online-Shops Kunst Auktionen',
#  'Top World Deutsch Online-Shops Unterhaltung Film und Fernsehen Poster und Plakate',
#  'Top World Deutsch Online-Shops Kunst Malerei Maler',
#  'Firmen Gesundheit Ernaehrung Nahrungsergaenzungsmittel Weizengras',
#  'Firmen Bekleidung Pullover',
#  'World Deutsch Online-Shops Freizeit Partys Schminke',
#  'World Deutsch Online-Shops Elektronik Telekommunikation Handys',
#  'Top World Deutsch Online-Shops Elektronik Multimedia Digitalkameras und Camcorder',
#  'Verzeichnis Einkaufen-Sparen Sportartikel Squash',
#  'subclass of',
#  'Top World Deutsch Online-Shops Haus und Garten Reinigung',
#  'Top World Deutsch Online-Shops Freizeit Modellbau Eisenbahnen Spurweite H0',
#  'Top World Deutsch Online-Shops Elektronik Telekommunikation Handys Zubehoer Oberschalen',
#  'World Deutsch Online-Shops Auktionen',
#  'World Deutsch Online-Shops Unterhaltung Bild-und-Tontraeger Musik Secondhand',
#  'Firmen Gesundheit Privatkliniken',
#  'World Deutsch Online-Shops Haus-und-Garten Dekorationsartikel Uhren',
#  'Top World Deutsch Online-Shops Freizeit Waffen',
#  'Verzeichnis Einkaufen-Sparen Gesundheit-Kosmetik Medizinische-Produkte',
#  'Top World Deutsch Online-Shops Freizeit Modellbau Flugmodelle Helikopter',
#  'Verzeichnis Einkaufen-Sparen Sportartikel Tischfussball',
#  'Firmen Computer Software Office-Programme',
#  'Top World Deutsch Online-Shops Freizeit Natur und Wissenschaft Astronomie Sternnamen',
# ...
#  'Firmen Schmuck Intimschmuck',
#  'Verzeichnis Einkaufen-Sparen Haus-Garten Umzugsbedarf',
#  'World Deutsch Online-Shops Publikationen Buecher Religion-und-Spiritualitaet Buddhismus',
#  'Firmen Gesundheit Behandlungen-und-Untersuchungen Hyperbarmedizin',
#  'Verzeichnis Einkaufen-Sparen Freizeit-Hobby Sammeln Muenzen',
#  'Firmen Kraftfahrzeuge Auto-Tuning Portale-und-Linksammlungen',
#  'Top World Deutsch Online-Shops Fahrzeuge Motorraeder Trikes',
#  'World Deutsch Online-Shops Freizeit Handarbeiten Maschinen-und-Zubehoer',
#  'Firmen Essen-und-Trinken Milchprodukte Portale-und-Linksammlungen',
#  'World Deutsch Online-Shops Werkzeug',
#  'Verzeichnis Einkaufen-Sparen Nahrungs-Genussmittel Getraenke Wein Sekt-Champagner Deutschland Saar',
#  'World Deutsch Online-Shops Essen-und-Trinken Fleisch-und-Wurst',
#  'Top World Deutsch Online-Shops Publikationen Buecher Religion und Spiritualitaet Buddhismus',
#  'Firmen Gesundheit Alternativmedizin Atemarbeit Bildung-und-Ausbildung',
#  'Firmen Computer Hardware Notebooks',
#  'World Deutsch Online-Shops Fahrzeuge Fahrraeder Zubehoer',
#  'World Deutsch Online-Shops Spielwaren',
#  'Verzeichnis Einkaufen-Sparen Mode-Accessoires Kleidung Maenner',
#  'Firmen Antiquitaeten-und-Sammeln Antiquitaeten',
#  'Firmen Buecher Buchhandel Portale-und-Linksammlungen',
#  'Firmen Sport Golf',
#  'Firmen Gesundheit Pflege Senioren-und-Pflegeheime Traeger',
#  'World Deutsch Online-Shops Gesundheit Sehen',
#  'Top World Deutsch Online-Shops Sammelbare Objekte Zahlungsmittel und Wertpapiere',
#  'World Deutsch Online-Shops Gesundheit Behinderte',
#  'Firmen Sport Veranstaltungsorganisation',
#  'Firmen Buecher Hoerspiele-und-Tonbuecher',
#  'Firmen Kraftfahrzeuge Fahrschulen',
#  'Top World Deutsch Online-Shops Sport Wassersport Bootszubehoer',
#  'Verzeichnis Einkaufen-Sparen Kleinanzeigen Anzeigenmaerkte Schweiz',
#  'World Deutsch Online-Shops Schmuck Uhren',
#  'World Deutsch Online-Shops Bekleidung Sondergroessen Herren',
#  'Firmen Sport Pferdesport Ausruestung Hufpflege',
#  'Firmen Bekleidung Gap-Inc',
#  'World Deutsch Online-Shops Freizeit Natur-und-Wissenschaft Astronomie',
#  'Top World Deutsch Online-Shops Fahrzeuge Autos Ersatzteile und Zubehoer Marderabwehr',
#  'Top World Deutsch Online-Shops Kunst Kuenstler',
#  'Top World Deutsch Online-Shops Schmuck Edel und Schmucksteine Bernstein',
#  'Verzeichnis Einkaufen-Sparen Sportartikel Tischtennis',
#  'Firmen Schmuck',
#  'Verzeichnis Einkaufen-Sparen Nahrungs-Genussmittel Getraenke Wein Sekt-Champagner Deutschland Saar',
#  'Verzeichnis Einkaufen-Sparen Sportartikel Wassersport',
#  'Firmen Sport Skifahren',
#  'Verzeichnis Einkaufen-Sparen Nahrungs-Genussmittel Getraenke Wein Sekt-Champagner Accessoires',
#  'Verzeichnis Einkaufen-Sparen Nahrungs-Genussmittel Tiefkuehlkost',
#  'Top World Deutsch Online-Shops Auktionen Verzeichnisse und Portale',
#  'World Deutsch Online-Shops Fotografie',
#  'Top World Deutsch Online-Shops Musik Instrumente Ethnisch',
#  'Top World Deutsch Online-Shops Publikationen Buecher Allgemeines Sortiment',
#  'Verzeichnis Einkaufen-Sparen Unterhaltungs-Kommunikationselektronik Unterhaltungselektronik Zubehoer',
#  'World Deutsch Online-Shops Haustiere Futter',
#  'Firmen Gesundheit Reisen',
#  'Top World Deutsch Online-Shops Freizeit Basteln Kerzen',
#  'World Deutsch Online-Shops Essen-und-Trinken Suesswaren',
#  'World Deutsch Online-Shops Schreibwaren-und-Buerobedarf Materialien-und-Zubehoer Stempel',
#  'Firmen Gesundheit Alternativmedizin Feldenkrais',
#  'Firmen Bekleidung Accessoires',
#  'Top World Deutsch Online-Shops Freizeit Partys Schminke',
#  'Verzeichnis Einkaufen-Sparen Unterhaltungs-Kommunikationselektronik Computer Komplettsysteme',
#  'World Deutsch Online-Shops Bekleidung Schuhe Komfort',
#  'World Deutsch Online-Shops Freizeit Outdoor-und-Camping Jagd',
#  'Top World Deutsch Online-Shops Sport Pferdesport Reitbedarf Westernreiten',
#  'Top World Deutsch Online-Shops Bekleidung Schuhe Sport',
#  'Verzeichnis Einkaufen-Sparen Nahrungs-Genussmittel Getraenke Wein Sekt-Champagner Deutschland Hohenlohe',
#  'World Deutsch Online-Shops Kunst Reproduktionen Handgemalt',
#  'World Deutsch Online-Shops Musik Noten Blasmusik',
#  'World Deutsch Online-Shops Essen-und-Trinken Getraenke Wein Suedafrikanisch',
#  'World Deutsch Online-Shops Essen-und-Trinken Getraenke Kaffee-und-Tee',
#  'Top World Deutsch Online-Shops Kunst Material und Zubehoer Rahmen',
#  'Top World Deutsch Online-Shops Freizeit Familienforschung',
#  'World Deutsch Online-Shops Kunst Fotografien Natur',
#  'Firmen Gesundheit Behandlungen-und-Untersuchungen',
#  'Firmen Sport Radsport Mountain-Biking Komponenten',
#  'Firmen Haus-und-Garten Garten-und-Pflanzen Blumen Rosen',
#  'World Deutsch Online-Shops Freizeit Handarbeiten Naehen',
#  'Firmen Bekleidung Damenbekleidung Bademoden',
#  'Firmen Buecher Buchhandel Buecherde',
#  'Top World Deutsch Online-Shops Publikationen Buecher Biografien',
#  'World Deutsch Online-Shops Essen-und-Trinken Regionale-Spezialitaeten Europaeisch',
#  'World Deutsch Online-Shops Schoenheit Maenner',
#  'World Deutsch Online-Shops Haus-und-Garten Gartenmaerkte',
#  'Verzeichnis Einkaufen-Sparen Kleinanzeigen Anzeigenmaerkte Regional Hessen',
#  'Firmen Koerperpflege Haare Portale-und-Linksammlungen',
#  'World Deutsch Online-Shops Essen-und-Trinken Getraenke Wein Europaeisch Schweizer',
#  'Top World Deutsch Online-Shops Fahrzeuge Autos Ersatzteile und Zubehoer Aufkleber und Folien',
#  'Top World Deutsch Online-Shops Regionale Spezialitaeten Asiatisch Chinesisch',
#  'Verzeichnis Einkaufen-Sparen Nahrungs-Genussmittel Getraenke Bier',
#  'Verzeichnis Einkaufen-Sparen Buecher Musik-Filme Musik C Ds Klassik',
#  'Firmen Unterhaltung Fanartikel Fernsehen',
#  'Top World Deutsch Online-Shops Kunst Fotografien',
#  'Top World Deutsch Online-Shops Bekleidung Naturtextilien Wolle',
#  'Verzeichnis Einkaufen-Sparen Buecher Musik-Filme Musik',
#  'Firmen Essen-und-Trinken Milchprodukte',
#  'Firmen Gesundheit Alternativmedizin Biofeedback',
#  'Top World Deutsch Online-Shops Publikationen Buecher Schueler und Lernhilfen',
#  'Firmen Gesundheit Ernaehrung Nahrungsergaenzungsmittel',
#  'Firmen Buecher Buchhandel Sport-und-Freizeit Eisenbahnen',
#  'Top World Deutsch Online-Shops Publikationen Buecher Antiquarisch Spezialisierte',
#  'Top World Deutsch Online-Shops Regionale Spezialitaeten Ozeanisch Australisch',
#  'Firmen Kraftfahrzeuge Auto-Tuning Elektronik Tachojustierungen',
#  'World Deutsch Online-Shops Essen-und-Trinken Getraenke Wein Europaeisch Italienisch',
#  'Firmen Kraftfahrzeuge Elektrofahrzeuge',
#  'World Deutsch Online-Shops Spielwaren Stofftiere',
#  'World Deutsch Online-Shops Kunst Kuenstler',
#  'Firmen Unterhaltung Eintrittskarten',
#  'World Deutsch Online-Shops Essen-und-Trinken Gewuerze-und-Kraeuter',
#  'Firmen Computer Computerkurse Bildungszentrum-fuer-informationsverarbeitende-Berufe-bib',
#  'Top World Deutsch Online-Shops Essen und Trinken Biokost',
#  'World Deutsch Online-Shops Fahrzeuge Autos Ersatzteile-und-Zubehoer Aufkleber-und-Folien',
#  'Firmen Essen-und-Trinken Gaststaetten-und-Restaurants Portale-und-Linksammlungen',
#  'World Deutsch Online-Shops Freizeit Modellbau Fahrzeuge',
#  'Top World Deutsch Online-Shops Haus und Garten Heimtextilien',
#  'Firmen Spiele-und-Spielzeug Computerspiele',
#  'Verzeichnis Einkaufen-Sparen Gesundheit-Kosmetik Medizinische-Produkte Zahnpflege',
#  'Top World Deutsch Online-Shops Essen und Trinken Gewuerze und Kraeuter',
#  'Top World Deutsch Online-Shops Haustiere Liebhaberartikel Malerei',
#  'Top World Deutsch Online-Shops Sport Ballsport',
#  'Top World Deutsch Online-Shops Haustiere Hunde und Katzen Hunde Futter',
#  'Top World Deutsch Online-Shops Essen und Trinken Getraenke Wein Europaeisch Deutsch Franken',
#  'Top World Deutsch Online-Shops Unterhaltung Bild und Tontraeger Musik Secondhand',
#  'Top World Deutsch Online-Shops Spielwaren Holz',
#  'World Deutsch Online-Shops Essen-und-Trinken Getraenke Wein Europaeisch Spanisch',
#  'Firmen Haus-und-Garten Garten-und-Pflanzen Garten-und-Landschaftsbau',
#  'Firmen Kraftfahrzeuge Personenbefoerderung Mitfahrzentralen',
#  'Top World Deutsch Online-Shops Nischenprodukte Transgender',
#  'World Deutsch Online-Shops Haus-und-Garten Bauen-und-Renovieren Baustoffe-und-Bauelemente',
#  'Firmen Haus-und-Garten Moebel Moebelhaeuser Moebel-Rieger',
#  'Top World Deutsch Online-Shops Haus und Garten Moebel Schlafzimmer',
#  'Top World Deutsch Online-Shops Haus und Garten Aussenanlagen Zaeune und Tore',
#  'Verzeichnis Einkaufen-Sparen Kleinanzeigen Anzeigenmaerkte Regional Brandenburg',
#  'World Deutsch Online-Shops Publikationen Buecher Fahrzeuge',
#  'Firmen Musik Software Haendler',
#  'Firmen Haus-und-Garten Bad',
#  'Firmen Gesundheit Bildung-und-Ausbildung Software',
#  'Firmen Koerperpflege L Oreal',
#  'World Deutsch Online-Shops Essen-und-Trinken Regionale-Spezialitaeten Europaeisch Griechisch',
#  'World Deutsch Online-Shops Verzeichnisse-und-Portale',
#  'Firmen Spiele-und-Spielzeug Modellbau Eisenbahn',
#  'World Deutsch Online-Shops Freizeit Artistik',
#  'Firmen Gesundheit Alternativmedizin Shiatsu',
#  'Top World Deutsch Online-Shops Haus und Garten Packmaterial',
#  'Firmen Bekleidung Streetwear',
#  'World Deutsch Online-Shops Computer Hardware Peripherie Drucker Verbrauchsmaterial',
#  'Firmen Gesundheit Pflege Senioren-und-Pflegeheime Portale-und-Linksammlungen',
#  'Firmen Outdoors Boote-und-Schiffe',
#  'Firmen Kunst-und-Kunsthandwerk Theater Private-Schauspielschulen',
#  'Firmen Antiquitaeten-und-Sammeln Karten',
#  'Top World Deutsch Online-Shops Elektronik Multimedia Heimkino',
#  'Verzeichnis Einkaufen-Sparen Sportartikel Camping-Outdoor',
#  'Firmen Gesundheit Privatkliniken Sucht-und-Entzug',
#  'Top World Deutsch Online-Shops Hochzeit',
#  'Top World Deutsch Online-Shops Elektronik Multimedia',
#  'Firmen Outdoors Boote-und-Schiffe Yacht-Charter',
#  'World Deutsch Online-Shops Unterhaltung Film-und-Fernsehen',
#  'Verzeichnis Einkaufen-Sparen Freizeit-Hobby Sammeln Telefonkarten',
#  'Firmen Kunst-und-Kunsthandwerk Kunsthandwerk Seidenmalerei',
#  'Verzeichnis Einkaufen-Sparen Freizeit-Hobby Feste-feiern',
#  'World Deutsch Online-Shops Spielwaren Lernspiele',
#  'World Deutsch Online-Shops Essen-und-Trinken Vegetarisch',
#  'Top World Deutsch Online-Shops Bekleidung Kinder',
#  'Firmen Computer Software Betriebssysteme Linux E-Commerce',
#  'World Deutsch Online-Shops Publikationen Buecher Schueler-und-Lernhilfen',
#  'World Deutsch Online-Shops Essen-und-Trinken Tiefkuehlkost',
#  'Firmen Antiquitaeten-und-Sammeln Spielzeug Sammlerpuppen',
#  'World Deutsch Online-Shops Freizeit Outdoor-und-Camping Fahrzeuge',
#  'Verzeichnis Einkaufen-Sparen Sportartikel Fussball Fan-Artikel',
#  'Top World Deutsch Online-Shops Kinder',
#  'Verzeichnis Einkaufen-Sparen Buecher Musik-Filme Buchshops Kalendershops',
#  'Verzeichnis Einkaufen-Sparen Blumen-Geschenke Kunsthandwerk',
#  'Verzeichnis Einkaufen-Sparen Buecher Musik-Filme Buchshops Fachbuecher Kunst',
#  'World Deutsch Online-Shops Freizeit Handarbeiten Naehen',
#  'Top World Deutsch Online-Shops Essen und Trinken Vegetarisch',
#  'Firmen Antiquitaeten-und-Sammeln Fanartikel',
#  'Firmen Haus-und-Garten Schwimmbaeder-und-Saunas',
#  'Top World Deutsch Online-Shops Auktionen Ebay',
#  'Firmen Musik Unterricht Musikschulen',
#  'Top World Deutsch Online-Shops Sport Wassersport Surfen',
#  'Firmen Musik Instrumente',
#  'Top World Deutsch Online-Shops Freizeit Outdoor und Camping Optik',
#  'Firmen Gesundheit Alternativmedizin Shiatsu Bildung-und-Ausbildung',
#  'Top World Deutsch Online-Shops Bekleidung Sondergroessen Damen',
#  'World Deutsch Online-Shops Haus-und-Garten',
#  'Firmen Gesundheit Fortpflanzung Verhuetung-und-Schwangerschaft Kondome',
#  'Top World Deutsch Online-Shops Freizeit Basteln Malen',
#  'Firmen Kraftfahrzeuge Ersatzteile-und-Zubehoer Kraftstoffersparnis',
#  'World Deutsch Online-Shops Publikationen Buecher Fremdsprachige-Literatur',
#  'Top World Deutsch Online-Shops Nischenprodukte Gothic',
#  'Top World Deutsch Online-Shops Schoenheit Hautpflege Gesichtspflege',
#  'Top World Deutsch Online-Shops Freizeit Modellbau Schiffe',
#  'Firmen Kunst-und-Kunsthandwerk Zeichentrickfilme-und-Animationskunst Konferenzen-und-Messen',
#  'Firmen Kraftfahrzeuge Ersatzteile-und-Zubehoer Gebraucht',
#  'Firmen Buecher Buchhandel Naturwissenschaft-und-Technik Tiere Buchtitel',
#  'Top World Deutsch Online-Shops Sport Paintball',
#  'World Deutsch Online-Shops Fahrzeuge Autos EU-Importfahrzeuge',
#  'Firmen Musik Geraete-und-Zubehoer Juke-Box',
#  'World Deutsch Online-Shops Publikationen Buecher Fremdsprachige-Literatur Ungarisch',
#  'Verzeichnis Einkaufen-Sparen Einkaufsfuehrer',
#  'Top World Deutsch Online-Shops Essen und Trinken Getraenke Wein Europaeisch Deutsch Mosel-Saar-Ruwer',
#  'World Deutsch Online-Shops Sport Flugsport Accessoires',
#  'Firmen Gesundheit Alternativmedizin Qigong',
#  'World Deutsch Online-Shops Essen-und-Trinken Tiefkuehlkost',
#  'World Deutsch Online-Shops Haus-und-Garten Haushaltsbedarf',
#  'World Deutsch Online-Shops Elektronik Telekommunikation Funktechnik',
#  'Top World Deutsch Online-Shops Freizeit Partys Ballons',
#  'Firmen Musik C Ds Schallplatten-und-Kassetten Klang-Restaurierung',
#  'Firmen Unterhaltung Video Heimvideo-Nachbearbeitung',
#  'Top World Deutsch Online-Shops Freizeit Modellbau Fahrzeuge Autos Slotcars',
#  'World Deutsch Online-Shops Fahrzeuge Motorraeder Pflegemittel',
#  'Firmen Sport Eishockey',
#  'Firmen Buecher Buchhandel Libro',
#  'Firmen Essen-und-Trinken Regionale-Spezialitaeten',
#  'Top World Deutsch Online-Shops Essen und Trinken Tiefkuehlkost',
#  'Verzeichnis Einkaufen-Sparen Nahrungs-Genussmittel Getraenke Wein Sekt-Champagner Champagner',
#  'World Deutsch Online-Shops Kinder Schule',
#  'World Deutsch Online-Shops Essen-und-Trinken Essig-und-Oel',
#  'Firmen Kraftfahrzeuge Motorraeder Ersatzteile-und-Zubehoer Bekleidung-und-Helme',
#  'World Deutsch Online-Shops Essen-und-Trinken Regionale-Spezialitaeten Europaeisch Oesterreichisch',
#  'Firmen Sport Fitness Fitness-Studios',
#  'World Deutsch Online-Shops Kunst',
#  'Firmen Kunst-und-Kunsthandwerk Koerperkunst Body-Painting',
#  'Top World Deutsch Online-Shops Kunsthandwerk Regionale Spezialitaeten Europaeisch Deutsch Saechsisch',
#  'Top World Deutsch Online-Shops Bekleidung Naturtextilien Wolle Kaschmir und Pashmina',
#  'Firmen Haus-und-Garten Garten-und-Pflanzen Gartenhaeuser-und-Gewaechshaeuser',
#  'Verzeichnis Einkaufen-Sparen Nahrungs-Genussmittel Getraenke Wein Sekt-Champagner Sekt',
#  'Top World Deutsch Online-Shops Bekleidung Nischenprodukte',
#  'Top World Deutsch Online-Shops Schreibwaren und Buerobedarf Materialien und Zubehoer Stempel',
#  'Verzeichnis Einkaufen-Sparen Unterhaltungs-Kommunikationselektronik Fernsehgeraete',
#  'Verzeichnis Einkaufen-Sparen Sportartikel Federfussball',
#  'Firmen Gesundheit Bildung-und-Ausbildung Medizin Pruefungsvorbereitung',
#  'World Deutsch Online-Shops Sport Pferdesport Haltung-und-Pflege Futter',
#  'Firmen Gesundheit Pflege Senioren-und-Pflegeheime',
#  'Firmen Bekleidung Damenbekleidung Brautmoden Secondhand',
#  'Firmen Outdoors Boote-und-Schiffe Segeln Ausbildung',
#  'World Deutsch Online-Shops Elektronik Telekommunikation Handys Logos-und-Klingeltoene',
#  'Verzeichnis Einkaufen-Sparen Nahrungs-Genussmittel',
#  'Top World Deutsch Online-Shops Bekleidung Kostueme',
#  'Top World Deutsch Online-Shops Bekleidung Nischenprodukte Tanz Schuhe',
#  'Verzeichnis Einkaufen-Sparen Sportartikel Tauchen',
#  'World Deutsch Online-Shops Essen-und-Trinken Regionale-Spezialitaeten',
#  'Top World Deutsch Online-Shops Essen und Trinken Getraenke Wein Geschenke',
#  'Verzeichnis Einkaufen-Sparen Nahrungs-Genussmittel Getraenke Wein Sekt-Champagner Kroatien',
#  'Firmen Haus-und-Garten Eisenwaren Elektrowerkzeuge',
#  'Top World Deutsch Online-Shops Schmuck Hochzeit',
#  'Verzeichnis Einkaufen-Sparen Freizeit-Hobby Basteln-Handarbeit Stofftiere',
#  'Top World Deutsch Online-Shops Essen und Trinken Getraenke Wein Europaeisch Deutsch Rheingau',
#  'Firmen Buecher Buchhandel Unterhaltung',
#  'World Deutsch Online-Shops Essen-und-Trinken Getraenke Cocktails',
#  'World Deutsch Online-Shops Computer Hardware Komponenten Speicher',
#  ...]

# %%
def path_to_root(elem, ont_mappings, path_store, i):
    if elem in path_store:
        return path_store[elem]
    if elem not in ont_mappings or not ont_mappings[elem]:
        path_store[elem] = []
        return []
    output = flatten([[e] + path_to_root(e, ont_mappings, path_store, i+1) for e in ont_mappings[elem]])
    path_store[elem] = output
    return output

def get_one_hop_neighbours(ont, K=1):

    ont_obj = Ontology(ont)
    triples = ont_obj.get_triples(rootpath=True)
#     print (triples)
    entities = [(a,b) for (a,b,c) in triples]
#     neighbours_dict = {ont_obj.mapping_dict.get(elem, elem): [ont_obj.mapping_dict.get(elem, elem)]
#                        for elem in list(set(flatten(entities)))}
#     for e1, e2 in entities:
#         neighbours_dict[ont_obj.mapping_dict.get(e1, e1)].append(ont_obj.mapping_dict.get(e2, e2))
#         neighbours_dict[ont_obj.mapping_dict.get(e2, e2)].append(ont_obj.mapping_dict.get(e1, e1))
    
#     rootpath_dict = {elem: list(OrderedSet(ont_obj.parents_dict[elem])) for elem in ont_obj.parents_dict}
    
#     rootpath_dict_new = {}
#     path_store = {}
#     for elem in rootpath_dict:
#         rootpath_dict_new[elem] = path_to_root(elem, rootpath_dict, path_store, 0)
#     rootpath_dict_new = {ont_obj.mapping_dict.get(elem, elem): 
#                      [ont_obj.mapping_dict.get(e, e) for e in rootpath_dict[elem]]
#                     for elem in rootpath_dict_new}
#     ont = ont.split("/")[-1].rsplit(".",1)[0].replace(".", "_").lower()
#     print (ont)
#     for entity in neighbours_dict:
#         if entity in rootpath_dict_new and len(rootpath_dict_new[entity]) > 0:
#             neighbours_dict[entity].extend(rootpath_dict_new[entity])
#         else:
#             continue
    
    neighbours_dict = {elem: [elem] for elem in list(set(flatten(entities)))}
    for e1, e2 in entities:
        neighbours_dict[e1].append(e2)
        neighbours_dict[e2].append(e1)
    
    rootpath_dict = {elem: list(OrderedSet(ont_obj.parents_dict[elem])) for elem in ont_obj.parents_dict}
    
    path_store = {}
    for elem in rootpath_dict:
        rootpath_dict[elem] = path_to_root(elem, rootpath_dict, path_store, 0)

#     print (ont)
    ont = ont.split("/")[-1].rsplit(".",1)[0].replace(".", "_").lower()
    print (ont)
    for entity in neighbours_dict:
        if entity in rootpath_dict and len(rootpath_dict[entity]) > 0:
            neighbours_dict[entity].extend(rootpath_dict[entity])
        else:
            continue
#     prop_triples = ont_obj.get_triples(subclass_of=False)
#     neighbours_dict_props = {c: [c] for a,b,c in prop_triples}
#     for e1, e2, p in prop_triples:
#         neighbours_dict_props[p].extend([e1, e2])

    #neighbours_dict = {**neighbours_dict, **neighbours_dict_props}
    
    # for elem in ont_obj.get_entities() + ont_obj.get_object_properties() + ont_obj.get_data_properties():
    #     if elem not in neighbours_dict:
    #         neighbours_dict[elem] = [elem]

    neighbours_dict = {el: neighbours_dict[el][:1] + sorted(list(set(neighbours_dict[el][1:])))
                       for el in neighbours_dict}
#     neighbours_dict = {el: neighbours_dict[el][:23] for el in neighbours_dict if len( neighbours_dict[el]) > 2}
#     ont = ont.split("/")[-1].split(".")[0]
    neighbours_dict = {ont + "#" + el: [ont + "#" + e for e in neighbours_dict[el]] for el in neighbours_dict}
    return neighbours_dict

neighbours_dicts = {ont.split("/")[-1].rsplit(".",1)[0].replace(".", "_").lower(): get_one_hop_neighbours(ont) for ont in list(set(flatten(ontologies_in_alignment)))}
max_neighbours = np.max(flatten([[len(el[e]) for e in el] for el in neighbours_dicts.values()]))
neighbours_lens = {ont: {key: len(neighbours_dicts[ont][key]) for key in neighbours_dicts[ont]}
                   for ont in neighbours_dicts}
neighbours_dicts = {ont: {key: neighbours_dicts[ont][key] + ["<UNK>" for i in range(max_neighbours -len(neighbours_dicts[ont][key]))]
              for key in neighbours_dicts[ont]} for ont in neighbours_dicts}

data_items = data.items()
data_shuffled_t = [elem for elem in data_items if elem[1]]
data_shuffled_f = [elem for elem in data_items if not elem[1]]

false_indices = np.random.permutation(len(data_shuffled_f))
# indices = np.random.permutation(len(data_shuffled_t) + len(data_shuffled_f[:130000-len(data_shuffled_t)]))

data_shuffled = data_shuffled_t + data_shuffled_f

# indices = np.random.arange(len(data_shuffled))

data = OrderedDict(list(np.array(data_shuffled)[indices]))

ontologies_in_alignment_rev = [[el.split("/")[-1].rsplit(".",1)[0].replace(".", "_").lower() for el in ont] for ont in ontologies_in_alignment]
f = open("data_german_dataset_phrase.pkl", "wb")
pickle.dump([data, emb_indexer, emb_indexer_inv, emb_vals, reference_alignments, neighbours_dicts, ontologies_in_alignment_rev], f)
# Out:
# dmoz
# web
# google
# yahoo_small
# google_freizeit
# google_lebensmittel
# dmoz_freizeit
# web_lebensmittel

# %%
data, emb_indexer, emb_indexer_inv, emb_vals, reference_alignments, neighbours_dicts, ontologies_in_alignment_rev = pickle.load(open("Input/data_german_dataset.pkl", "rb"))

# %%
data.keys()

# %%
data, emb_indexer, emb_indexer_inv, emb_vals, reference_alignments, neighbours_dicts, ontologies_in_alignment_rev = pickle.load(open("data_german_dataset.pkl", "rb"))

# %%
glob.glob("german_datasets/*/*.owl")

# %%
# AML test
def is_test(test_onto, key):
    return tuple([el.split("#")[0] for el in key]) in test_onto

results = []
# ontologies_in_alignment
for ont_pair in ontologies_in_alignment_new:
    t = time.time()
    a, b, c = ont_pair[0], ont_pair[1], ont_pair[0].split("/")[-1].rsplit(".",1)[0].replace(".", "_").lower() + "-" + ont_pair[1].split("/")[-1].rsplit(".",1)[0].replace(".", "_").lower()
    java_command = "java -jar AML_v3.1/AgreementMakerLight.jar -s " + a + " -t " + b + " -o AML-test-results/" + c + ".rdf -a"
    process = subprocess.Popen(java_command.split(), stdout=subprocess.PIPE)
    output, error = process.communicate()
    print ("Took {} seconds for {}".format(time.time()-t, ont_pair))
pred_aml = load_alignments("AML-test-results/")
# pred_aml
# all_ont_pairs = list(set([tuple([el.split("#")[0] for el in l]) for l in data.keys()]))
# # all_ont_pairs = [["conference", "confOf"]]
# for i in list(range(0, len(ontologies_in_alignment), 3)):
#     test_onto = all_ont_pairs[i+1:i+3]
#     for ont_pair in test_onto:
#         a, b, c = ont_pair[0], ont_pair[1], ont_pair[0] + "-" + ont_pair[1]
#         java_command = "java -jar AML_v3.1/AgreementMakerLight.jar -s conference_ontologies/" + a + ".owl" + \
#                             " -t conference_ontologies/" + b + ".owl -o AML-test-results/" + c + ".rdf -a"
#         process = subprocess.Popen(java_command.split(), stdout=subprocess.PIPE)
#         output, error = process.communicate()
#     print (os.listdir("AML-test-results/"))
#     pred_aml = load_alignments("AML-test-results/")
#     pred_aml = [tuple([el.split("/")[-1] for el in key]) for key in pred_aml]
#     tp = len([elem for elem in pred_aml if data[elem]])
#     fn = len([key for key in gt_mappings if key not in set(pred_aml) and is_test(test_onto, key)])
#     fp = len([elem for elem in pred_aml if not data[elem]])

#     precision = tp/(tp+fp)
#     recall = tp/(tp+fn)
#     f1score = 2 * precision * recall / (precision + recall)
#     f2score = 5 * precision * recall / (4 * precision + recall)
#     f0_5score = 1.25 * precision * recall / (0.25 * precision + recall)
#     print (precision, recall, f1score, f2score, f0_5score)
    
#     metrics = [precision, recall, f1score, f2score, f0_5score]
#     results.append(metrics)
    
#     _ = [os.remove(f) for f in glob.glob('AML-test-results/*')]
    
# print ("Final Results:", np.mean(results, axis=0))
# Out:
# Took 23236.648596525192 seconds for ('german_datasets_copy/lebensmittel/Google.Lebensmittel.owl', 'german_datasets_copy/lebensmittel/web.Lebensmittel.owl')
# Took 867.720184803009 seconds for ('german_datasets_copy/freizeit/dmoz.Freizeit.owl', 'german_datasets_copy/freizeit/Google.Freizeit.owl')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-7883e6f48909> in <module>
#      10     java_command = "java -jar AML_v3.1/AgreementMakerLight.jar -s " + a + " -t " + b + " -o AML-test-results/" + c + ".rdf -a"
#      11     process = subprocess.Popen(java_command.split(), stdout=subprocess.PIPE)
# ---> 12     output, error = process.communicate()
#      13     print ("Took {} seconds for {}".format(time.time()-t, ont_pair))
#      14 pred_aml = load_alignments("AML-test-results/")
#
# ~/anaconda3/lib/python3.7/subprocess.py in communicate(self, input, timeout)
#     949                 self._stdin_write(input)
#     950             elif self.stdout:
# --> 951                 stdout = self.stdout.read()
#     952                 self.stdout.close()
#     953             elif self.stderr:
#
# KeyboardInterrupt:

# %%
c
# Out:
# 'dmoz-google'

# %%
# AML test
def is_test(test_onto, key):
    return tuple([el.split("#")[0] for el in key]) in test_onto

results = []
prefix = "/data/Vivek/IBM/IBM-Internship/conference_ontologies/"
for i in list(range(0, len(ontologies_in_alignment), 3)):
    test_onto = ontologies_in_alignment[i:i+3]
    tp_tot, fn_tot, fp_tot = [], [], []
    for ont_pair in test_onto:
        a, b, c = prefix + ont_pair[0], prefix + ont_pair[1], ont_pair[0] + "-" + ont_pair[1]
        # !mkdir $c
        java_command = "java -jar logmap-matcher/target/logmap-matcher-4.0.jar MATCHER file:" +  a + ".owl file:" + b + ".owl " + \
                        "/data/Vivek/IBM/IBM-Internship/" + c + "/ false"
        process = subprocess.Popen(java_command.split(), stdout=subprocess.PIPE)
        output, error = process.communicate()
        
        pred_aml = [l.strip().split("\t")[:2] for l in open(c + "/logmap2_mappings.tsv", "r").read().split("\n")[:-1]]
        pred_aml = [tuple([el.split("/")[-1] for el in key]) for key in pred_aml]
        tp = [elem for elem in pred_aml if data[elem]]
        fn = [key for key in gt_mappings if key not in set(pred_aml) and is_test([tuple(ont_pair)], key)]
        fp = [elem for elem in pred_aml if not data[elem]]
        
        tp_tot.extend(tp)
        fn_tot.extend(fn)
        fp_tot.extend(fp)
        
        # !rm -rf $c
   
    precision = len(tp_tot)/(len(tp_tot)+len(fp_tot))
    recall = len(tp_tot)/(len(tp_tot)+len(fn_tot))
    f1score = 2 * precision * recall / (precision + recall)
    f2score = 5 * precision * recall / (4 * precision + recall)
    f0_5score = 1.25 * precision * recall / (0.25 * precision + recall)
    print (precision, recall, f1score, f2score, f0_5score)
    
    metrics = [precision, recall, f1score, f2score, f0_5score]
    results.append(metrics)
    
    
    
print ("Final Results:", np.mean(results, axis=0))

# %%
ontologies_in_alignment_new = \
[('german_datasets_copy/lebensmittel/Google.Lebensmittel.owl',
	'german_datasets_copy/lebensmittel/web.Lebensmittel.owl'),
 ('german_datasets_copy/freizeit/dmoz.Freizeit.owl',
	'german_datasets_copy/freizeit/Google.Freizeit.owl'),
 ('german_datasets_copy/webdirectory/dmoz.owl',
	'german_datasets_copy/webdirectory/google.owl'),
 ('german_datasets_copy/webdirectory/dmoz.owl',
	'german_datasets_copy/webdirectory/web.owl'),
 ('german_datasets_copy/webdirectory/dmoz.owl',
	'german_datasets_copy/webdirectory/yahoo.small.owl'),
 ('german_datasets_copy/webdirectory/google.owl',
	'german_datasets_copy/webdirectory/web.owl'),
 ('german_datasets_copy/webdirectory/google.owl',
	'german_datasets_copy/webdirectory/yahoo.small.owl'),
 ('german_datasets_copy/webdirectory/web.owl',
	'german_datasets_copy/webdirectory/yahoo.small.owl')]

# %%
max_neighbours
# Out:
# 51

# %%
all_pred = []
for ont_pair in ontologies_in_alignment_new:
    ont_name1 = ont_pair[0].split("/")[-1].rsplit(".",1)[0].replace(".", "_").lower()
    ont_name2 = ont_pair[1].split("/")[-1].rsplit(".",1)[0].replace(".", "_").lower()
    c = ont_pair[0].split("/")[-1].rsplit(".",1)[0].replace(".", "_").lower() + "-" + ont_pair[1].split("/")[-1].rsplit(".",1)[0].replace(".", "_").lower()
    c = "/data/Vivek/IBM/IBM-Internship/" + c
    pred_aml = [l.strip().split("\t")[:2] for l in open(c + "/logmap2_mappings.tsv", "r").read().split("\n")[:-1]]
    pred_aml = [tuple([el.split("#")[-1] for el in key]) for key in pred_aml]
    pred_aml = [tuple((ont_name1 + "#" + key[0], ont_name2 + "#" + key[1])) for key in pred_aml]
    all_pred.extend(pred_aml)


logmap_results = OrderedDict()
for key in data:
    logmap_results[key] = False
for key in all_pred:
    if key not in logmap_results:
        print (key)
    else:
        logmap_results[key] = True
# Out:
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Wein_Suedafrikanisch_http://www.hanseaten-select.de/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Spezialitaeten_http://www.hanseaten-select.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Kaffee-und-Tee_Kaffee_http://www.coffea-store.de/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Naturkost_http://www.oneworld.de/scripts/shop.prg/dritteweltpartner')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Kaffee-und-Tee_Kaffee_http://www.coffea-store.de/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Tee-Kaffee_http://www.cappuccino-laden.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Kaffee-und-Tee_Kaffee_http://www.coffea-store.de/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Tee-Kaffee_http://www.giuseppes.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Kaffee-und-Tee_Kaffee_http://www.coffea-store.de/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Zustellservice_http://www.coffee-service.net')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Wein_http://www.feineweine.de/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Weltweit_http://www.feineweine.de/shop/index.htm')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Kaffee-und-Tee_Tee_http://www.tea-versand.de/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Tee-Kaffee_http://www.f-b-w.de/Tee/versand.htm')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Kaffee-und-Tee_Tee_http://www.foehrerteekontor.mkd.de/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Tee-Kaffee_http://www.foehrerteekontor.de/go.to/modix/now/zum_shop.html')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Kaffee-und-Tee_Tee_http://www.teas-home.de/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Tee-Kaffee_http://www.teas-home.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Spirituosen_Whisky_http://www.whiskydepot.com/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Back-Suesswaren_http://www.Nuernberger-Elisenlebkuchen.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Spirituosen_Whisky_http://www.whiskydepot.com/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Spirituosen_http://www.whisky-corner.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Spirituosen_Whisky_http://www.whiskydepot.com/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Internationale-Kueche_http://www.maimai.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Spirituosen_Whisky_http://www.whiskydepot.com/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Spanien_http://www.4-cee.de/cgi-bin/vshop')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Spirituosen_Whisky_http://www.whiskydepot.com/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Tabakwaren_http://www.cigarrenversand.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Spirituosen_Whisky_http://www.whiskydepot.com/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Portugal_http://www.fahrenheit64.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Spirituosen_Whisky_http://www.whiskydepot.com/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Tee-Kaffee_http://www.teezeit.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Kaffee-und-Tee_Tee_http://www.teahouse.de/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Tee-Kaffee_http://teahouse.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Gewuerze-und-Kraeuter_http://gewuerze-kraeuter-tee.de/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Kraeuter-Gewuerze_http://www.gewuerze-kraeuter-tee.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Gewuerze-und-Kraeuter_http://gewuerze-kraeuter-tee.de/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Kraeuter-Gewuerze_http://www.gewuerzkontor-condimento.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Gewuerze-und-Kraeuter_http://gewuerze-kraeuter-tee.de/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Kraeuter-Gewuerze_http://www.gewuerzdealer.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Gewuerze-und-Kraeuter_http://gewuerze-kraeuter-tee.de/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Kraeuter-Gewuerze_http://www.grubauer.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Gewuerze-und-Kraeuter_http://gewuerze-kraeuter-tee.de/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Kraeuter-Gewuerze_http://www.broedner.com')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Gewuerze-und-Kraeuter_http://gewuerze-kraeuter-tee.de/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Kraeuter-Gewuerze_http://www.gepa-shop.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Gewuerze-und-Kraeuter_http://gewuerze-kraeuter-tee.de/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Kraeuter-Gewuerze_http://www.gasterea.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Kaffee-und-Tee_Tee_http://www.teehexe.de/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Tee-Kaffee_http://www.teehexe.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Regionale-Spezialitaeten_Europaeisch_Spanisch_http://www.finca-catalana.com/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Weltweit_http://www.anzaldo.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Regionale-Spezialitaeten_Europaeisch_Spanisch_http://www.finca-catalana.com/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Frankreich_http://www.gelderblom.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Regionale-Spezialitaeten_Europaeisch_Spanisch_http://www.finca-catalana.com/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Weltweit_http://www.wein-global.de/index.htm')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Regionale-Spezialitaeten_Europaeisch_Spanisch_http://www.finca-catalana.com/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Spezialitaeten_http://www.herzinger.at')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Regionale-Spezialitaeten_Europaeisch_Spanisch_http://www.finca-catalana.com/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Italien_http://www.saltner-wein.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Regionale-Spezialitaeten_Europaeisch_Spanisch_http://www.finca-catalana.com/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Spezialitaeten_http://www.italhandel.com')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Regionale-Spezialitaeten_Europaeisch_Spanisch_http://www.finca-catalana.com/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Internationale-Kueche_http://www.pico-bello.com')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Regionale-Spezialitaeten_Europaeisch_Spanisch_http://www.finca-catalana.com/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Weltweit_http://www.wein-glas.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Regionale-Spezialitaeten_Europaeisch_Spanisch_http://www.finca-catalana.com/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Frankreich_http://www.wein-lehmann-co.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Regionale-Spezialitaeten_Europaeisch_Spanisch_http://www.finca-catalana.com/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Weltweit_http://www.wein-bastion.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Regionale-Spezialitaeten_Europaeisch_Spanisch_http://www.finca-catalana.com/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Weltweit_http://www.haus-der-weine.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Regionale-Spezialitaeten_Europaeisch_Spanisch_http://www.finca-catalana.com/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Deutschland_Rheinhessen_http://www.weingut-strub.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Regionale-Spezialitaeten_Europaeisch_Spanisch_http://www.finca-catalana.com/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Deutschland_Rheinhessen_http://weinbau-wagner.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Regionale-Spezialitaeten_Europaeisch_Spanisch_http://www.finca-catalana.com/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Italien_http://www.la-cantinetta-piemontese.de/Shop/Wein/Vino_Rosso/vino_rosso.html')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Regionale-Spezialitaeten_Europaeisch_Spanisch_http://www.finca-catalana.com/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Deutschland_http://www.reiserwein.com')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Regionale-Spezialitaeten_Europaeisch_Spanisch_http://www.finca-catalana.com/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Weltweit_http://www.cinx.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Regionale-Spezialitaeten_Europaeisch_Spanisch_http://www.finca-catalana.com/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Spezialitaeten_http://www.ahrweinshop.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Regionale-Spezialitaeten_Europaeisch_Spanisch_http://www.finca-catalana.com/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Weltweit_http://www.viniculture.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Regionale-Spezialitaeten_Europaeisch_Spanisch_http://www.finca-catalana.com/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Internationale-Kueche_http://www.scope-net.de/la-credenza.htm')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Regionale-Spezialitaeten_Europaeisch_Spanisch_http://www.finca-catalana.com/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Weltweit_http://www.wein-discount.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Regionale-Spezialitaeten_Europaeisch_Spanisch_http://www.finca-catalana.com/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Weltweit_http://www.vintro.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Regionale-Spezialitaeten_Europaeisch_Spanisch_http://www.finca-catalana.com/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Italien_http://www.vinothek-haberer.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Regionale-Spezialitaeten_Europaeisch_Spanisch_http://www.finca-catalana.com/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Weltweit_http://www.aplusa.com')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Regionale-Spezialitaeten_Europaeisch_Spanisch_http://www.finca-catalana.com/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Spezialitaeten_http://www.mittelmeerbasar.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Regionale-Spezialitaeten_Europaeisch_Spanisch_http://www.finca-catalana.com/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Italien_http://www.vino-italia.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Regionale-Spezialitaeten_Europaeisch_Spanisch_http://www.finca-catalana.com/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Oesterreich_http://www.burgenland-vinothek.at')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Regionale-Spezialitaeten_Europaeisch_Spanisch_http://www.finca-catalana.com/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Deutschland_http://www.froehlich-weine.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Regionale-Spezialitaeten_Europaeisch_Spanisch_http://www.finca-catalana.com/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Deutschland_http://www.weinvondernahe.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Regionale-Spezialitaeten_Europaeisch_Spanisch_http://www.finca-catalana.com/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Internationale-Kueche_http://cybermarkt.com')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Kaffee-und-Tee_http://www.tee-peter-kaffee.de/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Tee-Kaffee_http://www.tee-peter-kaffee.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Wein_Europaeisch_Franzoesisch_http://www.rouge-blanc.com/de/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Frankreich_http://www.netzmarkt.de/index.html')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Wein_Europaeisch_Franzoesisch_http://www.rouge-blanc.com/de/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Weltweit_http://www.rouge-blanc.com/index.php')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Wein_Europaeisch_Franzoesisch_http://www.rouge-blanc.com/de/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Frankreich_http://www.rouge-blanc.com/index.php')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Wein_Europaeisch_Franzoesisch_http://www.rouge-blanc.com/de/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Frankreich_http://www.rouge-blanc.com')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Kaffee-und-Tee_Tee_http://www.teekesselchen.de/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Tee-Kaffee_http://www.teekesselchen.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Honig_http://www.bienengarten.de/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Naturkost_http://www.Honigmet.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Honig_http://www.bienengarten.de/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Naturkost_http://honig-goeken.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Backwaren_http://www.tortenexpress.de/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Weltweit_http://www.weinfass-wabnitz.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Wein_http://www.gallier.at/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Frankreich_http://www.gallier.at')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Wein_http://www.wein-web.de/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Deutschland_http://www.weinhaus-schmitz.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Wein_http://www.wein-web.de/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Weltweit_http://www.weinlust.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Wein_http://www.wein-web.de/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Italien_http://wein-web.de')
# ('google_lebensmittel#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Wein_http://www.weingala.de/', 'web_lebensmittel#Verzeichnis_Einkaufen-Sparen_Nahrungs-Genussmittel_Getraenke_Wein_Sekt-Champagner_Weltweit_http://www
de/')
# ('dmoz#Top_World_Deutsch_Online-Shops_Schoenheit_Hautpflege_Naturprodukte_http://www.indische-naturprodukte.de/', 'google#World_Deutsch_Online-Shops_Schoenheit_Hautpflege_Naturprodukte_http://www.indische-naturprodukte.de/')
# ('dmoz#Top_World_Deutsch_Online-Shops_Unterhaltung_Bild_und_Tontraeger_Musik_Genres_Rock_Punk_http://www.tiscalinet.ch/melcer/', 'google#World_Deutsch_Online-Shops_Unterhaltung_Bild-und-Tontraeger_Musik_Genres_Rock_Punk_http://www.tiscalinet.ch/melcer/')
# ('dmoz#Top_World_Deutsch_Online-Shops_Antiquitaeten_http://www.lamaisonhenri.de/shop/', 'google#World_Deutsch_Online-Shops_Antiquitaeten_http://www.lamaisonhenri.de/shop/')
# ('dmoz#Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Getraenke_Wein_Europaeisch_Deutsch_http://www.wein-likoer.de', 'google#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Wein_Europaeisch_Deutsch_http://www.wein-likoer.de/')
# ('dmoz#Top_World_Deutsch_Online-Shops_Essen_und_Trinken_Getraenke_Wein_Europaeisch_Deutsch_Wuerttemberg_http://www.wg-heilbronn.de/', 'google#World_Deutsch_Online-Shops_Essen-und-Trinken_Getraenke_Wein_Europaeisch_Deutsch_Wuerttemberg_http://www.wg-heilbronn.de/')
# ('dmoz#Top_World_Deutsch_Online-Shops_Haustiere_Hunde_und_Katzen_Katzen_http://www.katzen.tv', 'google#World_Deutsch_Online-Shops_Haus-und-Garten_Dekorationsartikel_http://shop.zaunershop.de/')
# ('dmoz#Top_World_Deutsch_Online-Shops_Haustiere_Hunde_und_Katzen_Katzen_http://www.katzen.tv', 'google#World_Deutsch_Online-Shops_Haustiere_Hunde-und-Katzen_Katzen_http://www.katzen.tv/')
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
data_items = list(data.items())
logmap_items = list(logmap_results.items())
results = []
for i in range(6):
    
    test_data = dict(data_items[int(0.15*i*len(data)):int((0.15*i + 0.1)*len(data))])
    logmap_data = dict(logmap_items[int(0.15*i*len(logmap_results)):int((0.15*i + 0.1)*len(logmap_results))])
    
    s = set(all_pred)
    tp_tot = [elem for elem in logmap_data if test_data[elem] and logmap_data[elem]]
    fp_tot = [elem for elem in logmap_data if not test_data[elem] and logmap_data[elem]]
#     print (len(tp_tot), len(fp_tot))
    fn_tot = [elem for elem in test_data if test_data[elem] and not logmap_data[elem]]
    precision = len(tp_tot)/(len(tp_tot)+len(fp_tot))
    recall = len(tp_tot)/(len(tp_tot)+len(fn_tot))
    f1score = 2 * precision * recall / (precision + recall)
    f2score = 5 * precision * recall / (4 * precision + recall)
    f0_5score = 1.25 * precision * recall / (0.25 * precision + recall)
    print (precision, recall, f1score, f2score, f0_5score)
    
    metrics = [precision, recall, f1score, f2score, f0_5score]
    results.append(metrics)
    
print ("Final Results:", np.mean(results, axis=0))
print (len(all_pred))
# Out:
# 0.7764705882352941 0.616822429906542 0.6875 0.6432748538011696 0.738255033557047
# 0.7692307692307693 0.5357142857142857 0.6315789473684211 0.5703422053231938 0.7075471698113207
# 0.7692307692307693 0.5106382978723404 0.6138107416879794 0.5474452554744526 0.6984866123399301
# 0.8106508875739645 0.5956521739130435 0.6867167919799498 0.6290174471992656 0.7560706401766006
# 0.8445945945945946 0.5841121495327103 0.6906077348066298 0.6225099601593624 0.7754342431761786
# 0.7596899224806202 0.47115384615384615 0.5816023738872403 0.509885535900104 0.6767955801104972
# Final Results: [0.78831126 0.55234886 0.6486361  0.58707921 0.72543155]
# 39611

# %%
logmap_results = OrderedDict()
for key in data:
    logmap_results[key] = False
for key in all_pred:
    if key not in logmap_results:
        print (key)
    else:
        logmap_results[key] = True

# %%
len(data), len(logmap_results)
# Out:
# (3308848, 3308848)

# %%
inp

# %%
glob

# %%
fn_spellchecked, fp_spellchecked = [dict(el) for el in pickle.load(open("test_v2.pkl", "rb"))]
fn_baseline, fp_baseline = [dict(el) for el in pickle.load(open("test_best.pkl", "rb"))]
fn_unhas, fp_unhas = [dict(el) for el in pickle.load(open("test_unhas.pkl", "rb"))]
fn_resolved, fp_resolved = [dict(el) for el in pickle.load(open("test_resolved.pkl", "rb"))]

fn_dict, fp_dict = {}, {}
def create_comparison_file(file, idx):
    fn, fp = [dict(el) for el in pickle.load(open(file, "rb"))]
    
    for key in fn:
        if key in fn_dict:
            fn_dict[key][idx] = fn[key]
        else:
            fn_dict[key] = ["N/A" for i in range(4)]
            fn_dict[key][idx] = fn[key]
    
    for key in fp:
        if key in fp_dict:
            fp_dict[key][idx] = fp[key]
        else:
            fp_dict[key] = ["N/A" for i in range(4)]
            fp_dict[key][idx] = fp[key]
    

create_comparison_file("test_best.pkl", 0)
create_comparison_file("test_unhas.pkl", 1)
create_comparison_file("test_v2.pkl", 2)
create_comparison_file("test_resolved.pkl", 3)

open("fn - comparison.tsv", "w+").write("\n".join(["\t".join([str(el) for el in flatten(el)]) for el in fn_dict.items()]))
open("fp - comparison.tsv", "w+").write("\n".join(["\t".join([str(el) for el in flatten(el)]) for el in fp_dict.items()]))

# %%
ontologies_in_alignment = pickle.load(open("data_path.pkl", "rb"))[-1]
ontologies_in_alignment

# %%
d = {('confOf#Organization', 'sigkdd#Organizator'): (1,2,3,4),
 ('iasted#Document', 'sigkdd#Document'): (5,6,78,8)}
[[str(el) for el in flatten(el)] for el in d.items()]

# %%
abbreviations_dict = {}
final_dict = {}

for mapping in all_mappings:
    mapping = tuple([el.split("#")[1] for el in mapping])
    is_abb = re.search("[A-Z][A-Z]+", mapping[0])
    if is_abb:
        abbreviation = "".join([el[0].upper() for el in mapping[1].split("_")])
        if is_abb.group() in abbreviation:
            
            start = abbreviation.find(is_abb.group())
            end = start + len(is_abb.group())
            fullform = "_".join(mapping[1].split("_")[start:end])
            print ("left", mapping, abbreviation, fullform)
            
            rest_first = " ".join([el for el in mapping[0].replace(is_abb.group(), "").split("_") if el]).lower()
            rest_second = " ".join(mapping[1].split("_")[:start] + mapping[1].split("_")[end:])
            if is_abb.group() not in final_dict:
                final_dict[is_abb.group()] = [(fullform, rest_first, rest_second)]
            else:
                final_dict[is_abb.group()].append((fullform, rest_first, rest_second))

    is_abb = re.search("[A-Z][A-Z]+", mapping[1])
    if is_abb:
        abbreviation = "".join([el[0].upper() for el in mapping[0].split("_")])
        
        if is_abb.group() in abbreviation:
            start = abbreviation.find(is_abb.group())
            end = start + len(is_abb.group())
            fullform = "_".join(mapping[0].split("_")[start:end])
            print ("right", mapping, abbreviation, fullform)

            rest_first = " ".join([el for el in mapping[1].replace(is_abb.group(), "").split("_") if el]).lower()
            rest_second = " ".join(mapping[0].split("_")[:start] + mapping[0].split("_")[end:])
            if is_abb.group() not in final_dict:
                final_dict[is_abb.group()] = [(fullform, rest_first, rest_second)]
            else:
                final_dict[is_abb.group()].append((fullform, rest_first, rest_second))

keys = [el for el in list(set(flatten([flatten([tup[1:] for tup in final_dict[key]]) for key in final_dict]))) if el]
abb_embeds = dict(zip(keys, extractUSEEmbeddings(keys)))

scored_dict = {}
for abbr in final_dict:
    sim_list = [(tup[0], tup[1], tup[2], cos_sim(abb_embeds[tup[1]], abb_embeds[tup[2]])) if tup[1] and tup[2]
                else (tup[0], tup[1], tup[2], 0) for tup in final_dict[abbr]]
    scored_dict[abbr] = sorted(list(set(sim_list)), key=lambda x:x[-1], reverse=True)

resolved_dict = {key: scored_dict[key][0] for key in scored_dict}
filtered_dict = {key: " ".join(resolved_dict[key][0].split("_")) for key in resolved_dict if resolved_dict[key][-1] > 0.9}
inp_resolved = []
for concept in inp:
    for key in filtered_dict:
        concept = concept.replace(key, filtered_dict[key])
    inp_resolved.append(concept)
inp_resolved

# %%
len()

# %%
cos_sim(*extractUSEEmbeddings(["Conference Banquet", "Dinner Banquet"]))

# %%
np.array(data.items())

# %%
scored_dict = {}
for abbr in final_dict:
    sim_list = [(tup[0], tup[1], tup[2], cos_sim(abb_embeds[tup[1]], abb_embeds[tup[2]])) if tup[1] and tup[2]
                else (tup[0], tup[1], tup[2], 0) for tup in final_dict[abbr]]
    scored_dict[abbr] = sorted(list(set(sim_list)), key=lambda x:x[-1], reverse=True)

# %%
inp_case_handled = []
for concept in inp:
    final_list = []
    for word in concept.split(" "):
        if not re.search("[A-Z][A-Z]+", concept):
            final_list.append(word.lower())
        else:
            final_list.append(word)
    case_resolved = " ".join(final_list)
    inp_case_handled.append(case_resolved)
    
inp_case_handled

# %%
indices
# Out:
# array([ 92749,  29890,  49076, ..., 121868,  56566,  66092])

# %%
Ontology("conference_ontologies/conference.owl").mapping_dict

# %%
# from transformers import XLNetTokenizer, XLNetModel
# import torch
# import scipy
# import torch.nn as nn
# import torch.nn.functional as F

# tokenizer = AutoTokenizer.from_pretrained("emilyalsentzer/Bio_ClinicalBERT")
# model = AutoModel.from_pretrained("emilyalsentzer/Bio_ClinicalBERT")

import time

t = time.time()
input_ids = torch.tensor(tokenizer.encode("fastigial nucleus", add_special_tokens=True)).unsqueeze(0)
outputs = model(input_ids)
last_hidden_states = outputs[0].mean(1)

print (t-time.time())
# input_ids = torch.tensor(tokenizer.encode("femur", add_special_tokens=True)).unsqueeze(0) 

# outputs1 = model(input_ids)
# last_hidden_states1 = outputs1[0].mean(1)

# cos = nn.CosineSimilarity(dim=1, eps=1e-6)
# cos(last_hidden_states, last_hidden_states1)

# %%
Ontology("german_datasets/mapping freizeit/Google.Freizeit.owl").mapping_dict

# %%
def load_german_mappings(file):
    mappings = [content.strip() for content in open(file).read().split("--------------------------------------------------------") if content.strip()]
    for mapping in mappings:
        src = [line.split(":")[-1].strip() for line in mapping.split("\n") if line.startswith(" + Source: ")][0]
        targ = [line.split(":")[-1].strip() for line in mapping.split("\n") if line.startswith(" + Target: ")][0]
        
        lines = [[row.strip().split(":")[0].split(".")[-1] for row in line.split("-",1)[1].strip().split("<->")]
                 for line in mapping.split("\n") if line.startswith(" -")]
        lines = [[src.rsplit(".",1)[0].replace(".", "_").lower() + "#" + line[0],
                  targ.rsplit(".",1)[0].replace(".", "_").lower() + "#" + line[1]] for line in lines]
    return lines
    
len(load_german_mappings("german_datasets/mapping lebensmittel/mapping.txt"))

# %%
import tensorflow_text

# %%
open("Output_a")
