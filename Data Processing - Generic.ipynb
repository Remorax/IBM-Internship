# %%
# Construction of dataset

import os, itertools, time, pickle, sys, glob, requests
import subprocess
from xml.dom import minidom
from collections import Counter, OrderedDict
from operator import itemgetter
from nltk.corpus import wordnet
import tensorflow as tf
import tensorflow_hub as hub
from scipy import spatial
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from sklearn.feature_extraction.text import TfidfVectorizer
import re
import numpy as np
import scipy.sparse as sp
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from math import ceil, exp
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
flatten = lambda l: [item for sublist in l for item in sublist]

class Ontology():
    def __init__(self, ontology):
        self.ontology = ontology
        self.ontology_obj = minidom.parse(ontology)
        self.root = self.ontology_obj.documentElement
        self.construct_mapping_dict()
        
        self.parents_dict = {}
        self.subclasses = self.parse_subclasses()
        self.object_properties = self.parse_object_properties()
        self.data_properties = self.parse_data_properties()
        self.triples = self.parse_triples()
        self.classes = self.parse_classes()        
    
    def construct_mapping_dict(self):
        self.mapping_dict = {self.extract_ID(el, False): self.get_child_node(el, "rdfs:label")[0].firstChild.nodeValue for el in self.root.getElementsByTagName("owl:Class") if self.get_child_node(el, "rdfs:label")}
        self.mapping_dict_inv = {self.mapping_dict[key]: key for key in self.mapping_dict}
        return
        
    def get_child_node(self, element, tag):
        return [e for e in element._get_childNodes() if type(e)==minidom.Element and e._get_tagName() == tag]
        
    def has_attribute_value(self, element, attribute, value):
        return True if element.getAttribute(attribute).split("#")[-1] == value else False
    
    def get_subclass_triples(self):
        subclasses = self.get_subclasses()
        for (a,b,c) in subclasses:
            if c == "subclass_of" and a!="Thing" and b!="Thing":
                if b not in self.parents_dict:
                    self.parents_dict[b] = [a]
                else:
                    self.parents_dict[b].append(a)
        return [(b,a,c) for (a,b,c) in subclasses]
    
    def parse_triples(self, union_flag=0, subclass_of=True):
        obj_props = self.object_properties
        data_props = self.data_properties
        props = obj_props + data_props
        all_triples = []
        for prop in props:
            domain_children = self.get_child_node(prop, "rdfs:domain")
            range_children = self.get_child_node(prop, "rdfs:range")
            domain_prop = self.filter_null([self.extract_ID(el) for el in domain_children])
            range_prop = self.filter_null([self.extract_ID(el) for el in range_children])
            if not domain_children or not range_children:
                continue
            if not domain_prop:
                domain_prop = self.filter_null([self.extract_ID(el) for el in domain_children[0].getElementsByTagName("owl:Class")])
            if not range_prop:
                range_prop = self.filter_null([self.extract_ID(el) for el in range_children[0].getElementsByTagName("owl:Class")])
            if domain_prop and range_prop:
                if union_flag == 0:
                    all_triples.extend([(el[0], el[1], self.extract_ID(prop)) for el in list(itertools.product(domain_prop, range_prop))])
                else:
                    all_triples.append(("###".join(domain_prop), "###".join(range_prop), self.extract_ID(prop)))
        if subclass_of:
            all_triples.extend(self.get_subclass_triples())
        
        return [triple for triple in list(set(all_triples)) if triple[0]!="Thing" and triple[1]!="Thing"]
    
    def get_triples(self, union_flag=0, subclass_of=True):
        return self.parse_triples(union_flag, subclass_of)

    def parse_subclasses(self, union_flag=0):
        subclasses = self.root.getElementsByTagName("rdfs:subClassOf")
        subclass_pairs = []
        for el in subclasses:
            inline_subclasses = self.extract_ID(el)
            if inline_subclasses:
                subclass_pairs.append((el, el.parentNode, "subclass_of"))
                
            else:
                level1_class = self.get_child_node(el, "owl:Class")
                if not level1_class:
                    restriction = el.getElementsByTagName("owl:Restriction")
                    if not restriction:
                        continue
                    prop = self.get_child_node(restriction[0], "owl:onProperty")
                    some_vals = self.get_child_node(restriction[0], "owl:someValuesFrom")
                    
                    if not prop or not some_vals:
                        continue
#                     print(self.extract_ID(el), "**", self.extract_ID(some_vals[0]), "**", self.extract_ID(prop[0]))
                    try:
                        if self.extract_ID(prop[0]) and self.extract_ID(some_vals[0]):
                            subclass_pairs.append((el.parentNode, some_vals[0], self.extract_ID(prop[0])))
                        elif self.extract_ID(prop[0]) and not self.extract_ID(some_vals[0]):
                            class_vals = self.get_child_node(some_vals[0], "owl:Class")
                            subclass_pairs.append((el.parentNode, class_vals[0], self.extract_ID(prop[0])))
                        elif not self.extract_ID(prop[0]) and self.extract_ID(some_vals[0]):
                            prop_vals = self.get_child_node(prop[0], "owl:ObjectProperty")
                            subclass_pairs.append((el.parentNode, some_vals[0], self.extract_ID(prop_vals[0])))
                        else:
                            prop_vals = self.get_child_node(prop[0], "owl:ObjectProperty")
                            class_vals = self.get_child_node(some_vals[0], "owl:Class")
                            subclass_pairs.append((el.parentNode, class_vals[0], self.extract_ID(prop_vals[0])))
                    except Exception as e:
                        print ("error", e)
                        continue
                else:
                    if self.extract_ID(level1_class[0]):
                        subclass_pairs.append((level1_class[0], el.parentNode, "subclass_of"))
                    else:
                        level2classes = level1_class[0].getElementsByTagName("owl:Class")
                        subclass_pairs.extend([(elem, el.parentNode, "subclass_of") for elem in level2classes if self.extract_ID(elem)])
                        continue
        return subclass_pairs
        
    def get_subclasses(self):
        subclasses = [(self.extract_ID(a), self.extract_ID(b), c) for (a,b,c) in self.subclasses]
        return [el for el in subclasses if el[0] and el[1] and el[2]]
    
    def filter_null(self, data):
        return [el for el in data if el]
    
    def extract_ID(self, element, check_coded = True):
        element_id = element.getAttribute("rdf:ID") or element.getAttribute("rdf:resource") or element.getAttribute("rdf:about")
        element_id = element_id.split("#")[-1]
        if len(list(filter(str.isdigit, element_id))) >= 3 and "_" in element_id and check_coded:
            return self.mapping_dict[element_id]
        return element_id.replace("UNDEFINED_", "").replace("DO_", "")
    
    def parse_classes(self):
        class_elems = [self.extract_ID(el) for el in self.root.getElementsByTagName("owl:Class")]
        subclass_classes = list(set(flatten([el[:-1] for el in self.triples])))
        return list(set(self.filter_null(class_elems + subclass_classes)))
    
    def get_classes(self):
        return self.classes
    
    def get_entities(self):
        entities = [self.extract_ID(el) for el in self.root.getElementsByTagName("owl:Class")]
        return list(set(self.filter_null(entities)))

    def parse_data_properties(self):
        data_properties = [el for el in self.get_child_node(self.root, 'owl:DatatypeProperty')]
        fn_data_properties = [el for el in self.get_child_node(self.root, 'owl:FunctionalProperty') if el]
        fn_data_properties = [el for el in fn_data_properties if type(el)==minidom.Element and 
            [el for el in self.get_child_node(el, "rdf:type") if 
             self.has_attribute_value(el, "rdf:resource", "DatatypeProperty")]]
        inv_fn_data_properties = [el for el in self.get_child_node(self.root, 'owl:InverseFunctionalProperty') if el]
        inv_fn_data_properties = [el for el in inv_fn_data_properties if type(el)==minidom.Element and 
            [el for el in self.get_child_node(el, "rdf:type") if 
             self.has_attribute_value(el, "rdf:resource", "DatatypeProperty")]]
        return data_properties + fn_data_properties + inv_fn_data_properties
        
    def parse_object_properties(self):
        obj_properties = [el for el in self.get_child_node(self.root, 'owl:ObjectProperty')]
        fn_obj_properties = [el for el in self.get_child_node(self.root, 'owl:FunctionalProperty') if el]
        fn_obj_properties = [el for el in fn_obj_properties if type(el)==minidom.Element and 
            [el for el in self.get_child_node(el, "rdf:type") if 
             self.has_attribute_value(el, "rdf:resource", "ObjectProperty")]]
        inv_fn_obj_properties = [el for el in self.get_child_node(self.root, 'owl:InverseFunctionalProperty') if el]
        inv_fn_obj_properties = [el for el in inv_fn_obj_properties if type(el)==minidom.Element and 
            [el for el in self.get_child_node(el, "rdf:type") if 
             self.has_attribute_value(el, "rdf:resource", "ObjectProperty")]]
        return obj_properties + fn_obj_properties + inv_fn_obj_properties
    
    def get_object_properties(self):
        obj_props = [self.extract_ID(el) for el in self.object_properties]
        return list(set(self.filter_null(obj_props)))
    
    def get_data_properties(self):
        data_props = [self.extract_ID(el) for el in self.data_properties]
        return list(set(self.filter_null(data_props)))

# %%
USE_folder = "/home/vlead/USE"
alignment_folder = "reference-alignment/"

# Load reference alignments 
def load_alignments(folder):
    alignments = []
    for f in os.listdir(folder):
        doc = minidom.parse(folder + f)
        ls = list(zip(doc.getElementsByTagName('entity1'), doc.getElementsByTagName('entity2')))
        alignments.extend([(a.getAttribute('rdf:resource'), b.getAttribute('rdf:resource')) for (a,b) in ls])
    return alignments
        
reference_alignments = load_alignments(alignment_folder)

ra_anatomy_coded = load_alignments("../Anatomy/Alignments/")
ra_anatomy = []
ont1 = Ontology("../Anatomy/Ontologies/mouse.owl")
ont2 = Ontology("../Anatomy/Ontologies/human.owl")
for elem in ra_anatomy_coded:
    pre1, pre2 = elem[0].split("#")[0].split(".")[0].split("/")[-1], elem[1].split("#")[0].split(".")[0].split("/")[-1]
    elem1, elem2 = elem[0].split("#")[-1], elem[1].split("#")[-1]
    ra_anatomy.append(( pre1 + "#" + ont1.mapping_dict[elem1], pre2 + "#" + ont2.mapping_dict[elem2]))

gt_mappings = [tuple([elem.split("/")[-1] for elem in el]) for el in reference_alignments]
gt_mappings.extend(ra_anatomy)


ontologies_in_alignment = [["conference_ontologies/" + el  + ".owl" for el in l.split(".")[0].split("-")]
                           for l in os.listdir("reference-alignment/")]
ontologies_in_alignment += [["../Anatomy/Ontologies/human.owl", "../Anatomy/Ontologies/mouse.owl"]]

# %%
# Combinatorial mapping generation

all_mappings = []
for l in ontologies_in_alignment[:-1]:
    ont1 = Ontology(l[0])
    ont2 = Ontology(l[1])
    
    ent1 = ont1.get_entities()
    ent2 = ont2.get_entities()
    
    obj1 = ont1.get_object_properties()
    obj2 = ont2.get_object_properties()
    
    data1 = ont1.get_data_properties()
    data2 = ont2.get_data_properties()
    
    mappings = list(itertools.product(ent1, ent2)) + list(itertools.product(obj1, obj2)) + list(itertools.product(data1, data2))

    
    all_mappings.extend([(l[0].split("/")[-1].split(".")[0] + "#" + el[0], l[1].split("/")[-1].split(".")[0] + "#" + el[1]) for el in mappings])
    

data = {mapping: False for mapping in all_mappings}
for mapping in set(gt_mappings):
    data[mapping] = True
# Out:
# error list index out of range
# error list index out of range
# error list index out of range
# error list index out of range
# error list index out of range
# error list index out of range

# %%
# Abbrevation resolution preprocessing

abbreviations_dict = {}
final_dict = {}

for mapping in all_mappings:
    mapping = tuple([el.split("#")[1] for el in mapping])
    is_abb = re.search("[A-Z][A-Z]+", mapping[0])
    if is_abb:
        abbreviation = "".join([el[0].upper() for el in mapping[1].split("_")])
        if is_abb.group() in abbreviation:
            
            start = abbreviation.find(is_abb.group())
            end = start + len(is_abb.group())
            fullform = "_".join(mapping[1].split("_")[start:end])
            print ("left", mapping, abbreviation, fullform)
            
            rest_first = " ".join([el for el in mapping[0].replace(is_abb.group(), "").split("_") if el]).lower()
            rest_second = " ".join(mapping[1].split("_")[:start] + mapping[1].split("_")[end:])
            if is_abb.group() not in final_dict:
                final_dict[is_abb.group()] = [(fullform, rest_first, rest_second)]
            else:
                final_dict[is_abb.group()].append((fullform, rest_first, rest_second))

    is_abb = re.search("[A-Z][A-Z]+", mapping[1])
    if is_abb:
        abbreviation = "".join([el[0].upper() for el in mapping[0].split("_")])
        
        if is_abb.group() in abbreviation:
            start = abbreviation.find(is_abb.group())
            end = start + len(is_abb.group())
            fullform = "_".join(mapping[0].split("_")[start:end])
            print ("right", mapping, abbreviation, fullform)

            rest_first = " ".join([el for el in mapping[1].replace(is_abb.group(), "").split("_") if el]).lower()
            rest_second = " ".join(mapping[0].split("_")[:start] + mapping[0].split("_")[end:])
            if is_abb.group() not in final_dict:
                final_dict[is_abb.group()] = [(fullform, rest_first, rest_second)]
            else:
                final_dict[is_abb.group()].append((fullform, rest_first, rest_second))

keys = [el for el in list(set(flatten([flatten([tup[1:] for tup in final_dict[key]]) for key in final_dict]))) if el]
abb_embeds = dict(zip(keys, extractUSEEmbeddings(keys)))

scored_dict = {}
for abbr in final_dict:
    sim_list = [(tup[0], tup[1], tup[2], cos_sim(abb_embeds[tup[1]], abb_embeds[tup[2]])) if tup[1] and tup[2]
                else (tup[0], tup[1], tup[2], 0) for tup in final_dict[abbr]]
    scored_dict[abbr] = sorted(list(set(sim_list)), key=lambda x:x[-1], reverse=True)

resolved_dict = {key: scored_dict[key][0] for key in scored_dict}
filtered_dict = {key: " ".join(resolved_dict[key][0].split("_")) for key in resolved_dict if resolved_dict[key][-1] > 0.9}
# Out:
# right ('Submitted_contribution', 'SC_Member') SC Submitted_contribution
# right ('Steering_committee', 'SC_Member') SC Steering_committee
# right ('Passive_conference_participant', 'PC_Chair') PCP Passive_conference
# right ('Passive_conference_participant', 'PC_Member') PCP Passive_conference
# right ('Organizing_committee', 'OC_Member') OC Organizing_committee
# right ('Organizing_committee', 'OC_Chair') OC Organizing_committee
# right ('Program_committee', 'PC_Chair') PC Program_committee
# right ('Program_committee', 'PC_Member') PC Program_committee
# left ('Chair_PC', 'PC_Chair') PC PC_Chair
# left ('Member_PC', 'PC_Chair') PC PC_Chair
# left ('PC_Chair', 'Program_Committee') PC Program_Committee
# left ('PC_Chair', 'Program_Committee_member') PCM Program_Committee
# left ('PC_Chair', 'Program_Chair') PC Program_Chair
# left ('PC_Member', 'Program_Committee') PC Program_Committee
# left ('PC_Member', 'Program_Committee_member') PCM Program_Committee
# left ('PC_Member', 'Program_Chair') PC Program_Chair
# left ('OC_Member', 'Organizing_Committee') OC Organizing_Committee
# left ('OC_Member', 'Organizing_Committee_member') OCM Organizing_Committee
# left ('OC_Chair', 'Organizing_Committee') OC Organizing_Committee
# left ('OC_Chair', 'Organizing_Committee_member') OCM Organizing_Committee
# left ('Chair_PC', 'Program_Committee') PC Program_Committee
# left ('Chair_PC', 'Program_Committee_member') PCM Program_Committee
# left ('Chair_PC', 'Program_Chair') PC Program_Chair
# left ('Member_PC', 'Program_Committee') PC Program_Committee
# left ('Member_PC', 'Program_Committee_member') PCM Program_Committee
# left ('Member_PC', 'Program_Chair') PC Program_Chair
# left ('Chair_PC', 'Presenter_city') PC Presenter_city
# left ('Member_PC', 'Presenter_city') PC Presenter_city
# right ('Passive_conference_participant', 'Chair_PC') PCP Passive_conference
# right ('Passive_conference_participant', 'Member_PC') PCP Passive_conference
# right ('Program_committee', 'Chair_PC') PC Program_committee
# right ('Program_committee', 'Member_PC') PC Program_committee
# left ('paperID', 'is_dated_on') IDO is_dated
# left ('PC_Chair', 'Presenter_city') PC Presenter_city
# left ('PC_Member', 'Presenter_city') PC Presenter_city
# left ('OC_Member', 'One_conference_day') OCD One_conference
# left ('SC_Member', 'Session_chair') SC Session_chair
# left ('SC_Member', 'Brief_introduction_for_Session_chair') BIFSC Session_chair
# left ('SC_Member', 'Sponsor_company_house') SCH Sponsor_company
# left ('SC_Member', 'Sponsor_city') SC Sponsor_city
# left ('OC_Chair', 'One_conference_day') OCD One_conference

# %%
# Extracting USE embeddings

def extractUSEEmbeddings(words):
    try:
        embed = hub.KerasLayer(USE_folder)
    except Exception as e:
        # !mkdir $USE_folder
        # !curl -L "https://tfhub.dev/google/universal-sentence-encoder-large/5?tf-hub-format=compressed" | tar -zxvC $USE_folder
        embed = hub.KerasLayer(USE_folder)
        pass
    word_embeddings = embed(words)
    return word_embeddings.numpy()

def cos_sim(a,b):
    return 1 - spatial.distance.cosine(a, b)

def camel_case_split(identifier):
    matches = re.finditer('.+?(?:(?<=[a-z])(?=[A-Z])|(?<=[A-Z])(?=[A-Z][a-z])|$)', identifier)
    return [m.group(0) for m in matches]

def parse(word):
    return flatten([el.split("_") for el in camel_case_split(word)])
    

extracted_elems = []

for ont_name in list(set(flatten(ontologies_in_alignment[:-1]))):
    ont = Ontology(ont_name)
    entities = ont.get_entities()
    props = ont.get_object_properties() + ont.get_data_properties()
    triples = list(set(flatten(ont.get_triples())))
    extracted_elems.extend([ont_name.split("/")[-1].split(".")[0] + "#" + elem for elem in entities + props + triples])

extracted_elems = list(set(extracted_elems))
inp = [" ".join(parse(word.split("#")[1])) for word in extracted_elems]

# Resolving abbreviations to full forms
inp_resolved = []
for concept in inp:
    for key in filtered_dict:
        concept = concept.replace(key, filtered_dict[key])
    final_list = []
    # Lowering case except in abbreviations
    for word in concept.split(" "):
        if not re.search("[A-Z][A-Z]+", word):
            final_list.append(word.lower())
        else:
            final_list.append(word)
    concept = " ".join(final_list)
    inp_resolved.append(concept)


url = "https://montanaflynn-spellcheck.p.rapidapi.com/check/"

headers = {
    'x-rapidapi-host': "montanaflynn-spellcheck.p.rapidapi.com",
    'x-rapidapi-key': "9965b01207msh06291e57d6f2c55p1a6a16jsn0fb016da4a62"
    }

inp_spellchecked = []
for concept in inp_resolved:
    querystring = {"text": concept}
    response = requests.request("GET", url, headers=headers, params=querystring).json()
    if response["suggestion"] != concept:
        resolved = str(concept)
        final_list = []
        for word in concept.split(" "):
            if not re.search("[A-Z][A-Z]+", concept):
                final_list.append(word.lower())
            else:
                final_list.append(word)
        resolved = " ".join(final_list)
#         print (resolved, "suggestion", response)
        for word in response["corrections"]:
            if not re.search("[A-Z][A-Z]+", concept):
                resolved = resolved.replace(word.lower(), response["corrections"][word][0].lower())
                
        
        print (concept, resolved)
        inp_spellchecked.append(resolved)
    else:
        inp_spellchecked.append(concept)

print ("Total number of extracted unique classes and properties from entire RA set: ", len(extracted_elems))

extracted_elems = ["<UNK>"] + extracted_elems

# stopwords = ["has", "is", "a", "an", "the"]
stopwords = ["has"]
inp_stemmed = []
for elem in inp_spellchecked:
    words = " ".join([word for word in elem.split() if word not in stopwords])
    words = words.replace("-", " ")
    inp_stemmed.append(words)

anatomy_terms = []
for ont_name in list(set(flatten(ontologies_in_alignment[-1:]))):
    ont = Ontology(ont_name)
    entities = ont.get_entities()
    props = ont.get_object_properties() + ont.get_data_properties()
    triples = list(set(flatten(ont.get_triples())))
    anatomy_terms.extend([ont_name.split("/")[-1].split(".")[0] + "#" + elem for elem in entities + props + triples])

anatomy_terms = list(set(anatomy_terms))
inp_anatomy = [" ".join(parse(word.split("#")[1])) for word in anatomy_terms]

roman_regex = "^M{0,3}(CM|CD|D?C{0,3})(XC|XL|L?X{0,3})(IX|IV|V?I{0,3})$"
inp_anatomy = [" ".join([word.replace("/", " or ") for word in elem.split() 
           if not re.search(word, roman_regex) and not re.search(word, "\d")]) for elem in inp_anatomy]

extracted_elems.extend(anatomy_terms)
inp_stemmed.extend(inp_anatomy)

embeds = np.array([np.zeros(512,)] + list(extractUSEEmbeddings(inp_stemmed)))
# embeds = np.array([np.zeros(512,)] + list(extractUSEEmbeddings(inp_spellchecked)))
embeddings = dict(zip(extracted_elems, embeds))


emb_vals = list(embeddings.values())
emb_indexer = {key: i for i, key in enumerate(list(embeddings.keys()))}
emb_indexer_inv = {i: key for i, key in enumerate(list(embeddings.keys()))}

inp_anatomy
# Out:
# error list index out of range
# LCD projector LCD projector
# registeered applicant registered applicant
# cheque exchequer
# technically organises technically organists
# IASTED member IASTED member
# print hardcopy mailing manifests print hard copy mailing manifests
# operating topicsystems operating topic systems
# has a URL has a URL
# contribution 1th-author contribution th-author
# has VAT has VAT
# conference www conference www
# has an ISBN has an ISBN
# accepts hardcopy submissions accepts hard copy submissions
# flyer flayer
# author cd proceedings included author cd proceedings included
# SC member SC member
# technically organised by technically organized by
# organised by organized by
# organisation organization
# presentationed by presentation ed by
# was a committe co-chair of was a committee co-chair of
# registation deadline registration deadline
# sponzorship sponsorship
# nonauthor registration fee non author registration fee
# accpet if room rating accept if room rating
# scientifically organises scientifically organists
# registration SIGKDD member registration SIGKDD member
# holded by holed by
# technical commitee technical committee
# author attendee cd registration fee author attendee cd registration fee
# coctail reception cocktail reception
# NGO NGO
# IASTED non member IASTED non member
# webmaster web master
# paper ID paper ID
# is a topis of conference parts is a tops of conference parts
# sponzor sponsor
# powerline transmission topic power line transmission topic
# programme brochure programmer brochure
# reviewes reviewed
# logo URL logo URL
# TProgram committee member TProgram committee member
# scientifically organised by scientifically organized by
# sponzor fee sponsor fee
# registration SIGMOD member registration SIGMOD member
# any URI any URI
# is the 1th part of is the th part of
# programme programmer
# cd proceening cd proceeding
# computer networks aapplications topic computer networks applications topic
# technic activity technical activity
# CAD topic CAD topic
# hardcopy mailing manifests printed by hard copy mailing manifests printed by
# has programme has programmer
# organizator organization
# has a commtitee has a committee
# memeber registration fee member registration fee
# modelling modeling
# is writen by is write by
# viza viz
# organises organists
# organising agency organizing agency
# site URL site URL
# ACM SIGKDD ACM SIGKDD
# initial manuscipt initial manuscript
# Total number of extracted unique classes and properties from entire RA set:  827
# ['gastroepiploic vein',
#  'Brachial Plexus',
#  'glomerular parietal epithelium',
#  'foot digit bone',
#  'Intestinal Epithelium',
#  'Omotransverse',
#  'Bronchus Smooth Muscle Tissue',
#  'subscapular vein',
#  'left adrenal gland',
#  'Pancreatico-Duodenal Vein',
#  'metacarpal or metatarsal bone',
#  'Long Bone',
#  'Respiratory System Part',
#  'foot skin',
#  'bile duct intrahepatic part',
#  'incus',
#  'gracilis',
#  'bulboglandular',
#  'Gracilis',
#  'Epidermal Ridges',
#  'sublingual gland',
#  'apex of arytenoid',
#  'Unipolar Neuron',
#  'Roof of the Fourth Ventricle',
#  'dental pulp',
#  'Carpal Joint',
#  'bulbourethral gland secretion',
#  'Squamous Epithelium',
#  'Bone Marrow Blood-Forming Cell',
#  'Cornea',
#  'ovarian vein',
#  'Immature Lymphocyte',
#  'phrenic artery',
#  'Frontal Bone',
#  'lower respiratory tract',
#  'cecum',
#  'Laryngeal Connective Tissue',
#  'common bile duct',
#  'External Maleolus',
#  'forelimb skin',
#  'Facial Nerve Nucleus',
#  'Bile Duct Tissue',
#  'Subependymal Tissue',
#  'Corona Dentis',
#  'T-Lymphoblast',
#  'Multipotent Stem Cell',
#  'otolymph',
#  'visceral mesothelium',
#  'left lung hilus',
#  'stomach lesser curvature',
#  'Levator Palpebrae Superioris',
#  'Intercostal Nerve',
#  'maxillary vein',
#  'esophagus smooth muscle longitudinal layer',
#  'upper jaw incisor',
#  'ductus venosus',
#  'Anterior Olfactory Lobule',
#  'Endothelial Cell',
#  'Peroneal Nerve',
#  'third ventricle ependyma',
#  'Cricoarytenoid Joint',
#  'vastus medialis',
#  'myocardium',
#  'large intestine',
#  'Exocrine Gland',
#  'nucleus of trapezoid body',
#  'Intestinal Mucosa',
#  'Left Renal Artery',
#  'pericardiacoophrenic artery',
#  'right lung alveolus',
#  'Trigeminal Nucleus',
#  'external acoustic meatus',
#  'lens anterior epithelium',
#  'Frontal Sulcus',
#  'Activated Mature Cytotoxic T-Lymphocyte',
#  'Thyroid Gland Oxyphil Cell',
#  'Oxyphil Cell',
#  'Ductus Santorini',
#  'thyroid gland lobe',
#  'Ganglionic Layer',
#  'Acromial Thoracic Artery',
#  'stomach blind ventricular sac',
#  'Prostate Gland Secretion',
#  'Bronchus',
#  'olfactory tract',
#  'Epigastric Artery',
#  'inferior suprarenal vein',
#  'Plantar Fascia',
#  'foramen caecum',
#  'lower respiratory tract epithelium',
#  'Endothelium of the Glomerular Capillary',
#  'cerebral white matter',
#  'sartorius',
#  'Spermatozoon',
#  'Dentin',
#  'Acinar Salivary Gland System',
#  'coronary artery',
#  'Lymphatic Capillary',
#  'pulmonary vein',
#  'Left Colon',
#  'Genioglossus',
#  'arachnoid mater',
#  'Body Region',
#  'vagus nerve trunk',
#  "meckel's cartilage",
#  'Primitive Stem Cell with Some Degree of Commitment to the Erythroid Lineage',
#  'knee bone',
#  'hand digit',
#  'Temporal Lobe',
#  'Bronchial Tree',
#  'Erythroid Progenitor Cell',
#  'Nasal Nerve',
#  'tensor tympani',
#  'spleen marginal sinus',
#  'internal spermatic vein',
#  'Large Intestinal Muscularis Mucosa',
#  'right lung',
#  'mammary gland lobule',
#  'middle cervical ganglion',
#  'metatarsal bone digit 2',
#  'metacarpal bone digit 4',
#  'septal cortex',
#  'Tentorium Cerebelli',
#  'Cardia',
#  'retrochiasmatic area',
#  'parathyroid gland capsule',
#  'saphenous artery',
#  'liver acinus',
#  'uterine horn',
#  'cricoarytenoid',
#  'T-Immunoblast',
#  'Splenic Hilum',
#  'segmental bronchus epithelium',
#  'vestibulocochlear VIII ganglion vestibular component',
#  'bile canaliculus',
#  'External Pterygoid Muscle',
#  'pancreas head',
#  'vestibular aqueduct',
#  'taste bud',
#  'Small Intestinal Mucosa',
#  'Interlobular Artery',
#  'right common carotid artery',
#  'Ascending Aorta Branch',
#  'bile duct extrahepatic part',
#  'serum',
#  'Epigastric Region',
#  'Central Vein',
#  'other limb bone',
#  'thyroid gland right lobe',
#  'meninges',
#  'cerebellum external granule cell layer',
#  'upper arm skin',
#  'Left Common Carotid Artery',
#  'pulmonary artery',
#  'synchondrosis',
#  'medial marginal vein',
#  'Cervical Spinal Cord',
#  'Alveolar Epithelium',
#  'lower arm connective tissue',
#  'Posterior Temporal Artery',
#  'Anterior Wall of the Tympanum',
#  'ovary theca externa',
#  'Geniculate Ganglion',
#  'thoraco-acromial artery',
#  'hippocampus stratum radiatum',
#  'eyelid subcutaneous connective tissue',
#  'phrenic vein',
#  'Ascending Parietal Convolution',
#  'Sputum',
#  'Nostril',
#  'Dentate Gyrus',
#  'Foot Skin',
#  'retina inner nuclear layer',
#  'Frontal Artery',
#  'Ascending Limb of the Henle s Loop',
#  'Axillary Artery Branch',
#  'right renal vein',
#  'Suprasellar Region',
#  'pigmented retinal epithelium',
#  'upper back bone',
#  'Bronchus Cartilage',
#  'spinal cord dorsal column',
#  'posterior facial vein',
#  'Spermatocyte',
#  'Nipple',
#  'Basilar Artery Branch',
#  'trigeminal ganglion',
#  'Thymic B-Lymphocyte',
#  'Stratum Disjunctum',
#  'hand bone',
#  'anterior lingual gland',
#  'Buccal Mucosa',
#  'inferior epigastric artery',
#  'Sternoclavicular Joint',
#  'Axillary Tail of the Breast',
#  'maternal placental artery',
#  'Connective Tissue Proper',
#  'Gastric Vein',
#  'basilar membrane',
#  'Corpora Albicantia',
#  'Granulosa Cell',
#  'T-Prolymphocyte',
#  'vein',
#  'Peroneal Artery',
#  'Anterior Surface of the Prostate',
#  'outer canthus',
#  'guard hair',
#  'Foveolar Cell',
#  'palatal shelf',
#  'ilio-lumbar artery',
#  'Dorsal Curve',
#  'fat',
#  'Membrane of the Brain or Spinal Cord',
#  'Cervical Artery',
#  'extrinsic auricular muscle',
#  'Endocervix',
#  'lumbar vertebra',
#  'eye chamber',
#  'seminiferous tubule epithelium',
#  'small intestine villus',
#  'head or neck blood vessel',
#  'Endometrial Cavity',
#  'nephron',
#  'Quadratus Lumborum',
#  'upper arm nerve',
#  'inferior mesenteric artery',
#  'Lentiform Nucleus',
#  'Posterior External Jugular Vein',
#  'sensory organ',
#  'Inferior Palpebral Fold',
#  'abdomen',
#  'Internal Nare',
#  'Subscapular Artery',
#  'Peritoneal Mesothelial Cell',
#  'caudate-putamen',
#  'hand digit connective tissue',
#  'Interphalangeal Joint of the Foot',
#  'pons',
#  'Prepontine Cistern',
#  'back nerve',
#  'Central Sulcus of Rolando',
#  'Epicardium',
#  'carotid artery',
#  'Anatomic Surface',
#  'subscapular artery',
#  'hand digit nerve',
#  'Deep Lymphatic Vessel',
#  'lumbar vertebra 4',
#  'Spinal Cord Column',
#  'Inferior Temporal Gyrus',
#  'Hair Bulb',
#  'Pons Varolii',
#  'Gastric Tissue',
#  'Left Subcostal Vein',
#  'Pericardium',
#  'nail bed',
#  'Upper Jaw Tooth',
#  'middle temporal vein',
#  'Anterior Surface of the Stomach',
#  'Superficial Cervical Artery',
#  'Osteoblast',
#  'Postcentral Sulcus',
#  'Posterior Fossa',
#  'Musculoskeletal System Part',
#  'Mature Cytotoxic T-Lymphocyte',
#  'Transversus Thoracis',
#  'Duct Salivary Gland System',
#  'Ulna',
#  'Infratentorial Brain',
#  'Parotid Gland Lymph Node',
#  'neck muscle',
#  'Cricoarytenoid Muscle',
#  'hypogastric nerve plexus',
#  'Nucleus of the Solitary Tract',
#  'Hemispheric Cistern',
#  'spinal cord ventral column',
#  'Gastrointestinal System',
#  'hypoglossal XII nucleus',
#  'Conjunctiva',
#  'fornix',
#  'spinal ganglion or nerve',
#  'thoracic vertebra',
#  'Scapula',
#  'facial artery',
#  'Superficial Intracranial Venous System',
#  'stomach proventricular region',
#  'bronchus basal lamina',
#  'Visceral Layer of Bowman s Capsule',
#  'Middle Cerebral Artery Branch',
#  'Bronchus Basement Membrane',
#  'C3 Vertebra',
#  'Fascicle',
#  'Common Femoral Artery',
#  'larynx mucosa',
#  'tail vein',
#  'Obsolete Class',
#  'right hepatic duct',
#  'eyelid',
#  'ureter luminal urothelium',
#  'Ulnar Nerve',
#  'Primordial Follicle',
#  'head',
#  'head blood vessel',
#  'hair follicle',
#  'esophagus',
#  'Microcirculatory Bed',
#  'Flat Bone',
#  'Pancreatic Endocrine Secretion',
#  'adrenal vein',
#  'Tongue Skeletal Muscle Tissue',
#  'Large Intestinal Crypt of the Lieberkuhn',
#  'ureter adventitia',
#  'Inferior Palpebral Vein',
#  'Definition',
#  'central nervous system',
#  'reproductive organ',
#  'accessory XI nucleus',
#  'Eosinophil',
#  'esophagus muscularis mucosa',
#  'minor calyx',
#  'vestibulocochlear VIII nerve cochlear component',
#  'leg nerve',
#  'Testis',
#  'retinal artery',
#  'kidney interstitium',
#  'cervical vertebra 4',
#  'Radix Dentis',
#  'lingual tonsillar tissue',
#  'iliac circumflex artery',
#  'Brunner s Gland',
#  'eye posterior chamber',
#  'Lesser Tuberosity',
#  'temporal cortex',
#  'trigeminal motor nucleus',
#  'Skeletal Fiber',
#  'Anterior Meningeal Artery',
#  'Thymic Vein',
#  'trachea connective tissue',
#  'Obsolete Class',
#  'Gland',
#  'Cuboidal Cell',
#  'Superior Infratentorial Cistern',
#  'respiratory system venous smooth muscle',
#  'Internal Elastic Membrane',
#  'hip bone',
#  'blood vessel',
#  'Cardiac Nerve Plexus',
#  'phrenic nerve trunk',
#  'respiratory tract',
#  'scala vestibuli',
#  'sphenoid sinus',
#  'Tarsal Artery',
#  'Pericallosal Artery',
#  'Quadrigeminal Body',
#  'Cerebral Gyrus',
#  'masseter',
#  'tonsil',
#  'placenta metrial gland',
#  'Small Intestinal Serosal Surface',
#  'Cauda Equina',
#  'Femoral Nerve',
#  'Bladder',
#  'lip philtrum',
#  'Chest',
#  'vagus nerve right recurrent laryngeal branch',
#  'extensor digitorum communis',
#  'seminal vesicle secretion',
#  'Auricle',
#  'Central Canal',
#  'Axillary Nerve',
#  'main bronchus smooth muscle',
#  'Foot',
#  'Anal Canal',
#  'fovea',
#  'corneal epithelium',
#  'Promontory',
#  'common plantar digital arteries',
#  'digital vein',
#  'Palmar Hand Interosseus Muscle',
#  'inferior cerebral vein',
#  'Erector Spinae',
#  'Prostatic Portion of the Male Urethra',
#  'Histiocyte',
#  'inferior olive medial nucleus',
#  'knee',
#  'Body Fluid or Substance',
#  'lower leg muscle',
#  'large intestine serosa',
#  'Rib 1',
#  'integumental system gland',
#  'Herring Body',
#  'auricular artery',
#  'Other Anatomic Concept',
#  'Renal Pelvis',
#  'sternebra',
#  'arterial system endothelium',
#  'nucleus ambiguus',
#  'external acoustic meatus osseus part',
#  'cholinergic enteric nerve',
#  'claustrum',
#  'medial tarsal artery',
#  'Activated Lymphocyte',
#  'Lamina Lucida',
#  'Lipocyte',
#  'Bone Tissue',
#  'aqueous humour',
#  'descending colon',
#  'navicular',
#  'Medulla Oblongata',
#  'Lymph Node Trabecula',
#  'Chondroblast',
#  'lateral geniculate nucleus',
#  'gomphosis',
#  'Anterior Annular Ligament',
#  'Left Coronary Artery',
#  'sebaceous gland',
#  'semimembranosus',
#  'foot blood vessel',
#  'male reproductive gland or organ',
#  'Intestinal Secretion',
#  'Lymph Node Sinus',
#  'chest nerve',
#  'Hippocampal Fissure',
#  'Endocrine Cell and Neuroendocrine Cell',
#  'Spinal Accessory Nerve',
#  'Scalene Muscle',
#  'Dorsum of the Tongue',
#  'median vein',
#  'Vein Endothelium',
#  'cranium',
#  'anal region skeletal muscle',
#  'Fibula',
#  'Outer Supporting Cell',
#  'rib',
#  'Common Hepatic Duct',
#  'tibilais cranialis',
#  'vagina stroma',
#  'Mastoid Process',
#  'metacarpus',
#  'female membranous urethra',
#  'Spinal Artery',
#  'outflow tract aortic component',
#  'Lower Gastrointestinal Tract',
#  'venule',
#  'external anal sphincter',
#  'heart septum',
#  'Duodenum',
#  'sural vein',
#  'Frontal Horn of the Lateral Ventricle',
#  'spinal nerve plexus',
#  'Lacrimal Sac',
#  'Eustachian Valve',
#  'Memory B Cell',
#  'external acoustic meatus cartilaginous part',
#  'anterior division',
#  'trachea basement membrane',
#  'inner ear epithelium',
#  'eye surface',
#  'Thymus Medulla',
#  'auditory tube',
#  'seminal fluid',
#  'grey matter',
#  'Adrenal Fluid or Secretion',
#  'shoulder',
#  'Ductal Epithelium',
#  'pelvis blood vessel',
#  'Tibial Artery',
#  'Geniculate Body',
#  'brown fat',
#  'viscerocranium bone',
#  'bile duct',
#  'Splenic Artery',
#  'ovary',
#  'right lung alveolar system',
#  'Lymph Node by Anatomic Site',
#  'Bladder Muscular Coat',
#  'clavicle',
#  'Glomeruloza Zone',
#  'Interatrial Septum',
#  'Saccule',
#  'base of arytenoid',
#  'Ciliary Muscle',
#  'reticular tegmental nucleus',
#  'shoulder muscle',
#  'cerebellum internal granule cell layer',
#  'Sphincter Pupillae Muscle',
#  'Posterior Cerebral Artery Branch',
#  'Cortex',
#  'urethralis',
#  'spinal cord ventral horn',
#  'L3 Vertebra',
#  'constrictor muscle of pharynx',
#  'inguinal lymph node',
#  'connective tissue',
#  'stomach body',
#  'Caudate Nucleus',
#  'Knee Joint',
#  'ovary follicle fluid',
#  'olfactory bulb glomerular layer',
#  'spinal cord central canal',
#  'basisphenoid bone',
#  'Intrinsic Tongue Muscle Transverse Component',
#  'Perikaryon',
#  'ventral thalamus',
#  'nail',
#  'Area of Broca',
#  'superior vagus ganglion',
#  'accumbens nucleus',
#  'Colorectal Zone of the Anal Canal',
#  'Mamillary Body',
#  'Oculomotor Nucleus',
#  'Posterior Circumflex Artery',
#  'left vagus nerve trunk',
#  'skin',
#  'blood vessel smooth muscle',
#  'reproductive gland',
#  'hamstring muscle',
#  'sphincter colli superficialis',
#  'lateral ventricle subependymal layer',
#  'medial femoral circumflex artery',
#  'psoas major',
#  'Epithelial Receptor Cell',
#  'hindlimb blood vessel',
#  'Supra-orbital Vein',
#  'Prostatic Epithelium',
#  'Transverse Rectal Fold',
#  'rest of ureter',
#  'kidney subcortical veins',
#  'Superior Temporal Gyrus',
#  'Other Body Part',
#  'prostate gland anterior lobe',
#  'Subcapsular Epithelium of the Lens',
#  'alveolar sac',
#  'Gastrointestinal Sphincter',
#  'prepositus hypoglossal nucleus',
#  'oral epithelium',
#  'nasal mucus',
#  'pars posterior',
#  'distal straight tubule postmacula segment',
#  'superior sagittal sinus',
#  'Synovial Fluid',
#  'Urine',
#  'choroid plexus',
#  'Macrophage',
#  'Superior Wall of the Nasopharynx',
#  'ureter',
#  'Lateral Wall of the Oropharynx',
#  'Vascular Endothelium',
#  'cuboidal oviduct epithelium',
#  'Mammary Gland',
#  'Trachea Basement Membrane',
#  'Anterior Surface of the Lens',
#  'Precursor NK-Cell',
#  'autonomic nervous system',
#  'retina photoreceptor layer inner segment',
#  'appendicular skeleton',
#  'foot digit nerve',
#  'Umbilical Cord Blood Stem Cell',
#  'Metacarpal Bone',
#  'vagus nerve left recurrent laryngeal branch',
#  'pharynx epithelium',
#  'autopod joint',
#  'gastrointestinal system',
#  'Molecular Layer of the Cerebellum',
#  'Enterocyte',
#  'Cortical Vein',
#  'Thyroid Gland Epithelial Tissue',
#  'Alveolar Duct',
#  'renal cortex artery',
#  'Basaloid Cell',
#  'liver lobule',
#  'internal anal sphincter',
#  'Renal Cortex',
#  'Membranous Canal of the Cochlea',
#  'tuberomammillary nucleus',
#  'medial geniculate nucleus',
#  'Nephron',
#  'popliteal vein',
#  'Bile Duct Epithelium',
#  'Cleidocephalic',
#  'Bronchiole',
#  'Hematopoietic and Lymphoid Tissue',
#  'cerebellum lobule VIII',
#  'choroidal blood vessel',
#  'Intra-thoracic Lymph Node',
#  'bronchus reticular lamina',
#  'perilymph',
#  'cleidobrachial',
#  'anterior facial vein',
#  'trochlear nerve',
#  'vagina squamous epithelium',
#  'T11 Vertebra',
#  'Internal Parieto-occipital Fissure',
#  'Non-Granular Leukocyte',
#  'paranasal sinus',
#  'paracentral nucleus',
#  'Vagal Triangle',
#  'Large Intestinal Mucosa',
#  'inferior olive beta subnucleus',
#  'heart endocardium',
#  'respiratory bronchiole',
#  'extraglomerular mesangium',
#  'joint of girdle',
#  'Rib Tubercle',
#  'Vaginal Fornix',
#  'Long Bone Epiphysis',
#  'Sphincter Colli Superficialis',
#  'mouse anatomy',
#  'lower jaw incisor',
#  'Mesenteric Artery',
#  'Auditory Ossicle',
#  'Medial Vestibular Nucleus',
#  'Granulocyte',
#  'Submucosal Tissue of Human Prostate',
#  'primary choana',
#  'Pituitary Gland',
#  'ureteric artery',
#  'left lung bronchiole',
#  'Renal Afferent Vessel',
#  'right lung cranial lobe',
#  'pancreas',
#  'External Plantar Artery',
#  'Esophageal Artery',
#  'upper leg bone',
#  'epidermis',
#  'Radius Bone',
#  'coat hair bulb',
#  'Left Lung',
#  'Diaphragm Part',
#  'frontal association cortex',
#  'Lower Eyelid',
#  'Hepatic Tissue',
#  'Palmar Region',
#  'Transitional Zone of the Prostatic Parenchyma',
#  'Alveolar Wall',
#  'Posterior Semicircular Canal',
#  'renal tubule',
#  'median artery palmar branch',
#  'leg skin',
#  'Thyroepiglottic Ligament',
#  'Cricothyroid Muscle',
#  'Heart Septum',
#  'Pharyngeal Tonsil',
#  'Ovarian Vein',
#  'pericardial fluid',
#  'Auricular Artery',
#  'Muscle and Fasciae of the Thorax',
#  'Appendage of the Uterus',
#  'mammary gland smooth muscle',
#  'Elastin Fiber',
#  'Space of Fontana',
#  'anterior thalamic group',
#  'right renal artery',
#  'Chromophobe Cell',
#  'vas deferens smooth muscle',
#  'Tract of Burdach',
#  'distal convoluted tubule',
#  'maxillary artery',
#  'Oculomotor Nerve',
#  'Endocrine Sex Organ',
#  'visceral serous pericardium',
#  'adductor group (leg)',
#  'intestine muscularis mucosa',
#  'Surface of the Prostate',
#  'dorsal venous arch',
#  'lesser omentum',
#  'nerve',
#  'artery endothelium',
#  'sesamoid bone',
#  'Ventricle Brain',
#  'Cervical Nerve',
#  'Merkel Cell',
#  'Superior Temporal Sulcus',
#  'bronchiole',
#  'ocular angle artery',
#  'Stratum Lucidum',
#  'Tympanic Membrane',
#  'joint',
#  'portal vein',
#  'neck organ',
#  'septal coronary artery',
#  'heart ventricle membranous part',
#  'dorsal metatarsal vein',
#  'Lobe of the Left Lung',
#  'Suprachorioid Lamina',
#  'Brachial Artery',
#  'Artery Smooth Muscle Tissue',
#  'Rostrum of the Corpus Callosum',
#  'Internal Intercostal Muscle',
#  'renal straight tubule',
#  'dorsal vena of penis',
#  'Lymphoid Blood-Forming Cell',
#  'peritoneal cavity greater sac',
#  'septohippocampal nucleus',
#  'tensor fasciae lata',
#  'glomerular capillary basement membrane',
#  'Anterior Inferior Frontal Convolution',
#  'Temporo-maxillary Vein',
#  'celiac ganglion',
#  'proper palmal digital arteries',
#  'genioglossus',
#  'female urethral meatus',
#  'frontal bone',
#  'outer renal medulla',
#  'forelimb nerve',
#  'Inferior Thyroid Artery',
#  'Cementocyte',
#  'lateral ventricle',
#  'thorax connective tissue',
#  'hair cortex',
#  'Anterior Part of the Calcarine Fissure',
#  'Nasal Cavity',
#  'girdle bone',
#  'Inferior Internal Articular Artery',
#  'Synonym',
#  'Sinus of Valsava',
#  'major palatine artery',
#  'Hymen',
#  'Tunica Intima',
#  'Meniscus Medialis',
#  'longissimus cervicis',
#  'hepatic duct extrahepatic part',
#  'descending aorta',
#  'cerumen',
#  'hindlimb muscle',
#  'Subependymal Cell',
#  'Shoulder',
#  'Epithelioid Cell',
#  'peripheral nerve',
#  'Postero-lateral Fissure',
#  'Transverse Colon',
#  'Rib 7',
#  'colostrum',
#  'Middle Cuneiform Bone of the Foot',
#  'prostate gland smooth muscle',
#  'gigantocellular reticular nucleus',
#  'uterus',
#  'Seromucous Salivary Gland',
#  'Large Intestinal Submucosa',
#  'penis foreskin',
#  'globus pallidus',
#  'Dorsal Hand Interosseous Muscle',
#  'medial saphenous vein',
#  'Thermoreceptor',
#  'Enteric Ganglion',
#  'Second Portion of the Duodenum',
#  'dorsal mesogastrium',
#  'Cochlear Duct',
#  'Vitreous Body',
#  'Pre-B Lymphocyte',
#  'Esophagus',
#  'Lateral Orbitofrontal Artery',
#  'Large Intestinal Serosal Surface',
#  'Exocrine Pancreas',
#  'lower back nerve',
#  'inguinal mammary gland',
#  'vas deferens',
#  'Lateral Wall of the Bladder',
#  'Vaginal Epithelium',
#  'liver bare area',
#  'Vestibular Hair Cell',
#  'Hepatobiliary System',
#  'scapholunate',
#  'body fluid or substance',
#  'Supratentorial Cistern',
#  'Extensor Carpi Ulnaris',
#  'Neuroendocrine Cell',
#  'Pia Mater',
#  'Fenestra Rotunda',
#  'right lung lobe',
#  'cerebellar vein',
#  'endometrium glandular epithelium',
#  'Myeloid Cell',
#  'uterine cervix',
#  'thoracic vertebra 4',
#  'Anterior Descending Coronary Artery',
#  'CD8 Plus T-Lymphocyte',
#  'thymus trabecula',
#  'omohyoid',
#  'brachial artery',
#  'spinal cord meninges',
#  'kidney',
#  'rib 10',
#  'liver quadrate lobe',
#  'Longissimus Cervicis',
#  'Quadrigeminal Cistern',
#  'loop of henle ascending limb thick segment',
#  'Peripheral Nerve',
#  'foot bone',
#  'forebrain arachnoid mater',
#  'hyaloid vascular plexus',
#  'Medial Palpebral Ligament',
#  'Body of the Corpus Callosum',
#  'inferior rectal artery',
#  'thoracic cavity connective tissue',
#  'Superior Parathyroid Gland',
#  'Liver Acinus',
#  "small intestine peyer's patch",
#  'respiratory system',
#  'sural artery',
#  'Pancreatic Acinus',
#  'Superficial Cervical Lymph Node',
#  'Intercostal Fascia',
#  'Thymocyte',
#  'rib 12',
#  'urogenital muscle',
#  'spinal cord dorsal nucleus',
#  'Lymphatic Vessel',
#  'maxilla',
#  'Nucleus of the Spinal Tract of the Trigeminal Nerve',
#  'Other Body Fluids and Secretions',
#  'Spinal Nerve Root',
#  'Antrum Pylori',
#  'neck connective tissue',
#  'superior vesical artery',
#  'renal cortex tubule',
#  'Cochlea',
#  'shoulder connective tissue',
#  'spermatic vein',
#  'Coccygeal Vertebra',
#  'pharynx muscle',
#  'Enamel',
#  'Ileal Vein',
#  'right lung caudal lobe',
#  'Genito-urinary Region',
#  'small intestine submucosa',
#  'corneal blood vessel',
#  'Vertebral Canal',
#  'Lung Tissue',
#  'Circular Ligament of the Tooth',
#  'medial femoral vein',
#  'Cuneiform Cartilage',
#  'Tongue',
#  'Thymic Lymphoid Tissue',
#  'kidney arterial blood vessel',
#  'forelimb joint',
#  'Cardiac Vein',
#  'median cubital vein',
#  'optic disc',
#  'Foot Bone',
#  'Femoral Artery Branch',
#  'Sensory Hair',
#  'heart valve',
#  'Male Breast',
#  'Bone Surface',
#  'Mullerian Duct',
#  'trachea non-cartilage connective tissue',
#  'Postgerminal Center Marginal Zone B-Lymphocyte',
#  'Epineurium',
#  'Superior Palpebral Fold',
#  'Basement Membrane',
#  'Megakaryoblast',
#  'adrenal gland zona reticularis',
#  'cervicothoracic ganglion',
#  'Spinal Nerve Plexus',
#  'Anterior Horn Cell',
#  'Thoracic Esophagus',
#  'coat hair',
#  'distal rib',
#  'foot digit connective tissue',
#  'metatarsal bone digit 4',
#  'retina nerve fiber layer',
#  'auricular ligament',
#  'part of afferent arteriole forming juxtaglomerular complex',
#  'Brain Stem',
#  'impulse conducting system',
#  'harderian gland',
#  'Foot Digit',
#  'female reproductive system fluid or secretion',
#  'adrenal gland capsule',
#  'male urethra ostium',
#  'kidney collecting duct',
#  'respiratory system basal lamina',
#  'bronchiole epithelium',
#  'pelvis skin',
#  'hepatic portal vein',
#  'spinal cord basal nucleus',
#  'metacarpal bone digit 2',
#  'Helper-Inducer T-Lymphocyte',
#  'Interstitial Cell',
#  'Anterior Median Fissure of Spinal Cord',
#  'brachialis',
#  'Lumbar Sympathetic Nerve Trunk',
#  'Communicating Artery',
#  'Costal Arch',
#  'lateral rectus extraocular muscle',
#  'brain arachnoid matter',
#  'os penis',
#  'Processus Cochleariformis',
#  'stomach glandular region mucous membrane',
#  'inferior cervical ganglion',
#  'vesical artery',
#  'Retinal Artery',
#  'Meninges',
#  'substantia nigra pars reticulata',
#  'Meniscus Lateralis',
#  'Terminal Bar',
#  'Putamen',
#  'Sacral Vertebra',
#  'Platysma Myoides',
#  'Node of Bizzozero',
#  'Spleen Germinal Center',
#  'Orbit',
#  'Female Reproductive System Part',
#  'Theca Cell',
#  'lung',
#  'Tonsil',
#  'pontine nucleus',
#  'Meningothelial Cell',
#  'Bone Marrow Myeloid Stem Cell with Predominant Neutrophil Differentiation',
#  'lobar bronchus epithelium',
#  'Lobe',
#  'Splenic Pulp',
#  'internal spiral sulcus',
#  'laterodorsal tegmental nucleus',
#  'Tract of Lissauer',
#  'trunk',
#  'Semimembranosus',
#  'Nitrergic Neuron',
#  'respiratory system venous blood vessel',
#  'Superior Thoracic Artery',
#  'Innominate Vein',
#  'styloglossus',
#  'sympathetic nervous system',
#  'Subclavian Artery',
#  'kidney pelvis smooth muscle',
#  'Anterior Olfactory Nucleus',
#  'clitoral gland',
#  'trigeminal nerve ophthalmic division',
#  'Nerve',
#  'Periurethral Zone of the Prostatic Parenchyma',
#  'Bladder Transitional Cell Epithelium',
#  'stomach smooth muscle',
#  'brain grey matter',
#  'hippocampus',
#  'Metatarsal Bone Digit 5',
#  'medial tarsal vein',
#  'Ileum',
#  'tricuspid valve',
#  'Depressor Labii Inferioris',
#  'Substantia Gelatinosa',
#  'gastrointestinal system mucosa',
#  'dermis adipose tissue',
#  'Lobule of the Auricle',
#  'Dentition',
#  'Fibroblast',
#  'External Acoustic Meatus',
#  'hair cuticle',
#  'Lateral Ventricle',
#  'trachea elastic framework',
#  'dermis connective tissue',
#  'Inner Hair Cell of the Organ of the Corti',
#  'Cardia Orifice',
#  'S1 Vertebra',
#  'small intestine smooth muscle',
#  'Postcentral Gyrus',
#  'thyroid artery',
#  'cardiac muscle tissue',
#  'Germinal Center',
#  'Gingiva',
#  'Gonadotroph Cell',
#  'Posterior Spinal Artery',
#  'outflow tract smooth muscle',
#  'articular cartilage',
#  'Nonphotosensitive Region of the Retina',
#  'Torcular Herophilli',
#  'Mesangium',
#  'Bronchiole Epithelium',
#  "barrington's nucleus",
#  'Amygdala',
#  'Histiocytic and Dendritic Cell',
#  'Osteoid',
#  'Leg',
#  'Left Suprarenal Vein',
#  'lateral ventricle choroid plexus stroma',
#  'Adenohypophysial Cell',
#  'Cutaneous Trunci',
#  'Cerebellar Cortex',
#  'Decidua Capsularis',
#  'Cowper s Gland',
#  'lymphatic vessel endothelium',
#  'Interstitial Cell of Cajal',
#  'Oropharynx',
#  'Bone of the Extremity',
#  'Gland of Krause',
#  'Middle Occipital Convolution',
#  'Cerebral Fissure',
#  'Anterior Eye Segment',
#  'lens equatorial epithelium',
#  'gastrointestinal system lamina propria',
#  'Fascia',
#  'left testis',
#  'Papillary Muscle',
#  'trigeminal nerve lingual branch',
#  'Basophilic Cell',
#  'Tunica Vasculosa',
#  'zigzag hair',
#  'Plantar Foot Interosseus Muscle',
#  'Vertebral Vein',
#  'Anterior Parietal Artery',
#  ...]

# %%
def path_to_root(elem, ont_mappings):
    if elem not in ont_mappings or not ont_mappings[elem]:
        return []
    output = ont_mappings[elem] + path_to_root(ont_mappings[elem][0], ont_mappings)
    return output


def get_one_hop_neighbours(ont, K=1):
    ont_obj = Ontology(ont)
    triples = ont_obj.get_triples()
#     print (triples)
    entities = [(a,b) for (a,b,c) in triples]
    neighbours_dict = {elem: [elem] for elem in list(set(flatten(entities)))}
    for e1, e2 in entities:
        neighbours_dict[e1].append(e2)
        neighbours_dict[e2].append(e1)
    
    rootpath_dict = ont_obj.parents_dict
    rootpath_dict = {elem: path_to_root(elem, rootpath_dict) for elem in rootpath_dict}
    ont = ont.split("/")[-1].split(".")[0]
    
    for entity in neighbours_dict:
        if entity in rootpath_dict and len(rootpath_dict[entity]) > 0:
            neighbours_dict[entity].extend(rootpath_dict[entity])
        else:
            continue
    
#     prop_triples = ont_obj.get_triples(subclass_of=False)
#     neighbours_dict_props = {c: [c] for a,b,c in prop_triples}
#     for e1, e2, p in prop_triples:
#         neighbours_dict_props[p].extend([e1, e2])

    #neighbours_dict = {**neighbours_dict, **neighbours_dict_props}
    
    # for elem in ont_obj.get_entities() + ont_obj.get_object_properties() + ont_obj.get_data_properties():
    #     if elem not in neighbours_dict:
    #         neighbours_dict[elem] = [elem]

    neighbours_dict = {el: neighbours_dict[el][:1] + sorted(list(set(neighbours_dict[el][1:])))
                       for el in neighbours_dict}
#     neighbours_dict = {el: neighbours_dict[el][:23] for el in neighbours_dict if len( neighbours_dict[el]) > 2}
    
    neighbours_dict = {ont + "#" + el: [ont + "#" + e for e in neighbours_dict[el]] for el in neighbours_dict}
    return neighbours_dict

neighbours_dicts = {ont.split("/")[-1].split(".")[0]: get_one_hop_neighbours(ont) for ont in list(set(flatten(ontologies_in_alignment)))}
max_neighbours = np.max(flatten([[len(el[e]) for e in el] for el in neighbours_dicts.values()]))
neighbours_lens = {ont: {key: len(neighbours_dicts[ont][key]) for key in neighbours_dicts[ont]}
                   for ont in neighbours_dicts}
neighbours_dicts = {ont: {key: neighbours_dicts[ont][key] + ["<UNK>" for i in range(max_neighbours -len(neighbours_dicts[ont][key]))]
              for key in neighbours_dicts[ont]} for ont in neighbours_dicts}

ontologies_in_alignment = [[el.split("/")[-1].split(".")[0] for el in ont] for ont in ontologies_in_alignment]
f = open("../data_generic_rootpath.pkl", "wb")
pickle.dump([data, emb_indexer, emb_indexer_inv, emb_vals, gt_mappings, neighbours_dicts, ontologies_in_alignment], f)
# Out:
# error list index out of range

# %%
# AML test
def is_test(test_onto, key):
    return tuple([el.split("#")[0] for el in key]) in test_onto

results = []
all_ont_pairs = list(set([tuple([el.split("#")[0] for el in l]) for l in data.keys()]))
for i in list(range(0, len(all_ont_pairs), 3)):
    test_onto = all_ont_pairs[i:i+3]
    for ont_pair in test_onto:
        a, b, c = ont_pair[0], ont_pair[1], ont_pair[0] + "-" + ont_pair[1]
        java_command = "java -jar AML_v3.1/AgreementMakerLight.jar -s conference_ontologies/" + a + ".owl" + \
                            " -t conference_ontologies/" + b + ".owl -o AML-test-results/" + c + ".rdf -a"
        process = subprocess.Popen(java_command.split(), stdout=subprocess.PIPE)
        output, error = process.communicate()
    print (os.listdir("AML-test-results/"))
    pred_aml = load_alignments("AML-test-results/")
    pred_aml = [tuple([el.split("/")[-1] for el in key]) for key in pred_aml]
    tp = len([elem for elem in pred_aml if data[elem]])
    fn = len([key for key in gt_mappings if key not in set(pred_aml) and is_test(test_onto, key)])
    fp = len([elem for elem in pred_aml if not data[elem]])

    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    f1score = 2 * precision * recall / (precision + recall)
    f2score = 5 * precision * recall / (4 * precision + recall)
    f0_5score = 1.25 * precision * recall / (0.25 * precision + recall)
    print (precision, recall, f1score, f2score, f0_5score)
    
    metrics = [precision, recall, f1score, f2score, f0_5score]
    results.append(metrics)
    
    _ = [os.remove(f) for f in glob.glob('AML-test-results/*')]
    
print ("Final Results:", np.mean(results, axis=0))
# Out:
# ['confOf-sigkdd.rdf', 'iasted-sigkdd.rdf', 'cmt-ekaw.rdf']
# 0.8275862068965517 0.7272727272727273 0.7741935483870968 0.7453416149068324 0.8053691275167786
# ['confOf-iasted.rdf', 'conference-edas.rdf', 'cmt-sigkdd.rdf']
# 0.8148148148148148 0.5789473684210527 0.6769230769230768 0.6145251396648045 0.7534246575342465
# ['ekaw-sigkdd.rdf', 'conference-sigkdd.rdf', 'conference-confOf.rdf']
# 0.78125 0.6097560975609756 0.684931506849315 0.6377551020408163 0.7396449704142012
# ['confOf-edas.rdf', 'edas-iasted.rdf', 'cmt-conference.rdf']
# 0.7941176470588235 0.5094339622641509 0.6206896551724137 0.548780487804878 0.7142857142857143
# ['edas-sigkdd.rdf', 'conference-iasted.rdf', 'ekaw-iasted.rdf']
# 0.7916666666666666 0.48717948717948717 0.6031746031746031 0.5277777777777778 0.7037037037037036
# ['cmt-confOf.rdf', 'cmt-edas.rdf', 'edas-ekaw.rdf']
# 0.8181818181818182 0.5192307692307693 0.6352941176470589 0.5601659751037344 0.733695652173913
# ['conference-ekaw.rdf', 'confOf-ekaw.rdf', 'cmt-iasted.rdf']
# 0.7954545454545454 0.7142857142857143 0.7526881720430106 0.7291666666666666 0.7777777777777778
# Final Results: [0.80329596 0.59230088 0.67827067 0.62335897 0.74684309]

# %%
ontologies_in_alignment = [[el.split("/")[1].split(".")[0] for el in ont] for ont in ontologies_in_alignment][:-1] + [["human", "mouse"]]

# %%
for i in list(range(0, len(ontologies_in_alignment)-1, 3)):
    
    test_onto = ontologies_in_alignment[i:i+3]
    print (test_onto)
# Out:
# [['conference', 'ekaw'], ['confOf', 'ekaw'], ['ekaw', 'sigkdd']]
# [['edas', 'sigkdd'], ['confOf', 'sigkdd'], ['iasted', 'sigkdd']]
# [['confOf', 'iasted'], ['conference', 'iasted'], ['confOf', 'edas']]
# [['edas', 'iasted'], ['conference', 'edas'], ['cmt', 'ekaw']]
# [['cmt', 'confOf'], ['cmt', 'edas'], ['conference', 'sigkdd']]
# [['cmt', 'sigkdd'], ['conference', 'confOf'], ['edas', 'ekaw']]
# [['cmt', 'conference'], ['cmt', 'iasted'], ['ekaw', 'iasted']]

# %%
[[el for el in neighbours_dicts[ont] if len(neighbours_dicts[ont][el]) == 156] for ont in neighbours_dicts]
# Out:
# [[], [], [], [], [], [], ['human#Brain_Part'], [], []]

# %%
def count_non_unk(elem):
    return len([l for l in elem if l!="<UNK>"])
neighbours_dicts = {ont: {el: neighbours_dicts[ont][el][:int(sys.argv[1])] for el in neighbours_dicts[ont]
       if count_non_unk(neighbours_dicts[ont][el]) > int(sys.argv[2])} for ont in neighbours_dicts}
# Out:
# (167, 1240)

# %%
a = torch.randn((1,22,512))
b = torch.randn((1,1,512))
W_sub = nn.Linear(512, 1)

att_weights = W_sub(a - b.squeeze(1)[:, None]).squeeze(-1)

# %%
fn, fp = pickle.load(open("test_results.pkl", "rb"))

# %%
max_neighbours
# Out:
# 156

# %%
pickle.dump([fn, fp], open("test_best.pkl", "wb"))

# %%
Ontology("../Anatomy/Ontologies/mouse.owl").triples
# Out:
# [('tail muscle', 'muscle', 'subclass_of'),
#  ('nail', 'Thing', 'subclass_of'),
#  ('loop of henle ascending limb thick segment',
#   'distal straight tubule macula densa',
#   'part_of'),
#  ('heart', 'mesocardium', 'part_of'),
#  ('third ventricle', 'third ventricle choroid plexus', 'part_of'),
#  ('cerebral cortex', 'neocortex', 'part_of'),
#  ('outer renal medulla', 'outer medulla inner stripe', 'part_of'),
#  ('external anal sphincter', 'skeletal muscle', 'subclass_of'),
#  ('cerebellar cortex', 'cerebellar hemisphere', 'part_of'),
#  ('upper leg nerve', 'leg nerve', 'subclass_of'),
#  ('bronchus basement membrane', 'bronchus basal lamina', 'part_of'),
#  ('internal spermatic artery', 'artery', 'subclass_of'),
#  ('respiratory bronchiole', 'bronchiole', 'subclass_of'),
#  ('kidney cortex', 'renal cortex tubule', 'part_of'),
#  ('semicircular canal', 'semicircular duct', 'part_of'),
#  ('hindbrain', 'myelencephalon', 'part_of'),
#  ('hindlimb', 'foot', 'part_of'),
#  ('limb muscle', 'muscle', 'subclass_of'),
#  ('intrinsic tongue muscle', 'skeletal muscle', 'subclass_of'),
#  ('hematopoietic system', 'blood', 'part_of'),
#  ('brain grey matter', 'grey matter', 'subclass_of'),
#  ('olfactory bulb external plexiform layer', 'Thing', 'subclass_of'),
#  ('autopod', 'Thing', 'subclass_of'),
#  ('superior colliculus', 'Thing', 'subclass_of'),
#  ('nail', 'nail plate', 'part_of'),
#  ('tegmentum', 'nucleus related to visual cortex', 'part_of'),
#  ('urethra epithelium', 'Thing', 'subclass_of'),
#  ('parietal mesothelium', 'mesothelium', 'subclass_of'),
#  ('principal nucleus', 'Thing', 'subclass_of'),
#  ('sclera', 'Thing', 'subclass_of'),
#  ('hindlimb nerve', 'limb nerve', 'subclass_of'),
#  ('cerebellum lobule IX', 'Thing', 'subclass_of'),
#  ('limb', 'stylopod', 'part_of'),
#  ('pelvis', 'pelvis blood vessel', 'part_of'),
#  ('endometrium luminal epithelium', 'Thing', 'subclass_of'),
#  ('gastrointestinal system', 'oral region', 'part_of'),
#  ('spinal cord ependymal layer', 'Thing', 'subclass_of'),
#  ('intrahepatic part of right hepatic duct', 'Thing', 'subclass_of'),
#  ('myometrium', 'Thing', 'subclass_of'),
#  ("hassall's corpuscle", 'Thing', 'subclass_of'),
#  ('interpeduncular nucleus', 'brainstem nucleus', 'subclass_of'),
#  ('vulva', 'clitoris', 'part_of'),
#  ('white matter', 'Thing', 'subclass_of'),
#  ('urinary bladder', 'urinary bladder fundus region', 'part_of'),
#  ('face', 'mouth', 'part_of'),
#  ('body cavity', 'Thing', 'subclass_of'),
#  ('inner renal medulla', 'Thing', 'subclass_of'),
#  ('brain', 'choroid plexus', 'part_of'),
#  ('cerebellar hemisphere', 'cerebellum anterior lobe', 'part_of'),
#  ('spinal cord', 'spinal cord lateral motor column', 'part_of'),
#  ('superior vesical artery', 'vesical artery', 'subclass_of'),
#  ('longissimus cervicis', 'skeletal muscle', 'subclass_of'),
#  ('main bronchus', 'main bronchus connective tissue', 'part_of'),
#  ('pharynx epithelium', 'Thing', 'subclass_of'),
#  ('left lung respiratory bronchiole', 'left lung bronchiole', 'subclass_of'),
#  ('gastric vein', 'vein', 'subclass_of'),
#  ('respiratory system lymphatic vessel',
#   'respiratory system lymphatic vessel smooth muscle',
#   'part_of'),
#  ('spleen trabeculum', 'Thing', 'subclass_of'),
#  ('serratus dorsalis cranialis', 'skeletal muscle', 'subclass_of'),
#  ('kidney', 'kidney calyx', 'part_of'),
#  ('neocortex', 'neocortex layer', 'part_of'),
#  ('proximal convoluted tubule', 'renal convoluted tubule', 'subclass_of'),
#  ('hippocampus', 'hippocampus region', 'part_of'),
#  ('penile urethra fossa terminalis', 'Thing', 'subclass_of'),
#  ('hand', 'hand digit', 'part_of'),
#  ('ureter subluminal urothelium', 'Thing', 'subclass_of'),
#  ('hand digit blood vessel', 'Thing', 'subclass_of'),
#  ('palpebral conjunctiva', 'Thing', 'subclass_of'),
#  ('medial thalamic group', 'Thing', 'subclass_of'),
#  ('nephron', 'renal tubule', 'part_of'),
#  ('brain ventricular zone', 'Thing', 'subclass_of'),
#  ('middle colic artery', 'artery', 'subclass_of'),
#  ('thoracic aorta', 'arch of aorta', 'part_of'),
#  ('septal cortex', 'subfornical organ', 'part_of'),
#  ('small intestine smooth muscle',
#   'small intestine smooth muscle longitudinal layer',
#   'part_of'),
#  ('respiratory system', 'visceral organ system', 'subclass_of'),
#  ('neck cartilage', 'neck connective tissue', 'subclass_of'),
#  ('bed nucleus of stria terminalis', 'anterior division', 'part_of'),
#  ('midbrain', 'midbrain periaqueductal grey', 'part_of'),
#  ('foot digit 2 phalanx', 'foot phalanx', 'subclass_of'),
#  ('midbrain', 'tectum', 'part_of'),
#  ('lower back blood vessel',
#   'abdomen/pelvis/perineum blood vessel',
#   'subclass_of'),
#  ('organ system', 'Thing', 'subclass_of'),
#  ('metatarsal bone digit 5', 'metatarsal bone', 'subclass_of'),
#  ('vagus X nerve',
#   'vagus X nerve right recurrent laryngeal branch',
#   'part_of'),
#  ('carpal bone', 'carpal/tarsal bone', 'subclass_of'),
#  ('midline thalamic group', 'Thing', 'subclass_of'),
#  ('temporal cortex', 'auditory cortex', 'part_of'),
#  ('cranial/facial muscle', 'head muscle', 'subclass_of'),
#  ('right lung alveolar duct', 'Thing', 'subclass_of'),
#  ('hand', 'hand blood vessel', 'part_of'),
#  ('brain', 'brain grey matter', 'part_of'),
#  ('sciatic nerve', 'hindlimb nerve', 'subclass_of'),
#  ('male reproductive system', 'efferent duct', 'part_of'),
#  ('buccal artery', 'artery', 'subclass_of'),
#  ('intestine serosa', 'large intestine serosa', 'part_of'),
#  ('ophthalmic plexus', 'vein', 'subclass_of'),
#  ('vertebra caudal articular process', 'Thing', 'subclass_of'),
#  ('superior cerebellar artery', 'cerebellar artery', 'subclass_of'),
#  ('spinal cord dorsal horn', 'Thing', 'subclass_of'),
#  ('ischiatic vein', 'vein', 'subclass_of'),
#  ('back', 'Thing', 'subclass_of'),
#  ('segmental bronchus', 'bronchus', 'subclass_of'),
#  ('stomach', 'abdomen organ', 'subclass_of'),
#  ('telencephalon meninges', 'Thing', 'subclass_of'),
#  ('spleen trabeculum', 'spleen trabecular artery', 'part_of'),
#  ('hand digit', 'hand digit skin', 'part_of'),
#  ('hypogastric nerve plexus', 'autonomic nerve plexus', 'subclass_of'),
#  ('omental bursa', 'omental bursa superior recess', 'part_of'),
#  ('urogenital muscle', 'pelvis muscle', 'subclass_of'),
#  ('middle ear', 'auditory bone', 'part_of'),
#  ('pelvic girdle muscle', 'pelvis muscle', 'subclass_of'),
#  ('nail', 'hyponychium', 'part_of'),
#  ('stria vascularis', 'Thing', 'subclass_of'),
#  ('limb', 'limb bone', 'part_of'),
#  ('spinal cord', 'spinal cord central canal', 'part_of'),
#  ('midgut', 'gut', 'subclass_of'),
#  ('thymus subcapsular epithelium', 'thymus epithelium', 'subclass_of'),
#  ('inguinal mammary gland', 'female reproductive gland/organ', 'subclass_of'),
#  ('raphe magnus nucleus', 'brainstem nucleus', 'subclass_of'),
#  ('cervix squamous epithelium', 'cervix epithelium', 'subclass_of'),
#  ('lower respiratory tract connective tissue',
#   'bronchus connective tissue',
#   'part_of'),
#  ('bone', 'bone marrow', 'part_of'),
#  ('upper back', 'upper back skin', 'part_of'),
#  ('parietal cortex', 'primary motor cortex', 'part_of'),
#  ('lateral geniculate nucleus', 'Thing', 'subclass_of'),
#  ('vagus X nerve trunk', 'left vagus X nerve trunk', 'part_of'),
#  ('falciform ligament', 'ligament', 'subclass_of'),
#  ('pancreas', 'pancreas parenchyma', 'part_of'),
#  ('pleura', 'cavity lining', 'subclass_of'),
#  ('intervertebral disc', 'connective tissue', 'subclass_of'),
#  ('posterior tibial artery', 'tibial artery', 'subclass_of'),
#  ('meninges', 'arachnoid mater', 'part_of'),
#  ('spinal cord pia mater', 'pia mater', 'subclass_of'),
#  ('intrinsic nerve plexus', 'nerve plexus', 'subclass_of'),
#  ('retina internal limiting lamina', 'retina lamina', 'subclass_of'),
#  ('knee skin', 'hindlimb skin', 'subclass_of'),
#  ('retina nerve fiber layer', 'retina layer', 'subclass_of'),
#  ('barrel cortex', 'Thing', 'subclass_of'),
#  ('ureter', 'rest of ureter', 'part_of'),
#  ('olfactory system', 'nose', 'part_of'),
#  ('midbrain pia mater', 'brain pia mater', 'subclass_of'),
#  ('transversus abdominis', 'skeletal muscle', 'subclass_of'),
#  ('neocortex', 'Thing', 'subclass_of'),
#  ('foot', 'metatarsus', 'part_of'),
#  ('thoracic vertebra 9', 'thoracic vertebra', 'subclass_of'),
#  ('hippocampus molecular layer', 'hippocampus layer', 'subclass_of'),
#  ('lienal artery', 'artery', 'subclass_of'),
#  ('thorax organ', 'trunk organ', 'subclass_of'),
#  ('urinary bladder lamina propria',
#   'urinary bladder muscularis mucosa',
#   'part_of'),
#  ('tibial vein', 'vein', 'subclass_of'),
#  ('spinal cord ventral horn', 'Thing', 'subclass_of'),
#  ('foot digit', 'foot digit blood vessel', 'part_of'),
#  ('mesenteric vein', 'vein', 'subclass_of'),
#  ('urinary bladder', 'urinary bladder serosa', 'part_of'),
#  ('ventral nasal vein', 'vein', 'subclass_of'),
#  ('foot digit skin', 'Thing', 'subclass_of'),
#  ('oculomotor muscle', 'extraocular skeletal muscle', 'subclass_of'),
#  ('vagina stroma', 'Thing', 'subclass_of'),
#  ('musculoskeletal system', 'skeletal system', 'part_of'),
#  ('digestive system', 'gastrointestinal system', 'part_of'),
#  ('oral epithelium', 'gastrointestinal system epithelium', 'subclass_of'),
#  ('limb', 'anatomic region', 'subclass_of'),
#  ('olfactory lobe', 'olfactory cortex', 'part_of'),
#  ('penis', 'male reproductive gland/organ', 'subclass_of'),
#  ('nerve plexus', 'Thing', 'subclass_of'),
#  ('spiral sulcus', 'internal spiral sulcus', 'part_of'),
#  ('maxillary artery', 'artery', 'subclass_of'),
#  ('tectum', 'corpora quadrigemina', 'part_of'),
#  ('hypothalamus periventricular zone',
#   'paraventricular hypothalamic nucleus',
#   'part_of'),
#  ('sphenoid sinus', 'paranasal sinus', 'subclass_of'),
#  ('ulna', 'forelimb long bone', 'subclass_of'),
#  ('eye surface', 'Thing', 'subclass_of'),
#  ('heart ventricle muscular part', 'Thing', 'subclass_of'),
#  ('tibilais cranialis', 'tibialis muscle', 'subclass_of'),
#  ('lower respiratory tract', 'lower respiratory tract epithelium', 'part_of'),
#  ('foot', 'autopod', 'subclass_of'),
#  ('bulbourethral gland secretion', 'Thing', 'subclass_of'),
#  ('intestine wall', 'large intestine wall', 'part_of'),
#  ('right lung', 'lung', 'subclass_of'),
#  ('auricular muscle', 'Thing', 'subclass_of'),
#  ('hand digit 3', 'hand digit', 'subclass_of'),
#  ('abdomen', 'abdomen muscle', 'part_of'),
#  ('cerebellar vermis', 'cerebellum lobule III', 'part_of'),
#  ('peripheral nervous system', 'spinal ganglion/nerve', 'part_of'),
#  ('upper back', 'Thing', 'subclass_of'),
#  ('medial septal nucleus', 'Thing', 'subclass_of'),
#  ('arm', 'arm nerve', 'part_of'),
#  ('tonsil', 'oropharyngeal lymphoid tissue', 'subclass_of'),
#  ('vertebra cranial articular process', 'Thing', 'subclass_of'),
#  ('urinary bladder mucosa', 'Thing', 'subclass_of'),
#  ('hepatic duct smooth muscle', 'Thing', 'subclass_of'),
#  ('glomerular visceral epithelium', 'Thing', 'subclass_of'),
#  ('inner renal medulla loop of henle', 'loop of henle bend', 'part_of'),
#  ('intestine mucosa', 'large intestine mucosa', 'part_of'),
#  ('adipose tissue', 'subcutaneous adipose tissue', 'part_of'),
#  ('parietal cortex', 'secondary somatosensory cortex', 'part_of'),
#  ('spinal cord lateral motor column', 'Thing', 'subclass_of'),
#  ('limb long bone', 'long bone epiphysis', 'part_of'),
#  ('other limb bone', 'limb bone', 'subclass_of'),
#  ('mammary gland', 'areola', 'part_of'),
#  ('lacrimal apparatus', 'lacrimal sac', 'part_of'),
#  ('kidney venous blood vessel', 'kidney blood vessel', 'subclass_of'),
#  ('nasal mucus', 'respiratory system fluid/secretion', 'subclass_of'),
#  ('gall bladder', 'gall bladder smooth muscle', 'part_of'),
#  ('cerebellar vermis', 'cerebellum lobule VIII', 'part_of'),
#  ('sacral vertebra 4', 'sacral vertebra', 'subclass_of'),
#  ('pterygoid bone', 'chondrocranium bone', 'subclass_of'),
#  ('spinal cord meninges', 'meninges', 'subclass_of'),
#  ('head/neck nerve/ganglion', 'Thing', 'subclass_of'),
#  ('upper back', 'upper back muscle', 'part_of'),
#  ('hair root sheath', 'hair root sheath matrix', 'part_of'),
#  ('tibia', 'lower leg bone', 'subclass_of'),
#  ('lower urinary tract', 'Thing', 'subclass_of'),
#  ('coronary artery', 'heart blood vessel', 'subclass_of'),
#  ('external naris', 'primary choana', 'part_of'),
#  ('perilymphatic channel', 'scala vestibuli', 'part_of'),
#  ('choroid plexus epithelium', 'Thing', 'subclass_of'),
#  ('head/neck muscle', 'muscle', 'subclass_of'),
#  ('renal/urinary system', 'visceral organ system', 'subclass_of'),
#  ('thoracic cavity', 'thoracic cavity organ', 'part_of'),
#  ('right kidney', 'kidney', 'subclass_of'),
#  ('lobar bronchus', 'bronchus', 'subclass_of'),
#  ('chondrocranium', 'fontanel', 'part_of'),
#  ('renal cortex tubule', 'distal straight tubule macula densa', 'part_of'),
#  ('renal connecting tubule', 'renal tubule', 'subclass_of'),
#  ('nerve', 'Thing', 'subclass_of'),
#  ('vomeronasal organ', 'vomeronasal organ sensory epithelium', 'part_of'),
#  ('spermatic vein', 'vein', 'subclass_of'),
#  ('alveolar wall', 'alveolus epithelium', 'part_of'),
#  ('kidney cortex', 'juxtaglomerular complex', 'part_of'),
#  ('lip', 'lip skeletal muscle', 'part_of'),
#  ('hindlimb', 'hindlimb joint', 'part_of'),
#  ('jugular vein', 'vein', 'subclass_of'),
#  ('outer medulla outer stripe loop of henle',
#   'proximal straight tubule',
#   'part_of'),
#  ('ilium', 'hip bone', 'subclass_of'),
#  ('left spermatic artery', 'spermatic artery', 'subclass_of'),
#  ('central nervous system', 'meninges', 'part_of'),
#  ('spinal cord', 'spinal cord ependymal layer', 'part_of'),
#  ('pupil', 'pupillary membrane', 'part_of'),
#  ('orbicularis oculi', 'skeletal muscle', 'subclass_of'),
#  ('hepatic duct intrahepatic part',
#   'intrahepatic part of right hepatic duct',
#   'part_of'),
#  ('thymus epithelium', 'Thing', 'subclass_of'),
#  ('modiolus', 'Thing', 'subclass_of'),
#  ("remnant of Rathke's pouch", 'Thing', 'subclass_of'),
#  ('liver lobule', 'bile canaliculus', 'part_of'),
#  ('vas deferens', 'vas deferens smooth muscle', 'part_of'),
#  ('pancreatic islet', 'pancreatic islet core', 'part_of'),
#  ('glomerulus', 'glomerular visceral epithelium', 'part_of'),
#  ('gastrointestinal system mucosa', 'Thing', 'subclass_of'),
#  ('spleen lymphoid follicle', 'Thing', 'subclass_of'),
#  ('spiral organ', 'reticular lamina', 'part_of'),
#  ('vibrissa inner root sheath', 'Thing', 'subclass_of'),
#  ('viscerocranium', 'viscerocranium bone', 'part_of'),
#  ('superior gluteal artery', 'artery', 'subclass_of'),
#  ('liver lobule', 'Thing', 'subclass_of'),
#  ('sympathetic nervous system', 'sympathetic nerve trunk', 'part_of'),
#  ('mesothelium', 'body cavity/lining', 'subclass_of'),
#  ('mandible', 'viscerocranium bone', 'subclass_of'),
#  ('fungiform papilla', 'tongue papilla', 'subclass_of'),
#  ('lower back bone', 'back bone', 'subclass_of'),
#  ('adenohypophysis', "remnant of Rathke's pouch", 'part_of'),
#  ('dorsal mesocardium', 'mesocardium', 'subclass_of'),
#  ('cardiovascular system', 'heart', 'part_of'),
#  ('female reproductive system', 'oviduct', 'part_of'),
#  ('inferior olive beta subnucleus', 'Thing', 'subclass_of'),
#  ('arteriole smooth muscle', 'arterial system smooth muscle', 'subclass_of'),
#  ('external naris', 'external naris epithelium', 'part_of'),
#  ('loop of henle ascending limb',
#   'loop of henle ascending limb thick segment',
#   'part_of'),
#  ('left spermatic vein', 'spermatic vein', 'subclass_of'),
#  ('vestibular membrane', 'Thing', 'subclass_of'),
#  ('penile urethra cavernous portion', 'Thing', 'subclass_of'),
#  ('oral region', 'tooth', 'part_of'),
#  ('third ventricle ependyma', 'brain ependyma', 'subclass_of'),
#  ('urethra', 'pelvis organ', 'subclass_of'),
#  ('tail connective tissue', 'connective tissue', 'subclass_of'),
#  ('coat hair', 'hair shaft', 'part_of'),
#  ('vagus X nerve trunk', 'right vagus X nerve trunk', 'part_of'),
#  ('lung surfactant', 'respiratory system fluid/secretion', 'subclass_of'),
#  ('epidermis', 'Thing', 'subclass_of'),
#  ('left testis', 'testis', 'subclass_of'),
#  ('hand digit 1', 'hand digit', 'subclass_of'),
#  ('carotid artery', 'artery', 'subclass_of'),
#  ('internal carotid artery', 'carotid artery', 'subclass_of'),
#  ('gastrointestinal system epithelium', 'Thing', 'subclass_of'),
#  ('inguinal lymph node', 'lymph node', 'subclass_of'),
#  ('foramen caecum', 'Thing', 'subclass_of'),
#  ('salivary gland', 'exocrine gland', 'subclass_of'),
#  ('parotidoauricular', 'skeletal muscle', 'subclass_of'),
#  ('lingual tonsillar tissue', 'tonsil', 'subclass_of'),
#  ('inferior epigastric artery', 'artery', 'subclass_of'),
#  ('upper back nerve', 'back nerve', 'subclass_of'),
#  ('olfactory gland', 'Thing', 'subclass_of'),
#  ('intestine mucosa', 'gastrointestinal system mucosa', 'subclass_of'),
#  ('cleidooccipital', 'skeletal muscle', 'subclass_of'),
#  ('lacrimal apparatus', 'Thing', 'subclass_of'),
#  ('omental bursa', 'Thing', 'subclass_of'),
#  ('humerus', 'forelimb long bone', 'subclass_of'),
#  ('long bone metaphysis', 'Thing', 'subclass_of'),
#  ('plasma', 'Thing', 'subclass_of'),
#  ('blood vessel smooth muscle', 'Thing', 'subclass_of'),
#  ('thorax blood vessel', 'trunk blood vessel', 'subclass_of'),
#  ('vibrissa hair bulb', 'vibrissa root sheath', 'part_of'),
#  ('brachial plexus', 'forelimb nerve', 'subclass_of'),
#  ('area postrema', 'Thing', 'subclass_of'),
#  ('ascending aorta', 'Thing', 'subclass_of'),
#  ('proximal nail bed', 'Thing', 'subclass_of'),
#  ('larynx epithelium', 'respiratory system epithelium', 'subclass_of'),
#  ('hindbrain arachnoid mater', 'brain arachnoid matter', 'subclass_of'),
#  ('lacrimal apparatus', 'nasolacrimal duct', 'part_of'),
#  ('olfactory cortex', 'Thing', 'subclass_of'),
#  ('ear', 'head organ', 'subclass_of'),
#  ('hand digit 4', 'hand digit', 'subclass_of'),
#  ('cerebellum purkinje cell layer', 'cerebellar layer', 'subclass_of'),
#  ('small intestine', 'small intestine mesentery', 'part_of'),
#  ('jaw', 'upper jaw', 'part_of'),
#  ('superior mesenteric vein', 'mesenteric vein', 'subclass_of'),
#  ('vesicular gland', 'male reproductive gland', 'subclass_of'),
#  ('body cavity/lining', 'body cavity', 'part_of'),
#  ('lower back muscle', 'back muscle', 'subclass_of'),
#  ('scala vestibuli', 'Thing', 'subclass_of'),
#  ('nail', 'nail matrix', 'part_of'),
#  ('urinary bladder', 'pelvis organ', 'subclass_of'),
#  ('pancreas lobe', 'Thing', 'subclass_of'),
#  ('upper back bone', 'thorax bone', 'subclass_of'),
#  ('hip bone', 'hindlimb bone', 'subclass_of'),
#  ('tibial nerve', 'peripheral nerve', 'subclass_of'),
#  ('nasolacrimal duct', 'Thing', 'subclass_of'),
#  ('joint articular surface', 'Thing', 'subclass_of'),
#  ('proximal straight tubule', 'renal proximal tubule', 'subclass_of'),
#  ('trigeminal V principal sensory nucleus',
#   'trigeminal V sensory nucleus',
#   'subclass_of'),
#  ('mandible', 'mandible squamous part', 'part_of'),
#  ('kidney cortex', 'renal cortex collecting duct', 'part_of'),
#  ('thoracic vertebra 10', 'thoracic vertebra', 'subclass_of'),
#  ('respiratory system connective tissue',
#   'respiratory system lamina propria',
#   'part_of'),
#  ('vas deferens', 'vas deferens epithelium', 'part_of'),
#  ('heart right ventricle', 'right ventricle muscular part', 'part_of'),
#  ('renal vein', 'vein', 'subclass_of'),
#  ('cerebellum external granule cell layer',
#   'cerebellum granule cell layer',
#   'subclass_of'),
#  ('spleen', 'spleen smooth muscle', 'part_of'),
#  ('bony labyrinth', 'osseus semicircular canal', 'part_of'),
#  ('ankle', 'ankle skin', 'part_of'),
#  ('metacarpal bone', 'hand bone', 'subclass_of'),
#  ('limb', 'limb connective tissue', 'part_of'),
#  ('enteric nervous system', 'intrinsic nerve plexus', 'part_of'),
#  ('mammary gland smooth muscle', 'Thing', 'subclass_of'),
#  ('thoracic vertebra 13', 'thoracic vertebra', 'subclass_of'),
#  ('left ventricle membranous part',
#   'heart ventricle membranous part',
#   'subclass_of'),
#  ('synovial fluid', 'body fluid/substance', 'subclass_of'),
#  ('head skin', 'head/neck skin', 'subclass_of'),
#  ('small intestine', 'small intestine crypt of lieberkuhn', 'part_of'),
#  ('corpus callosum', 'intercerebral commissure', 'subclass_of'),
#  ('fourth ventricle', 'fourth ventricle choroid plexus', 'part_of'),
#  ('habenula', 'Thing', 'subclass_of'),
#  ('arteriole', 'arteriole smooth muscle', 'part_of'),
#  ('bile duct', 'bile duct epithelium', 'part_of'),
#  ('upper back', 'upper back connective tissue', 'part_of'),
#  ('upper leg connective tissue', 'leg connective tissue', 'subclass_of'),
#  ('palate', 'hard palate', 'part_of'),
#  ('ureteric tip', 'kidney collecting duct', 'subclass_of'),
#  ('skin', 'epidermis', 'part_of'),
#  ('abdomen/pelvis/perineum', 'abdomen', 'part_of'),
#  ('retrohippocampal cortex', 'medial entorhinal cortex', 'part_of'),
#  ('femur', 'hindlimb long bone', 'subclass_of'),
#  ('hindlimb', 'limb', 'subclass_of'),
#  ('brachial plexus', 'radial nerve', 'part_of'),
#  ('bronchus connective tissue', 'Thing', 'subclass_of'),
#  ('deep temporal vein', 'temporal vein', 'subclass_of'),
#  ('abdomen/pelvis/perineum', 'pelvis', 'part_of'),
#  ('serous pericardium', 'Thing', 'subclass_of'),
#  ('thoracic cavity vein', 'thoracic cavity blood vessel', 'subclass_of'),
#  ('radial nerve', 'arm nerve', 'subclass_of'),
#  ('prostate gland ventral lobe', 'prostate gland lobe', 'subclass_of'),
#  ('scapholunate', 'lunate', 'part_of'),
#  ('seminiferous tubule epithelium', 'Thing', 'subclass_of'),
#  ('limb', 'limb blood vessel', 'part_of'),
#  ('knee', 'knee connective tissue', 'part_of'),
#  ('hypothalamus lateral zone', 'perifornical nucleus', 'part_of'),
#  ('lumbar vertebra 3', 'lumbar vertebra', 'subclass_of'),
#  ('ovary stratum granulosum', 'Thing', 'subclass_of'),
#  ('metatarsus', 'metatarsal bone', 'part_of'),
#  ('penis skin', 'penis foreskin', 'part_of'),
#  ('bile duct intrahepatic part', 'intralobular bile duct', 'part_of'),
#  ('temporal cortex', 'temporal cortex association area', 'part_of'),
#  ('celiac artery', 'artery', 'subclass_of'),
#  ('cerebellum', 'deep cerebellar nucleus', 'part_of'),
#  ('midbrain dura mater', 'brain dura mater', 'subclass_of'),
#  ('epidermis stratum granulosum', 'Thing', 'subclass_of'),
#  ('limb', 'limb digit', 'part_of'),
#  ('hypoglossal XII nerve', 'cranial nerve', 'subclass_of'),
#  ('respiratory system', 'respiratory system connective tissue', 'part_of'),
#  ('esophagus mucosa', 'esophagus epithelium', 'part_of'),
#  ('mammary gland sebaceous gland', 'sebaceous gland', 'subclass_of'),
#  ('medial habenular nucleus', 'Thing', 'subclass_of'),
#  ('ankle', 'ankle joint', 'part_of'),
#  ('forebrain', 'forebrain meninges', 'part_of'),
#  ('spinal cord central canal', 'Thing', 'subclass_of'),
#  ('back', 'back nerve', 'part_of'),
#  ('stomach smooth muscle', 'stomach smooth muscle circular layer', 'part_of'),
#  ('pharynx muscle', 'Thing', 'subclass_of'),
#  ('lower respiratory tract',
#   'lower respiratory tract smooth muscle',
#   'part_of'),
#  ('rib', 'rib ventral segment', 'part_of'),
#  ('salivary duct', 'Thing', 'subclass_of'),
#  ('vagina', 'vagina smooth muscle', 'part_of'),
#  ('brain', 'forebrain', 'part_of'),
#  ('respiratory system', 'oral region', 'part_of'),
#  ('small intestine smooth muscle circular layer', 'Thing', 'subclass_of'),
#  ('kidney medulla', 'outer renal medulla', 'part_of'),
#  ('prepuce', 'prepuce epithelium', 'part_of'),
#  ('lateral ventricle', 'lateral ventricle subependymal layer', 'part_of'),
#  ('heart endocardium', 'cardiovascular system endothelium', 'subclass_of'),
#  ('foot digit blood vessel', 'Thing', 'subclass_of'),
#  ('bronchus', 'bronchus smooth muscle', 'part_of'),
#  ('ankle', 'ankle connective tissue', 'part_of'),
#  ('prostate gland', 'male reproductive gland/organ', 'subclass_of'),
#  ('foot digit', 'foot interdigit region', 'part_of'),
#  ('left lung hilus', 'Thing', 'subclass_of'),
#  ('lienal vein', 'vein', 'subclass_of'),
#  ('cornea', 'corneal stroma', 'part_of'),
#  ('outer medulla outer stripe loop of henle', 'Thing', 'subclass_of'),
#  ('hippocampus layer', 'Thing', 'subclass_of'),
#  ('distal convoluted tubule convoluted part', 'Thing', 'subclass_of'),
#  ('semispinalis cervicis', 'skeletal muscle', 'subclass_of'),
#  ('right lung alveolar system', 'right lung alveolar duct', 'part_of'),
#  ('medial tarsal vein', 'vein', 'subclass_of'),
#  ('midline thalamic group', 'paraventricular thalamic nucleus', 'part_of'),
#  ('pancreatic islet', 'pancreatic islet mantle', 'part_of'),
#  ('arcuate nucleus', 'Thing', 'subclass_of'),
#  ('bronchus', 'thoracic cavity organ', 'subclass_of'),
#  ('adipose tissue', 'connective tissue', 'subclass_of'),
#  ('parietal cortex', 'neocortex region', 'subclass_of'),
#  ('immune system', 'organ system', 'subclass_of'),
#  ('ileocolic vein', 'vein', 'subclass_of'),
#  ('mammillary body', 'medial mammillary nucleus', 'part_of'),
#  ('spleen', 'spleen hilum', 'part_of'),
#  ('aortic valve', 'heart valve', 'subclass_of'),
#  ('epigastric vein', 'vein', 'subclass_of'),
#  ('external acoustic meatus',
#   'external acoustic meatus cartilaginous part',
#   'part_of'),
#  ('lateral ventricle choroid plexus', 'choroid plexus', 'subclass_of'),
#  ('oropharynx', 'Thing', 'subclass_of'),
#  ('brachiocephalic trunk', 'artery', 'subclass_of'),
#  ('thoracic cavity blood vessel', 'thorax blood vessel', 'subclass_of'),
#  ('tooth', 'Thing', 'subclass_of'),
#  ('cerebellar hemisphere', 'flocculus', 'part_of'),
#  ('extensor carpi radialis brevis', 'skeletal muscle', 'subclass_of'),
#  ('semicircular canal', 'osseus semicircular canal', 'part_of'),
#  ('abdominal mammary gland', 'abdomen organ', 'subclass_of'),
#  ('temporal cortex association area', 'Thing', 'subclass_of'),
#  ('wrist joint', 'forelimb joint', 'subclass_of'),
#  ('midbrain', 'pretectal region', 'part_of'),
#  ('outer renal medulla',
#   'outer renal medulla peritubular capillary',
#   'part_of'),
#  ('uvea', 'choroid', 'part_of'),
#  ('small intestine crypt of lieberkuhn', 'crypt of lieberkuhn', 'subclass_of'),
#  ('rib', 'rib tubercle', 'part_of'),
#  ('forelimb digital veins', 'vein', 'subclass_of'),
#  ('laryngeal extrinsic muscle', 'larynx muscle', 'subclass_of'),
#  ('bronchus submucosa', 'bronchus connective tissue', 'subclass_of'),
#  ('sensory organ', 'Thing', 'subclass_of'),
#  ('vestibular labyrinth', 'saccule', 'part_of'),
#  ('telencephalon pia mater', 'forebrain pia mater', 'subclass_of'),
#  ('common carotid artery', 'carotid artery', 'subclass_of'),
#  ('premaxilla', 'oral region cartilage/bone', 'subclass_of'),
#  ('metacarpus', 'Thing', 'subclass_of'),
#  ('testicular artery', 'artery', 'subclass_of'),
#  ('superior external pudendal vein', 'pudendal vein', 'subclass_of'),
#  ('third ventricle choroid plexus stroma',
#   'choroid plexus stroma',
#   'subclass_of'),
#  ('renal papilla', 'Thing', 'subclass_of'),
#  ('renal convoluted tubule', 'renal tubule', 'subclass_of'),
#  ('chest bone', 'thorax bone', 'subclass_of'),
#  ('vestibulocochlear VIII ganglion vestibular component',
#   'Thing',
#   'subclass_of'),
#  ('female reproductive system', 'vulva', 'part_of'),
#  ('rib 1', 'rib', 'subclass_of'),
#  ('parathyroid gland', 'endocrine gland', 'subclass_of'),
#  ('lower back nerve', 'abdomen/pelvis/perineum nerve', 'subclass_of'),
#  ('central nervous system', 'cranial ganglion/nerve', 'part_of'),
#  ('gall bladder', 'abdomen organ', 'subclass_of'),
#  ('distal convoluted tubule', 'renal cortex tubule', 'subclass_of'),
#  ('brain ependyma', 'Thing', 'subclass_of'),
#  ('nervous system', 'peripheral nervous system', 'part_of'),
#  ('ventral nasal artery', 'artery', 'subclass_of'),
#  ('head/neck', 'head/neck connective tissue', 'part_of'),
#  ('hemolymphoid system', 'hematopoietic system', 'part_of'),
#  ('cerebellar vermis', 'cerebellum lobule II', 'part_of'),
#  ('trunk blood vessel', 'blood vessel', 'subclass_of'),
#  ('respiratory system', 'respiratory tract', 'part_of'),
#  ('tegmentum', 'parabigeminal nucleus', 'part_of'),
#  ('respiratory system basal lamina', 'Thing', 'subclass_of'),
#  ('eye', 'ocular refractive media', 'part_of'),
#  ('hand phalanx', 'hand digit bone', 'subclass_of'),
#  ('cartilaginous joint', 'cartilaginous joint suture', 'part_of'),
#  ('superior olivary nucleus', 'brainstem nucleus', 'subclass_of'),
#  ('stapes', 'auditory bone', 'subclass_of'),
#  ('utricle', 'macula of utricle', 'part_of'),
#  ('iris', 'iris nerve', 'part_of'),
#  ('prostate gland', 'prostate gland epithelium', 'part_of'),
#  ('head/neck skin', 'skin', 'subclass_of'),
#  ('adenohypophysis', 'Thing', 'subclass_of'),
#  ('venule endothelium', 'venous system endothelium', 'subclass_of'),
#  ('intrinsic tongue muscle vertical component',
#   'intrinsic tongue muscle',
#   'subclass_of'),
#  ('glans penis', 'Thing', 'subclass_of'),
#  ('pons', 'ventral tegmental nucleus', 'part_of'),
#  ('hair medulla', 'Thing', 'subclass_of'),
#  ('outflow tract', 'outflow tract endothelium', 'part_of'),
#  ('communicating artery', 'artery', 'subclass_of'),
#  ('eye', 'eye muscle', 'part_of'),
#  ('urethral sphincter', 'Thing', 'subclass_of'),
#  ('outflow tract', 'outflow tract pericardium', 'part_of'),
#  ('liver lobe', 'Thing', 'subclass_of'),
#  ('occipital bone', 'chondrocranium bone', 'subclass_of'),
#  ('coat hair follicle', 'hair follicle', 'subclass_of'),
#  ('efferent lymphatic vessel', 'lymphatic vessel', 'subclass_of'),
#  ('striatum', 'caudate-putamen', 'part_of'),
#  ('loop of henle ascending limb thick segment',
#   'distal straight tubule postmacula segment',
#   'part_of'),
#  ('descending aorta', 'Thing', 'subclass_of'),
#  ('medial entorhinal cortex', 'Thing', 'subclass_of'),
#  ('laryngeal intrinsic ligament', 'larynx ligament', 'subclass_of'),
#  ('eyelid', 'eyelid blood vessel', 'part_of'),
#  ('lower back skin', 'back skin', 'subclass_of'),
#  ('bronchiole', 'Thing', 'subclass_of'),
#  ('glossopharyngeal IX nerve', 'cranial nerve', 'subclass_of'),
#  ('thoracic aorta', 'ascending aorta', 'part_of'),
#  ('trigeminal V mesencephalic nucleus',
#   'trigeminal V sensory nucleus',
#   'subclass_of'),
#  ('clitoral gland', 'female reproductive gland', 'subclass_of'),
#  ('distal straight tubule premacula segment', 'Thing', 'subclass_of'),
#  ('hematopoietic system', 'thymus', 'part_of'),
#  ('bed nucleus of stria terminalis', 'posterior division', 'part_of'),
#  ('psoas minor', 'psoas muscle', 'subclass_of'),
#  ('occipital cortex', 'neocortex region', 'subclass_of'),
#  ('inner renal medulla', 'inner renal medulla loop of henle', 'part_of'),
#  ('temporal bone petrous part', 'Thing', 'subclass_of'),
#  ('shoulder', 'shoulder skin', 'part_of'),
#  ('outer ear', 'Thing', 'subclass_of'),
#  ('interalveolar septum', 'Thing', 'subclass_of'),
#  ('right dorsal aorta', 'Thing', 'subclass_of'),
#  ('telencephalon dura mater', 'forebrain dura mater', 'subclass_of'),
#  ('lateral thoracic artery', 'artery', 'subclass_of'),
#  ('oral region', 'gingiva', 'part_of'),
#  ('head/neck connective tissue', 'connective tissue', 'subclass_of'),
#  ('forelimb', 'arm', 'part_of'),
#  ('axial skeleton', 'rib', 'part_of'),
#  ('brain', 'brainstem', 'part_of'),
#  ('ciliary body', 'ciliary epithelium', 'part_of'),
#  ('gall bladder', 'gall bladder serosa', 'part_of'),
#  ('skin', 'Thing', 'subclass_of'),
#  ('kidney calyx', 'Thing', 'subclass_of'),
#  ('quadriceps', 'skeletal muscle', 'subclass_of'),
#  ('eye', 'eye surface', 'part_of'),
#  ('vibrissa root sheath', 'Thing', 'subclass_of'),
#  ('nasopharynx epithelium', 'pharynx epithelium', 'subclass_of'),
#  ('cerebellar cortex', 'Thing', 'subclass_of'),
#  ('eye anterior chamber', 'aqueous humour', 'part_of'),
#  ('adductor group (leg)', 'skeletal muscle', 'subclass_of'),
#  ('abdomen skin', 'abdomen/pelvis/perineum skin', 'subclass_of'),
#  ('thoracic cavity', 'thoracic cavity connective tissue', 'part_of'),
#  ('cerebral artery', 'artery', 'subclass_of'),
#  ('renal connecting tubule', 'renal cortex tubule', 'subclass_of'),
#  ('liver parenchyma', 'portal triad', 'part_of'),
#  ('afferent arteriole',
#   'part of afferent arteriole forming juxtaglomerular complex',
#   'part_of'),
#  ('sacral vertebra 2', 'sacral vertebra', 'subclass_of'),
#  ('abdomen nerve', 'abdomen/pelvis/perineum nerve', 'subclass_of'),
#  ('vomer bone', 'viscerocranium bone', 'subclass_of'),
#  ('proximal tubule segment 2', 'Thing', 'subclass_of'),
#  ('intestine', 'small intestine', 'part_of'),
#  ('larynx cartilage', 'larynx connective tissue', 'subclass_of'),
#  ('upper back', 'upper back bone', 'part_of'),
#  ('alveolar duct', 'Thing', 'subclass_of'),
#  ('pharynx', 'nasopharynx', 'part_of'),
#  ('internal spiral sulcus', 'Thing', 'subclass_of'),
#  ('liver left lobe', 'liver lobe', 'subclass_of'),
#  ('scapula', 'pectoral girdle bone', 'subclass_of'),
#  ('descending colon', 'colon', 'subclass_of'),
#  ('lip philtrum', 'Thing', 'subclass_of'),
#  ('bile', 'digestive system fluid/secretion', 'subclass_of'),
#  ('external ear cartilage', 'yellow elastic cartilage', 'subclass_of'),
#  ('subclavian artery', 'artery', 'subclass_of'),
#  ('heart septum', 'Thing', 'subclass_of'),
#  ('minor calyx', 'kidney calyx', 'subclass_of'),
#  ('common hepatic duct', 'Thing', 'subclass_of'),
#  ('brain meninges', 'meninges', 'subclass_of'),
#  ('true rib', 'rib', 'subclass_of'),
#  ('common iliac vein', 'iliac vein', 'subclass_of'),
#  ('stomach muscularis mucosa', 'Thing', 'subclass_of'),
#  ('hypothalamus periventricular zone', 'Thing', 'subclass_of'),
#  ('inguinal mammary gland', 'mammary gland', 'subclass_of'),
#  ('medial femoral artery', 'femoral artery', 'subclass_of'),
#  ('caudal vertebra', 'vertebra', 'subclass_of'),
#  ('foot digit nerve', 'Thing', 'subclass_of'),
#  ('sciatic nerve', 'leg nerve', 'subclass_of'),
#  ('pancreas head', 'Thing', 'subclass_of'),
#  ('spiral sulcus', 'external spiral sulcus', 'part_of'),
#  ('limb connective tissue', 'connective tissue', 'subclass_of'),
#  ('anal canal caudal part', 'Thing', 'subclass_of'),
#  ('lateral reticular nucleus', 'brainstem nucleus', 'subclass_of'),
#  ('radio-carpal joint', 'wrist joint', 'subclass_of'),
#  ('spleen central arteriole', 'Thing', 'subclass_of'),
#  ('pupillary membrane', 'Thing', 'subclass_of'),
#  ('skeletal system', 'joint', 'part_of'),
#  ('dental papilla', 'Thing', 'subclass_of'),
#  ('pons', 'peduncular pontine nucleus', 'part_of'),
#  ('saccule epithelium', 'Thing', 'subclass_of'),
#  ('spiral ligament', 'ligament', 'subclass_of'),
#  ('larynx ligament', 'ligament', 'subclass_of'),
#  ('foot muscle', 'hindlimb muscle', 'subclass_of'),
#  ('epiglottic cartilage', 'larynx cartilage', 'subclass_of'),
#  ('femoral vein', 'vein', 'subclass_of'),
#  ('internal spermatic vein', 'vein', 'subclass_of'),
#  ('endocardial cushion', 'Thing', 'subclass_of'),
#  ('reticular lamina', 'Thing', 'subclass_of'),
#  ('digastric', 'skeletal muscle', 'subclass_of'),
#  ('gastrointestinal system serosa', 'Thing', 'subclass_of'),
#  ('coccygeus', 'skeletal muscle', 'subclass_of'),
#  ('interchondral joint', 'joint of rib', 'subclass_of'),
#  ('incisor', 'tooth', 'subclass_of'),
#  ('nervous system', 'nerve plexus', 'part_of'),
#  ('pancreatico-duodenal vein', 'vein', 'subclass_of'),
#  ('tuberal area', 'ventromedial hypothalamic nucleus', 'part_of'),
#  ('hand blood vessel', 'forelimb blood vessel', 'subclass_of'),
#  ('thyroid gland medulla', 'Thing', 'subclass_of'),
#  ('ulnar sesamoid bone', 'sesamoid bone', 'subclass_of'),
#  ('perineal artery', 'artery', 'subclass_of'),
#  ('endometrium epithelium', 'endometrium glandular epithelium', 'part_of'),
#  ('gonadal fat pad', 'fat pad', 'subclass_of'),
#  ('inferior olive', 'inferior olive principal nucleus', 'part_of'),
#  ('renal/urinary system', 'kidney', 'part_of'),
#  ('mesangium', 'Thing', 'subclass_of'),
#  ('inferior palpebral vein', 'vein', 'subclass_of'),
#  ('eye', 'retina', 'part_of'),
#  ('esophagus serosa', 'gastrointestinal system serosa', 'subclass_of'),
#  ('eye', 'head organ', 'subclass_of'),
#  ('taste bud', 'Thing', 'subclass_of'),
#  ('heart left atrium', 'left atrium auricular region', 'part_of'),
#  ('supramammillary nucleus', 'Thing', 'subclass_of'),
#  ('renal corpuscle', 'urinary space', 'part_of'),
#  ('vertebra', 'vertebra dorsal arch', 'part_of'),
#  ('incisive bone', 'viscerocranium bone', 'subclass_of'),
#  ('bronchus basal lamina', 'Thing', 'subclass_of'),
#  ('bronchus smooth muscle',
#   'lower respiratory tract smooth muscle',
#   'subclass_of'),
#  ('optic stalk', 'Thing', 'subclass_of'),
#  ('stomach glandular region mucous membrane', 'Thing', 'subclass_of'),
#  ('hand phalanx', 'phalanx', 'subclass_of'),
#  ('thyroid gland', 'thyroid gland isthmus', 'part_of'),
#  ('inferior olive medial accessory nucleus', 'Thing', 'subclass_of'),
#  ('parafascicular nucleus', 'Thing', 'subclass_of'),
#  ('endolymph', 'otolymph', 'subclass_of'),
#  ('yellow elastic cartilage', 'elastic cartilage', 'subclass_of'),
#  ('trunk', 'trunk connective tissue', 'part_of'),
#  ('septal cortex', 'lateral septal complex', 'part_of'),
#  ('uterus', 'reproductive organ', 'subclass_of'),
#  ('thorax muscle', 'trunk muscle', 'subclass_of'),
#  ('outflow tract pulmonary component proximal part', 'Thing', 'subclass_of'),
#  ('myometrium', 'myometrium inner circular layer', 'part_of'),
#  ('anterior olfactory nucleus', 'Thing', 'subclass_of'),
#  ('popliteal lymph node', 'lymph node', 'subclass_of'),
#  ('proximal convoluted tubule',
#   'proximal convoluted tubule convoluted part',
#   'part_of'),
#  ('choroid plexus', 'choroid plexus epithelium', 'part_of'),
#  ('pulmonary nerve plexus', 'autonomic nerve plexus', 'subclass_of'),
#  ('hindlimb digital veins', 'vein', 'subclass_of'),
#  ('skeletal muscle', 'skeletal muscle tissue', 'part_of'),
#  ('frontal association cortex', 'Thing', 'subclass_of'),
#  ('maxilla', 'viscerocranium bone', 'subclass_of'),
#  ('inferior vesical vein', 'vesical vein', 'subclass_of'),
#  ('posterior septal complex', 'Thing', 'subclass_of'),
#  ('larynx submucosa gland', 'Thing', 'subclass_of'),
#  ('respiratory system', 'paranasal sinus', 'part_of'),
#  ('alveolar system', 'alveolar duct', 'part_of'),
#  ('lower leg bone', 'leg bone', 'subclass_of'),
#  ('forebrain meninges', 'forebrain dura mater', 'part_of'),
#  ('metatarsal bone digit 4', 'metatarsal bone', 'subclass_of'),
#  ('dorsal nasal vein', 'vein', 'subclass_of'),
#  ('vibrissa', 'vibrissa hair', 'part_of'),
#  ('pancreatic islet core', 'Thing', 'subclass_of'),
#  ('brain ventricle', 'choroid plexus', 'part_of'),
#  ('abdominal aorta', 'Thing', 'subclass_of'),
#  ("large intestine peyer's patch", "peyer's patch", 'subclass_of'),
#  ('myenteric nerve plexus', 'intrinsic nerve plexus', 'subclass_of'),
#  ('vitreous body', 'Thing', 'subclass_of'),
#  ('elbow', 'elbow joint', 'part_of'),
#  ('pectineus', 'skeletal muscle', 'subclass_of'),
#  ('intervertebral disc', 'nucleus pulposus', 'part_of'),
#  ('integumental system', 'coat hair', 'part_of'),
#  ('sphincter colli superficialis', 'skeletal muscle', 'subclass_of'),
#  ('esophagus mucosa', 'esophagus muscularis mucosa', 'part_of'),
#  ('lower leg', 'lower leg nerve', 'part_of'),
#  ('biceps femoris', 'skeletal muscle', 'subclass_of'),
#  ('liver quadrate lobe', 'liver right lobe', 'subclass_of'),
#  ('respiratory system blood vessel',
#   'respiratory system blood vessel endothelium',
#   'part_of'),
#  ('fourth ventricle', 'brain ventricle', 'subclass_of'),
#  ('arm skin', 'forelimb skin', 'subclass_of'),
#  ('urinary bladder mucosa', 'urinary bladder lamina propria', 'part_of'),
#  ('subparaventricular zone', 'Thing', 'subclass_of'),
#  ('major palatine artery', 'artery', 'subclass_of'),
#  ('foot', 'foot skin', 'part_of'),
#  ('axillary nerve trunk', 'peripheral nerve trunk', 'subclass_of'),
#  ('proximal sesamoid bone of hand', 'sesamoid bone', 'subclass_of'),
#  ('penis', 'os penis', 'part_of'),
#  ('trachea', 'neck organ', 'subclass_of'),
#  ('spleen white pulp', 'spleen lymphoid follicle', 'part_of'),
#  ('cerebellum lobule II', 'Thing', 'subclass_of'),
#  ('palatine bone', 'viscerocranium bone', 'subclass_of'),
#  ('ulnar artery', 'artery', 'subclass_of'),
#  ('muscle', 'Thing', 'subclass_of'),
#  ('autonomic nervous system', 'sympathetic nervous system', 'part_of'),
#  ('foot digit bone', 'foot bone', 'subclass_of'),
#  ('arterial system', 'arterial system endothelium', 'part_of'),
#  ('thyroid gland', 'thyroid gland parenchyma', 'part_of'),
#  ('vagus X ganglion', 'inferior vagus X ganglion', 'part_of'),
#  ('bronchial artery', 'artery', 'subclass_of'),
#  ('ureter lamina propria', 'Thing', 'subclass_of'),
#  ('median nerve', 'peripheral nerve', 'subclass_of'),
#  ('intrinsic tongue muscle transverse component',
#   'intrinsic tongue muscle',
#   'subclass_of'),
#  ('large intestine wall', 'large intestine smooth muscle', 'part_of'),
#  ('oral region', 'salivary gland', 'part_of'),
#  ('hand digit connective tissue', 'Thing', 'subclass_of'),
#  ('thorax', 'Thing', 'subclass_of'),
#  ('juxtaglomerular complex', 'Thing', 'subclass_of'),
#  ('anterior division', 'oval nucleus', 'part_of'),
#  ('eyelid', 'outer canthus', 'part_of'),
#  ('lower jaw incisor', 'lower jaw tooth', 'subclass_of'),
#  ('orbit', 'Thing', 'subclass_of'),
#  ('septohippocampal nucleus', 'Thing', 'subclass_of'),
#  ('retina outer nuclear layer', 'retina layer', 'subclass_of'),
#  ('renal proximal tubule', 'renal cortex tubule', 'subclass_of'),
#  ('diencephalon meninges', 'Thing', 'subclass_of'),
#  ('flexor hallucis longus', 'skeletal muscle', 'subclass_of'),
#  ('alveolar system', 'alveolar sac', 'part_of'),
#  ('internal anal sphincter', 'anal region smooth muscle', 'subclass_of'),
#  ('limb', 'limb muscle', 'part_of'),
#  ('female reproductive system', 'ovary', 'part_of'),
#  ('septal cortex', 'medial septal complex', 'part_of'),
#  ('external acoustic meatus osseus part', 'Thing', 'subclass_of'),
#  ('pallidum', 'Thing', 'subclass_of'),
#  ('uterine gland', 'Thing', 'subclass_of'),
#  ('lymph node cortex', 'Thing', 'subclass_of'),
#  ('vibrissa hair', 'Thing', 'subclass_of'),
#  ('transverse nucleus', 'Thing', 'subclass_of'),
#  ("peyer's patch", 'gut associated lymphoid tissue', 'subclass_of'),
#  ('perilymph', 'otolymph', 'subclass_of'),
#  ('dorsal thalamus', 'geniculate thalamic group', 'part_of'),
#  ('spiral organ', 'Thing', 'subclass_of'),
#  ('forelimb', 'shoulder', 'part_of'),
#  ('ureter', 'pelvis organ', 'subclass_of'),
#  ('sensory organ system', 'sensory organ', 'part_of'),
#  ('perineal vein', 'vein', 'subclass_of'),
#  ('outer renal medulla vasa recta', 'vasa recta', 'subclass_of'),
#  ('upper leg muscle', 'leg muscle', 'subclass_of'),
#  ('inferior olive inferior nucleus', 'Thing', 'subclass_of'),
#  ('dermis adipose tissue', 'Thing', 'subclass_of'),
#  ('cranial synchondrosis', 'synchondrosis', 'subclass_of'),
#  ('thorax', 'thorax blood vessel', 'part_of'),
#  ('hindlimb long bone', 'limb long bone', 'subclass_of'),
#  ('medial preoptic nucleus', 'Thing', 'subclass_of'),
#  ('dorsal penis artery', 'artery', 'subclass_of'),
#  ('upper jaw molar', 'molar', 'subclass_of'),
#  ('foot digit', 'foot digit connective tissue', 'part_of'),
#  ('hippocampal formation', 'dentate gyrus', 'part_of'),
#  ('eye surface', 'eyelid', 'part_of'),
#  ('major salivary gland', 'salivary gland', 'subclass_of'),
#  ('cavity lining', 'Thing', 'subclass_of'),
#  ('trapezium', 'distal carpal bone', 'subclass_of'),
#  ('eye', 'eye chamber', 'part_of'),
#  ('cardiovascular system', 'organ system', 'subclass_of'),
#  ('outer medulla inner stripe',
#   'outer medulla inner stripe loop of henle',
#   'part_of'),
#  ('superior mesenteric artery', 'mesenteric artery', 'subclass_of'),
#  ('metatarsal bone digit 2', 'metatarsal bone', 'subclass_of'),
#  ('brain dura mater', 'dura mater', 'subclass_of'),
#  ('lateral hypothalamic area', 'Thing', 'subclass_of'),
#  ('external anal sphincter', 'anal region skeletal muscle', 'subclass_of'),
#  ('inferior olive dorsal accessory nucleus', 'Thing', 'subclass_of'),
#  ('zeugopod', 'Thing', 'subclass_of'),
#  ('left lung', 'left lung bronchiole', 'part_of'),
#  ('bulbourethral gland', 'male reproductive gland', 'subclass_of'),
#  ('bone', 'cortical bone', 'part_of'),
#  ('trachea submucosa',
#   'trachea non-cartilage connective tissue',
#   'subclass_of'),
#  ('retina', 'retina blood vessel', 'part_of'),
#  ('thoracic cavity connective tissue',
#   'thorax connective tissue',
#   'subclass_of'),
#  ('leg', 'leg skin', 'part_of'),
#  ('mammillary body', 'tuberomammillary nucleus', 'part_of'),
#  ('wrist', 'wrist connective tissue', 'part_of'),
#  ('renal corpuscle', 'afferent arteriole', 'part_of'),
#  ('vena cava', 'venous blood vessel', 'subclass_of'),
#  ('mammary gland', 'nipple', 'part_of'),
#  ('blood vessel endothelium',
#   'cardiovascular system endothelium',
#   'subclass_of'),
#  ('female reproductive system', 'uterus', 'part_of'),
#  ('ileocaecal junction', 'Thing', 'subclass_of'),
#  ('pons', 'reticular tegmental nucleus', 'part_of'),
#  ('pronator teres', 'skeletal muscle', 'subclass_of'),
#  ('paranasal sinus', 'head organ', 'subclass_of'),
#  ('hip', 'hip joint', 'part_of'),
#  ('lymph node', 'lymph node medulla', 'part_of'),
#  ('autonomic nervous system', 'enteric nervous system', 'part_of'),
#  ('hindbrain', 'hindbrain meninges', 'part_of'),
#  ('cerebellum lobule III', 'Thing', 'subclass_of'),
#  ('thoracic cavity artery', 'thoracic cavity blood vessel', 'subclass_of'),
#  ('midbrain', 'anterior tegmental nucleus', 'part_of'),
#  ('lymph node', 'lymph node trabeculum', 'part_of'),
#  ('pudic-epigastric trunk', 'artery', 'subclass_of'),
#  ('sebum', 'skin fluid/secretion', 'subclass_of'),
#  ('eye', 'hyaloid cavity', 'part_of'),
#  ('hand interosseous muscle', 'skeletal muscle', 'subclass_of'),
#  ('lower leg', 'lower leg skin', 'part_of'),
#  ('transverse sinus', 'venous sinus', 'subclass_of'),
#  ('pelvis', 'pelvis organ', 'part_of'),
#  ('cartilaginous joint suture', 'Thing', 'subclass_of'),
#  ('utricle', 'utricle epithelium', 'part_of'),
#  ('anterior abdominal wall muscle', 'skeletal muscle', 'subclass_of'),
#  ('metatarsal bone', 'foot bone', 'subclass_of'),
#  ('head muscle', 'head/neck muscle', 'subclass_of'),
#  ('lateral entorhinal cortex', 'Thing', 'subclass_of'),
#  ('medulla oblongata', 'trigeminal V spinal sensory nucleus', 'part_of'),
#  ('vagus X nerve left recurrent laryngeal branch', 'Thing', 'subclass_of'),
#  ('proper palmal digital arteries',
#   'forelimb digital arteries',
#   'subclass_of'),
#  ('parabigeminal nucleus', 'brainstem nucleus', 'subclass_of'),
#  ('right atrium venous valve', 'right atrium valve', 'subclass_of'),
#  ('back connective tissue', 'trunk connective tissue', 'subclass_of'),
#  ('cranial nerve', 'nerve', 'subclass_of'),
#  ('midline thalamic group', 'nucleus reuniens', 'part_of'),
#  ('trunk', 'thorax', 'part_of'),
#  ('glomerular capsule', 'glomerular juxtacapillary capsular wall', 'part_of'),
#  ('thymus trabecula', 'Thing', 'subclass_of'),
#  ('glomerular capsule', 'Thing', 'subclass_of'),
#  ('vas deferens', 'male reproductive gland/organ', 'subclass_of'),
#  ('trunk organ', 'Thing', 'subclass_of'),
#  ('medulla oblongata', 'cuneate nucleus', 'part_of'),
#  ('spinal cord intermediate grey',
#   'spinal cord central cervical nucleus',
#   'part_of'),
#  ('large intestine wall', 'large intestine serosa', 'part_of'),
#  ('tympanic endothelium', 'Thing', 'subclass_of'),
#  ('joint of vertebral body', 'intervertebral disc', 'part_of'),
#  ('prostate gland lobe', 'Thing', 'subclass_of'),
#  ('female urethra', 'female membranous urethra', 'part_of'),
#  ('heart right ventricle', 'heart ventricle', 'subclass_of'),
#  ('vagus X nerve right recurrent laryngeal branch', 'Thing', 'subclass_of'),
#  ('anal region', 'anal region skeletal muscle', 'part_of'),
#  ('rib 12', 'rib', 'subclass_of'),
#  ('pectoral girdle bone', 'chest bone', 'subclass_of'),
#  ('lumbar vertebra', 'lower back bone', 'subclass_of'),
#  ('lymph node', 'lymph node capsule', 'part_of'),
#  ('dorsal aorta', 'common dorsal aorta', 'part_of'),
#  ('paraventricular thalamic nucleus', 'Thing', 'subclass_of'),
#  ('loop of henle bend', 'Thing', 'subclass_of'),
#  ('hair root sheath matrix', 'Thing', 'subclass_of'),
#  ('kidney pelvis', 'Thing', 'subclass_of'),
#  ('fibula', 'hindlimb long bone', 'subclass_of'),
#  ('oblique extraocular muscle', 'oculomotor muscle', 'subclass_of'),
#  ('cornea', 'corneal blood vessel', 'part_of'),
#  ('loop of henle ascending limb thick segment',
#   'renal straight tubule',
#   'subclass_of'),
#  ('urethra', 'membranous urethra', 'part_of'),
#  ('kidney interstitium', 'renal subcapsular mesenchyme', 'part_of'),
#  ('septal cortex', 'neocortex region', 'subclass_of'),
#  ('thoracic vertebra 6', 'thoracic vertebra', 'subclass_of'),
#  ('epidermis', 'epidermis suprabasal layer', 'part_of'),
#  ('cervical trunk', 'artery', 'subclass_of'),
#  ('abdomen/pelvis/perineum bone', 'trunk bone', 'subclass_of'),
#  ('radial nerve', 'peripheral nerve', 'subclass_of'),
#  ('eyelid connective tissue', 'Thing', 'subclass_of'),
#  ('large intestine smooth muscle circular layer', 'Thing', 'subclass_of'),
#  ('main bronchus smooth muscle', 'Thing', 'subclass_of'),
#  ('venous system endothelium', 'blood vessel endothelium', 'subclass_of'),
#  ('sensory organ system', 'organ system', 'subclass_of'),
#  ('upper back muscle', 'thorax muscle', 'subclass_of'),
#  ('upper jaw incisor', 'incisor', 'subclass_of'),
#  ('septal coronary artery', 'coronary artery', 'subclass_of'),
#  ('vertebra dorsal arch', 'Thing', 'subclass_of'),
#  ('hindlimb', 'hindlimb skin', 'part_of'),
#  ('lower leg', 'lower leg muscle', 'part_of'),
#  ('ear', 'sensory organ', 'subclass_of'),
#  ('palatoglossus', 'skeletal muscle', 'subclass_of'),
#  ('pelvic girdle bone', 'girdle bone', 'subclass_of'),
#  ('dural vein', 'vein', 'subclass_of'),
#  ('ovary follicle', 'Thing', 'subclass_of'),
#  ('neck bone', 'head/neck bone', 'subclass_of'),
#  ('cerebral vein', 'vein', 'subclass_of'),
#  ('rib', 'rib head', 'part_of'),
#  ('sweat gland', 'skin gland', 'subclass_of'),
#  ('semen', 'male reproductive system fluid/secretion', 'subclass_of'),
#  ('foot digit 4', 'foot digit', 'subclass_of'),
#  ('lacrimal apparatus', 'lacrimal gland', 'part_of'),
#  ('pons', 'superior olivary nucleus', 'part_of'),
#  ('autonomic nervous system', 'Thing', 'subclass_of'),
#  ('omental bursa inferior recess', 'Thing', 'subclass_of'),
#  ('peritoneal cavity', 'peritoneal cavity lining', 'part_of'),
#  ('intestine wall', 'intestine mucosa', 'part_of'),
#  ('cutaneous vein', 'vein', 'subclass_of'),
#  ('upper back', 'upper back blood vessel', 'part_of'),
#  ('tympanic epithelium', 'Thing', 'subclass_of'),
#  ('choroidal blood vessel', 'Thing', 'subclass_of'),
#  ('rib dorsal segment', 'Thing', 'subclass_of'),
#  ('oviduct smooth muscle', 'Thing', 'subclass_of'),
#  ('frontal bone', 'chondrocranium bone', 'subclass_of'),
#  ('medulla oblongata', 'dorsal motor nucleus of vagus X nerve', 'part_of'),
#  ('middle temporal vein', 'temporal vein', 'subclass_of'),
#  ('forebrain meninges', 'forebrain arachnoid mater', 'part_of'),
#  ('pancreatic islet', 'Thing', 'subclass_of'),
#  ('liver middle lobe', 'liver lobe', 'subclass_of'),
#  ('striatum', 'lentiform nucleus', 'part_of'),
#  ('cranium', 'Thing', 'subclass_of'),
#  ('upper arm', 'Thing', 'subclass_of'),
#  ('shoulder skin', 'forelimb skin', 'subclass_of'),
#  ('gigantocellular reticular nucleus', 'brainstem nucleus', 'subclass_of'),
#  ('lumbar vertebra', 'vertebra', 'subclass_of'),
#  ('os penis', 'Thing', 'subclass_of'),
#  ('abducens VI nerve', 'cranial nerve', 'subclass_of'),
#  ('upper back skin', 'back skin', 'subclass_of'),
#  ('hypothalamus periventricular zone', 'arcuate nucleus', 'part_of'),
#  ('shoulder', 'shoulder connective tissue', 'part_of'),
#  ('epidermis', 'epidermis stratum spinosum', 'part_of'),
#  ('olfactory cortex', 'olfactory tract', 'part_of'),
#  ('nucleus pulposus', 'Thing', 'subclass_of'),
#  ('omental bursa superior recess', 'Thing', 'subclass_of'),
#  ('sesamoid bone of gastrocnemius', 'sesamoid bone', 'subclass_of'),
#  ('foot', 'tarsus', 'part_of'),
#  ('right hepatic recess', 'Thing', 'subclass_of'),
#  ('main bronchus', 'bronchus', 'subclass_of'),
#  ('esophagus mesentery', 'gastrointestinal system mesentery', 'subclass_of'),
#  ('glomerulus', 'Thing', 'subclass_of'),
#  ('corniculate cartilage', 'yellow elastic cartilage', 'subclass_of'),
#  ('posterior tibial vein', 'tibial vein', 'subclass_of'),
#  ('head', 'face', 'part_of'),
#  ('bile duct extrahepatic part', 'Thing', 'subclass_of'),
#  ('dorsomedial hypothalamic nucleus', 'Thing', 'subclass_of'),
#  ('vertebra spinous process', 'Thing', 'subclass_of'),
#  ('lower jaw', 'mandible', 'part_of'),
#  ('epididymis', 'epididymal duct', 'part_of'),
#  ('glomerular capsule', 'glomerular parietal epithelium', 'part_of'),
#  ('prostatic urethra', 'Thing', 'subclass_of'),
#  ('metacarpal bone digit 2', 'metacarpal bone', 'subclass_of'),
#  ('tongue', 'tongue skeletal muscle', 'part_of'),
#  ('vagina', 'female reproductive gland/organ', 'subclass_of'),
#  ('cortical layer IV', 'neocortex layer', 'subclass_of'),
#  ('telencephalon', 'olfactory lobe', 'part_of'),
#  ('intercostal artery', 'artery', 'subclass_of'),
#  ('foot', 'foot bone', 'part_of'),
#  ('proper plantar vein', 'hindlimb digital veins', 'subclass_of'),
#  ('renal proximal tubule', 'proximal tubule segment 2', 'part_of'),
#  ('leg connective tissue', 'hindlimb connective tissue', 'subclass_of'),
#  ('pons', 'parabrachial nucleus', 'part_of'),
#  ('retina', 'optic disc', 'part_of'),
#  ('neocortex', 'neocortex region', 'part_of'),
#  ('gastric artery', 'artery', 'subclass_of'),
#  ('frontal cortex', 'neocortex region', 'subclass_of'),
#  ('medial cerebellar nucleus', 'deep cerebellar nucleus', 'subclass_of'),
#  ('pancreatic duct', 'Thing', 'subclass_of'),
#  ('abdominal fat pad', 'fat pad', 'subclass_of'),
#  ('mammary gland', 'integumental system gland', 'subclass_of'),
#  ('esophagus squamous epithelium', 'esophagus epithelium', 'subclass_of'),
#  ('upper arm connective tissue', 'arm connective tissue', 'subclass_of'),
#  ('brachial plexus', 'spinal nerve plexus', 'subclass_of'),
#  ('areola', 'Thing', 'subclass_of'),
#  ('stomach mucosa', 'stomach epithelium', 'part_of'),
#  ('reproductive system', 'male reproductive system', 'part_of'),
#  ('retina layer', 'Thing', 'subclass_of'),
#  ('trachea blood vessel', 'Thing', 'subclass_of'),
#  ('foot', 'foot connective tissue', 'part_of'),
#  ('lower arm', 'lower arm blood vessel', 'part_of'),
#  ('limb bone', 'bone', 'subclass_of'),
#  ('telencephalon', 'telencephalon meninges', 'part_of'),
#  ('hand interdigit region', 'Thing', 'subclass_of'),
#  ('main bronchus', 'main bronchus smooth muscle', 'part_of'),
#  ('abdomen', 'abdomen nerve', 'part_of'),
#  ('trunk muscle', 'muscle', 'subclass_of'),
#  ('ureter', 'ureter urothelium', 'part_of'),
#  ('brain', 'brain ependyma', 'part_of'),
#  ('nervous system', 'ganglion', 'part_of'),
#  ('midbrain meninges', 'midbrain arachnoid mater', 'part_of'),
#  ('intercostales externus', 'intercostales', 'subclass_of'),
#  ('lobar bronchus', 'lobar bronchus connective tissue', 'part_of'),
#  ('periolivary nucleus', 'Thing', 'subclass_of'),
#  ('lower back connective tissue', 'back connective tissue', 'subclass_of'),
#  ('salivary gland epithelium', 'Thing', 'subclass_of'),
#  ('right ventricle muscular part',
#   'heart ventricle muscular part',
#   'subclass_of'),
#  ('median cubital vein', 'vein', 'subclass_of'),
#  ('trachea smooth muscle', 'respiratory system smooth muscle', 'subclass_of'),
#  ('accessory XI nerve', 'accessory XI nerve cranial component', 'part_of'),
#  ('olfactory cortex', 'piriform cortex', 'part_of'),
#  ('frontal artery', 'artery', 'subclass_of'),
#  ('plasma', 'serum', 'part_of'),
#  ('respiratory system venule',
#   'respiratory system venous blood vessel',
#   'subclass_of'),
#  ('proper palmal vein', 'forelimb digital veins', 'subclass_of'),
#  ('skin', 'skin gland', 'part_of'),
#  ('vesical artery', 'artery', 'subclass_of'),
#  ('thoracic vertebra 5', 'thoracic vertebra', 'subclass_of'),
#  ('popliteal vein', 'vein', 'subclass_of'),
#  ('alveolar wall', 'Thing', 'subclass_of'),
#  ('proximal phalanx of foot', 'foot phalanx', 'subclass_of'),
#  ('sternal manubrium', 'Thing', 'subclass_of'),
#  ('inner renal medulla', 'inner renal medulla vasa recta', 'part_of'),
#  ('pancreas', 'abdomen organ', 'subclass_of'),
#  ('pontine nucleus', 'brainstem nucleus', 'subclass_of'),
#  ('foot interosseus muscle', 'skeletal muscle', 'subclass_of'),
#  ('pituitary gland', 'neurohypophysis', 'part_of'),
#  ('brainstem', 'Thing', 'subclass_of'),
#  ('lower arm nerve', 'arm nerve', 'subclass_of'),
#  ('internal iliac vein', 'iliac vein', 'subclass_of'),
#  ('intestine epithelium', 'small intestine epithelium', 'part_of'),
#  ('metencephalon', 'Thing', 'subclass_of'),
#  ('spleen', 'spleen marginal sinus', 'part_of'),
#  ('peroneus longus', 'skeletal muscle', 'subclass_of'),
#  ('ureter muscle layer', 'Thing', 'subclass_of'),
#  ('tensor fasciae lata', 'skeletal muscle', 'subclass_of'),
#  ('foot', 'foot nerve', 'part_of'),
#  ('pupil', 'Thing', 'subclass_of'),
#  ...]

# %%
cos_sim(*extractUSEEmbeddings(["program committee member", "member program committee"]))
# Out:
# ['gastroepiploic vein',
#  'brachial plexus',
#  'glomerular parietal epithelium',
#  'foot digit bone',
#  'intestinal epithelium',
#  'omotransverse',
#  'bronchus smooth muscle tissue',
#  'subscapular vein',
#  'left adrenal gland',
#  'pancreatico-duodenal vein',
#  'metacarpal/metatarsal bone',
#  'long bone',
#  'rejected paper',
#  'respiratory system part',
#  'foot skin',
#  'bile duct intrahepatic part',
#  'incus',
#  'gracilis',
#  'bulboglandular',
#  'gracilis',
#  'epidermal ridges',
#  'sublingual gland',
#  'apex of arytenoid',
#  'unipolar neuron',
#  'roof of the fourth ventricle',
#  'dental pulp',
#  'reject paper',
#  'carpal joint',
#  'bulbourethral gland secretion',
#  'squamous epithelium',
#  'bone marrow blood-forming cell',
#  'ovarian vein',
#  'cornea',
#  'immature lymphocyte',
#  'phrenic artery',
#  'frontal bone',
#  'lower respiratory tract',
#  'cecum',
#  'laryngeal connective tissue',
#  'common bile duct',
#  'external maleolus',
#  'forelimb skin',
#  'facial nerve nucleus',
#  'bile duct tissue',
#  'subependymal tissue',
#  'conference event',
#  'corona dentis',
#  't-lymphoblast',
#  'otolymph',
#  'multipotent stem cell',
#  'visceral mesothelium',
#  'left lung hilus',
#  'stomach lesser curvature',
#  'levator palpebrae superioris',
#  'intercostal nerve',
#  'maxillary vein',
#  'esophagus smooth muscle longitudinal layer',
#  'nonmember registration fee',
#  'upper jaw incisor',
#  'ductus venosus',
#  'anterior olfactory lobule',
#  'endothelial cell',
#  'multi-author volume',
#  'third ventricle ependyma',
#  'peroneal nerve',
#  'cricoarytenoid joint',
#  'vastus medialis',
#  'myocardium',
#  'large intestine',
#  'exocrine gland',
#  'nucleus of trapezoid body',
#  'intestinal mucosa',
#  'left renal artery',
#  'pericardiacoophrenic artery',
#  'right lung alveolus',
#  'trigeminal nucleus',
#  'external acoustic meatus',
#  'lens anterior epithelium',
#  'frontal sulcus',
#  'activated mature cytotoxic t-lymphocyte',
#  'thyroid gland oxyphil cell',
#  'oxyphil cell',
#  'activity after conference',
#  'ductus santorini',
#  'thyroid gland lobe',
#  'ganglionic layer',
#  'acromial thoracic artery',
#  'stomach blind ventricular sac',
#  'prostate gland secretion',
#  'bronchus',
#  'olfactory tract',
#  'epigastric artery',
#  'inferior suprarenal vein',
#  'plantar fascia',
#  'foramen caecum',
#  'lower respiratory tract epithelium',
#  'endothelium of the glomerular capillary',
#  'cerebral white matter',
#  'sartorius',
#  'spermatozoon',
#  'dentin',
#  'coronary artery',
#  'acinar salivary gland system',
#  'lymphatic capillary',
#  'pulmonary vein',
#  'left colon',
#  'genioglossus',
#  'arachnoid mater',
#  'body region',
#  'vagus x nerve trunk',
#  "meckel's cartilage",
#  'primitive stem cell with some degree of commitment to the erythroid lineage',
#  'knee bone',
#  'hand digit',
#  'temporal lobe',
#  'bronchial tree',
#  'erythroid progenitor cell',
#  'free time break',
#  'nasal nerve',
#  'tensor tympani',
#  'spleen marginal sinus',
#  'internal spermatic vein',
#  'large intestinal muscularis mucosa',
#  'right lung',
#  'mammary gland lobule',
#  'middle cervical ganglion',
#  'metatarsal bone digit 2',
#  'metacarpal bone digit 4',
#  'personal publication history',
#  'septal cortex',
#  'best research paper award',
#  'retrochiasmatic area',
#  'has a date of issue',
#  'tentorium cerebelli',
#  'cardia',
#  'parathyroid gland capsule',
#  'saphenous artery',
#  'liver acinus',
#  'uterine horn',
#  'organizing committee',
#  'cricoarytenoid',
#  't-immunoblast',
#  'segmental bronchus epithelium',
#  'splenic hilum',
#  'vestibulocochlear viii ganglion vestibular component',
#  'bile canaliculus',
#  'external pterygoid muscle',
#  'pancreas head',
#  'vestibular aqueduct',
#  'taste bud',
#  'item',
#  'small intestinal mucosa',
#  'interlobular artery',
#  'right common carotid artery',
#  'bile duct extrahepatic part',
#  'ascending aorta branch',
#  'serum',
#  'epigastric region',
#  'central vein',
#  'other limb bone',
#  'thyroid gland right lobe',
#  'meninges',
#  'cerebellum external granule cell layer',
#  'upper arm skin',
#  'left common carotid artery',
#  'pulmonary artery',
#  'synchondrosis',
#  'medial marginal vein',
#  'cervical spinal cord',
#  'alveolar epithelium',
#  'lower arm connective tissue',
#  'posterior temporal artery',
#  'track',
#  'anterior wall of the tympanum',
#  'ovary theca externa',
#  'geniculate ganglion',
#  'thoraco-acromial artery',
#  'hippocampus stratum radiatum',
#  'eyelid subcutaneous connective tissue',
#  'phrenic vein',
#  'ascending parietal convolution',
#  'sputum',
#  'nostril',
#  'dentate gyrus',
#  'foot skin',
#  'retina inner nuclear layer',
#  'has end date time',
#  'scientifically organises',
#  'frontal artery',
#  'ascending limb of the henle s loop',
#  'axillary artery branch',
#  'right renal vein',
#  'suprasellar region',
#  'pigmented retinal epithelium',
#  'upper back bone',
#  'spinal cord dorsal column',
#  'bronchus cartilage',
#  'posterior facial vein',
#  'spermatocyte',
#  'nipple',
#  'trigeminal v ganglion',
#  'basilar artery branch',
#  'thymic b-lymphocyte',
#  'stratum disjunctum',
#  'hand bone',
#  'author attendee cd registration fee',
#  'anterior lingual gland',
#  'buccal mucosa',
#  'inferior epigastric artery',
#  'sternoclavicular joint',
#  'axillary tail of the breast',
#  'maternal placental artery',
#  'connective tissue proper',
#  'gastric vein',
#  'basilar membrane',
#  'corpora albicantia',
#  'granulosa cell',
#  't-prolymphocyte',
#  'vein',
#  'peroneal artery',
#  'anterior surface of the prostate',
#  'outer canthus',
#  'guard hair',
#  'palatal shelf',
#  'foveolar cell',
#  'ilio-lumbar artery',
#  'dorsal curve',
#  'fat',
#  'membrane of the brain or spinal cord',
#  'cervical artery',
#  'extrinsic auricular muscle',
#  'endocervix',
#  'lumbar vertebra',
#  'eye chamber',
#  'seminiferous tubule epithelium',
#  'small intestine villus',
#  'head/neck blood vessel',
#  'nephron',
#  'endometrial cavity',
#  'has decision',
#  'paper id',
#  'quadratus lumborum',
#  'upper arm nerve',
#  'inferior mesenteric artery',
#  'lentiform nucleus',
#  'posterior external jugular vein',
#  'sensory organ',
#  'abdomen',
#  'inferior palpebral fold',
#  'internal nare',
#  'subscapular artery',
#  'peritoneal mesothelial cell',
#  'caudate-putamen',
#  'hand digit connective tissue',
#  'interphalangeal joint of the foot',
#  'pons',
#  'back nerve',
#  'prepontine cistern',
#  'central sulcus of rolando',
#  'epicardium',
#  'has location',
#  'carotid artery',
#  'subscapular artery',
#  'anatomic surface',
#  'hand digit nerve',
#  'lumbar vertebra 4',
#  'deep lymphatic vessel',
#  'spinal cord column',
#  'inferior temporal gyrus',
#  'hair bulb',
#  'search',
#  'pons varolii',
#  'gastric tissue',
#  'left subcostal vein',
#  'nail bed',
#  'pericardium',
#  'upper jaw tooth',
#  'middle temporal vein',
#  'anterior surface of the stomach',
#  'superficial cervical artery',
#  'has biography',
#  'review',
#  'osteoblast',
#  'postcentral sulcus',
#  'posterior fossa',
#  'musculoskeletal system part',
#  'mature cytotoxic t-lymphocyte',
#  'transversus thoracis',
#  'duct salivary gland system',
#  'ulna',
#  'accepted paper',
#  'infratentorial brain',
#  'parotid gland lymph node',
#  'neck muscle',
#  'cricoarytenoid muscle',
#  'hypogastric nerve plexus',
#  'nucleus of the solitary tract',
#  'spinal cord ventral column',
#  'hemispheric cistern',
#  'gastrointestinal system',
#  'person',
#  'hypoglossal xii nucleus',
#  'fornix',
#  'conjunctiva',
#  'spinal ganglion/nerve',
#  'thoracic vertebra 3',
#  'scapula',
#  'facial artery',
#  'superficial intracranial venous system',
#  'stomach proventricular region',
#  'bronchus basal lamina',
#  'visceral layer of bowman s capsule',
#  'is the 1th part of',
#  'middle cerebral artery branch',
#  'bronchus basement membrane',
#  'c3 vertebra',
#  'fascicle',
#  'common femoral artery',
#  'larynx mucosa',
#  'tail vein',
#  'study at',
#  'obsolete class',
#  'right hepatic duct',
#  'eyelid',
#  'ureter luminal urothelium',
#  'ulnar nerve',
#  'head',
#  'conference',
#  'head blood vessel',
#  'hair follicle',
#  'primordial follicle',
#  'esophagus',
#  'microcirculatory bed',
#  'flat bone',
#  'pancreatic endocrine secretion',
#  'adrenal vein',
#  'tongue skeletal muscle tissue',
#  'large intestinal crypt of the lieberkuhn',
#  'hotel fee',
#  'ureter adventitia',
#  'inferior palpebral vein',
#  'definition',
#  'central nervous system',
#  'reproductive organ',
#  'accessory xi nucleus',
#  'eosinophil',
#  'esophagus muscularis mucosa',
#  'minor calyx',
#  'vestibulocochlear viii nerve cochlear component',
#  'leg nerve',
#  'testis',
#  'retinal artery',
#  'kidney interstitium',
#  'cervical vertebra 4',
#  'city of conference',
#  'radix dentis',
#  'lingual tonsillar tissue',
#  'iliac circumflex artery',
#  'brunner s gland',
#  'eye posterior chamber',
#  'lesser tuberosity',
#  'temporal cortex',
#  'trigeminal v motor nucleus',
#  'skeletal fiber',
#  'anterior meningeal artery',
#  'trachea connective tissue',
#  'thymic vein',
#  'social program',
#  'obsolete class',
#  'gland',
#  'cuboidal cell',
#  'poster session',
#  'superior infratentorial cistern',
#  'signal processing topic',
#  'respiratory system venous smooth muscle',
#  'internal elastic membrane',
#  'hip bone',
#  'blood vessel',
#  'cardiac nerve plexus',
#  'phrenic nerve trunk',
#  'respiratory tract',
#  'scala vestibuli',
#  'sphenoid sinus',
#  'tarsal artery',
#  'pericallosal artery',
#  'activity',
#  'quadrigeminal body',
#  'cerebral gyrus',
#  'masseter',
#  'tonsil',
#  'placenta metrial gland',
#  'small intestinal serosal surface',
#  'cauda equina',
#  'femoral nerve',
#  'bladder',
#  'lip philtrum',
#  'subclass of',
#  'chest',
#  'vagus x nerve right recurrent laryngeal branch',
#  'extensor digitorum communis',
#  'seminal vesicle secretion',
#  'auricle',
#  'money',
#  'central canal',
#  'main bronchus smooth muscle',
#  'axillary nerve',
#  'foot',
#  'fovea',
#  'anal canal',
#  'corneal epithelium',
#  'promontory',
#  'common plantar digital arteries',
#  'digital vein',
#  'palmar hand interosseus muscle',
#  'inferior cerebral vein',
#  'erector spinae',
#  'prostatic portion of the male urethra',
#  'histiocyte',
#  'inferior olive medial nucleus',
#  'knee',
#  'body fluid or substance',
#  'lower leg muscle',
#  'large intestine serosa',
#  'rib 1',
#  'integumental system gland',
#  'herring body',
#  'auricular artery',
#  'other anatomic concept',
#  'conference session',
#  'renal pelvis',
#  'sternebra',
#  'arterial system endothelium',
#  'nucleus ambiguus',
#  'external acoustic meatus osseus part',
#  'has part',
#  'cholinergic enteric nerve',
#  'default choice',
#  'claustrum',
#  'boolean',
#  'medial tarsal artery',
#  'activated lymphocyte',
#  'lamina lucida',
#  'lipocyte',
#  'bone tissue',
#  'aqueous humour',
#  'descending colon',
#  'navicular',
#  'medulla oblongata',
#  'lymph node trabecula',
#  'reception',
#  'write review',
#  'chondroblast',
#  'lateral geniculate nucleus',
#  'gomphosis',
#  'anterior annular ligament',
#  'left coronary artery',
#  'sebaceous gland',
#  'fee for extra trip',
#  'semimembranosus',
#  'foot blood vessel',
#  'male reproductive gland/organ',
#  'intestinal secretion',
#  'chest nerve',
#  'lymph node sinus',
#  'hippocampal fissure',
#  'endocrine cell and neuroendocrine cell',
#  'spinal accessory nerve',
#  'scalene muscle',
#  'presenter',
#  'median vein',
#  'dorsum of the tongue',
#  'vein endothelium',
#  'cranium',
#  'anal region skeletal muscle',
#  'fibula',
#  'outer supporting cell',
#  'rib 3',
#  'common hepatic duct',
#  'performance topic',
#  'tibilais cranialis',
#  'vagina stroma',
#  'enable virtual meeting',
#  'mastoid process',
#  'metacarpus',
#  'female membranous urethra',
#  'spinal artery',
#  'outflow tract aortic component',
#  'lower gastrointestinal tract',
#  'venule',
#  'external anal sphincter',
#  'heart septum',
#  'duodenum',
#  'sural vein',
#  'frontal horn of the lateral ventricle',
#  'spinal nerve plexus',
#  'lacrimal sac',
#  'eustachian valve',
#  'external acoustic meatus cartilaginous part',
#  'memory b cell',
#  'anterior division',
#  'trachea basement membrane',
#  'has a location',
#  'inner ear epithelium',
#  'eye surface',
#  'thymus medulla',
#  'author of paper',
#  'auditory tube',
#  'single hotel room',
#  'seminal fluid',
#  'grey matter',
#  'adrenal fluid or secretion',
#  'shoulder',
#  'ductal epithelium',
#  'pelvis blood vessel',
#  'tibial artery',
#  'geniculate body',
#  'brown fat',
#  'viscerocranium bone',
#  'has topic',
#  'bile duct',
#  'splenic artery',
#  'is used for',
#  'ovary',
#  'right lung alveolar system',
#  'lymph node by anatomic site',
#  'paper in volume',
#  'bladder muscular coat',
#  'clavicle',
#  'glomeruloza zone',
#  'interatrial septum',
#  'saccule',
#  'base of arytenoid',
#  'ciliary muscle',
#  'reticular tegmental nucleus',
#  'shoulder muscle',
#  'cerebellum internal granule cell layer',
#  'sphincter pupillae muscle',
#  'posterior cerebral artery branch',
#  'cortex',
#  'urethralis',
#  'spinal cord ventral horn',
#  'l3 vertebra',
#  'constrictor muscle of pharynx',
#  'inguinal lymph node',
#  'connective tissue',
#  'stomach body',
#  'caudate nucleus',
#  'knee joint',
#  'ovary follicle fluid',
#  'is held after',
#  'olfactory bulb glomerular layer',
#  'spinal cord central canal',
#  'basisphenoid bone',
#  'intrinsic tongue muscle transverse component',
#  'perikaryon',
#  'ventral thalamus',
#  'nail',
#  'area of broca',
#  'superior vagus x ganglion',
#  'accumbens nucleus',
#  'colorectal zone of the anal canal',
#  'platinum supporter',
#  'is sent after',
#  'mamillary body',
#  'oculomotor nucleus',
#  'posterior circumflex artery',
#  'left vagus x nerve trunk',
#  'skin',
#  'blood vessel smooth muscle',
#  'reproductive gland',
#  'hamstring muscle',
#  'sphincter colli superficialis',
#  'lateral ventricle subependymal layer',
#  'medial femoral circumflex artery',
#  'psoas major',
#  'hindlimb blood vessel',
#  'epithelial receptor cell',
#  'supra-orbital vein',
#  'prostatic epithelium',
#  'bid',
#  'transverse rectal fold',
#  'rest of ureter',
#  'kidney subcortical veins',
#  'superior temporal gyrus',
#  'other body part',
#  'prostate gland anterior lobe',
#  'subcapsular epithelium of the lens',
#  'alveolar sac',
#  'gastrointestinal sphincter',
#  'prepositus hypoglossal nucleus',
#  'oral epithelium',
#  'nasal mucus',
#  'pars posterior',
#  'distal straight tubule postmacula segment',
#  'superior sagittal sinus',
#  'synovial fluid',
#  'urine',
#  'choroid plexus',
#  'macrophage',
#  'superior wall of the nasopharynx',
#  'ureter',
#  'lateral wall of the oropharynx',
#  'vascular endothelium',
#  'conference dinner',
#  'cuboidal oviduct epithelium',
#  'mammary gland',
#  'author',
#  'trachea basement membrane',
#  'anterior surface of the lens',
#  'precursor nk-cell',
#  'autonomic nervous system',
#  'retina photoreceptor layer inner segment',
#  'appendicular skeleton',
#  'foot digit nerve',
#  'umbilical cord blood stem cell',
#  'metacarpal bone',
#  'vagus x nerve left recurrent laryngeal branch',
#  'pharynx epithelium',
#  'autopod joint',
#  'subclass of',
#  'gastrointestinal system',
#  'audiovisual equipment',
#  'molecular layer of the cerebellum',
#  'enterocyte',
#  'cortical vein',
#  'thyroid gland epithelial tissue',
#  'is menu of',
#  'renal cortex artery',
#  'alveolar duct',
#  'liver lobule',
#  'basaloid cell',
#  'internal anal sphincter',
#  'renal cortex',
#  'membranous canal of the cochlea',
#  'tuberomammillary nucleus',
#  'medial geniculate nucleus',
#  'nephron',
#  'popliteal vein',
#  'sponsor city',
#  'bile duct epithelium',
#  'cleidocephalic',
#  'bronchiole',
#  'hematopoietic and lymphoid tissue',
#  'cerebellum lobule viii',
#  'sign',
#  'choroidal blood vessel',
#  'intra-thoracic lymph node',
#  'bronchus reticular lamina',
#  'poster paper',
#  'perilymph',
#  'cleidobrachial',
#  'anterior facial vein',
#  'trochlear iv nerve',
#  'person',
#  'session chair',
#  'vagina squamous epithelium',
#  't11 vertebra',
#  'tutorial',
#  'internal parieto-occipital fissure',
#  'non-granular leukocyte',
#  'paranasal sinus',
#  'paracentral nucleus',
#  'is needed for',
#  'vagal triangle',
#  'large intestinal mucosa',
#  'inferior olive beta subnucleus',
#  'registration form',
#  'heart endocardium',
#  'respiratory bronchiole',
#  'extraglomerular mesangium',
#  'joint of girdle',
#  'rib tubercle',
#  'vaginal fornix',
#  'long bone epiphysis',
#  'lower jaw incisor',
#  'mouse anatomy',
#  'sphincter colli superficialis',
#  'best student paper award',
#  'mesenteric artery',
#  'auditory ossicle',
#  'medial vestibular nucleus',
#  'granulocyte',
#  'submucosal tissue of human prostate',
#  'primary choana',
#  'ureteric artery',
#  'pituitary gland',
#  'sponsorship',
#  'left lung bronchiole',
#  'organization',
#  'right lung cranial lobe',
#  'renal afferent vessel',
#  'pancreas',
#  'external plantar artery',
#  'esophageal artery',
#  'upper leg bone',
#  'epidermis',
#  'radius bone',
#  'coat hair bulb',
#  'left lung',
#  'diaphragm part',
#  'frontal association cortex',
#  'lower eyelid',
#  'hepatic tissue',
#  'palmar region',
#  'transitional zone of the prostatic parenchyma',
#  'renal tubule',
#  'alveolar wall',
#  'posterior semicircular canal',
#  'median artery palmar branch',
#  'leg skin',
#  'thyroepiglottic ligament',
#  'student',
#  'cricothyroid muscle',
#  'heart septum',
#  'pharyngeal tonsil',
#  'pericardial fluid',
#  'ovarian vein',
#  'hotel',
#  'paper',
#  'auricular artery',
#  'muscle and fasciae of the thorax',
#  'appendage of the uterus',
#  'sponzor fee',
#  'mammary gland smooth muscle',
#  'elastin fiber',
#  'space of fontana',
#  'anterior thalamic group',
#  'author attendee book registration fee',
#  'right renal artery',
#  'any uri',
#  'chromophobe cell',
#  'vas deferens smooth muscle',
#  'has menu',
#  'tract of burdach',
#  'distal convoluted tubule',
#  'maxillary artery',
#  'oculomotor nerve',
#  'endocrine sex organ',
#  'visceral serous pericardium',
#  'adductor group (leg)',
#  'intestine muscularis mucosa',
#  'surface of the prostate',
#  'dorsal venous arch',
#  'lesser omentum',
#  'nerve',
#  'artery endothelium',
#  'sesamoid bone',
#  'has first name',
#  'ventricle brain',
#  'cervical nerve',
#  'merkel cell',
#  'superior temporal sulcus',
#  'bronchiole',
#  'ocular angle artery',
#  'stratum lucidum',
#  'tympanic membrane',
#  'joint',
#  'portal vein',
#  'neck organ',
#  'septal coronary artery',
#  'member pc',
#  'heart ventricle membranous part',
#  'call for reviews',
#  'dorsal metatarsal vein',
#  'lobe of the left lung',
#  'suprachorioid lamina',
#  'accepted by',
#  'brachial artery',
#  'artery smooth muscle tissue',
#  'rostrum of the corpus callosum',
#  'internal intercostal muscle',
#  'renal straight tubule',
#  'dorsal vena of penis',
#  'lymphoid blood-forming cell',
#  'peritoneal cavity greater sac',
#  'has programme',
#  'septohippocampal nucleus',
#  'tensor fasciae lata',
#  'review',
#  'glomerular capillary basement membrane',
#  'has an abstract',
#  'anterior inferior frontal convolution',
#  'organizational meeting',
#  'important dates',
#  'temporo-maxillary vein',
#  'celiac ganglion',
#  'proper palmal digital arteries',
#  'genioglossus',
#  'female urethral meatus',
#  'frontal bone',
#  'outer renal medulla',
#  'forelimb nerve',
#  'lateral ventricle',
#  'inferior thyroid artery',
#  'cementocyte',
#  'thorax connective tissue',
#  'hair cortex',
#  'abstract',
#  'anterior part of the calcarine fissure',
#  'nasal cavity',
#  'girdle bone',
#  'book proceeding',
#  'synonym',
#  'inferior internal articular artery',
#  'sinus of valsava',
#  'major palatine artery',
#  'hymen',
#  'tunica intima',
#  'meniscus medialis',
#  'longissimus cervicis',
#  'hepatic duct extrahepatic part',
#  'descending aorta',
#  'cerumen',
#  'is dated on',
#  'hindlimb muscle',
#  'subependymal cell',
#  'shoulder',
#  'epithelioid cell',
#  'peripheral nerve',
#  'written by',
#  'postero-lateral fissure',
#  'transverse colon',
#  'rib 7',
#  'colostrum',
#  'publisher',
#  'middle cuneiform bone of the foot',
#  'prostate gland smooth muscle',
#  'gigantocellular reticular nucleus',
#  'has a volume',
#  'uterus',
#  'seromucous salivary gland',
#  'large intestinal submucosa',
#  'penis foreskin',
#  'globus pallidus',
#  'medial saphenous vein',
#  'dorsal hand interosseous muscle',
#  'thermoreceptor',
#  'enteric ganglion',
#  'second portion of the duodenum',
#  'dorsal mesogastrium',
#  'cochlear duct',
#  'vitreous body',
#  'pre-b lymphocyte',
#  'esophagus',
#  'lateral orbitofrontal artery',
#  'large intestinal serosal surface',
#  'exocrine pancreas',
#  'lower back nerve',
#  'inguinal mammary gland',
#  'computer networks security topic',
#  'vas deferens',
#  'lateral wall of the bladder',
#  'vaginal epithelium',
#  'liver bare area',
#  'vestibular hair cell',
#  'hepatobiliary system',
#  'reject rating',
#  'scapholunate',
#  'body fluid/substance',
#  'supratentorial cistern',
#  'extensor carpi ulnaris',
#  'neuroendocrine cell',
#  'pia mater',
#  'fenestra rotunda',
#  'right lung lobe',
#  'cerebellar vein',
#  'endometrium glandular epithelium',
#  'myeloid cell',
#  'uterine cervix',
#  'thoracic vertebra 4',
#  'anterior descending coronary artery',
#  'cd8 plus t-lymphocyte',
#  'thymus trabecula',
#  'omohyoid',
#  'spinal cord meninges',
#  'brachial artery',
#  'kidney',
#  'rib 10',
#  'liver quadrate lobe',
#  'longissimus cervicis',
#  'quadrigeminal cistern',
#  'loop of henle ascending limb thick segment',
#  'peripheral nerve',
#  'demo paper',
#  'foot bone',
#  'forebrain arachnoid mater',
#  'hyaloid vascular plexus',
#  'medial palpebral ligament',
#  'body of the corpus callosum',
#  'inferior rectal artery',
#  'thoracic cavity connective tissue',
#  "small intestine peyer's patch",
#  'administrative event',
#  'superior parathyroid gland',
#  'liver acinus',
#  'respiratory system',
#  'sural artery',
#  'pancreatic acinus',
#  'superficial cervical lymph node',
#  'intercostal fascia',
#  'thymocyte',
#  'rib 12',
#  'urogenital muscle',
#  'spinal cord dorsal nucleus',
#  'lymphatic vessel',
#  'maxilla',
#  'nucleus of the spinal tract of the trigeminal nerve',
#  'other body fluids and secretions',
#  'has review',
#  'spinal nerve root',
#  'antrum pylori',
#  'neck connective tissue',
#  'superior vesical artery',
#  'renal cortex tubule',
#  'shoulder connective tissue',
#  'cochlea',
#  'spermatic vein',
#  'coccygeal vertebra',
#  'information for participants',
#  'pharynx muscle',
#  'enamel',
#  'evaluated paper',
#  'ileal vein',
#  'right lung caudal lobe',
#  'genito-urinary region',
#  'small intestine submucosa',
#  'registration non-member',
#  'flyer',
#  'location',
#  'corneal blood vessel',
#  'vertebral canal',
#  'lung tissue',
#  'medial femoral vein',
#  'circular ligament of the tooth',
#  'cuneiform cartilage',
#  'tongue',
#  'thymic lymphoid tissue',
#  'kidney arterial blood vessel',
#  'forelimb joint',
#  'cardiac vein',
#  'median cubital vein',
#  'optic disc',
#  'initiates',
#  'foot bone',
#  'femoral artery branch',
#  'sensory hair',
#  'heart valve',
#  'male breast',
#  'bone surface',
#  'one day presenter',
#  'mullerian duct',
#  'trachea non-cartilage connective tissue',
#  'postgerminal center marginal zone b-lymphocyte',
#  'epineurium',
#  'superior palpebral fold',
#  'basement membrane',
#  'megakaryoblast',
#  'adrenal gland zona reticularis',
#  'cervicothoracic ganglion',
#  'spinal nerve plexus',
#  'anterior horn cell',
#  'coat hair',
#  'thoracic esophagus',
#  'distal rib',
#  'foot digit connective tissue',
#  'name',
#  'metatarsal bone digit 4',
#  'retina nerve fiber layer',
#  'auricular ligament',
#  'part of afferent arteriole forming juxtaglomerular complex',
#  'brain stem',
#  'impulse conducting system',
#  'harderian gland',
#  'foot digit 3',
#  'female reproductive system fluid/secretion',
#  'adrenal gland capsule',
#  'male urethra ostium',
#  'administrator',
#  'kidney collecting duct',
#  'respiratory system basal lamina',
#  'bronchiole epithelium',
#  'pelvis skin',
#  'hepatic portal vein',
#  'spinal cord basal nucleus',
#  'is reviewing',
#  'metacarpal bone digit 2',
#  'helper-inducer t-lymphocyte',
#  'interstitial cell',
#  'anterior median fissure of spinal cord',
#  'brachialis',
#  'lumbar sympathetic nerve trunk',
#  'has a review',
#  'full day tour',
#  'communicating artery',
#  'costal arch',
#  'meta-reviewer',
#  'lateral rectus extraocular muscle',
#  'brain arachnoid matter',
#  'os penis',
#  'processus cochleariformis',
#  ...]

# %%
ontologies_in_alignment
# Out:
# [['conference', 'ekaw'],
#  ['confOf', 'ekaw'],
#  ['ekaw', 'sigkdd'],
#  ['edas', 'sigkdd'],
#  ['confOf', 'sigkdd'],
#  ['iasted', 'sigkdd'],
#  ['confOf', 'iasted'],
#  ['conference', 'iasted'],
#  ['confOf', 'edas'],
#  ['edas', 'iasted'],
#  ['conference', 'edas'],
#  ['cmt', 'ekaw'],
#  ['cmt', 'confOf'],
#  ['cmt', 'edas'],
#  ['conference', 'sigkdd'],
#  ['cmt', 'sigkdd'],
#  ['conference', 'confOf'],
#  ['edas', 'ekaw'],
#  ['cmt', 'conference'],
#  ['cmt', 'iasted'],
#  ['ekaw', 'iasted'],
#  ['human', 'mouse']]
