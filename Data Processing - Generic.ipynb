# %%
# Construction of dataset

import os, itertools, time, pickle, sys, glob, requests
import subprocess
from xml.dom import minidom
from collections import Counter, OrderedDict
from operator import itemgetter
from nltk.corpus import wordnet
import tensorflow as tf
import tensorflow_hub as hub
from scipy import spatial
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
from sklearn.feature_extraction.text import TfidfVectorizer
import re
import numpy as np
import scipy.sparse as sp
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from math import ceil, exp
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence

# %%
flatten = lambda l: [item for sublist in l for item in sublist]

class Ontology():
    def __init__(self, ontology):
        self.ontology = ontology
        self.ontology_obj = minidom.parse(ontology)
        self.root = self.ontology_obj.documentElement
        self.construct_mapping_dict()
        
        self.parents_dict = {}
        self.subclasses = self.parse_subclasses()
        self.object_properties = self.parse_object_properties()
        self.data_properties = self.parse_data_properties()
        self.triples = self.parse_triples()
        self.classes = self.parse_classes()        
    
    def construct_mapping_dict(self):
        self.mapping_dict = {self.extract_ID(el, False): self.get_child_node(el, "rdfs:label")[0].firstChild.nodeValue for el in self.root.getElementsByTagName("owl:Class") if self.get_child_node(el, "rdfs:label")}
        self.mapping_dict_inv = {self.mapping_dict[key]: key for key in self.mapping_dict}
        return
        
    def get_child_node(self, element, tag):
        return [e for e in element._get_childNodes() if type(e)==minidom.Element and e._get_tagName() == tag]
        
    def has_attribute_value(self, element, attribute, value):
        return True if element.getAttribute(attribute).split("#")[-1] == value else False
    
    def get_subclass_triples(self):
        subclasses = self.get_subclasses()
        for (a,b,c) in subclasses:
            if c == "subclass_of" and a!="Thing" and b!="Thing":
                if b not in self.parents_dict:
                    self.parents_dict[b] = [a]
                else:
                    self.parents_dict[b].append(a)
        return [(b,a,c) for (a,b,c) in subclasses]
    
    def parse_triples(self, union_flag=0, subclass_of=True):
        obj_props = self.object_properties
        data_props = self.data_properties
        props = obj_props + data_props
        all_triples = []
        for prop in props:
            domain_children = self.get_child_node(prop, "rdfs:domain")
            range_children = self.get_child_node(prop, "rdfs:range")
            domain_prop = self.filter_null([self.extract_ID(el) for el in domain_children])
            range_prop = self.filter_null([self.extract_ID(el) for el in range_children])
            if not domain_children or not range_children:
                continue
            if not domain_prop:
                domain_prop = self.filter_null([self.extract_ID(el) for el in domain_children[0].getElementsByTagName("owl:Class")])
            if not range_prop:
                range_prop = self.filter_null([self.extract_ID(el) for el in range_children[0].getElementsByTagName("owl:Class")])
            if domain_prop and range_prop:
                if union_flag == 0:
                    all_triples.extend([(el[0], el[1], self.extract_ID(prop)) for el in list(itertools.product(domain_prop, range_prop))])
                else:
                    all_triples.append(("###".join(domain_prop), "###".join(range_prop), self.extract_ID(prop)))
        if subclass_of:
            all_triples.extend(self.get_subclass_triples())
        
        return [triple for triple in list(set(all_triples)) if triple[0]!="Thing" and triple[1]!="Thing"]
    
    def get_triples(self, union_flag=0, subclass_of=True):
        return self.parse_triples(union_flag, subclass_of)

    def parse_subclasses(self, union_flag=0):
        subclasses = self.root.getElementsByTagName("rdfs:subClassOf")
        subclass_pairs = []
        for el in subclasses:
            inline_subclasses = self.extract_ID(el)
            if inline_subclasses:
                subclass_pairs.append((el, el.parentNode, "subclass_of"))
                
            else:
                level1_class = self.get_child_node(el, "owl:Class")
                if not level1_class:
                    restriction = el.getElementsByTagName("owl:Restriction")
                    if not restriction:
                        continue
                    prop = self.get_child_node(restriction[0], "owl:onProperty")
                    some_vals = self.get_child_node(restriction[0], "owl:someValuesFrom")
                    
                    if not prop or not some_vals:
                        continue
#                     print(self.extract_ID(el), "**", self.extract_ID(some_vals[0]), "**", self.extract_ID(prop[0]))
                    try:
                        if self.extract_ID(prop[0]) and self.extract_ID(some_vals[0]):
                            subclass_pairs.append((el.parentNode, some_vals[0], self.extract_ID(prop[0])))
                        elif self.extract_ID(prop[0]) and not self.extract_ID(some_vals[0]):
                            class_vals = self.get_child_node(some_vals[0], "owl:Class")
                            subclass_pairs.append((el.parentNode, class_vals[0], self.extract_ID(prop[0])))
                        elif not self.extract_ID(prop[0]) and self.extract_ID(some_vals[0]):
                            prop_vals = self.get_child_node(prop[0], "owl:ObjectProperty")
                            subclass_pairs.append((el.parentNode, some_vals[0], self.extract_ID(prop_vals[0])))
                        else:
                            prop_vals = self.get_child_node(prop[0], "owl:ObjectProperty")
                            class_vals = self.get_child_node(some_vals[0], "owl:Class")
                            subclass_pairs.append((el.parentNode, class_vals[0], self.extract_ID(prop_vals[0])))
                    except Exception as e:
                        print ("error", e)
                        continue
                else:
                    if self.extract_ID(level1_class[0]):
                        subclass_pairs.append((level1_class[0], el.parentNode, "subclass_of"))
                    else:
#                         level2classes = level1_class[0].getElementsByTagName("owl:Class")
#                         subclass_pairs.extend([(elem, el.parentNode, "subclass_of") for elem in level2classes if self.extract_ID(elem)])
                        continue
        return subclass_pairs
        
    def get_subclasses(self):
        subclasses = [(self.extract_ID(a), self.extract_ID(b), c) for (a,b,c) in self.subclasses]
        return [el for el in subclasses if el[0] and el[1] and el[2]]
    
    def filter_null(self, data):
        return [el for el in data if el]
    
    def extract_ID(self, element, check_coded = True):
        element_id = element.getAttribute("rdf:ID") or element.getAttribute("rdf:resource") or element.getAttribute("rdf:about")
        element_id = element_id.split("#")[-1]
        if len(list(filter(str.isdigit, element_id))) >= 3 and "_" in element_id and check_coded:
            return self.mapping_dict[element_id]
        return element_id.replace("UNDEFINED_", "").replace("DO_", "")
    
    def parse_classes(self):
        class_elems = [self.extract_ID(el) for el in self.root.getElementsByTagName("owl:Class")]
        subclass_classes = list(set(flatten([el[:-1] for el in self.triples])))
        return list(set(self.filter_null(class_elems + subclass_classes)))
    
    def get_classes(self):
        return self.classes
    
    def get_entities(self):
        entities = [self.extract_ID(el) for el in self.root.getElementsByTagName("owl:Class")]
        return list(set(self.filter_null(entities)))

    def parse_data_properties(self):
        data_properties = [el for el in self.get_child_node(self.root, 'owl:DatatypeProperty')]
        fn_data_properties = [el for el in self.get_child_node(self.root, 'owl:FunctionalProperty') if el]
        fn_data_properties = [el for el in fn_data_properties if type(el)==minidom.Element and 
            [el for el in self.get_child_node(el, "rdf:type") if 
             self.has_attribute_value(el, "rdf:resource", "DatatypeProperty")]]
        inv_fn_data_properties = [el for el in self.get_child_node(self.root, 'owl:InverseFunctionalProperty') if el]
        inv_fn_data_properties = [el for el in inv_fn_data_properties if type(el)==minidom.Element and 
            [el for el in self.get_child_node(el, "rdf:type") if 
             self.has_attribute_value(el, "rdf:resource", "DatatypeProperty")]]
        return data_properties + fn_data_properties + inv_fn_data_properties
        
    def parse_object_properties(self):
        obj_properties = [el for el in self.get_child_node(self.root, 'owl:ObjectProperty')]
        fn_obj_properties = [el for el in self.get_child_node(self.root, 'owl:FunctionalProperty') if el]
        fn_obj_properties = [el for el in fn_obj_properties if type(el)==minidom.Element and 
            [el for el in self.get_child_node(el, "rdf:type") if 
             self.has_attribute_value(el, "rdf:resource", "ObjectProperty")]]
        inv_fn_obj_properties = [el for el in self.get_child_node(self.root, 'owl:InverseFunctionalProperty') if el]
        inv_fn_obj_properties = [el for el in inv_fn_obj_properties if type(el)==minidom.Element and 
            [el for el in self.get_child_node(el, "rdf:type") if 
             self.has_attribute_value(el, "rdf:resource", "ObjectProperty")]]
        return obj_properties + fn_obj_properties + inv_fn_obj_properties
    
    def get_object_properties(self):
        obj_props = [self.extract_ID(el) for el in self.object_properties]
        return list(set(self.filter_null(obj_props)))
    
    def get_data_properties(self):
        data_props = [self.extract_ID(el) for el in self.data_properties]
        return list(set(self.filter_null(data_props)))

# %%
USE_folder = "/home/vlead/USE"
alignment_folder = "reference-alignment/"

# Load reference alignments 
def load_alignments(folder):
    alignments = []
    for f in os.listdir(folder):
        doc = minidom.parse(folder + f)
        ls = list(zip(doc.getElementsByTagName('entity1'), doc.getElementsByTagName('entity2')))
        alignments.extend([(a.getAttribute('rdf:resource'), b.getAttribute('rdf:resource')) for (a,b) in ls])
    return alignments


def cos_sim(a,b):
    return 1 - spatial.distance.cosine(a, b)


# Extracting USE embeddings

def extractUSEEmbeddings(words):
    try:
        embed = hub.KerasLayer(USE_folder)
    except Exception as e:
        # !mkdir $USE_folder
        # !curl -L "https://tfhub.dev/google/universal-sentence-encoder-large/5?tf-hub-format=compressed" | tar -zxvC $USE_folder
        embed = hub.KerasLayer(USE_folder)
        pass
    word_embeddings = embed(words)
    return word_embeddings.numpy()
        
reference_alignments = load_alignments(alignment_folder)

ra_anatomy_coded = load_alignments("../Anatomy/Alignments/")
ra_anatomy = []
ont1 = Ontology("../Anatomy/Ontologies/mouse.owl")
ont2 = Ontology("../Anatomy/Ontologies/human.owl")
for elem in ra_anatomy_coded:
    pre1, pre2 = elem[0].split("#")[0].split(".")[0].split("/")[-1], elem[1].split("#")[0].split(".")[0].split("/")[-1]
    elem1, elem2 = elem[0].split("#")[-1], elem[1].split("#")[-1]
    ra_anatomy.append(( pre1 + "#" + ont1.mapping_dict[elem1], pre2 + "#" + ont2.mapping_dict[elem2]))

gt_mappings = [tuple([elem.split("/")[-1] for elem in el]) for el in reference_alignments]
gt_mappings.extend(ra_anatomy)


ontologies_in_alignment = [["conference_ontologies/" + el  + ".owl" for el in l.split(".")[0].split("-")]
                           for l in os.listdir("reference-alignment/")]
ontologies_in_alignment += [["../Anatomy/Ontologies/human.owl", "../Anatomy/Ontologies/mouse.owl"]]

# %%
# Combinatorial mapping generation

all_mappings = []
for l in ontologies_in_alignment[:-1]:
    ont1 = Ontology(l[0])
    ont2 = Ontology(l[1])
    
    ent1 = ont1.get_entities()
    ent2 = ont2.get_entities()
    
    obj1 = ont1.get_object_properties()
    obj2 = ont2.get_object_properties()
    
    data1 = ont1.get_data_properties()
    data2 = ont2.get_data_properties()
    
    mappings = list(itertools.product(ent1, ent2)) + list(itertools.product(obj1, obj2)) + list(itertools.product(data1, data2))

    
    all_mappings.extend([(l[0].split("/")[-1].split(".")[0] + "#" + el[0], l[1].split("/")[-1].split(".")[0] + "#" + el[1]) for el in mappings])
    

data = {mapping: False for mapping in all_mappings}
for mapping in set(gt_mappings):
    data[mapping] = True
# Out:
# error list index out of range
# error list index out of range
# error list index out of range
# error list index out of range
# error list index out of range
# error list index out of range

# %%
# Abbrevation resolution preprocessing

abbreviations_dict = {}
final_dict = {}

for mapping in all_mappings:
    mapping = tuple([el.split("#")[1] for el in mapping])
    is_abb = re.search("[A-Z][A-Z]+", mapping[0])
    if is_abb:
        abbreviation = "".join([el[0].upper() for el in mapping[1].split("_")])
        if is_abb.group() in abbreviation:
            
            start = abbreviation.find(is_abb.group())
            end = start + len(is_abb.group())
            fullform = "_".join(mapping[1].split("_")[start:end])
            print ("left", mapping, abbreviation, fullform)
            
            rest_first = " ".join([el for el in mapping[0].replace(is_abb.group(), "").split("_") if el]).lower()
            rest_second = " ".join(mapping[1].split("_")[:start] + mapping[1].split("_")[end:])
            if is_abb.group() not in final_dict:
                final_dict[is_abb.group()] = [(fullform, rest_first, rest_second)]
            else:
                final_dict[is_abb.group()].append((fullform, rest_first, rest_second))

    is_abb = re.search("[A-Z][A-Z]+", mapping[1])
    if is_abb:
        abbreviation = "".join([el[0].upper() for el in mapping[0].split("_")])
        
        if is_abb.group() in abbreviation:
            start = abbreviation.find(is_abb.group())
            end = start + len(is_abb.group())
            fullform = "_".join(mapping[0].split("_")[start:end])
            print ("right", mapping, abbreviation, fullform)

            rest_first = " ".join([el for el in mapping[1].replace(is_abb.group(), "").split("_") if el]).lower()
            rest_second = " ".join(mapping[0].split("_")[:start] + mapping[0].split("_")[end:])
            if is_abb.group() not in final_dict:
                final_dict[is_abb.group()] = [(fullform, rest_first, rest_second)]
            else:
                final_dict[is_abb.group()].append((fullform, rest_first, rest_second))

keys = [el for el in list(set(flatten([flatten([tup[1:] for tup in final_dict[key]]) for key in final_dict]))) if el]
abb_embeds = dict(zip(keys, extractUSEEmbeddings(keys)))

scored_dict = {}
for abbr in final_dict:
    sim_list = [(tup[0], tup[1], tup[2], cos_sim(abb_embeds[tup[1]], abb_embeds[tup[2]])) if tup[1] and tup[2]
                else (tup[0], tup[1], tup[2], 0) for tup in final_dict[abbr]]
    scored_dict[abbr] = sorted(list(set(sim_list)), key=lambda x:x[-1], reverse=True)

resolved_dict = {key: scored_dict[key][0] for key in scored_dict}
filtered_dict = {key: " ".join(resolved_dict[key][0].split("_")) for key in resolved_dict if resolved_dict[key][-1] > 0.9}
# Out:
# right ('Steering_committee', 'SC_Member') SC Steering_committee
# right ('Passive_conference_participant', 'PC_Member') PCP Passive_conference
# right ('Passive_conference_participant', 'PC_Chair') PCP Passive_conference
# right ('Submitted_contribution', 'SC_Member') SC Submitted_contribution
# right ('Organizing_committee', 'OC_Member') OC Organizing_committee
# right ('Organizing_committee', 'OC_Chair') OC Organizing_committee
# right ('Program_committee', 'PC_Member') PC Program_committee
# right ('Program_committee', 'PC_Chair') PC Program_committee
# left ('Chair_PC', 'PC_Chair') PC PC_Chair
# left ('Member_PC', 'PC_Chair') PC PC_Chair
# left ('OC_Member', 'Organizing_Committee_member') OCM Organizing_Committee
# left ('OC_Member', 'Organizing_Committee') OC Organizing_Committee
# left ('OC_Chair', 'Organizing_Committee_member') OCM Organizing_Committee
# left ('OC_Chair', 'Organizing_Committee') OC Organizing_Committee
# left ('PC_Member', 'Program_Committee_member') PCM Program_Committee
# left ('PC_Member', 'Program_Chair') PC Program_Chair
# left ('PC_Member', 'Program_Committee') PC Program_Committee
# left ('PC_Chair', 'Program_Committee_member') PCM Program_Committee
# left ('PC_Chair', 'Program_Chair') PC Program_Chair
# left ('PC_Chair', 'Program_Committee') PC Program_Committee
# left ('Chair_PC', 'Program_Committee_member') PCM Program_Committee
# left ('Chair_PC', 'Program_Chair') PC Program_Chair
# left ('Chair_PC', 'Program_Committee') PC Program_Committee
# left ('Member_PC', 'Program_Committee_member') PCM Program_Committee
# left ('Member_PC', 'Program_Chair') PC Program_Chair
# left ('Member_PC', 'Program_Committee') PC Program_Committee
# left ('Chair_PC', 'Presenter_city') PC Presenter_city
# left ('Member_PC', 'Presenter_city') PC Presenter_city
# right ('Passive_conference_participant', 'Chair_PC') PCP Passive_conference
# right ('Passive_conference_participant', 'Member_PC') PCP Passive_conference
# right ('Program_committee', 'Chair_PC') PC Program_committee
# right ('Program_committee', 'Member_PC') PC Program_committee
# left ('paperID', 'is_dated_on') IDO is_dated
# left ('OC_Member', 'One_conference_day') OCD One_conference
# left ('OC_Chair', 'One_conference_day') OCD One_conference
# left ('PC_Member', 'Presenter_city') PC Presenter_city
# left ('SC_Member', 'Sponsor_company_house') SCH Sponsor_company
# left ('SC_Member', 'Brief_introduction_for_Session_chair') BIFSC Session_chair
# left ('SC_Member', 'Sponsor_city') SC Sponsor_city
# left ('SC_Member', 'Session_chair') SC Session_chair
# left ('PC_Chair', 'Presenter_city') PC Presenter_city

# %%
def camel_case_split(identifier):
    matches = re.finditer('.+?(?:(?<=[a-z])(?=[A-Z])|(?<=[A-Z])(?=[A-Z][a-z])|$)', identifier)
    return [m.group(0) for m in matches]

def parse(word):
    return flatten([el.split("_") for el in camel_case_split(word)])
    

extracted_elems = []

for ont_name in list(set(flatten(ontologies_in_alignment[:-1]))):
    ont = Ontology(ont_name)
    entities = ont.get_entities()
    props = ont.get_object_properties() + ont.get_data_properties()
    triples = list(set(flatten(ont.get_triples())))
    extracted_elems.extend([ont_name.split("/")[-1].split(".")[0] + "#" + elem for elem in entities + props + triples])

extracted_elems = list(set(extracted_elems))
inp = [" ".join(parse(word.split("#")[1])) for word in extracted_elems]

# Resolving abbreviations to full forms
inp_resolved = []
for concept in inp:
    for key in filtered_dict:
        concept = concept.replace(key, filtered_dict[key])
    final_list = []
    # Lowering case except in abbreviations
    for word in concept.split(" "):
        if not re.search("[A-Z][A-Z]+", word):
            final_list.append(word.lower())
        else:
            final_list.append(word)
    concept = " ".join(final_list)
    inp_resolved.append(concept)


url = "https://montanaflynn-spellcheck.p.rapidapi.com/check/"

headers = {
    'x-rapidapi-host': "montanaflynn-spellcheck.p.rapidapi.com",
    'x-rapidapi-key': "9965b01207msh06291e57d6f2c55p1a6a16jsn0fb016da4a62"
    }

inp_spellchecked = []
for concept in inp_resolved:
    querystring = {"text": concept}
    response = requests.request("GET", url, headers=headers, params=querystring).json()
    if response["suggestion"] != concept:
        resolved = str(concept)
        final_list = []
        for word in concept.split(" "):
            if not re.search("[A-Z][A-Z]+", concept):
                final_list.append(word.lower())
            else:
                final_list.append(word)
        resolved = " ".join(final_list)
#         print (resolved, "suggestion", response)
        for word in response["corrections"]:
            if not re.search("[A-Z][A-Z]+", concept):
                resolved = resolved.replace(word.lower(), response["corrections"][word][0].lower())
                
        
        print (concept, resolved)
        inp_spellchecked.append(resolved)
    else:
        inp_spellchecked.append(concept)

print ("Total number of extracted unique classes and properties from entire RA set: ", len(extracted_elems))

extracted_elems = ["<UNK>"] + extracted_elems

# stopwords = ["has", "is", "a", "an", "the"]
stopwords = ["has"]
inp_stemmed = []
for elem in inp_spellchecked:
    words = " ".join([word for word in elem.split() if word not in stopwords])
    words = words.replace("-", " ")
    inp_stemmed.append(words)

anatomy_terms = []
for ont_name in list(set(flatten(ontologies_in_alignment[-1:]))):
    ont = Ontology(ont_name)
    entities = ont.get_entities()
    props = ont.get_object_properties() + ont.get_data_properties()
    triples = list(set(flatten(ont.get_triples())))
    anatomy_terms.extend([ont_name.split("/")[-1].split(".")[0] + "#" + elem for elem in entities + props + triples])

anatomy_terms = list(set(anatomy_terms))
inp_anatomy = [" ".join(parse(word.split("#")[1])) for word in anatomy_terms]

roman_regex = "^M{0,3}(CM|CD|D?C{0,3})(XC|XL|L?X{0,3})(IX|IV|V?I{0,3})$"
inp_anatomy = [" ".join([word.replace("/", " or ") for word in elem.split() 
           if not re.search(word, roman_regex) and not re.search(word, "\d")]) for elem in inp_anatomy]

extracted_elems.extend(anatomy_terms)
inp_stemmed.extend(inp_anatomy)

embeds = np.array([np.zeros(512,)] + list(extractUSEEmbeddings(inp_stemmed)))
# embeds = np.array([np.zeros(512,)] + list(extractUSEEmbeddings(inp_spellchecked)))
embeddings = dict(zip(extracted_elems, embeds))


emb_vals = list(embeddings.values())
emb_indexer = {key: i for i, key in enumerate(list(embeddings.keys()))}
emb_indexer_inv = {i: key for i, key in enumerate(list(embeddings.keys()))}

inp_anatomy
# Out:
# error list index out of range
# NGO NGO
# has a URL has a URL
# SC member SC member
# technically organised by technically organized by
# print hardcopy mailing manifests print hard copy mailing manifests
# sponzorship sponsorship
# scientifically organised by scientifically organized by
# ACM SIGKDD ACM SIGKDD
# LCD projector LCD projector
# coctail reception cocktail reception
# cheque exchequer
# operating topicsystems operating topic systems
# webmaster web master
# paper ID paper ID
# TProgram committee member TProgram committee member
# organising agency organizing agency
# site URL site URL
# powerline transmission topic power line transmission topic
# has VAT has VAT
# organised by organized by
# registeered applicant registered applicant
# has programme has programmer
# sponzor fee sponsor fee
# is writen by is write by
# technical commitee technical committee
# nonauthor registration fee non author registration fee
# conference www conference www
# presentationed by presentation ed by
# accepts hardcopy submissions accepts hard copy submissions
# viza viz
# CAD topic CAD topic
# holded by holed by
# memeber registration fee member registration fee
# organises organists
# modelling modeling
# cd proceening cd proceeding
# any URI any URI
# programme brochure programmer brochure
# is the 1th part of is the th part of
# programme programmer
# hardcopy mailing manifests printed by hard copy mailing manifests printed by
# reviewes reviewed
# has a commtitee has a committee
# registration SIGKDD member registration SIGKDD member
# author attendee cd registration fee author attendee cd registration fee
# IASTED member IASTED member
# has an ISBN has an ISBN
# registration SIGMOD member registration SIGMOD member
# was a committe co-chair of was a committee co-chair of
# sponzor sponsor
# is a topis of conference parts is a tops of conference parts
# organizator organization
# initial manuscipt initial manuscript
# registation deadline registration deadline
# computer networks aapplications topic computer networks applications topic
# accpet if room rating accept if room rating
# technic activity technical activity
# IASTED non member IASTED non member
# scientifically organises scientifically organists
# logo URL logo URL
# technically organises technically organists
# organisation organization
# flyer flayer
# author cd proceedings included author cd proceedings included
# contribution 1th-author contribution th-author
# Total number of extracted unique classes and properties from entire RA set:  829
# ['trigeminal nerve ophthalmic division',
#  'lower back connective tissue',
#  'Macula of Saccule',
#  'hypothalamus lateral zone',
#  'Other Multiple Areas',
#  'Sternum',
#  'scala media',
#  'Modiolus',
#  'lobar bronchus connective tissue',
#  'Right Lumbar Region',
#  'Vascular System',
#  'Sensory Ganglion',
#  'Cartilage Cell',
#  'Kidney Upper Lobe',
#  'hand digit muscle',
#  'Reserve Cell',
#  'Right Common Iliac Artery',
#  'S3 Vertebra',
#  'Nucleus of the Solitary Tract',
#  'small intestine smooth muscle longitudinal layer',
#  'lower jaw molar',
#  'Frontal Horn of the Lateral Ventricle',
#  'distal convoluted tubule macula densa',
#  'external ear cartilage',
#  'ventricular septum',
#  'posterior division',
#  'Erythroid Progenitor Cell',
#  'Diarthrosis',
#  'Left Lung Respiratory Bronchiole',
#  'cellular cartilage',
#  'Medial Lenticulostriate Artery',
#  'Communicating Artery',
#  'ureter lamina propria',
#  'esophagus smooth muscle longitudinal layer',
#  'Lateral-occipital Sulcus',
#  'Exocrine System',
#  'spinal nerve plexus',
#  'Seminal Vesicle Secretion',
#  'Alveolar Septum',
#  'trachea smooth muscle',
#  'Endocrine-Stromal Cell',
#  'Nucleus of the Mesencephalic Tract of the Trigeminal Nerve',
#  'common palmar digital arteries',
#  'Concha',
#  'Small Intestinal Mucosa',
#  'Rib 12',
#  'Hepatic Stellate Cell',
#  'Urinary System',
#  'Lipocyte',
#  'foot digit 5',
#  'Right Innominate Vein',
#  'adenohypophysis',
#  'Otolymph',
#  'Glomeruloza Zone',
#  'Anterior Infratentorial Cistern',
#  'parotid gland',
#  'Subclavian Artery',
#  'Thoracic Ganglion',
#  'cervical mammary gland',
#  'Utero-Vesical Pouch',
#  'Dorsal Horn of the Spinal Cord',
#  'Deep Fascia',
#  'lateral thoracic vein',
#  'Cerebral Arachnoid Membrane',
#  'Retinal Pigment Epithelium',
#  'thyroid gland follicle',
#  'cardiovascular system',
#  'small intestine wall',
#  'Urinary System Part',
#  'vertebra spinous process',
#  'Endocrine Cell of the Gastrointestinal System',
#  'Convoluted Tubule',
#  'Tunica Intima',
#  'abdomen organ',
#  'spinal cord arachnoid mater',
#  'thoracic vertebra 5',
#  'abdomen blood vessel',
#  'Pulp Horn',
#  'spinal cord lateral motor column',
#  'dorsal metacarpal artery',
#  'visceral pleura',
#  'costochondral joint',
#  'Palatal Muscle',
#  'thoracic vertebra 11',
#  'Pupil',
#  'outflow tract aortic component',
#  'splenic cord',
#  'female urethra',
#  'basilar membrane',
#  'ventral labial vein',
#  'head muscle',
#  'Right Pulmonary Artery',
#  'Vermis',
#  'Tibial Nerve',
#  'pituitary gland',
#  'Mesentery',
#  'Interosseous Vein',
#  'Choroid Plexus of the Fourth Ventricle',
#  'Parathyroid Gland Clear Cell',
#  'Mediastinal Lymph Node',
#  'Bronchus Basement Membrane',
#  'Endolymph',
#  'Auricle',
#  'Distal Convoluted Tubule',
#  'head organ',
#  'exocrine pancreas',
#  'ophthalmic plexus',
#  'Transverse Fissure',
#  'Type III Epithelial Receptor Cell',
#  'Lesser Trochanter',
#  'Fusiform Cell',
#  'Upper Third of the Esophagus',
#  'Cornea',
#  'trunk nerve',
#  'Alveolar Sac',
#  'locus coeruleus',
#  'joint of rib',
#  'Lower Jaw Molar',
#  'sacral vertebra 4',
#  'Blast Cell',
#  'longus capitis',
#  'Internal Thoracic Vein',
#  'Smegma',
#  'supraoccipital bone',
#  'Adenohypophysial Cell',
#  'Myoepithelial Cell',
#  'Posterior Longitudinal Ligament',
#  'abdomen connective tissue',
#  'axillary vein',
#  'primary somatosensory cortex',
#  'Vagal Triangle',
#  'Irregular Bone',
#  'iliacus',
#  'pericardial cavity',
#  'upper arm bone',
#  'Male Prepuce',
#  'right lung',
#  'intercostales',
#  'left lung alveolus',
#  'Bone Marrow Myeloid Stem Cell with Some Commitment to Monocytic Differentiation',
#  'fibrous joint',
#  'reticular tegmental nucleus',
#  'Enamel',
#  'urethra lamina propria',
#  'retina inner plexiform layer',
#  'Rod',
#  'kidney calyx',
#  'Obturator Internus Muscle',
#  'Fimbriated End of the Fallopian tube',
#  'Central Nervous System Part',
#  'middle colic artery',
#  'basal ganglia',
#  'Ovarian Capsule',
#  'transversus abdominis',
#  'spinal cord reticular nucleus',
#  'Craniopharyngeal Duct',
#  'Nasopharynx',
#  'Transformed Peripheral B-Lymphocyte',
#  'Ascending Parietal Convolution',
#  'Superior Profunda Artery',
#  'cortical layer III',
#  'forebrain dura mater',
#  'parietal mesothelium',
#  'Cardia',
#  'adrenal gland capsule',
#  'Corpus Callosum',
#  'Splenic Capsule',
#  'brain marginal zone',
#  'posterior semicircular canal',
#  'Unmyelinated Nerve Fiber',
#  'vestibular membrane',
#  'Trophoblastic Cell',
#  'labial artery',
#  'distal carpal bone',
#  'trigeminal ganglion',
#  'Posterior Wall of the Oropharynx',
#  'large intestine smooth muscle',
#  'Permanent Tooth',
#  'brown fat',
#  'tympanic ring',
#  'submandibular duct',
#  'Intercostal Fascia',
#  'temporal artery',
#  'intrinsic tongue muscle',
#  'Columnar Cell',
#  'shoulder connective tissue',
#  'hyaloid cavity',
#  'eye skin gland',
#  'Lutein Cell',
#  'Sternocostal Joint',
#  'right ureter',
#  'Female Urethra',
#  'auricular blood vessel',
#  'T9 Vertebra',
#  'skeletal muscle tissue',
#  'right lung accessory lobe',
#  'Postcapillary Venule',
#  'hippocampus stratum radiatum',
#  'midbrain pia mater',
#  'Endocrine Ovary',
#  'Nutrient Artery',
#  'Vasa Vasorum',
#  'Jugular Vein',
#  'right kidney',
#  'forebrain arachnoid mater',
#  'vitreous chamber',
#  'axillary lymph node',
#  'Renal Papilla',
#  'penile urethra fossa terminalis',
#  'sensory ganglion',
#  'Delta Cell',
#  'Immature B-Lymphocyte',
#  'Foot Bone',
#  'lens epithelium',
#  'gracilis',
#  'thoracic cavity',
#  'Metatarsal Bone',
#  'Temporary Tooth',
#  'Internal Mammary Vein',
#  'vena cava endothelium',
#  'thoracic vertebra 4',
#  'Left Colon',
#  'lung',
#  'autonomic nerve plexus',
#  'Anterior Tibial Artery Branch',
#  'Eccrine Cell',
#  'cerebellar cortex',
#  'juxtamedullary cortex',
#  'esophagus wall',
#  'Pyramid of Ferrein',
#  'Type Hair Cell',
#  'midline thalamic group',
#  'Coracobrachialis',
#  'Facial Artery',
#  'Head and Neck Fluids and Secretions',
#  'Cortical Vein',
#  'right internal spermatic vein',
#  'trachea',
#  'foregut',
#  'thoracic aorta',
#  'Glandular Epithelium',
#  'Adrenal Medulla',
#  'appendicular skeleton',
#  'Mesenteric Artery',
#  'Small Intestinal Wall Tissue',
#  'gall bladder',
#  'telencephalon dura mater',
#  'anal region',
#  'Musculoskeletal System Part',
#  'lacrimal artery',
#  'Lamina Rara Interna',
#  'left pulmonary vein',
#  'olfactory bulb glomerular layer',
#  'celiac ganglion',
#  'Medullary Artery',
#  'Connective and Soft Tissue',
#  'Lateral Surface of the Prostate',
#  'Tarsal Plate',
#  'spinal vestibular nucleus',
#  'Burr Hole',
#  'Skin Squamous Cell',
#  'zigzag hair',
#  'organ system',
#  'Cerebellar Cortex',
#  'anterior jugular vein',
#  'ischiatic vein',
#  'palatine gland',
#  'Perineural Cell',
#  'Perimysium',
#  'Anterior Surface of the Epiglottis',
#  'Inner Hair Cell of the Organ of the Corti',
#  'loop of henle',
#  'Cerebral Vein',
#  'Layer of the Rods and Cones',
#  'ventral posterior thalamic group',
#  'Extrahepatic Bile Duct Epithelium',
#  'parathyroid gland capsule',
#  'Inner Canthus',
#  'Gastrointestinal System',
#  'internal iliac artery',
#  'Prepontine Cistern',
#  'Central Portion of the Breast',
#  'spleen lymphoid follicle',
#  'Upper-outer Quadrant of the Breast',
#  'Mesangial Cell',
#  'arm muscle',
#  'tail intervertebral disc',
#  'infundibulum',
#  'bulbourethral gland secretion',
#  'Lung Upper Lobe',
#  'Pylorus',
#  'vestibular labyrinth',
#  'accumbens nucleus',
#  'Upper Respiratory System',
#  'Renshaw Cell',
#  'lip',
#  'Pituicyte',
#  'cervical vertebra 2',
#  'trachea submucosa',
#  'Ileocecal Valve',
#  'Superficial Vein',
#  'Gastric Glandular Cell',
#  'Corpora Cavernosa',
#  'Body of the Penis',
#  'Hematopoietic Stem Cell',
#  'adrenal gland brown degeneration zone',
#  'joint of girdle',
#  'Anterior Choroidal Artery',
#  'epididymal smooth muscle',
#  'pineal gland',
#  'hip joint',
#  'Hemispheric Cistern',
#  'Hair Root',
#  'Articular Cartilage',
#  'trunk muscle',
#  'Left Main Bronchus',
#  'Hilar Portion of the Left Hepatic Duct',
#  'neuroendocrine gland',
#  'Tuberculum Sellae',
#  'Membrane',
#  'tympanic cavity blood vessel',
#  'bronchus lamina propria',
#  'Orbitalis Muscle',
#  'Microcirculatory Bed',
#  'abdomen or pelvis or perineum connective tissue',
#  'Serratus Magnus',
#  'forelimb nerve',
#  'Fenestra Ovalis',
#  'Myofibroblast',
#  'Tendinocyte',
#  'Supratentorial Cistern',
#  'hip connective tissue',
#  'Skin of the Upper Limb and Shoulder',
#  'Middle Colic Artery',
#  'glomerular capsule',
#  'Superior Occipital Convolution',
#  'renal subcapsular mesenchyme',
#  'Other Body Fluids and Secretions',
#  'Vertebral Joint',
#  'Satellite Cell',
#  'Deep Palmar Vein',
#  'lip philtrum',
#  'Crypts of the Lieberkuhn',
#  'Right Cerebral Hemisphere',
#  'principal vein of forelimb',
#  'Cuneate Nucleus',
#  'cranium',
#  'omental bursa',
#  'rib 13',
#  'Stratum Reticulare',
#  'Classic Lobule',
#  'Middle Frontal Convolution',
#  'Sternohyoid',
#  'Left Spermatic Artery',
#  'Muscle of the Tympanum',
#  'spinal cord dorsal column',
#  'phrenic nerve trunk',
#  'Left Subclavian Artery',
#  'symphysis menti',
#  'External Cuneiform Bone of the Foot',
#  'lateral spinal nucleus',
#  'ureter',
#  'occipital bone',
#  'posterior semicircular duct',
#  'Lateral Lenticulostriate Artery',
#  'extensor digitorum lateralis',
#  'Promyelocyte',
#  'Occipital-temporal Gyrus',
#  'Gingival Epithelium',
#  'Common Bile Duct',
#  'Skin of the Extremity',
#  'vestibulocochlear VIII ganglion cochlear component',
#  'Pelvic Bone',
#  'lunate',
#  'Rete Testis',
#  'Semen',
#  'venous sinus',
#  'Anal Margin',
#  'Inferior Palpebral Fold',
#  'Midcortical Nephron',
#  'Eye',
#  'laterodorsal tegmental nucleus',
#  'Radius Bone',
#  'esophagus basal epithelium',
#  'corniculate cartilage',
#  'Lung Tissue',
#  'respiratory system blood vessel endothelium',
#  'Mucus',
#  'vagus nerve trunk',
#  'auditory tube',
#  'interlobular vein',
#  'hand joint',
#  'Tympanic Membrane',
#  'thoracic sympathetic nerve trunk',
#  'Sternothyroid',
#  'Keratinocyte',
#  'Epineurium',
#  'Subsegmental Bronchus of Right Lung',
#  'Paranasal Sinus',
#  'inner renal medulla',
#  'duvet hair',
#  'Lumbar Artery',
#  'Superficial Circumflex Iliac Artery',
#  'Heart Part',
#  'neck connective tissue',
#  'right atrium venous valve',
#  'left spermatic artery',
#  'Stratified Epithelium',
#  'barrel cortex',
#  'Infundibular Segment of the Fallopian Tube',
#  'Buccal Salivary Gland',
#  'serratus ventralis',
#  'Anterior Temporal Artery',
#  'palatal shelf',
#  'Immunoblast',
#  'Temporo-maxillary Vein',
#  'spinal cord dorsal nucleus',
#  'Superior Cerebellar Artery',
#  'Epiglottic Cartilage',
#  'S4 Vertebra',
#  'Splenic Sinus',
#  'Vertebral Canal',
#  'gall bladder lamina propria',
#  'brain arachnoid matter',
#  'pampiniform plexus',
#  'respiratory system submucosa',
#  'Head and Neck Lymph Node',
#  'True Vocal Cord',
#  'spinal cord central cervical nucleus',
#  'arrector pili smooth muscle',
#  'Epimysium',
#  'Outer Segment of the Photoreceptor Cell',
#  'pial vein',
#  'Corneal Stroma',
#  'Skin of Other and Unspecified Parts of Face',
#  'Wrist Joint',
#  'Bladder Wall',
#  'area postrema',
#  'vein',
#  'clitoris',
#  'Ellipsoid Portion of the Inner Segment of the Photoreceptor Cell',
#  'Pancreatic Secretion',
#  'Costophrenic Angle',
#  'hand digit',
#  'Small Intestinal Muscular Coat',
#  'Posterior Carpal Artery',
#  'Uvea',
#  'Gallbladder Serosal Surface',
#  'Ovarian Tissue',
#  'bowel',
#  'Subscapular Artery',
#  'Bronchial Epithelium',
#  'Astragalus',
#  'iliopsoas',
#  'Axilla',
#  'Uvula',
#  'vertebral artery',
#  'interparietal bone',
#  'medial femoral vein',
#  'Meningothelial Cell',
#  'Sacral Nerve',
#  'Uterine Gland',
#  'Spinal Dorsal Nerve',
#  'limb muscle',
#  'Opening of the Thorax',
#  'peritoneal cavity',
#  'Pancreatico-Duodenal Vein',
#  'Lingual Artery',
#  'major calyx',
#  'Lower Lobe of the Right Lung',
#  'shoulder skin',
#  'major salivary gland',
#  'vesical vein',
#  'Fovea Centralis',
#  'Spinal Cord Fissure',
#  'Ascending Frontal Artery',
#  'Basilar Membrane',
#  'wrist joint',
#  'vena cava',
#  'rectus femoris',
#  'foot bone',
#  'Renal Interstitial Cell',
#  'liver bare area',
#  'Central Zone of the Prostatic Parenchyma',
#  'Semispinalis Capitis',
#  'Ophthalmic Plexus',
#  'Sphenoid Bone',
#  'Spinal Meninges',
#  'Anatomic Sites',
#  'pelvic sympathetic nerve trunk',
#  'hippocampus layer',
#  'glomerular capillary basement membrane',
#  'Body of the Nail',
#  'cerebellum lobule',
#  'Adrenal Gland',
#  'High Endothelial Venule',
#  'masseter',
#  'abdomen or pelvis or perineum muscle',
#  'anterior semicircular canal',
#  'external acoustic meatus',
#  'hypopharynx',
#  'sternal manubrium',
#  'Sternocleidomastoid Muscle',
#  'atrioventricular node',
#  'seminiferous tubule',
#  'Fascia',
#  'zeugopod',
#  'bronchus associated lymphoid tissue',
#  'Nervous System Part',
#  'vertebra caudal articular process',
#  'intermediate cuneiform',
#  'zona incerta',
#  'male reproductive gland',
#  'Male Genital System Fluid or Secretion',
#  'Special Sense Organ System',
#  'sternohyoid',
#  'Neuropil',
#  'aorta endothelium',
#  'Anterior Circulation Intracranial Artery',
#  'Eccrine Sweat Gland',
#  'Foramen Magnum',
#  'Left Spermatic Vein',
#  'trigeminal nerve mandibular division',
#  'Trachea Smooth Muscle Tissue',
#  'Corpus Callosum Cistern',
#  'larynx submucosa',
#  'Body',
#  'Deep Middle Cerebral Vein',
#  'septohippocampal nucleus',
#  'Gut Associated Lymphoid Tissue',
#  'Longissimus Thoracis',
#  'Cortical Column',
#  'Stellate Reticulum',
#  'osseus cochlea',
#  'Right Ovary',
#  'Proximal Phalanx of Hand',
#  'Endosteal Cell',
#  'prostate gland ventral lobe',
#  'cranial nerve',
#  'Corpus Striatum',
#  'cuticle',
#  'ankle joint',
#  'epidermis stratum granulosum',
#  'adrenal gland',
#  'leg skin',
#  'Suppressor-Effector T-Lymphocyte',
#  'Skeletal Muscle Tissue',
#  'Ulna',
#  'Astrocyte',
#  'Abdominal Cavity',
#  'cerebral cortex',
#  'Muscle Cell',
#  'cervical ganglion',
#  'wrist skin',
#  'Germinal Center',
#  'Corona Dentis',
#  'respiratory system fluid or secretion',
#  'upper arm connective tissue',
#  'inferior mesenteric artery',
#  'esophagus smooth muscle',
#  'iris blood vessel',
#  'ureteral valve',
#  'Hilar Area of the Kidney',
#  'Rostrum of the Corpus Callosum',
#  'Lobar Bronchus',
#  'Phrenic Vein',
#  'dorsal spinal vein',
#  'secondary somatosensory cortex',
#  'abducens VI nucleus',
#  'Tragus',
#  'Sacral Bone',
#  'lateral habenular nucleus',
#  'arcuate vein',
#  "peyer's patch epithelium",
#  'Right Testis',
#  'Fore-Brain',
#  'Skeletal Muscle Cell',
#  'Cuneiform Cartilage',
#  'Cardiac Valve Cusp',
#  'Gland of Krause',
#  'Superior Hypophyseal Artery',
#  'Collateral Sulcus',
#  'Specialized Epithelial Cell',
#  'lumbar sympathetic nerve trunk',
#  'oral epithelium',
#  'Sacrococcygeal Joint',
#  'dorsal aorta',
#  'cleidooccipital',
#  'Psoas Minor',
#  'Internal Auditory Artery',
#  'Posterior Meningeal Artery',
#  'Purkinje s Cell',
#  'Theca Lutein Cell',
#  'elbow joint',
#  'Prostate Gland',
#  'Germinal Center B-Lymphocyte',
#  'accessory XI nerve cranial component',
#  'Glans Clitoris',
#  'myenteric nerve plexus',
#  'Lymph Node Efferent Vessel',
#  'liver right lobe',
#  'Vocalis Muscle',
#  'humerus',
#  'Collateral Fissure',
#  'Umbilical Region',
#  'Goblet Cell',
#  'Tibialis Caudalis',
#  'Vagina',
#  'Internal Iliac Artery Branch',
#  'Multiform Cell Layer',
#  'Ureter',
#  'Autonomic Ganglion',
#  'Base of the Brain',
#  'lymphatic vessel smooth muscle',
#  'outflow tract endothelium',
#  'right uterine horn',
#  'Premedullary Cistern',
#  'Glottis',
#  'heart myocardium',
#  'septal coronary artery',
#  'Cystic Duct',
#  'Superior Cerebellar Cistern',
#  'Internal Malleolar Artery',
#  'stapedius',
#  'third ventricle ependyma',
#  'Intercostal Artery',
#  'Choroid Plexus Epithelium of the Fourth Ventricle',
#  'paraventricular hypothalamic nucleus',
#  'Cervix Epithelium',
#  'right hepatic recess',
#  'thymus lobule',
#  'External Capsule',
#  'Juxtamedullary Nephron',
#  'Serosal Surface of the Liver',
#  'Connecting Segment of the Photoreceptor Cell',
#  'abducens VI nerve',
#  'lateral rectus extraocular muscle',
#  'Renal Pyramid',
#  'Opening of the Pulmonary Vein',
#  'cortical layer VI',
#  'labium',
#  'Oropharyngeal Lymphoid Tissue',
#  'bronchus',
#  'Visceral Part of the Peritoneum',
#  'Hematopoietic System',
#  'right lung hilus',
#  'larynx ligament',
#  'Immune System',
#  'Foot',
#  'Kinocilium',
#  'trachea basal lamina',
#  'left common carotid artery',
#  'extrinsic tongue muscle',
#  'Clara Cell',
#  'Pubic Symphisis',
#  'tubotympanic recess',
#  'lower leg',
#  'Neuron and Supporting Cell of the Nervous System',
#  'Middle Temporal Convolution',
#  'Low Columnar Cell',
#  'Magendie s Foramen',
#  'Spiral Tube of Schchowa',
#  'minor salivary gland',
#  'Foramen of Monroe',
#  'inferior vena cava',
#  'skin sebaceous gland',
#  'ocular smooth muscle',
#  'Bladder',
#  'Posterior Communicating Artery',
#  'White Matter of the Spinal Cord',
#  'intercostal artery',
#  'gastro-splenic ligament',
#  'omental bursa superior recess',
#  'nasal bone',
#  'loop of henle ascending limb',
#  'inferior oblique extraocular muscle',
#  'median dorsal digital artery for digit 01',
#  'respiratory system cartilage',
#  'Mucosa of the Lip',
#  'rest of ureter',
#  'Promonocyte',
#  'auricular cartilage',
#  'intercostales externus',
#  'Neck of the Humerus',
#  'Bladder Neck',
#  'sweat gland',
#  'Ion Channel',
#  'amygdala',
#  'tendon',
#  'Epidural Spinal Canal Space',
#  'Thymic Medullary Epithelial Cell',
#  'Transitional Cell',
#  'Left Testis',
#  'Epidermis',
#  'principal artery to hindlimb',
#  'Gastric Serosal Surface',
#  'upper jaw molar',
#  'Salivary Gland Tissue',
#  'mouse anatomy',
#  'Organ of Special Sense Part',
#  'Periodontium',
#  'lateral marginal vein',
#  'Pisiform Bone',
#  'Pronator Teres',
#  'Venous Sinus',
#  'Thymic Epithelial Cell Capable of Differentiating Towards Cortical Cell Type',
#  'Eyelid Connective Tissue',
#  'descending colon',
#  'elastic cartilage',
#  'right renal artery',
#  'Popliteus Muscle',
#  'Anal Canal',
#  'Jaw',
#  'rhomboid',
#  'Intrathoracic Lymph Node',
#  'small intestine',
#  'Chief Cell of the Stomach',
#  'Continuous Capillary',
#  'Innominate Vein',
#  'basilic vein',
#  'oval nucleus',
#  'Crystal of Reinke',
#  'lymphoid tissue',
#  'Lung',
#  'popliteus',
#  'tarsus',
#  'Biliary Tract',
#  'Dorsum of the Tongue',
#  'Hepatic Duct',
#  'Anterior Surface of the Liver',
#  'Foot Digit Phalanx',
#  'Ampullary Crest',
#  'forebrain',
#  'uvea',
#  'Terminal Ductal Lobular Unit Cell',
#  'foot digit nerve',
#  'Basal Domain of the Epithelium',
#  'Fourth Ventricle Ependyma',
#  'ear lobe',
#  'EBV-Specific Cytotoxic T-Lymphocyte',
#  'kidney capillary',
#  'temporal cortex',
#  'uterine horn',
#  'Lower Jaw',
#  'Venule',
#  'kidney cortex',
#  'nasal cavity olfactory epithelium',
#  'Long Bone',
#  'eye sebaceous gland',
#  'chest organ',
#  'Meningeal Layer of the Dura Mater',
#  'macula of saccule',
#  'Dorsal Cochlear Nucleus',
#  'superior vagus ganglion',
#  'thorax nerve',
#  'Inferior Temporal Convolution',
#  'Acromial Thoracic Artery',
#  'spleen periarteriolar lymphatic sheath',
#  'Circular Ligament of the Tooth',
#  'Thymus Cortex',
#  'lower back blood vessel',
#  'gastrointestinal system smooth muscle',
#  'Esophageal Epithelium',
#  'External Circumflex Artery',
#  'B-Immunoblast',
#  'Hair Follicle',
#  'stomach secretion',
#  'tibial nerve',
#  'right lung respiratory bronchiole',
#  'Median Basilic Vein',
#  'thymus',
#  'Pars Externa',
#  'Seminal Vesicle Epithelium',
#  'head or neck skin',
#  'Marginal Zone of Lymph Node',
#  'Oculomotor Nerve',
#  'mammary gland milk',
#  'spinal cord dorsal commissural nucleus',
#  'Posterior Surface of the Stomach',
#  'Photoreceptors Invertebrate',
#  'Long Bone Epiphysis',
#  'cuboidal oviduct epithelium',
#  'Thyroid Cartilage',
#  'scaphoid',
#  'Subependymal Cell',
#  'Sacral Spinal Nerve Root',
#  'Thyroid Gland Follicular Cell',
#  'Parotid Gland Lymph Node',
#  'nucleus ambiguus',
#  'dentate gyrus',
#  'Purkinje Cell Layer of the Cerebellum',
#  'Ductal Epithelial Cell',
#  'respiratory system lamina propria',
#  'medullary reticular nucleus',
#  'prostatic urethra',
#  'Macula Lutea',
#  'renal or urinary system',
#  'Outer Nuclear Layer of Retina',
#  'head or neck muscle',
#  'Left Innominate Vein',
#  'Lung Lobe',
#  'Splenic Pulp',
#  'Endothelium of the Glomerular Capillary',
#  'Sarcolemma',
#  'metacarpus',
#  'Kidney Part',
#  'areola',
#  'Vermiform Appendix',
#  'left lung terminal bronchiole',
#  'superior glossopharyngeal ganglion',
#  'Muscle of the Coccyx',
#  'sensory organ',
#  'Major Salivary Gland',
#  'T2 Vertebra',
#  'Trachea Cartilage',
#  'cerebellum',
#  'thymic vein',
#  'superior external pudendal vein',
#  'Middle Cerebral Artery Branch',
#  'inferior cervical ganglion',
#  'renal artery',
#  'penile urethra',
#  'anterior limiting lamina',
#  'Foot Digit 5',
#  'Endocrine Cell and Neuroendocrine Cell',
#  'lower eyelid',
#  'testis interstitial tissue',
#  'kidney pelvis urothelium',
#  'colon',
#  'bile duct extrahepatic part',
#  'Cervicomedullary Junction',
#  'pre-botzinger complex',
#  'internal spermatic artery',
#  'Subthalamic Nucleus',
#  'gall bladder epithelium',
#  'third ventricle choroid plexus',
#  'nail',
#  'Irregular Tubule',
#  'mammary gland epithelium',
#  'Rib 9',
#  'Blood-Brain Barrier',
#  'hippocampus pyramidal layer',
#  'small intestine muscularis mucosa',
#  'Extracellular Structure',
#  'longissimus lumborum',
#  'Axillary Vein',
#  'retina outer nuclear layer',
#  'Cauda Equina',
#  'Extensor Digitorum Communis',
#  'thoracic cavity artery',
#  'pancreatic acinus',
#  'small intestine epithelium',
#  'Sylvian Cistern',
#  'Bladder Transitional Cell Epithelium',
#  'internal thoracic artery',
#  'proximal tubule segment 1',
#  'Cortical Arch',
#  'trachea connective tissue',
#  'Skull',
#  'Nerve Plexus',
#  'common hepatic duct',
#  'Metatarsal Bone Digit',
#  'Superior Cerebellopontine Cistern',
#  'Neuroepithelial Tissue',
#  'Obturator Muscle',
#  'Tectum Mesencephali',
#  'T-Lymphocyte with a Post-Thymic Immunophenotype',
#  'sciatic nerve',
#  'Mature B-Lymphocyte',
#  'rectus abdominis',
#  'Gastrointestinal Tract',
#  'Trigeminal Nucleus',
#  'Trachea',
#  'Musculoskeletal System',
#  'Deep Vein',
#  'Coeliac Ganglion',
#  'Sagittal Sinus',
#  'Male Urethra',
#  'Gracilis',
#  'Prostate Gland Lobe',
#  'molar',
#  'Base of the Tongue',
#  'sacral vertebra',
#  'Labial Artery',
#  'costal arch',
#  'Thymic Lobule',
#  'prepuce epithelium',
#  'Thymus Medulla',
#  'Anterior Inferior Cerebellar Artery',
#  'Decidua',
#  'dentate gyrus layer',
#  'right adrenal gland',
#  'dorsal artery of foot',
#  'Pulmonary Lobule',
#  'Breast-Related Entity',
#  'Superficial Temporal Vein',
#  'transverse nucleus',
#  'Crystalline Lens',
#  'diencephalon',
#  'Ependyma',
#  'Ceruminous Gland',
#  'Distal Phalanx of Hand',
#  'External Pyramidal Cell Layer',
#  'central medial nucleus',
#  'posterior communicating artery',
#  'phrenic nerve',
#  'Neck',
#  'spinal cord ventral horn',
#  'gracile nucleus',
#  'Acidophilic Cell',
#  'Perivitelline Space',
#  'Interlobular Artery',
#  'Tonsillar Pillar',
#  'Cuboid Bone',
#  'parathyroid gland parenchyma',
#  'Glomerular Basement Membrane',
#  'distal convoluted tubule straight part',
#  'Simple Cuboidal Epithelium',
#  'stomach glandular region',
#  'hippocampus CA2',
#  'Costovertebral Joint',
#  'Lymphoid Blood-Forming Cell',
#  'Olfactory Cistern',
#  'Lymph',
#  'ductus reuniens',
#  'Subarachnoid Cistern',
#  'Cystic Vein',
#  'forelimb proper dorsal digital arteries',
#  'alveolar artery',
#  'Diaphragm Part',
#  'ovary theca',
#  'Odontoblast',
#  'Basilic Vein',
#  'Bronchus Elastic Tissue',
#  'Precentral Artery',
#  'venule',
#  'Plasmacytoid Dendritic Cell Precursor',
#  'Tear',
#  'forelimb bone',
#  'Pericardium',
#  'Frontal Bone',
#  'endolymph',
#  'palmar hand interosseus muscle',
#  'Myelocyte',
#  'Middle Fossa',
#  'Corneal Endothelium',
#  'Eparterial Branch',
#  'Arteriole Smooth Muscle Tissue',
#  'renal tubule basement membrane',
#  'Superior Mesenteric Artery Branch',
#  'Transverse Colon',
#  'Stroma of the Ovarian Cortex',
#  'Brunner s Gland',
#  'coccygeus',
#  'phrenic vein',
#  'Valve of Kerckring',
#  'Effector Cell',
#  'Erector Muscle of the Hair',
#  'Foot Digit 4',
#  'Rotator Cuff',
#  'longissimus cervicis',
#  'Vertebral Body',
#  'Left Fallopian Tube',
#  'Sternal Manubrium',
#  'Peyer s Patch Germinal Center',
#  'diencephalon dura mater',
#  'left atrium auricular region',
#  'White Commissure',
#  'intrahepatic bile duct epithelium',
#  'Posterior Supratentorial Cistern',
#  'Longissimus Capitis',
#  'Squamous Alveolar Lining Cell',
#  'presubiculum',
#  'Umbilical Fissure',
#  'Reticular Fiber',
#  'endometrium epithelium',
#  'supraspinatus',
#  'Large Intestinal Crypt of the Lieberkuhn',
#  'eyelid blood vessel',
#  'nail plate',
#  'Right Lobe of the Liver',
#  'cervical artery',
#  'retrochiasmatic area',
#  'pupillary membrane',
#  'Uterus Serosal Surface',
#  'Body of the Corpus Callosum',
#  'Skeletal Fiber',
#  'Head Ears Eyes Nose and Throat',
#  'saphenous artery',
#  'limb joint',
#  'Dorsal Curve',
#  'Corneal Epithelium',
#  'Elbow Skin',
#  'hand phalanx',
#  'zygomaticus',
#  'blood',
#  'substantia nigra pars lateralis',
#  'Esophagus Secretion',
#  'tibia',
#  'thyroid gland left lobe',
#  ...]

# %%
def path_to_root(elem, ont_mappings):
    if elem not in ont_mappings or not ont_mappings[elem]:
        return []
    output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
    return output


def get_one_hop_neighbours(ont, K=1):
    ont_obj = Ontology(ont)
    triples = ont_obj.get_triples()
#     print (triples)
    entities = [(a,b) for (a,b,c) in triples]
    neighbours_dict = {elem: [elem] for elem in list(set(flatten(entities)))}
    for e1, e2 in entities:
        neighbours_dict[e1].append(e2)
        neighbours_dict[e2].append(e1)
    print (ont)
    rootpath_dict = ont_obj.parents_dict
    rootpath_dict = {elem: path_to_root(elem, rootpath_dict) for elem in rootpath_dict}
    ont = ont.split("/")[-1].split(".")[0]
    
    for entity in neighbours_dict:
        if entity in rootpath_dict and len(rootpath_dict[entity]) > 0:
            neighbours_dict[entity].extend(rootpath_dict[entity])
        else:
            continue
    
#     prop_triples = ont_obj.get_triples(subclass_of=False)
#     neighbours_dict_props = {c: [c] for a,b,c in prop_triples}
#     for e1, e2, p in prop_triples:
#         neighbours_dict_props[p].extend([e1, e2])

    #neighbours_dict = {**neighbours_dict, **neighbours_dict_props}
    
    # for elem in ont_obj.get_entities() + ont_obj.get_object_properties() + ont_obj.get_data_properties():
    #     if elem not in neighbours_dict:
    #         neighbours_dict[elem] = [elem]

    neighbours_dict = {el: neighbours_dict[el][:1] + sorted(list(set(neighbours_dict[el][1:])))
                       for el in neighbours_dict}
#     neighbours_dict = {el: neighbours_dict[el][:23] for el in neighbours_dict if len( neighbours_dict[el]) > 2}
    
    neighbours_dict = {ont + "#" + el: [ont + "#" + e for e in neighbours_dict[el]] for el in neighbours_dict}
    return neighbours_dict

neighbours_dicts = {ont.split("/")[-1].split(".")[0]: get_one_hop_neighbours(ont) for ont in list(set(flatten(ontologies_in_alignment)))}
max_neighbours = np.max(flatten([[len(el[e]) for e in el] for el in neighbours_dicts.values()]))
neighbours_lens = {ont: {key: len(neighbours_dicts[ont][key]) for key in neighbours_dicts[ont]}
                   for ont in neighbours_dicts}
neighbours_dicts = {ont: {key: neighbours_dicts[ont][key] + ["<UNK>" for i in range(max_neighbours -len(neighbours_dicts[ont][key]))]
              for key in neighbours_dicts[ont]} for ont in neighbours_dicts}

ontologies_in_alignment = [[el.split("/")[-1].split(".")[0] for el in ont] for ont in ontologies_in_alignment]
f = open("data_generic_multi_rootpath.pkl", "wb")
pickle.dump([data, emb_indexer, emb_indexer_inv, emb_vals, gt_mappings, neighbours_dicts, ontologies_in_alignment], f)
# Out:
# error list index out of range
# conference_ontologies/confOf.owl
# ../Anatomy/Ontologies/human.owl
# conference_ontologies/ekaw.owl
# conference_ontologies/conference.owl
# conference_ontologies/edas.owl
# ../Anatomy/Ontologies/mouse.owl
# conference_ontologies/iasted.owl
# conference_ontologies/cmt.owl
# conference_ontologies/sigkdd.owl

# %%
# AML test
def is_test(test_onto, key):
    return tuple([el.split("#")[0] for el in key]) in test_onto

results = []
all_ont_pairs = list(set([tuple([el.split("#")[0] for el in l]) for l in data.keys()]))
for i in list(range(0, len(all_ont_pairs), 3)):
    test_onto = all_ont_pairs[i:i+3]
    for ont_pair in test_onto:
        a, b, c = ont_pair[0], ont_pair[1], ont_pair[0] + "-" + ont_pair[1]
        java_command = "java -jar AML_v3.1/AgreementMakerLight.jar -s conference_ontologies/" + a + ".owl" + \
                            " -t conference_ontologies/" + b + ".owl -o AML-test-results/" + c + ".rdf -a"
        process = subprocess.Popen(java_command.split(), stdout=subprocess.PIPE)
        output, error = process.communicate()
    print (os.listdir("AML-test-results/"))
    pred_aml = load_alignments("AML-test-results/")
    pred_aml = [tuple([el.split("/")[-1] for el in key]) for key in pred_aml]
    tp = len([elem for elem in pred_aml if data[elem]])
    fn = len([key for key in gt_mappings if key not in set(pred_aml) and is_test(test_onto, key)])
    fp = len([elem for elem in pred_aml if not data[elem]])

    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    f1score = 2 * precision * recall / (precision + recall)
    f2score = 5 * precision * recall / (4 * precision + recall)
    f0_5score = 1.25 * precision * recall / (0.25 * precision + recall)
    print (precision, recall, f1score, f2score, f0_5score)
    
    metrics = [precision, recall, f1score, f2score, f0_5score]
    results.append(metrics)
    
    _ = [os.remove(f) for f in glob.glob('AML-test-results/*')]
    
print ("Final Results:", np.mean(results, axis=0))
# Out:
# ['confOf-sigkdd.rdf', 'iasted-sigkdd.rdf', 'cmt-ekaw.rdf']
# 0.8275862068965517 0.7272727272727273 0.7741935483870968 0.7453416149068324 0.8053691275167786
# ['confOf-iasted.rdf', 'conference-edas.rdf', 'cmt-sigkdd.rdf']
# 0.8148148148148148 0.5789473684210527 0.6769230769230768 0.6145251396648045 0.7534246575342465
# ['ekaw-sigkdd.rdf', 'conference-sigkdd.rdf', 'conference-confOf.rdf']
# 0.78125 0.6097560975609756 0.684931506849315 0.6377551020408163 0.7396449704142012
# ['confOf-edas.rdf', 'edas-iasted.rdf', 'cmt-conference.rdf']
# 0.7941176470588235 0.5094339622641509 0.6206896551724137 0.548780487804878 0.7142857142857143
# ['edas-sigkdd.rdf', 'conference-iasted.rdf', 'ekaw-iasted.rdf']
# 0.7916666666666666 0.48717948717948717 0.6031746031746031 0.5277777777777778 0.7037037037037036
# ['cmt-confOf.rdf', 'cmt-edas.rdf', 'edas-ekaw.rdf']
# 0.8181818181818182 0.5192307692307693 0.6352941176470589 0.5601659751037344 0.733695652173913
# ['conference-ekaw.rdf', 'confOf-ekaw.rdf', 'cmt-iasted.rdf']
# 0.7954545454545454 0.7142857142857143 0.7526881720430106 0.7291666666666666 0.7777777777777778
# Final Results: [0.80329596 0.59230088 0.67827067 0.62335897 0.74684309]

# %%
ontologies_in_alignment = [[el.split("/")[1].split(".")[0] for el in ont] for ont in ontologies_in_alignment][:-1] + [["human", "mouse"]]

# %%
for i in list(range(0, len(ontologies_in_alignment)-1, 3)):
    
    test_onto = ontologies_in_alignment[i:i+3]
    print (test_onto)
# Out:
# [['conference', 'ekaw'], ['confOf', 'ekaw'], ['ekaw', 'sigkdd']]
# [['edas', 'sigkdd'], ['confOf', 'sigkdd'], ['iasted', 'sigkdd']]
# [['confOf', 'iasted'], ['conference', 'iasted'], ['confOf', 'edas']]
# [['edas', 'iasted'], ['conference', 'edas'], ['cmt', 'ekaw']]
# [['cmt', 'confOf'], ['cmt', 'edas'], ['conference', 'sigkdd']]
# [['cmt', 'sigkdd'], ['conference', 'confOf'], ['edas', 'ekaw']]
# [['cmt', 'conference'], ['cmt', 'iasted'], ['ekaw', 'iasted']]

# %%
[[el for el in neighbours_dicts[ont] if len(neighbours_dicts[ont][el]) == 156] for ont in neighbours_dicts]
# Out:
# [[], [], [], [], [], [], ['human#Brain_Part'], [], []]

# %%
def count_non_unk(elem):
    return len([l for l in elem if l!="<UNK>"])
neighbours_dicts = {ont: {el: neighbours_dicts[ont][el][:int(sys.argv[1])] for el in neighbours_dicts[ont]
       if count_non_unk(neighbours_dicts[ont][el]) > int(sys.argv[2])} for ont in neighbours_dicts}
# Out:
# (167, 1240)

# %%
a = torch.randn((1,22,512))
b = torch.randn((1,1,512))
W_sub = nn.Linear(512, 1)

att_weights = W_sub(a - b.squeeze(1)[:, None]).squeeze(-1)

# %%
open

# %%
max_neighbours
# Out:
# 156

# %%
# !mkdir "KG-datasets"
for folder in glob.glob("../VeeAlign/datasets/*"):
    if folder.split("/")[-1] == "multifarm":
        continue
    ontologies = {}
    for ont in glob.glob(folder + "/ontologies/*"):
        ontologies["_".join(ont.split("/")[-1].split(".")[:-1])] = Ontology(ont)
    for alignment in glob.glob(folder + "/alignments/*"):
        ab = ".".join(alignment.split("/")[-1].split(".")[:-1])
        a,b = ab.split("-")
        prefix = "../RREA/CIKM/datasets/"
        if not os.path.isdir(prefix+ab):
            os.mkdir(prefix + ab)
        entities1_dict = {elem: idx for idx, elem in enumerate(set(ontologies[a].classes))}
        entities2_dict = {elem: idx for idx, elem in enumerate(set(ontologies[b].classes))}
        relations1_dict = {elem: idx for idx, elem in enumerate(set([el[-1] for el in ontologies[a].triples]))}
        relations2_dict = {elem: idx for idx, elem in enumerate(set([el[-1] for el in ontologies[b].triples]))}
        triples1 = ["\t".join([str(entities1_dict[u]), str(relations1_dict[w]), str(entities1_dict[v])]) for (u,v,w) in ontologies[a].triples]
        triples2 = ["\t".join([str(entities2_dict[u]), str(relations2_dict[w]), str(entities2_dict[v])]) for (u,v,w) in ontologies[b].triples]
        
        open(prefix + ab + "/ent_ids_1", "w+").write("\n".join(["\t".join([str(i),label]) for (label,i) in list(entities1_dict.items())]))
        open(prefix + ab + "/ent_ids_2", "w+").write("\n".join(["\t".join([str(i),label]) for (label,i) in list(entities2_dict.items())]))

        open(prefix + ab + "/triples_1", "w+").write("\n".join(triples1))
        open(prefix + ab + "/triples_2", "w+").write("\n".join(triples2))
        
        doc = minidom.parse(alignment)
        ls = list(zip(doc.getElementsByTagName('entity1'), doc.getElementsByTagName('entity2')))
        matches = [(u.getAttribute('rdf:resource').split("#")[-1], v.getAttribute('rdf:resource').split("#")[-1]) for (u,v) in ls]
        ls = []
        for match in matches:
            try:
                ls.append("\t".join((str(entities1_dict[match[0]]), str(entities2_dict[match[1]]))))
            except:
                print (match)
        
        open(prefix + ab + "/ref_ent_ids", "w+").write("\n".join(ls))
        
        
# Ontology("../VeeAlign/datasets/lebensmittel/ontologies/Google.Lebensmittel.v2.owl").triples
# Out:
# error list index out of range
# ('has_a_review', 'hasReview')
# ('contributes', 'authorOf')
# ('hasCostAmount', 'Price')
# ('hasName', 'Name_of_conference')
# ('startDate', 'Start_of_conference')
# ('endDate', 'End_of_conference')
# ('hasEmail', 'E-mail')
# ('contributes', 'write')
# ('reviewes', 'isReviewing')
# ('writtenBy', 'isWrittenBy')
# ('hasSurname', 'hasLastName')
# ('hasFirstName', 'hasFirstName')
# ('writes', 'hasRelatedPaper')
# ('has_the_first_name', 'hasFirstName')
# ('has_a_review_expertise', 'hasRating')
# ('has_the_last_name', 'hasLastName')
# ('writtenBy', 'reviewWrittenBy')
# ('hasBeenAssigned', 'reviewerOfPaper')
# ('assignedTo', 'hasReviewer')
# ('writePaper', 'writes')
# ('title', 'hasTitle')
# ('hasBeenAssigned', 'reviewes')
# ('hasAuthor', 'writtenBy')
# ('hasSubjectArea', 'dealsWith')
# ('email', 'hasEmail')
# ('hasConferenceMember', 'hasMember')
# ('memberOfConference', 'isMemberOf')
# ('hasAuthor', 'isWrittenBy')
# ('hasBeenAssigned', 'isReviewing')
# ('assignedTo', 'isReviewedBy')
# ('has_an_email', 'E-mail')
# ('is_given_by', 'presentationed_by')
# ('gives_presentations', 'presentation')
# ('email', 'E-mail')
# ('submitPaper', 'submit')
# ('has_an_email', 'hasEmail')
# ('has_a_track-workshop-tutorial_topic', 'hasTopic')
# ('has_the_last_name', 'hasSurname')
# ('has_the_first_name', 'hasFirstName')
# ('isReviewedBy', 'hasReviewer')
# ('isReviewing', 'reviewerOfPaper')
# ('isLocationOf', 'locationOf')
# ('hasLocation', 'heldIn')
# ('email', 'has_an_email')
# ('assignedByReviewer', 'invited_by')
# ('assignExternalReviewer', 'invites_co-reviewers')

# %%
alignment
# Out:
# '../VeeAlign/datasets/conference/alignments/conference-ekaw.rdf'

# %%
max_neighbours
# Out:
# 156

# %%
cos_sim(*extractUSEEmbeddings(["program committee member", "member program committee"]))
# Out:
# ['gastroepiploic vein',
#  'brachial plexus',
#  'glomerular parietal epithelium',
#  'foot digit bone',
#  'intestinal epithelium',
#  'omotransverse',
#  'bronchus smooth muscle tissue',
#  'subscapular vein',
#  'left adrenal gland',
#  'pancreatico-duodenal vein',
#  'metacarpal/metatarsal bone',
#  'long bone',
#  'rejected paper',
#  'respiratory system part',
#  'foot skin',
#  'bile duct intrahepatic part',
#  'incus',
#  'gracilis',
#  'bulboglandular',
#  'gracilis',
#  'epidermal ridges',
#  'sublingual gland',
#  'apex of arytenoid',
#  'unipolar neuron',
#  'roof of the fourth ventricle',
#  'dental pulp',
#  'reject paper',
#  'carpal joint',
#  'bulbourethral gland secretion',
#  'squamous epithelium',
#  'bone marrow blood-forming cell',
#  'ovarian vein',
#  'cornea',
#  'immature lymphocyte',
#  'phrenic artery',
#  'frontal bone',
#  'lower respiratory tract',
#  'cecum',
#  'laryngeal connective tissue',
#  'common bile duct',
#  'external maleolus',
#  'forelimb skin',
#  'facial nerve nucleus',
#  'bile duct tissue',
#  'subependymal tissue',
#  'conference event',
#  'corona dentis',
#  't-lymphoblast',
#  'otolymph',
#  'multipotent stem cell',
#  'visceral mesothelium',
#  'left lung hilus',
#  'stomach lesser curvature',
#  'levator palpebrae superioris',
#  'intercostal nerve',
#  'maxillary vein',
#  'esophagus smooth muscle longitudinal layer',
#  'nonmember registration fee',
#  'upper jaw incisor',
#  'ductus venosus',
#  'anterior olfactory lobule',
#  'endothelial cell',
#  'multi-author volume',
#  'third ventricle ependyma',
#  'peroneal nerve',
#  'cricoarytenoid joint',
#  'vastus medialis',
#  'myocardium',
#  'large intestine',
#  'exocrine gland',
#  'nucleus of trapezoid body',
#  'intestinal mucosa',
#  'left renal artery',
#  'pericardiacoophrenic artery',
#  'right lung alveolus',
#  'trigeminal nucleus',
#  'external acoustic meatus',
#  'lens anterior epithelium',
#  'frontal sulcus',
#  'activated mature cytotoxic t-lymphocyte',
#  'thyroid gland oxyphil cell',
#  'oxyphil cell',
#  'activity after conference',
#  'ductus santorini',
#  'thyroid gland lobe',
#  'ganglionic layer',
#  'acromial thoracic artery',
#  'stomach blind ventricular sac',
#  'prostate gland secretion',
#  'bronchus',
#  'olfactory tract',
#  'epigastric artery',
#  'inferior suprarenal vein',
#  'plantar fascia',
#  'foramen caecum',
#  'lower respiratory tract epithelium',
#  'endothelium of the glomerular capillary',
#  'cerebral white matter',
#  'sartorius',
#  'spermatozoon',
#  'dentin',
#  'coronary artery',
#  'acinar salivary gland system',
#  'lymphatic capillary',
#  'pulmonary vein',
#  'left colon',
#  'genioglossus',
#  'arachnoid mater',
#  'body region',
#  'vagus x nerve trunk',
#  "meckel's cartilage",
#  'primitive stem cell with some degree of commitment to the erythroid lineage',
#  'knee bone',
#  'hand digit',
#  'temporal lobe',
#  'bronchial tree',
#  'erythroid progenitor cell',
#  'free time break',
#  'nasal nerve',
#  'tensor tympani',
#  'spleen marginal sinus',
#  'internal spermatic vein',
#  'large intestinal muscularis mucosa',
#  'right lung',
#  'mammary gland lobule',
#  'middle cervical ganglion',
#  'metatarsal bone digit 2',
#  'metacarpal bone digit 4',
#  'personal publication history',
#  'septal cortex',
#  'best research paper award',
#  'retrochiasmatic area',
#  'has a date of issue',
#  'tentorium cerebelli',
#  'cardia',
#  'parathyroid gland capsule',
#  'saphenous artery',
#  'liver acinus',
#  'uterine horn',
#  'organizing committee',
#  'cricoarytenoid',
#  't-immunoblast',
#  'segmental bronchus epithelium',
#  'splenic hilum',
#  'vestibulocochlear viii ganglion vestibular component',
#  'bile canaliculus',
#  'external pterygoid muscle',
#  'pancreas head',
#  'vestibular aqueduct',
#  'taste bud',
#  'item',
#  'small intestinal mucosa',
#  'interlobular artery',
#  'right common carotid artery',
#  'bile duct extrahepatic part',
#  'ascending aorta branch',
#  'serum',
#  'epigastric region',
#  'central vein',
#  'other limb bone',
#  'thyroid gland right lobe',
#  'meninges',
#  'cerebellum external granule cell layer',
#  'upper arm skin',
#  'left common carotid artery',
#  'pulmonary artery',
#  'synchondrosis',
#  'medial marginal vein',
#  'cervical spinal cord',
#  'alveolar epithelium',
#  'lower arm connective tissue',
#  'posterior temporal artery',
#  'track',
#  'anterior wall of the tympanum',
#  'ovary theca externa',
#  'geniculate ganglion',
#  'thoraco-acromial artery',
#  'hippocampus stratum radiatum',
#  'eyelid subcutaneous connective tissue',
#  'phrenic vein',
#  'ascending parietal convolution',
#  'sputum',
#  'nostril',
#  'dentate gyrus',
#  'foot skin',
#  'retina inner nuclear layer',
#  'has end date time',
#  'scientifically organises',
#  'frontal artery',
#  'ascending limb of the henle s loop',
#  'axillary artery branch',
#  'right renal vein',
#  'suprasellar region',
#  'pigmented retinal epithelium',
#  'upper back bone',
#  'spinal cord dorsal column',
#  'bronchus cartilage',
#  'posterior facial vein',
#  'spermatocyte',
#  'nipple',
#  'trigeminal v ganglion',
#  'basilar artery branch',
#  'thymic b-lymphocyte',
#  'stratum disjunctum',
#  'hand bone',
#  'author attendee cd registration fee',
#  'anterior lingual gland',
#  'buccal mucosa',
#  'inferior epigastric artery',
#  'sternoclavicular joint',
#  'axillary tail of the breast',
#  'maternal placental artery',
#  'connective tissue proper',
#  'gastric vein',
#  'basilar membrane',
#  'corpora albicantia',
#  'granulosa cell',
#  't-prolymphocyte',
#  'vein',
#  'peroneal artery',
#  'anterior surface of the prostate',
#  'outer canthus',
#  'guard hair',
#  'palatal shelf',
#  'foveolar cell',
#  'ilio-lumbar artery',
#  'dorsal curve',
#  'fat',
#  'membrane of the brain or spinal cord',
#  'cervical artery',
#  'extrinsic auricular muscle',
#  'endocervix',
#  'lumbar vertebra',
#  'eye chamber',
#  'seminiferous tubule epithelium',
#  'small intestine villus',
#  'head/neck blood vessel',
#  'nephron',
#  'endometrial cavity',
#  'has decision',
#  'paper id',
#  'quadratus lumborum',
#  'upper arm nerve',
#  'inferior mesenteric artery',
#  'lentiform nucleus',
#  'posterior external jugular vein',
#  'sensory organ',
#  'abdomen',
#  'inferior palpebral fold',
#  'internal nare',
#  'subscapular artery',
#  'peritoneal mesothelial cell',
#  'caudate-putamen',
#  'hand digit connective tissue',
#  'interphalangeal joint of the foot',
#  'pons',
#  'back nerve',
#  'prepontine cistern',
#  'central sulcus of rolando',
#  'epicardium',
#  'has location',
#  'carotid artery',
#  'subscapular artery',
#  'anatomic surface',
#  'hand digit nerve',
#  'lumbar vertebra 4',
#  'deep lymphatic vessel',
#  'spinal cord column',
#  'inferior temporal gyrus',
#  'hair bulb',
#  'search',
#  'pons varolii',
#  'gastric tissue',
#  'left subcostal vein',
#  'nail bed',
#  'pericardium',
#  'upper jaw tooth',
#  'middle temporal vein',
#  'anterior surface of the stomach',
#  'superficial cervical artery',
#  'has biography',
#  'review',
#  'osteoblast',
#  'postcentral sulcus',
#  'posterior fossa',
#  'musculoskeletal system part',
#  'mature cytotoxic t-lymphocyte',
#  'transversus thoracis',
#  'duct salivary gland system',
#  'ulna',
#  'accepted paper',
#  'infratentorial brain',
#  'parotid gland lymph node',
#  'neck muscle',
#  'cricoarytenoid muscle',
#  'hypogastric nerve plexus',
#  'nucleus of the solitary tract',
#  'spinal cord ventral column',
#  'hemispheric cistern',
#  'gastrointestinal system',
#  'person',
#  'hypoglossal xii nucleus',
#  'fornix',
#  'conjunctiva',
#  'spinal ganglion/nerve',
#  'thoracic vertebra 3',
#  'scapula',
#  'facial artery',
#  'superficial intracranial venous system',
#  'stomach proventricular region',
#  'bronchus basal lamina',
#  'visceral layer of bowman s capsule',
#  'is the 1th part of',
#  'middle cerebral artery branch',
#  'bronchus basement membrane',
#  'c3 vertebra',
#  'fascicle',
#  'common femoral artery',
#  'larynx mucosa',
#  'tail vein',
#  'study at',
#  'obsolete class',
#  'right hepatic duct',
#  'eyelid',
#  'ureter luminal urothelium',
#  'ulnar nerve',
#  'head',
#  'conference',
#  'head blood vessel',
#  'hair follicle',
#  'primordial follicle',
#  'esophagus',
#  'microcirculatory bed',
#  'flat bone',
#  'pancreatic endocrine secretion',
#  'adrenal vein',
#  'tongue skeletal muscle tissue',
#  'large intestinal crypt of the lieberkuhn',
#  'hotel fee',
#  'ureter adventitia',
#  'inferior palpebral vein',
#  'definition',
#  'central nervous system',
#  'reproductive organ',
#  'accessory xi nucleus',
#  'eosinophil',
#  'esophagus muscularis mucosa',
#  'minor calyx',
#  'vestibulocochlear viii nerve cochlear component',
#  'leg nerve',
#  'testis',
#  'retinal artery',
#  'kidney interstitium',
#  'cervical vertebra 4',
#  'city of conference',
#  'radix dentis',
#  'lingual tonsillar tissue',
#  'iliac circumflex artery',
#  'brunner s gland',
#  'eye posterior chamber',
#  'lesser tuberosity',
#  'temporal cortex',
#  'trigeminal v motor nucleus',
#  'skeletal fiber',
#  'anterior meningeal artery',
#  'trachea connective tissue',
#  'thymic vein',
#  'social program',
#  'obsolete class',
#  'gland',
#  'cuboidal cell',
#  'poster session',
#  'superior infratentorial cistern',
#  'signal processing topic',
#  'respiratory system venous smooth muscle',
#  'internal elastic membrane',
#  'hip bone',
#  'blood vessel',
#  'cardiac nerve plexus',
#  'phrenic nerve trunk',
#  'respiratory tract',
#  'scala vestibuli',
#  'sphenoid sinus',
#  'tarsal artery',
#  'pericallosal artery',
#  'activity',
#  'quadrigeminal body',
#  'cerebral gyrus',
#  'masseter',
#  'tonsil',
#  'placenta metrial gland',
#  'small intestinal serosal surface',
#  'cauda equina',
#  'femoral nerve',
#  'bladder',
#  'lip philtrum',
#  'subclass of',
#  'chest',
#  'vagus x nerve right recurrent laryngeal branch',
#  'extensor digitorum communis',
#  'seminal vesicle secretion',
#  'auricle',
#  'money',
#  'central canal',
#  'main bronchus smooth muscle',
#  'axillary nerve',
#  'foot',
#  'fovea',
#  'anal canal',
#  'corneal epithelium',
#  'promontory',
#  'common plantar digital arteries',
#  'digital vein',
#  'palmar hand interosseus muscle',
#  'inferior cerebral vein',
#  'erector spinae',
#  'prostatic portion of the male urethra',
#  'histiocyte',
#  'inferior olive medial nucleus',
#  'knee',
#  'body fluid or substance',
#  'lower leg muscle',
#  'large intestine serosa',
#  'rib 1',
#  'integumental system gland',
#  'herring body',
#  'auricular artery',
#  'other anatomic concept',
#  'conference session',
#  'renal pelvis',
#  'sternebra',
#  'arterial system endothelium',
#  'nucleus ambiguus',
#  'external acoustic meatus osseus part',
#  'has part',
#  'cholinergic enteric nerve',
#  'default choice',
#  'claustrum',
#  'boolean',
#  'medial tarsal artery',
#  'activated lymphocyte',
#  'lamina lucida',
#  'lipocyte',
#  'bone tissue',
#  'aqueous humour',
#  'descending colon',
#  'navicular',
#  'medulla oblongata',
#  'lymph node trabecula',
#  'reception',
#  'write review',
#  'chondroblast',
#  'lateral geniculate nucleus',
#  'gomphosis',
#  'anterior annular ligament',
#  'left coronary artery',
#  'sebaceous gland',
#  'fee for extra trip',
#  'semimembranosus',
#  'foot blood vessel',
#  'male reproductive gland/organ',
#  'intestinal secretion',
#  'chest nerve',
#  'lymph node sinus',
#  'hippocampal fissure',
#  'endocrine cell and neuroendocrine cell',
#  'spinal accessory nerve',
#  'scalene muscle',
#  'presenter',
#  'median vein',
#  'dorsum of the tongue',
#  'vein endothelium',
#  'cranium',
#  'anal region skeletal muscle',
#  'fibula',
#  'outer supporting cell',
#  'rib 3',
#  'common hepatic duct',
#  'performance topic',
#  'tibilais cranialis',
#  'vagina stroma',
#  'enable virtual meeting',
#  'mastoid process',
#  'metacarpus',
#  'female membranous urethra',
#  'spinal artery',
#  'outflow tract aortic component',
#  'lower gastrointestinal tract',
#  'venule',
#  'external anal sphincter',
#  'heart septum',
#  'duodenum',
#  'sural vein',
#  'frontal horn of the lateral ventricle',
#  'spinal nerve plexus',
#  'lacrimal sac',
#  'eustachian valve',
#  'external acoustic meatus cartilaginous part',
#  'memory b cell',
#  'anterior division',
#  'trachea basement membrane',
#  'has a location',
#  'inner ear epithelium',
#  'eye surface',
#  'thymus medulla',
#  'author of paper',
#  'auditory tube',
#  'single hotel room',
#  'seminal fluid',
#  'grey matter',
#  'adrenal fluid or secretion',
#  'shoulder',
#  'ductal epithelium',
#  'pelvis blood vessel',
#  'tibial artery',
#  'geniculate body',
#  'brown fat',
#  'viscerocranium bone',
#  'has topic',
#  'bile duct',
#  'splenic artery',
#  'is used for',
#  'ovary',
#  'right lung alveolar system',
#  'lymph node by anatomic site',
#  'paper in volume',
#  'bladder muscular coat',
#  'clavicle',
#  'glomeruloza zone',
#  'interatrial septum',
#  'saccule',
#  'base of arytenoid',
#  'ciliary muscle',
#  'reticular tegmental nucleus',
#  'shoulder muscle',
#  'cerebellum internal granule cell layer',
#  'sphincter pupillae muscle',
#  'posterior cerebral artery branch',
#  'cortex',
#  'urethralis',
#  'spinal cord ventral horn',
#  'l3 vertebra',
#  'constrictor muscle of pharynx',
#  'inguinal lymph node',
#  'connective tissue',
#  'stomach body',
#  'caudate nucleus',
#  'knee joint',
#  'ovary follicle fluid',
#  'is held after',
#  'olfactory bulb glomerular layer',
#  'spinal cord central canal',
#  'basisphenoid bone',
#  'intrinsic tongue muscle transverse component',
#  'perikaryon',
#  'ventral thalamus',
#  'nail',
#  'area of broca',
#  'superior vagus x ganglion',
#  'accumbens nucleus',
#  'colorectal zone of the anal canal',
#  'platinum supporter',
#  'is sent after',
#  'mamillary body',
#  'oculomotor nucleus',
#  'posterior circumflex artery',
#  'left vagus x nerve trunk',
#  'skin',
#  'blood vessel smooth muscle',
#  'reproductive gland',
#  'hamstring muscle',
#  'sphincter colli superficialis',
#  'lateral ventricle subependymal layer',
#  'medial femoral circumflex artery',
#  'psoas major',
#  'hindlimb blood vessel',
#  'epithelial receptor cell',
#  'supra-orbital vein',
#  'prostatic epithelium',
#  'bid',
#  'transverse rectal fold',
#  'rest of ureter',
#  'kidney subcortical veins',
#  'superior temporal gyrus',
#  'other body part',
#  'prostate gland anterior lobe',
#  'subcapsular epithelium of the lens',
#  'alveolar sac',
#  'gastrointestinal sphincter',
#  'prepositus hypoglossal nucleus',
#  'oral epithelium',
#  'nasal mucus',
#  'pars posterior',
#  'distal straight tubule postmacula segment',
#  'superior sagittal sinus',
#  'synovial fluid',
#  'urine',
#  'choroid plexus',
#  'macrophage',
#  'superior wall of the nasopharynx',
#  'ureter',
#  'lateral wall of the oropharynx',
#  'vascular endothelium',
#  'conference dinner',
#  'cuboidal oviduct epithelium',
#  'mammary gland',
#  'author',
#  'trachea basement membrane',
#  'anterior surface of the lens',
#  'precursor nk-cell',
#  'autonomic nervous system',
#  'retina photoreceptor layer inner segment',
#  'appendicular skeleton',
#  'foot digit nerve',
#  'umbilical cord blood stem cell',
#  'metacarpal bone',
#  'vagus x nerve left recurrent laryngeal branch',
#  'pharynx epithelium',
#  'autopod joint',
#  'subclass of',
#  'gastrointestinal system',
#  'audiovisual equipment',
#  'molecular layer of the cerebellum',
#  'enterocyte',
#  'cortical vein',
#  'thyroid gland epithelial tissue',
#  'is menu of',
#  'renal cortex artery',
#  'alveolar duct',
#  'liver lobule',
#  'basaloid cell',
#  'internal anal sphincter',
#  'renal cortex',
#  'membranous canal of the cochlea',
#  'tuberomammillary nucleus',
#  'medial geniculate nucleus',
#  'nephron',
#  'popliteal vein',
#  'sponsor city',
#  'bile duct epithelium',
#  'cleidocephalic',
#  'bronchiole',
#  'hematopoietic and lymphoid tissue',
#  'cerebellum lobule viii',
#  'sign',
#  'choroidal blood vessel',
#  'intra-thoracic lymph node',
#  'bronchus reticular lamina',
#  'poster paper',
#  'perilymph',
#  'cleidobrachial',
#  'anterior facial vein',
#  'trochlear iv nerve',
#  'person',
#  'session chair',
#  'vagina squamous epithelium',
#  't11 vertebra',
#  'tutorial',
#  'internal parieto-occipital fissure',
#  'non-granular leukocyte',
#  'paranasal sinus',
#  'paracentral nucleus',
#  'is needed for',
#  'vagal triangle',
#  'large intestinal mucosa',
#  'inferior olive beta subnucleus',
#  'registration form',
#  'heart endocardium',
#  'respiratory bronchiole',
#  'extraglomerular mesangium',
#  'joint of girdle',
#  'rib tubercle',
#  'vaginal fornix',
#  'long bone epiphysis',
#  'lower jaw incisor',
#  'mouse anatomy',
#  'sphincter colli superficialis',
#  'best student paper award',
#  'mesenteric artery',
#  'auditory ossicle',
#  'medial vestibular nucleus',
#  'granulocyte',
#  'submucosal tissue of human prostate',
#  'primary choana',
#  'ureteric artery',
#  'pituitary gland',
#  'sponsorship',
#  'left lung bronchiole',
#  'organization',
#  'right lung cranial lobe',
#  'renal afferent vessel',
#  'pancreas',
#  'external plantar artery',
#  'esophageal artery',
#  'upper leg bone',
#  'epidermis',
#  'radius bone',
#  'coat hair bulb',
#  'left lung',
#  'diaphragm part',
#  'frontal association cortex',
#  'lower eyelid',
#  'hepatic tissue',
#  'palmar region',
#  'transitional zone of the prostatic parenchyma',
#  'renal tubule',
#  'alveolar wall',
#  'posterior semicircular canal',
#  'median artery palmar branch',
#  'leg skin',
#  'thyroepiglottic ligament',
#  'student',
#  'cricothyroid muscle',
#  'heart septum',
#  'pharyngeal tonsil',
#  'pericardial fluid',
#  'ovarian vein',
#  'hotel',
#  'paper',
#  'auricular artery',
#  'muscle and fasciae of the thorax',
#  'appendage of the uterus',
#  'sponzor fee',
#  'mammary gland smooth muscle',
#  'elastin fiber',
#  'space of fontana',
#  'anterior thalamic group',
#  'author attendee book registration fee',
#  'right renal artery',
#  'any uri',
#  'chromophobe cell',
#  'vas deferens smooth muscle',
#  'has menu',
#  'tract of burdach',
#  'distal convoluted tubule',
#  'maxillary artery',
#  'oculomotor nerve',
#  'endocrine sex organ',
#  'visceral serous pericardium',
#  'adductor group (leg)',
#  'intestine muscularis mucosa',
#  'surface of the prostate',
#  'dorsal venous arch',
#  'lesser omentum',
#  'nerve',
#  'artery endothelium',
#  'sesamoid bone',
#  'has first name',
#  'ventricle brain',
#  'cervical nerve',
#  'merkel cell',
#  'superior temporal sulcus',
#  'bronchiole',
#  'ocular angle artery',
#  'stratum lucidum',
#  'tympanic membrane',
#  'joint',
#  'portal vein',
#  'neck organ',
#  'septal coronary artery',
#  'member pc',
#  'heart ventricle membranous part',
#  'call for reviews',
#  'dorsal metatarsal vein',
#  'lobe of the left lung',
#  'suprachorioid lamina',
#  'accepted by',
#  'brachial artery',
#  'artery smooth muscle tissue',
#  'rostrum of the corpus callosum',
#  'internal intercostal muscle',
#  'renal straight tubule',
#  'dorsal vena of penis',
#  'lymphoid blood-forming cell',
#  'peritoneal cavity greater sac',
#  'has programme',
#  'septohippocampal nucleus',
#  'tensor fasciae lata',
#  'review',
#  'glomerular capillary basement membrane',
#  'has an abstract',
#  'anterior inferior frontal convolution',
#  'organizational meeting',
#  'important dates',
#  'temporo-maxillary vein',
#  'celiac ganglion',
#  'proper palmal digital arteries',
#  'genioglossus',
#  'female urethral meatus',
#  'frontal bone',
#  'outer renal medulla',
#  'forelimb nerve',
#  'lateral ventricle',
#  'inferior thyroid artery',
#  'cementocyte',
#  'thorax connective tissue',
#  'hair cortex',
#  'abstract',
#  'anterior part of the calcarine fissure',
#  'nasal cavity',
#  'girdle bone',
#  'book proceeding',
#  'synonym',
#  'inferior internal articular artery',
#  'sinus of valsava',
#  'major palatine artery',
#  'hymen',
#  'tunica intima',
#  'meniscus medialis',
#  'longissimus cervicis',
#  'hepatic duct extrahepatic part',
#  'descending aorta',
#  'cerumen',
#  'is dated on',
#  'hindlimb muscle',
#  'subependymal cell',
#  'shoulder',
#  'epithelioid cell',
#  'peripheral nerve',
#  'written by',
#  'postero-lateral fissure',
#  'transverse colon',
#  'rib 7',
#  'colostrum',
#  'publisher',
#  'middle cuneiform bone of the foot',
#  'prostate gland smooth muscle',
#  'gigantocellular reticular nucleus',
#  'has a volume',
#  'uterus',
#  'seromucous salivary gland',
#  'large intestinal submucosa',
#  'penis foreskin',
#  'globus pallidus',
#  'medial saphenous vein',
#  'dorsal hand interosseous muscle',
#  'thermoreceptor',
#  'enteric ganglion',
#  'second portion of the duodenum',
#  'dorsal mesogastrium',
#  'cochlear duct',
#  'vitreous body',
#  'pre-b lymphocyte',
#  'esophagus',
#  'lateral orbitofrontal artery',
#  'large intestinal serosal surface',
#  'exocrine pancreas',
#  'lower back nerve',
#  'inguinal mammary gland',
#  'computer networks security topic',
#  'vas deferens',
#  'lateral wall of the bladder',
#  'vaginal epithelium',
#  'liver bare area',
#  'vestibular hair cell',
#  'hepatobiliary system',
#  'reject rating',
#  'scapholunate',
#  'body fluid/substance',
#  'supratentorial cistern',
#  'extensor carpi ulnaris',
#  'neuroendocrine cell',
#  'pia mater',
#  'fenestra rotunda',
#  'right lung lobe',
#  'cerebellar vein',
#  'endometrium glandular epithelium',
#  'myeloid cell',
#  'uterine cervix',
#  'thoracic vertebra 4',
#  'anterior descending coronary artery',
#  'cd8 plus t-lymphocyte',
#  'thymus trabecula',
#  'omohyoid',
#  'spinal cord meninges',
#  'brachial artery',
#  'kidney',
#  'rib 10',
#  'liver quadrate lobe',
#  'longissimus cervicis',
#  'quadrigeminal cistern',
#  'loop of henle ascending limb thick segment',
#  'peripheral nerve',
#  'demo paper',
#  'foot bone',
#  'forebrain arachnoid mater',
#  'hyaloid vascular plexus',
#  'medial palpebral ligament',
#  'body of the corpus callosum',
#  'inferior rectal artery',
#  'thoracic cavity connective tissue',
#  "small intestine peyer's patch",
#  'administrative event',
#  'superior parathyroid gland',
#  'liver acinus',
#  'respiratory system',
#  'sural artery',
#  'pancreatic acinus',
#  'superficial cervical lymph node',
#  'intercostal fascia',
#  'thymocyte',
#  'rib 12',
#  'urogenital muscle',
#  'spinal cord dorsal nucleus',
#  'lymphatic vessel',
#  'maxilla',
#  'nucleus of the spinal tract of the trigeminal nerve',
#  'other body fluids and secretions',
#  'has review',
#  'spinal nerve root',
#  'antrum pylori',
#  'neck connective tissue',
#  'superior vesical artery',
#  'renal cortex tubule',
#  'shoulder connective tissue',
#  'cochlea',
#  'spermatic vein',
#  'coccygeal vertebra',
#  'information for participants',
#  'pharynx muscle',
#  'enamel',
#  'evaluated paper',
#  'ileal vein',
#  'right lung caudal lobe',
#  'genito-urinary region',
#  'small intestine submucosa',
#  'registration non-member',
#  'flyer',
#  'location',
#  'corneal blood vessel',
#  'vertebral canal',
#  'lung tissue',
#  'medial femoral vein',
#  'circular ligament of the tooth',
#  'cuneiform cartilage',
#  'tongue',
#  'thymic lymphoid tissue',
#  'kidney arterial blood vessel',
#  'forelimb joint',
#  'cardiac vein',
#  'median cubital vein',
#  'optic disc',
#  'initiates',
#  'foot bone',
#  'femoral artery branch',
#  'sensory hair',
#  'heart valve',
#  'male breast',
#  'bone surface',
#  'one day presenter',
#  'mullerian duct',
#  'trachea non-cartilage connective tissue',
#  'postgerminal center marginal zone b-lymphocyte',
#  'epineurium',
#  'superior palpebral fold',
#  'basement membrane',
#  'megakaryoblast',
#  'adrenal gland zona reticularis',
#  'cervicothoracic ganglion',
#  'spinal nerve plexus',
#  'anterior horn cell',
#  'coat hair',
#  'thoracic esophagus',
#  'distal rib',
#  'foot digit connective tissue',
#  'name',
#  'metatarsal bone digit 4',
#  'retina nerve fiber layer',
#  'auricular ligament',
#  'part of afferent arteriole forming juxtaglomerular complex',
#  'brain stem',
#  'impulse conducting system',
#  'harderian gland',
#  'foot digit 3',
#  'female reproductive system fluid/secretion',
#  'adrenal gland capsule',
#  'male urethra ostium',
#  'administrator',
#  'kidney collecting duct',
#  'respiratory system basal lamina',
#  'bronchiole epithelium',
#  'pelvis skin',
#  'hepatic portal vein',
#  'spinal cord basal nucleus',
#  'is reviewing',
#  'metacarpal bone digit 2',
#  'helper-inducer t-lymphocyte',
#  'interstitial cell',
#  'anterior median fissure of spinal cord',
#  'brachialis',
#  'lumbar sympathetic nerve trunk',
#  'has a review',
#  'full day tour',
#  'communicating artery',
#  'costal arch',
#  'meta-reviewer',
#  'lateral rectus extraocular muscle',
#  'brain arachnoid matter',
#  'os penis',
#  'processus cochleariformis',
#  ...]

# %%
def path_to_root(elem, ont_mappings):
    if elem not in ont_mappings or not ont_mappings[elem]:
        print ("Returning", elem)
        return []
    print ("Elem:", elem)
    output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
    return output

ont_mappings = Ontology("conference_ontologies/conference.owl").parents_dict
d = {elem: path_to_root(elem, ont_mappings) for elem in ont_mappings}
d
# Out:
# Elem: Conference_participant
# Returning Person
# Elem: Regular_author
# Elem: Conference_contributor
# Returning Person
# Elem: Co-chair
# Elem: Committee_member
# Returning Person
# Elem: Abstract
# Elem: Extended_abstract
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# Elem: Written_contribution
# Elem: Poster
# Elem: Conference_contribution
# Returning Conference_document
# Elem: Regular_contribution
# ...
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in path_to_root
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 6, in <listcomp>
#     output = flatten([[e] + path_to_root(e, ont_mappings) for e in ont_mappings[elem]])
#   File "<ipython-input-211-5839aa11c665>", line 5, in path_to_root
#     print ("Elem:", elem)
#   File "/home/vlead/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py", line 402, in write
#     self.pub_thread.schedule(lambda : self._buffer.write(string))
#   File "/home/vlead/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py", line 202, in schedule
#     if self.thread.is_alive():
#   File "/home/vlead/anaconda3/lib/python3.7/threading.py", line 1101, in is_alive
#     if self._is_stopped or not self._started.is_set():
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vlead/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'RecursionError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vlead/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1151, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/vlead/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 319, in wrapped
#     return f(*args, **kwargs)
#   File "/home/vlead/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 353, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/vlead/anaconda3/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/vlead/anaconda3/lib/python3.7/inspect.py", line 1464, in getframeinfo
#     lines, lnum = findsource(frame)
#   File "/home/vlead/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 173, in findsource
#     file = getsourcefile(object) or getfile(object)
#   File "/home/vlead/anaconda3/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/vlead/anaconda3/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/home/vlead/anaconda3/lib/python3.7/inspect.py", line 63, in ismodule
#     def ismodule(object):
# KeyboardInterrupt
# ---------------------------------------------------------------------------

# %%
[(el, ont_mappings[el]) for el in ont_mappings if len(ont_mappings[el]) > 1]

# %%
ont_mappings
# Out:
# {'Conference_participant': ['Person'],
#  'Regular_author': ['Conference_contributor'],
#  'Co-chair': ['Committee_member'],
#  'Abstract': ['Extended_abstract'],
#  'Active_conference_participant': ['Conference_contributor',
#   'Invited_speaker',
#   'Regular_author',
#   'Conference_participant'],
#  'Information_for_participants': ['Conference_document'],
#  'Submitted_contribution': ['Regular_contribution',
#   'Poster',
#   'Written_contribution'],
#  'Conference_applicant': ['Person'],
#  'Camera_ready_contribution': ['Accepted_contribution'],
#  'Program_committee': ['Committee'],
#  'Conference_volume': ['Conference'],
#  'Contribution_1th-author': ['Regular_author'],
#  'Call_for_paper': ['Conference_document'],
#  'Conference_announcement': ['Conference_document'],
#  'Committee_member': ['Person'],
#  'Regular_contribution': ['Written_contribution'],
#  'Conference_contribution': ['Conference_document'],
#  'Chair': ['Committee_member'],
#  'Contribution_co-author': ['Regular_author'],
#  'Track': ['Conference_part'],
#  'Accepted_contribution': ['Reviewed_contribution'],
#  'Review': ['Conference_document'],
#  'Written_contribution': ['Poster',
#   'Regular_contribution',
#   'Conference_contribution'],
#  'Late_paid_applicant': ['Paid_applicant'],
#  'Poster': ['Conference_contribution'],
#  'Passive_conference_participant': ['Conference_participant'],
#  'Conference_contributor': ['Person'],
#  'Workshop': ['Conference_part'],
#  'Organizer': ['Organization', 'Committee_member'],
#  'Call_for_participation': ['Conference_document'],
#  'Steering_committee': ['Committee'],
#  'Organizing_committee': ['Committee'],
#  'Reviewer': ['Person'],
#  'Paid_applicant': ['Registeered_applicant'],
#  'Track-workshop_chair': ['Person'],
#  'Presentation': ['Conference_contribution'],
#  'Rejected_contribution': ['Reviewed_contribution'],
#  'Invited_talk': ['Presentation'],
#  'Extended_abstract': ['Regular_contribution'],
#  'Invited_speaker': ['Conference_contributor'],
#  'Conference_www': ['Conference_document'],
#  'Paper': ['Regular_contribution'],
#  'Tutorial': ['Conference_part'],
#  'Registeered_applicant': ['Conference_applicant'],
#  'Reviewed_contribution': ['Submitted_contribution'],
#  'Early_paid_applicant': ['Paid_applicant']}

# %%
ont_mappings['blood vessel']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-203-9c560a177dc4> in <module>
# ----> 1 ont_mappings['blood vessel']
#
# KeyError: 'blood vessel'
